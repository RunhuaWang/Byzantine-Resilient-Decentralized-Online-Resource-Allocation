# %% [raw]
# 观察IOS+decentralized online economic dispatch algorithm在拜占庭攻击下的算法性能
# 实验设置：4个热能发电站 2个风能发电站
# 时变风速服从的Weibull distribution的参数c和kappa
# 时变的需求侧用电需求D
# c的变化：[3,25]间的均匀分布
# kappa的变化：[2，3]间的均匀分布
# D的变化为：均值为70 标准差为5的高斯分布
# 拜占庭攻击：假设一个风力发电站受到拜占庭攻击 向其他发电站发送恶意的对偶变量
# 大值攻击 large-value Byzantine attacks
#
# 加上一个adaptive clipping

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
from sympy import *
import math 
from datetime import datetime
from scipy.special import gamma, factorial
import scipy.special as sc

# %%
#定义变量 
thermal_power_station_strategy=np.zeros(shape=(4,1000)) 
wind_power_station_strategy=np.zeros(shape=(2,1000))
c_wind_speed= np.loadtxt("./data/c_wind_speed_uniform_distribution_(3,25).txt")      
kappa_wind_speed= np.loadtxt("./data/kappa_wind_speed_uniform_distribution_(2,3).txt")  
#c_wind_speed_list= np.loadtxt("./data/c_wind_speed_normal_distribution_(15,2).txt")      
#kappa_wind_speed_list= np.loadtxt("./data/kappa_wind_speed_normal_distribution_(2,0.5).txt") 
d_power_demand=np.loadtxt("./data/d_power_demand_normal_distribution_(70,5).txt") #时变的需求侧用电需求 
thermal_power_station_dual_variable=np.zeros(shape=(4,1000))
wind_power_station_dual_variable=np.zeros(shape=(2,1000))#两个风力发电站中有一个是受到拜占庭攻击的 假设第二个风力发电站是受到攻击的
E=np.loadtxt("6_Network_Topology_Double_Random_Adjacency_Matrix.txt")
thermal_power_station_cost=np.zeros(shape=(1,1000)) #火力发电成本
wind_power_station_cost=np.zeros(shape=(1,1000)) #风力发电成本
sum_cost=np.zeros(shape=(1,1000)) #总发电成本
#thermal_power_station_eta=[0.0375,0.0375,0.0625,0.035]
thermal_power_station_eta=[0.0675,0.0675,0.0925,0.0625]
thermal_power_station_zeta=[2,1.75,1,3]
thermal_power_station_xi=[0,0,0,0]
thermal_power_station_P_min=[50,20,15,10]
thermal_power_station_P_max=[200,120,80,100]
#wind_power_station_varphi=[3]
wind_power_station_varphi=[1]
wind_power_station_v_in=[3]
wind_power_station_v_out=[25]
wind_power_station_v_r=[13]
wind_power_station_sigma_ue=[5]
wind_power_station_sigma_oe=[30]
wind_power_station_P_r=[160]
wind_power_station_P_min=[0]
wind_power_station_P_max=[160]
sum_thermal_wind_power_station_strategy=np.zeros(shape=(1,1000))
step_size_primal=1
step_size_dual=3
regularization_parameter=0.001

# %%
#火力，风力发电策略初始化
thermal_power_station_strategy[0][0]=70
thermal_power_station_strategy[1][0]=70
thermal_power_station_strategy[2][0]=70
thermal_power_station_strategy[3][0]=70
wind_power_station_strategy[0][0]=70
wind_power_station_strategy[1][0]=0
#初始总发电策略
sum_thermal_wind_power_station_strategy[0][0]=350
#初始化受到攻击的风力发电站的对偶变量
wind_power_station_dual_variable[1][0]=-0.01

#火力，风力发电对偶初始化
thermal_power_station_dual_variable[0][0]=-70
thermal_power_station_dual_variable[1][0]=-70
thermal_power_station_dual_variable[2][0]=-70
thermal_power_station_dual_variable[3][0]=-70
wind_power_station_dual_variable[0][0]=-70

#安全发电站的初始总发电成本
#火力发电成本
for i in range(0,4):
    thermal_power_station_cost[0][0]=thermal_power_station_cost[0][0]+thermal_power_station_eta[i]*thermal_power_station_strategy[i][0]*thermal_power_station_strategy[i][0]+thermal_power_station_zeta[i]*thermal_power_station_strategy[i][0]
#风力发电成本
for i in range(0,1):
    wind_power_station_cost[0][0]=wind_power_station_cost[0][0]+wind_power_station_varphi[i]*wind_power_station_strategy[i][0]+wind_power_station_sigma_ue[i]*((wind_power_station_P_r[i]-wind_power_station_strategy[i][0])*(math.exp(-(math.pow(wind_power_station_v_r[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0])))-math.exp(-(math.pow(wind_power_station_v_out[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0]))))+(wind_power_station_P_r[i]*wind_power_station_v_in[i]/(wind_power_station_v_r[i]-wind_power_station_v_in[i])+wind_power_station_strategy[i][0])*(math.exp(-(math.pow(wind_power_station_v_r[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0])))-math.exp(-(math.pow(wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][0])/wind_power_station_P_r[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0]))))+(wind_power_station_P_r[i]*c_wind_speed[0]/(wind_power_station_v_r[i]-wind_power_station_v_in[i]))*(sc.gammaincc(1+1/kappa_wind_speed[0],(math.pow(wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][0])/wind_power_station_P_r[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0])))*sc.gamma(1+1/kappa_wind_speed[0])-sc.gammaincc(1+1/kappa_wind_speed[0],math.pow(wind_power_station_v_r[i]/c_wind_speed[0],kappa_wind_speed[0]))*sc.gamma(1+1/kappa_wind_speed[0])))+wind_power_station_sigma_oe[i]*((wind_power_station_strategy[i][0])*(1-math.exp(-(math.pow(wind_power_station_v_in[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0])))+math.exp(-(math.pow(wind_power_station_v_out[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0]))))+(wind_power_station_P_r[i]*wind_power_station_v_in[i]/(wind_power_station_v_r[i]-wind_power_station_v_in[i])+wind_power_station_strategy[i][0])*(math.exp(-(math.pow(wind_power_station_v_in[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0])))-math.exp(-(math.pow(wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][0])/wind_power_station_P_r[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0]))))+(wind_power_station_P_r[i]*c_wind_speed[0]/(wind_power_station_v_r[i]-wind_power_station_v_in[i]))*(sc.gammaincc(1+1/kappa_wind_speed[0],(math.pow(wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][0])/wind_power_station_P_r[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0])))*sc.gamma(1+1/kappa_wind_speed[0])-sc.gammaincc(1+1/kappa_wind_speed[0],math.pow(wind_power_station_v_in[i]/c_wind_speed[0],kappa_wind_speed[0]))*sc.gamma(1+1/kappa_wind_speed[0])))
#发电总成本
sum_cost[0][0]=thermal_power_station_cost[0][0]+wind_power_station_cost[0][0]

#计算每个发电站的邻居发电站
neighbor_robust1_help=[]
for i in range (0,6):
    for j in range (0,6):
        if E[i][j]!=0:
            neighbor_robust1_help.append(j)
        elif E[i][j]==0:
            neighbor_robust1_help.append(99)
neighbor_robust1=np.array(neighbor_robust1_help).reshape(6,6)

#计算安全的发电站的拜占庭邻居用户数量
q_robust1=[]
for i in range(0,6):
    q_robust1_help=0
    for j in range(0,6):
        if neighbor_robust1[i][j]==5:
            q_robust1_help=q_robust1_help+1
    q_robust1.append(q_robust1_help)

# %%
def IOS_Byzantine_attack_decentralized_economic_dispatch(thermal_power_station_strategy,wind_power_station_strategy,c_wind_speed,kappa_wind_speed,d_power_demand,thermal_power_station_dual_variable,wind_power_station_dual_variable,E,thermal_power_station_cost,wind_power_station_cost,thermal_power_station_eta,thermal_power_station_zeta,thermal_power_station_P_min,thermal_power_station_P_max,wind_power_station_varphi,wind_power_station_sigma_ue,wind_power_station_sigma_oe,wind_power_station_P_min,wind_power_station_P_max,sum_thermal_wind_power_station_strategy,step_size_primal,step_size_dual):
    #显示初始化的数据
    #输出初始状态的原变量和对偶变量
    print("***************************attack_free_online_decentralized_economic_dispatch*****************************")
    print("相关变量初始值为：")
    for i in range (0,4):
        print("第",(i+1),"个火力发电站的初始计划发电量为:",thermal_power_station_strategy[i][0])
    for i in range (0,2):
        print("第",(i+5),"个风力发电站的初始计划发电量为:",wind_power_station_strategy[i][0])
    print("****************************************************************************")
    for i in range (0,4):
        print("第",(i+1),"个火力发电站的初始对偶变量为:",thermal_power_station_dual_variable[i][0])
    for i in range (0,1):
        print("第",(i+5),"个风力发电站的初始对偶变量为:",wind_power_station_dual_variable[i][0])
    print("****************************************************************************")
    print("第",(6),"个受到Byzantin攻击的风力发电站的初始对偶变量为:",wind_power_station_dual_variable[1][0])
    print("****************************************************************************")
    print("安全发电站的初始总发电量:",sum_thermal_wind_power_station_strategy[0][0])
    print("*************************")
    print("需求侧平均用电需求:",d_power_demand[0])
    print("****************************************************************************")
    print("风速分布参数c:",c_wind_speed[0])
    print("****************************************************************************")
    print("风速分布参数kappa:",kappa_wind_speed[0])
    print("****************************************************************************")
    print("安全发电站的总发电成本：", sum_cost[0][0])
    print("****************************************************************************")
    print("原变量迭代步长为:",step_size_primal)
    print("*****************************************************************************")
    print("对偶变量迭代步长为:",step_size_dual)
    print("*****************************************************************************")
    
    #开始迭代
    for k in range(1,1000):
        #发电站更新计划发电量和对偶变量
        #对偶变量 先做梯度上升 再做聚合
        #安全发电站的梯度上升
        dual_variable_intermediate=[] #存放当前迭代中6个用户对对偶变量做完梯度下降后得到的中间值
        for i in range(0,4):
            dual_variable_intermediate.append(thermal_power_station_dual_variable[i][k-1]+step_size_dual*((1/6)*thermal_power_station_strategy[i][k-1]-(1/6)*d_power_demand[k-1]-regularization_parameter*thermal_power_station_dual_variable[i][k-1]))
        for j in range(0,1):
            dual_variable_intermediate.append(wind_power_station_dual_variable[j][k-1]+step_size_dual*((1/6)*wind_power_station_strategy[j][k-1]-(1/6)*d_power_demand[k-1]-regularization_parameter*wind_power_station_dual_variable[j][k-1]))
        #受到攻击的风力发电站的对偶值
        dual_variable_intermediate.append(wind_power_station_dual_variable[1][k-1])
        
        #IOS鲁棒聚合+adaptive clipping 安全的火力发电站的对偶更新
        #在做鲁棒聚合前 对收集到的信息进行adaptive clipping的剪裁操作
        for i in range (0,4):
            u_neighbor_help_robust1=neighbor_robust1[i].tolist()#将用户i的邻居序号存在辅助变量u中
            if i==0 or i==3:
                u_neighbor_help_robust1 = list(set(u_neighbor_help_robust1))
                u_neighbor_help_robust1.remove(99)
            if int(q_robust1[i])==1: #只有具有拜占庭邻居的用户才需要先进行adaptive clipping和后续的IOS聚合操作
                #先进行adaptive clipping
                dual_variable_intermediate_auxiliary=[]
                #注意必须以这样的方式赋值 不能直接写dual_variable_intermediate_auxiliary=dual_variable_intermediate
                #不然在修改变量dual_variable_intermediate_auxiliary的同时也会对dual_variable_intermediate进行修改
                for j in range(len(dual_variable_intermediate)): 
                    dual_variable_intermediate_auxiliary.append(dual_variable_intermediate[j])
                dual_variable_receive=[]
                clipping_C=0
                for j in range(0, len(u_neighbor_help_robust1)):
                    dual_variable_receive.append(dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[j]])
                dual_variable_receive.sort()
                clipping_C=-dual_variable_receive[1] #确定clpping的阈值
                #接下来对大于clipping_C的值进行clipping
                for j in range(0, len(u_neighbor_help_robust1)):
                    if -dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[j]]>clipping_C:
                        dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[j]]=-clipping_C
                #接下来做IOS鲁棒聚合
                dual_variable_weight_average_robust1=0
                h_robust1=0
                for j in range(0,len(u_neighbor_help_robust1)):#计算当前循环中的h值
                    h_robust1=h_robust1+E[i][u_neighbor_help_robust1[j]]
                for j in range(0,len(u_neighbor_help_robust1)):#计算当前循环中的对偶权重平均值
                    dual_variable_weight_average_robust1=dual_variable_weight_average_robust1+(1/h_robust1)*(E[i][u_neighbor_help_robust1[j]]*dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[j]])
                #剔除一个对偶值离权重平均对偶值最远的用户 保留自身的值
                u_neighbor_help_robust1.remove(i)
                neighbor_index_robust1=u_neighbor_help_robust1[0]
                max_distance_roubust1=abs(dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[0]]-dual_variable_weight_average_robust1)
                for j in range(1,len(u_neighbor_help_robust1)):
                    if abs(dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[j]]-dual_variable_weight_average_robust1)>=max_distance_roubust1:
                        max_distance_roubust1=abs(dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[j]]-dual_variable_weight_average_robust1)
                        neighbor_index_robust1=u_neighbor_help_robust1[j]
                u_neighbor_help_robust1.remove(neighbor_index_robust1)
                u_neighbor_help_robust1.append(i)
                #计算剔除q个信息后的权重平均对偶值
                dual_variable_weight_average_robust1=0
                h_robust1=0
                for j in range(0,len(u_neighbor_help_robust1)):
                    h_robust1=h_robust1+E[i][u_neighbor_help_robust1[j]]
                for j in range(0,len(u_neighbor_help_robust1)):
                    dual_variable_weight_average_robust1=dual_variable_weight_average_robust1+(1/h_robust1)*(E[i][u_neighbor_help_robust1[j]]*dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[j]])     
                #诚实用户基于IOS鲁棒聚合后的值进行自身的对偶变量的更新 基于权重平均值
                thermal_power_station_dual_variable[i][k]=dual_variable_weight_average_robust1              
            else: #没有拜占庭邻居的用户直接进行权重聚合即可
                dual_variable_weight_average_robust1=0
                h_robust1=0
                for j in range(0,len(u_neighbor_help_robust1)):#计算当前循环中的h值
                    h_robust1=h_robust1+E[i][u_neighbor_help_robust1[j]]
                for j in range(0,len(u_neighbor_help_robust1)):
                    dual_variable_weight_average_robust1=dual_variable_weight_average_robust1+(1/h_robust1)*(E[i][u_neighbor_help_robust1[j]]*dual_variable_intermediate[u_neighbor_help_robust1[j]])     
                 #诚实用户基于IOS鲁棒聚合后的值进行自身的对偶变量的更新 基于权重平均值
                thermal_power_station_dual_variable[i][k]=dual_variable_weight_average_robust1  
    
        #安全的风力发电站的adaptive clipping操作 由于风力发电站的邻居中没有拜占庭用户 所以不需要进行adaptive clipping的操作
        #聚合 安全的风力发电站的对偶更新
        for i in range(0,1):
            u_neighbor_help_robust1=neighbor_robust1[i+4].tolist()#将用户i的邻居序号存在辅助变量u中
            u_neighbor_help_robust1 = list(set(u_neighbor_help_robust1))
            u_neighbor_help_robust1.remove(99)
            dual_variable_weight_average_robust1=0
            h_robust1=0
            for j in range(0,len(u_neighbor_help_robust1)):
                h_robust1=h_robust1+E[i][u_neighbor_help_robust1[j]]               
            for j in range(0,len(u_neighbor_help_robust1)):
                dual_variable_weight_average_robust1=dual_variable_weight_average_robust1+(1/h_robust1)*(E[i][u_neighbor_help_robust1[j]]*dual_variable_intermediate[u_neighbor_help_robust1[j]])     
            wind_power_station_dual_variable[i][k]=dual_variable_weight_average_robust1
        #受到Byzantine攻击的风力发电站的对偶更新
        wind_power_station_dual_variable[1][k]=wind_power_station_dual_variable[1][k-1]            
        
        #安全的火力发电站计划发电量
        for i in range(0,4):
            thermal_power_station_strategy[i][k]=thermal_power_station_strategy[i][k-1]-step_size_primal*(2*thermal_power_station_eta[i]*thermal_power_station_strategy[i][k-1]+thermal_power_station_zeta[i]+(1/6)*thermal_power_station_dual_variable[i][k-1]) 
            if thermal_power_station_strategy[i][k]<=thermal_power_station_P_min[i]:
                thermal_power_station_strategy[i][k]=thermal_power_station_P_min[i]
            elif thermal_power_station_strategy[i][k]>=thermal_power_station_P_max[i]:
                thermal_power_station_strategy[i][k]=thermal_power_station_P_max[i]
        #安全的风力发电站计划发电量
        for i in range(0,1):
            wind_power_station_strategy[i][k]=wind_power_station_strategy[i][k-1]-step_size_primal*(wind_power_station_varphi[i]+wind_power_station_sigma_oe[i]+(wind_power_station_sigma_ue[i]+wind_power_station_sigma_oe[i])*math.exp(-(math.pow(wind_power_station_v_out[i],kappa_wind_speed[k-1]))/(math.pow(c_wind_speed[k-1],kappa_wind_speed[k-1])))+(-wind_power_station_sigma_ue[i]-wind_power_station_sigma_oe[i])*math.exp(-(math.pow((wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][k-1])/wind_power_station_P_r[i]),kappa_wind_speed[k-1]))/(math.pow(c_wind_speed[k-1],kappa_wind_speed[k-1])))+(1/6)*wind_power_station_dual_variable[i][k-1])
            if wind_power_station_strategy[i][k]<=wind_power_station_P_min[i]:
                wind_power_station_strategy[i][k]=wind_power_station_P_min[i]
            elif wind_power_station_strategy[i][k]>=wind_power_station_P_max[i]:
                wind_power_station_strategy[i][k]=wind_power_station_P_max[i]
        #受到Byzantine攻击的风力发电站的计划发电量
        wind_power_station_strategy[1][k]=wind_power_station_strategy[1][k-1]
        
        #安全发电站的计算总计划发电
        #火力发电量
        for i in range(0,4):
            sum_thermal_wind_power_station_strategy[0][k]=sum_thermal_wind_power_station_strategy[0][k]+thermal_power_station_strategy[i][k]
        #风力发电量
        for i in range(0,1):
            sum_thermal_wind_power_station_strategy[0][k]=sum_thermal_wind_power_station_strategy[0][k]+wind_power_station_strategy[i][k]
        
        #安全发电站的计算总发电成本
        #火力发电成本
        for i in range(0,4):
            thermal_power_station_cost[0][k]=thermal_power_station_cost[0][k]+thermal_power_station_eta[i]*thermal_power_station_strategy[i][k]*thermal_power_station_strategy[i][k]+thermal_power_station_zeta[i]*thermal_power_station_strategy[i][k]
        #风力发电成本
        for i in range(0,1):
            wind_power_station_cost[0][k]=wind_power_station_cost[0][k]+wind_power_station_varphi[i]*wind_power_station_strategy[i][k]+wind_power_station_sigma_ue[i]*((wind_power_station_P_r[i]-wind_power_station_strategy[i][k])*(math.exp(-(math.pow(wind_power_station_v_r[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k])))-math.exp(-(math.pow(wind_power_station_v_out[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k]))))+(wind_power_station_P_r[i]*wind_power_station_v_in[i]/(wind_power_station_v_r[i]-wind_power_station_v_in[i])+wind_power_station_strategy[i][k])*(math.exp(-(math.pow(wind_power_station_v_r[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k])))-math.exp(-(math.pow(wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][k])/wind_power_station_P_r[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k]))))+(wind_power_station_P_r[i]*c_wind_speed[k]/(wind_power_station_v_r[i]-wind_power_station_v_in[i]))*(sc.gammaincc(1+1/kappa_wind_speed[k],(math.pow(wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][k])/wind_power_station_P_r[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k])))*sc.gamma(1+1/kappa_wind_speed[k])-sc.gammaincc(1+1/kappa_wind_speed[k],math.pow(wind_power_station_v_r[i]/c_wind_speed[k],kappa_wind_speed[k]))*sc.gamma(1+1/kappa_wind_speed[k])))+wind_power_station_sigma_oe[i]*((wind_power_station_strategy[i][k])*(1-math.exp(-(math.pow(wind_power_station_v_in[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k])))+math.exp(-(math.pow(wind_power_station_v_out[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k]))))+(wind_power_station_P_r[i]*wind_power_station_v_in[i]/(wind_power_station_v_r[i]-wind_power_station_v_in[i])+wind_power_station_strategy[i][k])*(math.exp(-(math.pow(wind_power_station_v_in[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k])))-math.exp(-(math.pow(wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][k])/wind_power_station_P_r[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k]))))+(wind_power_station_P_r[i]*c_wind_speed[k]/(wind_power_station_v_r[i]-wind_power_station_v_in[i]))*(sc.gammaincc(1+1/kappa_wind_speed[k],(math.pow(wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][k])/wind_power_station_P_r[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k])))*sc.gamma(1+1/kappa_wind_speed[k])-sc.gammaincc(1+1/kappa_wind_speed[k],math.pow(wind_power_station_v_in[i]/c_wind_speed[k],kappa_wind_speed[k]))*sc.gamma(1+1/kappa_wind_speed[k])))
        #发电总成本
        sum_cost[0][k]=thermal_power_station_cost[0][k]+wind_power_station_cost[0][k]
        
        #输出第k次迭代中的结果 每间隔10次迭代输出一次结果
        #if (k+1)%10==0:
        print(k,"次迭代中的结果：")
        for i in range (0,4):
            print("第",(i+1),"个火力发电站的计划发电量为:",thermal_power_station_strategy[i][k])
        for i in range (0,2):
            print("第",(i+5),"个风力发电站的计划发电量为:",wind_power_station_strategy[i][k])
        print("****************************************************************************")
        for i in range (0,4):
            print("第",(i+1),"个火力发电站的对偶变量为:",thermal_power_station_dual_variable[i][k])
        for i in range (0,1):
            print("第",(i+5),"个风力发电站的对偶变量为:",wind_power_station_dual_variable[i][k])
        print("****************************************************************************")
        print("第",(6),"个受到Byzantin攻击的风力发电站的初始对偶变量为:",wind_power_station_dual_variable[1][k])
        print("****************************************************************************")
        print("安全发电站的总发电量:",sum_thermal_wind_power_station_strategy[0][k])
        print("*************************")
        print("需求侧平均用电需求:",d_power_demand[k])
        print("****************************************************************************")
        print("风速分布参数c:",c_wind_speed[k])
        print("****************************************************************************")
        print("风速分布参数kappa:",kappa_wind_speed[k])
        print("****************************************************************************")        
        print("安全发电站的总发电成本：", sum_cost[0][k])
        print("****************************************************************************")
        print("原变量迭代步长为:",step_size_primal)
        print("****************************************************************************")
        print("对偶变量迭代步长为:",step_size_dual)
        print("****************************************************************************")
        
        #step_size_primal=(pow(k+1,0.1))
        #step_size_dual=1/(pow(k+1,0.7))#我们发现在在线算法中 不能使用太小的对偶步长 不然后续算法对在线变化会不敏感 
        
        '''#尝试使用两阶段的步长
        if k<=500:
            step_size_dual=1/(pow(k+1,0.7))
        else:
            step_size_dual=0.1'''

    print(datetime.now().strftime('%Y-%m-%d %H:%M:%S.%f')[:-3])
    return None

# %%
IOS_Byzantine_attack_decentralized_economic_dispatch(thermal_power_station_strategy,wind_power_station_strategy,c_wind_speed,kappa_wind_speed,d_power_demand,thermal_power_station_dual_variable,wind_power_station_dual_variable,E,thermal_power_station_cost,wind_power_station_cost,thermal_power_station_eta,thermal_power_station_zeta,thermal_power_station_P_min,thermal_power_station_P_max,wind_power_station_varphi,wind_power_station_sigma_ue,wind_power_station_sigma_oe,wind_power_station_P_min,wind_power_station_P_max,sum_thermal_wind_power_station_strategy,step_size_primal,step_size_dual)
# Out:
# ***************************attack_free_online_decentralized_economic_dispatch*****************************
# 相关变量初始值为：
# 第 1 个火力发电站的初始计划发电量为: 70.0
# 第 2 个火力发电站的初始计划发电量为: 70.0
# 第 3 个火力发电站的初始计划发电量为: 70.0
# 第 4 个火力发电站的初始计划发电量为: 70.0
# 第 5 个风力发电站的初始计划发电量为: 70.0
# 第 6 个风力发电站的初始计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的初始对偶变量为: -70.0
# 第 2 个火力发电站的初始对偶变量为: -70.0
# 第 3 个火力发电站的初始对偶变量为: -70.0
# 第 4 个火力发电站的初始对偶变量为: -70.0
# 第 5 个风力发电站的初始对偶变量为: -70.0
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -0.01
# ****************************************************************************
# 安全发电站的初始总发电量: 350.0
# *************************
# 需求侧平均用电需求: 72.62781256
# ****************************************************************************
# 风速分布参数c: 8.301041
# ****************************************************************************
# 风速分布参数kappa: 2.66836324
# ****************************************************************************
# 安全发电站的总发电成本： 2678.3230777617387
# ****************************************************************************
# 原变量迭代步长为: 1
# *****************************************************************************
# 对偶变量迭代步长为: 3
# *****************************************************************************
# 1 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 70.21666666666667
# 第 2 个火力发电站的计划发电量为: 70.46666666666667
# 第 3 个火力发电站的计划发电量为: 67.71666666666667
# 第 4 个火力发电站的计划发电量为: 69.91666666666667
# 第 5 个风力发电站的计划发电量为: 67.54476648507118
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -71.10390627999999
# 第 2 个火力发电站的对偶变量为: -71.10390627999998
# 第 3 个火力发电站的对偶变量为: -71.10390627999998
# 第 4 个火力发电站的对偶变量为: -71.10390627999999
# 第 5 个风力发电站的对偶变量为: -71.10390627999999
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -0.01
# ****************************************************************************
# 安全发电站的总发电量: 345.86143315173786
# *************************
# 需求侧平均用电需求: 64.01095166
# ****************************************************************************
# 风速分布参数c: 14.69554708
# ****************************************************************************
# 风速分布参数kappa: 2.10218816
# ****************************************************************************
# 安全发电站的总发电成本： 2591.3476835205556
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 2 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 70.58806771333333
# 第 2 个火力发电站的计划发电量为: 71.05431771333333
# 第 3 个火力发电站的计划发电量为: 66.03973438
# 第 4 个火力发电站的计划发电量为: 70.02773438
# 第 5 个风力发电站的计划发电量为: 74.70701504539119
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -68.37398254199437
# 第 2 个火力发电站的对偶变量为: -68.36273705782664
# 第 3 个火力发电站的对偶变量为: -68.20995928004886
# 第 4 个火力发电站的对偶变量为: -67.86773705810666
# 第 5 个风力发电站的对偶变量为: -68.37398254199437
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -0.01
# ****************************************************************************
# 安全发电站的总发电量: 352.4168692320579
# *************************
# 需求侧平均用电需求: 72.48160172
# ****************************************************************************
# 风速分布参数c: 11.73462138
# ****************************************************************************
# 风速分布参数kappa: 2.30593756
# ****************************************************************************
# 安全发电站的总发电成本： 2569.835981364422
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 3 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 70.45434232903239
# 第 2 个火力发电站的计划发电量为: 71.1057743316711
# 第 3 个火力发电站的计划发电量为: 64.1907100663748
# 第 4 个火力发电站的计划发电量为: 69.58555709218444
# 第 5 个风力发电站的计划发电量为: 79.04272333730967
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -68.86653357928016
# 第 2 个火力发电站的对偶变量为: -68.58091601533373
# 第 3 个火力发电站的对偶变量为: -68.55376748780981
# 第 4 个火力发电站的对偶变量为: -68.88603345627536
# 第 5 个风力发电站的对偶变量为: -68.86653357928016
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -0.01
# ****************************************************************************
# 安全发电站的总发电量: 354.37910715657245
# *************************
# 需求侧平均用电需求: 74.35324129
# ****************************************************************************
# 风速分布参数c: 20.88797006
# ****************************************************************************
# 风速分布参数kappa: 2.49450248
# ****************************************************************************
# 安全发电站的总发电成本： 2817.377321608291
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 4 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 70.42076171115971
# 第 2 个火力发电站的计划发电量为: 71.18664746611779
# 第 3 个火力发电站的计划发电量为: 62.74105661873043
# 第 4 个火力发电站的计划发电量为: 69.36836803170728
# 第 5 个风力发电站的计划发电量为: 84.20825325083416
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -69.78420125045938
# 第 2 个火力发电站的对偶变量为: -69.7889921548374
# 第 3 个火力发电站的对偶变量为: -69.67073540946383
# 第 4 个火力发电站的对偶变量为: -70.79230200286035
# 第 5 个风力发电站的对偶变量为: -69.78420125045938
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -0.01
# ****************************************************************************
# 安全发电站的总发电量: 357.9250870785494
# *************************
# 需求侧平均用电需求: 73.36237628
# ****************************************************************************
# 风速分布参数c: 17.01236112
# ****************************************************************************
# 风速分布参数kappa: 2.63537814
# ****************************************************************************
# 安全发电站的总发电成本： 2532.244077331811
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 5 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 70.54465908856305
# 第 2 个火力发电站的计划发电量为: 71.45794875066478
# 第 3 个火力发电站的计划发电量为: 61.745750379175945
# 第 4 个火力发电站的计划发电量为: 69.4960390282206
# 第 5 个风力发电站的计划发电量为: 92.77088249774222
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -69.68484347550265
# 第 2 个火力发电站的对偶变量为: -70.15225985046051
# 第 3 个火力发电站的对偶变量为: -69.94009989094005
# 第 4 个火力发电站的对偶变量为: -72.09089004294998
# 第 5 个风力发电站的对偶变量为: -69.68484347550265
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -0.01
# ****************************************************************************
# 安全发电站的总发电量: 366.0152797443666
# *************************
# 需求侧平均用电需求: 72.02509011
# ****************************************************************************
# 风速分布参数c: 11.53887689
# ****************************************************************************
# 风速分布参数kappa: 2.44466253
# ****************************************************************************
# 安全发电站的总发电成本： 2641.3136281999186
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 6 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 70.63527069085748
# 第 2 个火力发电站的计划发电量为: 71.75316897773513
# 第 3 个火力发电站的计划发电量为: 60.97946987418507
# 第 4 个火力发电站的计划发电量为: 69.82418249018468
# 第 5 个风力发电站的计划发电量为: 94.24385173610739
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -67.88870495343322
# 第 2 个火力发电站的对偶变量为: -69.04663775771324
# 第 3 个火力发电站的对偶变量为: -68.72288562847613
# 第 4 个火力发电站的对偶变量为: -72.39745622060708
# 第 5 个风力发电站的对偶变量为: -67.88870495343322
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -0.01
# ****************************************************************************
# 安全发电站的总发电量: 367.43594376906975
# *************************
# 需求侧平均用电需求: 71.92071638
# ****************************************************************************
# 风速分布参数c: 20.17759
# ****************************************************************************
# 风速分布参数kappa: 2.96946266
# ****************************************************************************
# 安全发电站的总发电成本： 2711.091834209154
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 7 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 70.41429330649726
# 第 2 个火力发电站的计划发电量为: 71.82426412535976
# 第 3 个火力发电站的计划发电量为: 60.152082218873524
# 第 4 个火力发电站的计划发电量为: 70.16240238234612
# 第 5 个风力发电站的计划发电量为: 101.33023822842935
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -66.09239598683347
# 第 2 个火力发电站的对偶变量为: -67.94887338003454
# 第 3 个火力发电站的对偶变量为: -67.4705112410034
# 第 4 个火力发电站的对偶变量为: -72.13264662818328
# 第 5 个风力发电站的对偶变量为: -66.09239598683347
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -0.01
# ****************************************************************************
# 安全发电站的总发电量: 373.883280261506
# *************************
# 需求侧平均用电需求: 72.93331067
# ****************************************************************************
# 风速分布参数c: 12.95856003
# ****************************************************************************
# 风速分布参数kappa: 2.36446438
# ****************************************************************************
# 安全发电站的总发电成本： 2658.4441376473546
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 8 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 69.92376304125904
# 第 2 个火力发电站的计划发电量为: 71.70280069844195
# 第 3 个火力发电站的计划发电量为: 59.26903221521582
# 第 4 个火力发电站的计划发电量为: 70.41420985591674
# 第 5 个风力发电站的计划发电量为: 103.1258018417835
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -64.12815638633613
# 第 2 个火力发电站的对偶变量为: -66.57832515125361
# 第 3 个火力发电站的对偶变量为: -66.02253039570792
# 第 4 个火力发电站的对偶变量为: -72.02842757905958
# 第 5 个风力发电站的对偶变量为: -64.12815638633613
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -0.01
# ****************************************************************************
# 安全发电站的总发电量: 374.435607652617
# *************************
# 需求侧平均用电需求: 65.05998342
# ****************************************************************************
# 风速分布参数c: 4.42860238
# ****************************************************************************
# 风速分布参数kappa: 2.42410411
# ****************************************************************************
# 安全发电站的总发电成本： 4453.891679046219
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 9 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 69.17208109507843
# 第 2 个火力发电站的计划发电量为: 71.36931012936122
# 第 3 个火力发电站的计划发电量为: 58.30801632135221
# 第 4 个火力发电站的计划发电量为: 70.6171715537704
# 第 5 个风力发电站的计划发电量为: 82.8799162184824
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -58.35516193399872
# 第 2 个火力发电站的对偶变量为: -61.1944916433218
# 第 3 个火力发电站的对偶变量为: -60.565296435506916
# 第 4 个火力发电站的对偶变量为: -67.27850939113904
# 第 5 个风力发电站的对偶变量为: -58.35516193399872
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -0.01
# ****************************************************************************
# 安全发电站的总发电量: 352.3464953180446
# *************************
# 需求侧平均用电需求: 65.89481815
# ****************************************************************************
# 风速分布参数c: 13.39240335
# ****************************************************************************
# 风速分布参数kappa: 2.3728007
# ****************************************************************************
# 安全发电站的总发电成本： 2471.043359705088
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 10 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 67.55971046957596
# 第 2 个火力发电站的计划发电量为: 70.1835352024511
# 第 3 个火力发电站的计划发电量为: 56.61524937448654
# 第 4 个火力发电站的计划发电量为: 70.00311000807227
# 第 5 个风力发电站的计划发电量为: 86.83455154539735
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -56.2864270756597
# 第 2 个火力发电站的对偶变量为: -58.60441031111493
# 第 3 个火力发电站的对偶变量为: -57.94848372424681
# 第 4 个火力发电站的对偶变量为: -62.674333285709835
# 第 5 个风力发电站的对偶变量为: -56.2864270756597
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -0.01
# ****************************************************************************
# 安全发电站的总发电量: 351.1961565999832
# *************************
# 需求侧平均用电需求: 82.22889118
# ****************************************************************************
# 风速分布参数c: 3.71616054
# ****************************************************************************
# 风速分布参数kappa: 2.52674506
# ****************************************************************************
# 安全发电站的总发电成本： 4114.413300295206
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 11 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 65.82022073545983
# 第 2 个火力发电站的计划发电量为: 68.72615966863935
# 第 3 个火力发电站的计划发电量为: 54.79950886091433
# 第 4 个火力发电站的计划发电量为: 68.69844347134821
# 第 5 个风力发电站的计划发电量为: 65.22839947416165
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -62.17650354035385
# 第 2 个火力发电站的对偶变量为: -63.70909667544221
# 第 3 个火力发电站的对偶变量为: -63.248216030679934
# 第 4 个火力发电站的对偶变量为: -67.54336521712997
# 第 5 个风力发电站的对偶变量为: -62.17650354035385
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -0.01
# ****************************************************************************
# 安全发电站的总发电量: 323.2727322105234
# *************************
# 需求侧平均用电需求: 72.39439433
# ****************************************************************************
# 风速分布参数c: 22.04759493
# ****************************************************************************
# 风速分布参数kappa: 2.67853757
# ****************************************************************************
# 安全发电站的总发电成本： 2586.1625015772806
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 12 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 65.29724152623173
# 第 2 个火力发电站的计划发电量为: 68.31631089261342
# 第 3 个火力发电站的计划发电量为: 54.20296906009183
# 第 4 个火力发电站的计划发电量为: 68.36836557361801
# 第 5 个风力发电站的计划发电量为: 69.333342689362
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -66.57140292504812
# 第 2 个火力发电站的对偶变量为: -67.0896659431804
# 第 3 个火力发电站的对偶变量为: -66.66337440599061
# 第 4 个火力发电站的对偶变量为: -68.21211539678512
# 第 5 个风力发电站的对偶变量为: -66.57140292504812
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -0.01
# ****************************************************************************
# 安全发电站的总发电量: 325.51822974191697
# *************************
# 需求侧平均用电需求: 59.43051398
# ****************************************************************************
# 风速分布参数c: 22.07798354
# ****************************************************************************
# 风速分布参数kappa: 2.67292298
# ****************************************************************************
# 安全发电站的总发电成本： 2594.186015094754
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 13 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 65.5773477410318
# 第 2 个火力发电站的计划发电量为: 68.52521991264067
# 第 3 个火力发电站的计划发电量为: 54.28598218497328
# 第 4 个火力发电站的计划发电量为: 68.19100577637994
# 第 5 个风力发电站的计划发电量为: 73.95458366114981
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -63.706467290242344
# 第 2 个火力发电站的对偶变量为: -62.92410112374281
# 第 3 个火力发电站的对偶变量为: -62.802650594327076
# 第 4 个火力发电站的对偶变量为: -63.260321132964464
# 第 5 个风力发电站的对偶变量为: -63.706467290242344
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -0.01
# ****************************************************************************
# 安全发电站的总发电量: 330.5341392761755
# *************************
# 需求侧平均用电需求: 66.57067559
# ****************************************************************************
# 风速分布参数c: 24.23535384
# ****************************************************************************
# 风速分布参数kappa: 2.6829301
# ****************************************************************************
# 安全发电站的总发电成本： 2787.313325927996
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 14 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 65.34215034436623
# 第 2 个火力发电站的计划发电量为: 68.01166541172464
# 第 3 个火力发电站的计划发电量为: 53.710183913141066
# 第 4 个火力发电站的计划发电量为: 67.21051690982652
# 第 5 个风力发电站的计划发电量为: 75.23186984996164
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -63.26810423422367
# 第 2 个火力发电站的对偶变量为: -62.44151575209096
# 第 3 个火力发电站的对偶变量为: -62.19107629055713
# 第 4 个火力发电站的对偶变量为: -62.132512207022685
# 第 5 个风力发电站的对偶变量为: -63.26810423422367
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -0.01
# ****************************************************************************
# 安全发电站的总发电量: 329.5063864290201
# *************************
# 需求侧平均用电需求: 69.25657964
# ****************************************************************************
# 风速分布参数c: 14.77327144
# ****************************************************************************
# 风速分布参数kappa: 2.06624199
# ****************************************************************************
# 安全发电站的总发电成本： 2360.2063111611533
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 15 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 65.06564408691406
# 第 2 个火力发电站的计划发电量为: 67.48700987315696
# 第 3 个火力发电站的计划发电量为: 53.138979270969486
# 第 4 个火力发电站的计划发电量为: 66.16462099726866
# 第 5 个风力发电站的计划发电量为: 79.95043502128517
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -64.09239203584104
# 第 2 个火力发电站的对偶变量为: -63.237589811153434
# 第 3 个火力发电站的对偶变量为: -62.99771578333504
# 第 4 个火力发电站的对偶变量为: -62.94560116228756
# 第 5 个风力发电站的对偶变量为: -64.09239203584104
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -0.01
# ****************************************************************************
# 安全发电站的总发电量: 331.80668924959434
# *************************
# 需求侧平均用电需求: 62.4132554
# ****************************************************************************
# 风速分布参数c: 22.01070443
# ****************************************************************************
# 风速分布参数kappa: 2.82899266
# ****************************************************************************
# 安全发电站的总发电成本： 2591.309685234693
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 16 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 64.96384747448751
# 第 2 个火力发电站的计划发电量为: 67.16586184213968
# 第 3 个火力发电站的计划发电量为: 52.80788740306264
# 第 4 个火力发电站的计划发电量为: 65.384976899658
# 第 5 个风力发电站的计划发电量为: 84.34768075793785
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -60.95825258765191
# 第 2 个火力发电站的对偶变量为: -60.31465500986244
# 第 3 个火力发电站的对偶变量为: -60.08544159751412
# 第 4 个火力发电站的对偶变量为: -60.786878931991396
# 第 5 个风力发电站的对偶变量为: -60.95825258765191
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -0.01
# ****************************************************************************
# 安全发电站的总发电量: 334.6702543772857
# *************************
# 需求侧平均用电需求: 68.27939592
# ****************************************************************************
# 风速分布参数c: 24.26368821
# ****************************************************************************
# 风速分布参数kappa: 2.29481562
# ****************************************************************************
# 安全发电站的总发电成本： 2853.13934441822
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 17 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 64.35343683004035
# 第 2 个火力发电站的计划发电量为: 66.40091299509456
# 第 3 个火力发电站的计划发电量为: 52.0526684997484
# 第 4 个火力发电站的计划发电量为: 64.34300127586599
# 第 5 个风力发电站的计划发电量为: 83.67424322033568
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -60.29405360243583
# 第 2 个火力发电站的对偶变量为: -60.00100141410186
# 第 3 个火力发电站的对偶变量为: -59.80737097311494
# 第 4 个火力发电站的对偶变量为: -61.70522787761702
# 第 5 个风力发电站的对偶变量为: -60.29405360243583
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -0.01
# ****************************************************************************
# 安全发电站的总发电量: 330.824262821085
# *************************
# 需求侧平均用电需求: 74.37551359
# ****************************************************************************
# 风速分布参数c: 17.54487156
# ****************************************************************************
# 风速分布参数kappa: 2.9754401
# ****************************************************************************
# 安全发电站的总发电成本： 2183.410133064886
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 18 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 63.714731791724205
# 第 2 个火力发电站的计划发电量为: 65.6869566431071
# 第 3 个火力发电站的计划发电量为: 51.39081998948077
# 第 4 个火力发电站的计划发电量为: 63.58433076265224
# 第 5 个风力发电站的计划发电量为: 92.24194882328024
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -63.154867386306535
# 第 2 个火力发电站的对偶变量为: -63.45886722307277
# 第 3 个火力发电站的对偶变量为: -63.15574837376845
# 第 4 个火力发电站的对偶变量为: -65.84195062633168
# 第 5 个风力发电站的对偶变量为: -63.154867386306535
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -0.01
# ****************************************************************************
# 安全发电站的总发电量: 336.61878801024454
# *************************
# 需求侧平均用电需求: 76.41692674
# ****************************************************************************
# 风速分布参数c: 4.81637973
# ****************************************************************************
# 风速分布参数kappa: 2.19682287
# ****************************************************************************
# 安全发电站的总发电成本： 3667.872580440596
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 19 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 63.639054230892526
# 第 2 个火力发电站的计划发电量为: 65.64569536679977
# 第 3 个火力发电站的计划发电量为: 51.409476353721566
# 第 4 个火力发电站的计划发电量为: 63.60994785504266
# 第 5 个风力发电站的计划发电量为: 72.61078175758138
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -66.23751249697797
# 第 2 个火力发电站的对偶变量为: -67.29057230266024
# 第 3 个火力发电站的对偶变量为: -66.90976707007395
# 第 4 个火力发电站的对偶变量为: -71.18833259741847
# 第 5 个风力发电站的对偶变量为: -66.23751249697797
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -0.01
# ****************************************************************************
# 安全发电站的总发电量: 316.9149555640379
# *************************
# 需求侧平均用电需求: 63.07056204
# ****************************************************************************
# 风速分布参数c: 22.76341842
# ****************************************************************************
# 风速分布参数kappa: 2.30087244
# ****************************************************************************
# 安全发电站的总发电成本： 2573.1339557943115
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 20 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 64.08736732588503
# 第 2 个火力发电站的计划发电量为: 66.24862187605851
# 第 3 个火力发电站的计划发电量为: 52.0503510732954
# 第 4 个火力发电站的计划发电量为: 64.52342647273207
# 第 5 个风力发电站的计划发电量为: 74.88158074433801
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -65.71498879985239
# 第 2 个火力发电站的对偶变量为: -66.96310229113845
# 第 3 个火力发电站的对偶变量为: -66.41821998338817
# 第 4 个火力发电站的对偶变量为: -69.45679886479735
# 第 5 个风力发电站的对偶变量为: -65.71498879985239
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -0.01
# ****************************************************************************
# 安全发电站的总发电量: 321.791347492309
# *************************
# 需求侧平均用电需求: 72.76413739
# ****************************************************************************
# 风速分布参数c: 7.10546984
# ****************************************************************************
# 风速分布参数kappa: 2.49300975
# ****************************************************************************
# 安全发电站的总发电成本： 2578.4947679745437
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 21 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 64.38807087019927
# 第 2 个火力发电站的计划发电量为: 66.71557497131369
# 第 3 个火力发电站的计划发电量为: 52.49073945530045
# 第 4 个火力发电站的计划发电量为: 65.03413130777345
# 第 5 个风力发电站的计划发电量为: 65.22989359418162
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -69.56572043096975
# 第 2 个火力发电站的对偶变量为: -70.23620094357464
# 第 3 个火力发电站的对偶变量为: -69.86411058961896
# 第 4 个火力发电站的对偶变量为: -72.51635875572998
# 第 5 个风力发电站的对偶变量为: -69.56572043096975
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -0.01
# ****************************************************************************
# 安全发电站的总发电量: 313.8584101987685
# *************************
# 需求侧平均用电需求: 72.47977434
# ****************************************************************************
# 风速分布参数c: 20.89161523
# ****************************************************************************
# 风速分布参数kappa: 2.7421258
# ****************************************************************************
# 安全发电站的总发电成本： 2402.1617595502303
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 22 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 65.28996804121732
# 第 2 个火力发电站的计划发电量为: 67.66500584078211
# 第 3 个火力发电站的计划发电量为: 53.423971087673024
# 第 4 个火力发电站的计划发电量为: 65.99092468692344
# 第 5 个风力发电站的计划发电量为: 72.25497473434686
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -74.32822873338274
# 第 2 个火力发电站的对偶变量为: -74.4181993446353
# 第 3 个火力发电站的对偶变量为: -74.07219499235876
# 第 4 个火力发电站的对偶变量为: -75.22896668262227
# 第 5 个风力发电站的对偶变量为: -74.32822873338274
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -0.01
# ****************************************************************************
# 安全发电站的总发电量: 324.6248443909427
# *************************
# 需求侧平均用电需求: 72.35827036
# ****************************************************************************
# 风速分布参数c: 4.73395435
# ****************************************************************************
# 风速分布参数kappa: 2.61322499
# ****************************************************************************
# 安全发电站的总发电成本： 3198.33944267514
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 23 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 66.86386047788343
# 第 2 个火力发电站的计划发电量为: 69.1832632763824
# 第 3 个火力发电站的计划发电量为: 54.885902268513306
# 第 4 个火力发电站的计划发电量为: 67.28022021482839
# 第 5 个风力发电站的计划发电量为: 54.87491348943417
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -77.47710597927092
# 第 2 个火力发电站的对偶变量为: -76.98688462398081
# 第 3 个火力发电站的对偶变量为: -76.80406511143609
# 第 4 个火力发电站的对偶变量为: -77.76812973750376
# 第 5 个风力发电站的对偶变量为: -77.47710597927092
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -0.01
# ****************************************************************************
# 安全发电站的总发电量: 313.08815972704167
# *************************
# 需求侧平均用电需求: 71.12392002
# ****************************************************************************
# 风速分布参数c: 18.17359002
# ****************************************************************************
# 风速分布参数kappa: 2.07787691
# ****************************************************************************
# 安全发电站的总发电成本： 2412.9291218111944
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 24 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 68.75009030991433
# 第 2 个火力发电站的计划发电量为: 70.92467017140092
# 第 3 个火力发电站的计划发电量为: 56.53268786741103
# 第 4 个火力发电站的计划发电量为: 68.83154764422547
# 第 5 个风力发电站的计划发电量为: 62.94183606180944
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -81.75459394022394
# 第 2 个火力发电站的对偶变量为: -81.57329543064833
# 第 3 个火力发电站的对偶变量为: -80.79924993621195
# 第 4 个火力发电站的对偶变量为: -79.01620396672202
# 第 5 个风力发电站的对偶变量为: -81.75459394022394
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -0.01
# ****************************************************************************
# 安全发电站的总发电量: 327.9808320547612
# *************************
# 需求侧平均用电需求: 76.7139357
# ****************************************************************************
# 风速分布参数c: 4.48706041
# ****************************************************************************
# 风速分布参数kappa: 2.43670989
# ****************************************************************************
# 安全发电站的总发电成本： 3141.4359146428924
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 25 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 71.09459377477988
# 第 2 个火力发电站的计划发电量为: 73.19538893670318
# 第 3 个火力发电站的计划发电量为: 58.54068226797531
# 第 4 个火力发电站的计划发电量为: 70.39697151648429
# 第 5 个风力发电站的计划发电量为: 47.517003584741474
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -87.02794504832444
# 第 2 个火力发电站的对偶变量为: -86.02532585455117
# 第 3 个火力发电站的对偶变量为: -85.56175122467977
# 第 4 个火力发电站的对偶变量为: -83.4854411964944
# 第 5 个风力发电站的对偶变量为: -87.02794504832444
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -0.01
# ****************************************************************************
# 安全发电站的总发电量: 320.7446400806841
# *************************
# 需求侧平均用电需求: 61.05044826
# ****************************************************************************
# 风速分布参数c: 11.55331759
# ****************************************************************************
# 风速分布参数kappa: 2.5075835
# ****************************************************************************
# 安全发电站的总发电成本： 2357.537406784549
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 26 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 74.00148112323868
# 第 2 个火力发电站的计划发电量为: 75.90156573934011
# 第 3 个火力发电站的计划发电量为: 60.97094791917984
# 第 4 个火力发电站的计划发电量为: 72.51159027633949
# 第 5 个风力发电站的计划发电量为: 59.90293993397844
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -85.61577050657723
# 第 2 个火力发电站的对偶变量为: -82.94973320084587
# 第 3 个火力发电站的对偶变量为: -82.1869365976923
# 第 4 个火力发电站的对偶变量为: -79.13855190110544
# 第 5 个风力发电站的对偶变量为: -85.61577050657723
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -0.01
# ****************************************************************************
# 安全发电站的总发电量: 343.28852499207653
# *************************
# 需求侧平均用电需求: 76.57534104
# ****************************************************************************
# 风速分布参数c: 11.11125981
# ****************************************************************************
# 风速分布参数kappa: 2.9635753
# ****************************************************************************
# 安全发电站的总发电成本： 2465.6953967057725
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 27 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 76.280576256031
# 第 2 个火力发电站的计划发电量为: 77.72980989800351
# 第 3 个火力发电站的计划发电量为: 62.38914532041362
# 第 4 个火力发电站的计划发电量为: 73.63740014198129
# 第 5 个风力发电站的计划发电量为: 71.04460321661325
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -88.56695553242258
# 第 2 个火力发电站的对偶变量为: -86.35175451179461
# 第 3 个火力发电站的对偶变量为: -85.60677665660171
# 第 4 个火力发电站的对偶变量为: -82.00452581715624
# 第 5 个风力发电站的对偶变量为: -88.56695553242258
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -0.01
# ****************************************************************************
# 安全发电站的总发电量: 361.08153483304267
# *************************
# 需求侧平均用电需求: 79.54768147
# ****************************************************************************
# 风速分布参数c: 13.22114577
# ****************************************************************************
# 风速分布参数kappa: 2.23501543
# ****************************************************************************
# 安全发电站的总发电成本： 2688.4725145225916
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 28 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 78.74385771687058
# 第 2 个火力发电站的计划发电量为: 79.87824464707214
# 第 3 个火力发电站的计划发电量为: 64.11494954557071
# 第 4 个火力发电站的计划发电量为: 75.10014609375966
# 第 5 个风力发电站的计划发电量为: 80.79632289450484
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -90.87575704696356
# 第 2 个火力发电站的对偶变量为: -89.61219228415334
# 第 3 个火力发电站的对偶变量为: -88.99539686656875
# 第 4 个火力发电站的对偶变量为: -85.87844380187704
# 第 5 个风力发电站的对偶变量为: -90.87575704696356
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -0.01
# ****************************************************************************
# 安全发电站的总发电量: 378.63352089777794
# *************************
# 需求侧平均用电需求: 70.77558923
# ****************************************************************************
# 风速分布参数c: 16.55283022
# ****************************************************************************
# 风速分布参数kappa: 2.00468584
# ****************************************************************************
# 安全发电站的总发电成本： 2987.259515320163
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 29 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 81.25939643292031
# 第 2 个火力发电站的计划发电量为: 82.28004700040962
# 第 3 个火力发电站的计划发电量为: 66.08625002406825
# 第 4 个火力发电站的计划发电量为: 77.0257017990192
# 第 5 个风力发电站的计划发电量为: 89.03252721892692
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -86.9826530198161
# 第 2 个火力发电站的对偶变量为: -85.48562178807087
# 第 3 个火力发电站的对偶变量为: -85.28262539544613
# 第 4 个火力发电站的对偶变量为: -84.13740172469156
# 第 5 个风力发电站的对偶变量为: -86.9826530198161
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -0.01
# ****************************************************************************
# 安全发电站的总发电量: 395.68392247534433
# *************************
# 需求侧平均用电需求: 75.70722657
# ****************************************************************************
# 风速分布参数c: 7.5123474
# ****************************************************************************
# 风速分布参数kappa: 2.84390111
# ****************************************************************************
# 安全发电站的总发电成本： 3447.4973469104943
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 30 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 82.78648675111208
# 第 2 个火力发电站的计划发电量为: 83.66984428669947
# 第 3 个火力发电站的计划发电量为: 67.07406466885665
# 第 4 个火力发电站的计划发电量为: 78.4203893615904
# 第 5 个风力发电站的计划发电量为: 80.72508159164602
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -83.54222380335902
# 第 2 个火力发电站的对偶变量为: -82.6994276119211
# 第 3 个火力发电站的对偶变量为: -82.47688700949948
# 第 4 个火力发电站的对偶变量为: -82.8991708014945
# 第 5 个风力发电站的对偶变量为: -83.54222380335902
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -0.01
# ****************************************************************************
# 安全发电站的总发电量: 392.6758666599046
# *************************
# 需求侧平均用电需求: 67.43684589
# ****************************************************************************
# 风速分布参数c: 6.9741147
# ****************************************************************************
# 风速分布参数kappa: 2.01470627
# ****************************************************************************
# 安全发电站的总发电成本： 3590.5329864142564
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 31 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 83.53401500693845
# 第 2 个火力发电站的计划发电量为: 84.40765324331522
# 第 3 个火力发电站的计划发电量为: 67.41151054003475
# 第 4 个火力发电站的计划发电量为: 79.43436915830735
# 第 5 个风力发电站的计划发电量为: 72.87228902891975
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -76.91346745386635
# 第 2 个火力发电站的对偶变量为: -76.38868314543916
# 第 3 个火力发电站的对偶变量为: -76.0749196540437
# 第 4 个火力发电站的对偶变量为: -76.43989792133678
# 第 5 个风力发电站的对偶变量为: -76.91346745386635
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -0.01
# ****************************************************************************
# 安全发电站的总发电量: 387.6598369775155
# *************************
# 需求侧平均用电需求: 64.79238622
# ****************************************************************************
# 风速分布参数c: 23.88060792
# ****************************************************************************
# 风速分布参数kappa: 2.21015256
# ****************************************************************************
# 安全发电站的总发电成本： 3492.814475738036
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 32 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 83.07583422331281
# 第 2 个火力发电站的计划发电量为: 83.99406724637419
# 第 3 个火力发电站的计划发电量为: 66.61953436580228
# 第 4 个火力发电站的计划发电量为: 79.2450560004084
# 第 5 个风力发电站的计划发电量为: 75.47191656786036
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -69.97414201760697
# 第 2 个火力发电站的对偶变量为: -69.92510944504821
# 第 3 个火力发电站的对偶变量为: -69.22612143808159
# 第 4 个火力发电站的对偶变量为: -68.24362595305688
# 第 5 个风力发电站的对偶变量为: -69.97414201760697
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -0.01
# ****************************************************************************
# 安全发电站的总发电量: 388.40640840375806
# *************************
# 需求侧平均用电需求: 79.20664696
# ****************************************************************************
# 风速分布参数c: 15.04406637
# ****************************************************************************
# 风速分布参数kappa: 2.84368377
# ****************************************************************************
# 安全发电站的总发电成本： 2895.5194201085933
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 33 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 81.52295360610007
# 第 2 个火力发电站的计划发电量为: 82.5590530756217
# 第 3 个火力发电站的计划发电量为: 64.83260741447579
# 第 4 个火力发电站的计划发电量为: 77.71336165920016
# 第 5 个风力发电站的计划发电量为: 85.75963658340139
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -70.18396744603496
# 第 2 个火力发电站的对偶变量为: -69.5051773504227
# 第 3 个火力发电站的对偶变量为: -69.02629281552292
# 第 4 个火力发电站的对偶变量为: -67.84200088042164
# 第 5 个风力发电站的对偶变量为: -70.18396744603496
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -0.01
# ****************************************************************************
# 安全发电站的总发电量: 392.38761233879916
# *************************
# 需求侧平均用电需求: 71.90639999
# ****************************************************************************
# 风速分布参数c: 19.92973653
# ****************************************************************************
# 风速分布参数kappa: 2.02497384
# ****************************************************************************
# 安全发电站的总发电成本： 3304.6438039218324
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 34 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 80.21468277694905
# 第 2 个火力发电站的计划发电量为: 81.24777713548322
# 第 3 个火力发电站的计划发电量为: 63.34295717871825
# 第 4 个火力发电站的计划发电量为: 76.30619159853708
# 第 5 个风力发电站的计划发电量为: 88.72956110101114
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -65.65011065926558
# 第 2 个火力发电站的对偶变量为: -64.46605253316675
# 第 3 个火力发电站的对偶变量为: -64.33329659315716
# 第 4 个火力发电站的对偶变量为: -64.54035363038294
# 第 5 个风力发电站的对偶变量为: -65.65011065926558
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -0.01
# ****************************************************************************
# 安全发电站的总发电量: 389.84116979069876
# *************************
# 需求侧平均用电需求: 72.83572783
# ****************************************************************************
# 风速分布参数c: 18.72716024
# ****************************************************************************
# 风速分布参数kappa: 2.20984039
# ****************************************************************************
# 安全发电站的总发电成本： 3116.9469956937946
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 35 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 78.32738571193852
# 第 2 个火力发电站的计划发电量为: 79.2736693110541
# 第 3 个火力发电站的计划发电量为: 61.346726199514904
# 第 4 个火力发电站的计划发电量为: 74.52464325378376
# 第 5 个风力发电站的计划发电量为: 92.7355960044424
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -61.53380728095322
# 第 2 个火力发电站的对偶变量为: -61.00583172832327
# 第 3 个火力发电站的对偶变量为: -60.72306828805687
# 第 4 个火力发电站的对偶变量为: -61.96371535193137
# 第 5 个风力发电站的对偶变量为: -61.53380728095322
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -0.01
# ****************************************************************************
# 安全发电站的总发电量: 386.2080204807337
# *************************
# 需求侧平均用电需求: 66.23133285
# ****************************************************************************
# 风速分布参数c: 6.39076728
# ****************************************************************************
# 风速分布参数kappa: 2.33880209
# ****************************************************************************
# 安全发电站的总发电成本： 3740.323585766485
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 36 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 76.00882318765235
# 第 2 个火力发电站的计划发电量为: 76.98936257544901
# 第 3 个火力发电站的计划发电量为: 59.11809323394746
# 第 4 个火力发电站的计划发电量为: 72.53634873904936
# 第 5 个风力发电站的计划发电量为: 76.23081164259075
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -54.45786172991064
# 第 2 个火力发电站的对偶变量为: -54.62475882651183
# 第 3 个火力发电站的对偶变量为: -54.25481182635934
# 第 4 个火力发电站的对偶变量为: -56.78365406156986
# 第 5 个风力发电站的对偶变量为: -54.45786172991064
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -0.01
# ...
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 988 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 65.83459301514863
# 第 2 个火力发电站的计划发电量为: 66.85986371736854
# 第 3 个火力发电站的计划发电量为: 50.30623783482095
# 第 4 个火力发电站的计划发电量为: 61.276514963673165
# 第 5 个风力发电站的计划发电量为: 22.981090364056456
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -74.80834327382735
# 第 2 个火力发电站的对偶变量为: -68.91512550523842
# 第 3 个火力发电站的对偶变量为: -68.07289189913382
# 第 4 个火力发电站的对偶变量为: -64.66866599594171
# 第 5 个风力发电站的对偶变量为: -74.80834327382735
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -0.01
# ****************************************************************************
# 安全发电站的总发电量: 267.2582998950677
# *************************
# 需求侧平均用电需求: 63.41616792
# ****************************************************************************
# 风速分布参数c: 7.46037989
# ****************************************************************************
# 风速分布参数kappa: 2.06906595
# ****************************************************************************
# 安全发电站的总发电成本： 1918.6499080007284
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 989 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 67.41498017040811
# 第 2 个火力发电站的计划发电量为: 67.56963636639685
# 第 3 个火力发电站的计划发电量为: 51.345065818568045
# 第 4 个火力发电站的计划发电量为: 61.39506159253764
# 第 5 个风力发电站的计划发电量为: 29.33255049787166
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -78.525863675979
# 第 2 个火力发电站的对偶变量为: -71.39105218213776
# 第 3 个火力发电站的对偶变量为: -70.56470706702802
# 第 4 个火力发电站的对偶变量为: -66.27861885699517
# 第 5 个风力发电站的对偶变量为: -78.525863675979
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -0.01
# ****************************************************************************
# 安全发电站的总发电量: 277.0572944457823
# *************************
# 需求侧平均用电需求: 73.35026091
# ****************************************************************************
# 风速分布参数c: 7.43418951
# ****************************************************************************
# 风速分布参数kappa: 2.06366986
# ****************************************************************************
# 安全发电站的总发电成本： 2000.2780486752306
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 990 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 69.40160179339952
# 第 2 个火力发电站的计划发电量为: 68.59624415395623
# 第 3 个火力发电站的计划发电量为: 52.607013153304294
# 第 4 个火力发电站的计划发电量为: 61.767115369636294
# 第 5 个风力发电站的计划发电量为: 34.618635445072194
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -85.408627987042
# 第 2 个火力发电站的对偶变量为: -78.45780572126326
# 第 3 个火力发电站的对偶变量为: -77.6479813663577
# 第 4 个火力发电站的对偶变量为: -73.08055796180179
# 第 5 个风力发电站的对偶变量为: -85.408627987042
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -0.01
# ****************************************************************************
# 安全发电站的总发电量: 286.99060991536857
# *************************
# 需求侧平均用电需求: 68.80907141
# ****************************************************************************
# 风速分布参数c: 19.00064664
# ****************************************************************************
# 风速分布参数kappa: 2.40368022
# ****************************************************************************
# 安全发电站的总发电成本： 2277.0570498462657
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 991 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 72.26715688246425
# 第 2 个火力发电站的计划发电量为: 70.66205214671602
# 第 3 个火力发电站的计划发电量为: 54.81604594766928
# 第 4 个火力发电站的计划发电量为: 63.22631894206539
# 第 5 个风力发电站的计划发电量为: 46.29851668978196
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -88.7583392182868
# 第 2 个火力发电站的对偶变量为: -82.5411082859451
# 第 3 个火力发电站的对偶变量为: -81.74252821722453
# 第 4 个火力发电站的对偶变量为: -77.37326604000067
# 第 5 个风力发电站的对偶变量为: -88.7583392182868
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -0.01
# ****************************************************************************
# 安全发电站的总发电量: 307.27009060869693
# *************************
# 需求侧平均用电需求: 68.43412668
# ****************************************************************************
# 风速分布参数c: 24.69532358
# ****************************************************************************
# 风速分布参数kappa: 2.76905839
# ****************************************************************************
# 安全发电站的总发电成本： 2607.298209368774
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 992 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 75.3041472397127
# 第 2 个火力发电站的计划发电量为: 73.12952648790021
# 第 3 个火力发电站的计划发电量为: 57.298832150221216
# 第 4 个火力发电站的计划发电量为: 65.21857341430733
# 第 5 个风力发电站的计划发电量为: 51.99678551425879
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -89.61894854491688
# 第 2 个火力发电站的对偶变量为: -85.22734273813083
# 第 3 个火力发电站的对偶变量为: -84.43547398579652
# 第 4 个火力发电站的对偶变量为: -80.47532682197553
# 第 5 个风力发电站的对偶变量为: -89.61894854491688
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -0.01
# ****************************************************************************
# 安全发电站的总发电量: 322.9478648064003
# *************************
# 需求侧平均用电需求: 77.5218747
# ****************************************************************************
# 风速分布参数c: 19.34977167
# ****************************************************************************
# 风速分布参数kappa: 2.81628725
# ****************************************************************************
# 安全发电站的总发电成本： 2521.5960516664786
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 993 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 78.0745787865043
# 第 2 个火力发电站的计划发电量为: 75.71159753505549
# 第 3 个火力发电站的计划发电量为: 59.77112720006305
# 第 4 个火力发电站的计划发电量为: 67.47880620784817
# 第 5 个风力发电站的计划发电量为: 65.03969537543904
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -93.88741727217135
# 第 2 个火力发电站的对偶变量为: -90.89240044427153
# 第 3 个火力发电站的对偶变量为: -90.10063888618683
# 第 4 个火力发电站的对偶变量为: -86.78380481521913
# 第 5 个风力发电站的对偶变量为: -93.88741727217135
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -0.01
# ****************************************************************************
# 安全发电站的总发电量: 346.07580510491005
# *************************
# 需求侧平均用电需求: 67.46785371
# ****************************************************************************
# 风速分布参数c: 10.91176004
# ****************************************************************************
# 风速分布参数kappa: 2.64243598
# ****************************************************************************
# 安全发电站的总发电成本： 2502.617612074619
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 994 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 81.18241352902145
# 第 2 个火力发电站的计划发电量为: 78.88926527520158
# 第 3 个火力发电站的计划发电量为: 62.73024181574919
# 第 4 个火力发电站的计划发电量为: 70.50792290107033
# 第 5 个风力发电站的计划发电量为: 75.17288924056318
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -90.81393081252163
# 第 2 个火力发电站的对偶变量为: -90.09482127736689
# 第 3 个火力发电站的对偶变量为: -89.29694917802401
# 第 4 个火力发电站的对偶变量为: -86.51285421550374
# 第 5 个风力发电站的对偶变量为: -90.81393081252163
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -0.01
# ****************************************************************************
# 安全发电站的总发电量: 368.48273276160575
# *************************
# 需求侧平均用电需求: 66.54800521
# ****************************************************************************
# 风速分布参数c: 15.71097882
# ****************************************************************************
# 风速分布参数kappa: 2.6773563
# ****************************************************************************
# 安全发电站的总发电成本： 2688.113237639814
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 995 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 83.35844283802382
# 第 2 个火力发电站的计划发电量为: 81.50501800927718
# 第 3 个火力发电站的计划发电量为: 65.00797194283959
# 第 4 个火力发电站的计划发电量为: 73.11324157435382
# 第 5 个风力发电站的计划发电量为: 88.3999290587652
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -85.5633841624979
# 第 2 个火力发电站的对偶变量为: -84.84059757065941
# 第 3 个火力发电站的对偶变量为: -84.55447087911847
# 第 4 个火力发电站的对偶变量为: -84.11567861941764
# 第 5 个风力发电站的对偶变量为: -85.5633841624979
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -0.01
# ****************************************************************************
# 安全发电站的总发电量: 391.3846034232596
# *************************
# 需求侧平均用电需求: 64.64150556
# ****************************************************************************
# 风速分布参数c: 3.22319547
# ****************************************************************************
# 风速分布参数kappa: 2.62903492
# ****************************************************************************
# 安全发电站的总发电成本： 4779.030759533671
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 996 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 84.36561708197358
# 第 2 个火力发电站的计划发电量为: 82.89194017313466
# 第 3 个火力发电站的计划发电量为: 66.07390894660068
# 第 4 个火力发电站的计划发电量为: 74.99336614746254
# 第 5 个风力发电站的计划发电量为: 71.66058068811553
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -76.7508208616045
# 第 2 个火力发电站的对偶变量为: -77.04617656912124
# 第 3 个火力发电站的对偶变量为: -76.66027167766863
# 第 4 个火力发电站的对偶变量为: -78.74339055586367
# 第 5 个风力发电站的对偶变量为: -76.7508208616045
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -0.01
# ****************************************************************************
# 安全发电站的总发电量: 379.985413037287
# *************************
# 需求侧平均用电需求: 75.10408906
# ****************************************************************************
# 风速分布参数c: 8.16558337
# ****************************************************************************
# 风速分布参数kappa: 2.05432022
# ****************************************************************************
# 安全发电站的总发电成本： 3193.6759909113803
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 997 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 83.76806225284123
# 第 2 个火力发电站的计划发电量为: 82.79255767794835
# 第 3 个火力发电站的计划发电量为: 65.62694773775766
# 第 4 个火力发电站的计划发电量为: 75.74309380500699
# 第 5 个风力发电站的计划发电量为: 68.63842082184358
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -75.53878861897095
# 第 2 个火力发电站的对偶变量为: -76.38171708785505
# 第 3 个火力发电站的对偶变量为: -75.75489382589747
# 第 4 个火力发电站的对偶变量为: -77.12652673699688
# 第 5 个风力发电站的对偶变量为: -75.53878861897095
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -0.01
# ****************************************************************************
# 安全发电站的总发电量: 376.5690822953978
# *************************
# 需求侧平均用电需求: 74.46242037
# ****************************************************************************
# 风速分布参数c: 3.06843305
# ****************************************************************************
# 风速分布参数kappa: 2.46674814
# ****************************************************************************
# 安全发电站的总发电成本： 4255.3204234646755
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 998 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 83.0491719518695
# 第 2 个火力发电站的计划发电量为: 82.5958485727345
# 第 3 个火力发电站的计划发电量为: 65.11177804392207
# 第 4 个火力发电站的计划发电量为: 76.12962820221394
# 第 5 个风力发电站的计划发电量为: 50.235682228134465
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -74.75057705751396
# 第 2 个火力发电站的对偶变量为: -75.41250165481532
# 第 3 个火力发电站的对偶变量为: -74.71953846097365
# 第 4 个火力发电站的对偶变量为: -75.16858680374892
# 第 5 个风力发电站的对偶变量为: -74.75057705751396
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -0.01
# ****************************************************************************
# 安全发电站的总发电量: 357.12210899887447
# *************************
# 需求侧平均用电需求: 57.53112837
# ****************************************************************************
# 风速分布参数c: 20.15305097
# ****************************************************************************
# 风速分布参数kappa: 2.53492363
# ****************************************************************************
# 安全发电站的总发电成本： 3009.6983109841335
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 999 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 82.29596324795277
# 第 2 个火力发电站的计划发电量为: 82.2641592912179
# 第 3 个火力发电站的计划发电量为: 64.51935551595876
# 第 4 个火力发电站的计划发电量为: 76.14152247756202
# 第 5 个风力发电站的计划发电量为: 58.79133607269746
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -68.24119079265475
# 第 2 个火力发电站的对偶变量为: -66.69959926758634
# 第 3 个火力发电站的对偶变量为: -65.80502693868122
# 第 4 个火力发电站的对偶变量为: -64.88275878295758
# 第 5 个风力发电站的对偶变量为: -68.24119079265475
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -0.01
# ****************************************************************************
# 安全发电站的总发电量: 364.0123366053889
# *************************
# 需求侧平均用电需求: 69.0560216
# ****************************************************************************
# 风速分布参数c: 17.58707426
# ****************************************************************************
# 风速分布参数kappa: 2.68279184
# ****************************************************************************
# 安全发电站的总发电成本： 2883.538726014225
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 2024-07-30 17:07:16.160

# %%
#数据存储
np.savetxt('./data/02_IOS_optimal_parameters_large_Byzantine_attack_sum_cost.txt',sum_cost,fmt='%0.8f')
np.savetxt('./data/02_IOS_optimal_parameters_large_Byzantine_attack_sum_thermal_wind_power_station_strategy.txt',sum_thermal_wind_power_station_strategy,fmt='%0.8f')

# %%
#评价指标：动态regret和累计的约束违反

# %%
#动态regret

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
from sympy import *
import math 
from datetime import datetime
from scipy.special import gamma, factorial
import scipy.special as sc

# %%
sum_cost=np.loadtxt("./data/02_IOS_optimal_parameters_large_Byzantine_attack_sum_cost.txt")
optimal_sum_cost=np.loadtxt("./data/00_optimal_sum_cost_varying_D_c_kappa_normal_distribution_(70,5).txt")

# %%
dynamic_regret=[]
dynamic_regret_T=[]
for T in range(1, 1000):
    dynamic_regret_auxiliary_variable=0
    for t in range(0, T):
        dynamic_regret_auxiliary_variable=dynamic_regret_auxiliary_variable+sum_cost[t]-optimal_sum_cost[t]
    dynamic_regret.append(dynamic_regret_auxiliary_variable)
    dynamic_regret_T.append((dynamic_regret_auxiliary_variable)/T)

# %%
dynamic_regret
# Out:
# [-141.43343337999977,
#  289.20797399,
#  239.12044245000016,
#  214.30786970000008,
#  397.4311834,
#  471.7902247500001,
#  801.12947089,
#  919.7899775999999,
#  2786.2810579300003,
#  3109.8311006700005,
#  3360.6608920400004,
#  3133.6245149100005,
#  3514.8556103700007,
#  3513.9412479000007,
#  3431.1079438600004,
#  3732.9284782000004,
#  3659.8083400399996,
#  3620.2368085199996,
#  3902.9395156399996,
#  3939.8443353599996,
#  3566.5814831899993,
#  3341.21444669,
#  3473.9421445399994,
#  3224.5075234299993,
#  2960.8938108899997,
#  3342.7172548699996,
#  3065.38256796,
#  2794.2159743500006,
#  3176.7059175400004,
#  3566.4830898600003,
#  4458.4371418499995,
#  5229.65946745,
#  5568.21168133,
#  6011.8721246000005,
#  6420.332789890002,
#  7560.940050480001,
#  7946.095827620002,
#  7959.879824220001,
#  8745.12824331,
#  9027.770722960002,
#  8883.845239910002,
#  8583.431842170003,
#  7939.843946910003,
#  7826.127818310002,
#  7275.913296510002,
#  6906.307162300001,
#  6747.563026370002,
#  7258.682140830003,
#  7105.616027390002,
#  6993.161932560002,
#  7229.720512810003,
#  7785.879727100002,
#  8171.544336930001,
#  8763.71795021,
#  9143.73537159,
#  9061.58301107,
#  9583.613258190002,
#  10308.173271990001,
#  11466.532645450001,
#  13522.02940234,
#  13721.760430089998,
#  14367.805365309998,
#  14101.664499569999,
#  14181.534900729997,
#  14202.184613489997,
#  14473.757559149997,
#  14422.586846279995,
#  14165.594538669997,
#  13875.296321049998,
#  13537.967113579998,
#  13541.237446049998,
#  12796.734389259997,
#  13695.844093519996,
#  13643.560354449995,
#  13717.042715619997,
#  13339.654364419997,
#  13777.818405459999,
#  13816.690270459998,
#  13620.615296449998,
#  14316.813658949999,
#  14558.966607259998,
#  14424.113540979997,
#  15132.020775139998,
#  15433.011396589996,
#  16281.767297029995,
#  16513.733072909996,
#  16852.945360449998,
#  17201.84968026,
#  17504.53640115,
#  17474.30463512,
#  17358.811823660002,
#  17485.92427267,
#  17422.58374146,
#  18059.80568583,
#  16971.28846193,
#  17073.66398658,
#  16841.735071069998,
#  17199.679832809998,
#  17149.241204219998,
#  17310.5025971,
#  17771.92487601,
#  18181.83973015,
#  18644.71966528,
#  18851.420919720003,
#  19372.199798600006,
#  20138.046506730007,
#  20427.572599640007,
#  19972.795477240008,
#  19400.737179350006,
#  19389.995648770004,
#  18893.539917980004,
#  18297.665777690007,
#  17886.222115120006,
#  17694.674024780008,
#  17401.322954670006,
#  17263.009639560005,
#  17775.671175280004,
#  18021.777709440004,
#  18253.596276580007,
#  18893.802831800007,
#  19941.19622055001,
#  20707.008708120007,
#  21325.21661362001,
#  21562.43831524001,
#  22341.57618095001,
#  22826.11453222001,
#  23206.47710945001,
#  23043.60195328001,
#  23181.01980543001,
#  23077.04446183001,
#  23204.187573200008,
#  23021.91433307001,
#  21913.759265580007,
#  21965.706264260007,
#  22149.160410450007,
#  21851.614777090006,
#  22049.915024800004,
#  22875.250377670007,
#  22364.908388330008,
#  22297.875747750008,
#  22725.46749365001,
#  22752.81261197001,
#  23313.034938420013,
#  23016.224340350014,
#  23093.572165950016,
#  23584.82071100002,
#  24540.90051704002,
#  25829.039127730022,
#  26765.192363170023,
#  27401.774136470023,
#  27041.886568280024,
#  27256.581915450028,
#  26600.338287810027,
#  25594.80225003003,
#  24481.19417446003,
#  23360.41647704003,
#  22388.433839030033,
#  21840.657443070035,
#  22324.227660190038,
#  22912.69743193004,
#  23908.73727925004,
#  24429.28172239004,
#  26733.165411950038,
#  27455.411991170036,
#  28912.451937040034,
#  29551.815139170034,
#  29778.963099300032,
#  29622.04427859003,
#  29767.92027164003,
#  29225.466426130028,
#  28984.930761440028,
#  28715.01457360003,
#  28310.12249434003,
#  28564.12888851003,
#  28065.997100710032,
#  27847.89958597003,
#  28153.65085018003,
#  28195.88015290003,
#  28233.69321606003,
#  28899.81597857003,
#  28950.81091151003,
#  28725.16268362003,
#  28491.97138128003,
#  28823.63430048003,
#  30157.072337430032,
#  30123.62734950003,
#  29847.831053620033,
#  30177.117638960037,
#  30119.489596540036,
#  30305.620652450038,
#  30542.856838180036,
#  31057.831201670037,
#  31408.65310932004,
#  31421.82571863004,
#  31676.569684090042,
#  31623.630656820045,
#  31796.80029709005,
#  33596.228431490046,
#  33802.28789483004,
#  34023.413900510044,
#  33892.86111169004,
#  33812.229157750044,
#  33834.95482252004,
#  32861.802824590035,
#  32674.648629060037,
#  32155.920014670035,
#  32146.930795700035,
#  31968.365974840035,
#  32211.184338480038,
#  32161.752249830035,
#  32852.595950990035,
#  34822.89140161003,
#  35261.34326879003,
#  35780.675336140026,
#  35715.537872660025,
#  35897.344185970025,
#  36021.99941739002,
#  36563.94191844002,
#  36764.74704734002,
#  36300.80996722002,
#  35609.30043167002,
#  35580.28192139002,
#  35495.22319451002,
#  35084.26669730002,
#  34830.65597450002,
#  34586.13403046002,
#  35068.89143395002,
#  35122.05678835002,
#  34655.63541746002,
#  34492.39008916002,
#  34529.60104248002,
#  33831.62409577002,
#  34809.66231763002,
#  34460.65280399002,
#  33882.311514220026,
#  34022.31393921003,
#  34619.44217270002,
#  34815.12816301002,
#  35525.34293956002,
#  35994.47044236001,
#  36509.80071333001,
#  36980.28113760001,
#  37459.18045907001,
#  37311.530761720016,
#  37239.005587920015,
#  36800.293171400015,
#  36720.42117225002,
#  36227.07873121002,
#  36099.90102062002,
#  35840.37345734002,
#  35913.10775459002,
#  36268.18701470002,
#  36204.61437359002,
#  36721.00095980002,
#  37093.47827341002,
#  37326.79939393002,
#  37760.15374705002,
#  38145.12353923002,
#  38431.53982814003,
#  38689.15631217003,
#  38249.473012860035,
#  38357.84525438004,
#  38073.64845834004,
#  37616.09068701004,
#  37393.691466530036,
#  37503.262777860036,
#  37296.20225549003,
#  36930.54743453003,
#  36915.89315966003,
#  36829.67125294003,
#  38896.37463709003,
#  39220.15736959003,
#  39967.63452386003,
#  41525.23533342003,
#  41554.457346200026,
#  41819.25307469002,
#  41441.29298203002,
#  41494.19453953002,
#  40972.23232451003,
#  40575.20283956002,
#  41569.04844185003,
#  40957.98668221003,
#  40924.85308600003,
#  41137.82952823003,
#  40829.77717150003,
#  41117.83054985003,
#  41137.87013446003,
#  40176.26943780002,
#  40451.43531057002,
#  40795.41810378002,
#  40761.55447411002,
#  41542.569343500014,
#  41543.809722270016,
#  42037.26454447001,
#  42330.57206257001,
#  42722.98777696001,
#  42249.57087369001,
#  42213.49122589001,
#  42939.24800885001,
#  42515.79587080001,
#  41970.24106783001,
#  41859.61698116001,
#  41616.67523324001,
#  41955.75182890001,
#  41302.02793722001,
#  41426.89399582001,
#  41788.45706425001,
#  41796.035157520004,
#  40983.16070426001,
#  41512.968021780005,
#  42504.29752274001,
#  42898.63990747001,
#  43466.42176444001,
#  44220.46254319001,
#  45244.26254451001,
#  45834.01927617001,
#  45951.78232879001,
#  45919.906101800014,
#  45831.44284139001,
#  45925.23040219001,
#  45694.82076203001,
#  45053.89539882001,
#  44319.52838459001,
#  44378.77416229001,
#  44208.04034348,
#  44092.245654930004,
#  44186.20445258001,
#  44454.36267946001,
#  45020.42797603001,
#  45852.688252430016,
#  45992.615355290014,
#  46244.63004226001,
#  46526.22261413001,
#  46810.48950066001,
#  46771.05029843001,
#  46683.55146780001,
#  47458.80671580001,
#  46575.32181959001,
#  46610.542457040014,
#  45364.49856753001,
#  45094.23682361001,
#  44386.30752542001,
#  43784.36449413001,
#  43809.32026179001,
#  43696.67020615001,
#  44295.291156640014,
#  45110.40039557002,
#  46036.42493637002,
#  46840.81987577002,
#  47638.66679034002,
#  48656.55103255002,
#  50104.62079296002,
#  51015.78025838002,
#  50739.08903744002,
#  50438.74083755002,
#  50444.16511938002,
#  50126.92774978002,
#  49583.165661300016,
#  48501.410064810014,
#  48160.59188664001,
#  47733.70411460001,
#  47431.66324598001,
#  47471.11380276001,
#  47325.946091430014,
#  47296.85573977001,
#  48059.541546950015,
#  48395.689851570016,
#  48925.84880448002,
#  49410.36492779002,
#  50137.346434430016,
#  50746.24566045002,
#  51488.61579914002,
#  52492.82541214002,
#  53017.749392350015,
#  53253.339551500016,
#  54594.160380160014,
#  54599.472043080015,
#  54152.78304107002,
#  53164.169318430024,
#  52166.62954958003,
#  51865.79653261003,
#  51291.53776417003,
#  50475.70115918003,
#  50253.587546600036,
#  50273.46902308003,
#  50448.177164140034,
#  50537.16391210003,
#  51063.59869230003,
#  51351.27353689003,
#  51795.85906630003,
#  52015.55350858003,
#  52530.51665477003,
#  53140.66492255002,
#  53699.370913400024,
#  54099.46737331002,
#  53945.90635259002,
#  53980.35775347002,
#  53417.78099089002,
#  54379.400779900025,
#  54010.19851813002,
#  53283.58475564002,
#  52528.14917475002,
#  52096.35659903001,
#  52656.05477326002,
#  52518.09865637001,
#  52275.62876221001,
#  52555.83451572001,
#  52316.81244772,
#  53751.243807180006,
#  53695.8380408,
#  53763.05664763,
#  53876.566722430005,
#  54067.38294177,
#  54460.859851860005,
#  54809.104786430005,
#  55175.770955390006,
#  54728.57576796001,
#  55427.420734960004,
#  55349.87540006001,
#  55523.63237545001,
#  55346.17242695001,
#  55377.824833530016,
#  55591.424238590014,
#  55707.57486433001,
#  55627.872689140015,
#  55693.301190220016,
#  55724.35936977001,
#  55567.334140200015,
#  55963.02265735001,
#  56415.39631524002,
#  56331.89064814001,
#  57394.55186418001,
#  57447.77603553001,
#  57019.89132592001,
#  57049.30003140002,
#  57219.896080430015,
#  57297.17472593002,
#  56887.71822043001,
#  58067.66799245001,
#  58482.83383857001,
#  58409.31519315001,
#  58403.72654100001,
#  59271.81039656001,
#  59299.74677894001,
#  59124.22021945001,
#  59516.098211370016,
#  59446.727904920015,
#  59032.73093170001,
#  58654.35606109001,
#  58104.22028677001,
#  57930.79951015001,
#  58009.864822090014,
#  58161.589160780015,
#  58166.19203663002,
#  58783.25740274002,
#  58992.86931857002,
#  59729.53361983002,
#  60024.80643519002,
#  60366.67963716002,
#  60515.25317642002,
#  61436.50875115002,
#  60515.61473687001,
#  60087.53768041001,
#  60837.76200850001,
#  60234.67509320001,
#  59553.766690720004,
#  58970.69790844,
#  58222.68241715,
#  57285.540709789995,
#  57378.20078236,
#  57843.87432179,
#  58353.16852401,
#  58942.29699398,
#  61704.595283810006,
#  62962.05532243,
#  63567.033129250005,
#  64129.62428514001,
#  64333.39134385002,
#  65434.52400655002,
#  64771.22470522002,
#  64594.98175801001,
#  64172.59772661002,
#  63806.57406306002,
#  63462.68328927001,
#  62862.21159061001,
#  63317.27538152001,
#  63815.359259530014,
#  64692.45505673001,
#  64950.796517430004,
#  64761.202696600005,
#  64896.70437317001,
#  65021.65520716001,
#  65658.63817643,
#  67660.91921202,
#  67188.40487962001,
#  68102.09798715,
#  67595.27582288,
#  67342.4645163,
#  67219.21579459,
#  67504.52772978,
#  67565.48996547001,
#  67356.62598862001,
#  67390.57320422001,
#  67651.87232255001,
#  67753.92896665001,
#  67964.47474418001,
#  68973.22501806001,
#  68991.45739176,
#  68678.67377973002,
#  68674.91871950001,
#  68186.30873839001,
#  68321.86464145001,
#  68223.16748723002,
#  68650.07147006002,
#  68414.60518495002,
#  68590.16068699001,
#  68576.52422648002,
#  69033.26278267002,
#  69201.75697226003,
#  69524.41901727003,
#  69838.52870913003,
#  69843.30763765002,
#  70432.15006774003,
#  69946.67156154003,
#  69458.39581530004,
#  69256.75841453005,
#  69347.28441859005,
#  69538.89607187004,
#  69076.98170466005,
#  68846.36883849006,
#  69516.29966375006,
#  69246.93916239007,
#  69567.01204885008,
#  70763.32055364008,
#  70803.02732724007,
#  70443.95599688006,
#  70846.12752121006,
#  70850.43597739007,
#  70796.33447934008,
#  70886.60163221008,
#  70952.13671813007,
#  71203.24539412008,
#  71606.27801364008,
#  72229.62529620007,
#  72787.14320479007,
#  72857.57037037007,
#  72949.39699704006,
#  72959.43269652006,
#  72724.21095385007,
#  72432.39304961007,
#  72065.53245906006,
#  71706.21081620007,
#  71378.62481990007,
#  71360.50125419007,
#  71156.85720383006,
#  70952.40269112006,
#  71486.60951567006,
#  72025.27375955007,
#  71676.31816256007,
#  71869.07786221006,
#  72283.83653313006,
#  72930.10672500006,
#  74772.58331711007,
#  75280.30795075007,
#  75538.47596600007,
#  76084.81266149007,
#  76226.44293049007,
#  76408.07637736006,
#  76139.98350024005,
#  75794.54544139004,
#  75049.69931496005,
#  74079.40158462005,
#  73886.12876916004,
#  73566.22439388004,
#  73753.74990370004,
#  73415.36619927004,
#  73820.84859893004,
#  74266.68364001003,
#  75306.60169635003,
#  75033.10424246003,
#  75300.53256985004,
#  74818.51596713004,
#  74563.06999330004,
#  75176.03472406005,
#  75249.09390776005,
#  75951.78542957004,
#  76022.71293156005,
#  76331.09863879005,
#  76472.70230948005,
#  76523.87285973005,
#  76687.54763467006,
#  76813.87120607005,
#  76411.66095132004,
#  76911.83920654004,
#  77058.76929220004,
#  77421.74035006005,
#  77778.02466389006,
#  77059.59252000006,
#  77520.40685592007,
#  77702.57395734006,
#  77599.14094460006,
#  77655.98865680007,
#  77553.97916788007,
#  76800.32697622007,
#  76422.48348662005,
#  76912.61925579005,
#  76632.48916943006,
#  76876.60307985007,
#  76137.59673323008,
#  75393.23447174008,
#  75543.73734703008,
#  76014.22376418009,
#  76338.35508925008,
#  76374.91402286007,
#  76425.02008583008,
#  76749.10530139008,
#  76706.19166784009,
#  76632.59045460008,
#  77619.24154076008,
#  78164.18439831007,
#  78071.57268293007,
#  77976.27918280008,
#  77701.37358184009,
#  76895.5236020701,
#  76867.33468118009,
#  77001.59719119009,
#  76652.56867887008,
#  77236.04790620008,
#  77425.11008790007,
#  78124.73299889007,
#  78547.84476860007,
#  79544.86059057007,
#  80019.69161085006,
#  81348.61441372005,
#  81506.21946210004,
#  81492.47848788003,
#  81276.17245356002,
#  81042.21532784002,
#  81017.09791237002,
#  80946.45573450002,
#  80659.88453088002,
#  80860.28867778003,
#  80963.56146526003,
#  80599.30509037004,
#  80624.34378858004,
#  80786.99547843004,
#  81665.67972443003,
#  81554.48697614002,
#  81347.39681165002,
#  81159.12819960002,
#  81033.16368051001,
#  80846.09489747001,
#  81587.7122568,
#  81640.90750538,
#  81176.07530993,
#  80928.59730871001,
#  80911.00826259001,
#  80472.47508028001,
#  79688.49195726,
#  80345.21510294001,
#  80643.98462463001,
#  81582.98658761002,
#  82044.01847227002,
#  82779.09579781002,
#  83852.57320794002,
#  84128.73257505003,
#  85047.80995446004,
#  85668.66890447003,
#  86088.38342457003,
#  86228.56930457002,
#  86469.98782013002,
#  86358.47238361002,
#  85903.43022353003,
#  85353.39368276003,
#  84583.58299362003,
#  84149.01951311003,
#  83663.47895402003,
#  83588.33862604003,
#  83308.19841987002,
#  83559.90863791002,
#  83071.47147651002,
#  82863.48413030003,
#  83031.06983270003,
#  83190.62196071004,
#  85274.85148320004,
#  85460.72603759002,
#  87162.00481598004,
#  87424.56798461004,
#  86815.75530648003,
#  86948.81639946002,
#  86778.49706355002,
#  86448.23054385002,
#  86698.89965823002,
#  86479.92428368001,
#  86858.36659896001,
#  87126.77697062,
#  87446.42369172,
#  88055.95147574,
#  88317.86423897,
#  88524.22899868999,
#  88503.24577149999,
#  88614.6638456,
#  88166.9180215,
#  88748.46428529,
#  88795.31511849,
#  88296.46456152,
#  87298.18806593,
#  86619.51950837,
#  86718.45318179,
#  86848.1103838,
#  86914.09791719,
#  87844.86787332999,
#  88785.97091274,
#  89748.44733365999,
#  90737.80164254,
#  91938.35543291,
#  92625.52194876001,
#  93106.25244325,
#  93602.43272734001,
#  93240.07444263002,
#  92760.50627231003,
#  92511.66434321002,
#  91863.23100832003,
#  91303.34720725003,
#  90104.71478749003,
#  89463.46387708002,
#  88986.86755305002,
#  89014.81117803002,
#  89409.75788394002,
#  89512.31196902003,
#  89618.18348870002,
#  90039.15134055002,
#  90151.85150864003,
#  91288.63549272003,
#  92393.90654009003,
#  93508.36646008004,
#  94108.31450680004,
#  94687.86924816004,
#  95782.11115337005,
#  96377.71855746004,
#  96126.09637019003,
#  97017.68264062004,
#  96974.15622185003,
#  96818.99816408004,
#  96551.06201027003,
#  96532.33346800003,
#  96599.82887322002,
#  96767.05310862,
#  96615.00416192,
#  96279.02871225,
#  96689.43142331,
#  96761.0563261,
#  96861.44307187,
#  98182.45369426,
#  99071.97589172,
#  98958.41232684998,
#  99361.75716169998,
#  99093.67437926999,
#  98536.85495781999,
#  98228.63011093998,
#  98371.52085946998,
#  98502.37391865999,
#  99045.51984899999,
#  99281.63599199,
#  99555.83559594999,
#  99574.91603028998,
#  99387.21117961999,
#  99572.47479686998,
#  99006.50613535999,
#  99408.12785846999,
#  99709.25703539,
#  99785.65058398999,
#  100391.16059295999,
#  100205.11277606999,
#  100110.15585047,
#  100839.48514902999,
#  100606.16499872999,
#  100561.06257308,
#  100346.76897604,
#  100961.92671921,
#  100797.86302111,
#  100937.45824363,
#  100802.26925956,
#  101265.07722147,
#  101855.56017165999,
#  103335.03676961,
#  103369.86652332,
#  103484.92354388999,
#  103495.59554716,
#  103783.65897994999,
#  104156.85741864999,
#  103400.80889597,
#  102604.89623223999,
#  102226.02404157,
#  102362.20027291999,
#  102393.67138782999,
#  102208.00474386998,
#  104360.58496379,
#  104981.75803211,
#  105059.98508769,
#  106066.29814857,
#  106626.23845185,
#  106957.02754704,
#  107353.42793908,
#  107234.05689539,
#  106992.03857948999,
#  107002.71722620999,
#  107023.17356065,
#  107688.67688757,
#  107698.70946160001,
#  108197.85460160002,
#  108651.78783880001,
#  108777.67144982002,
#  108994.15004785001,
#  108820.81179279,
#  108923.58644048,
#  108802.53830598,
#  108945.19568735,
#  109708.44305636,
#  110081.78668710002,
#  110828.66135105002,
#  112347.07964207002,
#  112512.20204153002,
#  112238.66188395003,
#  112005.96951853004,
#  111636.83224032003,
#  110919.99358042002,
#  110441.88550824003,
#  109554.37991921003,
#  109192.67675662003,
#  108756.44351251003,
#  108899.43968574003,
#  109167.31277648003,
#  109474.97147624004,
#  109750.27455933005,
#  110098.51453945004,
#  110904.14074550004,
#  112087.91692093005,
#  113290.41424122005,
#  114042.05529183004,
#  114263.65010567004,
#  114950.03145357003,
#  115205.33836788003,
#  116554.78902142003,
#  116203.90384686003,
#  115284.51653585002,
#  114941.63028831003,
#  114730.76549933002,
#  113475.19116312002,
#  112520.34706356002,
#  111938.01277648003,
#  111344.96299649002,
#  111003.52172282002,
#  110714.25673221002,
#  111183.83046963002,
#  112183.79845765002,
#  113483.63586878002,
#  114573.35939438002,
#  115286.37655418002,
#  115830.28343870003,
#  117088.87242538003,
#  117409.38262641004,
#  117475.21917700004,
#  117290.92619421004,
#  116871.26454756004,
#  115883.62334097005,
#  115113.13815150005,
#  114943.63238995006,
#  115048.07120492005,
#  113915.75877124006,
#  113454.95547195006,
#  113778.08331363005,
#  113367.18115435005,
#  113373.18151342006,
#  113212.02320911006,
#  113804.11621044006,
#  114952.08877804007,
#  115445.18320086006,
#  116836.20243736006,
#  117806.20298235006,
#  119822.68345905007,
#  120164.11922923005,
#  120129.38823246004,
#  119976.74504538006,
#  120094.07456004006,
#  120374.34541662005,
#  120038.85745300006,
#  119411.08813265005,
#  118745.73349082004,
#  118185.48735443005,
#  117627.93133959005,
#  117489.33276734006,
#  117273.91686343006,
#  117746.34507343006,
#  117753.95188121006,
#  118018.67462197006,
#  118940.55174278007,
#  119560.62552704006,
#  119959.98894407005,
#  120325.95160995005,
#  121284.42362587004,
#  121134.06478935004,
#  121237.51925056004,
#  122085.94721886005,
#  121654.31454687004,
#  121430.65239388004,
#  121036.78689208004,
#  121047.24040234004,
#  119728.96686421004,
#  119506.53391380004,
#  119371.65995501004,
#  119051.83739253004,
#  118902.25722236004,
#  119518.46659886005,
#  120513.90769852005,
#  121315.53041782005,
#  121891.27797403005,
#  122797.26053763005,
#  123508.56558454005,
#  123905.46293709005,
#  124587.55025671006,
#  124521.74434981006,
#  124104.50385516006,
#  125476.50397253006,
#  125061.13070950005,
#  124577.43912679005,
#  123975.32279759005,
#  123293.49925742006,
#  122788.77466456006,
#  121736.25019154005,
#  121517.07233669005,
#  121658.94930874005,
#  121595.06210502004,
#  122423.56495082004,
#  123175.67072490005,
#  123927.01705016004,
#  124745.25666866003,
#  125847.03112205004,
#  126427.93616729004,
#  127268.04847208003,
#  127957.03517117004,
#  128142.49236690003,
#  129302.6043345,
#  128838.23169134,
#  128700.04899868,
#  128062.41408509,
#  128064.72018515,
#  127197.21682932,
#  126414.30291936,
#  126116.25627676999,
#  125922.66267297999,
#  125835.16893954,
#  125216.78461944,
#  125217.14204101,
#  125633.10176644,
#  126011.72385011001,
#  126933.34832114002,
#  127384.22646921001,
#  127710.65620366001,
#  128563.31698566001,
#  130423.63496543001,
#  130667.54982978002,
#  130698.48018021003,
#  131617.2353283,
#  131464.50899806002,
#  131483.61267549003,
#  131763.48559608002,
#  131937.95744443,
#  131249.27813033,
#  129986.73714989,
#  129348.99164430001,
#  129208.33481212,
#  129425.17940060001,
#  130342.79371657001,
#  130231.36649337,
#  130701.08483485001,
#  131263.36630075,
#  132204.89188706,
#  132688.11086436998,
#  133277.6108305,
#  133900.45221709,
#  134460.92128718,
#  135338.72060284,
#  136688.88888078,
#  136566.41423619,
#  136303.05610169002,
#  135574.16216641004,
#  134709.73722900002,
#  134203.49223139,
#  133157.92022541998,
#  133021.69696908997,
#  132703.28065543997,
#  132594.49690447998,
#  132781.34041535997,
#  133488.82184248997,
#  135736.08128231997,
#  135813.52376195998,
#  136836.85713564,
#  137879.45325586]

# %%
#绘图 dynamic_regret和dynamic_regret_T

# %%
sub1=plt.subplot(1, 2, 1)##############################################################
iteration=[]
for i in range(0,999):
    iteration.append(i)

#在同一幅图片上画3条折线
A,=plt.plot(iteration,dynamic_regret,color = 'red',linewidth = '1.5',label='attack-free online primal-dual algorithm')


#设置图例并且设置图例的字体及大小
font1 = {
'size'   : 18,
}
#legend = plt.legend(handles=[A],prop=font1)
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=18)
 
#设置横纵坐标的名称以及对应字体格式
font2 = {
'size'   : 18,
}
plt.xlabel('T',font2)
plt.ylabel(r'Dynamic regret $Reg(T)$',font2)
plt.title('varying $D_{t}$',font2) 

sub2=plt.subplot(1, 2, 2)##############################################################
iteration=[]
for i in range(0,999):
    iteration.append(i)

#在同一幅图片上画3条折线
A,=plt.plot(iteration,dynamic_regret_T,color = 'red',linewidth = '1.5',label='attack-free online primal-dual algorithm')


#设置图例并且设置图例的字体及大小
font1 = {
'size'   : 18,
}
#legend = plt.legend(handles=[A],prop=font1)
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=18)
 
#设置横纵坐标的名称以及对应字体格式
font2 = {
'size'   : 18,
}
plt.xlabel('T',font2)
plt.ylabel(r'Dynamic regret $Reg(T)/T$',font2)
plt.title('varying $D_{t}$',font2) 

plt.legend(handles=[A],prop={'size':18},loc="upper center", bbox_to_anchor=[-0.3, -0.2],
           ncol=18, shadow=True, fancybox=True)

plt.subplots_adjust(wspace=0.5,hspace=0.5) 
plt.gcf().set_size_inches((15, 5))

#plt.savefig('./figures/01-figure1_dynamic_regret_attack_free_varying_D.pdf',format='pdf', bbox_inches='tight')
#plt.savefig('./figures/01-figure1_dynamic_regret_attack_free_varying_D.png',format='png', bbox_inches='tight')

# %%
#累计的约束违反

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
from sympy import *
import math 
from datetime import datetime
from scipy.special import gamma, factorial
import scipy.special as sc

# %%
sum_thermal_wind_power_station_strategy=np.loadtxt("./data/02_IOS_optimal_parameters_large_Byzantine_attack_sum_thermal_wind_power_station_strategy.txt")
d_power_demand=np.loadtxt("./data/d_power_demand_normal_distribution_(70,5).txt")

# %%
accumulative_constraint_violation=[]
accumulative_constraint_violation_T=[]
for T in range(1, 1000):
    accumulative_constraint_violation_auxiliary_variable=0
    for t in range(0, T): 
        accumulative_constraint_violation_auxiliary_variable=accumulative_constraint_violation_auxiliary_variable+(1/5)*sum_thermal_wind_power_station_strategy[t+1]-d_power_demand[t+1]
    accumulative_constraint_violation.append(abs(accumulative_constraint_violation_auxiliary_variable))
    accumulative_constraint_violation_T.append(abs(accumulative_constraint_violation_auxiliary_variable)/T)

# %%
accumulative_constraint_violation
# Out:
# [5.161334969999999,
#  3.1631070959999903,
#  0.31431276200001435,
#  2.0916716260000072,
#  0.9137057880000015,
#  0.6527665859999985,
#  2.496111968000008,
#  12.323250078000015,
#  16.897730992000007,
#  4.9080711320000034,
#  2.8317767559999822,
#  2.8413552120000105,
#  2.3775074780000125,
#  0.9777948759999759,
#  2.970287574000025,
#  1.6249425300000269,
#  6.58571849599997,
#  15.678887633999963,
#  15.366458561999956,
#  23.772326453999945,
#  33.48041875399995,
#  40.91372023599995,
#  49.42000830999996,
#  60.53777759999994,
#  57.439297843999945,
#  65.35693388599995,
#  72.68830838999995,
#  67.73719343999994,
#  64.30763551399994,
#  53.20930807199994,
#  40.469726895999926,
#  41.99509217599993,
#  35.42396969799992,
#  30.29146356999992,
#  19.281192323999917,
#  14.841332477999913,
#  15.047972887999904,
#  0.5263524639998991,
#  0.04954883000009147,
#  8.556314061999913,
#  18.039574413999908,
#  39.701967763999896,
#  55.09472202199989,
#  66.94964959999987,
#  77.90023734799988,
#  84.14204807999988,
#  92.08483324999987,
#  95.64435080399987,
#  103.27620871199989,
#  105.59946956799988,
#  104.02726830799988,
#  104.82216607599987,
#  97.75249833599987,
#  94.78261712599988,
#  97.84723021399986,
#  94.23537389199984,
#  87.19877531999984,
#  66.40311400199982,
#  58.07855528999981,
#  56.66983227799982,
#  48.030084883999805,
#  53.36682599999979,
#  52.59811809999978,
#  54.56797438399977,
#  53.66721872999976,
#  57.647660997999765,
#  62.97782411999975,
#  69.08215237799973,
#  76.87927535799973,
#  77.53007928399973,
#  91.67039834799974,
#  102.02599847999973,
#  108.94108640599973,
#  110.42998501799973,
#  118.53393711599972,
#  118.68791193799971,
#  119.71591661999972,
#  123.45133933399971,
#  127.68400884999971,
#  125.16230929799971,
#  127.46193496199972,
#  121.32901878999972,
#  121.0789068719997,
#  118.26435319599969,
#  118.75421369199968,
#  112.94749288199968,
#  110.51026603599968,
#  105.94463250599968,
#  107.69548398399967,
#  110.86848725399967,
#  110.28611006799967,
#  117.81667854399967,
#  123.36142105999966,
#  142.14912306999963,
#  146.16927115799962,
#  151.12243059599962,
#  145.9246346439996,
#  150.2669909239996,
#  151.05370415599958,
#  142.63872434999956,
#  135.41430898199957,
#  127.83678556999956,
#  126.42645766799956,
#  116.88374963999955,
#  104.09914088799954,
#  107.45470880599953,
#  120.93435561199954,
#  136.44571614799952,
#  142.8343490839995,
#  159.2381586699995,
#  170.1105805659995,
#  179.6753621679995,
#  186.1682349699995,
#  200.23094283599949,
#  203.13288156999948,
#  205.61549367199947,
#  213.24808231999947,
#  209.80359457399945,
#  206.68605482399943,
#  190.66638134199943,
#  179.01333951399943,
#  171.05723125399942,
#  170.8787811719994,
#  166.6152807439994,
#  161.0500290079994,
#  160.0870473879994,
#  163.47000317999942,
#  172.67115154799944,
#  177.40235875999946,
#  178.03098853399948,
#  181.52090377999946,
#  199.93938079599945,
#  202.13114925999946,
#  205.40315178599946,
#  211.49516044399945,
#  213.36861013399943,
#  209.6991806859994,
#  218.2152628319994,
#  222.5256511479994,
#  223.7390326319994,
#  227.8134723179994,
#  229.1469827259994,
#  235.69253711599941,
#  234.6763070959994,
#  231.80963202399937,
#  217.61659003199935,
#  195.56751482199934,
#  178.27497992799934,
#  176.62704987799935,
#  182.68562310199934,
#  189.68331124199932,
#  201.1643230539993,
#  224.3701526439993,
#  249.62806914399928,
#  268.5948799599993,
#  288.30445431999925,
#  303.0596939819992,
#  294.38533138999924,
#  285.65640250799925,
#  270.82828217999923,
#  263.01425601199924,
#  250.86133923799923,
#  239.13217610799921,
#  224.53524231199918,
#  221.8558891539992,
#  223.13743334799918,
#  228.37219971599916,
#  231.86459305199915,
#  242.2542719539992,
#  252.27323857199917,
#  257.9925459839992,
#  265.09117762199924,
#  261.81083066399924,
#  271.55379477199926,
#  275.8174158879993,
#  271.5501676259993,
#  271.23280036999927,
#  271.9575033279993,
#  260.02635693599933,
#  260.29159477599933,
#  264.5767480179993,
#  270.36525611799925,
#  264.62116111599926,
#  265.7106747279992,
#  267.0059822599992,
#  274.7805314299992,
#  282.2729334639992,
#  295.0592757379992,
#  296.6244524159992,
#  296.1957323039992,
#  288.2395062459992,
#  285.09578398399924,
#  288.0772203239992,
#  286.9739614399992,
#  287.9012880239992,
#  288.11707213799923,
#  281.9771541759992,
#  280.6713543479992,
#  277.0061272019992,
#  280.97611916799923,
#  288.20742932999923,
#  290.7348690099992,
#  307.56432582999923,
#  312.60586763599923,
#  322.4500217879992,
#  328.99142335199923,
#  335.40238127599923,
#  331.1361324819992,
#  332.11660376599923,
#  319.3622177859992,
#  311.2317667379991,
#  308.6989209579991,
#  302.2020348139991,
#  304.6796119739991,
#  302.7499862259991,
#  300.5399988079991,
#  290.5236570719991,
#  286.8060690259991,
#  295.146405055999,
#  308.70132366999906,
#  309.57396712599905,
#  311.81218768999906,
#  320.5017106239991,
#  325.59712113399905,
#  332.42282332599905,
#  333.788921927999,
#  335.993399573999,
#  344.450921001999,
#  349.08913735199906,
#  348.69080897599906,
#  360.5075409279991,
#  359.1519771379991,
#  365.53657539799906,
#  376.52653469399905,
#  374.35580016399905,
#  369.42311119799905,
#  368.5730023959991,
#  359.2203543759991,
#  353.70841842599907,
#  344.83751263399904,
#  340.822971103999,
#  344.37026457599904,
#  347.41493380199904,
#  355.68984312799904,
#  363.816746879999,
#  368.940890999999,
#  377.327890531999,
#  383.110523139999,
#  389.003868997999,
#  389.26578048999903,
#  382.85288223799904,
#  386.3079625999991,
#  380.19693721599907,
#  377.82442966199903,
#  373.905306517999,
#  368.30344955399903,
#  363.87609909599905,
#  363.921484691999,
#  359.799662405999,
#  367.931382979999,
#  366.251769193999,
#  372.297533729999,
#  385.939916785999,
#  393.303505445999,
#  391.198137437999,
#  395.02533871599894,
#  403.94918899599895,
#  404.55597432799897,
#  407.22738576999893,
#  399.48376898599895,
#  393.57477972199894,
#  382.0981285719989,
#  378.26854241199896,
#  377.9628357719989,
#  376.5689349199989,
#  383.4655392199989,
#  388.72838734799893,
#  398.2160605999989,
#  406.7030241499989,
#  414.14357746199886,
#  425.1516893559988,
#  427.83492022399884,
#  425.28223303599884,
#  430.71903171199887,
#  435.9304015579989,
#  438.67032682399883,
#  454.46017088999884,
#  449.7106636339988,
#  446.2402980619988,
#  447.87945426199883,
#  439.61323480399886,
#  442.31203816599884,
#  436.2760381259988,
#  431.2807091999988,
#  425.40615924599877,
#  435.4013033379988,
#  441.6382268859988,
#  434.3868427439988,
#  441.5994194159988,
#  451.28650581999875,
#  453.77087049399876,
#  461.20940482399874,
#  466.44180651999875,
#  480.42195439999875,
#  491.20389001199874,
#  490.9796706099987,
#  490.9508307159987,
#  503.7304579299987,
#  498.3367269239987,
#  483.3798983759987,
#  477.9403339519987,
#  470.1419085159987,
#  461.7469082879986,
#  455.52103758599856,
#  446.1930777159985,
#  449.0398899279985,
#  455.3512627459985,
#  457.5904188699985,
#  461.7504987759985,
#  466.91209359399846,
#  480.98335578799845,
#  500.49181668599846,
#  502.0023265179985,
#  510.32573949399847,
#  514.7510543919984,
#  515.5606118099984,
#  512.5392041139984,
#  503.1980522339984,
#  487.66017406199836,
#  485.6399704499983,
#  482.5707142599983,
#  480.33963886599827,
#  475.4417884079983,
#  476.5982658319983,
#  479.39678373199826,
#  481.4561568219982,
#  497.7461413079982,
#  512.5642031699981,
#  534.9380483119982,
#  548.7939356719982,
#  563.2628845959981,
#  575.3364747739981,
#  576.2042494679981,
#  578.6717336399981,
#  569.0063814579981,
#  560.9150020239981,
#  547.172262737998,
#  536.639679377998,
#  529.3961400599981,
#  513.8227583359981,
#  502.3743441399981,
#  491.8301167439981,
#  499.32097373599805,
#  509.59907675999807,
#  517.0118788599981,
#  527.0312258879981,
#  552.9570148099981,
#  573.8447613899981,
#  585.1277019019981,
#  597.9218581519981,
#  603.4602204099981,
#  604.4299897979981,
#  608.5164570759981,
#  614.1052667819981,
#  600.8420264419981,
#  601.6657991759981,
#  593.6086719439982,
#  586.7003880119981,
#  575.5487130239982,
#  567.9348437259981,
#  555.9024055159981,
#  539.2538546159981,
#  530.048002763998,
#  527.544835189998,
#  525.862998243998,
#  530.4302677379981,
#  539.619628683998,
#  558.5979296999981,
#  577.1243162679981,
#  587.4981799519982,
#  600.9459253359983,
#  616.5050170579983,
#  625.7269420419983,
#  626.3090632059983,
#  623.4923663219982,
#  622.4639606899982,
#  614.6199298459982,
#  611.6243243179981,
#  603.9268999379981,
#  601.0247577539981,
#  591.926452997998,
#  581.103579499998,
#  572.439143715998,
#  565.8071856299979,
#  569.3236884399979,
#  569.0253663319979,
#  579.6269120419979,
#  579.8863825259979,
#  593.6335217319978,
#  608.5035851939979,
#  622.8944401459979,
#  632.581636457998,
#  632.5702192079981,
#  636.321495867998,
#  640.761902459998,
#  637.7214923339981,
#  642.765758985998,
#  640.966433279998,
#  643.090367899998,
#  648.3271265279981,
#  649.8791309799981,
#  646.8222513699981,
#  641.364291861998,
#  635.664975739998,
#  629.3893108759979,
#  636.533594405998,
#  635.275369549998,
#  644.821336643998,
#  647.550709751998,
#  650.596230013998,
#  650.085666189998,
#  648.1647236379981,
#  646.9089139239982,
#  652.2044549519981,
#  651.731394489998,
#  655.3244882439981,
#  659.078672723998,
#  652.595451443998,
#  647.1072965299979,
#  648.807920479998,
#  649.372197455998,
#  649.752678807998,
#  661.102292623998,
#  665.615305109998,
#  668.183671591998,
#  671.273182401998,
#  678.566717501998,
#  677.209754903998,
#  671.767889527998,
#  673.987936021998,
#  677.458561455998,
#  666.777128347998,
#  668.393874607998,
#  672.7714585099981,
#  665.978091043998,
#  667.2506561139979,
#  674.698527737998,
#  681.990731535998,
#  691.801624573998,
#  699.3166463339979,
#  698.9724315639979,
#  698.238953025998,
#  700.218044091998,
#  688.956144081998,
#  687.450115029998,
#  673.8010994339979,
#  670.442658751998,
#  663.985430465998,
#  666.290758963998,
#  661.3186417059981,
#  678.8593440499981,
#  687.130517739998,
#  694.638041149998,
#  709.462399759998,
#  725.475763217998,
#  738.4725652419979,
#  756.240260525998,
#  772.4432187539979,
#  772.3764438399979,
#  765.7978247979979,
#  757.6651261399979,
#  748.0520496259979,
#  729.7060133399979,
#  713.1847215939979,
#  703.3274772859979,
#  700.5273834039979,
#  697.2379957099979,
#  697.096837903998,
#  709.3175135999979,
#  721.741210343998,
#  731.229520579998,
#  737.9704844979981,
#  747.0961732599981,
#  760.9346327779981,
#  758.842615427998,
#  752.4007723939981,
#  747.150388987998,
#  744.275259447998,
#  748.306207423998,
#  746.395987945998,
#  744.309921709998,
#  734.424652157998,
#  727.7310882459981,
#  742.164863181998,
#  745.193312195998,
#  754.012145721998,
#  759.863744875998,
#  768.434047401998,
#  771.432237885998,
#  772.271623625998,
#  780.624619893998,
#  785.382450165998,
#  781.969805805998,
#  781.041722621998,
#  777.4534853719981,
#  766.4482194239981,
#  766.8618127599982,
#  776.0115104979982,
#  778.2597026419982,
#  788.5675815139981,
#  789.3045437779981,
#  791.0027061979981,
#  786.3033925599981,
#  790.409787517998,
#  789.018986431998,
#  789.407632969998,
#  789.3896163319979,
#  787.843114127998,
#  784.8323297439979,
#  779.6157512119979,
#  781.970981261998,
#  772.972494901998,
#  782.7222288819979,
#  791.5738987739978,
#  802.7868135379979,
#  801.1373689339978,
#  800.8826548739978,
#  812.0140444859977,
#  816.6366975499977,
#  814.1822839239977,
#  820.8655796959977,
#  817.5058452719976,
#  810.4591182939977,
#  812.4929396899977,
#  819.5879089819977,
#  822.7044313059977,
#  834.5330908239977,
#  837.6167211079977,
#  836.1605151359977,
#  835.0759801939977,
#  833.2633446859977,
#  826.8987922099977,
#  817.6787538339977,
#  813.5972899879978,
#  814.1810787719977,
#  813.2218959679977,
#  813.5154610199977,
#  820.5466294799977,
#  830.7229678399978,
#  841.5782902039978,
#  849.6686594639978,
#  857.4863681399977,
#  864.1708138819977,
#  868.2586506939978,
#  876.3421155999978,
#  872.6345109719978,
#  870.4339553319977,
#  877.7827739779977,
#  876.8561262739978,
#  873.4961708039979,
#  862.4242361139978,
#  855.7467458459979,
#  847.013169079998,
#  843.0370820659979,
#  836.4378952919978,
#  836.6949395759979,
#  838.4864921899979,
#  843.4152904199979,
#  855.5330736119978,
#  868.8376761499978,
#  885.9296485639978,
#  892.3765294439978,
#  899.0787257259979,
#  895.6568552479979,
#  902.8844390979979,
#  895.529788229998,
#  887.459451801998,
#  883.7959088699979,
#  888.3347155419979,
#  883.6603959339978,
#  891.8014618839978,
#  898.1982703739977,
#  891.4368640699977,
#  892.2768255559977,
#  892.4621657719977,
#  892.3803721019976,
#  898.2104863899976,
#  898.9242260539976,
#  905.4544496039975,
#  908.2639165259976,
#  910.0513362179977,
#  916.9247321859978,
#  909.3510456739978,
#  911.6085286899978,
#  905.3470123539978,
#  899.5876127499978,
#  911.9976700039978,
#  903.4012010699978,
#  900.0955043619978,
#  902.1728049939977,
#  901.7695342999978,
#  903.9718231719977,
#  918.3799041939977,
#  926.4090231259977,
#  921.1338908359977,
#  927.4315051139977,
#  927.6281739399977,
#  940.3978396879977,
#  953.2563477319977,
#  950.9163084859978,
#  942.6181818899977,
#  936.8367686779977,
#  936.9868337099977,
#  936.7788416639977,
#  931.6723253099977,
#  932.8484505419976,
#  936.1939116599976,
#  938.7798438259977,
#  943.2963667859976,
#  946.2802196239977,
#  949.3713807339977,
#  956.7371186959978,
#  972.0411890759979,
#  976.2213741559979,
#  974.0050625439978,
#  979.6659370999978,
#  972.7151365539978,
#  969.5434317859979,
#  959.7956754499978,
#  955.2801036479979,
#  951.6772152299978,
#  947.4025408339978,
#  946.9212281839978,
#  944.4513363959977,
#  949.6702162179978,
#  955.8789853879978,
#  961.8749983999978,
#  963.1313956579978,
#  966.9683236999979,
#  973.4803124999978,
#  971.1797766899979,
#  969.376262761998,
#  976.582334887998,
#  977.329725369998,
#  975.977987191998,
#  970.650557161998,
#  972.8722549039979,
#  979.252252107998,
#  982.9775844439979,
#  986.8462631739978,
#  990.3762521979978,
#  994.3954984199978,
#  1004.5033855979977,
#  1022.0710354379978,
#  1026.4094416599978,
#  1032.2709952819978,
#  1042.9254189859978,
#  1059.0956598679977,
#  1053.6836767979976,
#  1048.9516164659976,
#  1033.9340103879977,
#  1027.0904549759975,
#  1017.2899116019976,
#  1000.8527135479976,
#  998.1324172959976,
#  982.6063450999976,
#  971.6886042439977,
#  964.6518973239977,
#  964.8362289859976,
#  961.6371009619977,
#  966.2732754159977,
#  979.0127701299976,
#  994.2420048439977,
#  1015.4765933939977,
#  1033.7868930039979,
#  1045.026013717998,
#  1048.091466291998,
#  1055.7286503959979,
#  1050.7645057159978,
#  1059.3940487799978,
#  1063.2869471779977,
#  1060.9334365079978,
#  1058.5605149179978,
#  1049.617504779998,
#  1048.925794395998,
#  1039.373968857998,
#  1037.568246349998,
#  1047.3933354599978,
#  1049.0604899739978,
#  1051.9634108579978,
#  1062.3657343559978,
#  1059.9498207779977,
#  1067.3438544679977,
#  1068.4758069159977,
#  1064.3431519779976,
#  1061.1783632219976,
#  1049.8000477879978,
#  1045.1870085959977,
#  1049.1011394479976,
#  1052.2494624879976,
#  1054.0228667919976,
#  1063.6943024019974,
#  1072.8661538439974,
#  1081.7774522219975,
#  1097.6117573619974,
#  1115.5764747419976,
#  1128.0101452819977,
#  1133.8088838779977,
#  1131.7597910379977,
#  1131.3015750359978,
#  1115.6545096159978,
#  1100.3283695179975,
#  1087.1314308399976,
#  1070.5041329479975,
#  1062.6781879419975,
#  1050.9622123899976,
#  1042.4896758399977,
#  1034.4207004339978,
#  1041.6004491039978,
#  1052.4502356639978,
#  1065.7113397679977,
#  1082.3249344239978,
#  1097.880300543998,
#  1119.781940909998,
#  1135.927825081998,
#  1147.573007741998,
#  1159.627781035998,
#  1169.638836787998,
#  1169.1457835299977,
#  1168.2272556819978,
#  1163.982618349998,
#  1163.6185669739978,
#  1148.5513520219977,
#  1140.7120270159976,
#  1133.6348414679976,
#  1126.7186255799977,
#  1118.3476908119978,
#  1108.256030521998,
#  1109.054860939998,
#  1123.7321294539981,
#  1112.3196073299982,
#  1113.1805360479982,
#  1117.7776416139984,
#  1126.5880018559985,
#  1133.5160373299984,
#  1132.8015356579983,
#  1134.5891078299983,
#  1138.3355501679982,
#  1144.6111813819982,
#  1146.3280367339983,
#  1149.6327073159982,
#  1151.7748193339983,
#  1146.7484489039982,
#  1148.3364286399983,
#  1156.4870907759985,
#  1154.6448672939987,
#  1163.8930948599987,
#  1175.2290239299987,
#  1180.8064920279985,
#  1184.0474904419984,
#  1183.7345314519985,
#  1174.1049868639984,
#  1174.7284358599984,
#  1175.5335099619983,
#  1176.1797036619982,
#  1183.217164237998,
#  1191.3573906159982,
#  1200.8012132319982,
#  1198.3767813679983,
#  1196.2890600839983,
#  1198.8289709799983,
#  1190.2171476339984,
#  1195.8590002879982,
#  1197.944258349998,
#  1191.4526208819982,
#  1195.3656968299981,
#  1196.4282981159981,
#  1200.759288175998,
#  1201.6593822999982,
#  1204.4414320479982,
#  1206.0509974959982,
#  1213.9440459599982,
#  1206.7799332919983,
#  1196.7451352219982,
#  1194.5288945359982,
#  1196.9463452039981,
#  1196.065953829998,
#  1196.2259544559981,
#  1200.538507311998,
#  1199.783798573998,
#  1214.4999380379982,
#  1230.5282982699982,
#  1243.1530765339983,
#  1249.0856666999982,
#  1251.2292637159983,
#  1261.0228795459984,
#  1248.2545157599984,
#  1251.2840091159985,
#  1250.2762259859987,
#  1240.4590393019987,
#  1238.0146827759986,
#  1239.1463431939985,
#  1249.8610841099985,
#  1257.5087738159987,
#  1268.4091718739987,
#  1268.8012631439988,
#  1272.6375227979988,
#  1264.4398949279987,
#  1266.6495474899987,
#  1262.2503338759986,
#  1254.2551215779986,
#  1255.4463478899986,
#  1251.7214945459984,
#  1256.6947880259984,
#  1260.5161916419984,
#  1263.1809362479983,
#  1264.8205099019983,
#  1249.9294001159985,
#  1242.9714876579985,
#  1227.5109386399984,
#  1229.9357135379985,
#  1230.9630200399986,
#  1236.3837172359986,
#  1241.1004231659986,
#  1251.7714090059985,
#  1265.4951668839985,
#  1280.4202310579985,
#  1299.3871721319986,
#  1312.7712146659987,
#  1322.1937679159987,
#  1328.3160665839987,
#  1326.5238177119988,
#  1323.3715908359989,
#  1323.3464798859989,
#  1318.8909710759988,
#  1304.7608131899988,
#  1285.0148934479987,
#  1262.6472825499989,
#  1249.5017295999987,
#  1246.9668873699986,
#  1237.5198986619987,
#  1232.6632963619986,
#  1231.4969662179988,
#  1241.953103129999,
#  1260.2900504179988,
#  1271.2278792879988,
#  1279.9858966799989,
#  1308.9556402359988,
#  1330.8798941299988,
#  1343.9843121199988,
#  1356.9667209539987,
#  1363.5351652359986,
#  1371.5591922559988,
#  1366.4148802099987,
#  1348.5158624959986,
#  1324.0362517979986,
#  1305.1445480959987,
#  1293.7007997179987,
#  1284.5778178439987,
#  1270.5023206779986,
#  1267.5581074199986,
#  1266.6137553699984,
#  1271.7408737059984,
#  1287.8678182219985,
#  1307.0726728759987,
#  1323.2206467119986,
#  1326.9463495639986,
#  1339.4660342299985,
#  1359.8120597599984,
#  1378.4169624759984,
#  1385.8011688479985,
#  1394.2503534139985,
#  1397.3720435979985,
#  1400.4807754699984,
#  1395.4404143879983,
#  1382.3716184579982,
#  1374.801520309998,
#  1350.061505973998,
#  1334.157244863998,
#  1324.904175121998,
#  1328.446686177998,
#  1329.1180572639978,
#  1332.1823304799977,
#  1330.1453544139977,
#  1327.3882357199977,
#  1333.6940510339978,
#  1346.3995264739979,
#  1363.8096381459977,
#  1375.2727136819976,
#  1390.4325794779977,
#  1394.1150685619978,
#  1401.9033338919978,
#  1392.8358338699977,
#  1393.7101485899977,
#  1389.9461077899978,
#  1373.8728202199977,
#  1370.8768876359977,
#  1365.4994443719977,
#  1359.2691186779978,
#  1354.5045437979977,
#  1359.5722484459975,
#  1358.0304098239976,
#  1358.9165587939976,
#  1371.6829522399978,
#  1377.3070118439978,
#  1386.0852411619978,
#  1399.6956801339977,
#  1422.8324052839976,
#  1430.8956276159975,
#  1439.0276641159974,
#  1446.8191621619974,
#  1449.9772893599975,
#  1440.1131993539975,
#  1428.3241605319974,
#  1415.1468966979974,
#  1406.8442358159973,
#  1391.3037184719974,
#  1379.2665103739973,
#  1373.6200665159975,
#  1365.3281971399974,
#  1366.5911080779974,
#  1374.1407204279974,
#  1372.4696336619975,
#  1386.5714280819975,
#  1408.4829753519975,
#  1426.1468669779977,
#  1443.6949576939976,
#  1458.8712884539977,
#  1481.8118545919979,
#  1490.7381447159978,
#  1491.7276648059978,
#  1492.7785974719977,
#  1482.6217553859976,
#  1472.1308898139976,
#  1460.9264358959974,
#  1448.2836734519974,
#  1436.3797702079974,
#  1427.7900817279974,
#  1413.9049796959976,
#  1404.4644647499977,
#  1403.9061138919976,
#  1404.3272302919977,
#  1418.1863689839977,
#  1421.5027988339978,
#  1434.4602680379978,
#  1434.5703391579978,
#  1453.3608786919976,
#  1468.6502363659974,
#  1477.7787362859974,
#  1484.8340944179972,
#  1492.210415413997,
#  1503.0288041919969,
#  1505.788492367997,
#  1502.555212463997,
#  1496.8954489199969,
#  1490.875976821997,
#  1485.352902665997,
#  1480.377048267997,
#  1471.2539486439969,
#  1459.270707347997,
#  1456.153645563997,
#  1461.3710137599971,
#  1457.1469828799973,
#  1460.8271923099971,
#  1470.7791557999972,
#  1472.6674943299972,
#  1483.6864567579971,
#  1497.254865357997,
#  1524.3617886519971,
#  1535.3635736019971,
#  1546.129777915997,
#  1543.547658705997,
#  1537.533465253997,
#  1544.148637341997,
#  1549.452769893997,
#  1545.119409343997,
#  1531.4314770279968,
#  1524.095367153997,
#  1514.6993647339968,
#  1505.1125022959968,
#  1497.8864610419969,
#  1490.799552489997,
#  1488.377448469997,
#  1496.0574531759971,
#  1506.918096287997,
#  1522.0250781939972,
#  1536.962731503997,
#  1546.927239443997,
#  1564.8660414639971,
#  1576.2769908899973,
#  1583.2570994479972,
#  1596.1894011859972,
#  1594.4420938759972,
#  1587.2935525339972,
#  1573.6581374099972,
#  1572.765143861997,
#  1571.9137477719971,
#  1558.020454341997,
#  1554.274008619997]

# %%
#绘图 accumulative_constraint_violation和accumulative_constraint_violation_T

# %%
sub1=plt.subplot(1, 2, 1)##############################################################
iteration=[]
for i in range(0,999):
    iteration.append(i)

#在同一幅图片上画3条折线
A,=plt.plot(iteration,accumulative_constraint_violation,color = 'green',linewidth = '1.5',label='attack-free online primal-dual algorithm')


#设置图例并且设置图例的字体及大小
font1 = {
'size'   : 18,
}
#legend = plt.legend(handles=[A],prop=font1)
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=18)
 
#设置横纵坐标的名称以及对应字体格式
font2 = {
'size'   : 18,
}
plt.xlabel('T',font2)
plt.ylabel(r'Constraint violation $Fit(T)$',font2)
plt.title('varying $D_{t}$',font2) 

sub2=plt.subplot(1, 2, 2)##############################################################
iteration=[]
for i in range(0,999):
    iteration.append(i)

#在同一幅图片上画3条折线
A,=plt.plot(iteration,accumulative_constraint_violation_T,color = 'green',linewidth = '1.5',label='attack-free online primal-dual algorithm')


#设置图例并且设置图例的字体及大小
font1 = {
'size'   : 18,
}
#legend = plt.legend(handles=[A],prop=font1)
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=18)
 
#设置横纵坐标的名称以及对应字体格式
font2 = {
'size'   : 18,
}
plt.xlabel('T',font2)
plt.ylabel(r'Constraint violation $Fit(T)/T$',font2)
plt.title('varying $D_{t}$',font2) 

plt.legend(handles=[A],prop={'size':18},loc="upper center", bbox_to_anchor=[-0.3, -0.2],
           ncol=18, shadow=True, fancybox=True)

plt.subplots_adjust(wspace=0.5,hspace=0.5) 
plt.gcf().set_size_inches((15, 5))


#plt.savefig('./figures/01-figure2_constraint_violation_attack_free_varying_D.pdf',format='pdf', bbox_inches='tight')
#plt.savefig('./figures/01-figure2_constraint_violation_attack_free_varying_D.png',format='png', bbox_inches='tight')
