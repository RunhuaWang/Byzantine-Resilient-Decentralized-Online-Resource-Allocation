# %% [raw]
# 大值攻击 large-value Byzantine attacks观察SCC+decentralized online economic dispatch algorithm在拜占庭攻击下的算法性能
# 实验设置：4个热能发电站 2个风能发电站
# 时变风速服从的Weibull distribution的参数c和kappa
# 时变的需求侧用电需求D
# c的变化：[3,25]间的均匀分布
# kappa的变化：[2，3]间的均匀分布
# D的变化为：均值为70 标准差为5的高斯分布
# 拜占庭攻击：假设一个风力发电站受到拜占庭攻击 向其他发电站发送恶意的对偶变量
# 小值攻击 small-value Byzantine attacks
#
# 加上一个adaptive clipping

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
from sympy import *
import math 
from datetime import datetime
from scipy.special import gamma, factorial
import scipy.special as sc

# %%
#定义变量 
thermal_power_station_strategy=np.zeros(shape=(4,1000)) 
wind_power_station_strategy=np.zeros(shape=(2,1000))
c_wind_speed= np.loadtxt("./data/c_wind_speed_uniform_distribution_(3,25).txt")      
kappa_wind_speed= np.loadtxt("./data/kappa_wind_speed_uniform_distribution_(2,3).txt")  
d_power_demand=np.loadtxt("./data/d_power_demand_normal_distribution_(70,5).txt") #时变的需求侧用电需求  阶梯式变化 
thermal_power_station_dual_variable=np.zeros(shape=(4,1000))
wind_power_station_dual_variable=np.zeros(shape=(2,1000))#两个风力发电站中有一个是受到拜占庭攻击的 假设第二个风力发电站是受到攻击的
E=np.loadtxt("6_Network_Topology_Double_Random_Adjacency_Matrix.txt")
thermal_power_station_cost=np.zeros(shape=(1,1000)) #火力发电成本
wind_power_station_cost=np.zeros(shape=(1,1000)) #风力发电成本
sum_cost=np.zeros(shape=(1,1000)) #总发电成本
#thermal_power_station_eta=[0.0375,0.0375,0.0625,0.035]
thermal_power_station_eta=[0.0675,0.0675,0.0925,0.0625]
thermal_power_station_zeta=[2,1.75,1,3]
thermal_power_station_xi=[0,0,0,0]
thermal_power_station_P_min=[50,20,15,10]
thermal_power_station_P_max=[200,120,80,100]
#wind_power_station_varphi=[3,6]
wind_power_station_varphi=[1,6]
wind_power_station_v_in=[3,5]
wind_power_station_v_out=[25,25]
wind_power_station_v_r=[13,15]
wind_power_station_sigma_ue=[5,5]
wind_power_station_sigma_oe=[30,20]
wind_power_station_P_r=[160,160]
wind_power_station_P_min=[0,0]
wind_power_station_P_max=[160,160]
sum_thermal_wind_power_station_strategy=np.zeros(shape=(1,1000))
step_size_primal=1
step_size_dual=3
tau_robust1=np.zeros(shape=(6,1000))#每个用户在每次迭代中均需要计算出一个tau值
regularization_parameter=0.001

# %%
#火力，风力发电策略初始化
thermal_power_station_strategy[0][0]=70
thermal_power_station_strategy[1][0]=70
thermal_power_station_strategy[2][0]=70
thermal_power_station_strategy[3][0]=70
wind_power_station_strategy[0][0]=70
wind_power_station_strategy[1][0]=0
#初始总发电策略
sum_thermal_wind_power_station_strategy[0][0]=350
#初始化受到攻击的风力发电站的对偶变量
wind_power_station_dual_variable[1][0]=-300

thermal_power_station_dual_variable[0][0]=-70
thermal_power_station_dual_variable[1][0]=-70
thermal_power_station_dual_variable[2][0]=-70
thermal_power_station_dual_variable[3][0]=-70
wind_power_station_dual_variable[0][0]=-70

#安全发电站的初始总发电成本
#火力发电成本
for i in range(0,4):
    thermal_power_station_cost[0][0]=thermal_power_station_cost[0][0]+thermal_power_station_eta[i]*thermal_power_station_strategy[i][0]*thermal_power_station_strategy[i][0]+thermal_power_station_zeta[i]*thermal_power_station_strategy[i][0]
#风力发电成本
for i in range(0,1):
    wind_power_station_cost[0][0]=wind_power_station_cost[0][0]+wind_power_station_varphi[i]*wind_power_station_strategy[i][0]+wind_power_station_sigma_ue[i]*((wind_power_station_P_r[i]-wind_power_station_strategy[i][0])*(math.exp(-(math.pow(wind_power_station_v_r[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0])))-math.exp(-(math.pow(wind_power_station_v_out[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0]))))+(wind_power_station_P_r[i]*wind_power_station_v_in[i]/(wind_power_station_v_r[i]-wind_power_station_v_in[i])+wind_power_station_strategy[i][0])*(math.exp(-(math.pow(wind_power_station_v_r[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0])))-math.exp(-(math.pow(wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][0])/wind_power_station_P_r[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0]))))+(wind_power_station_P_r[i]*c_wind_speed[0]/(wind_power_station_v_r[i]-wind_power_station_v_in[i]))*(sc.gammaincc(1+1/kappa_wind_speed[0],(math.pow(wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][0])/wind_power_station_P_r[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0])))*sc.gamma(1+1/kappa_wind_speed[0])-sc.gammaincc(1+1/kappa_wind_speed[0],math.pow(wind_power_station_v_r[i]/c_wind_speed[0],kappa_wind_speed[0]))*sc.gamma(1+1/kappa_wind_speed[0])))+wind_power_station_sigma_oe[i]*((wind_power_station_strategy[i][0])*(1-math.exp(-(math.pow(wind_power_station_v_in[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0])))+math.exp(-(math.pow(wind_power_station_v_out[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0]))))+(wind_power_station_P_r[i]*wind_power_station_v_in[i]/(wind_power_station_v_r[i]-wind_power_station_v_in[i])+wind_power_station_strategy[i][0])*(math.exp(-(math.pow(wind_power_station_v_in[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0])))-math.exp(-(math.pow(wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][0])/wind_power_station_P_r[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0]))))+(wind_power_station_P_r[i]*c_wind_speed[0]/(wind_power_station_v_r[i]-wind_power_station_v_in[i]))*(sc.gammaincc(1+1/kappa_wind_speed[0],(math.pow(wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][0])/wind_power_station_P_r[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0])))*sc.gamma(1+1/kappa_wind_speed[0])-sc.gammaincc(1+1/kappa_wind_speed[0],math.pow(wind_power_station_v_in[i]/c_wind_speed[0],kappa_wind_speed[0]))*sc.gamma(1+1/kappa_wind_speed[0])))
#发电总成本
sum_cost[0][0]=thermal_power_station_cost[0][0]+wind_power_station_cost[0][0]

#计算每个发电站的邻居发电站
neighbor_robust1_help=[]
for i in range (0,6):
    for j in range (0,6):
        if E[i][j]!=0:
            neighbor_robust1_help.append(j)
        elif E[i][j]==0:
            neighbor_robust1_help.append(99)
neighbor_robust1=np.array(neighbor_robust1_help).reshape(6,6)

#计算安全的发电站的拜占庭邻居用户数量
q_robust1=[]
for i in range(0,6):
    q_robust1_help=0
    for j in range(0,6):
        if neighbor_robust1[i][j]==5:
            q_robust1_help=q_robust1_help+1
    q_robust1.append(q_robust1_help)
    
#计算出5个诚实用户的邻居中有多少是诚实用户 有多少是拜占庭用户
neighbor_honest_num_robust1=[]
neighbor_byzantine_num_robust1=[]
for i in range(0,6):
    h_num_robust1=0
    b_num_robust1=0
    u_neighbor_help_robust1=neighbor_robust1[i].tolist()#将用户i的邻居序号存在辅助变量u中
    if i==0 or i==3 or i==4 or i==5:
        u_neighbor_help_robust1 = list(set(u_neighbor_help_robust1))
        u_neighbor_help_robust1.remove(99)
    u_neighbor_help_robust1.remove(i)
    for j in range(0,len(u_neighbor_help_robust1)):
        if u_neighbor_help_robust1[j]==5:
            b_num_robust1=b_num_robust1+1
        else:
            h_num_robust1=h_num_robust1+1
    neighbor_honest_num_robust1.append(h_num_robust1)
    neighbor_byzantine_num_robust1.append(b_num_robust1)

# %%
def SCC_Byzantine_attack_decentralized_economic_dispatch(thermal_power_station_strategy,wind_power_station_strategy,c_wind_speed,kappa_wind_speed,d_power_demand,thermal_power_station_dual_variable,wind_power_station_dual_variable,E,thermal_power_station_cost,wind_power_station_cost,thermal_power_station_eta,thermal_power_station_zeta,thermal_power_station_P_min,thermal_power_station_P_max,wind_power_station_varphi,wind_power_station_sigma_ue,wind_power_station_sigma_oe,wind_power_station_P_min,wind_power_station_P_max,sum_thermal_wind_power_station_strategy,step_size_primal,step_size_dual):
    #显示初始化的数据
    #输出初始状态的原变量和对偶变量
    print("***************************attack_free_online_decentralized_economic_dispatch*****************************")
    print("相关变量初始值为：")
    for i in range (0,4):
        print("第",(i+1),"个火力发电站的初始计划发电量为:",thermal_power_station_strategy[i][0])
    for i in range (0,2):
        print("第",(i+5),"个风力发电站的初始计划发电量为:",wind_power_station_strategy[i][0])
    print("****************************************************************************")
    for i in range (0,4):
        print("第",(i+1),"个火力发电站的初始对偶变量为:",thermal_power_station_dual_variable[i][0])
    for i in range (0,1):
        print("第",(i+5),"个风力发电站的初始对偶变量为:",wind_power_station_dual_variable[i][0])
    print("****************************************************************************")
    print("第",(6),"个受到Byzantin攻击的风力发电站的初始对偶变量为:",wind_power_station_dual_variable[1][0])
    print("****************************************************************************")
    print("安全发电站的初始总发电量:",sum_thermal_wind_power_station_strategy[0][0])
    print("*************************")
    print("需求侧用电需求:",d_power_demand[0])
    print("****************************************************************************")
    print("风速分布参数c:",c_wind_speed[0])
    print("****************************************************************************")
    print("风速分布参数kappa:",kappa_wind_speed[0])
    print("****************************************************************************")
    print("安全发电站的总发电成本：", sum_cost[0][0])
    print("****************************************************************************")
    print("原变量迭代步长为:",step_size_primal)
    print("*****************************************************************************")
    print("对偶变量迭代步长为:",step_size_dual)
    print("*****************************************************************************")
    
    #开始迭代
    for k in range(1,1000):
        #发电站更新计划发电量和对偶变量
        #对偶变量 先做梯度上升 再做聚合
        #安全发电站的梯度上升
        dual_variable_intermediate=[] #存放当前迭代中6个用户对对偶变量做完梯度下降后得到的中间值
        for i in range(0,4):
            dual_variable_intermediate.append(thermal_power_station_dual_variable[i][k-1]+step_size_dual*((1/6)*thermal_power_station_strategy[i][k-1]-(1/6)*d_power_demand[k-1]-regularization_parameter*thermal_power_station_dual_variable[i][k-1]))
        for j in range(0,1):
            dual_variable_intermediate.append(wind_power_station_dual_variable[j][k-1]+step_size_dual*((1/6)*wind_power_station_strategy[j][k-1]-(1/6)*d_power_demand[k-1]-regularization_parameter*wind_power_station_dual_variable[j][k-1]))
        #受到攻击的风力发电站的对偶值
        dual_variable_intermediate.append(wind_power_station_dual_variable[1][k-1])
        
        #SCC鲁棒聚合+adaptive clipping 安全的火力发电站的对偶更新
        #在做鲁棒聚合前 对收集到的信息进行adaptive clipping的剪裁操作
        for i in range (0,4):
            u_neighbor_help_robust1=neighbor_robust1[i].tolist()#将用户i的邻居序号存在辅助变量u中
            if i==0 or i==3:
                u_neighbor_help_robust1 = list(set(u_neighbor_help_robust1))
                u_neighbor_help_robust1.remove(99)
            if int(q_robust1[i])==1: #只有具有拜占庭邻居的用户才需要先进行adaptive clipping和后续的SCC聚合操作    
                #先进行adaptive clipping
                dual_variable_intermediate_auxiliary=[]
                #注意必须以这样的方式赋值 不能直接写dual_variable_intermediate_auxiliary=dual_variable_intermediate
                #不然在修改变量dual_variable_intermediate_auxiliary的同时也会对dual_variable_intermediate进行修改
                for j in range(len(dual_variable_intermediate)): 
                    dual_variable_intermediate_auxiliary.append(dual_variable_intermediate[j])
                dual_variable_receive=[]
                clipping_C=0
                for j in range(0, len(u_neighbor_help_robust1)):
                    dual_variable_receive.append(dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[j]])
                dual_variable_receive.sort()
                clipping_C= -dual_variable_receive[1] #确定clpping的阈值
                #接下来对大于clipping_C的值进行clipping
                for j in range(0, len(u_neighbor_help_robust1)):
                    if -dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[j]]>clipping_C:
                        dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[j]]=-clipping_C
                c_clipping_dual_robust1=[]#存放当前诚实用户对邻居的对偶变量裁剪后的值
                mix_sum_c_dual_robust1=0#存放clipping后的对偶值和  
                u_neighbor_help_robust1.remove(i)
                weight_sum_robust1=0
                for j in range(0,len(u_neighbor_help_robust1)):
                    if u_neighbor_help_robust1[j]!=5:
                        weight_sum_robust1=weight_sum_robust1+E[i][u_neighbor_help_robust1[j]]*(dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[j]]-dual_variable_intermediate_auxiliary[i])*(dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[j]]-dual_variable_intermediate_auxiliary[i])
                tau_robust1[i][k]=sqrt(weight_sum_robust1/(E[i][5])) 
                #每个诚实用户首先对邻居传来的对偶变量进行剪裁clipping
                for j in range (0, len(u_neighbor_help_robust1)): #问题：分母会出现0的情况
                    if (dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[j]]-dual_variable_intermediate_auxiliary[i])==0:
                        c_clipping_dual_robust1.append(0)
                    elif 1<=(tau_robust1[i][k]/(abs((dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[j]]-dual_variable_intermediate_auxiliary[i])))):
                        c_clipping_dual_robust1.append(dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[j]]-dual_variable_intermediate_auxiliary[i])
                    else:
                        c_clipping_dual_robust1.append((dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[j]]-dual_variable_intermediate_auxiliary[i])*((tau_robust1[i][k]/(abs((dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[j]]-dual_variable_intermediate_auxiliary[i]))))))
                #诚实用户聚合clipping后的邻居对偶值和自身的对偶值 
                for j in range(0,len(u_neighbor_help_robust1)):
                    mix_sum_c_dual_robust1=mix_sum_c_dual_robust1+E[i][u_neighbor_help_robust1[j]]*(dual_variable_intermediate_auxiliary[i]+c_clipping_dual_robust1[j])            
                #诚实用户基于SCC鲁棒聚合后的值进行自身的对偶变量的更新
                thermal_power_station_dual_variable[i][k]=E[i][i]*dual_variable_intermediate_auxiliary[i]+mix_sum_c_dual_robust1
            else:  #没有拜占庭邻居的用户直接进行权重聚合即可
                for j in range(0,len(u_neighbor_help_robust1)):
                     thermal_power_station_dual_variable[i][k]=thermal_power_station_dual_variable[i][k]+E[i][u_neighbor_help_robust1[j]]*dual_variable_intermediate[u_neighbor_help_robust1[j]]
        
        #聚合 安全的风力发电站的对偶更新 由于其邻居中没有拜占庭用户 所以直接按权重聚合即可
        for j in range(0,6):
            wind_power_station_dual_variable[0][k]=wind_power_station_dual_variable[0][k]+E[4][j]*dual_variable_intermediate[j]          

        #受到Byzantine攻击的风力发电站的对偶更新
        wind_power_station_dual_variable[1][k]=wind_power_station_dual_variable[1][k-1]            
        
        #安全的火力发电站计划发电量
        for i in range(0,4):
            thermal_power_station_strategy[i][k]=thermal_power_station_strategy[i][k-1]-step_size_primal*(2*thermal_power_station_eta[i]*thermal_power_station_strategy[i][k-1]+thermal_power_station_zeta[i]+(1/6)*thermal_power_station_dual_variable[i][k-1]) 
            if thermal_power_station_strategy[i][k]<=thermal_power_station_P_min[i]:
                thermal_power_station_strategy[i][k]=thermal_power_station_P_min[i]
            elif thermal_power_station_strategy[i][k]>=thermal_power_station_P_max[i]:
                thermal_power_station_strategy[i][k]=thermal_power_station_P_max[i]
        #安全的风力发电站计划发电量
        for i in range(0,1):
            wind_power_station_strategy[i][k]=wind_power_station_strategy[i][k-1]-step_size_primal*(wind_power_station_varphi[i]+wind_power_station_sigma_oe[i]+(wind_power_station_sigma_ue[i]+wind_power_station_sigma_oe[i])*math.exp(-(math.pow(wind_power_station_v_out[i],kappa_wind_speed[k-1]))/(math.pow(c_wind_speed[k-1],kappa_wind_speed[k-1])))+(-wind_power_station_sigma_ue[i]-wind_power_station_sigma_oe[i])*math.exp(-(math.pow((wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][k-1])/wind_power_station_P_r[i]),kappa_wind_speed[k-1]))/(math.pow(c_wind_speed[k-1],kappa_wind_speed[k-1])))+(1/6)*wind_power_station_dual_variable[i][k-1])
            if wind_power_station_strategy[i][k]<=wind_power_station_P_min[i]:
                wind_power_station_strategy[i][k]=wind_power_station_P_min[i]
            elif wind_power_station_strategy[i][k]>=wind_power_station_P_max[i]:
                wind_power_station_strategy[i][k]=wind_power_station_P_max[i]
        #受到Byzantine攻击的风力发电站的计划发电量
        wind_power_station_strategy[1][k]=wind_power_station_strategy[1][k-1]
        
        #安全发电站的计算总计划发电
        #火力发电量
        for i in range(0,4):
            sum_thermal_wind_power_station_strategy[0][k]=sum_thermal_wind_power_station_strategy[0][k]+thermal_power_station_strategy[i][k]
        #风力发电量
        for i in range(0,1):
            sum_thermal_wind_power_station_strategy[0][k]=sum_thermal_wind_power_station_strategy[0][k]+wind_power_station_strategy[i][k]
        
        #安全发电站的计算总发电成本
        #火力发电成本
        for i in range(0,4):
            thermal_power_station_cost[0][k]=thermal_power_station_cost[0][k]+thermal_power_station_eta[i]*thermal_power_station_strategy[i][k]*thermal_power_station_strategy[i][k]+thermal_power_station_zeta[i]*thermal_power_station_strategy[i][k]
        #风力发电成本
        for i in range(0,1):
            wind_power_station_cost[0][k]=wind_power_station_cost[0][k]+wind_power_station_varphi[i]*wind_power_station_strategy[i][k]+wind_power_station_sigma_ue[i]*((wind_power_station_P_r[i]-wind_power_station_strategy[i][k])*(math.exp(-(math.pow(wind_power_station_v_r[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k])))-math.exp(-(math.pow(wind_power_station_v_out[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k]))))+(wind_power_station_P_r[i]*wind_power_station_v_in[i]/(wind_power_station_v_r[i]-wind_power_station_v_in[i])+wind_power_station_strategy[i][k])*(math.exp(-(math.pow(wind_power_station_v_r[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k])))-math.exp(-(math.pow(wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][k])/wind_power_station_P_r[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k]))))+(wind_power_station_P_r[i]*c_wind_speed[k]/(wind_power_station_v_r[i]-wind_power_station_v_in[i]))*(sc.gammaincc(1+1/kappa_wind_speed[k],(math.pow(wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][k])/wind_power_station_P_r[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k])))*sc.gamma(1+1/kappa_wind_speed[k])-sc.gammaincc(1+1/kappa_wind_speed[k],math.pow(wind_power_station_v_r[i]/c_wind_speed[k],kappa_wind_speed[k]))*sc.gamma(1+1/kappa_wind_speed[k])))+wind_power_station_sigma_oe[i]*((wind_power_station_strategy[i][k])*(1-math.exp(-(math.pow(wind_power_station_v_in[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k])))+math.exp(-(math.pow(wind_power_station_v_out[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k]))))+(wind_power_station_P_r[i]*wind_power_station_v_in[i]/(wind_power_station_v_r[i]-wind_power_station_v_in[i])+wind_power_station_strategy[i][k])*(math.exp(-(math.pow(wind_power_station_v_in[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k])))-math.exp(-(math.pow(wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][k])/wind_power_station_P_r[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k]))))+(wind_power_station_P_r[i]*c_wind_speed[k]/(wind_power_station_v_r[i]-wind_power_station_v_in[i]))*(sc.gammaincc(1+1/kappa_wind_speed[k],(math.pow(wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][k])/wind_power_station_P_r[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k])))*sc.gamma(1+1/kappa_wind_speed[k])-sc.gammaincc(1+1/kappa_wind_speed[k],math.pow(wind_power_station_v_in[i]/c_wind_speed[k],kappa_wind_speed[k]))*sc.gamma(1+1/kappa_wind_speed[k])))
        #发电总成本
        sum_cost[0][k]=thermal_power_station_cost[0][k]+wind_power_station_cost[0][k]
        
        #输出第k次迭代中的结果 每间隔10次迭代输出一次结果
        #if (k+1)%10==0:
        print(k,"次迭代中的结果：")
        for i in range (0,4):
            print("第",(i+1),"个火力发电站的计划发电量为:",thermal_power_station_strategy[i][k])
        for i in range (0,2):
            print("第",(i+5),"个风力发电站的计划发电量为:",wind_power_station_strategy[i][k])
        print("****************************************************************************")
        for i in range (0,4):
            print("第",(i+1),"个火力发电站的对偶变量为:",thermal_power_station_dual_variable[i][k])
        for i in range (0,1):
            print("第",(i+5),"个风力发电站的对偶变量为:",wind_power_station_dual_variable[i][k])
        print("****************************************************************************")
        print("第",(6),"个受到Byzantin攻击的风力发电站的初始对偶变量为:",wind_power_station_dual_variable[1][k])
        print("****************************************************************************")
        print("安全发电站的总发电量:",sum_thermal_wind_power_station_strategy[0][k])
        print("*************************")
        print("需求侧用电需求:",d_power_demand[k])
        print("****************************************************************************")
        print("风速分布参数c:",c_wind_speed[k])
        print("****************************************************************************")
        print("风速分布参数kappa:",kappa_wind_speed[k])
        print("****************************************************************************")        
        print("安全发电站的总发电成本：", sum_cost[0][k])
        print("****************************************************************************")
        print("原变量迭代步长为:",step_size_primal)
        print("****************************************************************************")
        print("对偶变量迭代步长为:",step_size_dual)
        print("****************************************************************************")

    print(datetime.now().strftime('%Y-%m-%d %H:%M:%S.%f')[:-3])
    return None

# %%
SCC_Byzantine_attack_decentralized_economic_dispatch(thermal_power_station_strategy,wind_power_station_strategy,c_wind_speed,kappa_wind_speed,d_power_demand,thermal_power_station_dual_variable,wind_power_station_dual_variable,E,thermal_power_station_cost,wind_power_station_cost,thermal_power_station_eta,thermal_power_station_zeta,thermal_power_station_P_min,thermal_power_station_P_max,wind_power_station_varphi,wind_power_station_sigma_ue,wind_power_station_sigma_oe,wind_power_station_P_min,wind_power_station_P_max,sum_thermal_wind_power_station_strategy,step_size_primal,step_size_dual)
# Out:
# ***************************attack_free_online_decentralized_economic_dispatch*****************************
# 相关变量初始值为：
# 第 1 个火力发电站的初始计划发电量为: 70.0
# 第 2 个火力发电站的初始计划发电量为: 70.0
# 第 3 个火力发电站的初始计划发电量为: 70.0
# 第 4 个火力发电站的初始计划发电量为: 70.0
# 第 5 个风力发电站的初始计划发电量为: 70.0
# 第 6 个风力发电站的初始计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的初始对偶变量为: -70.0
# 第 2 个火力发电站的初始对偶变量为: -70.0
# 第 3 个火力发电站的初始对偶变量为: -70.0
# 第 4 个火力发电站的初始对偶变量为: -70.0
# 第 5 个风力发电站的初始对偶变量为: -70.0
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的初始总发电量: 350.0
# *************************
# 需求侧用电需求: 72.62781256
# ****************************************************************************
# 风速分布参数c: 8.301041
# ****************************************************************************
# 风速分布参数kappa: 2.66836324
# ****************************************************************************
# 安全发电站的总发电成本： 2678.3230777617387
# ****************************************************************************
# 原变量迭代步长为: 1
# *****************************************************************************
# 对偶变量迭代步长为: 3
# *****************************************************************************
# 1 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 70.21666666666667
# 第 2 个火力发电站的计划发电量为: 70.46666666666667
# 第 3 个火力发电站的计划发电量为: 67.71666666666667
# 第 4 个火力发电站的计划发电量为: 69.91666666666667
# 第 5 个风力发电站的计划发电量为: 67.54476648507118
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -71.10390627999999
# 第 2 个火力发电站的对偶变量为: -71.10390556896093
# 第 3 个火力发电站的对偶变量为: -71.10390556896093
# 第 4 个火力发电站的对偶变量为: -71.10390627999999
# 第 5 个风力发电站的对偶变量为: -71.10390627999999
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 345.86143315173786
# *************************
# 需求侧用电需求: 64.01095166
# ****************************************************************************
# 风速分布参数c: 14.69554708
# ****************************************************************************
# 风速分布参数kappa: 2.10218816
# ****************************************************************************
# 安全发电站的总发电成本： 2591.3476835205556
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 2 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 70.58806771333333
# 第 2 个火力发电站的计划发电量为: 71.05431759482681
# 第 3 个火力发电站的计划发电量为: 66.03973426149349
# 第 4 个火力发电站的计划发电量为: 70.02773438
# 第 5 个风力发电站的计划发电量为: 74.70701504539119
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -68.3739822842104
# 第 2 个火力发电站的对偶变量为: -68.51671803052066
# 第 3 个火力发电站的对偶变量为: -68.39171803177067
# 第 4 个火力发电站的对偶变量为: -68.3106210785145
# 第 5 个风力发电站的对偶变量为: -68.46073228351335
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 352.4168689950448
# *************************
# 需求侧用电需求: 72.48160172
# ****************************************************************************
# 风速分布参数c: 11.73462138
# ****************************************************************************
# 风速分布参数kappa: 2.30593756
# ****************************************************************************
# 安全发电站的总发电成本： 2569.83597845394
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 3 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 70.4543422860684
# 第 2 个火力发电站的计划发电量为: 71.13143772461197
# 第 3 个火力发电站的计划发电量为: 64.22100309507897
# 第 4 个火力发电站的计划发电量为: 69.65937109558575
# 第 5 个风力发电站的计划发电量为: 79.05718162756283
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -68.95210524947962
# 第 2 个火力发电站的对偶变量为: -69.62149963711269
# 第 3 个火力发电站的对偶变量为: -69.4048935785594
# 第 4 个火力发电站的对偶变量为: -70.05896760916113
# 第 5 个风力发电站的对偶变量为: -68.82398942046811
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 354.52333582890793
# *************************
# 需求侧用电需求: 74.35324129
# ****************************************************************************
# 风速分布参数c: 20.88797006
# ****************************************************************************
# 风速分布参数kappa: 2.49450248
# ****************************************************************************
# 安全发电站的总发电成本： 2819.0138437263963
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 4 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 70.4350236190291
# 第 2 个火力发电站的计划发电量为: 71.38227690464147
# 第 3 个火力发电站的计划发电量为: 62.90759978558259
# 第 4 个火力发电站的计划发电量为: 69.62844431016438
# 第 5 个风力发电站的计划发电量为: 84.21480708900712
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -70.13776084179867
# 第 2 个火力发电站的对偶变量为: -71.48969673486286
# 第 3 个火力发电站的对偶变量为: -71.19521845831775
# 第 4 个火力发电站的对偶变量为: -72.868870862487
# 第 5 个风力发电站的对偶变量为: -69.85015364597685
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 358.56815170842464
# *************************
# 需求侧用电需求: 73.36237628
# ****************************************************************************
# 风速分布参数c: 17.01236112
# ****************************************************************************
# 风速分布参数kappa: 2.63537814
# ****************************************************************************
# 安全发电站的总发电成本： 2539.7950628460426
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 5 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 70.61592223742662
# 第 2 个火力发电站的计划发电量为: 71.91061897832535
# 第 3 个火力发电站的计划发电量为: 62.13556356830277
# 第 4 个火力发电站的计划发电量为: 70.06970058180833
# 第 5 个风力发电站的计划发电量为: 92.78784106777694
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -70.3755110439598
# 第 2 个火力发电站的对偶变量为: -72.4860579427
# 第 3 个火力发电站的对偶变量为: -72.12753579012032
# 第 4 个火力发电站的对偶变量为: -74.89967018142084
# 第 5 个风力发电站的对偶变量为: -69.90949574760923
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 367.51964643364
# *************************
# 需求侧用电需求: 72.02509011
# ****************************************************************************
# 风速分布参数c: 11.53887689
# ****************************************************************************
# 风速分布参数kappa: 2.44466253
# ****************************************************************************
# 安全发电站的总发电成本： 2659.06165883865
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 6 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 70.81202457603399
# 第 2 个火力发电站的计划发电量为: 72.5336950733681
# 第 3 个火力发电站的计划发电量为: 61.66174027318681
# 第 4 个火力发电站的计划发电量为: 70.79426637265243
# 第 5 个风力发电站的计划发电量为: 94.2950794904394
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -68.92222451229992
# 第 2 个火力发电站的对偶变量为: -71.9481405056307
# 第 3 个火力发电站的对偶变量为: -71.5363149534863
# 第 4 个火力发电站的对偶变量为: -75.70210803678444
# 第 5 个风力发电站的对偶变量为: -68.1721871234822
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 370.0968057856808
# *************************
# 需求侧用电需求: 71.92071638
# ****************************************************************************
# 风速分布参数c: 20.17759
# ****************************************************************************
# 风速分布参数kappa: 2.96946266
# ****************************************************************************
# 安全发电站的总发电成本： 2742.175510916064
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 7 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 70.73943867698605
# 第 2 个火力发电站的计划发电量为: 72.98300298940185
# 第 3 个火力发电站的计划发电量为: 61.177037481561634
# 第 4 个火力发电站的计划发电量为: 71.56200108220162
# 第 5 个风力发电站的计划发电量为: 101.42570509237268
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -67.3991359079939
# 第 2 个火力发电站的对偶变量为: -71.0370558272232
# 第 3 个火力发电站的对偶变量为: -70.58020243864604
# 第 4 个火力发电站的对偶变量为: -75.55963754318665
# 第 5 个风力发电站的对偶变量为: -66.5881415063922
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 377.8871853225238
# *************************
# 需求侧用电需求: 72.93331067
# ****************************************************************************
# 风速分布参数c: 12.95856003
# ****************************************************************************
# 风速分布参数kappa: 2.36446438
# ****************************************************************************
# 安全发电站的总发电成本： 2705.5512680485003
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 8 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 70.42280377359192
# 第 2 个火力发电站的计划发电量为: 73.2198068903698
# 第 3 个火力发电站的计划发电量为: 60.6226526205804
# 第 4 个火力发电站的计划发电量为: 72.21002387079086
# 第 5 个风力发电站的计划发电量为: 103.28852364199217
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -65.58054959392427
# 第 2 个火力发电站的对偶变量为: -69.88134728173901
# 第 3 个火力发电站的对偶变量为: -69.38612002073596
# 第 4 个火力发电站的对偶变量为: -75.36743972733083
# 第 5 个风力发电站的对偶变量为: -64.53173833427743
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 379.76381079732516
# *************************
# 需求侧用电需求: 65.05998342
# ****************************************************************************
# 风速分布参数c: 4.42860238
# ****************************************************************************
# 风速分布参数kappa: 2.42410411
# ****************************************************************************
# 安全发电站的总发电成本： 4519.906212310027
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 9 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 69.84581686314439
# 第 2 个火力发电站的计划发电量为: 73.23202417379304
# 第 3 个火力发电站的计划发电量为: 59.971815222562356
# 第 4 个火力发电站的计划发电量为: 72.74501084149715
# 第 5 个风力发电站的计划发电量为: 83.10882774427628
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -59.814646733105945
# 第 2 个火力发电站的对偶变量为: -64.59116807315556
# 第 3 个火力发电站的对偶变量为: -64.06345575518954
# 第 4 个火力发电站的对偶变量为: -70.66856541768385
# 第 5 个风力发电站的对偶变量为: -58.67967767909944
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 358.90349484527326
# *************************
# 需求侧用电需求: 65.89481815
# ****************************************************************************
# 风速分布参数c: 13.39240335
# ****************************************************************************
# 风速分布参数kappa: 2.3728007
# ****************************************************************************
# 安全发电站的总发电成本： 2546.7952722785276
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 10 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 68.38573937547089
# 第 2 个火力发电站的计划发电量为: 72.36089558919024
# 第 3 个火力发电站的计划发电量为: 58.554272032253245
# 第 4 个火力发电站的计划发电量为: 72.42997872259065
# 第 5 个风力发电站的计划发电量为: 87.08447285148088
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -57.66752923250905
# 第 2 个火力发电站的对偶变量为: -61.6029860506584
# 第 3 个火力发电站的对偶变量为: -61.04807921124353
# 第 4 个火力发电站的对偶变量为: -66.08073845214656
# 第 5 个风力发电站的对偶变量为: -57.16343384306638
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 358.8153585709859
# *************************
# 需求侧用电需求: 82.22889118
# ****************************************************************************
# 风速分布参数c: 3.71616054
# ****************************************************************************
# 风速分布参数kappa: 2.52674506
# ****************************************************************************
# 安全发电站的总发电成本： 4207.630621757358
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 11 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 66.76491943186716
# 第 2 个火力发电站的计划发电量为: 71.10933902642596
# 第 3 个火力发电站的计划发电量为: 56.896411574826985
# 第 4 个火力发电站的计划发电量为: 71.38968779095791
# 第 5 个风力发电站的计划发电量为: 65.62402294715068
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -63.459844100153916
# 第 2 个火力发电站的对偶变量为: -66.97141464979305
# 第 3 个火力发电站的对偶变量为: -66.39413559560477
# 第 4 个火力发电站的对偶变量为: -70.97948169536804
# 第 5 个风力发电站的对偶变量为: -62.82010714609346
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 331.7843807712287
# *************************
# 需求侧用电需求: 72.39439433
# ****************************************************************************
# 风速分布参数c: 22.04759493
# ****************************************************************************
# 风速分布参数kappa: 2.67853757
# ****************************************************************************
# 安全发电站的总发电成本： 2681.0490873253457
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 12 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 66.32829599192408
# 第 2 个火力发电站的计划发电量为: 70.92148069949063
# 第 3 个火力发电站的计划发电量为: 56.43626469941812
# 第 4 个火力发电站的计划发电量为: 71.29589043298284
# 第 5 个风力发电站的计划发电量为: 69.82131078021828
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -67.73560240569421
# 第 2 个火力发电站的对偶变量为: -69.99351461177883
# 第 3 个火力发电站的对偶变量为: -69.39979493510023
# 第 4 个火力发电站的对偶变量为: -71.83890216517486
# 第 5 个风力发电站的对偶变量为: -67.73122776311499
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 334.8032426040339
# *************************
# 需求侧用电需求: 59.43051398
# ****************************************************************************
# 风速分布参数c: 22.07798354
# ****************************************************************************
# 风速分布参数kappa: 2.67292298
# ****************************************************************************
# 安全发电站的总发电成本： 2697.042589043248
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 13 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 66.66324310063003
# 第 2 个火力发电站的计划发电量为: 71.2626665736892
# 第 3 个火力发电站的计划发电量为: 56.56218821920913
# 第 4 个火力发电站的计划发电量为: 71.35705448972246
# 第 5 个风力发电站的计划发电量为: 74.61639475760393
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -64.77594026024018
# 第 2 个火力发电站的对偶变量为: -66.45514537902861
# 第 3 个火力发电站的对偶变量为: -65.85053906849396
# 第 4 个火力发电站的对偶变量为: -67.35355039269265
# 第 5 个风力发电站的对偶变量为: -64.66224748233547
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 340.46154714085475
# *************************
# 需求侧用电需求: 66.57067559
# ****************************************************************************
# 风速分布参数c: 24.23535384
# ****************************************************************************
# 风速分布参数kappa: 2.6829301
# ****************************************************************************
# 安全发电站的总发电成本： 2898.7139922682345
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 14 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 66.45969532541834
# 第 2 个火力发电站的计划发电量为: 70.9680641494126
# 第 3 个火力发电站的计划发电量为: 56.07327324340444
# 第 4 个火力发电站的计划发电量为: 70.6630144106226
# 第 5 个风力发电站的计划发电量为: 76.03101278591927
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -64.36611579240088
# 第 2 个火力发电站的对偶变量为: -66.00152381830758
# 第 3 个火力发电站的对偶变量为: -65.3881195802928
# 第 4 个火力发电站的对偶变量为: -66.82674497847971
# 第 5 个风力发电站的对偶变量为: -64.10053610297079
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 340.1950599147773
# *************************
# 需求侧用电需求: 69.25657964
# ****************************************************************************
# 风速分布参数c: 14.77327144
# ****************************************************************************
# 风速分布参数kappa: 2.06624199
# ****************************************************************************
# 安全发电站的总发电成本： 2476.4535728549586
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 15 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 66.21532242188701
# 第 2 个火力发电站的计划发电量为: 70.63762945895982
# 第 3 个火力发电站的计划发电量为: 55.59773762342341
# 第 4 个火力发电站的计划发电量为: 69.96792843904139
# 第 5 个风力发电站的计划发电量为: 80.79405232480573
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -65.14456099816695
# 第 2 个火力发电站的对偶变量为: -66.91938664317382
# 第 3 个火力发电站的对偶变量为: -66.29794742868789
# 第 4 个火力发电站的对偶变量为: -67.96155000955844
# 第 5 个风力发电站的对偶变量为: -64.81661026460989
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 343.21267026811734
# *************************
# 需求侧用电需求: 62.4132554
# ****************************************************************************
# 风速分布参数c: 22.01070443
# ****************************************************************************
# 风速分布参数kappa: 2.82899266
# ****************************************************************************
# 安全发电站的总发电成本： 2714.9607113179227
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 16 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 66.13368072796008
# 第 2 个火力发电站的计划发电量为: 70.50478058919589
# 第 3 个火力发电站的计划发电量为: 55.36181406787139
# 第 4 个火力发电站的计划发电量为: 69.54886238575429
# 第 5 个风力发电站的计划发电量为: 85.27664380287848
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -61.96601100945267
# 第 2 个火力发电站的对偶变量为: -64.14127759348061
# 第 3 个火力发电站的对偶变量为: -63.513971143305874
# 第 4 个火力发电站的对偶变量为: -65.85443651549552
# 第 5 个风力发电站的对偶变量为: -61.47144404490888
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 346.82578157366015
# *************************
# 需求侧用电需求: 68.27939592
# ****************************************************************************
# 风速分布参数c: 24.26368821
# ****************************************************************************
# 风速分布参数kappa: 2.29481562
# ****************************************************************************
# 安全发电站的总发电成本： 2988.5008418072744
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 17 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 65.53330233126091
# 第 2 个火力发电站的计划发电量为: 69.92684814190122
# 第 3 个火力发电站的计划发电量为: 54.705540322532826
# 第 4 个火力发电站的计划发电量为: 68.83099400678425
# 第 5 个风力发电站的计划发电量为: 84.64473204278656
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -61.234187925778045
# 第 2 个火力发电站的对偶变量为: -63.93564251369496
# 第 3 个火力发电站的对偶变量为: -63.30418263547883
# 第 4 个火力发电站的对偶变量为: -66.57827156771094
# 第 5 个风力发电站的对偶变量为: -60.58064480654413
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 343.6414168452658
# *************************
# 需求侧用电需求: 74.37551359
# ****************************************************************************
# 风速分布参数c: 17.54487156
# ****************************************************************************
# 风速分布参数kappa: 2.9754401
# ****************************************************************************
# 安全发电站的总发电成本： 2315.8731864992997
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 18 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 64.89200450417036
# 第 2 个火力发电站的计划发电量为: 69.39266406169371
# 第 3 个火力发电站的计划发电量为: 54.13571246877739
# 第 4 个火力发电站的计划发电量为: 68.32349835055471
# 第 5 个风力发电站的计划发电量为: 93.18711126795758
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -64.00508263544688
# 第 2 个火力发电站的对偶变量为: -67.04895910758871
# 第 3 个火力发电站的对偶变量为: -66.41431471292583
# 第 4 个火力发电站的对偶变量为: -70.34804034002286
# 第 5 个风力发电站的对偶变量为: -63.34227116986998
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 349.93099065315374
# *************************
# 需求侧用电需求: 76.41692674
# ****************************************************************************
# 风速分布参数c: 4.81637973
# ****************************************************************************
# 风速分布参数kappa: 2.19682287
# ****************************************************************************
# 安全发电站的总发电成本： 3832.0717026075545
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 19 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 64.79909766868184
# 第 2 个火力发电站的计划发电量为: 69.4494809312965
# 第 3 个火力发电站的计划发电量为: 54.18965811420788
# 第 4 个火力发电站的计划发电量为: 68.50773444673919
# 第 5 个风力发电站的计划发电量为: 73.54175319699539
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -66.9017574574978
# 第 2 个火力发电站的对偶变量为: -70.62140304016206
# 第 3 个火力发电站的对偶变量为: -69.98542710697825
# 第 4 个火力发电站的对偶变量为: -74.97147834855579
# 第 5 个风力发电站的对偶变量为: -65.94017464661226
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 330.4877243579208
# *************************
# 需求侧用电需求: 63.07056204
# ****************************************************************************
# 风速分布参数c: 22.76341842
# ****************************************************************************
# 风速分布参数kappa: 2.30087244
# ****************************************************************************
# 安全发电站的总发电成本： 2720.111665761753
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 20 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 65.20151239299275
# 第 2 个火力发电站的计划发电量为: 70.09403484559849
# 第 3 个火力发电站的计划发电量为: 54.82880921424246
# 第 4 个火力发电站的计划发电量为: 69.43951403232276
# 第 5 个风力发电站的计划发电量为: 75.71761460342448
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -66.08890770509905
# 第 2 个火力发电站的对偶变量为: -69.16607310741254
# 第 3 个火力发电站的对偶变量为: -68.53008734984876
# 第 4 个火力发电站的对偶变量为: -72.28476035356472
# 第 5 个风力发电站的对偶变量为: -65.7428021582466
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 335.28148508858095
# *************************
# 需求侧用电需求: 72.76413739
# ****************************************************************************
# 风速分布参数c: 7.10546984
# ****************************************************************************
# 风速分布参数kappa: 2.49300975
# ****************************************************************************
# 安全发电站的总发电成本： 2736.036768479116
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 21 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 65.41412617078858
# 第 2 个火力发电站的计划发电量为: 70.40901899267811
# 第 3 个火力发电站的计划发电量为: 55.1071607345824
# 第 4 个火力发电站的计划发电量为: 69.80703483720987
# 第 5 个风力发电站的计划发电量为: 65.8576339039069
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -69.56958619305384
# 第 2 个火力发电站的对偶变量为: -72.21857051570359
# 第 3 个火力发电站的对偶变量为: -71.58234006612163
# 第 4 个火力发电站的对偶变量为: -74.7707071300341
# 第 5 个风力发电站的对偶变量为: -69.20574736775573
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 326.59497463916586
# *************************
# 需求侧用电需求: 72.47977434
# ****************************************************************************
# 风速分布参数c: 20.89161523
# ****************************************************************************
# 风速分布参数kappa: 2.7421258
# ****************************************************************************
# 安全发电站的总发电成本： 2539.929826092633
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 22 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 66.17815016990775
# 第 2 个火力发电站的计划发电量为: 71.19022984795049
# 第 3 个火力发电站的计划发电量为: 55.84272600970493
# 第 4 个火力发电站的计划发电量为: 70.54294000423099
# 第 5 个风力发电站的计划发电量为: 72.79663251838319
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -74.05466285625228
# 第 2 个火力发电站的对偶变量为: -75.94765606943093
# 第 3 个火力发电站的对偶变量为: -75.30978267846288
# 第 4 个火力发电站的对偶变量为: -77.24858968058385
# 第 5 个风力发电站的对偶变量为: -74.01670823735884
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 336.55067855017734
# *************************
# 需求侧用电需求: 72.35827036
# ****************************************************************************
# 风速分布参数c: 4.73395435
# ****************************************************************************
# 风速分布参数kappa: 2.61322499
# ****************************************************************************
# 安全发电站的总发电成本： 3342.7104392653355
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 23 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 67.58654370634558
# 第 2 个火力发电站的计划发电量为: 72.48749149671566
# 第 3 个火力发电站的计划发电量为: 57.063452144319996
# 第 4 个火力发电站的计划发电量为: 71.59983745046608
# 第 5 个风力发电站的计划发电量为: 55.31689581614542
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -77.02085725834601
# 第 2 个火力发电站的对偶变量为: -78.77412880778328
# 第 3 个火力发电站的对偶变量为: -78.13432952796967
# 第 4 个火力发电站的对偶变量为: -79.73869998804328
# 第 5 个风力发电站的对偶变量为: -76.80351429244367
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 324.05422061399275
# *************************
# 需求侧用电需求: 71.12392002
# ****************************************************************************
# 风速分布参数c: 18.17359002
# ****************************************************************************
# 风速分布参数kappa: 2.07787691
# ****************************************************************************
# 安全发电站的总发电成本： 2535.6419582954336
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 24 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 69.29916984904659
# 第 2 个火力发电站的计划发电量为: 74.08070161262293
# 第 3 个火力发电站的计划发电量为: 58.52910175228241
# 第 4 个火力发电站的计划发电量为: 72.93964110049836
# 第 5 个风力发电站的计划发电量为: 63.23935842296004
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -81.28014445333889
# 第 2 个火力发电站的对偶变量为: -82.01544557324381
# 第 3 个火力发电站的对偶变量为: -81.37234196201815
# 第 4 个火力发电站的对偶变量为: -81.18418069134302
# 第 5 个风力发电站的对偶变量为: -81.66443877530754
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 338.0879727374103
# *************************
# 需求侧用电需求: 76.7139357
# ****************************************************************************
# 风速分布参数c: 4.48706041
# ****************************************************************************
# 风速分布参数kappa: 2.43670989
# ****************************************************************************
# 安全发电站的总发电成本： 3264.682618574056
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 25 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 71.49047266164845
# 第 2 个火力发电站的计划发电量为: 75.99904782379281
# 第 3 个火力发电站的计划发电量为: 60.26327492177985
# 第 4 个火力发电站的计划发电量为: 74.35288274482657
# 第 5 个风力发电站的计划发电量为: 47.76298794115068
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -86.41325860943883
# 第 2 个火力发电站的对偶变量为: -86.8568152136255
# 第 3 个火力发电站的对偶变量为: -86.20821289013166
# 第 4 个火力发电站的对偶变量为: -85.63366739276897
# 第 5 个风力发电站的对偶变量为: -86.63488503103977
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 329.8686660931984
# *************************
# 需求侧用电需求: 61.05044826
# ****************************************************************************
# 风速分布参数c: 11.55331759
# ****************************************************************************
# 风速分布参数kappa: 2.5075835
# ****************************************************************************
# 安全发电站的总发电成本： 2464.114984481661
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 26 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 74.24146862056571
# 第 2 个火力发电站的计划发电量为: 78.46531223651836
# 第 3 个火力发电站的计划发电量为: 62.48260454293919
# 第 4 个火力发电站的计划发电量为: 76.33105030051809
# 第 5 个风力发电站的计划发电量为: 60.04770767013208
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -85.04079861092194
# 第 2 个火力发电站的对偶变量为: -85.74565809987465
# 第 3 个火力发电站的对偶变量为: -85.08918265785002
# 第 4 个火力发电站的对偶变量为: -81.64254914075184
# 第 5 个风力发电站的对偶变量为: -85.82551958391855
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 351.56814337067345
# *************************
# 需求侧用电需求: 76.57534104
# ****************************************************************************
# 风速分布参数c: 11.11125981
# ****************************************************************************
# 风速分布参数kappa: 2.9635753
# ****************************************************************************
# 安全发电站的总发电成本： 2565.9950672396003
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 27 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 76.392336791943
# 第 2 个火力发电站的计划发电量为: 80.41343810123415
# 第 3 个火力发电站的计划发电量为: 64.10485314547044
# 第 4 个火力发电站的计划发电量为: 77.39676053641196
# 第 5 个风力发电站的计划发电量为: 71.19907335725006
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -89.02537033064503
# 第 2 个火力发电站的对偶变量为: -88.96147180677494
# 第 3 个火力发电站的对偶变量为: -88.29448564698198
# 第 4 个火力发电站的对偶变量为: -86.09479917655472
# 第 5 个风力发电站的对偶变量为: -89.53700972587046
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 369.50646193230966
# *************************
# 需求侧用电需求: 79.54768147
# ****************************************************************************
# 风速分布参数c: 13.22114577
# ****************************************************************************
# 风速分布参数kappa: 2.23501543
# ****************************************************************************
# 安全发电站的总发电成本： 2792.522174718989
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 28 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 78.91693304680486
# 第 2 个火力发电站的计划发电量为: 82.63453592536337
# 第 3 个火力发电站的计划发电量为: 65.96120292138875
# 第 4 个火力发电站的计划发电量为: 79.07129866545291
# 第 5 个风力发电站的计划发电量为: 81.09116463165273
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -91.83102226236383
# 第 2 个火力发电站的对偶变量为: -92.05882304305702
# 第 3 个火力发电站的对偶变量为: -91.37797693381381
# 第 4 个火力发电站的对偶变量为: -90.4922202218969
# 第 5 个风力发电站的对偶变量为: -92.03275836355047
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 387.67513519066256
# *************************
# 需求侧用电需求: 70.77558923
# ****************************************************************************
# 风速分布参数c: 16.55283022
# ****************************************************************************
# 风速分布参数kappa: 2.00468584
# ****************************************************************************
# 安全发电站的总发电成本： 3100.7870128983714
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 29 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 81.56831746254684
# 第 2 个火力发电站的计划发电量为: 85.07201074928214
# 第 3 个火力发电站的计划发电量为: 67.98804320323413
# 第 4 个火力发电站的计划发电量为: 81.26942303592078
# 第 5 个风力发电站的计划发电量为: 89.49027593344758
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -88.0307177888823
# 第 2 个火力发电站的对偶变量为: -89.11004955363978
# 第 3 个火力发电站的对偶变量为: -88.4138802032313
# 第 4 个火力发电站的对偶变量为: -88.80829601667823
# 第 5 个风力发电站的对偶变量为: -87.97318630627151
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 405.38807038443144
# *************************
# 需求侧用电需求: 75.70722657
# ****************************************************************************
# 风速分布参数c: 7.5123474
# ****************************************************************************
# 风速分布参数kappa: 2.84390111
# ****************************************************************************
# 安全发电站的总发电成本： 3578.6035314745495
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 30 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 83.22838090325007
# 第 2 个火力发电站的计划发电量为: 86.68896422373568
# 第 3 个火力发电站的计划发电量为: 69.14590191117436
# 第 4 个火力发电站的计划发电量为: 82.91212782587705
# 第 5 个风力发电站的计划发电量为: 81.23532283841105
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -84.86914667761846
# 第 2 个火力发电站的对偶变量为: -86.82022082274632
# 第 3 个火力发电站的对偶变量为: -86.10677510891107
# 第 4 个火力发电站的对偶变量为: -87.87508767140147
# 第 5 个风力发电站的对偶变量为: -84.60821565046135
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 403.2106977024482
# *************************
# 需求侧用电需求: 67.43684589
# ****************************************************************************
# 风速分布参数c: 6.9741147
# ****************************************************************************
# 风速分布参数kappa: 2.01470627
# ****************************************************************************
# 安全发电站的总发电成本： 3734.4502846672212
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 31 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 84.13740726091439
# 第 2 个火力发电站的计划发电量为: 87.70599085732242
# 第 3 个火力发电站的计划发电量为: 69.70503924242561
# 第 4 个火力发电站的计划发电量为: 84.193959792876
# 第 5 个风力发电站的计划发电量为: 73.4622913263437
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -78.47281792421728
# 第 2 个火力发电站的对偶变量为: -80.45499005788884
# 第 3 个火力发电站的对偶变量为: -79.72224226707205
# 第 4 个火力发电站的对偶变量为: -81.54130225479261
# 第 5 个风力发电站的对偶变量为: -78.52063485554059
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 399.20468847988207
# *************************
# 需求侧用电需求: 64.79238622
# ****************************************************************************
# 风速分布参数c: 23.88060792
# ****************************************************************************
# 风速分布参数kappa: 2.21015256
# ****************************************************************************
# 安全发电站的总发电成本： 3645.3159538346613
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 32 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 83.85766026806049
# 第 2 个火力发电站的计划发电量为: 87.52484710123203
# 第 3 个火力发电站的计划发电量为: 69.09664736042221
# 第 4 个火力发电站的计划发电量为: 84.25993186123193
# 第 5 个风力发电站的计划发电量为: 76.30228407360548
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -71.67694358623987
# 第 2 个火力发电站的对偶变量为: -73.18960115028995
# 第 3 个火力发电站的对偶变量为: -72.43778967962588
# 第 4 个火力发电站的对偶变量为: -73.36527280012925
# 第 5 个风力发电站的对偶变量为: -72.02663391341761
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 401.0413706645521
# *************************
# 需求侧用电需求: 79.20664696
# ****************************************************************************
# 风速分布参数c: 15.04406637
# ****************************************************************************
# 风速分布参数kappa: 2.84368377
# ****************************************************************************
# 安全发电站的总发电成本： 3053.9927852419414
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 33 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 82.48303339624563
# 第 2 个火力发电站的计划发电量为: 86.15725960094736
# 第 3 个火力发电站的计划发电量为: 67.38673254534841
# 第 4 个火力发电站的计划发电量为: 82.95498584526615
# 第 5 个风力发电站的计划发电量为: 86.84534660469464
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -71.73601120034527
# 第 2 个火力发电站的对偶变量为: -73.0861982593747
# 第 3 个火力发电站的对偶变量为: -72.31669428214674
# 第 4 个火力发电站的对偶变量为: -72.86256776421868
# 第 5 个风力发电站的对偶变量为: -72.00395464448961
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 405.82735799250224
# *************************
# 需求侧用电需求: 71.90639999
# ****************************************************************************
# 风速分布参数c: 19.92973653
# ****************************************************************************
# 风速分布参数kappa: 2.02497384
# ****************************************************************************
# 安全发电站的总发电成本： 3476.139592443089
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 34 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 81.30382575447668
# 第 2 个火力发电站的计划发电量为: 84.95706259804858
# 第 3 个火力发电站的计划发电量为: 65.97296940481674
# 第 4 个火力发电站的计划发电量为: 81.72937390864433
# 第 5 个风力发电站的计划发电量为: 90.03499012616419
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -67.0740089630932
# 第 2 个火力发电站的对偶变量为: -68.95646364551477
# 第 3 个火力发电站的对偶变量为: -68.17300292039454
# 第 4 个火力发电站的对偶变量为: -69.61780035761149
# 第 5 个风力发电站的对偶变量为: -66.94972215497974
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 403.9982217921505
# *************************
# 需求侧用电需求: 72.83572783
# ****************************************************************************
# 风速分布参数c: 18.72716024
# ****************************************************************************
# 风速分布参数kappa: 2.20984039
# ****************************************************************************
# 安全发电站的总发电成本： 3292.1552924412463
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 35 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 79.5068107714712
# 第 2 个火力发电站的计划发电量为: 83.23060308823115
# 第 3 个火力发电站的计划发电量为: 64.13013721832473
# 第 4 个火力发电站的计划发电量为: 80.11616889633237
# 第 5 个风力发电站的计划发电量为: 94.14789183442204
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -62.95808185712178
# 第 2 个火力发电站的对偶变量为: -65.43532542116341
# 第 3 个火力发电站的对偶变量为: -64.64342213329417
# 第 4 个火力发电站的对偶变量为: -67.09513491320486
# 第 5 个风力发电站的对偶变量为: -62.66655615632105
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 401.1316118087815
# *************************
# 需求侧用电需求: 66.23133285
# ****************************************************************************
# 风速分布参数c: 6.39076728
# ****************************************************************************
# 风速分布参数kappa: 2.33880209
# ****************************************************************************
# 安全发电站的总发电成本： 3949.4226984789793
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 36 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 77.26640496017622
# 第 2 个火力发电站的计划发电量为: 81.15035924151384
# 第 3 个火力发电站的计划发电量为: 62.03996552181702
# 第 4 个火力发电站的计划发电量为: 78.28417026982497
# 第 5 个风力发电站的计划发电量为: 77.62563281553787
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -55.77075817775224
# 第 2 个火力发电站的对偶变量为: -58.904190076432805
# 第 3 个火力发电站的对偶变量为: -58.10776232467458
# 第 4 个火力发电站的对偶变量为: -61.75859597510065
# 第 5 个风力发电站的对偶变量为: -55.276524990952026
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ...
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 988 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 65.73097135943077
# 第 2 个火力发电站的计划发电量为: 69.78271172132891
# 第 3 个火力发电站的计划发电量为: 51.935352733220746
# 第 4 个火力发电站的计划发电量为: 65.45844247679955
# 第 5 个风力发电站的计划发电量为: 23.22747032017337
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -73.32121549328448
# 第 2 个火力发电站的对偶变量为: -74.69089324342605
# 第 3 个火力发电站的对偶变量为: -73.92735748635282
# 第 4 个火力发电站的对偶变量为: -66.88426772382512
# 第 5 个风力发电站的对偶变量为: -74.84246321524373
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 276.13494861095336
# *************************
# 需求侧用电需求: 63.41616792
# ****************************************************************************
# 风速分布参数c: 7.46037989
# ****************************************************************************
# 风速分布参数kappa: 2.06906595
# ****************************************************************************
# 安全发电站的总发电成本： 2013.8172364649886
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 989 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 67.07749280812169
# 第 2 个火力发电站的计划发电量为: 71.06052784618718
# 第 3 个火力发电站的计划发电量为: 53.64853872530038
# 第 4 个火力发电站的计划发电量为: 65.42351512117045
# 第 5 个风力发电站的计划发电量为: 29.523613613999256
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -79.69308656016612
# 第 2 个火力发电站的对偶变量为: -80.3852090796324
# 第 3 个火力发电站的对偶变量为: -79.64316960121171
# 第 4 个火力发电站的对偶变量为: -72.23625662678626
# 第 5 个风力发电站的对偶变量为: -81.17155622042722
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 286.73368811477894
# *************************
# 需求侧用电需求: 73.35026091
# ****************************************************************************
# 风速分布参数c: 7.43418951
# ****************************************************************************
# 风速分布参数kappa: 2.06366986
# ****************************************************************************
# 安全发电站的总发电成本： 2105.4998459674694
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 990 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 69.30421237238627
# 第 2 个火力发电站的计划发电量为: 73.11489143355732
# 第 3 个火力发电站的计划发电量为: 55.997420661321755
# 第 4 个火力发电站的计划发电量为: 66.28495183548853
# 第 5 个风力发电站的计划发电量为: 35.2019905800806
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -89.35151822314423
# 第 2 个火力发电站的对偶变量为: -89.84647249775088
# 第 3 个火力发电站的对偶变量为: -89.12227421404215
# 第 4 个火力发电站的对偶变量为: -82.27858194243454
# 第 5 个风力发电站的对偶变量为: -90.6665164250447
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 299.90346688283444
# *************************
# 需求侧用电需求: 68.80907141
# ****************************************************************************
# 风速分布参数c: 19.00064664
# ****************************************************************************
# 风速分布参数kappa: 2.40368022
# ****************************************************************************
# 安全发电站的总发电成本： 2415.7399191959057
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 991 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 72.84006340597149
# 第 2 个火力发电站的计划发电量为: 76.46879317298556
# 第 3 个火力发电站的计划发电量为: 59.49161020798425
# 第 4 个火力发电站的计划发电量为: 68.71242984645822
# 第 5 个风力发电站的计划发电量为: 47.733251908123044
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -94.9936748505117
# 第 2 个火力发电站的对偶变量为: -95.54519141774476
# 第 3 个火力发电站的对偶变量为: -94.83276327057266
# 第 4 个火力发电站的对偶变量为: -88.7663110164258
# 第 5 个风力发电站的对偶变量为: -96.18602307829892
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 325.2461485415226
# *************************
# 需求侧用电需求: 68.43412668
# ****************************************************************************
# 风速分布参数c: 24.69532358
# ****************************************************************************
# 风速分布参数kappa: 2.76905839
# ****************************************************************************
# 安全发电站的总发电成本： 2810.7645809842743
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 992 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 76.83893398791729
# 第 2 个火力发电站的计划发电量为: 80.31970466425663
# 第 3 个火力发电站的计划发电量为: 63.291122864602606
# 第 4 个火力发电站的计划发电量为: 71.91776128505525
# 第 5 个风力发电站的计划发电量为: 54.64172778257202
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -97.3864790309497
# 第 2 个火力发电站的对偶变量为: -97.8186399797036
# 第 3 个火力发电站的对偶变量为: -97.11152174861387
# 第 4 个火力发电站的对偶变量为: -93.00243309314705
# 第 5 个风力发电站的对偶变量为: -98.27882811456156
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 347.00925058440384
# *************************
# 需求侧用电需求: 77.5218747
# ****************************************************************************
# 风速分布参数c: 19.34977167
# ****************************************************************************
# 风速分布参数kappa: 2.81628725
# ****************************************************************************
# 安全发电站的总发电成本： 2782.982586385682
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 993 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 80.69675773804008
# 第 2 个火力发电站的计划发电量为: 84.02965119786592
# 第 3 个火力发电站的计划发电量为: 66.7675187594201
# 第 4 个火力发电站的计划发电量为: 75.42844663994785
# 第 5 个风力发电站的计划发电量为: 69.02187945736273
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -101.80469369266349
# 第 2 个火力发电站的对偶变量为: -102.51056266016468
# 第 3 个火力发电站的对偶变量为: -101.80062684695217
# 第 4 个火力发电站的对偶变量为: -98.7793491466813
# 第 5 个风力发电站的对偶变量为: -102.58315305811314
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 375.9442537926367
# *************************
# 需求侧用电需求: 67.46785371
# ****************************************************************************
# 风速分布参数c: 10.91176004
# ****************************************************************************
# 风速分布参数kappa: 2.64243598
# ****************************************************************************
# 安全发电站的总发电成本： 2847.4233483581033
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 994 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 84.77014439218192
# 第 2 个火力发电站的计划发电量为: 88.02074206284813
# 第 3 个火力发电站的计划发电量为: 70.38229893008608
# 第 4 个火力发电站的计划发电量为: 79.46311566773458
# 第 5 个风力发电站的计划发电量为: 79.84173637259244
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -97.86493880275377
# 第 2 个火力发电站的对偶变量为: -98.46141427986191
# 第 3 个火力发电站的对偶变量为: -97.74111790402398
# 第 4 个火力发电站的对偶变量为: -97.14424047651711
# 第 5 个风力发电站的对偶变量为: -98.29439092126424
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 402.4780374254431
# *************************
# 需求侧用电需求: 66.54800521
# ****************************************************************************
# 风速分布参数c: 15.71097882
# ****************************************************************************
# 风速分布参数kappa: 2.6773563
# ****************************************************************************
# 安全发电站的总发电成本： 3076.999374809267
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 995 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 87.63699803302966
# 第 2 个火力发电站的计划发电量为: 90.79817759767394
# 第 3 个火力发电站的计划发电量为: 72.65175994535748
# 第 4 个火力发电站的计划发电量为: 82.72093295535394
# 第 5 个风力发电站的计划发电量为: 93.85097440445327
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -90.38482164508319
# 第 2 个火力发电站的对偶变量为: -91.81536185903107
# 第 3 个火力发电站的对偶变量为: -91.07889949551655
# 第 4 个火力发电站的对偶变量为: -92.06781689820082
# 第 5 个风力发电站的对偶变量为: -90.57263771989682
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 427.6588429358683
# *************************
# 需求侧用电需求: 64.64150556
# ****************************************************************************
# 风速分布参数c: 3.22319547
# ****************************************************************************
# 风速分布参数kappa: 2.62903492
# ****************************************************************************
# 安全发电站的总发电成本： 5357.675371829897
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 996 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 88.87014023941785
# 第 2 个火力发电站的计划发电量为: 92.09298393182647
# 第 3 个火力发电站的计划发电量为: 73.39100093805244
# 第 4 个火力发电站的计划发电量为: 84.72545248563483
# 第 5 个风力发电站的计划发电量为: 77.94643563497193
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -79.24176047889779
# 第 2 个火力发电站的对偶变量为: -81.7992477572773
# 第 3 个火力发电站的对偶变量为: -81.04116086942778
# 第 4 个火力发电站的对偶变量为: -83.8647102978774
# 第 5 个风力发电站的对偶变量为: -79.05216727518203
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 417.0260132299035
# *************************
# 需求侧用电需求: 75.10408906
# ****************************************************************************
# 风速分布参数c: 8.16558337
# ****************************************************************************
# 风速分布参数kappa: 2.05432022
# ****************************************************************************
# 安全发电站的总发电成本： 3711.8481794025565
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 997 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 88.07963138691274
# 第 2 个火力发电站的计划发电量为: 91.54363906057611
# 第 3 个火力发电站的计划发电量为: 72.32052590941737
# 第 4 个火力发电站的计划发电量为: 85.11222264124338
# 第 5 个风力发电站的计划发电量为: 73.96472401028609
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -75.5315254640885
# 第 2 个火力发电站的对偶变量为: -77.84657117288369
# 第 3 个火力发电站的对偶变量为: -77.06519128345194
# 第 4 个火力发电站的对偶变量为: -79.2058660121045
# 第 5 个风力发电站的对偶变量为: -75.8739168587238
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 411.02074300843566
# *************************
# 需求侧用电需求: 74.46242037
# ****************************************************************************
# 风速分布参数c: 3.06843305
# ****************************************************************************
# 风速分布参数kappa: 2.46674814
# ****************************************************************************
# 安全发电站的总发电成本： 4811.745063227343
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 998 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 86.7774687270276
# 第 2 个火力发电站的计划发电量为: 90.40967631621228
# 第 3 个火力发电站的计划发电量为: 70.78542716341714
# 第 4 个火力发电站的计划发电量为: 84.67417247977204
# 第 5 个风力发电站的计划发电量为: 55.61316584080724
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -72.42567596590787
# 第 2 个火力发电站的对偶变量为: -74.25107432703747
# 第 3 个火力发电站的对偶变量为: -73.4481178963565
# 第 4 个火力发电站的对偶变量为: -74.80470432988193
# 第 5 个风力发电站的对偶变量为: -72.90611865074257
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 388.2599105272363
# *************************
# 需求侧用电需求: 57.53112837
# ****************************************************************************
# 风速分布参数c: 20.15305097
# ****************************************************************************
# 风速分布参数kappa: 2.53492363
# ****************************************************************************
# 安全发电站的总发电成本： 3374.9329820569574
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 999 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 85.13345644319685
# 第 2 个火力发电站的计划发电量为: 88.82954906802988
# 第 3 个火力发电站的计划发电量为: 68.93147612091104
# 第 4 个火力发电站的计划发电量为: 83.55735164144753
# 第 5 个风力发电站的计划发电量为: 63.62536647017576
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -63.81398665879385
# 第 2 个火力发电站的对偶变量为: -65.6876189343438
# 第 3 个火力发电站的对偶变量为: -64.86838466844445
# 第 4 个火力发电站的对偶变量为: -62.83163272150816
# 第 5 个风力发电站的对偶变量为: -64.85691857952389
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 390.07719974376107
# *************************
# 需求侧用电需求: 69.0560216
# ****************************************************************************
# 风速分布参数c: 17.58707426
# ****************************************************************************
# 风速分布参数kappa: 2.68279184
# ****************************************************************************
# 安全发电站的总发电成本： 3170.204337831585
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 2024-07-30 17:10:32.224

# %%
#数据存储
np.savetxt('./data/04_SCC_optimal_parameters_small_Byzantine_attack_sum_cost.txt',sum_cost,fmt='%0.8f')
np.savetxt('./data/04_SCC_optimal_parameters_small_Byzantine_attack_sum_thermal_wind_power_station_strategy.txt',sum_thermal_wind_power_station_strategy,fmt='%0.8f')

# %%
#评价指标：动态regret和累计的约束违反

# %%
#动态regret

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
from sympy import *
import math 
from datetime import datetime
from scipy.special import gamma, factorial
import scipy.special as sc

# %%
sum_cost=np.loadtxt("./data/04_SCC_optimal_parameters_small_Byzantine_attack_sum_cost.txt")
optimal_sum_cost=np.loadtxt("./data/00_optimal_sum_cost_varying_D_c_kappa_normal_distribution_(70,5).txt")

# %%
dynamic_regret=[]
dynamic_regret_T=[]
for T in range(1, 1000):
    dynamic_regret_auxiliary_variable=0
    for t in range(0, T):
        dynamic_regret_auxiliary_variable=dynamic_regret_auxiliary_variable+sum_cost[t+1]-optimal_sum_cost[t+1]
    dynamic_regret.append(dynamic_regret_auxiliary_variable)
    dynamic_regret_T.append((dynamic_regret_auxiliary_variable)/T)

# %%
dynamic_regret
# Out:
# [430.6414073699998,
#  380.5538729199998,
#  357.37782229000004,
#  548.0521215099998,
#  640.1591934999997,
#  1000.5821163499995,
#  1166.3497534599996,
#  3098.8553670500005,
#  3498.1573223600008,
#  3842.2044351900013,
#  3710.054643810001,
#  4194.142313220002,
#  4304.628617090002,
#  4338.042574740002,
#  4763.514135170002,
#  4825.755494400002,
#  4918.647016320002,
#  5365.548845610002,
#  5549.431375300002,
#  5333.710523640002,
#  5246.111553680002,
#  5523.210248120001,
#  5396.488463500001,
#  5256.121454890001,
#  5744.52247657,
#  5567.487460190001,
#  5400.370526780001,
#  5896.387967549999,
#  6417.271324429999,
#  7453.142674679999,
#  8376.86647837,
#  8873.89205738,
#  9489.048289170001,
#  10072.71725121,
#  11422.423624510002,
#  11988.237182480001,
#  12186.843035040001,
#  13144.603005,
#  13590.624259300002,
#  13624.960784640003,
#  13468.003897120003,
#  12953.206893050003,
#  12967.661456210002,
#  12522.548023210002,
#  12246.03087815,
#  12167.19739406,
#  12730.972779029998,
#  12628.177739939998,
#  12572.897950729997,
#  12843.689911499998,
#  13463.191337829998,
#  13902.731038839996,
#  14582.046368329999,
#  15068.769691949998,
#  15121.467103269997,
#  15801.024981609997,
#  16705.401125869997,
#  18075.516999069998,
#  20406.33296463,
#  20841.36451913,
#  21711.07521778,
#  21666.266140729997,
#  21959.05744002,
#  22146.497866479996,
#  22555.331064849997,
#  22618.7898482,
#  22453.23465584,
#  22232.47176057,
#  21947.26159091,
#  21989.26694717,
#  21267.15380571,
#  22134.566668320003,
#  22111.487455370003,
#  22210.43707491,
#  21858.383322370002,
#  22291.22939422,
#  22392.45200911,
#  22274.508564159998,
#  23053.473102329997,
#  23422.9854102,
#  23436.940167179997,
#  24319.373978129996,
#  24804.748753729997,
#  25869.997231969995,
#  26302.254270739995,
#  26848.301807429994,
#  27388.565753359995,
#  27888.995128969997,
#  28027.709010289997,
#  28066.086808549997,
#  28330.732145219994,
#  28391.900183059995,
#  29150.470838589998,
#  28171.144069159996,
#  28377.423484889998,
#  28241.445361989998,
#  28693.45677568,
#  28736.06002934,
#  28989.98869803,
#  29545.927892850003,
#  30056.220669140002,
#  30624.991836100002,
#  30943.476699849998,
#  31578.09508544,
#  32458.11207292,
#  32860.2915826,
#  32513.679863690002,
#  32047.69370594,
#  32137.750600270003,
#  31740.287038010007,
#  31244.24208510001,
#  30937.539860490007,
#  30857.07564181001,
#  30696.384547250007,
#  30690.955132650008,
#  31350.44451962001,
#  31729.915531390012,
#  32116.753319150015,
#  32938.28223739001,
#  34215.092192350014,
#  35256.99178388002,
#  36219.31310580002,
#  36754.010935810016,
#  37903.20480823001,
#  38665.56219211001,
#  39299.67376245001,
#  39367.63609745001,
#  39734.92003792001,
#  39784.68379715001,
#  40044.269555610015,
#  39954.876033000015,
#  38914.13146644002,
#  39015.63419826002,
#  39240.23964523002,
#  38969.540809010025,
#  39203.83041804002,
#  40050.973969860024,
#  39595.62740519002,
#  39607.65587847002,
#  40140.67428825002,
#  40310.64989877002,
#  41012.32579706002,
#  40882.248423910016,
#  41154.159662270016,
#  41840.69990203001,
#  43041.20831345001,
#  44533.39851632001,
#  45685.98863763001,
#  46565.17495504001,
#  46394.47235072001,
#  46795.391670500016,
#  46280.25701287002,
#  45388.52891319002,
#  44375.315359560016,
#  43356.67169439001,
#  42487.432105880005,
#  42051.767981130004,
#  42667.076052920005,
#  43400.212170620005,
#  44551.87872128001,
#  45251.76602382001,
#  47753.52248039001,
#  48653.35058034002,
#  50300.50503886002,
#  51087.14206207002,
#  51472.86141164002,
#  51439.63727412002,
#  51701.02079325002,
#  51270.406224450024,
#  51136.58336073002,
#  50977.153730160026,
#  50690.49054457003,
#  51068.02103887002,
#  50704.806962800016,
#  50628.66870102002,
#  51086.09720553002,
#  51272.29832371002,
#  51446.70397449002,
#  52241.681358470014,
#  52406.35797927002,
#  52281.00089253001,
#  52136.61085917002,
#  52548.51444276002,
#  53941.51733944001,
#  53973.63936328001,
#  53759.42431012001,
#  54149.863445060015,
#  54180.37118110002,
#  54463.72828140002,
#  54815.194972620026,
#  55466.01469340002,
#  55985.17821420002,
#  56169.39949779002,
#  56604.48814021002,
#  56752.799814700025,
#  57117.15325487003,
#  59144.339256140025,
#  59555.906966590024,
#  59953.782496320026,
#  59969.07290911002,
#  60010.33023434002,
#  60134.32926259002,
#  59246.28009700002,
#  59133.41684621001,
#  58683.059524780016,
#  58747.31698379001,
#  58644.67360217001,
#  58964.96992464001,
#  58999.188605450014,
#  59779.30578393001,
#  61832.771869000004,
#  62360.99513966,
#  62986.57219994,
#  63023.667234090004,
#  63307.61910036,
#  63536.59679059,
#  64191.04303675,
#  64512.74653339,
#  64177.9566541,
#  63622.53750861,
#  63735.77507349001,
#  63798.56345923001,
#  63534.04912568001,
#  63422.46685084001,
#  63310.66567022001,
#  63910.61900235002,
#  64070.16165254002,
#  63687.86858730002,
#  63580.158565120015,
#  63669.59775821002,
#  63009.25182720001,
#  63991.68831869001,
#  63681.88839182001,
#  63151.769420020006,
#  63353.67112400001,
#  64021.83129916001,
#  64322.746100810014,
#  65161.39212859001,
#  65778.61940469,
#  66462.17040158,
#  67134.36545566001,
#  67834.64266163,
#  67882.84510004,
#  67995.80202659,
#  67745.70359536,
#  67839.68857421,
#  67518.82254491,
#  67543.44423642999,
#  67437.85444232999,
#  67641.12558503999,
#  68118.20082633,
#  68165.84246583999,
#  68783.17485287,
#  69250.19120885,
#  69571.10410130999,
#  70091.94238259998,
#  70567.49631338997,
#  70944.88393000998,
#  71304.23068712998,
#  70972.31510397998,
#  71192.09878450997,
#  71022.64963568997,
#  70681.06620064998,
#  70575.85765696998,
#  70804.82961888998,
#  70716.97939479999,
#  70467.34923146998,
#  70561.80371848997,
#  70577.09864948997,
#  72715.07033176997,
#  73112.52480160998,
#  73934.58040676998,
#  75512.65180878997,
#  75585.77486160999,
#  75907.14217330999,
#  75576.56117786998,
#  75702.47239451998,
#  75255.42759850998,
#  74956.23858195997,
#  76053.34637654998,
#  75578.70266233997,
#  75702.43764734999,
#  76082.75645197999,
#  75951.82705887,
#  76428.55029222,
#  76619.85232543999,
#  75825.74836982999,
#  76258.78255999999,
#  76747.35415937999,
#  76848.41720227999,
#  77754.93948955998,
#  77874.12381708999,
#  78477.75136555999,
#  78882.37813903,
#  79387.38303064,
#  79030.79856019,
#  79115.63337354001,
#  79975.84416655001,
#  79690.19406576,
#  79291.22705557001,
#  79334.56522689002,
#  79247.79611231001,
#  79779.09984169001,
#  79292.77316247001,
#  79621.98070462,
#  80142.5500712,
#  80322.76790953,
#  79687.01570849,
#  80374.92254615,
#  81537.37913858,
#  82129.72572929,
#  82914.25586125,
#  83884.92812249,
#  85187.78929607,
#  86006.96685453001,
#  86335.12890245,
#  86496.73489683999,
#  86591.48173949998,
#  86872.87339351999,
#  86777.57083362999,
#  86256.20568625999,
#  85606.85162936998,
#  85732.10350978999,
#  85613.01985990998,
#  85537.90799850998,
#  85656.71825343999,
#  85973.11314623,
#  86600.02325528,
#  87506.21186844999,
#  87741.22627912999,
#  88105.50914475998,
#  88516.36544591999,
#  88945.23625661999,
#  89060.26567765999,
#  89125.86770254998,
#  90069.30922345998,
#  89335.76688352998,
#  89527.17943604,
#  88427.97385822999,
#  88287.86042471,
#  87705.82625255,
#  87243.58986868,
#  87418.48421803002,
#  87474.51534701002,
#  88268.64627858001,
#  89334.74290089,
#  90512.19597481,
#  91582.50560578,
#  92647.46061677,
#  93975.38829208,
#  95750.70333061999,
#  96954.89796061999,
#  96890.09306228999,
#  96810.25247332,
#  96971.56601253,
#  96826.81516369001,
#  96420.14632416001,
#  95499.95581079002,
#  95340.63941780003,
#  95133.94732430002,
#  95137.52746175003,
#  95496.03753354003,
#  95750.39069908003,
#  96049.42139727004,
#  97141.17999010003,
#  97741.59509365004,
#  98526.23093424005,
#  99183.60882899005,
#  100027.31276183005,
#  100704.07205629005,
#  101475.11172309006,
#  102486.98845128006,
#  102999.74698878005,
#  103229.25110586005,
#  104515.22542732004,
#  104547.53869519004,
#  104132.19968631005,
#  103193.40511910005,
#  102263.25839968004,
#  102063.41670744003,
#  101610.47437185002,
#  100938.41476600003,
#  100874.73503417002,
#  101067.02989442003,
#  101422.70741576003,
#  101698.75643388003,
#  102395.60933286003,
#  102841.80235074002,
#  103426.61475218002,
#  103762.98309732002,
#  104377.17606179001,
#  105065.68777381002,
#  105695.51687587,
#  106152.09774051,
#  106048.34171122,
#  106130.7022145,
#  105606.64121397,
#  106590.46968961,
#  106299.92388793001,
#  105650.34878321,
#  104976.77490852002,
#  104640.52248001001,
#  105287.51401752,
#  105272.11879131,
#  105160.23425252999,
#  105583.39994588999,
#  105493.41456276,
#  107081.63551301,
#  107181.16576286001,
#  107404.46258038,
#  107669.45035431,
#  108010.3894181,
#  108547.50176061,
#  109033.69627225,
#  109531.6501047,
#  109208.97568378001,
#  110030.71390924002,
#  110072.74386937002,
#  110368.08959965002,
#  110320.25990291002,
#  110484.34257408002,
#  110834.11852109003,
#  111094.69028405003,
#  111160.94144952003,
#  111378.91883633003,
#  111559.43720742004,
#  111553.49394071003,
#  112099.46460119003,
#  112690.77175436003,
#  112725.72197789003,
#  113884.25463593003,
#  114015.94461351003,
#  113659.84181104004,
#  113749.64197563003,
#  113977.52894425004,
#  114113.57928147004,
#  113765.20419418004,
#  115008.25872547003,
#  115522.60271716003,
#  115566.24817555003,
#  115692.81243314003,
#  116712.99224878004,
#  116896.93440185003,
#  116884.09942501003,
#  117443.93480840004,
#  117536.05177919003,
#  117274.19996167003,
#  117035.29825098003,
#  116612.79929434003,
#  116553.24086585004,
#  116734.46800672002,
#  116978.42832663002,
#  117067.51692922002,
#  117757.08997782003,
#  118041.54507764002,
#  118851.37312184002,
#  119217.71533993003,
#  119619.11910132003,
#  119810.08370565003,
#  120768.60476199002,
#  119917.14895097002,
#  119555.16586008001,
#  120356.77894904002,
#  119842.72402207002,
#  119258.04469380002,
#  118771.18210613003,
#  118141.02787666004,
#  117334.12736727003,
#  117567.97777180003,
#  118185.58832701002,
#  118856.31073894002,
#  119612.71626098001,
#  122554.35106954002,
#  123985.53471677002,
#  124752.08441694002,
#  125462.77515214004,
#  125807.06595714003,
#  127045.27736252004,
#  126510.46261690004,
#  126460.39366043004,
#  126166.51858899005,
#  125933.82339454004,
#  125720.40349765006,
#  125253.59608954006,
#  125843.78499927006,
#  126484.20794410007,
#  127530.97438490007,
#  127937.69257725007,
#  127894.14704936006,
#  128165.26595459007,
#  128413.89718073007,
#  129159.45636784006,
#  131256.41306073006,
#  130868.90490207006,
#  131842.11600886006,
#  131398.64011263006,
#  131209.64427160006,
#  131157.27775785004,
#  131519.67484463003,
#  131662.38630471003,
#  131556.38085299003,
#  131713.41123291003,
#  132119.09877968003,
#  132384.77857132003,
#  132767.34121462004,
#  133970.36113586003,
#  134167.37330378,
#  134026.81380812,
#  134194.19203719002,
#  133875.11420964,
#  134167.2937536,
#  134228.74778620002,
#  134800.13687428,
#  134713.35395135,
#  135027.94360215,
#  135138.30500558997,
#  135710.26902512996,
#  135980.86582481995,
#  136397.11996900995,
#  136797.32423395992,
#  136886.54338777994,
#  137561.28051250993,
#  137170.81673016993,
#  136786.66727777992,
#  136697.87973666991,
#  136915.0729216099,
#  137241.18479192993,
#  136922.93909363993,
#  136847.33560584992,
#  137679.21884157992,
#  137552.11654532992,
#  138006.40517108992,
#  139318.7431147099,
#  139453.9750032599,
#  139174.7090224299,
#  139651.3815590599,
#  139730.21472807988,
#  139768.2780520299,
#  139984.72545859992,
#  140214.64460015993,
#  140648.86423697992,
#  141260.31388529993,
#  142101.13810941993,
#  142926.15769326992,
#  143220.97741877992,
#  143526.0891634899,
#  143727.2984452299,
#  143652.09138368993,
#  143505.00794790994,
#  143242.71883871994,
#  142959.32023110994,
#  142682.11286364993,
#  142702.38040690994,
#  142515.77527826995,
#  142337.41989347994,
#  142873.48245025994,
#  143439.31203365992,
#  143165.87909703993,
#  143460.84696892995,
#  144004.37015485993,
#  144810.21242631995,
#  146866.36763162995,
#  147589.64663676996,
#  148073.47695969,
#  148841.1828714,
#  149202.85788639,
#  149591.42849435002,
#  149539.83273989003,
#  149372.85844864004,
#  148806.30450825003,
#  147984.63278800002,
#  147916.07380348002,
#  147697.34948762,
#  147964.22941057,
#  147684.89957792,
#  148127.57244222003,
#  148594.78389466,
#  149612.96949020002,
#  149353.04061538,
#  149645.70602768,
#  149203.39186928,
#  149017.06748629,
#  149712.26905163,
#  149911.16130348,
#  150777.45526780002,
#  151031.46465178003,
#  151575.05664779,
#  151931.5140803,
#  152200.09561582,
#  152589.44804672,
#  152938.75723783002,
#  152774.08986755004,
#  153470.64548993006,
#  153794.05741796005,
#  154315.05394750004,
#  154803.49625999003,
#  154190.53058355002,
#  154730.21566395002,
#  154963.45370339003,
#  154893.40207237002,
#  154972.12593428002,
#  154880.21816304003,
#  154112.04857529004,
#  153750.39016953003,
#  154244.63243445003,
#  154009.88138641004,
#  154325.33453900003,
#  153672.44346025004,
#  153040.73701171004,
#  153331.87441047005,
#  153969.90005578005,
#  154485.97279717005,
#  154735.75115294007,
#  154995.32578485008,
#  155524.59572855008,
#  155676.49999108008,
#  155785.88351872007,
#  156929.91913134005,
#  157599.84164409008,
#  157614.07798009008,
#  157607.21946015008,
#  157401.5851075401,
#  156650.3264260201,
#  156677.22726617008,
#  156861.63296320007,
#  156570.75765761005,
#  157237.75080021005,
#  157528.37298811006,
#  158355.18461884008,
#  158928.42102210005,
#  160110.50782283006,
#  160763.93227352004,
#  162305.45202882003,
#  162648.72387711005,
#  162804.55586120006,
#  162744.57212495006,
#  162652.45244606008,
#  162760.49028482006,
#  162806.88686409005,
#  162628.01670075004,
#  162928.56214014004,
#  163121.66670030003,
#  162845.07194639003,
#  162945.32850767003,
#  163190.73350533005,
#  164126.66547849003,
#  164088.94612248003,
#  163958.74001670003,
#  163837.37225738005,
#  163788.14970187005,
#  163682.84095859004,
#  164503.50470772004,
#  164649.41685649005,
#  164304.55520975005,
#  164187.19179143003,
#  164320.36400627,
#  164037.67828871,
#  163413.49544453,
#  164245.76031271002,
#  164760.44104495,
#  165932.42447518,
#  166646.80597955,
#  167633.00792126002,
#  168953.20287451003,
#  169468.42046321003,
#  170606.85208760004,
#  171429.99353598003,
#  172018.37218959004,
#  172294.36258193004,
#  172640.99806253004,
#  172596.79186035003,
#  172175.24426634,
#  171672.38654661,
#  170898.07637693,
#  170508.6790918,
#  170055.30643841,
#  169990.34089535003,
#  169759.24683503003,
#  170065.59672453,
#  169649.47567065002,
#  169535.92841082002,
#  169821.84815132,
#  170121.28885675,
#  172366.15113987,
#  172724.0622559,
#  174614.246071,
#  175055.44983332,
#  174623.7636854,
#  174932.06369599,
#  174923.20730466998,
#  174745.12584902998,
#  175141.08338317997,
#  175065.12990938997,
#  175575.90708262997,
#  175974.99631202,
#  176422.51823907,
#  177159.98631950998,
#  177551.29608303995,
#  177889.54394185994,
#  177998.18292663994,
#  178237.99829549994,
#  177915.52038438994,
#  178625.6221702599,
#  178799.36713462992,
#  178419.14281743992,
#  177539.42469398992,
#  176980.7118610699,
#  177200.08764025988,
#  177458.9201924199,
#  177654.0062590699,
#  178717.7100686299,
#  179797.8021922799,
#  180903.5512077399,
#  182045.48624527987,
#  183413.37648999988,
#  184258.73175275986,
#  184897.61353722986,
#  185546.84148450987,
#  185324.3764181299,
#  184975.2931464699,
#  184857.20291071988,
#  184327.3594396299,
#  183883.0982963899,
#  182802.7512633299,
#  182276.6859257299,
#  181922.7750676499,
#  182069.1770116699,
#  182594.3520137799,
#  182818.1079439899,
#  183048.5897068099,
#  183593.69785719988,
#  183834.20670414987,
#  185116.41182238984,
#  186383.41546630985,
#  187644.81242046985,
#  188401.52027557985,
#  189154.51556929987,
#  190469.03308126988,
#  191301.1313508399,
#  191233.3700034099,
#  192309.70191123988,
#  192481.67766805989,
#  192540.46072167988,
#  192481.82182164988,
#  192656.08345964988,
#  192920.39194500988,
#  193256.1011575799,
#  193266.2691632699,
#  193072.4344330399,
#  193612.3324663199,
#  193766.88190286988,
#  193927.49690920988,
#  195265.8456316699,
#  196144.7363888699,
#  196050.9366551199,
#  196465.6007250799,
#  196210.38033623988,
#  195675.34355062986,
#  195407.90824040986,
#  195612.26022902987,
#  195849.75179611988,
#  196537.73189933988,
#  196964.90263364988,
#  197427.6481493199,
#  197663.34778628987,
#  197771.08918749986,
#  198197.13042862987,
#  197930.05368533987,
#  198638.2555289399,
#  199279.8539713999,
#  199710.0584454799,
#  200729.6622472299,
#  200862.7680003899,
#  201057.48183521986,
#  202002.75966598987,
#  201958.18276350986,
#  202045.16859190987,
#  201904.58292913987,
#  202531.1231921799,
#  202355.37526880988,
#  202480.7620398299,
#  202316.68808312988,
#  202750.0138903799,
#  203331.20003222988,
#  204793.71426799987,
#  204867.80396314987,
#  205083.2862799799,
#  205237.6547380199,
#  205687.1319830599,
#  206248.4507254299,
#  205750.0571908199,
#  205182.6694857399,
#  205096.48496935988,
#  205444.23939383987,
#  205692.17346694987,
#  205697.61508584986,
#  208067.22229770987,
#  208868.7891692799,
#  209072.3242311099,
#  210164.5899161699,
#  210786.29240611993,
#  211175.58902975993,
#  211648.3784066399,
#  211631.6843874799,
#  211548.7282311299,
#  211821.4723229199,
#  212154.7660670899,
#  213188.8257252299,
#  213618.0608065399,
#  214531.6670554899,
#  215430.8168204599,
#  215929.9733909499,
#  216504.2936822899,
#  216587.5125472599,
#  216858.02309281987,
#  216837.45857436987,
#  217007.34736419987,
#  217726.06220945987,
#  218009.57529336988,
#  218641.97497040988,
#  219931.52577859987,
#  220007.44332435986,
#  219628.81492834986,
#  219319.84639923988,
#  218876.4808883599,
#  218182.5146316799,
#  217794.0158805599,
#  217039.1723843499,
#  216854.9456581899,
#  216648.30136115992,
#  217108.50523432993,
#  217657.23002056993,
#  218256.85509282994,
#  218804.93624260993,
#  219402.83427478993,
#  220421.04725779992,
#  221769.52229857992,
#  223081.02724404994,
#  223886.62141886994,
#  224128.45600655995,
#  224764.27089392996,
#  224985.24635566998,
#  226214.9500349,
#  225854.36451935,
#  224933.68162940998,
#  224617.05908814998,
#  224406.11144526998,
#  223221.71411187996,
#  222366.52913019995,
#  221916.32332210994,
#  221489.97341124993,
#  221347.12117368993,
#  221272.29291217992,
#  221990.00512085995,
#  223217.14580776996,
#  224720.86976329997,
#  225986.96290921996,
#  226834.98070474993,
#  227476.20318859993,
#  228780.60860189993,
#  229154.19370552993,
#  229249.58610036992,
#  229067.54180435993,
#  228692.03181902994,
#  227742.66708904994,
#  227013.04718492992,
#  226915.73685661991,
#  227094.0709521399,
#  226066.9784735499,
#  225731.64837049993,
#  226198.67471658994,
#  225937.01542971996,
#  226097.83833015995,
#  226110.73876662995,
#  226871.66592543997,
#  228192.09294605997,
#  228879.58897778997,
#  230454.01374956997,
#  231602.41234107997,
#  233810.68377344997,
#  234307.25483849997,
#  234426.18632284997,
#  234415.05469066996,
#  234666.13261006997,
#  235078.38719742995,
#  234865.71787627993,
#  234356.72603790992,
#  233805.4507140699,
#  233359.7925133499,
#  232917.12712502992,
#  232896.6475399099,
#  232801.46844086988,
#  233394.64142816988,
#  233519.8049628399,
#  233893.6695620799,
#  234911.29779334986,
#  235607.35806620988,
#  236088.6181267899,
#  236526.9136774299,
#  237523.20079627988,
#  237437.1451979199,
#  237600.6132944699,
#  238481.00287131988,
#  238128.46136576988,
#  237995.55639551987,
#  237707.25052228986,
#  237833.29826358985,
#  236655.51148081984,
#  236588.4533972098,
#  236623.88473111982,
#  236504.00845571983,
#  236543.41302041983,
#  237345.57111045983,
#  238514.98285020984,
#  239483.48735511984,
#  240209.69632256986,
#  241251.82775034985,
#  242086.35989782985,
#  242592.59211255985,
#  243364.93944622987,
#  243382.30550235987,
#  243037.07467046985,
#  244455.69856199986,
#  244079.67407736985,
#  243661.57016564984,
#  243119.73656860986,
#  242502.38756503985,
#  242061.39321856986,
#  241095.23832420987,
#  240979.1741451299,
#  241251.45845478988,
#  241329.7858017099,
#  242308.1638168599,
#  243225.77618237986,
#  244156.58970597986,
#  245160.41477044986,
#  246471.72858070984,
#  247240.16057892985,
#  248270.08015798987,
#  249133.15886981986,
#  249485.95263745985,
#  250824.53047359985,
#  250507.73484891985,
#  250514.04333016984,
#  250012.00478664984,
#  250146.43891606983,
#  249403.25142290985,
#  248740.49338926983,
#  248558.75717184984,
#  248481.32139752983,
#  248504.9662850798,
#  247994.3867286098,
#  248097.9398433898,
#  248612.91374066978,
#  249086.82207078979,
#  250101.1208449198,
#  250656.4100679198,
#  251096.4370926398,
#  252075.7688939898,
#  254084.1414844498,
#  254490.10381567982,
#  254686.33097436983,
#  255803.94646719983,
#  255836.06709382983,
#  256029.88939229984,
#  256486.23987135984,
#  256891.37360023984,
#  256411.90072405981,
#  255315.42889763982,
#  254846.65167318983,
#  254849.41001226983,
#  255217.6866628398,
#  256321.0965119098,
#  256409.2812646898,
#  257044.89934861983,
#  257785.1339204898,
#  258935.9578198698,
#  259669.46419166977,
#  260532.21999968978,
#  261426.5023704398,
#  262246.71205412975,
#  263425.7071366197,
#  265062.31995605974,
#  265146.9169292497,
#  265104.7780382497,
#  264550.72461478965,
#  263801.06119022967,
#  263389.98352107964,
#  262449.6333123997,
#  262452.0929254197,
#  262337.14298337966,
#  262489.74576713966,
#  263021.3950143097,
#  264117.7625786097,
#  266943.6666307397,
#  267539.2812988697,
#  269119.0393123197,
#  270526.8701036197,
#  271552.06595373974]

# %%
#绘图 dynamic_regret和dynamic_regret_T

# %%
sub1=plt.subplot(1, 2, 1)##############################################################
iteration=[]
for i in range(0,999):
    iteration.append(i)

#在同一幅图片上画3条折线
A,=plt.plot(iteration,dynamic_regret,color = 'red',linewidth = '1.5',label='attack-free online primal-dual algorithm')


#设置图例并且设置图例的字体及大小
font1 = {
'size'   : 18,
}
#legend = plt.legend(handles=[A],prop=font1)
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=18)
 
#设置横纵坐标的名称以及对应字体格式
font2 = {
'size'   : 18,
}
plt.xlabel('T',font2)
plt.ylabel(r'Dynamic regret $Reg(T)$',font2)
plt.title('varying $D_{t}$',font2) 

sub2=plt.subplot(1, 2, 2)##############################################################
iteration=[]
for i in range(0,999):
    iteration.append(i)

#在同一幅图片上画3条折线
A,=plt.plot(iteration,dynamic_regret_T,color = 'red',linewidth = '1.5',label='attack-free online primal-dual algorithm')


#设置图例并且设置图例的字体及大小
font1 = {
'size'   : 18,
}
#legend = plt.legend(handles=[A],prop=font1)
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=18)
 
#设置横纵坐标的名称以及对应字体格式
font2 = {
'size'   : 18,
}
plt.xlabel('T',font2)
plt.ylabel(r'Dynamic regret $Reg(T)/T$',font2)
plt.title('varying $D_{t}$',font2) 

plt.legend(handles=[A],prop={'size':18},loc="upper center", bbox_to_anchor=[-0.3, -0.2],
           ncol=18, shadow=True, fancybox=True)

plt.subplots_adjust(wspace=0.5,hspace=0.5) 
plt.gcf().set_size_inches((15, 5))

#plt.savefig('./figures/01-figure1_dynamic_regret_attack_free_varying_D.pdf',format='pdf', bbox_inches='tight')
#plt.savefig('./figures/01-figure1_dynamic_regret_attack_free_varying_D.png',format='png', bbox_inches='tight')

# %%
#累计的约束违反

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
from sympy import *
import math 
from datetime import datetime
from scipy.special import gamma, factorial
import scipy.special as sc

# %%
sum_thermal_wind_power_station_strategy=np.loadtxt("./data/04_SCC_optimal_parameters_small_Byzantine_attack_sum_thermal_wind_power_station_strategy.txt")
d_power_demand=np.loadtxt("./data/d_power_demand_normal_distribution_(70,5).txt")

# %%
accumulative_constraint_violation=[]
accumulative_constraint_violation_T=[]
for T in range(1, 1000):
    accumulative_constraint_violation_auxiliary_variable=0
    for t in range(0, T): 
        accumulative_constraint_violation_auxiliary_variable=accumulative_constraint_violation_auxiliary_variable+(1/5)*sum_thermal_wind_power_station_strategy[t+1]-d_power_demand[t+1]
    accumulative_constraint_violation.append(abs(accumulative_constraint_violation_auxiliary_variable))
    accumulative_constraint_violation_T.append(abs(accumulative_constraint_violation_auxiliary_variable)/T)

# %%
accumulative_constraint_violation
# Out:
# [5.161334969999999,
#  3.163107050000008,
#  0.28546707399998184,
#  1.9342130119999865,
#  0.4553738359999784,
#  1.6432709420000293,
#  4.287397336000041,
#  15.180176076000052,
#  21.06605689600005,
#  10.60023743000005,
#  4.562719254000058,
#  12.09285379400005,
#  13.614487632000063,
#  12.39691997400007,
#  18.62619862800007,
#  19.711959022000073,
#  14.064728802000076,
#  7.634000192000087,
#  10.660983024000089,
#  4.953142652000082,
#  2.2076367599999287,
#  7.255771409999937,
#  13.568847307999931,
#  22.665188459999925,
#  17.741903501999936,
#  24.003615867999933,
#  29.650004951999925,
#  22.89056714399991,
#  17.52017963799991,
#  4.314885987999894,
#  10.733665488000128,
#  11.735292660000127,
#  20.99436426800014,
#  28.958280796000153,
#  42.95327030800016,
#  50.48974884000016,
#  53.449062442000155,
#  71.12154670800015,
#  74.80580558800017,
#  69.23193245400017,
#  62.63791541600017,
#  43.68945397200018,
#  30.748840754000184,
#  21.0475589400002,
#  11.927771288000201,
#  7.176292710000197,
#  0.43559224000020436,
#  2.1432546679997984,
#  8.893896303999796,
#  10.396665889999795,
#  7.955354785999802,
#  7.734554087999797,
#  0.6417447840002097,
#  5.247700906000205,
#  4.28338819000021,
#  10.44233809800022,
#  20.425523238000224,
#  44.536302182000234,
#  56.49716346800024,
#  61.78346531400024,
#  74.36048279400023,
#  72.82180495200024,
#  77.13831092000024,
#  78.29208179800025,
#  81.89805746400026,
#  80.15241027000026,
#  76.59922651400026,
#  71.85250021600027,
#  65.03908960400027,
#  65.04239704000028,
#  51.316066796000285,
#  41.2168350000003,
#  34.4641362520003,
#  33.1749244560003,
#  25.375420856000304,
#  25.7516580180003,
#  25.609684738000297,
#  23.154221754000304,
#  20.606183230000298,
#  25.1901951760003,
#  25.330902452000302,
#  34.2352952840003,
#  37.52660689800031,
#  43.59435802200031,
#  46.469828292000315,
#  55.68423467400032,
#  61.47815539400035,
#  69.22872356600035,
#  70.38665411800037,
#  69.90792484400035,
#  72.97537163400035,
#  67.73022446800036,
#  64.30539618000036,
#  47.50298767800038,
#  45.3481268620004,
#  42.123193428000405,
#  48.948811684000404,
#  46.177398886000404,
#  46.94537516400041,
#  56.95058041200042,
#  65.84997082200042,
#  75.20446910600042,
#  78.48965608200042,
#  89.98031115400043,
#  104.75928011000043,
#  103.43080184000044,
#  91.98936946000045,
#  78.49922911600045,
#  74.09553224000047,
#  59.629070094000454,
#  50.68647346400046,
#  43.13423232800045,
#  38.74097368800045,
#  26.861353362000457,
#  26.196191990000457,
#  25.96745103200047,
#  20.65788661800046,
#  26.585426026000462,
#  32.660083730000466,
#  52.30127364000048,
#  68.26683919000048,
#  80.9761053440005,
#  86.06779219200052,
#  95.28786928000052,
#  105.66164562800053,
#  111.09233709600053,
#  111.72882005400052,
#  105.93371494000053,
#  104.04474504400054,
#  105.67895826800054,
#  103.87057481600054,
#  86.67413527000056,
#  85.33313567600058,
#  82.64300965600057,
#  77.00433306200055,
#  75.59800621400056,
#  79.93534869200056,
#  72.41263719600059,
#  69.51201608000059,
#  70.10808459600061,
#  68.22914019800061,
#  69.43742599400063,
#  65.74937375800063,
#  69.94615501000065,
#  76.24823442200065,
#  94.02166475400065,
#  119.63535189800065,
#  140.45754971400066,
#  145.53114630200068,
#  142.69912950800068,
#  138.62507263600065,
#  129.75156224000065,
#  108.79394242600067,
#  85.54318311800066,
#  68.51581256800067,
#  50.78634602600067,
#  38.11069157400068,
#  49.04511192200069,
#  60.1567698820007,
#  77.49830646800072,
#  87.93218136400074,
#  102.73159660600074,
#  117.12880764400074,
#  134.32595237600077,
#  139.45673735800077,
#  140.4940526440008,
#  137.40266139600078,
#  135.96182750400078,
#  127.58964015600078,
#  119.55545623000079,
#  115.87215089600079,
#  110.9083471340008,
#  116.4528233400008,
#  109.11711390600081,
#  107.36611349000081,
#  114.18804896000083,
#  116.99009984200083,
#  118.62397284200081,
#  132.71585532000083,
#  134.3765816180008,
#  131.79367394000082,
#  127.5048957200008,
#  134.59613281000082,
#  134.76604312800083,
#  134.68282599400084,
#  128.16699514600083,
#  122.00526279600084,
#  110.65086560400086,
#  110.69330380800085,
#  113.07664834400083,
#  123.38905093200084,
#  129.24262434800085,
#  129.25557861200087,
#  133.6104438220009,
#  136.09739674200088,
#  139.35287495800088,
#  148.94047909400092,
#  153.58577902600092,
#  160.3002323420009,
#  158.9950052080009,
#  154.02812029800089,
#  153.38313126200092,
#  138.12645419200092,
#  134.44794333800093,
#  125.84862288000093,
#  120.51437524400093,
#  115.33698426400095,
#  120.90790782000096,
#  121.31590688600099,
#  135.531189572001,
#  145.201414778001,
#  149.32538660000102,
#  157.47385905600103,
#  156.66353269800103,
#  160.285730492001,
#  164.293540550001,
#  176.27237623400103,
#  182.15329458400103,
#  176.19588716600103,
#  165.24009481000104,
#  167.13931107800104,
#  167.76878337200105,
#  161.95869586200104,
#  159.64493491400106,
#  155.40486918200108,
#  156.34384940800112,
#  156.10112828200113,
#  149.2271580060011,
#  145.7744349880011,
#  147.07213057800112,
#  135.91441129600113,
#  137.8489966960011,
#  132.03864422200112,
#  121.8177282600011,
#  124.96209948600112,
#  131.19176660000113,
#  133.71872097200114,
#  145.14343755800115,
#  153.08755955000115,
#  164.70040252600114,
#  171.74332182000114,
#  171.42396310400113,
#  171.78383966200116,
#  166.94445146400113,
#  162.22207646400113,
#  160.31756334000113,
#  154.96816474600115,
#  151.94938793400115,
#  148.60823251000116,
#  150.64418737200117,
#  159.1258194120012,
#  157.5193879080012,
#  165.2992019580012,
#  169.20318642200118,
#  174.5648966860012,
#  181.60606801400118,
#  187.53409970000118,
#  189.1069383380012,
#  195.00023396400124,
#  188.78757280400123,
#  192.49702698600123,
#  188.57232129200122,
#  177.1152121180012,
#  171.9754245600012,
#  176.3086653680012,
#  174.67174931400118,
#  167.85208610600114,
#  169.19939403000114,
#  168.27625066000115,
#  177.53962040800116,
#  184.70952872800115,
#  197.24475037400111,
#  201.93081264000114,
#  202.94975513400115,
#  205.05419082200115,
#  198.99825032200113,
#  194.84700155000112,
#  186.8061618720011,
#  180.14765563000108,
#  174.93956305600108,
#  166.52858087000106,
#  166.75031436000106,
#  172.36996299000106,
#  170.06112299200106,
#  167.95244033800105,
#  168.23241512000106,
#  155.32437129200108,
#  162.72345511600108,
#  168.60697250400105,
#  169.16816081600103,
#  179.451981780001,
#  178.635723586001,
#  186.47877030600102,
#  193.26754948400105,
#  200.98985751000106,
#  192.93174770600103,
#  188.76334992400103,
#  198.22215964200106,
#  193.38280804000107,
#  186.25093480000106,
#  186.47832594400109,
#  181.87877123400108,
#  179.5590261620011,
#  168.53345936400112,
#  160.72397501600113,
#  163.84215033200115,
#  166.6055289780012,
#  156.46964861400122,
#  164.51444481000124,
#  182.25967409600122,
#  190.8167820260012,
#  202.07404272000122,
#  214.15406749400123,
#  224.18826229800126,
#  237.37296848400123,
#  238.35078148600127,
#  235.65396167000125,
#  236.74365884200125,
#  235.55737119400123,
#  232.92548520400123,
#  220.93887256400126,
#  203.02213175600127,
#  202.67696861400128,
#  195.18220748200127,
#  191.38797808600128,
#  191.1664546180013,
#  194.90942144400134,
#  205.18393973400137,
#  221.9187647560014,
#  225.47170530000142,
#  230.41716049600143,
#  234.84769485400142,
#  242.2225351700014,
#  243.74152493800142,
#  243.74253103800146,
#  244.54076300600147,
#  231.0997481420015,
#  219.0431061880015,
#  199.30899777800153,
#  187.92947753400153,
#  175.76743726000154,
#  166.03484444600153,
#  167.67752296000154,
#  167.93291476800152,
#  180.6469773360015,
#  192.1933148720015,
#  209.7596685980015,
#  224.3765519240015,
#  235.93767765600148,
#  255.92513177200146,
#  271.6404068720015,
#  286.3110447300015,
#  282.6205041940015,
#  275.7192129800015,
#  271.3894255960015,
#  264.2518050520015,
#  241.24789490200146,
#  223.54969095600143,
#  216.07141821000147,
#  207.78527391600147,
#  207.4582327400015,
#  212.15412377200153,
#  213.9440035740015,
#  213.9275890000015,
#  232.37673891800148,
#  236.0864160300015,
#  247.83028144400146,
#  257.41927180800144,
#  270.3747570880015,
#  278.98976580000146,
#  291.38007526000143,
#  307.9498167600014,
#  316.85397762400146,
#  319.0331303780015,
#  320.55942626200147,
#  316.1235972100015,
#  307.48940347800146,
#  289.52638978600146,
#  272.5184451720015,
#  264.20370879400156,
#  253.27393416800157,
#  240.59829448800156,
#  234.51697155400157,
#  237.18974612200157,
#  243.23512044000157,
#  247.38428486200155,
#  258.1210263540016,
#  263.7196427440016,
#  273.67735308400165,
#  278.48210063400165,
#  289.14607294600165,
#  301.23602449800165,
#  310.89792931000164,
#  318.36129484800165,
#  315.5882027300016,
#  316.68374084000163,
#  306.98653396800165,
#  307.84943464600167,
#  295.4100395960017,
#  282.02992084200173,
#  269.2902272420017,
#  261.42955015200175,
#  263.4517202500017,
#  261.9058554360017,
#  259.8348998820017,
#  265.3672361600017,
#  262.8872276000018,
#  267.2833368160018,
#  267.75838614800176,
#  265.09349016600174,
#  266.05466849400176,
#  271.55827547400173,
#  279.36218403600174,
#  287.30839337000174,
#  295.7221102440018,
#  290.6309936980018,
#  293.91395866800184,
#  286.4194444520018,
#  285.81366591400183,
#  284.98683527600184,
#  287.7869107560018,
#  292.09906208400184,
#  295.87375760600185,
#  293.2133397860019,
#  296.3955941680019,
#  295.52827499600187,
#  294.45740337600193,
#  303.50025624000193,
#  311.3272322140019,
#  311.6851229060019,
#  312.8895062040019,
#  313.9588628520019,
#  303.7962029480019,
#  300.2560678180019,
#  298.5525999560019,
#  296.37081672800196,
#  290.1516076360019,
#  292.85692931000193,
#  299.9699064880019,
#  299.76794451400195,
#  298.61402704800196,
#  311.87371617400197,
#  313.03631194200193,
#  311.568580512002,
#  321.300070670002,
#  322.905307604002,
#  318.20546888000206,
#  313.4776436780021,
#  305.9910032360021,
#  300.5397003640021,
#  302.69672545600207,
#  305.0117089960021,
#  304.42844532600213,
#  316.9517233060021,
#  319.6178319100021,
#  334.3629666360021,
#  338.78424170600215,
#  346.29464193600217,
#  345.09164811000215,
#  351.2480870900022,
#  334.98925700000217,
#  328.08682079400216,
#  322.07813464200217,
#  308.86097966200214,
#  294.63499620600214,
#  283.60868327400215,
#  268.0098119960021,
#  254.1295972920021,
#  256.6224678460021,
#  265.6895547280021,
#  276.3382260700021,
#  288.4788058180022,
#  309.3442424340022,
#  328.35982782000224,
#  340.6341808660022,
#  345.75022364200225,
#  351.27214484800226,
#  353.59643012200223,
#  343.5928565380022,
#  333.47160677800224,
#  326.34295727400223,
#  321.9963589400022,
#  315.29789102400224,
#  303.96241478200227,
#  308.60851062800225,
#  317.6604993680022,
#  325.5434612840022,
#  331.0305014960022,
#  329.52086531800217,
#  333.76824477800216,
#  337.98010068200216,
#  349.74735055200216,
#  358.09316457000216,
#  345.10461113200216,
#  343.35339557000214,
#  335.66862252000215,
#  330.92659323000214,
#  323.4983518780021,
#  321.7766088920021,
#  322.4279778120021,
#  315.8550691800021,
#  313.1960028360021,
#  319.0215219740021,
#  322.63233122000213,
#  329.08804812600215,
#  343.08537757200213,
#  345.69736016800215,
#  339.53728616800214,
#  340.2858837460021,
#  332.96437489000215,
#  335.1152034780022,
#  336.1459530460022,
#  343.4418765400022,
#  341.7958776380022,
#  345.46891008400223,
#  347.1865720020022,
#  349.12086302400223,
#  352.39469176200225,
#  356.9769973260023,
#  363.6581176540023,
#  362.7506286360023,
#  373.2765828600023,
#  365.21619572200234,
#  358.26150420400234,
#  349.16633681000235,
#  353.15762428200236,
#  355.95011632000234,
#  347.49780421800233,
#  345.61058979000234,
#  350.74801585400235,
#  346.60222285000236,
#  352.2601777160024,
#  361.2858931620024,
#  360.92465674200247,
#  355.2496465000024,
#  353.3409772660024,
#  342.7127741820024,
#  341.19555630200244,
#  344.8187484240025,
#  348.6595105680025,
#  353.6968754740025,
#  363.6854800020025,
#  376.78967500600254,
#  384.8968701520026,
#  388.30238369600255,
#  393.0915564120026,
#  396.2729866460026,
#  392.2414868760026,
#  384.5393520880026,
#  375.5870604800026,
#  368.8503141580026,
#  361.89213119800263,
#  355.6626098600027,
#  351.81553242000274,
#  343.93474221600275,
#  348.0054462320028,
#  350.9118309620028,
#  344.6966485100028,
#  347.2210166020028,
#  352.6438428520028,
#  366.2557689120028,
#  375.9350753700028,
#  388.0899440380027,
#  395.74741165000273,
#  406.2135273880028,
#  409.89428931600276,
#  412.0042843920028,
#  410.85845922000277,
#  402.2613652420028,
#  392.1850609900028,
#  377.90014714800276,
#  373.82078385400274,
#  368.99167077800274,
#  373.79537564000276,
#  367.50799239400277,
#  375.4195584560028,
#  383.7632237960028,
#  387.6111817160028,
#  383.25456269000284,
#  388.3150529680028,
#  380.8020394040028,
#  375.40867677600284,
#  383.6875844440028,
#  384.9378759180028,
#  387.40319630800286,
#  390.65663681000285,
#  388.4245309580029,
#  391.62243075000293,
#  389.1677260740029,
#  390.5324810800029,
#  392.8810415980029,
#  389.96034519000295,
#  401.127065204003,
#  402.09236861400296,
#  411.14911261200297,
#  419.213723504003,
#  408.630209930003,
#  418.571929664003,
#  422.769177560003,
#  421.236282594003,
#  421.895070670003,
#  419.801615736003,
#  405.453927214003,
#  397.624900728003,
#  403.293800528003,
#  397.73645421400295,
#  398.644728566003,
#  387.404434280003,
#  376.530457266003,
#  381.32339180000304,
#  392.49551831000304,
#  401.49145763400304,
#  404.792091664003,
#  408.52279010200306,
#  417.10919368400306,
#  419.2310396180031,
#  418.8911401340031,
#  418.9324725100031,
#  416.6433282400031,
#  415.4693065160031,
#  413.8056232520031,
#  407.5605813520031,
#  393.1431266660031,
#  389.7284135800031,
#  392.74108202400316,
#  388.0521824620032,
#  396.2786481360032,
#  401.0882967640032,
#  412.87766377800324,
#  419.84417929800327,
#  426.24943737800334,
#  433.5942928740034,
#  437.2836501480034,
#  442.9671277260034,
#  440.82586580600343,
#  437.47600434000344,
#  434.08879201800346,
#  435.20173371600345,
#  433.4993267560034,
#  428.93137132000345,
#  433.00502232400345,
#  436.4460496580034,
#  430.7819079060034,
#  431.4899592040034,
#  434.24123381000345,
#  440.89220582800345,
#  439.93922571200346,
#  434.82523410400347,
#  432.3629111240035,
#  429.83639793600355,
#  427.7632907000036,
#  425.3858242800036,
#  417.1210874600036,
#  401.61722283000364,
#  399.55173032800366,
#  396.1766341820036,
#  388.14080570400364,
#  374.68248075800363,
#  383.03608816600365,
#  391.0669721060036,
#  409.65922196200364,
#  420.27321899200365,
#  433.9535566440037,
#  454.2781120900037,
#  460.7797907940037,
#  479.86041341400374,
#  494.0222528920038,
#  503.9248956080038,
#  506.14388382800377,
#  511.2505276740037,
#  508.0373014540037,
#  496.3110007940037,
#  481.8441984100037,
#  461.3015027880037,
#  443.5805869320037,
#  432.8359537460037,
#  430.2877301240037,
#  423.3951540000037,
#  429.3543311900037,
#  421.99356140600366,
#  419.73809219800364,
#  424.06951804400364,
#  428.75247113000364,
#  440.2866383540037,
#  443.78203919000373,
#  456.25896949600366,
#  461.01469427600364,
#  454.1036642320036,
#  455.25032920600364,
#  455.05684285600364,
#  447.2562264640037,
#  452.15630484600376,
#  447.12225877800375,
#  448.24692820000377,
#  454.57471457400374,
#  459.88310213400376,
#  473.4055183660038,
#  480.1995179600038,
#  478.5193585240038,
#  477.6491591600038,
#  478.1700475860038,
#  470.7659764040039,
#  463.83108766000385,
#  457.1305096460038,
#  443.4702371020038,
#  427.61800258800383,
#  417.2963287380038,
#  413.5888708100038,
#  417.7004339560038,
#  420.17888924000385,
#  437.86799621600386,
#  455.2782728580038,
#  470.63920871400376,
#  489.54038483600374,
#  499.7680699900037,
#  513.9975236880038,
#  525.0460248300037,
#  535.6889933840037,
#  531.0557571320037,
#  522.7256386660036,
#  511.96352346400363,
#  497.82796659600365,
#  484.7347767060037,
#  465.25541109200367,
#  451.48545204200366,
#  442.17812132400365,
#  432.3953893800036,
#  424.5954477600036,
#  427.1810985000036,
#  430.08044382200364,
#  436.2781300160036,
#  438.6163338360036,
#  455.7584878040036,
#  465.7870435040036,
#  475.1748712620036,
#  484.51515681400355,
#  495.6018928100035,
#  508.6902884080035,
#  511.0879409320035,
#  499.80892543800354,
#  514.7056443340035,
#  517.5775800200036,
#  516.8901273260036,
#  512.1041345540036,
#  509.1680764960036,
#  513.7082496000036,
#  515.4407238900036,
#  514.8476235940036,
#  511.25455640000354,
#  511.6684663380035,
#  509.9295116440035,
#  508.83802181600345,
#  514.4675435620035,
#  513.1300328940034,
#  504.99842336800344,
#  506.79178670600345,
#  497.6012018700035,
#  486.5719661560035,
#  481.71042863000343,
#  479.6972225480034,
#  481.8349821820034,
#  493.87846615200334,
#  496.15387189800333,
#  498.64166112200337,
#  501.6767637800034,
#  498.8360916220034,
#  495.32837143400343,
#  490.9652969520034,
#  498.8478237600034,
#  506.83422747200336,
#  510.4522461900034,
#  525.1395232020034,
#  524.9690409560034,
#  527.7435003800034,
#  538.3000992600034,
#  537.5450300580034,
#  538.6525637180034,
#  535.5706152820035,
#  535.1231634800035,
#  532.1529471240035,
#  529.9886945080035,
#  521.3479991020034,
#  527.8051018080034,
#  537.4526343600035,
#  539.8674632960035,
#  538.3414343300035,
#  540.9540100480035,
#  543.2992650060036,
#  542.1558522700036,
#  546.6675285520037,
#  536.1299913380036,
#  524.4759153280037,
#  516.3258861660038,
#  514.7208978180038,
#  516.6298972880038,
#  510.42088591800376,
#  526.2497988720038,
#  525.7457516280039,
#  528.7361777720039,
#  539.951658676004,
#  543.454863596004,
#  543.3637762860039,
#  533.859498554004,
#  527.946168342004,
#  519.8454552860039,
#  523.604120246004,
#  525.153624882004,
#  539.8090543640039,
#  544.798466032004,
#  556.6251567200039,
#  571.912953088004,
#  577.500443482004,
#  587.067183610004,
#  586.660264650004,
#  586.052529380004,
#  585.165982010004,
#  583.9153875320039,
#  597.971010988004,
#  603.135277326004,
#  616.228360142004,
#  611.186152326004,
#  607.5513369000041,
#  599.9492803580042,
#  593.7096718460042,
#  582.4070394320042,
#  569.2324984860043,
#  555.9488972180043,
#  539.6929170920043,
#  529.9683679360044,
#  524.9720085460043,
#  523.8125703680042,
#  530.7806791280043,
#  539.0231675780044,
#  543.7541232360044,
#  552.3138184840044,
#  569.7724234440045,
#  592.0189541480045,
#  616.0209826000045,
#  629.9765465700045,
#  632.5962719320046,
#  641.5833232780046,
#  645.7254707400047,
#  646.0368526320046,
#  634.7964482540046,
#  616.2951556780047,
#  605.6228130520046,
#  597.6157144460046,
#  570.0819950980047,
#  550.3171067020047,
#  540.0310515320047,
#  530.4188188820046,
#  527.6175163020047,
#  523.5303972960047,
#  532.5807439180047,
#  554.1024901960047,
#  581.8048473420047,
#  603.3776270980046,
#  616.8984495460047,
#  627.5293490860047,
#  642.6167920180047,
#  646.2231549400046,
#  647.6206383480047,
#  642.8460160440047,
#  627.2250739140047,
#  608.7403471920047,
#  593.7555757460048,
#  591.5992374460047,
#  580.9974956900047,
#  562.8704544060048,
#  546.7436770820048,
#  541.9807711400047,
#  536.2220539200047,
#  535.8083557880046,
#  535.4479574860046,
#  543.2633345180046,
#  559.1359181520046,
#  569.5489182080046,
#  597.0421022340046,
#  615.6452219580046,
#  627.5340839840047,
#  626.5767409440047,
#  628.4270889900047,
#  627.8015229040047,
#  632.1984704400048,
#  637.2665175900048,
#  633.2437921380049,
#  622.8087534840049,
#  607.664578100005,
#  598.4642792780049,
#  585.561527888005,
#  584.1315870160049,
#  578.5603640280049,
#  589.7709693800049,
#  590.9051595380049,
#  596.4855930300049,
#  614.1688604600049,
#  618.5874161720049,
#  625.2242479700049,
#  632.5666114400049,
#  638.3430570680049,
#  634.2419973020048,
#  636.7959123140049,
#  637.025123098005,
#  625.577027296005,
#  621.5625587460049,
#  614.761693062005,
#  603.4907297320049,
#  583.0251254580048,
#  577.9166692440049,
#  572.9338174660048,
#  568.4117325780048,
#  568.4800688500048,
#  581.4473117600049,
#  596.1242821120048,
#  611.9296804980048,
#  622.6120729540048,
#  640.2967393740048,
#  654.2787808560048,
#  661.6893247740048,
#  671.5784305680048,
#  671.7639553340049,
#  665.5333585440048,
#  668.4158920220048,
#  655.4324566280047,
#  634.6379999700048,
#  618.1221310640049,
#  601.8149612140048,
#  588.0436893800049,
#  566.7357363700049,
#  559.6853560160049,
#  560.8162463020049,
#  562.049450670005,
#  574.6165398280049,
#  587.6610448500048,
#  601.5478408600048,
#  616.9554391800049,
#  631.6620014180048,
#  643.0881996500048,
#  659.8110693200047,
#  672.0485044460047,
#  675.3778935600047,
#  677.7034770480047,
#  666.5758580240048,
#  665.9446508540047,
#  655.5951763560048,
#  658.0042328680048,
#  641.6330142800048,
#  628.6826450320048,
#  621.7972834120047,
#  616.8771059680047,
#  611.5099876600046,
#  602.5649540360047,
#  601.5186020940047,
#  606.3208616740047,
#  613.4654653500047,
#  620.9758949940048,
#  628.0785139640047,
#  634.7983505280047,
#  645.8817824020048,
#  660.0887164000047,
#  665.7238315780047,
#  663.3005928100047,
#  670.5789102300047,
#  670.1355965200047,
#  663.5882644740047,
#  665.1838600180047,
#  657.6484899260047,
#  647.4967437300047,
#  623.5699460740047,
#  615.5228269220047,
#  607.4726551820046,
#  612.7163443260046,
#  621.4780471540046,
#  617.7070001600046,
#  615.2455377880045,
#  622.5173654300045,
#  639.5086559380045,
#  650.6338755700045,
#  664.2019340060045,
#  678.0885479320045,
#  689.6273645080046,
#  700.9246524960046,
#  707.3380838200046,
#  703.3721761040046,
#  695.8132150440046,
#  683.4482161460046,
#  670.6522221900046,
#  662.4630439920046,
#  646.4595207040046,
#  637.6311426700046,
#  634.2462456980046,
#  626.1262211140046,
#  633.8472181620047,
#  647.7948204380046,
#  668.6850834660046,
#  676.9861970520046,
#  684.7279252840046,
#  704.8487790200046,
#  713.8081973680046]

# %%
#绘图 accumulative_constraint_violation和accumulative_constraint_violation_T

# %%
sub1=plt.subplot(1, 2, 1)##############################################################
iteration=[]
for i in range(0,999):
    iteration.append(i)

#在同一幅图片上画3条折线
A,=plt.plot(iteration,accumulative_constraint_violation,color = 'green',linewidth = '1.5',label='attack-free online primal-dual algorithm')


#设置图例并且设置图例的字体及大小
font1 = {
'size'   : 18,
}
#legend = plt.legend(handles=[A],prop=font1)
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=18)
 
#设置横纵坐标的名称以及对应字体格式
font2 = {
'size'   : 18,
}
plt.xlabel('T',font2)
plt.ylabel(r'Constraint violation $Fit(T)$',font2)
plt.title('varying $D_{t}$',font2) 

sub2=plt.subplot(1, 2, 2)##############################################################
iteration=[]
for i in range(0,999):
    iteration.append(i)

#在同一幅图片上画3条折线
A,=plt.plot(iteration,accumulative_constraint_violation_T,color = 'green',linewidth = '1.5',label='attack-free online primal-dual algorithm')


#设置图例并且设置图例的字体及大小
font1 = {
'size'   : 18,
}
#legend = plt.legend(handles=[A],prop=font1)
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=18)
 
#设置横纵坐标的名称以及对应字体格式
font2 = {
'size'   : 18,
}
plt.xlabel('T',font2)
plt.ylabel(r'Constraint violation $Fit(T)/T$',font2)
plt.title('varying $D_{t}$',font2) 

plt.legend(handles=[A],prop={'size':18},loc="upper center", bbox_to_anchor=[-0.3, -0.2],
           ncol=18, shadow=True, fancybox=True)

plt.subplots_adjust(wspace=0.5,hspace=0.5) 
plt.gcf().set_size_inches((15, 5))


#plt.savefig('./figures/01-figure2_constraint_violation_attack_free_varying_D.pdf',format='pdf', bbox_inches='tight')
#plt.savefig('./figures/01-figure2_constraint_violation_attack_free_varying_D.png',format='png', bbox_inches='tight')
