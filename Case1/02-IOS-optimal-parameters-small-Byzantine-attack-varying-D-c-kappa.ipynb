# %% [raw]
# 观察IOS+decentralized online economic dispatch algorithm在拜占庭攻击下的算法性能
# 实验设置：4个热能发电站 2个风能发电站
# 时变风速服从的Weibull distribution的参数c和kappa
# 时变的需求侧用电需求D
# c的变化：[3,25]间的均匀分布
# kappa的变化：[2，3]间的均匀分布
# D的变化为：均值为70 标准差为5的高斯分布
# 拜占庭攻击：假设一个风力发电站受到拜占庭攻击 向其他发电站发送恶意的对偶变量
# 小值攻击 small-value Byzantine attacks
#
# 加上一个adaptive clipping

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
from sympy import *
import math 
from datetime import datetime
from scipy.special import gamma, factorial
import scipy.special as sc

# %%
#定义变量 
thermal_power_station_strategy=np.zeros(shape=(4,1000)) 
wind_power_station_strategy=np.zeros(shape=(2,1000))
c_wind_speed= np.loadtxt("./data/c_wind_speed_uniform_distribution_(3,25).txt")      
kappa_wind_speed= np.loadtxt("./data/kappa_wind_speed_uniform_distribution_(2,3).txt")  
d_power_demand=np.loadtxt("./data/d_power_demand_normal_distribution_(70,5).txt") #时变的需求侧用电需求  阶梯式变化 
thermal_power_station_dual_variable=np.zeros(shape=(4,1000))
wind_power_station_dual_variable=np.zeros(shape=(2,1000))#两个风力发电站中有一个是受到拜占庭攻击的 假设第二个风力发电站是受到攻击的
E=np.loadtxt("6_Network_Topology_Double_Random_Adjacency_Matrix.txt")
thermal_power_station_cost=np.zeros(shape=(1,1000)) #火力发电成本
wind_power_station_cost=np.zeros(shape=(1,1000)) #风力发电成本
sum_cost=np.zeros(shape=(1,1000)) #总发电成本
#thermal_power_station_eta=[0.0375,0.0375,0.0625,0.035]
thermal_power_station_eta=[0.0675,0.0675,0.0925,0.0625]
thermal_power_station_zeta=[2,1.75,1,3]
thermal_power_station_xi=[0,0,0,0]
thermal_power_station_P_min=[50,20,15,10]
thermal_power_station_P_max=[200,120,80,100]
#wind_power_station_varphi=[3]
wind_power_station_varphi=[1]
wind_power_station_v_in=[3]
wind_power_station_v_out=[25]
wind_power_station_v_r=[13]
wind_power_station_sigma_ue=[5]
wind_power_station_sigma_oe=[30]
wind_power_station_P_r=[160]
wind_power_station_P_min=[0]
wind_power_station_P_max=[160]
sum_thermal_wind_power_station_strategy=np.zeros(shape=(1,1000))
step_size_primal=1
step_size_dual=3
regularization_parameter=0.001

# %%
#火力，风力发电策略初始化
thermal_power_station_strategy[0][0]=70
thermal_power_station_strategy[1][0]=70
thermal_power_station_strategy[2][0]=70
thermal_power_station_strategy[3][0]=70
wind_power_station_strategy[0][0]=70
wind_power_station_strategy[1][0]=0
#初始总发电策略
sum_thermal_wind_power_station_strategy[0][0]=350
#初始化受到攻击的风力发电站的对偶变量
wind_power_station_dual_variable[1][0]=-300

#火力，风力发电对偶初始化
thermal_power_station_dual_variable[0][0]=-70
thermal_power_station_dual_variable[1][0]=-70
thermal_power_station_dual_variable[2][0]=-70
thermal_power_station_dual_variable[3][0]=-70
wind_power_station_dual_variable[0][0]=-70

#安全发电站的初始总发电成本
#火力发电成本
for i in range(0,4):
    thermal_power_station_cost[0][0]=thermal_power_station_cost[0][0]+thermal_power_station_eta[i]*thermal_power_station_strategy[i][0]*thermal_power_station_strategy[i][0]+thermal_power_station_zeta[i]*thermal_power_station_strategy[i][0]
#风力发电成本
for i in range(0,1):
    wind_power_station_cost[0][0]=wind_power_station_cost[0][0]+wind_power_station_varphi[i]*wind_power_station_strategy[i][0]+wind_power_station_sigma_ue[i]*((wind_power_station_P_r[i]-wind_power_station_strategy[i][0])*(math.exp(-(math.pow(wind_power_station_v_r[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0])))-math.exp(-(math.pow(wind_power_station_v_out[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0]))))+(wind_power_station_P_r[i]*wind_power_station_v_in[i]/(wind_power_station_v_r[i]-wind_power_station_v_in[i])+wind_power_station_strategy[i][0])*(math.exp(-(math.pow(wind_power_station_v_r[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0])))-math.exp(-(math.pow(wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][0])/wind_power_station_P_r[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0]))))+(wind_power_station_P_r[i]*c_wind_speed[0]/(wind_power_station_v_r[i]-wind_power_station_v_in[i]))*(sc.gammaincc(1+1/kappa_wind_speed[0],(math.pow(wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][0])/wind_power_station_P_r[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0])))*sc.gamma(1+1/kappa_wind_speed[0])-sc.gammaincc(1+1/kappa_wind_speed[0],math.pow(wind_power_station_v_r[i]/c_wind_speed[0],kappa_wind_speed[0]))*sc.gamma(1+1/kappa_wind_speed[0])))+wind_power_station_sigma_oe[i]*((wind_power_station_strategy[i][0])*(1-math.exp(-(math.pow(wind_power_station_v_in[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0])))+math.exp(-(math.pow(wind_power_station_v_out[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0]))))+(wind_power_station_P_r[i]*wind_power_station_v_in[i]/(wind_power_station_v_r[i]-wind_power_station_v_in[i])+wind_power_station_strategy[i][0])*(math.exp(-(math.pow(wind_power_station_v_in[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0])))-math.exp(-(math.pow(wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][0])/wind_power_station_P_r[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0]))))+(wind_power_station_P_r[i]*c_wind_speed[0]/(wind_power_station_v_r[i]-wind_power_station_v_in[i]))*(sc.gammaincc(1+1/kappa_wind_speed[0],(math.pow(wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][0])/wind_power_station_P_r[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0])))*sc.gamma(1+1/kappa_wind_speed[0])-sc.gammaincc(1+1/kappa_wind_speed[0],math.pow(wind_power_station_v_in[i]/c_wind_speed[0],kappa_wind_speed[0]))*sc.gamma(1+1/kappa_wind_speed[0])))
#发电总成本
sum_cost[0][0]=thermal_power_station_cost[0][0]+wind_power_station_cost[0][0]

#计算每个发电站的邻居发电站
neighbor_robust1_help=[]
for i in range (0,6):
    for j in range (0,6):
        if E[i][j]!=0:
            neighbor_robust1_help.append(j)
        elif E[i][j]==0:
            neighbor_robust1_help.append(99)
neighbor_robust1=np.array(neighbor_robust1_help).reshape(6,6)

#计算安全的发电站的拜占庭邻居用户数量
q_robust1=[]
for i in range(0,6):
    q_robust1_help=0
    for j in range(0,6):
        if neighbor_robust1[i][j]==5:
            q_robust1_help=q_robust1_help+1
    q_robust1.append(q_robust1_help)

# %%
def IOS_Byzantine_attack_decentralized_economic_dispatch(thermal_power_station_strategy,wind_power_station_strategy,c_wind_speed,kappa_wind_speed,d_power_demand,thermal_power_station_dual_variable,wind_power_station_dual_variable,E,thermal_power_station_cost,wind_power_station_cost,thermal_power_station_eta,thermal_power_station_zeta,thermal_power_station_P_min,thermal_power_station_P_max,wind_power_station_varphi,wind_power_station_sigma_ue,wind_power_station_sigma_oe,wind_power_station_P_min,wind_power_station_P_max,sum_thermal_wind_power_station_strategy,step_size_primal,step_size_dual):
    #显示初始化的数据
    #输出初始状态的原变量和对偶变量
    print("***************************attack_free_online_decentralized_economic_dispatch*****************************")
    print("相关变量初始值为：")
    for i in range (0,4):
        print("第",(i+1),"个火力发电站的初始计划发电量为:",thermal_power_station_strategy[i][0])
    for i in range (0,2):
        print("第",(i+5),"个风力发电站的初始计划发电量为:",wind_power_station_strategy[i][0])
    print("****************************************************************************")
    for i in range (0,4):
        print("第",(i+1),"个火力发电站的初始对偶变量为:",thermal_power_station_dual_variable[i][0])
    for i in range (0,1):
        print("第",(i+5),"个风力发电站的初始对偶变量为:",wind_power_station_dual_variable[i][0])
    print("****************************************************************************")
    print("第",(6),"个受到Byzantin攻击的风力发电站的初始对偶变量为:",wind_power_station_dual_variable[1][0])
    print("****************************************************************************")
    print("安全发电站的初始总发电量:",sum_thermal_wind_power_station_strategy[0][0])
    print("*************************")
    print("需求侧平均用电需求:",d_power_demand[0])
    print("****************************************************************************")
    print("风速分布参数c:",c_wind_speed[0])
    print("****************************************************************************")
    print("风速分布参数kappa:",kappa_wind_speed[0])
    print("****************************************************************************")
    print("安全发电站的总发电成本：", sum_cost[0][0])
    print("****************************************************************************")
    print("原变量迭代步长为:",step_size_primal)
    print("*****************************************************************************")
    print("对偶变量迭代步长为:",step_size_dual)
    print("*****************************************************************************")
    
    #开始迭代
    for k in range(1,1000):
        #发电站更新计划发电量和对偶变量
        #对偶变量 先做梯度上升 再做聚合
        #安全发电站的梯度上升
        dual_variable_intermediate=[] #存放当前迭代中6个用户对对偶变量做完梯度下降后得到的中间值
        for i in range(0,4):
            dual_variable_intermediate.append(thermal_power_station_dual_variable[i][k-1]+step_size_dual*((1/6)*thermal_power_station_strategy[i][k-1]-(1/6)*d_power_demand[k-1]-regularization_parameter*thermal_power_station_dual_variable[i][k-1]))
        for j in range(0,1):
            dual_variable_intermediate.append(wind_power_station_dual_variable[j][k-1]+step_size_dual*((1/6)*wind_power_station_strategy[j][k-1]-(1/6)*d_power_demand[k-1]-regularization_parameter*wind_power_station_dual_variable[j][k-1]))
        #受到攻击的风力发电站的对偶值
        dual_variable_intermediate.append(wind_power_station_dual_variable[1][k-1])      
        
        #IOS鲁棒聚合+adaptive clipping 安全的火力发电站的对偶更新
        #在做鲁棒聚合前 对收集到的信息进行adaptive clipping的剪裁操作
        for i in range (0,4):
            u_neighbor_help_robust1=neighbor_robust1[i].tolist()#将用户i的邻居序号存在辅助变量u中
            if i==0 or i==3:
                u_neighbor_help_robust1 = list(set(u_neighbor_help_robust1))
                u_neighbor_help_robust1.remove(99)
            if int(q_robust1[i])==1: #只有具有拜占庭邻居的用户才需要先进行adaptive clipping和后续的IOS聚合操作
                #先进行adaptive clipping
                dual_variable_intermediate_auxiliary=[]
                #注意必须以这样的方式赋值 不能直接写dual_variable_intermediate_auxiliary=dual_variable_intermediate
                #不然在修改变量dual_variable_intermediate_auxiliary的同时也会对dual_variable_intermediate进行修改
                for j in range(len(dual_variable_intermediate)): 
                    dual_variable_intermediate_auxiliary.append(dual_variable_intermediate[j])
                dual_variable_receive=[]
                clipping_C=0
                for j in range(0, len(u_neighbor_help_robust1)):
                    dual_variable_receive.append(dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[j]])
                dual_variable_receive.sort()
                clipping_C=-dual_variable_receive[1] #确定clpping的阈值
                #接下来对大于clipping_C的值进行clipping
                for j in range(0, len(u_neighbor_help_robust1)):
                    if -dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[j]]>clipping_C:
                        dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[j]]=-clipping_C
                #接下来做IOS鲁棒聚合
                dual_variable_weight_average_robust1=0
                h_robust1=0
                for j in range(0,len(u_neighbor_help_robust1)):#计算当前循环中的h值
                    h_robust1=h_robust1+E[i][u_neighbor_help_robust1[j]]
                for j in range(0,len(u_neighbor_help_robust1)):#计算当前循环中的对偶权重平均值
                    dual_variable_weight_average_robust1=dual_variable_weight_average_robust1+(1/h_robust1)*(E[i][u_neighbor_help_robust1[j]]*dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[j]])
                #剔除一个对偶值离权重平均对偶值最远的用户 保留自身的值
                u_neighbor_help_robust1.remove(i)
                neighbor_index_robust1=u_neighbor_help_robust1[0]
                max_distance_roubust1=abs(dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[0]]-dual_variable_weight_average_robust1)
                for j in range(1,len(u_neighbor_help_robust1)):
                    if abs(dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[j]]-dual_variable_weight_average_robust1)>=max_distance_roubust1:
                        max_distance_roubust1=abs(dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[j]]-dual_variable_weight_average_robust1)
                        neighbor_index_robust1=u_neighbor_help_robust1[j]
                u_neighbor_help_robust1.remove(neighbor_index_robust1)
                u_neighbor_help_robust1.append(i)
                #计算剔除q个信息后的权重平均对偶值
                dual_variable_weight_average_robust1=0
                h_robust1=0
                for j in range(0,len(u_neighbor_help_robust1)):
                    h_robust1=h_robust1+E[i][u_neighbor_help_robust1[j]]
                for j in range(0,len(u_neighbor_help_robust1)):
                    dual_variable_weight_average_robust1=dual_variable_weight_average_robust1+(1/h_robust1)*(E[i][u_neighbor_help_robust1[j]]*dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[j]])     
                #诚实用户基于IOS鲁棒聚合后的值进行自身的对偶变量的更新 基于权重平均值
                thermal_power_station_dual_variable[i][k]=dual_variable_weight_average_robust1              
            else: #没有拜占庭邻居的用户直接进行权重聚合即可
                dual_variable_weight_average_robust1=0
                h_robust1=0
                for j in range(0,len(u_neighbor_help_robust1)):#计算当前循环中的h值
                    h_robust1=h_robust1+E[i][u_neighbor_help_robust1[j]]
                for j in range(0,len(u_neighbor_help_robust1)):
                    dual_variable_weight_average_robust1=dual_variable_weight_average_robust1+(1/h_robust1)*(E[i][u_neighbor_help_robust1[j]]*dual_variable_intermediate[u_neighbor_help_robust1[j]])     
                 #诚实用户基于IOS鲁棒聚合后的值进行自身的对偶变量的更新 基于权重平均值
                thermal_power_station_dual_variable[i][k]=dual_variable_weight_average_robust1             

        #聚合 安全的风力发电站的对偶更新
        for i in range(0,1):
            u_neighbor_help_robust1=neighbor_robust1[i+4].tolist()#将用户i的邻居序号存在辅助变量u中
            u_neighbor_help_robust1 = list(set(u_neighbor_help_robust1))
            u_neighbor_help_robust1.remove(99)
            dual_variable_weight_average_robust1=0
            h_robust1=0
            for j in range(0,len(u_neighbor_help_robust1)):
                h_robust1=h_robust1+E[i][u_neighbor_help_robust1[j]]               
            for j in range(0,len(u_neighbor_help_robust1)):
                dual_variable_weight_average_robust1=dual_variable_weight_average_robust1+(1/h_robust1)*(E[i][u_neighbor_help_robust1[j]]*dual_variable_intermediate[u_neighbor_help_robust1[j]])     
            wind_power_station_dual_variable[i][k]=dual_variable_weight_average_robust1
        #受到Byzantine攻击的风力发电站的对偶更新
        wind_power_station_dual_variable[1][k]=wind_power_station_dual_variable[1][k-1]            
        
        #安全的火力发电站计划发电量
        for i in range(0,4):
            thermal_power_station_strategy[i][k]=thermal_power_station_strategy[i][k-1]-step_size_primal*(2*thermal_power_station_eta[i]*thermal_power_station_strategy[i][k-1]+thermal_power_station_zeta[i]+(1/6)*thermal_power_station_dual_variable[i][k-1]) 
            if thermal_power_station_strategy[i][k]<=thermal_power_station_P_min[i]:
                thermal_power_station_strategy[i][k]=thermal_power_station_P_min[i]
            elif thermal_power_station_strategy[i][k]>=thermal_power_station_P_max[i]:
                thermal_power_station_strategy[i][k]=thermal_power_station_P_max[i]
        #安全的风力发电站计划发电量
        for i in range(0,1):
            wind_power_station_strategy[i][k]=wind_power_station_strategy[i][k-1]-step_size_primal*(wind_power_station_varphi[i]+wind_power_station_sigma_oe[i]+(wind_power_station_sigma_ue[i]+wind_power_station_sigma_oe[i])*math.exp(-(math.pow(wind_power_station_v_out[i],kappa_wind_speed[k-1]))/(math.pow(c_wind_speed[k-1],kappa_wind_speed[k-1])))+(-wind_power_station_sigma_ue[i]-wind_power_station_sigma_oe[i])*math.exp(-(math.pow((wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][k-1])/wind_power_station_P_r[i]),kappa_wind_speed[k-1]))/(math.pow(c_wind_speed[k-1],kappa_wind_speed[k-1])))+(1/6)*wind_power_station_dual_variable[i][k-1])
            if wind_power_station_strategy[i][k]<=wind_power_station_P_min[i]:
                wind_power_station_strategy[i][k]=wind_power_station_P_min[i]
            elif wind_power_station_strategy[i][k]>=wind_power_station_P_max[i]:
                wind_power_station_strategy[i][k]=wind_power_station_P_max[i]
        #受到Byzantine攻击的风力发电站的计划发电量
        wind_power_station_strategy[1][k]=wind_power_station_strategy[1][k-1]
        
        #安全发电站的计算总计划发电
        #火力发电量
        for i in range(0,4):
            sum_thermal_wind_power_station_strategy[0][k]=sum_thermal_wind_power_station_strategy[0][k]+thermal_power_station_strategy[i][k]
        #风力发电量
        for i in range(0,1):
            sum_thermal_wind_power_station_strategy[0][k]=sum_thermal_wind_power_station_strategy[0][k]+wind_power_station_strategy[i][k]
        
        #安全发电站的计算总发电成本
        #火力发电成本
        for i in range(0,4):
            thermal_power_station_cost[0][k]=thermal_power_station_cost[0][k]+thermal_power_station_eta[i]*thermal_power_station_strategy[i][k]*thermal_power_station_strategy[i][k]+thermal_power_station_zeta[i]*thermal_power_station_strategy[i][k]
        #风力发电成本
        for i in range(0,1):
            wind_power_station_cost[0][k]=wind_power_station_cost[0][k]+wind_power_station_varphi[i]*wind_power_station_strategy[i][k]+wind_power_station_sigma_ue[i]*((wind_power_station_P_r[i]-wind_power_station_strategy[i][k])*(math.exp(-(math.pow(wind_power_station_v_r[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k])))-math.exp(-(math.pow(wind_power_station_v_out[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k]))))+(wind_power_station_P_r[i]*wind_power_station_v_in[i]/(wind_power_station_v_r[i]-wind_power_station_v_in[i])+wind_power_station_strategy[i][k])*(math.exp(-(math.pow(wind_power_station_v_r[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k])))-math.exp(-(math.pow(wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][k])/wind_power_station_P_r[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k]))))+(wind_power_station_P_r[i]*c_wind_speed[k]/(wind_power_station_v_r[i]-wind_power_station_v_in[i]))*(sc.gammaincc(1+1/kappa_wind_speed[k],(math.pow(wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][k])/wind_power_station_P_r[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k])))*sc.gamma(1+1/kappa_wind_speed[k])-sc.gammaincc(1+1/kappa_wind_speed[k],math.pow(wind_power_station_v_r[i]/c_wind_speed[k],kappa_wind_speed[k]))*sc.gamma(1+1/kappa_wind_speed[k])))+wind_power_station_sigma_oe[i]*((wind_power_station_strategy[i][k])*(1-math.exp(-(math.pow(wind_power_station_v_in[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k])))+math.exp(-(math.pow(wind_power_station_v_out[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k]))))+(wind_power_station_P_r[i]*wind_power_station_v_in[i]/(wind_power_station_v_r[i]-wind_power_station_v_in[i])+wind_power_station_strategy[i][k])*(math.exp(-(math.pow(wind_power_station_v_in[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k])))-math.exp(-(math.pow(wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][k])/wind_power_station_P_r[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k]))))+(wind_power_station_P_r[i]*c_wind_speed[k]/(wind_power_station_v_r[i]-wind_power_station_v_in[i]))*(sc.gammaincc(1+1/kappa_wind_speed[k],(math.pow(wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][k])/wind_power_station_P_r[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k])))*sc.gamma(1+1/kappa_wind_speed[k])-sc.gammaincc(1+1/kappa_wind_speed[k],math.pow(wind_power_station_v_in[i]/c_wind_speed[k],kappa_wind_speed[k]))*sc.gamma(1+1/kappa_wind_speed[k])))
        #发电总成本
        sum_cost[0][k]=thermal_power_station_cost[0][k]+wind_power_station_cost[0][k]
        
        #输出第k次迭代中的结果 每间隔10次迭代输出一次结果
        #if (k+1)%10==0:
        print(k,"次迭代中的结果：")
        for i in range (0,4):
            print("第",(i+1),"个火力发电站的计划发电量为:",thermal_power_station_strategy[i][k])
        for i in range (0,2):
            print("第",(i+5),"个风力发电站的计划发电量为:",wind_power_station_strategy[i][k])
        print("****************************************************************************")
        for i in range (0,4):
            print("第",(i+1),"个火力发电站的对偶变量为:",thermal_power_station_dual_variable[i][k])
        for i in range (0,1):
            print("第",(i+5),"个风力发电站的对偶变量为:",wind_power_station_dual_variable[i][k])
        print("****************************************************************************")
        print("第",(6),"个受到Byzantin攻击的风力发电站的初始对偶变量为:",wind_power_station_dual_variable[1][k])
        print("****************************************************************************")
        print("安全发电站的总发电量:",sum_thermal_wind_power_station_strategy[0][k])
        print("*************************")
        print("需求侧平均用电需求:",d_power_demand[k])
        print("****************************************************************************")
        print("风速分布参数c:",c_wind_speed[k])
        print("****************************************************************************")
        print("风速分布参数kappa:",kappa_wind_speed[k])
        print("****************************************************************************")        
        print("安全发电站的总发电成本：", sum_cost[0][k])
        print("****************************************************************************")
        print("原变量迭代步长为:",step_size_primal)
        print("****************************************************************************")
        print("对偶变量迭代步长为:",step_size_dual)
        print("****************************************************************************")
        
        #step_size_primal=(pow(k+1,0.1))
        #step_size_dual=1/(pow(k+1,0.7))#我们发现在在线算法中 不能使用太小的对偶步长 不然后续算法对在线变化会不敏感 
        
        '''#尝试使用两阶段的步长
        if k<=500:
            step_size_dual=1/(pow(k+1,0.7))
        else:
            step_size_dual=0.1'''

    print(datetime.now().strftime('%Y-%m-%d %H:%M:%S.%f')[:-3])
    return None

# %%
IOS_Byzantine_attack_decentralized_economic_dispatch(thermal_power_station_strategy,wind_power_station_strategy,c_wind_speed,kappa_wind_speed,d_power_demand,thermal_power_station_dual_variable,wind_power_station_dual_variable,E,thermal_power_station_cost,wind_power_station_cost,thermal_power_station_eta,thermal_power_station_zeta,thermal_power_station_P_min,thermal_power_station_P_max,wind_power_station_varphi,wind_power_station_sigma_ue,wind_power_station_sigma_oe,wind_power_station_P_min,wind_power_station_P_max,sum_thermal_wind_power_station_strategy,step_size_primal,step_size_dual)
# Out:
# ***************************attack_free_online_decentralized_economic_dispatch*****************************
# 相关变量初始值为：
# 第 1 个火力发电站的初始计划发电量为: 70.0
# 第 2 个火力发电站的初始计划发电量为: 70.0
# 第 3 个火力发电站的初始计划发电量为: 70.0
# 第 4 个火力发电站的初始计划发电量为: 70.0
# 第 5 个风力发电站的初始计划发电量为: 70.0
# 第 6 个风力发电站的初始计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的初始对偶变量为: -70.0
# 第 2 个火力发电站的初始对偶变量为: -70.0
# 第 3 个火力发电站的初始对偶变量为: -70.0
# 第 4 个火力发电站的初始对偶变量为: -70.0
# 第 5 个风力发电站的初始对偶变量为: -70.0
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的初始总发电量: 350.0
# *************************
# 需求侧平均用电需求: 72.62781256
# ****************************************************************************
# 风速分布参数c: 8.301041
# ****************************************************************************
# 风速分布参数kappa: 2.66836324
# ****************************************************************************
# 安全发电站的总发电成本： 2678.3230777617387
# ****************************************************************************
# 原变量迭代步长为: 1
# *****************************************************************************
# 对偶变量迭代步长为: 3
# *****************************************************************************
# 1 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 70.21666666666667
# 第 2 个火力发电站的计划发电量为: 70.46666666666667
# 第 3 个火力发电站的计划发电量为: 67.71666666666667
# 第 4 个火力发电站的计划发电量为: 69.91666666666667
# 第 5 个风力发电站的计划发电量为: 67.54476648507118
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -71.10390627999999
# 第 2 个火力发电站的对偶变量为: -71.10390627999998
# 第 3 个火力发电站的对偶变量为: -71.10390627999998
# 第 4 个火力发电站的对偶变量为: -71.10390627999999
# 第 5 个风力发电站的对偶变量为: -71.10390627999999
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 345.86143315173786
# *************************
# 需求侧平均用电需求: 64.01095166
# ****************************************************************************
# 风速分布参数c: 14.69554708
# ****************************************************************************
# 风速分布参数kappa: 2.10218816
# ****************************************************************************
# 安全发电站的总发电成本： 2591.3476835205556
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 2 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 70.58806771333333
# 第 2 个火力发电站的计划发电量为: 71.05431771333333
# 第 3 个火力发电站的计划发电量为: 66.03973438
# 第 4 个火力发电站的计划发电量为: 70.02773438
# 第 5 个风力发电站的计划发电量为: 74.70701504539119
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -68.37398254199437
# 第 2 个火力发电站的对偶变量为: -68.67871487595896
# 第 3 个火力发电站的对偶变量为: -68.22905930022614
# 第 4 个火力发电站的对偶变量为: -68.56630848831871
# 第 5 个风力发电站的对偶变量为: -68.37398254199437
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 352.4168692320579
# *************************
# 需求侧平均用电需求: 72.48160172
# ****************************************************************************
# 风速分布参数c: 11.73462138
# ****************************************************************************
# 风速分布参数kappa: 2.30593756
# ****************************************************************************
# 安全发电站的总发电成本： 2569.835981364422
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 3 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 70.45434232903239
# 第 2 个火力发电站的计划发电量为: 71.15843730135983
# 第 3 个火力发电站的计划发电量为: 64.19389340307102
# 第 4 个火力发电站的计划发电量为: 69.70198566388645
# 第 5 个风力发电站的计划发电量为: 79.04272333730967
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -68.92727405227178
# 第 2 个火力发电站的对偶变量为: -70.17487617389746
# 第 3 个火力发电站的对偶变量为: -69.94610005637956
# 第 4 个火力发电站的对偶变量为: -70.53483612687495
# 第 5 个风力发电站的对偶变量为: -68.92727405227178
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 354.5513820346593
# *************************
# 需求侧平均用电需求: 74.35324129
# ****************************************************************************
# 风速分布参数c: 20.88797006
# ****************************************************************************
# 风速分布参数kappa: 2.49450248
# ****************************************************************************
# 安全发电站的总发电成本： 2819.379034187923
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 4 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 70.43088512332497
# 第 2 个火力发电站的计划发电量为: 71.49786096132583
# 第 3 个火力发电站的计划发电量为: 62.97570646623281
# 第 4 个火力发电站的计划发电量为: 69.74504347704647
# 第 5 个风力发电站的计划发电量为: 84.21837666299945
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -70.35899480463773
# 第 2 个火力发电站的对偶变量为: -73.0514554025217
# 第 3 个火力发电站的对偶变量为: -72.68987960696847
# 第 4 个火力发电站的对偶变量为: -73.88718873140564
# 第 5 个风力发电站的对偶变量为: -70.35899480463773
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 358.8678726909295
# *************************
# 需求侧平均用电需求: 73.36237628
# ****************************************************************************
# 风速分布参数c: 17.01236112
# ****************************************************************************
# 风速分布参数kappa: 2.63537814
# ****************************************************************************
# 安全发电站的总发电成本： 2543.302031029031
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 5 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 70.64921476578239
# 第 2 个火力发电站的计划发电量为: 72.27089229863378
# 第 3 个火力发电站的计划发电量为: 62.440180704474486
# 第 4 个火力发电站的计划发电量为: 70.34144449764993
# 第 5 个风力发电站的计划发电量为: 92.87589759250277
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -71.13536293713469
# 第 2 个火力发电站的对偶变量为: -75.40009468069721
# 第 3 个火力发电站的对偶变量为: -74.96669621632165
# 第 4 个火力发电站的对偶变量为: -76.72616574670965
# 第 5 个风力发电站的对偶变量为: -71.13536293713469
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 368.5776298590434
# *************************
# 需求侧平均用电需求: 72.02509011
# ****************************************************************************
# 风速分布参数c: 11.53887689
# ****************************************************************************
# 风速分布参数kappa: 2.44466253
# ****************************************************************************
# 安全发电站的总发电成本： 2671.491223893212
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 6 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 70.96746459525755
# 第 2 个火力发电站的计划发电量为: 73.33100428510109
# 第 3 个火力发电站的计划发电量为: 62.38319664353365
# 第 4 个火力发电站的计划发电量为: 71.33645822656196
# 第 5 个风力发电站的计划发电量为: 94.57097116133818
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -70.50110042866899
# 第 2 个火力发电站的对偶变量为: -76.78704508624813
# 第 3 个火力发电站的对偶变量为: -76.28890536090401
# 第 4 个火力发电站的对偶变量为: -78.59291907364585
# 第 5 个风力发电站的对偶变量为: -70.50110042866899
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 372.5890949117925
# *************************
# 需求侧平均用电需求: 71.92071638
# ****************************************************************************
# 风速分布参数c: 20.17759
# ****************************************************************************
# 风速分布参数kappa: 2.96946266
# ****************************************************************************
# 安全发电站的总发电成本： 2769.8316269113457
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 7 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 71.13704027967594
# 第 2 个火力发电站的计划发电量为: 74.47915955432046
# 第 3 个火力发电站的计划发电量为: 62.557122824630596
# 第 4 个火力发电站的计划发电量为: 72.51822079384935
# 第 5 个风力发电站的计划发电量为: 102.07351773276834
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -70.14845569982717
# 第 2 个火力发电站的对偶变量为: -77.55530209738366
# 第 3 个火力发电站的对偶变量为: -77.00227337353748
# 第 4 个火力发电站的对偶变量为: -79.89471460832692
# 第 5 个风力发电站的对偶变量为: -70.14845569982717
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 382.7650611852447
# *************************
# 需求侧平均用电需求: 72.93331067
# ****************************************************************************
# 风速分布参数c: 12.95856003
# ****************************************************************************
# 风速分布参数kappa: 2.36446438
# ****************************************************************************
# 安全发电站的总发电成本： 2762.3363673471185
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 8 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 71.22494912522421
# 第 2 个火力发电站的计划发电量为: 75.60035669738447
# 第 3 个火力发电站的计划发电量为: 62.81776733099685
# 第 4 个火力发电站的计划发电量为: 73.76922896267267
# 第 5 个风力发电站的计划发电量为: 104.42535956241092
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -69.477881591836
# 第 2 个火力发电站的对偶变量为: -78.42051061269683
# 第 3 个火力发电站的对偶变量为: -77.81943853190012
# 第 4 个火力发电站的对偶变量为: -81.06073830539506
# 第 5 个风力发电站的对偶变量为: -69.477881591836
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 387.83766167868913
# *************************
# 需求侧平均用电需求: 65.05998342
# ****************************************************************************
# 风速分布参数c: 4.42860238
# ****************************************************************************
# 风速分布参数kappa: 2.42410411
# ****************************************************************************
# 安全发电站的总发电成本： 4638.594329788487
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 9 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 71.1892279252916
# 第 2 个火力发电站的计划发电量为: 76.71439364535371
# 第 3 个火力发电站的计划发电量为: 63.16638679674578
# 第 4 个火力发电站的计划发电量为: 75.05819839323776
# 第 5 个风力发电站的计划发电量为: 85.06294871514729
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -64.9437256686716
# 第 2 个火力发电站的对偶变量为: -74.78257914584135
# 第 3 个火力发电站的对偶变量为: -74.13902072154809
# 第 4 个火力发电站的对偶变量为: -77.74530757544002
# 第 5 个风力发电站的对偶变量为: -64.9437256686716
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 371.19115547577616
# *************************
# 需求侧平均用电需求: 65.89481815
# ****************************************************************************
# 风速分布参数c: 13.39240335
# ****************************************************************************
# 风速分布参数kappa: 2.3728007
# ****************************************************************************
# 安全发电站的总发电成本： 2683.12067200018
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 10 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 70.40263643348916
# 第 2 个火力发电站的计划发电量为: 77.07171369420452
# 第 3 个火力发电站的计划发电量为: 62.83710869293916
# 第 4 个火力发电站的计划发电量为: 75.63347485665638
# 第 5 个风力发电站的计划发电量为: 89.79877589948536
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -63.797162840806436
# 第 2 个火力发电站的对偶变量为: -71.1484292527776
# 第 3 个火力发电站的对偶变量为: -70.46705417774609
# 第 4 个火力发电站的对偶变量为: -74.27348885229348
# 第 5 个风力发电站的对偶变量为: -63.797162840806436
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 375.74370957677456
# *************************
# 需求侧平均用电需求: 82.22889118
# ****************************************************************************
# 风速分布参数c: 3.71616054
# ****************************************************************************
# 风速分布参数kappa: 2.52674506
# ****************************************************************************
# 安全发电站的总发电成本： 4462.064708758821
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 11 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 69.53114098843587
# 第 2 个火力发电站的计划发电量为: 76.77510388761651
# 第 3 个火力发电站的计划发电量为: 61.95675261436976
# 第 4 个火力发电站的计划发电量为: 75.55820530828991
# 第 5 个风力发电站的计划发电量为: 69.43980685512474
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -69.37117059400688
# 第 2 个火力发电站的对偶变量为: -76.33936669875398
# 第 3 个火力发电站的对偶变量为: -75.62403652643994
# 第 4 个火力发电站的对偶变量为: -78.8359009584307
# 第 5 个风力发电站的对偶变量为: -69.37117059400688
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 353.2610096538368
# *************************
# 需求侧平均用电需求: 72.39439433
# ****************************************************************************
# 风速分布参数c: 22.04759493
# ****************************************************************************
# 风速分布参数kappa: 2.67853757
# ****************************************************************************
# 安全发电站的总发电成本： 2914.2016710306143
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 12 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 69.70629872066483
# 第 2 个火力发电站的计划发电量为: 77.38369264591394
# 第 3 个火力发电站的计划发电量为: 62.09875946845135
# 第 4 个火力发电站的计划发电量为: 76.25274647115879
# 第 5 个风力发电站的计划发电量为: 74.5808519059536
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -73.03438811472284
# 第 2 个火力发电站的对偶变量为: -76.85551245452203
# 第 3 个火力发电站的对偶变量为: -73.88455751028158
# 第 4 个火力发电站的对偶变量为: -79.07377206313086
# 第 5 个风力发电站的对偶变量为: -73.03438811472284
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 360.0223492121425
# *************************
# 需求侧平均用电需求: 59.43051398
# ****************************************************************************
# 风速分布参数c: 22.07798354
# ****************************************************************************
# 风速分布参数kappa: 2.67292298
# ****************************************************************************
# 安全发电站的总发电成本： 2970.51493791186
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 13 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 70.46834641249555
# 第 2 个火力发电站的计划发电量为: 77.99614621446923
# 第 3 个火力发电站的计划发电量为: 61.92458188516811
# 第 4 个火力发电站的计划发电量为: 76.90011517278575
# 第 5 个风力发电站的计划发电量为: 80.06346309250489
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -67.8214555509199
# 第 2 个火力发电站的对偶变量为: -70.35212612456871
# 第 3 个火力发电站的对偶变量为: -69.83207895686608
# 第 4 个火力发电站的对偶变量为: -71.51306112877853
# 第 5 个风力发电站的对偶变量为: -67.8214555509199
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 367.3526527774235
# *************************
# 需求侧平均用电需求: 66.57067559
# ****************************************************************************
# 风速分布参数c: 24.23535384
# ****************************************************************************
# 风速分布参数kappa: 2.6829301
# ****************************************************************************
# 安全发电站的总发电成本： 3204.798519107151
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 14 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 70.25869557196197
# 第 2 个火力发电站的计划发电量为: 77.44202082961067
# 第 3 个火力发电站的计划发电量为: 61.10721406255636
# 第 4 个火力发电站的计划发电量为: 76.20644429765062
# 第 5 个风力发电站的计划发电量为: 81.81674369942839
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -65.21399796362164
# 第 2 个火力发电站的对偶变量为: -68.42408539751594
# 第 3 个火力发电站的对偶变量为: -65.12793435115543
# 第 4 个火力发电站的对偶变量为: -69.4548464032396
# 第 5 个风力发电站的对偶变量为: -65.21399796362164
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 366.831118461208
# *************************
# 需求侧平均用电需求: 69.25657964
# ****************************************************************************
# 风速分布参数c: 14.77327144
# ****************************************************************************
# 风速分布参数kappa: 2.06624199
# ****************************************************************************
# 安全发电站的总发电成本： 2758.6540954013135
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 15 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 69.64277133035071
# 第 2 个火力发电站的计划发电量为: 76.64136225053255
# 第 3 个火力发电站的计划发电量为: 59.657035186176
# 第 4 个火力发电站的计划发电量为: 75.25644649431756
# 第 5 个风力发电站的计划发电量为: 86.0737732538644
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -63.611371852824604
# 第 2 个火力发电站的对偶变量为: -66.74808010796909
# 第 3 个火力发电站的对偶变量为: -66.20573113126845
# 第 4 个火力发电站的对偶变量为: -67.62051171320803
# 第 5 个风力发电站的对偶变量为: -63.611371852824604
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 367.27138851524126
# *************************
# 需求侧平均用电需求: 62.4132554
# ****************************************************************************
# 风速分布参数c: 22.01070443
# ****************************************************************************
# 风速分布参数kappa: 2.82899266
# ****************************************************************************
# 安全发电站的总发电成本： 2968.610576026025
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 16 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 68.84289250955746
# 第 2 个火力发电站的计划发电量为: 75.6694583647055
# 第 3 个火力发电站的计划发电量为: 58.65477219861152
# 第 4 个火力发电站的计划发电量为: 74.11947596806253
# 第 5 个风力发电站的计划发电量为: 90.12536876633608
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -58.768938633428014
# 第 2 个火力发电站的对偶变量为: -63.39759415861402
# 第 3 个火力发电站的对偶变量为: -62.51410064723538
# 第 4 个火力发电站的对偶变量为: -64.64700859285219
# 第 5 个风力发电站的对偶变量为: -58.768938633428014
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 367.4119678072731
# *************************
# 需求侧平均用电需求: 68.27939592
# ****************************************************************************
# 风速分布参数c: 24.26368821
# ****************************************************************************
# 风速分布参数kappa: 2.29481562
# ****************************************************************************
# 安全发电站的总发电成本： 3224.6811048484647
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 17 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 67.34392512633853
# 第 2 个火力发电站的计划发电量为: 74.27034717857259
# 第 3 个火力发电站的计划发电量为: 57.22265611640762
# 第 4 个火力发电站的计划发电量为: 72.62904290419675
# 第 5 个风力发电站的计划发电量为: 88.80788189887383
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -57.09407031053543
# 第 2 个火力发电站的对偶变量为: -63.083963678813305
# 第 3 个火力发电站的对偶变量为: -62.236574784124144
# 第 4 个火力发电站的对偶变量为: -64.73636621737066
# 第 5 个风力发电站的对偶变量为: -57.09407031053543
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 360.2738532243893
# *************************
# 需求侧平均用电需求: 74.37551359
# ****************************************************************************
# 风速分布参数c: 17.54487156
# ****************************************************************************
# 风速分布参数kappa: 2.9754401
# ****************************************************************************
# 安全发电站的总发电成本： 2466.302615509831
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 18 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 65.76817361937206
# 第 2 个火力发电站的计划发电量为: 73.00784425593417
# 第 3 个火力发电站的计划发电量为: 56.0092271988929
# 第 4 个火力发电站的计划发电量为: 71.33980691073393
# 第 5 个风力发电站的计划发电量为: 96.44550965703222
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -59.68074347382042
# 第 2 个火力发电站的对偶变量为: -66.35115775176354
# 第 3 个火力发电站的对偶变量为: -65.49793566253271
# 第 4 个火力发电站的对偶变量为: -68.39305037640304
# 第 5 个风力发电站的对偶变量为: -59.68074347382042
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 362.5705616419653
# *************************
# 需求侧平均用电需求: 76.41692674
# ****************************************************************************
# 风速分布参数c: 4.81637973
# ****************************************************************************
# 风速分布参数kappa: 2.19682287
# ****************************************************************************
# 安全发电站的总发电成本： 4037.6144616958572
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 19 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 64.83626075972691
# 第 2 个火力发电站的计划发电量为: 72.46031157334365
# 第 3 个火力发电站的计划发电量为: 55.56384277751983
# 第 4 个火力发电站的计划发电量为: 70.82117277629268
# 第 5 个风力发电站的计划发电量为: 76.04900266544352
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -62.93628868882466
# 第 2 个火力发电站的对偶变量为: -71.22031443468614
# 第 3 个火力发电站的对偶变量为: -70.37046486740198
# 第 4 个火力发电站的对偶变量为: -73.45720856893193
# 第 5 个风力发电站的对偶变量为: -62.93628868882466
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 339.73059055232665
# *************************
# 需求侧平均用电需求: 63.07056204
# ****************************************************************************
# 风速分布参数c: 22.76341842
# ****************************************************************************
# 风速分布参数kappa: 2.30087244
# ****************************************************************************
# 安全发电站的总发电成本： 2819.2860356553592
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 20 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 64.57274700530122
# 第 2 个火力发电站的计划发电量为: 72.79822191672328
# 第 3 个火力发电站的计划发电量为: 56.012942674912324
# 第 4 个火力发电站的计划发电量为: 71.21139427407809
# 第 5 个风力发电站的计划发电量为: 77.60006119638317
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -63.261943028078264
# 第 2 个火力发电站的对偶变量为: -69.37943946853518
# 第 3 个火力发电站的对偶变量为: -68.53489120416523
# 第 4 个火力发电站的对偶变量为: -71.96220674243162
# 第 5 个风力发电站的对偶变量为: -63.261943028078264
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 342.19536706739814
# *************************
# 需求侧平均用电需求: 72.76413739
# ****************************************************************************
# 风速分布参数c: 7.10546984
# ****************************************************************************
# 风速分布参数kappa: 2.49300975
# ****************************************************************************
# 安全发电站的总发电成本： 2833.935130847717
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 21 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 64.39908333093193
# 第 2 个火力发电站的计划发电量为: 72.78370186938817
# 第 3 个火力发电站的计划发电量为: 56.073030147414414
# 第 4 个火力发电站的计划发电量为: 71.30367111355693
# 第 5 个风力发电站的计划发电量为: 66.85551973411792
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -67.40197800206806
# 第 2 个火力发电站的对偶变量为: -72.81720917579683
# 第 3 个火力发电站的对偶变量为: -71.97825084231587
# 第 4 个火力发电站的对偶变量为: -74.91251580628541
# 第 5 个风力发电站的对偶变量为: -67.40197800206806
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 331.4150061954094
# *************************
# 需求侧平均用电需求: 72.47977434
# ****************************************************************************
# 风速分布参数c: 20.89161523
# ****************************************************************************
# 风速分布参数kappa: 2.7421258
# ****************************************************************************
# 安全发电站的总发电成本： 2589.308611108875
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 22 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 64.9388700816008
# 第 2 个火力发电站的计划发电量为: 73.34410364632024
# 第 3 个火力发电站的计划发电量为: 56.69589471052873
# 第 4 个火力发电站的计划发电量为: 71.87613152540987
# 第 5 个风力发电站的计划发电量为: 73.45194529655888
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -72.69506112209774
# 第 2 个火力发电站的对偶变量为: -76.14904904636334
# 第 3 个火力发电站的对偶变量为: -73.10166326495624
# 第 4 个火力发电站的对偶变量为: -77.95574891684453
# 第 5 个风力发电站的对偶变量为: -72.69506112209774
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 340.3069452604185
# *************************
# 需求侧平均用电需求: 72.35827036
# ****************************************************************************
# 风速分布参数c: 4.73395435
# ****************************************************************************
# 风速分布参数kappa: 2.61322499
# ****************************************************************************
# 安全发电站的总发电成本： 3399.204539625124
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 23 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 66.28796614093432
# 第 2 个火力发电站的计划发电量为: 74.3841578284609
# 第 3 个火力发电站的计划发电量为: 57.39076473324029
# 第 4 个火力发电站的计划发电量为: 72.88423990420773
# 第 5 个风力发电站的计划发电量为: 55.69619307640999
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -75.65559139617375
# 第 2 个火力发电站的对偶变量为: -78.5090137762547
# 第 3 个火力发电站的对偶变量为: -77.92169590471771
# 第 4 个火力发电站的对偶变量为: -79.53471967076767
# 第 5 个风力发电站的对偶变量为: -75.65559139617375
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 326.64332168325325
# *************************
# 需求侧平均用电需求: 71.12392002
# ****************************************************************************
# 风速分布参数c: 18.17359002
# ****************************************************************************
# 风速分布参数kappa: 2.07787691
# ****************************************************************************
# 安全发电站的总发电成本： 2564.5323524069227
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 24 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 67.9483559446038
# 第 2 个火力发电站的计划发电量为: 75.67713215099447
# 第 3 个火力发电站的计划发电量为: 58.76042257504378
# 第 4 个火力发电站的计划发电量为: 74.02949652797638
# 第 5 个风力发电站的计划发电量为: 63.39961462839486
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -80.36056167891229
# 第 2 个火力发电站的对偶变量为: -81.99758766656583
# 第 3 个火力发电站的对偶变量为: -79.62792606351933
# 第 4 个火力发电站的对偶变量为: -81.92370008935929
# 第 5 个风力发电站的对偶变量为: -80.36056167891229
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 339.8150218270133
# *************************
# 需求侧平均用电需求: 76.7139357
# ****************************************************************************
# 风速分布参数c: 4.48706041
# ****************************************************************************
# 风速分布参数kappa: 2.43670989
# ****************************************************************************
# 安全发电站的总发电成本： 3289.0827327635984
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 25 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 70.16875483856766
# 第 2 个火力发电站的计划发电量为: 77.37698392170452
# 第 3 个火力发电站的计划发电量为: 60.161065409247236
# 第 4 个火力发电站的计划发电量为: 75.42975947687255
# 第 5 个风力发电站的计划发电量为: 47.68649164708188
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -85.44868202688096
# 第 2 个火力发电站的对偶变量为: -86.47677920797776
# 第 3 个火力发电站的对偶变量为: -84.61154557296157
# 第 4 个火力发电站的对偶变量为: -86.07480588312461
# 第 5 个风力发电站的对偶变量为: -85.44868202688096
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 330.82305529347383
# *************************
# 需求侧平均用电需求: 61.05044826
# ****************************************************************************
# 风速分布参数c: 11.55331759
# ****************************************************************************
# 风速分布参数kappa: 2.5075835
# ****************************************************************************
# 安全发电站的总发电成本： 2477.4168768132236
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 26 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 72.93741993984119
# 第 2 个火力发电站的计划发电量为: 79.59388762693737
# 第 3 个火力发电站的计划发电量为: 62.13319257069676
# 第 4 个火力发电站的计划发电量为: 77.34684052278425
# 第 5 个风力发电站的计划发电量为: 59.78462503512705
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -84.13404698822464
# 第 2 个火力发电站的对偶变量为: -83.3253034927077
# 第 3 个火力发电站的对偶变量为: -82.57549001247241
# 第 4 个火力发电站的对偶变量为: -80.05305028076353
# 第 5 个风力发电站的对偶变量为: -84.13404698822464
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 351.7959656953866
# *************************
# 需求侧平均用电需求: 76.57534104
# ****************************************************************************
# 风速分布参数c: 11.11125981
# ****************************************************************************
# 风速分布参数kappa: 2.9635753
# ****************************************************************************
# 安全发电站的总发电成本： 2572.050971582308
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 27 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 75.11320941266673
# 第 2 个火力发电站的计划发电量为: 80.98626337941877
# 第 3 个火力发电站的计划发电量为: 63.40113361386326
# 第 4 个火力发电站的计划发电量为: 78.02066050423014
# 第 5 个风力发电站的计划发电量为: 70.69994288685794
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -87.52751817602137
# 第 2 个火力发电站的对偶变量为: -89.01921689293317
# 第 3 个火力发电站的对偶变量为: -88.13224094978585
# 第 4 个火力发电站的对偶变量为: -82.54802374046467
# 第 5 个风力发电站的对偶变量为: -87.52751817602137
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 368.22120979703686
# *************************
# 需求侧平均用电需求: 79.54768147
# ****************************************************************************
# 风速分布参数c: 13.22114577
# ****************************************************************************
# 风速分布参数kappa: 2.23501543
# ****************************************************************************
# 安全发电站的总发电成本： 2780.560422969079
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 28 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 77.56084583796029
# 第 2 个火力发电站的计划发电量为: 83.13965397201943
# 第 3 个火力发电站的计划发电量为: 65.36063072026286
# 第 4 个火力发电站的计划发电量为: 79.02608189794549
# 第 5 个风力发电站的计划发电量为: 80.32589611055693
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -91.0234825047308
# 第 2 个火力发电站的对偶变量为: -92.68214378155697
# 第 3 个火力发电站的对偶变量为: -91.80344935183922
# 第 4 个火力发电站的对偶变量为: -87.60656078734132
# 第 5 个风力发电站的对偶变量为: -91.0234825047308
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 385.413108538745
# *************************
# 需求侧平均用电需求: 70.77558923
# ****************************************************************************
# 风速分布参数c: 16.55283022
# ****************************************************************************
# 风速分布参数kappa: 2.00468584
# ****************************************************************************
# 安全发电站的总发电成本： 3076.5282736616964
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 29 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 80.26071206729078
# 第 2 个火力发电站的计划发电量为: 85.61282464938964
# 第 3 个火力发电站的计划发电量为: 67.56948892898744
# 第 4 个火力发电站的计划发电量为: 80.74891512525919
# 第 5 个风力发电站的计划发电量为: 88.63439436139154
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -88.00677941532305
# 第 2 个火力发电站的对偶变量为: -89.9811358615734
# 第 3 个火力发电站的对偶变量为: -86.64252472215773
# 第 4 个火力发电站的对偶变量为: -86.78737315203622
# 第 5 个风力发电站的对偶变量为: -88.00677941532305
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 402.8263351323186
# *************************
# 需求侧平均用电需求: 75.70722657
# ****************************************************************************
# 风速分布参数c: 7.5123474
# ****************************************************************************
# 风速分布参数kappa: 2.84390111
# ****************************************************************************
# 安全发电站的总发电成本： 3536.858722307527
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 30 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 82.09331250742703
# 第 2 个火力发电站的计划发电量为: 87.30194929865094
# 第 3 个火力发电站的计划发电量为: 68.50955426415105
# 第 4 个火力发电站的计划发电量为: 82.11986292660782
# 第 5 个风力发电站的计划发电量为: 80.59627021863952
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -85.04756265242301
# 第 2 个火力发电站的对偶变量为: -87.27873593944982
# 第 3 个火力发电站的对偶变量为: -84.6078854807347
# 第 4 个火力发电站的对偶变量为: -85.83826424253968
# 第 5 个风力发电站的对偶变量为: -85.04756265242301
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 400.62094921547634
# *************************
# 需求侧平均用电需求: 67.43684589
# ****************************************************************************
# 风速分布参数c: 6.9741147
# ****************************************************************************
# 风速分布参数kappa: 2.01470627
# ****************************************************************************
# 安全发电站的总发电成本： 3694.558144483766
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 31 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 83.18530909432822
# 第 2 个火力发电站的计划发电量为: 88.31264213324137
# 第 3 个火力发电站的计划发电量为: 68.93660097207223
# 第 4 个火力发电站的计划发电量为: 83.16125743453846
# 第 5 个风力发电站的计划发电量为: 73.01918656177705
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -78.76417389639661
# 第 2 个火力发电站的对偶变量为: -79.17244823072807
# 第 3 个火力发电站的对偶变量为: -78.42429716296017
# 第 4 个火力发电站的对偶变量为: -81.42693620165338
# 第 5 个风力发电站的对偶变量为: -78.76417389639661
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 396.61499619595736
# *************************
# 需求侧平均用电需求: 64.79238622
# ****************************************************************************
# 风速分布参数c: 23.88060792
# ****************************************************************************
# 风速分布参数kappa: 2.21015256
# ****************************************************************************
# 安全发电站的总发电成本： 3611.8690688748275
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 32 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 83.08265468266
# 第 2 个火力发电站的计划发电量为: 87.83584348370846
# 第 3 个火力发电站的计划发电量为: 68.25404598606556
# 第 4 个火力发电站的计划发电量为: 83.33725628883005
# 第 5 个风力发电站的计划发电量为: 75.92043223628397
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -71.62533770616828
# 第 2 个火力发电站的对偶变量为: -73.82976361003911
# 第 3 个火力发电站的对偶变量为: -73.31544361562092
# 第 4 个火力发电站的对偶变量为: -74.35176099848827
# 第 5 个风力发电站的对偶变量为: -71.62533770616828
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 398.430232677548
# *************************
# 需求侧平均用电需求: 79.20664696
# ****************************************************************************
# 风速分布参数c: 15.04406637
# ****************************************************************************
# 风速分布参数kappa: 2.84368377
# ****************************************************************************
# 安全发电站的总发电成本： 3023.4040256793774
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 33 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 81.80405258486229
# 第 2 个火力发电站的计划发电量为: 86.53296521508099
# 第 3 个火力发电站的计划发电量为: 66.84628808124693
# 第 4 个火力发电站的计划发电量为: 82.31205941914101
# 第 5 个风力发电站的计划发电量为: 86.4366020374002
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -72.11755213252778
# 第 2 个火力发电站的对偶变量为: -72.84623638624977
# 第 3 个火力发电站的对偶变量为: -71.81533397354016
# 第 4 个火力发电站的对偶变量为: -75.7824849028208
# 第 5 个风力发电站的对偶变量为: -72.11755213252778
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 403.9319673377314
# *************************
# 需求侧平均用电需求: 71.90639999
# ****************************************************************************
# 风速分布参数c: 19.92973653
# ****************************************************************************
# 风速分布参数kappa: 2.02497384
# ****************************************************************************
# 安全发电站的总发电成本： 3452.873487269695
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 34 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 80.78009750799384
# 第 2 个火力发电站的计划发电量为: 85.24205430875335
# 第 3 个火力发电站的计划发电量为: 65.4489471151396
# 第 4 个火力发电站的计划发电量为: 81.65346614221852
# 第 5 个风力发电站的计划发电量为: 89.67670992266665
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -67.29778267670224
# 第 2 个火力发电站的对偶变量为: -70.71595028811295
# 第 3 个火力发电站的对偶变量为: -67.62670364271546
# 第 4 个火力发电站的对偶变量为: -72.5109569929687
# 第 5 个风力发电站的对偶变量为: -67.29778267670224
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 402.80127499677195
# *************************
# 需求侧平均用电需求: 72.83572783
# ****************************************************************************
# 风速分布参数c: 18.72716024
# ****************************************************************************
# 风速分布参数kappa: 2.20984039
# ****************************************************************************
# 安全发电站的总发电成本： 3278.7347731944346
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 35 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 79.09108145719838
# 第 2 个火力发电站的计划发电量为: 83.77036869175714
# 第 3 个火力发电站的计划发电量为: 63.61200917262468
# 第 4 个火力发电站的计划发电量为: 80.53194237326932
# 第 5 个风力发电站的计划发电量为: 93.87782353501916
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -63.52011329740433
# 第 2 个火力发电站的对偶变量为: -67.86511262953925
# 第 3 个火力发电站的对偶变量为: -67.10771544161197
# 第 4 个火力发电站的对偶变量为: -69.73178864200312
# 第 5 个风力发电站的对偶变量为: -63.52011329740433
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 400.8832252298687
# *************************
# 需求侧平均用电需求: 66.23133285
# ****************************************************************************
# 风速分布参数c: 6.39076728
# ****************************************************************************
# 风速分布参数kappa: 2.33880209
# ****************************************************************************
# 安全发电站的总发电成本： 3942.6737275061896
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 36 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 77.000471010044
# 第 2 个火力发电站的计划发电量为: 82.02222102329313
# 第 3 个火力发电站的计划发电量为: 62.02840671595778
# 第 4 个火力发电站的计划发电量为: 79.08741435027784
# 第 5 个风力发电站的计划发电量为: 77.53668616714734
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -57.207049817521174
# 第 2 个火力发电站的对偶变量为: -63.366683360375774
# 第 3 个火力发电站的对偶变量为: -62.33067727557547
# 第 4 个火力发电站的对偶变量为: -65.71158316437862
# 第 5 个风力发电站的对偶变量为: -57.207049817521174
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ...
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 988 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 66.93520638431573
# 第 2 个火力发电站的计划发电量为: 71.7193814278885
# 第 3 个火力发电站的计划发电量为: 53.05733078048402
# 第 4 个火力发电站的计划发电量为: 67.84699264063953
# 第 5 个风力发电站的计划发电量为: 23.819097331508644
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -77.54278424836846
# 第 2 个火力发电站的对偶变量为: -76.24716828315674
# 第 3 个火力发电站的对偶变量为: -75.25430023662845
# 第 4 个火力发电站的对偶变量为: -73.38900320821202
# 第 5 个风力发电站的对偶变量为: -77.54278424836846
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 283.3780085648364
# *************************
# 需求侧平均用电需求: 63.41616792
# ****************************************************************************
# 风速分布参数c: 7.46037989
# ****************************************************************************
# 风速分布参数kappa: 2.06906595
# ****************************************************************************
# 安全发电站的总发电成本： 2091.6793920980667
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 989 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 68.82275089716119
# 第 2 个火力发电站的计划发电量为: 72.99512631564967
# 第 3 个火力发电站的计划发电量为: 54.78410795886589
# 第 4 个火力发电站的计划发电量为: 68.59761909526159
# 第 5 个风力发电站的计划发电量为: 30.418501269584482
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -81.88708137778063
# 第 2 个火力发电站的对偶变量为: -79.94535946876894
# 第 3 个火力发电站的对偶变量为: -79.01856659306743
# 第 4 个火力发电站的对偶变量为: -73.54162374698865
# 第 5 个风力发电站的对偶变量为: -81.88708137778063
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 295.61810553652276
# *************************
# 需求侧平均用电需求: 73.35026091
# ****************************************************************************
# 风速分布参数c: 7.43418951
# ****************************************************************************
# 风速分布参数kappa: 2.06366986
# ****************************************************************************
# 安全发电站的总发电成本： 2202.95930667879
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 990 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 71.1795264223412
# 第 2 个火力发电站的计划发电量为: 74.71501084116512
# 第 3 个火力发电站的计划发电量为: 56.81880908532027
# 第 4 个火力发电站的计划发电量为: 69.27985399951866
# 第 5 个风力发电站的计划发电量为: 35.98791049064782
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -89.4164652840726
# 第 2 个火力发电站的对偶变量为: -92.91686839120021
# 第 3 个火力发电站的对偶变量为: -85.91670649977867
# 第 4 个火力发电站的对偶变量为: -79.9108204728489
# 第 5 个风力发电站的对偶变量为: -89.4164652840726
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 307.98111083899306
# *************************
# 需求侧平均用电需求: 68.80907141
# ****************************************************************************
# 风速分布参数c: 19.00064664
# ****************************************************************************
# 风速分布参数kappa: 2.40368022
# ****************************************************************************
# 安全发电站的总发电成本： 2501.8342822011045
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 991 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 74.47303456933723
# 第 2 个火力发电站的计划发电量为: 78.36462910947454
# 第 3 个火力发电站的计划发电量为: 59.62678048783246
# 第 4 个火力发电站的计划发电量为: 70.93834232838698
# 第 5 个风力发电站的计划发电量为: 48.276876793854896
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -93.9745910337755
# 第 2 个火力发电站的对偶变量为: -96.7949428123742
# 第 3 个火力发电站的对偶变量为: -96.5761717599103
# 第 4 个火力发电站的对偶变量为: -85.15478379408735
# 第 5 个风力发电站的对偶变量为: -93.9745910337755
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 331.6796632888861
# *************************
# 需求侧平均用电需求: 68.43412668
# ****************************************************************************
# 风速分布参数c: 24.69532358
# ****************************************************************************
# 风速分布参数kappa: 2.76905839
# ****************************************************************************
# 安全发电站的总发电成本： 2886.092332005829
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 992 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 78.08160674143929
# 第 2 个火力发电站的计划发电量为: 82.16789464842451
# 第 3 个火力发电站的计划发电量为: 63.69185472423517
# 第 4 个火力发电站的计划发电量为: 73.26351350301984
# 第 5 个风力发电站的计划发电量为: 54.80608156242371
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -96.39424823833924
# 第 2 个火力发电站的对偶变量为: -98.81679276640293
# 第 3 个火力发电站的对偶变量为: -97.80003614734576
# 第 4 个火力发电站的对偶变量为: -89.99430246985912
# 第 5 个风力发电站的对偶变量为: -96.39424823833924
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 352.0109511795425
# *************************
# 需求侧平均用电需求: 77.5218747
# ****************************************************************************
# 风速分布参数c: 19.34977167
# ****************************************************************************
# 风速分布参数kappa: 2.81628725
# ****************************************************************************
# 安全发电站的总发电成本： 2843.6531359837045
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 993 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 81.6062978710682
# 第 2 个火力发电站的计划发电量为: 85.79469433195435
# 第 3 个火力发电站的计划发电量为: 67.20886762480929
# 第 4 个火力发电站的计划发电量为: 76.10462472678554
# 第 5 个风力发电站的计划发电量为: 68.86539017194733
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -100.78092534929667
# 第 2 个火力发电站的对偶变量为: -102.94920796254692
# 第 3 个火力发电站的对偶变量为: -102.03539533889196
# 第 4 个火力发电站的对偶变量为: -96.15836730123246
# 第 5 个风力发电站的对偶变量为: -100.78092534929667
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 379.57987472656464
# *************************
# 需求侧平均用电需求: 67.46785371
# ****************************************************************************
# 风速分布参数c: 10.91176004
# ****************************************************************************
# 风速分布参数kappa: 2.64243598
# ****************************************************************************
# 安全发电站的总发电成本： 2895.8920597639203
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 994 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 85.38626855002343
# 第 2 个火力发电站的计划发电量为: 89.62061192423167
# 第 3 个火力发电站的计划发电量为: 70.78112633736822
# 第 4 个火力发电站的计划发电量为: 79.61794118614276
# 第 5 个风力发电站的计划发电量为: 79.41521959065008
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -96.77803585542021
# 第 2 个火力发电站的对偶变量为: -98.58782427550491
# 第 3 个火力发电站的对偶变量为: -95.36600281140961
# 第 4 个火力发电站的对偶变量为: -94.6652871108069
# 第 5 个风力发电站的对偶变量为: -96.77803585542021
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 404.8211675884162
# *************************
# 需求侧平均用电需求: 66.54800521
# ****************************************************************************
# 风速分布参数c: 15.71097882
# ****************************************************************************
# 风速分布参数kappa: 2.6773563
# ****************************************************************************
# 安全发电站的总发电成本： 3113.899089229287
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 995 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 87.9887949383403
# 第 2 个火力发电站的计划发电量为: 92.20313336037788
# 第 3 个火力发电站的计划发电量为: 72.5809517668567
# 第 4 个火力发电站的计划发电量为: 82.44324638967606
# 第 5 个风力发电站的计划发电量为: 93.21507077634564
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -88.93647917089712
# 第 2 个火力发电站的对偶变量为: -89.1800468575215
# 第 3 个火力发电站的对偶变量为: -88.49031499155164
# 第 4 个火力发电站的对偶变量为: -90.77033525770226
# 第 5 个风力发电站的对偶变量为: -88.93647917089712
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 428.43119723159657
# *************************
# 需求侧平均用电需求: 64.64150556
# ****************************************************************************
# 风速分布参数c: 3.22319547
# ****************************************************************************
# 风速分布参数kappa: 2.62903492
# ****************************************************************************
# 安全发电站的总发电成本： 5357.928343424379
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 996 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 88.93305415014721
# 第 2 个火力发电站的计划发电量为: 92.86905149964711
# 第 3 个火力发电站的计划发电量为: 72.90186152191349
# 第 4 个火力发电站的计划发电量为: 84.2662298005836
# 第 5 个风力发电站的计划发电量为: 77.0378428659978
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -77.23028031129299
# 第 2 个火力发电站的对偶变量为: -81.03761492799615
# 第 3 个火力发电站的对偶变量为: -77.8300709544114
# 第 4 个火力发电站的对偶变量为: -83.1159921880506
# 第 5 个风力发电站的对偶变量为: -77.23028031129299
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 416.0080398382892
# *************************
# 需求侧平均用电需求: 75.10408906
# ****************************************************************************
# 风速分布参数c: 8.16558337
# ****************************************************************************
# 风速分布参数kappa: 2.05432022
# ****************************************************************************
# 安全发电站的总发电成本： 3694.9380018108227
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 997 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 87.79880522509283
# 第 2 个火力发电站的计划发电量为: 92.08799870186078
# 第 3 个火力发电站的计划发电量为: 71.38669563276139
# 第 4 个火力发电站的计划发电量为: 84.58561644018575
# 第 5 个风力发电站的计划发电量为: 72.94335706889204
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -73.68187765196433
# 第 2 个火力发电站的对偶变量为: -77.25970796920711
# 第 3 个火力发电站的对偶变量为: -76.505744230629
# 第 4 个火力发电站的对偶变量为: -78.52107136728381
# 第 5 个风力发电站的对偶变量为: -73.68187765196433
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 408.80247306879284
# *************************
# 需求侧平均用电需求: 74.46242037
# ****************************************************************************
# 风速分布参数c: 3.06843305
# ****************************************************************************
# 风速分布参数kappa: 2.46674814
# ****************************************************************************
# 安全发电站的总发电成本： 4763.37808602155
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 998 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 86.22627946169936
# 第 2 个火力发电站的计划发电量为: 90.78273687197743
# 第 3 个火力发电站的计划发电量为: 69.93111431247203
# 第 4 个火力发电站的计划发电量为: 84.09925961304316
# 第 5 个风力发电站的计划发电量为: 54.22705532179523
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -71.17738281885455
# 第 2 个火力发电站的对偶变量为: -74.92889385787751
# 第 3 个火力发电站的对偶变量为: -73.86234389263448
# 第 4 个火力发电站的对偶变量为: -75.84686969665646
# 第 5 个风力发电站的对偶变量为: -71.17738281885455
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 385.26644558098724
# *************************
# 需求侧平均用电需求: 57.53112837
# ****************************************************************************
# 风速分布参数c: 20.15305097
# ****************************************************************************
# 风速分布参数kappa: 2.53492363
# ****************************************************************************
# 安全发电站的总发电成本： 3347.15272889296
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 999 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 84.44862887084571
# 第 2 个火力发电站的计划发电量为: 89.2652163705734
# 第 3 个火力发电站的计划发电量为: 68.30424881343713
# 第 4 个火力发电站的计划发电量为: 83.22799711085551
# 第 5 个风力发电站的计划发电量为: 62.01366349262755
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -63.421505007948994
# 第 2 个火力发电站的对偶变量为: -67.56598960164973
# 第 3 个火力发电站的对偶变量为: -66.52571616116023
# 第 4 个火力发电站的对偶变量为: -65.25269228848822
# 第 5 个风力发电站的对偶变量为: -63.421505007948994
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -300.0
# ****************************************************************************
# 安全发电站的总发电量: 387.25975465833926
# *************************
# 需求侧平均用电需求: 69.0560216
# ****************************************************************************
# 风速分布参数c: 17.58707426
# ****************************************************************************
# 风速分布参数kappa: 2.68279184
# ****************************************************************************
# 安全发电站的总发电成本： 3151.6646065811537
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 2024-07-30 17:10:36.133

# %%
#数据存储
np.savetxt('./data/02_IOS_optimal_parameters_small_Byzantine_attack_sum_cost.txt',sum_cost,fmt='%0.8f')
np.savetxt('./data/02_IOS_optimal_parameters_small_Byzantine_attack_sum_thermal_wind_power_station_strategy.txt',sum_thermal_wind_power_station_strategy,fmt='%0.8f')

# %%
#评价指标：动态regret和累计的约束违反

# %%
#动态regret

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
from sympy import *
import math 
from datetime import datetime
from scipy.special import gamma, factorial
import scipy.special as sc

# %%
sum_cost=np.loadtxt("./data/02_IOS_optimal_parameters_small_Byzantine_attack_sum_cost.txt")
optimal_sum_cost=np.loadtxt("./data/00_optimal_sum_cost_varying_D_c_kappa_normal_distribution_(70,5).txt")

# %%
dynamic_regret=[]
dynamic_regret_T=[]
for T in range(1, 1000):
    dynamic_regret_auxiliary_variable=0
    for t in range(0, T):
        dynamic_regret_auxiliary_variable=dynamic_regret_auxiliary_variable+sum_cost[t]-optimal_sum_cost[t]
    dynamic_regret.append(dynamic_regret_auxiliary_variable)
    dynamic_regret_T.append((dynamic_regret_auxiliary_variable)/T)

# %% [raw]
# dynamic_regret

# %%
#绘图 dynamic_regret和dynamic_regret_T

# %%
sub1=plt.subplot(1, 2, 1)##############################################################
iteration=[]
for i in range(0,999):
    iteration.append(i)

#在同一幅图片上画3条折线
A,=plt.plot(iteration,dynamic_regret,color = 'red',linewidth = '1.5',label='attack-free online primal-dual algorithm')


#设置图例并且设置图例的字体及大小
font1 = {
'size'   : 18,
}
#legend = plt.legend(handles=[A],prop=font1)
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=18)
 
#设置横纵坐标的名称以及对应字体格式
font2 = {
'size'   : 18,
}
plt.xlabel('T',font2)
plt.ylabel(r'Dynamic regret $Reg(T)$',font2)
plt.title('varying $D_{t}$',font2) 

sub2=plt.subplot(1, 2, 2)##############################################################
iteration=[]
for i in range(0,999):
    iteration.append(i)

#在同一幅图片上画3条折线
A,=plt.plot(iteration,dynamic_regret_T,color = 'red',linewidth = '1.5',label='attack-free online primal-dual algorithm')


#设置图例并且设置图例的字体及大小
font1 = {
'size'   : 18,
}
#legend = plt.legend(handles=[A],prop=font1)
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=18)
 
#设置横纵坐标的名称以及对应字体格式
font2 = {
'size'   : 18,
}
plt.xlabel('T',font2)
plt.ylabel(r'Dynamic regret $Reg(T)/T$',font2)
plt.title('varying $D_{t}$',font2) 

plt.legend(handles=[A],prop={'size':18},loc="upper center", bbox_to_anchor=[-0.3, -0.2],
           ncol=18, shadow=True, fancybox=True)

plt.subplots_adjust(wspace=0.5,hspace=0.5) 
plt.gcf().set_size_inches((15, 5))

#plt.savefig('./figures/01-figure1_dynamic_regret_attack_free_varying_D.pdf',format='pdf', bbox_inches='tight')
#plt.savefig('./figures/01-figure1_dynamic_regret_attack_free_varying_D.png',format='png', bbox_inches='tight')

# %%
#累计的约束违反

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
from sympy import *
import math 
from datetime import datetime
from scipy.special import gamma, factorial
import scipy.special as sc

# %%
sum_thermal_wind_power_station_strategy=np.loadtxt("./data/02_IOS_optimal_parameters_small_Byzantine_attack_sum_thermal_wind_power_station_strategy.txt")
d_power_demand=np.loadtxt("./data/d_power_demand_normal_distribution_(70,5).txt")

# %%
accumulative_constraint_violation=[]
accumulative_constraint_violation_T=[]
for T in range(1, 1000):
    accumulative_constraint_violation_auxiliary_variable=0
    for t in range(0, T): 
        accumulative_constraint_violation_auxiliary_variable=accumulative_constraint_violation_auxiliary_variable+(1/5)*sum_thermal_wind_power_station_strategy[t+1]-d_power_demand[t+1]
    accumulative_constraint_violation.append(abs(accumulative_constraint_violation_auxiliary_variable))
    accumulative_constraint_violation_T.append(abs(accumulative_constraint_violation_auxiliary_variable)/T)

# %%
accumulative_constraint_violation
# Out:
# [5.161334969999999,
#  3.1631070959999903,
#  0.27985778800000105,
#  1.8686595300000022,
#  0.1782236679999869,
#  2.4188789340000056,
#  6.038580502000002,
#  18.546129418000007,
#  26.889542364000008,
#  19.809393099999994,
#  18.0672007,
#  30.641156562000006,
#  37.54101152800003,
#  41.650655580000034,
#  52.69167788400004,
#  57.89467552600006,
#  55.57393258000005,
#  51.671118168000035,
#  56.54667423800004,
#  52.22161026200003,
#  46.024837162000026,
#  41.72795585400003,
#  35.93270017000003,
#  27.181768836000032,
#  32.295931634000034,
#  26.07978373400003,
#  20.176344224000033,
#  26.483376702000044,
#  31.341417158000056,
#  44.028761112000055,
#  58.55937413200006,
#  59.038773708000065,
#  67.9187671860001,
#  75.6432943560001,
#  89.5886065520001,
#  97.3868183760001,
#  101.10795397800007,
#  119.98599920000008,
#  125.30160836400009,
#  121.83781815000009,
#  117.86284058200008,
#  102.17413583400007,
#  93.06292167400007,
#  87.67738983000008,
#  83.18184331200007,
#  83.24263597400007,
#  81.22864138800009,
#  83.15309318400008,
#  80.37594234200006,
#  82.14331846800007,
#  86.87633323000007,
#  88.32614053800008,
#  96.84893832000007,
#  100.54396263200006,
#  97.78690731400008,
#  101.59963126800008,
#  108.96009292600007,
#  130.29317372800006,
#  139.60473545000008,
#  142.74999161400007,
#  154.2083827840001,
#  152.84307622000009,
#  158.75784348200008,
#  163.00542478400007,
#  171.1843197260001,
#  175.2847505260001,
#  178.6026774760001,
#  181.5359240320001,
#  182.93892023600011,
#  191.4523804880001,
#  186.14111981600013,
#  184.18613771200017,
#  185.26735523800016,
#  191.24162305600015,
#  189.92516695000018,
#  195.7917381600002,
#  200.00462684600018,
#  200.87858165800017,
#  200.68336289600018,
#  206.88358529000018,
#  208.0707187160002,
#  217.54508176000016,
#  221.10413973000018,
#  227.2968996820002,
#  230.13830622000023,
#  239.15704129400024,
#  244.73437627200025,
#  252.24590846800024,
#  253.22976157600021,
#  252.5105881180002,
#  255.29547030800018,
#  249.74638797800017,
#  246.06580350400014,
#  229.20876231800017,
#  227.4673873680002,
#  225.1159603820002,
#  233.2149898080002,
#  232.1764814820002,
#  235.01345242200023,
#  247.35714546800023,
#  258.85023346000025,
#  271.1638582320002,
#  277.74685069600025,
#  292.9554715520003,
#  311.8537123560003,
#  314.9070404920003,
#  308.1438570060003,
#  299.5123600600003,
#  299.9401883640003,
#  289.8771781360003,
#  284.62158317400025,
#  279.74598736600024,
#  276.95126468400025,
#  265.60431019800023,
#  264.50284382600023,
#  263.01587785000027,
#  255.67114966000025,
#  258.97212093400026,
#  261.9129506520003,
#  278.0462824660003,
#  290.5030165220003,
#  300.14118417800034,
#  302.80886343800034,
#  310.31285291000034,
#  319.85154871800034,
#  325.4017581500003,
#  327.0905135100003,
#  323.0918861540003,
#  323.7075691540003,
#  328.48912736200026,
#  330.1379204260002,
#  316.4950767520003,
#  318.4602428940003,
#  318.7226851700003,
#  315.48490799000035,
#  315.7714968240004,
#  321.0089018020004,
#  313.66389495800047,
#  310.47674933800045,
#  310.4371393480004,
#  307.6515719920004,
#  307.9165961780004,
#  303.1749838360004,
#  306.1925740500005,
#  311.3114218180005,
#  327.9860212300005,
#  352.6753382320005,
#  372.75523359600055,
#  377.2713431820006,
#  374.27055891200064,
#  370.6298516480006,
#  362.75955874200065,
#  343.28297835800066,
#  321.9719895820007,
#  307.06729250800066,
#  291.42947066800065,
#  280.7263410040007,
#  293.4277872180007,
#  306.0049195480007,
#  324.3356970840007,
#  335.2164305360007,
#  350.03398987400067,
#  364.2660184380007,
#  381.3776773800007,
#  386.56060445800074,
#  387.7559919260008,
#  384.9995814780008,
#  384.0052019060008,
#  376.2533420920008,
#  368.8393209720008,
#  365.6119139080008,
#  360.8161219980008,
#  366.31340266800083,
#  358.8652337180008,
#  357.1648646620008,
#  364.44566354800077,
#  368.3420767120008,
#  371.8764115360008,
#  388.72610301800074,
#  393.94957442400073,
#  395.72494995400075,
#  396.3802786500007,
#  408.91408953600074,
#  414.82349316800077,
#  420.7839317140008,
#  420.24980778400084,
#  419.8095938740008,
#  413.8287488540008,
#  418.4387540800008,
#  424.2124743580008,
#  436.5590998760008,
#  443.1143924960008,
#  442.4984465040008,
#  445.0721165560008,
#  444.7633543480008,
#  444.5935964860008,
#  450.5734592040008,
#  451.8830053160008,
#  456.2674306180008,
#  453.89907511600086,
#  449.1336452800009,
#  449.8774906680009,
#  436.9926079340009,
#  436.40350569200086,
#  431.53330051400087,
#  430.4428516920009,
#  429.8531184000009,
#  440.15451418200087,
#  445.39520471800097,
#  464.55256231800104,
#  479.183858830001,
#  488.465456194001,
#  501.7941682900009,
#  506.1059973340009,
#  514.6207878180008,
#  523.0127727980008,
#  538.7474515660008,
#  547.8204932580007,
#  544.5546340580007,
#  535.8937244740007,
#  539.8036116180007,
#  542.3361761840007,
#  538.5477487260007,
#  538.5372753740007,
#  537.0499253460008,
#  541.2970110120008,
#  544.9415288800008,
#  542.5866828060008,
#  544.1716479800008,
#  550.6742703720008,
#  544.8735245120008,
#  551.9235687520008,
#  550.9421939340009,
#  544.8904320660008,
#  551.3868523360007,
#  559.8869402360008,
#  563.4887908320009,
#  574.7942922140008,
#  581.5911948420008,
#  591.1475476760008,
#  595.3947725380008,
#  591.8182745660008,
#  588.7293135280008,
#  580.6069136440009,
#  573.0556857740008,
#  569.0367630780008,
#  562.2691618180008,
#  558.5883874960008,
#  555.2812946360008,
#  558.0425839920008,
#  567.9500531740008,
#  568.2662661540007,
#  578.3754166720008,
#  585.0316179700009,
#  593.2550537080009,
#  603.0637951440009,
#  611.7348517920009,
#  616.0232839100008,
#  624.6174755460008,
#  621.2646768560008,
#  628.0274984960008,
#  627.3524005120008,
#  619.2990981560008,
#  617.7645567440009,
#  625.8886011820009,
#  628.2216208280009,
#  625.7041666560009,
#  631.749380762001,
#  635.933774650001,
#  650.6348334400011,
#  663.719331852001,
#  682.404384304001,
#  693.4284661740011,
#  700.8657223460011,
#  709.2451977280011,
#  708.9707311480012,
#  709.8173132260011,
#  705.9653227720012,
#  702.6840681520011,
#  700.1326154560011,
#  693.8374490920011,
#  695.7119011300011,
#  702.7073152620011,
#  701.5230632020011,
#  700.3631705520012,
#  701.5576078980013,
#  689.6524871880013,
#  698.0260678040012,
#  704.8236017840012,
#  706.1776693680013,
#  717.1150223060013,
#  716.7570906580012,
#  724.9691223100012,
#  731.9841672400012,
#  739.7578222500011,
#  731.5640528160011,
#  727.0715242800011,
#  736.0269710120011,
#  730.5547822340011,
#  722.7662992960011,
#  722.3484308780012,
#  717.1295857660011,
#  714.2590118760012,
#  702.7654162860011,
#  694.6371663400012,
#  697.6574542500011,
#  700.4435950840011,
#  690.2850626540011,
#  698.343017992001,
#  716.2015555500011,
#  725.0346990540011,
#  736.7580630680011,
#  749.4997702760012,
#  760.2139743800012,
#  774.0189474480013,
#  775.6818389300013,
#  773.7105856080013,
#  775.5833372180014,
#  775.3767479620013,
#  774.0963203800013,
#  764.0245296680014,
#  748.5701944020013,
#  751.2547805640014,
#  747.0679454880014,
#  746.5971945720014,
#  749.5688082660014,
#  756.2613801460014,
#  769.3548579100014,
#  788.7902540180014,
#  794.9055998140013,
#  802.3786139160013,
#  809.3724128400013,
#  819.5130670200014,
#  824.0037147080013,
#  827.2205460300013,
#  831.5439253060013,
#  821.9282175920013,
#  813.8647092220014,
#  798.1166063620013,
#  790.2901029260013,
#  781.2240470340013,
#  773.6320989840013,
#  776.4329997600013,
#  776.9644009900013,
#  789.2202436860013,
#  799.7509679000012,
#  815.9417309380012,
#  828.9643433440012,
#  838.7931915880013,
#  857.1178455720013,
#  871.3981687860013,
#  884.7854490920013,
#  880.1041422340012,
#  872.6845329440013,
#  868.3139701700012,
#  861.5451615700013,
#  839.0954831720013,
#  821.9449526640013,
#  814.7514721540014,
#  806.2583630020014,
#  805.0827602160014,
#  808.3904527560013,
#  808.3691615240012,
#  806.4336011880013,
#  822.9729552000013,
#  825.0391078920012,
#  835.5826953260012,
#  844.6163432100011,
#  857.6386394000011,
#  866.9090547200011,
#  880.5726624440011,
#  899.1005905800012,
#  910.7276163940012,
#  916.4692929260012,
#  922.4567389460012,
#  923.4347177540012,
#  921.0799641800013,
#  910.0686979740012,
#  900.4285543060013,
#  899.3866498800012,
#  895.5181213420011,
#  889.2457985340011,
#  888.9730676740011,
#  896.645835272001,
#  906.633185140001,
#  913.751923162001,
#  926.509835114001,
#  933.4313560640011,
#  944.2577408700012,
#  949.7729895480012,
#  961.3342062800014,
#  974.8275968380013,
#  986.6337753300013,
#  997.1382396460014,
#  998.4043810680014,
#  1004.5282571380014,
#  1000.8954826560014,
#  1008.6690186120013,
#  1004.0274708120014,
#  999.0942688420014,
#  995.0307822300013,
#  995.7080051360012,
#  1005.7378127320013,
#  1011.2095040540013,
#  1014.9454096580013,
#  1024.7691853140013,
#  1025.1694420340013,
#  1031.0912322300014,
#  1031.9042622960014,
#  1028.6531360880015,
#  1028.1911093580013,
#  1031.6539114560012,
#  1037.2121935680013,
#  1042.7427345980013,
#  1048.8103813540013,
#  1041.7332471960012,
#  1043.4604469480014,
#  1034.8139009100014,
#  1033.5264812880014,
#  1032.5758327220015,
#  1035.7861922800016,
#  1040.9310574800015,
#  1045.8505648720015,
#  1044.5698681020017,
#  1049.3362606220016,
#  1050.2974440140017,
#  1051.3974887140016,
#  1063.0503372680016,
#  1073.9995850660016,
#  1078.0882649460016,
#  1083.7624803900017,
#  1089.9715491520017,
#  1085.2554022640018,
#  1087.165310962002,
#  1090.5048249760018,
#  1092.513661708002,
#  1089.377715554002,
#  1094.009312368002,
#  1102.1540012260018,
#  1102.336243676002,
#  1101.111197358002,
#  1114.0795001020022,
#  1115.0118491080023,
#  1113.6706094880021,
#  1124.0755620220023,
#  1127.0651596740022,
#  1124.5770478820023,
#  1122.9455035060023,
#  1119.3529091560022,
#  1118.431302636002,
#  1125.6558891000022,
#  1133.3755427420022,
#  1138.393242522002,
#  1156.537518722002,
#  1164.804589438002,
#  1185.084583038002,
#  1194.926326030002,
#  1207.781004112002,
#  1211.819664500002,
#  1223.2743919300021,
#  1212.566328370002,
#  1211.533053656002,
#  1211.3730630560021,
#  1203.9862363120021,
#  1195.2063026480023,
#  1188.8379357700023,
#  1176.7042101420025,
#  1165.0332586480024,
#  1168.3938148780023,
#  1176.9966642480024,
#  1185.9520264940024,
#  1195.3378786120024,
#  1212.7911396800023,
#  1228.1659881800024,
#  1237.2453071260024,
#  1239.8012485460024,
#  1243.5753335280024,
#  1245.1158085560023,
#  1235.2657282220023,
#  1226.2072429660022,
#  1220.9843283980022,
#  1219.1754067200022,
#  1215.3088932580022,
#  1206.9026273280022,
#  1214.2721607720023,
#  1225.6239087660024,
#  1235.2440869540023,
#  1241.9641312140025,
#  1241.4206781240025,
#  1246.5085490720023,
#  1251.6073709340021,
#  1264.4742826740023,
#  1274.3062049700022,
#  1263.3488906880023,
#  1264.3197679200023,
#  1260.0229637320024,
#  1259.1535537320024,
#  1255.7874265980024,
#  1257.9776249480024,
#  1262.1115910100025,
#  1258.2812767540026,
#  1257.6716675880025,
#  1264.8852525680024,
#  1269.3732925300023,
#  1276.2368594420025,
#  1290.1679579000024,
#  1292.2577449800024,
#  1285.2531525040022,
#  1284.9453435420023,
#  1276.5653003780023,
#  1277.6931094480024,
#  1277.8130002040025,
#  1284.2493655960025,
#  1281.9397169360025,
#  1285.3306710680024,
#  1287.3552951280026,
#  1290.3305123020025,
#  1295.4126183020026,
#  1302.5309093800024,
#  1312.2640001040024,
#  1314.6319379360025,
#  1328.4286194500025,
#  1323.3450645740024,
#  1319.1147047080026,
#  1312.4986668860026,
#  1318.7170188880027,
#  1323.5132861200027,
#  1316.9296281580027,
#  1316.9072301860026,
#  1324.0625709860028,
#  1322.3085613180028,
#  1330.8792856340028,
#  1343.2608600380029,
#  1346.6905218680029,
#  1344.9237958200029,
#  1346.761123090003,
#  1339.436568240003,
#  1340.297591984003,
#  1345.318262430003,
#  1349.637229940003,
#  1354.371102242003,
#  1363.3198651600028,
#  1374.7034560800028,
#  1380.5770595800027,
#  1381.6225098340026,
#  1384.3295285900026,
#  1386.0707532880026,
#  1381.5317025880026,
#  1374.4487034780027,
#  1367.3919407600026,
#  1363.8654247020027,
#  1361.2678907820027,
#  1360.2287319480026,
#  1361.8458838100028,
#  1359.2664259000026,
#  1368.1409299160025,
#  1375.1105504800025,
#  1372.2550014340025,
#  1377.3754181140025,
#  1384.5291683020027,
#  1398.8967388240028,
#  1408.408417542003,
#  1419.689817694003,
#  1426.191306718003,
#  1435.230115306003,
#  1437.3249529920029,
#  1437.8160804660029,
#  1435.3019240860028,
#  1425.9794873480027,
#  1416.0913036940028,
#  1403.163929478003,
#  1401.759734550003,
#  1400.934764814003,
#  1410.9043482340032,
#  1410.7738231760034,
#  1425.6109843100035,
#  1441.3780024600035,
#  1452.6227878860034,
#  1455.5622726760034,
#  1467.3382183740034,
#  1465.8800692520035,
#  1465.6040060500034,
#  1477.7694308580033,
#  1481.5973052380032,
#  1485.5199269240034,
#  1489.1177654940034,
#  1486.2816606940034,
#  1487.9926983680034,
#  1483.4254712280035,
#  1482.3029295780034,
#  1482.0139025200035,
#  1476.6068827780036,
#  1485.6569999220037,
#  1485.0151168260038,
#  1493.1698397320038,
#  1501.3277645480039,
#  1492.0219980380039,
#  1504.5841325600038,
#  1512.832400286004,
#  1516.618122004004,
#  1523.794184930004,
#  1529.0600319460038,
#  1522.698495500004,
#  1522.9659476780039,
#  1536.7349430780039,
#  1538.664276422004,
#  1546.3849841520039,
#  1540.919877516004,
#  1534.6409542540039,
#  1542.6907752740037,
#  1555.948740668004,
#  1566.038668458004,
#  1569.729232548004,
#  1573.506325796004,
#  1582.170077532004,
#  1584.730729712004,
#  1585.4877421380038,
#  1587.5284915580037,
#  1588.3273118060038,
#  1591.355814040004,
#  1594.789461876004,
#  1594.0493663680038,
#  1585.1998418980038,
#  1587.032120884004,
#  1594.5603417200039,
#  1593.361786842004,
#  1603.684715902004,
#  1609.263414340004,
#  1620.629482880004,
#  1626.311762360004,
#  1630.9947248800038,
#  1636.6501619520038,
#  1639.2340513200038,
#  1644.6939745180039,
#  1643.557717530004,
#  1642.457556780004,
#  1642.478029900004,
#  1648.031920646004,
#  1651.5309496580041,
#  1652.859817720004,
#  1663.2579143880039,
#  1673.202030800004,
#  1673.9163011020041,
#  1680.832976088004,
#  1689.3895184520038,
#  1701.5259300700038,
#  1705.6118081780037,
#  1704.9952780580036,
#  1706.4873411980034,
#  1707.2758846600034,
#  1707.9916618400032,
#  1707.8886350280034,
#  1701.5299827260033,
#  1687.6966029620032,
#  1686.9908084920032,
#  1684.4985960100032,
#  1676.8749448340034,
#  1663.4151224020034,
#  1671.4986217240034,
#  1679.1170500600035,
#  1697.3024086920036,
#  1707.5854343580036,
#  1720.9315084440036,
#  1740.9410900520036,
#  1747.3101298940035,
#  1766.6729948280035,
#  1781.7921163040037,
#  1793.5877168520035,
#  1798.8555131060034,
#  1808.3239615140035,
#  1810.8591002840035,
#  1806.1554613820035,
#  1799.8284923640035,
#  1788.0631767380037,
#  1779.5911036660036,
#  1778.4562612720035,
#  1785.2203902020035,
#  1786.5599398600036,
#  1799.5848877440037,
#  1797.9848020340037,
#  1799.8616072720035,
#  1806.8576845000036,
#  1812.8372818300038,
#  1824.5697744140039,
#  1827.5208565760038,
#  1839.1649052080038,
#  1843.0657841420038,
#  1835.6211660340039,
#  1836.610950358004,
#  1836.648151878004,
#  1829.447661738004,
#  1835.2058123160039,
#  1831.311994028004,
#  1833.627372642004,
#  1841.018226902004,
#  1847.1790180020039,
#  1861.2749379580039,
#  1868.4694688480038,
#  1867.2109457440038,
#  1866.9853349780037,
#  1868.5828158040035,
#  1862.7423634360034,
#  1857.8668779780035,
#  1853.7604226780036,
#  1843.2094019480035,
#  1830.6419161920035,
#  1823.5747180100034,
#  1822.7926443220035,
#  1829.3048627800035,
#  1833.4568462380034,
#  1851.9617290540034,
#  1869.2815190120036,
#  1883.7647660440036,
#  1901.2532114280036,
#  1909.8937546260038,
#  1922.8287997000036,
#  1933.3373035880036,
#  1944.4557599240036,
#  1941.4559942020037,
#  1935.9352470820036,
#  1929.0819602280035,
#  1919.7515105140035,
#  1912.2175702280033,
#  1898.4653599660032,
#  1889.9276416280031,
#  1885.222591376003,
#  1878.832423444003,
#  1873.1610793160032,
#  1876.5632239520032,
#  1878.9226657300032,
#  1883.4048905220031,
#  1882.9612010780033,
#  1896.6939606100034,
#  1903.0877742520033,
#  1908.9084799740033,
#  1915.0396611560031,
#  1923.341425832003,
#  1934.3985035720032,
#  1935.7005141460031,
#  1924.137792122003,
#  1939.623007572003,
#  1943.740188966003,
#  1944.713292980003,
#  1941.945954028003,
#  1941.237473994003,
#  1948.011812764003,
#  1951.725587112003,
#  1952.858949370003,
#  1950.7994328860032,
#  1952.703279856003,
#  1952.607995902003,
#  1953.501281906003,
#  1961.478695160003,
#  1962.872983682003,
#  1957.890925380003,
#  1962.9698555540028,
#  1956.9611708100028,
#  1948.7606381620028,
#  1946.1329320960028,
#  1945.5974368580028,
#  1948.2911485520028,
#  1959.9673650040029,
#  1961.034799520003,
#  1961.694944498003,
#  1962.536916128003,
#  1957.1750834400032,
#  1951.033368546003,
#  1943.963790412003,
#  1949.266202906003,
#  1954.6641536860031,
#  1955.835182444003,
#  1968.459348588003,
#  1966.792237658003,
#  1968.599253072003,
#  1978.8559150040028,
#  1978.4209341700027,
#  1980.4329809700027,
#  1978.8610468040026,
#  1980.5670222360027,
#  1980.3928646700028,
#  1981.5302456320028,
#  1976.4947277360027,
#  1986.633891966003,
#  1999.705879758003,
#  2005.103059116003,
#  2006.1791040560029,
#  2010.952348720003,
#  2014.971366524003,
#  2014.9371798760033,
#  2019.9494353260031,
#  2009.3415098220034,
#  1997.1017165220037,
#  1988.0499504120037,
#  1985.3127444260037,
#  1985.9793273580037,
#  1978.5749197920038,
#  1993.327735192004,
#  1991.9634411120037,
#  1994.5192177680037,
#  2005.8830424060036,
#  2009.8902316700037,
#  2010.4978257660039,
#  2001.760958510004,
#  1996.5480941840042,
#  1988.687901248004,
#  1992.3751035240039,
#  1993.691569086004,
#  2008.0144589740041,
#  2012.5429518180042,
#  2023.7858877300043,
#  2038.3875006840042,
#  2043.276195424004,
#  2052.352571052004,
#  2051.940183038004,
#  2052.0621677680037,
#  2052.8517526700034,
#  2054.3739629560037,
#  2072.410589290004,
#  2082.798454514004,
#  2102.2659919320035,
#  2104.6930717380033,
#  2109.566134012003,
#  2111.1458792060034,
#  2114.3884106220034,
#  2112.4594451160033,
#  2107.8390054320034,
#  2102.2969489640036,
#  2092.5158608920037,
#  2087.8089594240037,
#  2086.3153828840036,
#  2087.245771920004,
#  2095.091813942004,
#  2103.387182284004,
#  2107.657172780004,
#  2115.598579026004,
#  2132.691590188004,
#  2155.232971024004,
#  2180.620156162004,
#  2197.372568766004,
#  2204.382519354004,
#  2219.392213180004,
#  2230.982734578004,
#  2240.173131700004,
#  2238.958502606004,
#  2230.331694082004,
#  2229.017830052004,
#  2229.9174273900035,
#  2210.2375531480034,
#  2197.2923625940034,
#  2192.5132466940036,
#  2186.9829994180036,
#  2186.8675762260036,
#  2184.1195399820035,
#  2193.4908945140037,
#  2214.6531922700037,
#  2241.7680640720037,
#  2262.8901821760037,
#  2276.429649330004,
#  2287.839576298004,
#  2304.688926910004,
#  2311.1970218720035,
#  2316.732909854003,
#  2317.2843237580028,
#  2307.860839580003,
#  2296.3815768380027,
#  2288.568472490003,
#  2293.651242676003,
#  2290.329473794003,
#  2279.206164318003,
#  2269.178345382003,
#  2269.5391676220033,
#  2267.5691859920034,
#  2269.3960510840034,
#  2269.6460350080033,
#  2276.473554292003,
#  2290.010303150003,
#  2297.067218878003,
#  2320.7379476800033,
#  2335.1524449640033,
#  2342.855390880003,
#  2338.120056366003,
#  2337.129613886003,
#  2334.8240777200026,
#  2338.9637141040025,
#  2345.1575518000027,
#  2343.5599535800025,
#  2336.7438618320025,
#  2326.1647226780024,
#  2322.0634917260027,
#  2314.3555003380025,
#  2318.0076081200027,
#  2317.1836374580025,
#  2332.8232068380025,
#  2338.0025570300027,
#  2347.331033460003,
#  2368.670221826003,
#  2376.763523720003,
#  2387.321337054003,
#  2399.031789840003,
#  2409.537929802003,
#  2410.534970552003,
#  2418.494534982003,
#  2424.297900718003,
#  2418.4299634480026,
#  2419.8139938040026,
#  2417.7197025500027,
#  2410.292007720003,
#  2392.8109107840028,
#  2389.7122070560026,
#  2385.7193009220027,
#  2381.2093254440024,
#  2380.5278360860025,
#  2392.0150884820027,
#  2404.6855199000024,
#  2418.1867643260025,
#  2426.4381485100025,
#  2441.8933029880027,
#  2454.1248757440026,
#  2460.7235929960025,
#  2471.0565038820023,
#  2473.197828924002,
#  2470.553371194002,
#  2478.551779440002,
#  2472.1473684280018,
#  2458.9178952740017,
#  2450.4310913860018,
#  2442.031204664002,
#  2435.3141403020018,
#  2419.5926673860017,
#  2416.338435392002,
#  2419.408075692002,
#  2420.482941598002,
#  2430.979195726002,
#  2440.2830061440022,
#  2449.213017620002,
#  2458.8654067540024,
#  2467.5952277500023,
#  2473.369375504002,
#  2485.377931628002,
#  2494.227130808002,
#  2495.7028934320024,
#  2497.930389284002,
#  2488.6027715860023,
#  2491.6898490340022,
#  2486.6481529220023,
#  2495.4432899500025,
#  2486.0265919540025,
#  2480.461744244002,
#  2480.933681958002,
#  2482.9387616620024,
#  2483.5969145100025,
#  2479.6987769760026,
#  2482.7032658780026,
#  2490.3087384600026,
#  2498.7826146240027,
#  2506.1064654800025,
#  2511.6806964660027,
#  2515.9032889440027,
#  2523.797812098003,
#  2534.4048701120028,
#  2536.3216686200026,
#  2530.796269462003,
#  2535.603532424003,
#  2533.5795235220025,
#  2526.3742946760026,
#  2528.3037451160026,
#  2522.1430262700023,
#  2514.129148654002,
#  2492.7328453020023,
#  2487.5039345680025,
#  2481.9802886240027,
#  2489.353459544003,
#  2499.762434658003,
#  2497.1426078100026,
#  2495.3267861840022,
#  2502.5513650580024,
#  2518.5967575180025,
#  2527.9398897360024,
#  2539.1261020780025,
#  2550.2393353120024,
#  2558.8317907940022,
#  2567.215148890002,
#  2571.0122692300024,
#  2565.0136922620027,
#  2556.2040914880026,
#  2543.5518499940026,
#  2531.4793485280024,
#  2524.7387823200024,
#  2510.5121425180023,
#  2503.2992932760026,
#  2501.201099254002,
#  2494.0814147900023,
#  2502.5295360260025,
#  2516.9457643340024,
#  2537.9904982200023,
#  2546.0880171280023,
#  2553.3860913720023,
#  2572.9082521180026,
#  2581.3041814500025]

# %%
#绘图 accumulative_constraint_violation和accumulative_constraint_violation_T

# %%
sub1=plt.subplot(1, 2, 1)##############################################################
iteration=[]
for i in range(0,999):
    iteration.append(i)

#在同一幅图片上画3条折线
A,=plt.plot(iteration,accumulative_constraint_violation,color = 'green',linewidth = '1.5',label='attack-free online primal-dual algorithm')


#设置图例并且设置图例的字体及大小
font1 = {
'size'   : 18,
}
#legend = plt.legend(handles=[A],prop=font1)
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=18)
 
#设置横纵坐标的名称以及对应字体格式
font2 = {
'size'   : 18,
}
plt.xlabel('T',font2)
plt.ylabel(r'Constraint violation $Fit(T)$',font2)
plt.title('varying $D_{t}$',font2) 

sub2=plt.subplot(1, 2, 2)##############################################################
iteration=[]
for i in range(0,999):
    iteration.append(i)

#在同一幅图片上画3条折线
A,=plt.plot(iteration,accumulative_constraint_violation_T,color = 'green',linewidth = '1.5',label='attack-free online primal-dual algorithm')


#设置图例并且设置图例的字体及大小
font1 = {
'size'   : 18,
}
#legend = plt.legend(handles=[A],prop=font1)
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=18)
 
#设置横纵坐标的名称以及对应字体格式
font2 = {
'size'   : 18,
}
plt.xlabel('T',font2)
plt.ylabel(r'Constraint violation $Fit(T)/T$',font2)
plt.title('varying $D_{t}$',font2) 

plt.legend(handles=[A],prop={'size':18},loc="upper center", bbox_to_anchor=[-0.3, -0.2],
           ncol=18, shadow=True, fancybox=True)

plt.subplots_adjust(wspace=0.5,hspace=0.5) 
plt.gcf().set_size_inches((15, 5))


#plt.savefig('./figures/01-figure2_constraint_violation_attack_free_varying_D.pdf',format='pdf', bbox_inches='tight')
#plt.savefig('./figures/01-figure2_constraint_violation_attack_free_varying_D.png',format='png', bbox_inches='tight')
