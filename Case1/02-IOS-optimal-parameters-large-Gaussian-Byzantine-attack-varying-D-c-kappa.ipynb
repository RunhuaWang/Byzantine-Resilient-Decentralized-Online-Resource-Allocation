# %% [raw]
# 观察IOS+decentralized online economic dispatch algorithm在拜占庭攻击下的算法性能
# 实验设置：4个热能发电站 2个风能发电站
# 时变风速服从的Weibull distribution的参数c和kappa
# 时变的需求侧用电需求D
# c的变化：[3,25]间的均匀分布
# kappa的变化：[2，3]间的均匀分布
# D的变化为：均值为70 标准差为5的高斯分布
# 拜占庭攻击：假设一个风力发电站受到拜占庭攻击 向其他发电站发送恶意的对偶变量
# 大值高斯攻击 large-value Gaussian Byzantine attacks
#
# 加上一个adaptive clipping

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
from sympy import *
import math 
from datetime import datetime
from scipy.special import gamma, factorial
import scipy.special as sc

# %%
#定义变量 
thermal_power_station_strategy=np.zeros(shape=(4,1000)) 
wind_power_station_strategy=np.zeros(shape=(2,1000))
c_wind_speed= np.loadtxt("./data/c_wind_speed_uniform_distribution_(3,25).txt")      
kappa_wind_speed= np.loadtxt("./data/kappa_wind_speed_uniform_distribution_(2,3).txt")  
d_power_demand=np.loadtxt("./data/d_power_demand_normal_distribution_(70,5).txt") #时变的需求侧用电需求  阶梯式变化 
thermal_power_station_dual_variable=np.zeros(shape=(4,1000))
wind_power_station_dual_variable=np.zeros(shape=(2,1000))#两个风力发电站中有一个是受到拜占庭攻击的 假设第二个风力发电站是受到攻击的
E=np.loadtxt("6_Network_Topology_Double_Random_Adjacency_Matrix.txt")
thermal_power_station_cost=np.zeros(shape=(1,1000)) #火力发电成本
wind_power_station_cost=np.zeros(shape=(1,1000)) #风力发电成本
sum_cost=np.zeros(shape=(1,1000)) #总发电成本
#thermal_power_station_eta=[0.0375,0.0375,0.0625,0.035]
thermal_power_station_eta=[0.0675,0.0675,0.0925,0.0625]
thermal_power_station_zeta=[2,1.75,1,3]
thermal_power_station_xi=[0,0,0,0]
thermal_power_station_P_min=[50,20,15,10]
thermal_power_station_P_max=[200,120,80,100]
#wind_power_station_varphi=[3]
wind_power_station_varphi=[1]
wind_power_station_v_in=[3]
wind_power_station_v_out=[25]
wind_power_station_v_r=[13]
wind_power_station_sigma_ue=[5]
wind_power_station_sigma_oe=[30]
wind_power_station_P_r=[160]
wind_power_station_P_min=[0]
wind_power_station_P_max=[160]
sum_thermal_wind_power_station_strategy=np.zeros(shape=(1,1000))
step_size_primal=1
step_size_dual=3
regularization_parameter=0.001
large_Gaussian_Byzantine_attack=np.loadtxt("./data/large_Gaussian_Byzantine_attack_(-10,5).txt")

# %%
#火力，风力发电策略初始化
thermal_power_station_strategy[0][0]=70
thermal_power_station_strategy[1][0]=70
thermal_power_station_strategy[2][0]=70
thermal_power_station_strategy[3][0]=70
wind_power_station_strategy[0][0]=70
wind_power_station_strategy[1][0]=0
#初始总发电策略
sum_thermal_wind_power_station_strategy[0][0]=350
#初始化受到攻击的风力发电站的对偶变量
wind_power_station_dual_variable[1][0]=large_Gaussian_Byzantine_attack[0]

#火力，风力发电对偶初始化
thermal_power_station_dual_variable[0][0]=-70
thermal_power_station_dual_variable[1][0]=-70
thermal_power_station_dual_variable[2][0]=-70
thermal_power_station_dual_variable[3][0]=-70
wind_power_station_dual_variable[0][0]=-70

#火力，风力发电对偶初始化
thermal_power_station_dual_variable[0][0]=0
thermal_power_station_dual_variable[1][0]=0
thermal_power_station_dual_variable[2][0]=0
thermal_power_station_dual_variable[3][0]=0
wind_power_station_dual_variable[0][0]=0

#安全发电站的初始总发电成本
#火力发电成本
for i in range(0,4):
    thermal_power_station_cost[0][0]=thermal_power_station_cost[0][0]+thermal_power_station_eta[i]*thermal_power_station_strategy[i][0]*thermal_power_station_strategy[i][0]+thermal_power_station_zeta[i]*thermal_power_station_strategy[i][0]
#风力发电成本
for i in range(0,1):
    wind_power_station_cost[0][0]=wind_power_station_cost[0][0]+wind_power_station_varphi[i]*wind_power_station_strategy[i][0]+wind_power_station_sigma_ue[i]*((wind_power_station_P_r[i]-wind_power_station_strategy[i][0])*(math.exp(-(math.pow(wind_power_station_v_r[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0])))-math.exp(-(math.pow(wind_power_station_v_out[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0]))))+(wind_power_station_P_r[i]*wind_power_station_v_in[i]/(wind_power_station_v_r[i]-wind_power_station_v_in[i])+wind_power_station_strategy[i][0])*(math.exp(-(math.pow(wind_power_station_v_r[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0])))-math.exp(-(math.pow(wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][0])/wind_power_station_P_r[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0]))))+(wind_power_station_P_r[i]*c_wind_speed[0]/(wind_power_station_v_r[i]-wind_power_station_v_in[i]))*(sc.gammaincc(1+1/kappa_wind_speed[0],(math.pow(wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][0])/wind_power_station_P_r[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0])))*sc.gamma(1+1/kappa_wind_speed[0])-sc.gammaincc(1+1/kappa_wind_speed[0],math.pow(wind_power_station_v_r[i]/c_wind_speed[0],kappa_wind_speed[0]))*sc.gamma(1+1/kappa_wind_speed[0])))+wind_power_station_sigma_oe[i]*((wind_power_station_strategy[i][0])*(1-math.exp(-(math.pow(wind_power_station_v_in[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0])))+math.exp(-(math.pow(wind_power_station_v_out[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0]))))+(wind_power_station_P_r[i]*wind_power_station_v_in[i]/(wind_power_station_v_r[i]-wind_power_station_v_in[i])+wind_power_station_strategy[i][0])*(math.exp(-(math.pow(wind_power_station_v_in[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0])))-math.exp(-(math.pow(wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][0])/wind_power_station_P_r[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0]))))+(wind_power_station_P_r[i]*c_wind_speed[0]/(wind_power_station_v_r[i]-wind_power_station_v_in[i]))*(sc.gammaincc(1+1/kappa_wind_speed[0],(math.pow(wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][0])/wind_power_station_P_r[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0])))*sc.gamma(1+1/kappa_wind_speed[0])-sc.gammaincc(1+1/kappa_wind_speed[0],math.pow(wind_power_station_v_in[i]/c_wind_speed[0],kappa_wind_speed[0]))*sc.gamma(1+1/kappa_wind_speed[0])))
#发电总成本
sum_cost[0][0]=thermal_power_station_cost[0][0]+wind_power_station_cost[0][0]

#计算每个发电站的邻居发电站
neighbor_robust1_help=[]
for i in range (0,6):
    for j in range (0,6):
        if E[i][j]!=0:
            neighbor_robust1_help.append(j)
        elif E[i][j]==0:
            neighbor_robust1_help.append(99)
neighbor_robust1=np.array(neighbor_robust1_help).reshape(6,6)

#计算安全的发电站的拜占庭邻居用户数量
q_robust1=[]
for i in range(0,6):
    q_robust1_help=0
    for j in range(0,6):
        if neighbor_robust1[i][j]==5:
            q_robust1_help=q_robust1_help+1
    q_robust1.append(q_robust1_help)

# %%
def IOS_Byzantine_attack_decentralized_economic_dispatch(thermal_power_station_strategy,wind_power_station_strategy,c_wind_speed,kappa_wind_speed,d_power_demand,thermal_power_station_dual_variable,wind_power_station_dual_variable,E,thermal_power_station_cost,wind_power_station_cost,thermal_power_station_eta,thermal_power_station_zeta,thermal_power_station_P_min,thermal_power_station_P_max,wind_power_station_varphi,wind_power_station_sigma_ue,wind_power_station_sigma_oe,wind_power_station_P_min,wind_power_station_P_max,sum_thermal_wind_power_station_strategy,step_size_primal,step_size_dual):
    #显示初始化的数据
    #输出初始状态的原变量和对偶变量
    print("***************************attack_free_online_decentralized_economic_dispatch*****************************")
    print("相关变量初始值为：")
    for i in range (0,4):
        print("第",(i+1),"个火力发电站的初始计划发电量为:",thermal_power_station_strategy[i][0])
    for i in range (0,2):
        print("第",(i+5),"个风力发电站的初始计划发电量为:",wind_power_station_strategy[i][0])
    print("****************************************************************************")
    for i in range (0,4):
        print("第",(i+1),"个火力发电站的初始对偶变量为:",thermal_power_station_dual_variable[i][0])
    for i in range (0,1):
        print("第",(i+5),"个风力发电站的初始对偶变量为:",wind_power_station_dual_variable[i][0])
    print("****************************************************************************")
    print("第",(6),"个受到Byzantin攻击的风力发电站的初始对偶变量为:",wind_power_station_dual_variable[1][0])
    print("****************************************************************************")
    print("安全发电站的初始总发电量:",sum_thermal_wind_power_station_strategy[0][0])
    print("*************************")
    print("需求侧平均用电需求:",d_power_demand[0])
    print("****************************************************************************")
    print("风速分布参数c:",c_wind_speed[0])
    print("****************************************************************************")
    print("风速分布参数kappa:",kappa_wind_speed[0])
    print("****************************************************************************")
    print("安全发电站的总发电成本：", sum_cost[0][0])
    print("****************************************************************************")
    print("原变量迭代步长为:",step_size_primal)
    print("*****************************************************************************")
    print("对偶变量迭代步长为:",step_size_dual)
    print("*****************************************************************************")
    
    #开始迭代
    for k in range(1,1000):
        #发电站更新计划发电量和对偶变量
        #对偶变量 先做梯度上升 再做聚合
        #安全发电站的梯度上升
        dual_variable_intermediate=[] #存放当前迭代中6个用户对对偶变量做完梯度下降后得到的中间值
        for i in range(0,4):
            dual_variable_intermediate.append(thermal_power_station_dual_variable[i][k-1]+step_size_dual*((1/6)*thermal_power_station_strategy[i][k-1]-(1/6)*d_power_demand[k-1]-regularization_parameter*thermal_power_station_dual_variable[i][k-1]))
        for j in range(0,1):
            dual_variable_intermediate.append(wind_power_station_dual_variable[j][k-1]+step_size_dual*((1/6)*wind_power_station_strategy[j][k-1]-(1/6)*d_power_demand[k-1]-regularization_parameter*wind_power_station_dual_variable[j][k-1]))
        #受到攻击的风力发电站的对偶值
        dual_variable_intermediate.append(wind_power_station_dual_variable[1][k-1])
        
        #IOS鲁棒聚合+adaptive clipping 安全的火力发电站的对偶更新
        #在做鲁棒聚合前 对收集到的信息进行adaptive clipping的剪裁操作
        for i in range (0,4):
            u_neighbor_help_robust1=neighbor_robust1[i].tolist()#将用户i的邻居序号存在辅助变量u中
            if i==0 or i==3:
                u_neighbor_help_robust1 = list(set(u_neighbor_help_robust1))
                u_neighbor_help_robust1.remove(99)
            if int(q_robust1[i])==1: #只有具有拜占庭邻居的用户才需要先进行adaptive clipping和后续的IOS聚合操作
                #先进行adaptive clipping
                dual_variable_intermediate_auxiliary=[]
                #注意必须以这样的方式赋值 不能直接写dual_variable_intermediate_auxiliary=dual_variable_intermediate
                #不然在修改变量dual_variable_intermediate_auxiliary的同时也会对dual_variable_intermediate进行修改
                for j in range(len(dual_variable_intermediate)): 
                    dual_variable_intermediate_auxiliary.append(dual_variable_intermediate[j])
                dual_variable_receive=[]
                clipping_C=0
                for j in range(0, len(u_neighbor_help_robust1)):
                    dual_variable_receive.append(dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[j]])
                dual_variable_receive.sort()
                clipping_C=-dual_variable_receive[1] #确定clpping的阈值
                #接下来对大于clipping_C的值进行clipping
                for j in range(0, len(u_neighbor_help_robust1)):
                    if -dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[j]]>clipping_C:
                        dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[j]]=-clipping_C
                #接下来做IOS鲁棒聚合
                dual_variable_weight_average_robust1=0
                h_robust1=0
                for j in range(0,len(u_neighbor_help_robust1)):#计算当前循环中的h值
                    h_robust1=h_robust1+E[i][u_neighbor_help_robust1[j]]
                for j in range(0,len(u_neighbor_help_robust1)):#计算当前循环中的对偶权重平均值
                    dual_variable_weight_average_robust1=dual_variable_weight_average_robust1+(1/h_robust1)*(E[i][u_neighbor_help_robust1[j]]*dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[j]])
                #剔除一个对偶值离权重平均对偶值最远的用户 保留自身的值
                u_neighbor_help_robust1.remove(i)
                neighbor_index_robust1=u_neighbor_help_robust1[0]
                max_distance_roubust1=abs(dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[0]]-dual_variable_weight_average_robust1)
                for j in range(1,len(u_neighbor_help_robust1)):
                    if abs(dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[j]]-dual_variable_weight_average_robust1)>=max_distance_roubust1:
                        max_distance_roubust1=abs(dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[j]]-dual_variable_weight_average_robust1)
                        neighbor_index_robust1=u_neighbor_help_robust1[j]
                u_neighbor_help_robust1.remove(neighbor_index_robust1)
                u_neighbor_help_robust1.append(i)
                #计算剔除q个信息后的权重平均对偶值
                dual_variable_weight_average_robust1=0
                h_robust1=0
                for j in range(0,len(u_neighbor_help_robust1)):
                    h_robust1=h_robust1+E[i][u_neighbor_help_robust1[j]]
                for j in range(0,len(u_neighbor_help_robust1)):
                    dual_variable_weight_average_robust1=dual_variable_weight_average_robust1+(1/h_robust1)*(E[i][u_neighbor_help_robust1[j]]*dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[j]])     
                #诚实用户基于IOS鲁棒聚合后的值进行自身的对偶变量的更新 基于权重平均值
                thermal_power_station_dual_variable[i][k]=dual_variable_weight_average_robust1              
            else: #没有拜占庭邻居的用户直接进行权重聚合即可
                dual_variable_weight_average_robust1=0
                h_robust1=0
                for j in range(0,len(u_neighbor_help_robust1)):#计算当前循环中的h值
                    h_robust1=h_robust1+E[i][u_neighbor_help_robust1[j]]
                for j in range(0,len(u_neighbor_help_robust1)):
                    dual_variable_weight_average_robust1=dual_variable_weight_average_robust1+(1/h_robust1)*(E[i][u_neighbor_help_robust1[j]]*dual_variable_intermediate[u_neighbor_help_robust1[j]])     
                 #诚实用户基于IOS鲁棒聚合后的值进行自身的对偶变量的更新 基于权重平均值
                thermal_power_station_dual_variable[i][k]=dual_variable_weight_average_robust1           

        #聚合 安全的风力发电站的对偶更新
        for i in range(0,1):
            u_neighbor_help_robust1=neighbor_robust1[i+4].tolist()#将用户i的邻居序号存在辅助变量u中
            u_neighbor_help_robust1 = list(set(u_neighbor_help_robust1))
            u_neighbor_help_robust1.remove(99)
            dual_variable_weight_average_robust1=0
            h_robust1=0
            for j in range(0,len(u_neighbor_help_robust1)):
                h_robust1=h_robust1+E[i][u_neighbor_help_robust1[j]]               
            for j in range(0,len(u_neighbor_help_robust1)):
                dual_variable_weight_average_robust1=dual_variable_weight_average_robust1+(1/h_robust1)*(E[i][u_neighbor_help_robust1[j]]*dual_variable_intermediate[u_neighbor_help_robust1[j]])     
            wind_power_station_dual_variable[i][k]=dual_variable_weight_average_robust1
        #受到Byzantine攻击的风力发电站的对偶更新
        wind_power_station_dual_variable[1][k]=large_Gaussian_Byzantine_attack[k]          
        
        #安全的火力发电站计划发电量
        for i in range(0,4):
            thermal_power_station_strategy[i][k]=thermal_power_station_strategy[i][k-1]-step_size_primal*(2*thermal_power_station_eta[i]*thermal_power_station_strategy[i][k-1]+thermal_power_station_zeta[i]+(1/6)*thermal_power_station_dual_variable[i][k-1]) 
            if thermal_power_station_strategy[i][k]<=thermal_power_station_P_min[i]:
                thermal_power_station_strategy[i][k]=thermal_power_station_P_min[i]
            elif thermal_power_station_strategy[i][k]>=thermal_power_station_P_max[i]:
                thermal_power_station_strategy[i][k]=thermal_power_station_P_max[i]
        #安全的风力发电站计划发电量
        for i in range(0,1):
            wind_power_station_strategy[i][k]=wind_power_station_strategy[i][k-1]-step_size_primal*(wind_power_station_varphi[i]+wind_power_station_sigma_oe[i]+(wind_power_station_sigma_ue[i]+wind_power_station_sigma_oe[i])*math.exp(-(math.pow(wind_power_station_v_out[i],kappa_wind_speed[k-1]))/(math.pow(c_wind_speed[k-1],kappa_wind_speed[k-1])))+(-wind_power_station_sigma_ue[i]-wind_power_station_sigma_oe[i])*math.exp(-(math.pow((wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][k-1])/wind_power_station_P_r[i]),kappa_wind_speed[k-1]))/(math.pow(c_wind_speed[k-1],kappa_wind_speed[k-1])))+(1/6)*wind_power_station_dual_variable[i][k-1])
            if wind_power_station_strategy[i][k]<=wind_power_station_P_min[i]:
                wind_power_station_strategy[i][k]=wind_power_station_P_min[i]
            elif wind_power_station_strategy[i][k]>=wind_power_station_P_max[i]:
                wind_power_station_strategy[i][k]=wind_power_station_P_max[i]
        #受到Byzantine攻击的风力发电站的计划发电量
        wind_power_station_strategy[1][k]=wind_power_station_strategy[1][k-1]
        
        #安全发电站的计算总计划发电
        #火力发电量
        for i in range(0,4):
            sum_thermal_wind_power_station_strategy[0][k]=sum_thermal_wind_power_station_strategy[0][k]+thermal_power_station_strategy[i][k]
        #风力发电量
        for i in range(0,1):
            sum_thermal_wind_power_station_strategy[0][k]=sum_thermal_wind_power_station_strategy[0][k]+wind_power_station_strategy[i][k]
        
        #安全发电站的计算总发电成本
        #火力发电成本
        for i in range(0,4):
            thermal_power_station_cost[0][k]=thermal_power_station_cost[0][k]+thermal_power_station_eta[i]*thermal_power_station_strategy[i][k]*thermal_power_station_strategy[i][k]+thermal_power_station_zeta[i]*thermal_power_station_strategy[i][k]
        #风力发电成本
        for i in range(0,1):
            wind_power_station_cost[0][k]=wind_power_station_cost[0][k]+wind_power_station_varphi[i]*wind_power_station_strategy[i][k]+wind_power_station_sigma_ue[i]*((wind_power_station_P_r[i]-wind_power_station_strategy[i][k])*(math.exp(-(math.pow(wind_power_station_v_r[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k])))-math.exp(-(math.pow(wind_power_station_v_out[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k]))))+(wind_power_station_P_r[i]*wind_power_station_v_in[i]/(wind_power_station_v_r[i]-wind_power_station_v_in[i])+wind_power_station_strategy[i][k])*(math.exp(-(math.pow(wind_power_station_v_r[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k])))-math.exp(-(math.pow(wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][k])/wind_power_station_P_r[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k]))))+(wind_power_station_P_r[i]*c_wind_speed[k]/(wind_power_station_v_r[i]-wind_power_station_v_in[i]))*(sc.gammaincc(1+1/kappa_wind_speed[k],(math.pow(wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][k])/wind_power_station_P_r[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k])))*sc.gamma(1+1/kappa_wind_speed[k])-sc.gammaincc(1+1/kappa_wind_speed[k],math.pow(wind_power_station_v_r[i]/c_wind_speed[k],kappa_wind_speed[k]))*sc.gamma(1+1/kappa_wind_speed[k])))+wind_power_station_sigma_oe[i]*((wind_power_station_strategy[i][k])*(1-math.exp(-(math.pow(wind_power_station_v_in[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k])))+math.exp(-(math.pow(wind_power_station_v_out[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k]))))+(wind_power_station_P_r[i]*wind_power_station_v_in[i]/(wind_power_station_v_r[i]-wind_power_station_v_in[i])+wind_power_station_strategy[i][k])*(math.exp(-(math.pow(wind_power_station_v_in[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k])))-math.exp(-(math.pow(wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][k])/wind_power_station_P_r[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k]))))+(wind_power_station_P_r[i]*c_wind_speed[k]/(wind_power_station_v_r[i]-wind_power_station_v_in[i]))*(sc.gammaincc(1+1/kappa_wind_speed[k],(math.pow(wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][k])/wind_power_station_P_r[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k])))*sc.gamma(1+1/kappa_wind_speed[k])-sc.gammaincc(1+1/kappa_wind_speed[k],math.pow(wind_power_station_v_in[i]/c_wind_speed[k],kappa_wind_speed[k]))*sc.gamma(1+1/kappa_wind_speed[k])))
        #发电总成本
        sum_cost[0][k]=thermal_power_station_cost[0][k]+wind_power_station_cost[0][k]
        
        #输出第k次迭代中的结果 每间隔10次迭代输出一次结果
        #if (k+1)%10==0:
        print(k,"次迭代中的结果：")
        for i in range (0,4):
            print("第",(i+1),"个火力发电站的计划发电量为:",thermal_power_station_strategy[i][k])
        for i in range (0,2):
            print("第",(i+5),"个风力发电站的计划发电量为:",wind_power_station_strategy[i][k])
        print("****************************************************************************")
        for i in range (0,4):
            print("第",(i+1),"个火力发电站的对偶变量为:",thermal_power_station_dual_variable[i][k])
        for i in range (0,1):
            print("第",(i+5),"个风力发电站的对偶变量为:",wind_power_station_dual_variable[i][k])
        print("****************************************************************************")
        print("第",(6),"个受到Byzantin攻击的风力发电站的初始对偶变量为:",wind_power_station_dual_variable[1][k])
        print("****************************************************************************")
        print("安全发电站的总发电量:",sum_thermal_wind_power_station_strategy[0][k])
        print("*************************")
        print("需求侧平均用电需求:",d_power_demand[k])
        print("****************************************************************************")
        print("风速分布参数c:",c_wind_speed[k])
        print("****************************************************************************")
        print("风速分布参数kappa:",kappa_wind_speed[k])
        print("****************************************************************************")        
        print("安全发电站的总发电成本：", sum_cost[0][k])
        print("****************************************************************************")
        print("原变量迭代步长为:",step_size_primal)
        print("****************************************************************************")
        print("对偶变量迭代步长为:",step_size_dual)
        print("****************************************************************************")
        
        #step_size_primal=(pow(k+1,0.1))
        #step_size_dual=1/(pow(k+1,0.7))#我们发现在在线算法中 不能使用太小的对偶步长 不然后续算法对在线变化会不敏感 
        
        '''#尝试使用两阶段的步长
        if k<=500:
            step_size_dual=1/(pow(k+1,0.7))
        else:
            step_size_dual=0.1'''

    print(datetime.now().strftime('%Y-%m-%d %H:%M:%S.%f')[:-3])
    return None

# %%
IOS_Byzantine_attack_decentralized_economic_dispatch(thermal_power_station_strategy,wind_power_station_strategy,c_wind_speed,kappa_wind_speed,d_power_demand,thermal_power_station_dual_variable,wind_power_station_dual_variable,E,thermal_power_station_cost,wind_power_station_cost,thermal_power_station_eta,thermal_power_station_zeta,thermal_power_station_P_min,thermal_power_station_P_max,wind_power_station_varphi,wind_power_station_sigma_ue,wind_power_station_sigma_oe,wind_power_station_P_min,wind_power_station_P_max,sum_thermal_wind_power_station_strategy,step_size_primal,step_size_dual)
# Out:
# ***************************attack_free_online_decentralized_economic_dispatch*****************************
# 相关变量初始值为：
# 第 1 个火力发电站的初始计划发电量为: 70.0
# 第 2 个火力发电站的初始计划发电量为: 70.0
# 第 3 个火力发电站的初始计划发电量为: 70.0
# 第 4 个火力发电站的初始计划发电量为: 70.0
# 第 5 个风力发电站的初始计划发电量为: 70.0
# 第 6 个风力发电站的初始计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的初始对偶变量为: 0.0
# 第 2 个火力发电站的初始对偶变量为: 0.0
# 第 3 个火力发电站的初始对偶变量为: 0.0
# 第 4 个火力发电站的初始对偶变量为: 0.0
# 第 5 个风力发电站的初始对偶变量为: 0.0
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -4.09660692
# ****************************************************************************
# 安全发电站的初始总发电量: 350.0
# *************************
# 需求侧平均用电需求: 72.62781256
# ****************************************************************************
# 风速分布参数c: 8.301041
# ****************************************************************************
# 风速分布参数kappa: 2.66836324
# ****************************************************************************
# 安全发电站的总发电成本： 2678.3230777617387
# ****************************************************************************
# 原变量迭代步长为: 1
# *****************************************************************************
# 对偶变量迭代步长为: 3
# *****************************************************************************
# 1 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 58.55
# 第 2 个火力发电站的计划发电量为: 58.8
# 第 3 个火力发电站的计划发电量为: 56.05
# 第 4 个火力发电站的计划发电量为: 58.25
# 第 5 个风力发电站的计划发电量为: 55.87809981840451
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -1.3139062799999959
# 第 2 个火力发电站的对偶变量为: -1.3139062799999959
# 第 3 个火力发电站的对偶变量为: -1.3139062799999959
# 第 4 个火力发电站的对偶变量为: -1.313906279999996
# 第 5 个风力发电站的对偶变量为: -1.3139062799999959
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -9.23941845
# ****************************************************************************
# 安全发电站的总发电量: 287.5280998184045
# *************************
# 需求侧平均用电需求: 64.01095166
# ****************************************************************************
# 风速分布参数c: 14.69554708
# ****************************************************************************
# 风速分布参数kappa: 2.10218816
# ****************************************************************************
# 安全发电站的总发电成本： 2023.6137796078897
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 2 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 50.0
# 第 2 个火力发电站的计划发电量为: 49.33098438
# 第 3 个火力发电站的计划发电量为: 44.89973438
# 第 4 个火力发电站的计划发电量为: 48.18773438
# 第 5 个风力发电站的计划发电量为: 52.69634642699502
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -4.626685875327711
# 第 2 个火力发电站的对偶变量为: -4.931418209292329
# 第 3 个火力发电站的对偶变量为: -4.481762633559496
# 第 4 个火力发电站的对偶变量为: -4.819011821652062
# 第 5 个风力发电站的对偶变量为: -4.626685875327711
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -14.20669738
# ****************************************************************************
# 安全发电站的总发电量: 245.11479956699503
# *************************
# 需求侧平均用电需求: 72.48160172
# ****************************************************************************
# 风速分布参数c: 11.73462138
# ****************************************************************************
# 风速分布参数kappa: 2.30593756
# ****************************************************************************
# 安全发电站的总发电成本： 1565.9235112271647
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 3 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 50.0
# 第 2 个火力发电站的计划发电量为: 41.74320452358205
# 第 3 个火力发电站的计划发电量为: 36.34024395862658
# 第 4 个火力发电站的计划发电量为: 39.967436219442014
# 第 5 个风力发电站的计划发电量为: 49.947480405150586
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -16.02186346238847
# 第 2 个火力发电站的对偶变量为: -16.112885192580524
# 第 3 个火力发电站的对偶变量为: -16.061823433522456
# 第 4 个火力发电站的对偶变量为: -16.83451060863107
# 第 5 个风力发电站的对偶变量为: -16.02186346238847
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -9.20396922
# ****************************************************************************
# 安全发电站的总发电量: 217.99836510680126
# *************************
# 需求侧平均用电需求: 74.35324129
# ****************************************************************************
# 风速分布参数c: 20.88797006
# ****************************************************************************
# 风速分布参数kappa: 2.49450248
# ****************************************************************************
# 安全发电站的总发电成本： 1594.4681873382924
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 4 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 50.0
# 第 2 个火力发电站的计划发电量为: 37.04335277832856
# 第 3 个火力发电站的计划发电量为: 31.294269398534404
# 第 4 个火力发电站的计划发电量为: 34.77725846011694
# 第 5 个风力发电站的计划发电量为: 47.703369505370866
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -30.174078480783344
# 第 2 个火力发电站的对偶变量为: -31.214599670155895
# 第 3 个火力发电站的对偶变量为: -31.036005815503405
# 第 4 个火力发电站的对偶变量为: -33.56776732851685
# 第 5 个风力发电站的对偶变量为: -30.174078480783344
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -18.0954435
# ****************************************************************************
# 安全发电站的总发电量: 200.81825014235076
# *************************
# 需求侧平均用电需求: 73.36237628
# ****************************************************************************
# 风速分布参数c: 17.01236112
# ****************************************************************************
# 风速分布参数kappa: 2.63537814
# ****************************************************************************
# 安全发电站的总发电成本： 1323.0017472695786
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 5 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 50.0
# 第 2 个火力发电站的计划发电量为: 35.49493343161352
# 第 3 个火力发电站的计划发电量为: 29.677497195722772
# 第 4 个火力发电站的计划发电量为: 33.02472904068846
# 第 5 个风力发电站的计划发电量为: 52.35477822541546
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -45.31609444507084
# 第 2 个火力发电站的对偶变量为: -47.39376451257033
# 第 3 个火力发电站的对偶变量为: -47.09415522181382
# 第 4 个火力发电站的对偶变量为: -51.29057359362031
# 第 5 个风力发电站的对偶变量为: -45.31609444507084
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -5.96549267
# ****************************************************************************
# 安全发电站的总发电量: 200.55193789344023
# *************************
# 需求侧平均用电需求: 72.02509011
# ****************************************************************************
# 风速分布参数c: 11.53887689
# ****************************************************************************
# 风速分布参数kappa: 2.44466253
# ****************************************************************************
# 安全发电站的总发电成本： 1201.0280874511282
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 6 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 50.0
# 第 2 个火力发电站的计划发电量为: 36.85207817044075
# 第 3 个火力发电站的计划发电量为: 31.036186084816364
# 第 4 个火力发电站的计划发电量为: 34.44506684287246
# 第 5 个风力发电站的计划发电量为: 56.80010718217035
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -59.72137579970135
# 第 2 个火力发电站的对偶变量为: -62.271036116988974
# 第 3 个火力发电站的对偶变量为: -61.98103526642663
# 第 4 个火力发电站的对偶变量为: -67.46230363101981
# 第 5 个风力发电站的对偶变量为: -59.72137579970135
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -11.65296038
# ****************************************************************************
# 安全发电站的总发电量: 209.1334382802999
# *************************
# 需求侧平均用电需求: 71.92071638
# ****************************************************************************
# 风速分布参数c: 20.17759
# ****************************************************************************
# 风速分布参数kappa: 2.96946266
# ****************************************************************************
# 安全发电站的总发电成本： 1440.1641291315736
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 7 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 51.20356263328355
# 第 2 个火力发电站的计划发电量为: 40.505553636929406
# 第 3 个火力发电站的计划发电量为: 34.624664203529775
# 第 4 个火力发电站的计划发电量为: 38.38315075935003
# 第 5 个风力发电站的计划发电量为: 64.24662027071965
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -73.32217314429516
# 第 2 个火力发电站的对偶变量为: -75.97534929037032
# 第 3 个火力发电站的对偶变量为: -75.68436982428128
# 第 4 个火力发电站的对偶变量为: -81.57074980675432
# 第 5 个风力发电站的对偶变量为: -73.32217314429516
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -16.2645874
# ****************************************************************************
# 安全发电站的总发电量: 228.96355150381243
# *************************
# 需求侧平均用电需求: 72.93331067
# ****************************************************************************
# 风速分布参数c: 12.95856003
# ****************************************************************************
# 风速分布参数kappa: 2.36446438
# ****************************************************************************
# 安全发电站的总发电成本： 1374.488907208166
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 8 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 54.511443868506134
# 第 2 个火力发电站的计划发电量为: 45.94986211100566
# 第 3 个火力发电站的计划发电量为: 39.83316296325698
# 第 4 个火力发电站的计划发电量为: 44.180381882223664
# 第 5 个风力发电站的计划发电量为: 72.84579217018593
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -85.49265580056579
# 第 2 个火力发电站的对偶变量为: -88.13701405407271
# 第 3 个火力发电站的对偶变量为: -87.8425320330717
# 第 4 个火力发电站的对偶变量为: -93.93700841172159
# 第 5 个风力发电站的对偶变量为: -85.49265580056579
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -17.09768272
# ****************************************************************************
# 安全发电站的总发电量: 257.3206429951784
# *************************
# 需求侧平均用电需求: 65.05998342
# ****************************************************************************
# 风速分布参数c: 4.42860238
# ****************************************************************************
# 风速分布参数kappa: 2.42410411
# ****************************************************************************
# 安全发电站的总发电成本： 2651.539806644669
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 9 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 59.40117491301877
# 第 2 个火力发电站的计划发电量为: 52.68613306836534
# 第 3 个火力发电站的计划发电量为: 46.10444982056639
# 第 4 个火力发电站的计划发电量为: 51.31400221556597
# 第 5 个风力发电站的计划发电量为: 57.006375560249005
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -90.90928821835885
# 第 2 个火力发电站的对偶变量为: -93.54497382908309
# 第 3 个火力发电站的对偶变量为: -93.23777927364571
# 第 4 个火力发电站的对偶变量为: -99.48865986842976
# 第 5 个风力发电站的对偶变量为: -90.90928821835885
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -13.01555695
# ****************************************************************************
# 安全发电站的总发电量: 266.5121355777655
# *************************
# 需求侧平均用电需求: 65.89481815
# ****************************************************************************
# 风速分布参数c: 13.39240335
# ****************************************************************************
# 风速分布参数kappa: 2.3728007
# ****************************************************************************
# 安全发电站的总发电成本： 1739.1702582882117
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 10 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 64.53356433615437
# 第 2 个火力发电站的计划发电量为: 59.41433407564987
# 第 3 个火力发电站的计划发电量为: 52.11475648270256
# 第 4 个火力发电站的计划发电量为: 58.48119525002518
# 第 5 个风力发电站的计划发电量为: 69.84278589005521
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -96.94461752603607
# 第 2 个火力发电站的对偶变量为: -98.80111212134742
# 第 3 个火力发电站的对偶变量为: -98.46949338222204
# 第 4 个火力发电站的对偶变量为: -102.0935417194023
# 第 5 个风力发电站的对偶变量为: -96.94461752603607
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -8.6044179
# ****************************************************************************
# 安全发电站的总发电量: 304.3866360345872
# *************************
# 需求侧平均用电需求: 82.22889118
# ****************************************************************************
# 风速分布参数c: 3.71616054
# ****************************************************************************
# 风速分布参数kappa: 2.52674506
# ****************************************************************************
# 安全发电站的总发电成本： 3265.5950257030418
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 11 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 69.97896940511288
# 第 2 个火力发电站的计划发电量为: 66.1102509956617
# 第 3 个火力发电站的计划发电量为: 57.88510876377293
# 第 4 个火力发电站的计划发电量为: 65.18663613033908
# 第 5 个风力发电站的计划发电量为: 55.12556420834876
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -106.95030418487595
# 第 2 个火力发电站的对偶变量为: -108.83701812974188
# 第 3 个火力发电站的对偶变量为: -108.46822202823459
# 第 4 个火力发电站的对偶变量为: -112.38627391246872
# 第 5 个风力发电站的对偶变量为: -106.95030418487595
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -15.88658941
# ****************************************************************************
# 安全发电站的总发电量: 314.2865295032354
# *************************
# 需求侧平均用电需求: 72.39439433
# ****************************************************************************
# 风速分布参数c: 22.04759493
# ****************************************************************************
# 风速分布参数kappa: 2.67853757
# ****************************************************************************
# 安全发电站的总发电成本： 2538.151048313144
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 12 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 76.35685923290197
# 第 2 个火力发电站的计划发电量为: 73.57487013287101
# 第 3 个火力发电站的计划发电量为: 64.2544006471807
# 第 4 个火力发电站的计划发电量为: 72.76935226612481
# 第 5 个风力发电站的计划发电量为: 67.04683373044585
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -112.02739121370246
# 第 2 个火力发电站的对偶变量为: -113.271609717711
# 第 3 个火力发电站的对偶变量为: -112.85551178407304
# 第 4 个火力发电站的对偶变量为: -114.44421761019672
# 第 5 个风力发电站的对偶变量为: -112.02739121370246
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -10.94763918
# ****************************************************************************
# 安全发电站的总发电量: 354.0023160095244
# *************************
# 需求侧平均用电需求: 59.43051398
# ****************************************************************************
# 风速分布参数c: 22.07798354
# ****************************************************************************
# 风速分布参数kappa: 2.67292298
# ****************************************************************************
# 安全发电站的总发电成本： 2939.1332409044207
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 13 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 82.7199151054106
# 第 2 个火力发电站的计划发电量为: 80.77086428455192
# 第 3 个火力发电站的计划发电量为: 70.17658849146444
# 第 4 个火力发电站的计划发电量为: 79.74721950122533
# 第 5 个风力发电站的计划发电量为: 79.33361876313191
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -106.28693022312274
# 第 2 个火力发电站的对偶变量为: -106.52349088081158
# 第 3 个火力发电站的对偶变量为: -106.29865395273202
# 第 4 个火力发电站的对偶变量为: -107.03135879716709
# 第 5 个风力发电站的对偶变量为: -106.28693022312274
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -8.4579762
# ****************************************************************************
# 安全发电站的总发电量: 392.74820614578425
# *************************
# 需求侧平均用电需求: 66.57067559
# ****************************************************************************
# 风速分布参数c: 24.23535384
# ****************************************************************************
# 风速分布参数kappa: 2.6829301
# ****************************************************************************
# 安全发电站的总发电成本： 3529.1184430236826
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 14 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 87.26721493670063
# 第 2 个火力发电站的计划发电量为: 85.87071275293934
# 第 3 个火力发电站的计划发电量为: 73.91036194599886
# 第 4 个火力发电站的计划发电量为: 84.6173768631
# 第 5 个风力发电站的计划发电量为: 87.5237215007287
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -99.73970233443929
# 第 2 个火力发电站的对偶变量为: -99.39465468475731
# 第 3 个火力发电站的对偶变量为: -99.28152505094955
# 第 4 个火力发电站的对偶变量为: -99.86282305965821
# 第 5 个风力发电站的对偶变量为: -99.73970233443929
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -8.80487891
# ****************************************************************************
# 安全发电站的总发电量: 419.18938799946756
# *************************
# 需求侧平均用电需求: 69.25657964
# ****************************************************************************
# 风速分布参数c: 14.77327144
# ****************************************************************************
# 风速分布参数kappa: 2.06624199
# ****************************************************************************
# 安全发电站的总发电成本： 3403.381390867588
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 15 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 90.10942464265258
# 第 2 个火力发电站的计划发电量为: 89.09394231208542
# 第 3 个火力发电站的计划发电量为: 75.783865827814
# 第 4 个火力发电站的计划发电量为: 87.68400859848887
# 第 5 个风力发电站的计划发电量为: 96.83858821275483
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -91.5941331042386
# 第 2 个火力发电站的对偶变量为: -91.08943375914052
# 第 3 个火力发电站的对偶变量为: -90.96794133528543
# 第 4 个火力发电站的对偶变量为: -91.60450788175635
# 第 5 个风力发电站的对偶变量为: -91.5941331042386
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -5.72045939
# ****************************************************************************
# 安全发电站的总发电量: 439.5098295937957
# *************************
# 需求侧平均用电需求: 62.4132554
# ****************************************************************************
# 风速分布参数c: 22.01070443
# ****************************************************************************
# 风速分布参数kappa: 2.82899266
# ****************************************************************************
# 安全发电站的总发电成本： 3846.5905190677727
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 16 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 91.21034116660091
# 第 2 个火力发电站的计划发电量为: 90.49783239314397
# 第 3 个火力发电站的计划发电量为: 75.92517420554931
# 第 4 个火力发电站的计划发电量为: 88.99092550397049
# 第 5 个风力发电站的计划发电量为: 105.03688353666459
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -77.69959736347562
# 第 2 个火力发电站的对偶变量为: -77.26766597795367
# 第 3 个火力发电站的对偶变量为: -77.1322775605041
# 第 4 个火力发电站的对偶变量为: -78.38415520376824
# 第 5 个风力发电站的对偶变量为: -77.69959736347562
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -18.93383069
# ****************************************************************************
# 安全发电站的总发电量: 451.6611568059293
# *************************
# 需求侧平均用电需求: 68.27939592
# ****************************************************************************
# 风速分布参数c: 24.26368821
# ****************************************************************************
# 风速分布参数kappa: 2.29481562
# ****************************************************************************
# 安全发电站的总发电成本： 4303.226653741905
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 17 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 89.8468780030224
# 第 2 个火力发电站的计划发电量为: 89.40856934972848
# 第 3 个火力发电站的计划发电量为: 73.73439657094004
# 第 4 个火力发电站的计划发电量为: 87.93108568326889
# 第 5 个风力发电站的计划发电量为: 106.09490011375385
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -65.2990027366578
# 第 2 个火力发电站的对偶变量为: -65.25301755004553
# 第 3 个火力发电站的对偶变量为: -65.04561830529843
# 第 4 个火力发电站的对偶变量为: -67.31810513283344
# 第 5 个风力发电站的对偶变量为: -65.2990027366578
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -9.79297611
# ****************************************************************************
# 安全发电站的总发电量: 447.01582972071367
# *************************
# 需求侧平均用电需求: 74.37551359
# ****************************************************************************
# 风速分布参数c: 17.54487156
# ****************************************************************************
# 风速分布参数kappa: 2.9754401
# ****************************************************************************
# 安全发电站的总发电成本： 3404.9959882682824
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 18 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 86.60071659539068
# 第 2 个火力发电站的计划发电量为: 86.46391541252272
# 第 3 个火力发电站的计划发电量为: 69.93446958953254
# 第 4 个火力发电站的计划发电量为: 85.15938416166586
# 第 5 个风力发电站的计划发电量为: 113.58128144527595
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -56.4966271901736
# 第 2 个火力发电站的对偶变量为: -56.901762408638675
# 第 3 个火力发电站的对偶变量为: -56.59091416938654
# 第 4 个火力发电站的对偶变量为: -59.62623971645317
# 第 5 个风力发电站的对偶变量为: -56.4966271901736
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -7.0281088
# ****************************************************************************
# 安全发电站的总发电量: 441.7397672043878
# *************************
# 需求侧平均用电需求: 76.41692674
# ****************************************************************************
# 风速分布参数c: 4.81637973
# ****************************************************************************
# 风速分布参数kappa: 2.19682287
# ****************************************************************************
# 安全发电站的总发电成本： 5339.045915946543
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 19 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 82.32572438670853
# 第 2 个火力发电站的计划发电量为: 82.5249138999386
# 第 3 个火力发电站的计划发电量为: 65.42841174370011
# 第 4 个火力发电站的计划发电量为: 81.45216776086649
# 第 5 个风力发电站的计划发电量为: 92.21374809476254
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -48.99895735895733
# 第 2 个火力发电站的对偶变量为: -49.99694406719784
# 第 3 个火力发电站的对偶变量为: -49.62265856705123
# 第 4 个火力发电站的对偶变量为: -54.21867823501938
# 第 5 个风力发电站的对偶变量为: -48.99895735895733
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -7.41537487
# ****************************************************************************
# 安全发电站的总发电量: 403.9449658859763
# *************************
# 需求侧平均用电需求: 63.07056204
# ****************************************************************************
# 风速分布参数c: 22.76341842
# ****************************************************************************
# 风速分布参数kappa: 2.30087244
# ****************************************************************************
# 安全发电站的总发电成本： 3555.575277309924
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 20 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 77.37824448766243
# 第 2 个火力发电站的计划发电量为: 77.96687453464652
# 第 3 个火力发电站的计划发电量为: 60.594598665624126
# 第 4 个火力发电站的计划发电量为: 77.30709316326141
# 第 5 个风力发电站的计划发电量为: 90.57478760604305
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -39.62378344377687
# 第 2 个火力发电站的对偶变量为: -40.732238690066886
# 第 3 个火力发电站的对偶变量为: -40.20496735286086
# 第 4 个火力发电站的对偶变量为: -43.657288644931754
# 第 5 个风力发电站的对偶变量为: -39.62378344377687
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -8.75477426
# ****************************************************************************
# 安全发电站的总发电量: 383.82159845723754
# *************************
# 需求侧平均用电需求: 72.76413739
# ****************************************************************************
# 风速分布参数c: 7.10546984
# ****************************************************************************
# 风速分布参数kappa: 2.49300975
# ****************************************************************************
# 安全发电站的总发电成本： 3468.497623066014
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 21 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 71.53614538912414
# 第 2 个火力发电站的计划发电量为: 72.48005292081372
# 第 3 个火力发电站的计划发电量为: 55.08542580462714
# 第 4 个火力发电站的计划发电量为: 71.91992129200904
# 第 5 个风力发电站的计划发电量为: 72.98129271459015
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -37.09119771223748
# 第 2 个火力发电站的对偶变量为: -37.62476889235723
# 第 3 个火力发电站的对偶变量为: -37.264083837835805
# 第 4 个火力发电站的对偶变量为: -40.428542225313265
# 第 5 个风力发电站的对偶变量为: -37.09119771223748
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -7.21969714
# ****************************************************************************
# 安全发电站的总发电量: 344.0028381211642
# *************************
# 需求侧平均用电需求: 72.47977434
# ****************************************************************************
# 风速分布参数c: 20.89161523
# ****************************************************************************
# 风速分布参数kappa: 2.7421258
# ****************************************************************************
# 安全发电站的总发电成本： 2691.0072451027827
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 22 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 66.0606320469653
# 第 2 个火力发电站的计划发电量为: 67.21604059189674
# 第 3 个火力发电站的计划发电量为: 50.105302670410424
# 第 4 个火力发电站的计划发电量为: 66.66802150139345
# 第 5 个风力发电站的计划发电量为: 74.25554085515884
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -38.783060587268636
# 第 2 个火力发电站的对偶变量为: -38.69136609316592
# 第 3 个火力发电站的对偶变量为: -38.34965189012597
# 第 4 个火力发电站的对偶变量为: -39.804346951527194
# 第 5 个风力发电站的对偶变量为: -38.783060587268636
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -8.54206195
# ****************************************************************************
# 安全发电站的总发电量: 324.3055376658248
# *************************
# 需求侧平均用电需求: 72.35827036
# ****************************************************************************
# 风速分布参数c: 4.73395435
# ****************************************************************************
# 风速分布参数kappa: 2.61322499
# ****************************************************************************
# 安全发电站的总发电成本： 3234.111186974399
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 23 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 61.60629015183642
# 第 2 个火力发电站的计划发电量为: 62.84043612751834
# 第 3 个火力发电站的计划发电量为: 46.227430324738826
# 第 4 个火力发电站的计划发电量为: 61.9685766389738
# 第 5 个风力发电站的计划发电量为: 50.78239142608979
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -41.895089734400436
# 第 2 个火力发电站的对偶变量为: -41.14820596430497
# 第 3 个火力发电站的对偶变量为: -40.99446691307854
# 第 4 个火力发电站的对偶变量为: -42.17785615130234
# 第 5 个风力发电站的对偶变量为: -41.895089734400436
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -8.18893607
# ****************************************************************************
# 安全发电站的总发电量: 283.4251246691572
# *************************
# 需求侧平均用电需求: 71.12392002
# ****************************************************************************
# 风速分布参数c: 18.17359002
# ****************************************************************************
# 风速分布参数kappa: 2.07787691
# ****************************************************************************
# 安全发电站的总发电成本： 2121.4833935971396
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 24 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 58.27195593707191
# 第 2 个火力发电站的计划发电量为: 59.46501157768752
# 第 3 个火力发电站的计划发电量为: 43.5077668668419
# 第 4 个火力发电站的计划发电量为: 58.2521472509858
# 第 5 个风力发电站的计划发电量为: 53.21153921325515
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -49.06172572351139
# 第 2 个火力发电站的对偶变量为: -48.80462285406036
# 第 3 个火力发电站的对偶变量为: -48.05199335744931
# 第 4 个火力发电站的对偶变量为: -46.25672384339751
# 第 5 个风力发电站的对偶变量为: -49.06172572351139
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -11.28797568
# ****************************************************************************
# 安全发电站的总发电量: 272.7084208458423
# *************************
# 需求侧平均用电需求: 76.7139357
# ****************************************************************************
# 风速分布参数c: 4.48706041
# ****************************************************************************
# 风速分布参数kappa: 2.43670989
# ****************************************************************************
# 安全发电站的总发电成本： 2384.6173657588542
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 25 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 56.582196172819096
# 第 2 个火力发电站的计划发电量为: 57.821338823709766
# 第 3 个火力发电站的计划发电量为: 42.467495556051034
# 第 4 个火力发电站的计划发电量为: 55.68008281851216
# 第 5 个风力发电站的计划发电量为: 33.8659876171158
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -59.86254382798421
# 第 2 个火力发电站的对偶变量为: -58.54604253931845
# 第 3 个火力发电站的对偶变量为: -58.17014612342302
# 第 4 个火力发电站的对偶变量为: -56.333339678033546
# 第 5 个风力发电站的对偶变量为: -59.86254382798421
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -8.97148206
# ****************************************************************************
# 安全发电站的总发电量: 246.41710098820786
# *************************
# 需求侧平均用电需求: 61.05044826
# ****************************************************************************
# 风速分布参数c: 11.55331759
# ****************************************************************************
# 风速分布参数kappa: 2.5075835
# ****************************************************************************
# 安全发电站的总发电成本： 1698.1067870135255
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 26 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 56.920690327485886
# 第 2 个火力发电站的计划发电量为: 58.02313183906202
# 第 3 个火力发电站的计划发电量为: 43.306033232085426
# 第 4 个火力发电站的计划发电量为: 55.10896241253707
# 第 5 个风力发电站的计划发电量为: 43.550711822713794
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -65.78732887636713
# 第 2 个火力发电站的对偶变量为: -63.4074018352914
# 第 3 个火力发电站的对偶变量为: -62.596051512271224
# 第 4 个火力发电站的对偶变量为: -59.427562904755995
# 第 5 个风力发电站的对偶变量为: -65.78732887636713
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -8.72039781
# ****************************************************************************
# 安全发电站的总发电量: 256.9095296338842
# *************************
# 需求侧平均用电需求: 76.57534104
# ****************************************************************************
# 风速分布参数c: 11.11125981
# ****************************************************************************
# 风速分布参数kappa: 2.9635753
# ****************************************************************************
# 安全发电站的总发电成本： 1679.1913151499991
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 27 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 58.200951946003144
# 第 2 个火力发电站的计划发电量为: 59.007909346670544
# 第 3 个火力发电站的计划发电量为: 44.72709233619483
# 第 4 个火力发电站的计划发电量为: 55.12493592842927
# 第 5 个风力发电站的计划发电量为: 53.94513977759775
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -77.45485592988726
# 第 2 个火力发电站的对偶变量为: -75.49605298095086
# 第 3 个火力发电站的对偶变量为: -74.76831597745785
# 第 4 个火力发电站的对偶变量为: -71.26070246308711
# 第 5 个风力发电站的对偶变量为: -77.45485592988726
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -10.43346352
# ****************************************************************************
# 安全发电站的总发电量: 271.0060293348955
# *************************
# 需求侧平均用电需求: 79.54768147
# ****************************************************************************
# 风速分布参数c: 13.22114577
# ****************************************************************************
# 风速分布参数kappa: 2.23501543
# ****************************************************************************
# 安全发电站的总发电成本： 1819.2977890998309
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 28 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 61.25296608827393
# 第 2 个火力发电站的计划发电量为: 61.87451708169516
# 第 3 个火力发电站的计划发电量为: 47.91396625024176
# 第 4 个火力发电站的计划发电量为: 57.11110268122346
# 第 5 个风力发电站的计划发电量为: 64.0850807385693
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -88.81329188465583
# 第 2 个火力发电站的对偶变量为: -87.54919980200289
# 第 3 个火力发电站的对偶变量为: -87.05094298815555
# 第 4 个火力发电站的对偶变量为: -84.41960979822537
# 第 5 个风力发电站的对偶变量为: -88.81329188465583
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -16.57515529
# ****************************************************************************
# 安全发电站的总发电量: 292.2376328400036
# *************************
# 需求侧平均用电需求: 70.77558923
# ****************************************************************************
# 风速分布参数c: 16.55283022
# ****************************************************************************
# 风速分布参数kappa: 2.00468584
# ****************************************************************************
# 安全发电站的总发电成本： 2094.863946070129
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 29 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 65.78603098046625
# 第 2 个火力发电站的计划发电量为: 66.36299057600013
# 第 3 个火力发电站的计划发电量为: 52.55837299197296
# 第 4 个火力发电站的计划发电量为: 61.04214981244142
# 第 5 个风力发电站的计划发电量为: 73.60853428430427
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -93.51109626346121
# 第 2 个火力发电站的对偶变量为: -92.30568262134233
# 第 3 个火力发电站的对偶变量为: -92.13111869877395
# 第 4 个火力发电站的对偶变量为: -91.37455484060331
# 第 5 个风力发电站的对偶变量为: -93.51109626346121
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -11.53092105
# ****************************************************************************
# 安全发电站的总发电量: 319.358078645185
# *************************
# 需求侧平均用电需求: 75.70722657
# ****************************************************************************
# 风速分布参数c: 7.5123474
# ****************************************************************************
# 风速分布参数kappa: 2.84390111
# ****************************************************************************
# 安全发电站的总发电成本： 2407.529805647262
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 30 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 70.49009950868017
# 第 2 个火力发电站的计划发电量为: 71.0382672851305
# 第 3 个火力发电站的计划发电量为: 57.19026043825362
# 第 4 个火力发电站的计划发电量为: 65.64097355932013
# 第 5 个风力发电站的计划发电量为: 70.6422347787949
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -97.75506284902866
# 第 2 个火力发电站的对偶变量为: -97.26387795153711
# 第 3 个火力发电站的对偶变量为: -97.07142395327239
# 第 4 个火力发电站的对偶变量为: -97.99207494241791
# 第 5 个风力发电站的对偶变量为: -97.75506284902866
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -16.89157044
# ****************************************************************************
# 安全发电站的总发电量: 335.0018355701793
# *************************
# 需求侧平均用电需求: 67.43684589
# ****************************************************************************
# 风速分布参数c: 6.9741147
# ****************************************************************************
# 风速分布参数kappa: 2.01470627
# ****************************************************************************
# 安全发电站的总发电成本： 2798.4488682015945
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 31 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 75.26644654984646
# 第 2 个火力发电站的计划发电量为: 75.90874752689408
# 第 3 个火力发电站的计划发电量为: 61.78863291605543
# 第 4 个火力发电站的计划发电量为: 70.7678643548081
# 第 5 个风力发电站的计划发电量为: 67.22396200791474
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -96.8597165631763
# 第 2 个火力发电站的对偶变量为: -97.01600703181008
# 第 3 个火力发电站的对偶变量为: -96.63548933594193
# 第 4 个火力发电站的对偶变量为: -97.7243034377014
# 第 5 个风力发电站的对偶变量为: -96.8597165631763
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -8.73524371
# ****************************************************************************
# 安全发电站的总发电量: 350.9556533555188
# *************************
# 需求侧平均用电需求: 64.79238622
# ****************************************************************************
# 风速分布参数c: 23.88060792
# ****************************************************************************
# 风速分布参数kappa: 2.21015256
# ****************************************************************************
# 安全发电站的总发电成本： 3043.6443929773786
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 32 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 79.24876235947991
# 第 2 个火力发电站的计划发电量为: 80.08040111606505
# 第 3 个火力发电站的计划发电量为: 65.46365071590883
# 第 4 个火力发电站的计划发电量为: 75.20926521674065
# 第 5 个风力发电站的计划发电量为: 73.40414023891574
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -93.63558332284812
# 第 2 个火力发电站的对偶变量为: -93.79235265027563
# 第 3 个火力发电站的对偶变量为: -93.32717807669098
# 第 4 个火力发电站的对偶变量为: -93.60934449171984
# 第 5 个风力发电站的对偶变量为: -93.63558332284812
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -8.47049405
# ****************************************************************************
# 安全发电站的总发电量: 373.4062196471101
# *************************
# 需求侧平均用电需求: 79.20664696
# ****************************************************************************
# 风速分布参数c: 15.04406637
# ****************************************************************************
# 风速分布参数kappa: 2.84368377
# ****************************************************************************
# 安全发电站的总发电成本： 2726.7730043615425
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 33 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 82.15610999475814
# 第 2 个火力发电站的计划发电量为: 83.1516057404422
# 第 3 个火力发电站的计划发电量为: 67.90740501291418
# 第 4 个火力发电站的计划发电量为: 78.4096644799347
# 第 5 个风力发电站的计划发电量为: 87.84785029209766
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -95.31866587911708
# 第 2 个火力发电站的对偶变量为: -95.04660785044521
# 第 3 个火力发电站的对偶变量为: -94.6930710260975
# 第 4 个火力发电站的对偶变量为: -94.75368872456573
# 第 5 个风力发电站的对偶变量为: -95.31866587911708
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -13.07606569
# ****************************************************************************
# 安全发电站的总发电量: 399.4726355201469
# *************************
# 需求侧平均用电需求: 71.90639999
# ****************************************************************************
# 风速分布参数c: 19.92973653
# ****************************************************************************
# 风速分布参数kappa: 2.02497384
# ****************************************************************************
# 安全发电站的总发电成本： 3388.6748745956884
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 34 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 84.95147945865197
# 第 2 个火力发电站的计划发电量为: 86.01724027389004
# 第 3 个火力发电站的计划发电量为: 70.12671358987464
# 第 4 个火力发电站的计划发电量为: 81.40073787403716
# 第 5 个风力发电站的计划发电量为: 94.84567261284289
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -90.13686631699895
# 第 2 个火力发电站的对偶变量为: -89.77219178049272
# 第 3 个火力发电站的对偶变量为: -89.54119952918695
# 第 4 个火力发电站的对偶变量为: -90.68861316709548
# 第 5 个风力发电站的对偶变量为: -90.13686631699895
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -9.99840594
# ****************************************************************************
# 安全发电站的总发电量: 417.34184380929673
# *************************
# 需求侧平均用电需求: 72.83572783
# ****************************************************************************
# 风速分布参数c: 18.72716024
# ****************************************************************************
# 风速分布参数kappa: 2.20984039
# ****************************************************************************
# 安全发电站的总发电成本： 3441.464243856494
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 35 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 86.50584078456711
# 第 2 个火力发电站的计划发电量为: 87.61694480033033
# 第 3 个火力发电站的计划发电量为: 71.07680483061232
# 第 4 个火力发电站的计划发电量为: 83.3404145009651
# 第 5 个风力发电站的计划发电量为: 102.4114931938498
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -83.47185865712731
# 第 2 个火力发电站的对偶变量为: -83.64315718513396
# 第 3 个火力发电站的对偶变量为: -83.28516570487068
# 第 4 个火力发电站的对偶变量为: -85.31391637225302
# 第 5 个风力发电站的对偶变量为: -83.47185865712731
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -11.09397655
# ****************************************************************************
# 安全发电站的总发电量: 430.9514981103247
# *************************
# 需求侧平均用电需求: 66.23133285
# ****************************************************************************
# 风速分布参数c: 6.39076728
# ****************************************************************************
# 风速分布参数kappa: 2.33880209
# ****************************************************************************
# 安全发电站的总发电成本： 4463.942897289404
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 36 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 86.73952872150511
# 第 2 个火力发电站的计划发电量为: 87.97918344980806
# 第 3 个火力发电站的计划发电量为: 70.80845688776083
# 第 4 个火力发电站的计划发电量为: 84.14184875038663
# 第 5 个风力发电站的计划发电量为: 88.29565415974072
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -72.11079259526213
# 第 2 个火力发电站的对偶变量为: -72.7938067750261
# 第 3 个火力发电站的对偶变量为: -72.37113876844384
# 第 4 个火力发电站的对偶变量为: -75.53513982281117
# 第 5 个风力发电站的对偶变量为: -72.11079259526213
# ...
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 988 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 65.83458067283041
# 第 2 个火力发电站的计划发电量为: 66.85985108743274
# 第 3 个火力发电站的计划发电量为: 50.306225875407286
# 第 4 个火力发电站的计划发电量为: 61.27650220185748
# 第 5 个风力发电站的计划发电量为: 22.98108167604298
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -74.80833591450187
# 第 2 个火力发电站的对偶变量为: -68.91511822157055
# 第 3 个火力发电站的对偶变量为: -68.07288462329835
# 第 4 个火力发电站的对偶变量为: -64.66865857893376
# 第 5 个风力发电站的对偶变量为: -74.80833591450187
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -15.85193881
# ****************************************************************************
# 安全发电站的总发电量: 267.2582415135709
# *************************
# 需求侧平均用电需求: 63.41616792
# ****************************************************************************
# 风速分布参数c: 7.46037989
# ****************************************************************************
# 风速分布参数kappa: 2.06906595
# ****************************************************************************
# 安全发电站的总发电成本： 1918.6493250824624
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 989 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 67.41496826774862
# 第 2 个火力发电站的计划发电量为: 67.56962422755775
# 第 3 个火力发电站的计划发电量为: 51.345054859006666
# 第 4 个火力发电站的计划发电量为: 61.39504918978092
# 第 5 个风力发电站的计划发电量为: 29.33254273310177
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -78.52586200803373
# 第 2 个火力发电站的对偶变量为: -71.3910510261457
# 第 3 个火力发电站的对偶变量为: -70.56470594741955
# 第 4 个火力发电站的对偶变量为: -66.27861787725523
# 第 5 个风力发电站的对偶变量为: -78.52586200803373
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -14.76788189
# ****************************************************************************
# 安全发电站的总发电量: 277.0572392771957
# *************************
# 需求侧平均用电需求: 73.35026091
# ****************************************************************************
# 风速分布参数c: 7.43418951
# ****************************************************************************
# 风速分布参数kappa: 2.06366986
# ****************************************************************************
# 安全发电站的总发电成本： 2000.2774765396014
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 990 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 69.40159121960818
# 第 2 个火力发电站的计划发电量为: 68.59623346119507
# 第 3 个火力发电站的计划发电量为: 52.607004034660356
# 第 4 个火力发电站的计划发电量为: 61.76710435393417
# 第 5 个风力发电站的计划发电量为: 34.61862937919118
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -85.40863181223956
# 第 2 个火力发电站的对偶变量为: -78.45781032092454
# 第 3 个火力发电站的对偶变量为: -77.64798602750392
# 第 4 个火力发电站的对偶变量为: -73.08056302974123
# 第 5 个风力发电站的对偶变量为: -85.40863181223956
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -8.84187543
# ****************************************************************************
# 安全发电站的总发电量: 286.99056244858895
# *************************
# 需求侧平均用电需求: 68.80907141
# ****************************************************************************
# 风速分布参数c: 19.00064664
# ****************************************************************************
# 风速分布参数kappa: 2.40368022
# ****************************************************************************
# 安全发电站的总发电成本： 2277.056580438222
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 991 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 72.26714837366767
# 第 2 个火力发电站的计划发电量为: 70.66204366408782
# 第 3 个火力发电站的计划发电量为: 54.81603929283217
# 第 4 个火力发电站的计划发电量为: 63.2263101479826
# 第 5 个风力发电站的计划发电量为: 46.298511519527324
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -88.75834784537042
# 第 2 个火力发电站的对偶变量为: -82.54111785045515
# 第 3 个火力发电站的对偶变量为: -81.74253786237438
# 第 4 个火力发电站的对偶变量为: -77.37327628070324
# 第 5 个风力发电站的对偶变量为: -88.75834784537042
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -10.9264476
# ****************************************************************************
# 安全发电站的总发电量: 307.2700529980976
# *************************
# 需求侧平均用电需求: 68.43412668
# ****************************************************************************
# 风速分布参数c: 24.69532358
# ****************************************************************************
# 风速分布参数kappa: 2.76905839
# ****************************************************************************
# 安全发电站的总发电成本： 2607.297796527096
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 992 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 75.30414131745093
# 第 2 个火力发电站的计划发电量为: 73.12952074451182
# 第 3 个火力发电站的计划发电量为: 57.29882833405395
# 第 4 个火力发电站的计划发电量为: 65.21856742626865
# 第 5 个风力发电站的计划发电量为: 51.996781880524324
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -89.61896110713974
# 第 2 个火力发电站的对偶变量为: -85.2273561244539
# 第 3 个火力发电站的对偶变量为: -84.43548746473043
# 第 4 个火力发电站的对偶变量为: -80.4753410065073
# 第 5 个风力发电站的对偶变量为: -89.61896110713974
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -10.21310166
# ****************************************************************************
# 安全发电站的总发电量: 322.9478397028097
# *************************
# 需求侧平均用电需求: 77.5218747
# ****************************************************************************
# 风速分布参数c: 19.34977167
# ****************************************************************************
# 风速分布参数kappa: 2.81628725
# ****************************************************************************
# 安全发电站的总发电成本： 2521.595794933514
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 993 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 78.07457575745167
# 第 2 个火力发电站的计划发电量为: 75.71159479807838
# 第 3 个火力发电站的计划发电量为: 59.77112633637571
# 第 4 个火力发电站的计划发电量为: 67.47880333240295
# 第 5 个风力发电站的计划发电量为: 65.03969397791677
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -93.88743253874318
# 第 2 个火力发电站的对偶变量为: -90.89241631621714
# 第 3 个火力发电站的对偶变量为: -90.10065485494107
# 第 4 个火力发电站的对偶变量为: -86.78382148380032
# 第 5 个风力发电站的对偶变量为: -93.88743253874318
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: 0.0
# ****************************************************************************
# 安全发电站的总发电量: 346.0757942022255
# *************************
# 需求侧平均用电需求: 67.46785371
# ****************************************************************************
# 风速分布参数c: 10.91176004
# ****************************************************************************
# 风速分布参数kappa: 2.64243598
# ****************************************************************************
# 安全发电站的总发电成本： 2502.6174903242995
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 994 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 81.18241345331955
# 第 2 个火力发电站的计划发电量为: 78.88926555304066
# 第 3 个火力发电站的计划发电量为: 62.730243773303044
# 第 4 个火力发电站的计划发电量为: 70.50792316315264
# 第 5 个风力发电站的计划发电量为: 75.17289065149802
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -90.81394732836488
# 第 2 个火力发电站的对偶变量为: -90.09483818700889
# 第 3 个火力发电站的对偶变量为: -89.29696618101343
# 第 4 个火力发电站的对偶变量为: -86.51287205200697
# 第 5 个风力发电站的对偶变量为: -90.81394732836488
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -11.69107323
# ****************************************************************************
# 安全发电站的总发电量: 368.4827365943139
# *************************
# 需求侧平均用电需求: 66.54800521
# ****************************************************************************
# 风速分布参数c: 15.71097882
# ****************************************************************************
# 风速分布参数kappa: 2.6773563
# ****************************************************************************
# 安全发电站的总发电成本： 2688.1132705681557
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 995 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 83.35844552518222
# 第 2 个火力发电站的计划发电量为: 81.50502106788164
# 第 3 个火力发电站的计划发电量为: 65.00797637207755
# 第 4 个火力发电站的计划发电量为: 73.11324477642638
# 第 5 个风力发电站的计划发电量为: 88.39993308525759
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -85.56340039697766
# 第 2 个火力发电站的对偶变量为: -84.84061402349332
# 第 3 个火力发电站的对偶变量为: -84.55448743852628
# 第 4 个火力发电站的对偶变量为: -84.11569603414426
# 第 5 个风力发电站的对偶变量为: -85.56340039697766
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -8.04890092
# ****************************************************************************
# 安全发电站的总发电量: 391.38462082682537
# *************************
# 需求侧平均用电需求: 64.64150556
# ****************************************************************************
# 风速分布参数c: 3.22319547
# ****************************************************************************
# 风速分布参数kappa: 2.62903492
# ****************************************************************************
# 安全发电站的总发电成本： 4779.031055543282
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 996 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 84.36562211211223
# 第 2 个火力发电站的计划发电量为: 82.8919455609665
# 第 3 个火力发电站的计划发电量为: 66.07391531633091
# 第 4 个火力发电站的计划发电量为: 74.99337185173046
# 第 5 个风力发电站的计划发电量为: 71.66058742026686
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -76.75083541881173
# 第 2 个火力发电站的对偶变量为: -77.0461916746115
# 第 3 个火力发电站的对偶变量为: -76.660286684573
# 第 4 个火力发电站的对偶变量为: -78.74340609145852
# 第 5 个风力发电站的对偶变量为: -76.75083541881173
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -11.83471366
# ****************************************************************************
# 安全发电站的总发电量: 379.985442261407
# *************************
# 需求侧平均用电需求: 75.10408906
# ****************************************************************************
# 风速分布参数c: 8.16558337
# ****************************************************************************
# 风速分布参数kappa: 2.05432022
# ****************************************************************************
# 安全发电站的总发电成本： 3193.676389261297
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 997 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 83.76806903011237
# 第 2 个火力发电站的计划发电量为: 82.79256485600462
# 第 3 个火力发电站的计划发电量为: 65.62695543023852
# 第 4 个火力发电站的计划发电量为: 75.74310138550723
# 第 5 个风力发电站的计划发电量为: 68.63842851472336
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -75.53880040090053
# 第 2 个火力发电站的对偶变量为: -76.38172922180244
# 第 3 个火力发电站的对偶变量为: -75.75490592977863
# 第 4 个火力发电站的对偶变量为: -77.12653930497194
# 第 5 个风力发电站的对偶变量为: -75.53880040090053
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -7.84648521
# ****************************************************************************
# 安全发电站的总发电量: 376.56911921658616
# *************************
# 需求侧平均用电需求: 74.46242037
# ****************************************************************************
# 风速分布参数c: 3.06843305
# ****************************************************************************
# 风速分布参数kappa: 2.46674814
# ****************************************************************************
# 安全发电站的总发电成本： 4255.321040473436
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 998 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 83.04917977786396
# 第 2 个火力发电站的计划发电量为: 82.59585680407773
# 第 3 个火力发电站的计划发电量为: 65.1117863306075
# 第 4 个火力发电站的计划发电量为: 76.12963692981415
# 第 5 个风力发电站的计划发电量为: 50.235691874405106
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -74.75058528719732
# 第 2 个火力发电站的对偶变量为: -75.41250991092993
# 第 3 个火力发电站的对偶变量为: -74.71954678468532
# 第 4 个火力发电站的对偶变量为: -75.16859548484175
# 第 5 个风力发电站的对偶变量为: -74.75058528719732
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -6.92268099
# ****************************************************************************
# 安全发电站的总发电量: 357.1221517167685
# *************************
# 需求侧平均用电需求: 57.53112837
# ****************************************************************************
# 风速分布参数c: 20.15305097
# ****************************************************************************
# 风速分布参数kappa: 2.53492363
# ****************************************************************************
# 安全发电站的总发电成本： 3009.6987755553964
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 999 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 82.29597138905187
# 第 2 个火力发电站的计划发电量为: 82.26416778734888
# 第 3 个火力发电站的计划发电量为: 64.51936365689266
# 第 4 个火力发电站的计划发电量为: 76.14153156106102
# 第 5 个风力发电站的计划发电量为: 58.79134668294563
# 第 6 个风力发电站的计划发电量为: 0.0
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -68.24119476771752
# 第 2 个火力发电站的对偶变量为: -66.69960347911511
# 第 3 个火力发电站的对偶变量为: -65.8050311457963
# 第 4 个火力发电站的对偶变量为: -64.88276302951525
# 第 5 个风力发电站的对偶变量为: -68.24119476771752
# ****************************************************************************
# 第 6 个受到Byzantin攻击的风力发电站的初始对偶变量为: -18.11670408
# ****************************************************************************
# 安全发电站的总发电量: 364.01238107730006
# *************************
# 需求侧平均用电需求: 69.0560216
# ****************************************************************************
# 风速分布参数c: 17.58707426
# ****************************************************************************
# 风速分布参数kappa: 2.68279184
# ****************************************************************************
# 安全发电站的总发电成本： 2883.5391735898747
# ****************************************************************************
# 原变量迭代步长为: 1
# ****************************************************************************
# 对偶变量迭代步长为: 3
# ****************************************************************************
# 2024-07-30 17:09:21.982

# %%
#数据存储
np.savetxt('./data/02_IOS_optimal_parameters_large_Gaussian_Byzantine_attack_sum_cost.txt',sum_cost,fmt='%0.8f')
np.savetxt('./data/02_IOS_optimal_parameters_large_Gaussian_Byzantine_attack_sum_thermal_wind_power_station_strategy.txt',sum_thermal_wind_power_station_strategy,fmt='%0.8f')

# %%
#评价指标：动态regret和累计的约束违反

# %%
#动态regret

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
from sympy import *
import math 
from datetime import datetime
from scipy.special import gamma, factorial
import scipy.special as sc

# %%
sum_cost=np.loadtxt("./data/02_IOS_optimal_parameters_large_Gaussian_Byzantine_attack_sum_cost.txt")
optimal_sum_cost=np.loadtxt("./data/00_optimal_sum_cost_varying_D_c_kappa_normal_distribution_(70,5).txt")

# %%
dynamic_regret=[]
dynamic_regret_T=[]
for T in range(1, 1000):
    dynamic_regret_auxiliary_variable=0
    for t in range(0, T):
        dynamic_regret_auxiliary_variable=dynamic_regret_auxiliary_variable+sum_cost[t]-optimal_sum_cost[t]
    dynamic_regret.append(dynamic_regret_auxiliary_variable)
    dynamic_regret_T.append((dynamic_regret_auxiliary_variable)/T)

# %%
dynamic_regret
# Out:
# [-141.43343337999977,
#  -278.52592991999995,
#  -1332.5259315899998,
#  -2580.2476386099997,
#  -3606.36665497,
#  -4972.29315437,
#  -5913.881613309999,
#  -7079.176337039999,
#  -7015.037129119999,
#  -7423.360187799999,
#  -8021.3486710299985,
#  -8296.396501429997,
#  -7570.218180159996,
#  -6829.327425539996,
#  -5868.9856498699955,
#  -4311.884281689996,
#  -2934.917110529996,
#  -1752.9027868399962,
#  200.97325579000335,
#  1220.319397030003,
#  1737.0593999600028,
#  1800.537849010003,
#  1969.0372911500026,
#  1428.1569418300028,
#  407.7246804100032,
#  130.11750462000327,
#  -933.7212638499966,
#  -2074.0625828799966,
#  -2583.9682089399967,
#  -3234.1585778799968,
#  -3134.288644099997,
#  -2812.236401259997,
#  -2642.430603129997,
#  -2114.7390891799973,
#  -1381.7611757199975,
#  482.4653963900023,
#  1513.649764210002,
#  2290.834070690002,
#  3762.4988557100023,
#  4639.939287830002,
#  5225.622517170002,
#  5283.924448830001,
#  4824.725331920001,
#  4827.516164280001,
#  4199.335620470001,
#  3626.9723757200013,
#  3162.4973968100016,
#  3054.937538260002,
#  2342.429918410002,
#  1769.6326857300014,
#  1362.4561346700011,
#  1582.2239443400013,
#  1552.0700939000012,
#  1993.8849921900019,
#  2353.777284520002,
#  2390.9243082300018,
#  3141.9751526300015,
#  4188.053280870001,
#  5770.22800617,
#  8446.413631919999,
#  9070.86417515,
#  10058.8988331,
#  10093.7160815,
#  10414.1393157,
#  10513.84546938,
#  10766.06319331,
#  10619.317133749999,
#  10191.969557429999,
#  9680.573595499998,
#  9100.587286789998,
#  8865.456341969997,
#  7872.585055089996,
#  8431.965831749996,
#  8231.981587209995,
#  8192.947453919996,
#  7755.285662089997,
#  8178.436601579996,
#  8296.774669049997,
#  8246.394646769997,
#  9193.530583439997,
#  9656.068072179996,
#  9783.831230619995,
#  10779.401042689995,
#  11265.109310479995,
#  12313.486222109996,
#  12638.529506639996,
#  13018.505519119997,
#  13351.311408909998,
#  13574.580786429999,
#  13435.08581384,
#  13179.859773299999,
#  13162.35789189,
#  12964.73667231,
#  13383.55410356,
#  12162.58001434,
#  12185.12741334,
#  11874.03003324,
#  12217.85932501,
#  12193.38114804,
#  12417.182907990002,
#  12981.84842331,
#  13519.47534604,
#  14131.696201220002,
#  14462.09227554,
#  15098.825954070002,
#  15977.103218750002,
#  16355.361363510001,
#  15947.007773510002,
#  15378.230309470002,
#  15333.345226550002,
#  14795.115208060004,
#  14128.321127130006,
#  13642.936252110005,
#  13372.452587310005,
#  12958.871194890007,
#  12728.803764200007,
#  13156.378113960007,
#  13364.495063920007,
#  13574.149783820007,
#  14217.186238590006,
#  15291.083776490004,
#  16104.549737970003,
#  16799.459513120004,
#  17101.763908240006,
#  17975.441464330008,
#  18520.644290430006,
#  18952.340581900007,
#  18831.46209888001,
#  19005.61888379001,
#  18910.55318934001,
#  19030.93594995001,
#  18827.63158082001,
#  17686.27662725001,
#  17699.97372271001,
#  17844.529640000008,
#  17498.855643510007,
#  17658.573024970006,
#  18427.457769610006,
#  17883.249010300005,
#  17794.091050770003,
#  18218.952531140003,
#  18258.589246610005,
#  18836.787731540007,
#  18569.14605293001,
#  18684.17565354001,
#  19211.48082381001,
#  20215.33864400001,
#  21534.733183610013,
#  22499.603560470012,
#  23163.456592900013,
#  22813.581087830014,
#  23028.492978220012,
#  22362.87099639001,
#  21342.721920830012,
#  20209.74153943001,
#  19061.558004450013,
#  18066.441645660016,
#  17495.84311143002,
#  17956.36416373002,
#  18526.77335905002,
#  19511.07928812002,
#  20026.164729280023,
#  22334.340646210025,
#  23067.021035040023,
#  24545.572966080024,
#  25201.824510930022,
#  25457.41416111002,
#  25319.73751140002,
#  25482.78339507002,
#  24955.308715670017,
#  24724.975036040018,
#  24461.48847643002,
#  24058.382493160017,
#  24309.234414030016,
#  23803.353566540016,
#  23573.676327660014,
#  23863.154495440012,
#  23890.195377790013,
#  23913.36816427001,
#  24564.36527762001,
#  24604.387370060012,
#  24370.88519737001,
#  24133.89487484001,
#  24465.47608161001,
#  25803.85360032001,
#  25778.14889612001,
#  25513.65564376001,
#  25857.17408668001,
#  25809.27392361001,
#  26004.73752504001,
#  26250.50222037001,
#  26772.86814498001,
#  27130.64426813001,
#  27146.01489570001,
#  27400.16571922001,
#  27343.76217699001,
#  27511.828270130012,
#  29301.205502050012,
#  29497.058808230013,
#  29709.02092920001,
#  29571.27080187001,
#  29484.81163107001,
#  29503.01771020001,
#  28526.75192166001,
#  28338.519041230007,
#  27820.668182410005,
#  27813.999331970004,
#  27639.286827260003,
#  27887.65094675,
#  27844.70774862,
#  28542.34445093,
#  30521.22773453,
#  30966.6066987,
#  31489.185434020004,
#  31426.127422610007,
#  31608.358416850006,
#  31731.925712630004,
#  32271.538573020003,
#  32468.86532275,
#  32000.650056420003,
#  31304.976681680007,
#  31271.882608590004,
#  31182.84612083,
#  30768.96705343,
#  30513.19885501,
#  30267.62844668,
#  30750.192980189997,
#  30804.29159491,
#  30339.909490129998,
#  30179.90736573,
#  30220.30373941,
#  29525.916839229998,
#  30508.52847169,
#  30162.53066523,
#  29586.60408454,
#  29728.251189819995,
#  30326.339410879995,
#  30521.835951489993,
#  31231.045880929993,
#  31698.46429553999,
#  32211.396834269988,
#  32678.47424909999,
#  33153.67256575999,
#  33003.59051837999,
#  32929.279212279995,
#  32489.061229279996,
#  32408.331326179996,
#  31914.671118769995,
#  31787.810974389995,
#  31529.367905309995,
#  31603.385799329993,
#  31960.214285109992,
#  31898.925562829994,
#  32417.097206199996,
#  32791.18664334,
#  33026.00469186,
#  33460.37763371,
#  33845.91570747,
#  34132.51992808,
#  34389.814863010004,
#  33949.396394150004,
#  34056.75212864001,
#  33771.36523840001,
#  33312.63543943001,
#  33089.077036840004,
#  33197.45426549001,
#  32989.401442910006,
#  32623.099866070006,
#  32608.088984020007,
#  32521.861678390007,
#  34588.94772661,
#  34913.369869,
#  35661.59077553001,
#  37220.51683003001,
#  37250.77129627,
#  37516.41074507,
#  37139.31700481,
#  37192.75462709,
#  36671.24130133,
#  36274.39245526,
#  37268.211953000005,
#  36656.84944180001,
#  36623.26131059001,
#  36835.646606810005,
#  36526.813344320006,
#  36813.85547259,
#  36833.19647349,
#  35870.944711330005,
#  36145.58248078,
#  36489.27033162,
#  36455.29544369999,
#  37236.42679615999,
#  37237.93612293,
#  37731.9138893,
#  38025.76961335,
#  38418.83466691,
#  37945.95701873,
#  37910.35430453999,
#  38636.65983150999,
#  38213.53575684999,
#  37668.17025214999,
#  37557.597572479994,
#  37314.58213258999,
#  37653.37532888999,
#  36999.35764748999,
#  37123.67980102999,
#  37484.87741352999,
#  37491.975057939984,
#  36678.64124308999,
#  37208.17644135998,
#  38199.30700278998,
#  38593.54063519998,
#  39161.31956242998,
#  39915.44410503998,
#  40939.49269386998,
#  41529.484007909974,
#  41647.48943361997,
#  41615.86340474997,
#  41527.66601641997,
#  41621.77797363997,
#  41391.54450653997,
#  40750.78933837997,
#  40016.46326565997,
#  40075.688028649965,
#  39904.87616744996,
#  39788.94624001996,
#  39882.68003448997,
#  40150.63605185997,
#  40716.486245349966,
#  41548.52460553997,
#  41688.27148899997,
#  41940.13224906997,
#  42221.65016913997,
#  42505.89179933997,
#  42466.48545488997,
#  42379.05775836997,
#  43154.46878727997,
#  42271.11369802996,
#  42306.54189926996,
#  41060.69560094996,
#  40790.54809995996,
#  40082.722421039965,
#  39480.88541209996,
#  39505.88735958996,
#  39393.243977539954,
#  39991.830661649954,
#  40806.847738579956,
#  41732.77382880996,
#  42537.05217191996,
#  43334.78381367996,
#  44352.52340197996,
#  45800.44492925996,
#  46711.49450314996,
#  46434.75595447996,
#  46134.376009739965,
#  46139.804720689965,
#  45822.60552911997,
#  45278.88046377996,
#  44197.18696466996,
#  43856.42944205996,
#  43429.60534905996,
#  43127.64641795996,
#  43167.15908941996,
#  43022.05371102996,
#  42992.99248324997,
#  43755.68833618997,
#  44091.82592792997,
#  44621.94905966997,
#  45106.41712689997,
#  45833.33988166998,
#  46442.177427249975,
#  47184.48440200997,
#  48188.63998498997,
#  48713.51606273997,
#  48949.074363789965,
#  50289.865202509965,
#  50295.17432338997,
#  49848.49428584997,
#  48859.900506519974,
#  47862.39119221998,
#  47561.58817047998,
#  46987.37547455998,
#  46171.576561449976,
#  45949.49487875998,
#  45969.40498168998,
#  46144.13504243998,
#  46233.13547202998,
#  46759.57058796998,
#  47047.23498340999,
#  47491.798731219984,
#  47711.46076640998,
#  48226.39075130998,
#  48836.50345221997,
#  49395.17918846997,
#  49795.24834150997,
#  49641.66601591997,
#  49676.10337379997,
#  49113.51914281997,
#  50075.140218789966,
#  49705.945503179966,
#  48979.34572607997,
#  48223.92941125997,
#  47792.15818913997,
#  48351.889987099974,
#  48213.95514466997,
#  47971.50653722997,
#  48251.72585845997,
#  48012.71298592997,
#  49447.14916072997,
#  49391.739962869964,
#  49458.946749539966,
#  49572.44385689997,
#  49763.240798699975,
#  50156.698985119976,
#  50504.92435458997,
#  50871.571237079974,
#  50424.36060070997,
#  51123.19204235997,
#  51045.641400369976,
#  51219.397229989976,
#  51041.94081702997,
#  51073.600537029975,
#  51287.20958005997,
#  51403.372410289965,
#  51323.682277019965,
#  51389.12357211996,
#  51420.19224759996,
#  51263.176398699965,
#  51658.87264015996,
#  52111.25045331997,
#  52027.74464550996,
#  53090.40139526996,
#  53143.618737859964,
#  52715.72709817996,
#  52745.12789271996,
#  52915.71606761996,
#  52992.986978599954,
#  52583.52240838995,
#  53763.463215579955,
#  54178.62546936996,
#  54105.10522009996,
#  54099.517349899965,
#  54967.604730149964,
#  54995.54568915997,
#  54820.025126509965,
#  55211.91066703996,
#  55142.54760079996,
#  54728.55726161996,
#  54350.187858049954,
#  53800.05669146996,
#  53626.638101939956,
#  53705.70411850996,
#  53857.427506509965,
#  53862.02791361997,
#  54479.089093109964,
#  54688.69635418996,
#  55425.35566691996,
#  55720.62351865996,
#  56062.49158281996,
#  56211.060020509954,
#  57132.31177594996,
#  56211.41636754996,
#  55783.33908981996,
#  56533.56473283996,
#  55930.47962241995,
#  55249.57380955995,
#  54666.50936923995,
#  53918.49732173995,
#  52981.35930067996,
#  53074.02258421996,
#  53539.69882143995,
#  54048.99503198995,
#  54638.12450457995,
#  57400.42260541995,
#  58657.881178199954,
#  59262.85683118996,
#  59825.44558332996,
#  60029.20936396996,
#  61130.337874149955,
#  60467.035743159955,
#  60290.790839599955,
#  59868.404977019956,
#  59502.379854129955,
#  59158.48864372995,
#  58558.017214999956,
#  59013.08188434996,
#  59511.16719598996,
#  60388.265634349955,
#  60646.60923497995,
#  60457.01769027995,
#  60592.521509849954,
#  60717.47419853995,
#  61354.45839535995,
#  63356.74054409996,
#  62884.22642049996,
#  63797.919112219955,
#  63291.09610520995,
#  63038.28361666995,
#  62915.03362249995,
#  63200.34416108995,
#  63261.304379779955,
#  63052.43904872995,
#  63086.38456928996,
#  63347.682626229966,
#  63449.73875288996,
#  63660.28452452996,
#  64669.03536928996,
#  64687.26849830996,
#  64374.48585936996,
#  64370.73196271996,
#  63882.12322440996,
#  64017.680211989966,
#  63918.98420495996,
#  64345.88895935996,
#  64110.42334188996,
#  64285.97913750996,
#  64272.342561919955,
#  64729.08059364996,
#  64897.57414343996,
#  65220.23540313997,
#  65534.34414531996,
#  65539.12213383996,
#  66127.96346584997,
#  65642.48425085997,
#  65154.20795309997,
#  64952.57027086997,
#  65043.09618179997,
#  65234.70796044997,
#  64772.79391678997,
#  64542.181628629965,
#  65212.11330663996,
#  64942.753471679964,
#  65262.82719484997,
#  66459.13657686996,
#  66498.84403151996,
#  66139.77312902996,
#  66541.94482614996,
#  66546.25330066997,
#  66492.15165770997,
#  66582.41850063998,
#  66647.95313805998,
#  66899.06136928998,
#  67302.09350039998,
#  67925.44033441998,
#  68482.95769713998,
#  68553.38454126997,
#  68645.21095126997,
#  68655.24655326996,
#  68420.02483140996,
#  68128.20710201997,
#  67761.34680682997,
#  67402.02543344996,
#  67074.43976074997,
#  67056.31649551996,
#  66852.67279167996,
#  66648.21854810996,
#  67182.42569514996,
#  67721.09014251996,
#  67372.13459757996,
#  67564.89425606997,
#  67979.65279959996,
#  68625.92277593997,
#  70468.39898833996,
#  70976.12330382997,
#  71234.29101942996,
#  71780.62746723996,
#  71922.25752936996,
#  72103.89083632996,
#  71835.79784996995,
#  71490.35977946995,
#  70745.51369907995,
#  69775.21607750995,
#  69581.94340775994,
#  69262.03925293994,
#  69449.56497431993,
#  69111.18147760992,
#  69516.66407398992,
#  69962.4992832199,
#  71002.4174957499,
#  70728.92010566991,
#  70996.34843492991,
#  70514.33177714991,
#  70258.88571025991,
#  70871.85027173992,
#  70944.90930524992,
#  71647.60059807992,
#  71718.52794859993,
#  72026.91345972994,
#  72168.51703179994,
#  72219.68752066995,
#  72383.36226617996,
#  72509.68584462996,
#  72107.47563681996,
#  72607.65396425995,
#  72754.58414327996,
#  73117.55531494996,
#  73473.83974690997,
#  72755.40773938998,
#  73216.22217012999,
#  73398.38935029999,
#  73294.95638447998,
#  73351.80411356999,
#  73249.79461325999,
#  72496.14237552,
#  72118.29882910999,
#  72608.43450569999,
#  72328.30433867,
#  72572.41817598001,
#  71833.41174632002,
#  71089.04941512003,
#  71239.55223930001,
#  71710.03862606002,
#  72034.16994188001,
#  72070.72888967,
#  72120.83498735001,
#  72444.92025376,
#  72402.00668389001,
#  72328.40555304001,
#  73315.0567314,
#  73859.99967715,
#  73767.38801321,
#  73672.09454833,
#  73397.18896739002,
#  72591.33899150002,
#  72563.15005759001,
#  72697.41253849001,
#  72348.38398216,
#  72931.86316318,
#  73120.92528735999,
#  73820.54814710999,
#  74243.65987096999,
#  75240.67563782999,
#  75715.50663349999,
#  77044.42941478998,
#  77202.03446242998,
#  77188.29349952997,
#  76971.98748688996,
#  76738.03039090996,
#  76712.91301661996,
#  76642.27087364996,
#  76355.69970495996,
#  76556.10388182996,
#  76659.37669661996,
#  76295.12033840996,
#  76320.15904512997,
#  76482.81073280997,
#  77361.49496355996,
#  77250.30219635996,
#  77043.21200971997,
#  76854.94336783997,
#  76728.97882165996,
#  76541.91001154995,
#  77283.52733836995,
#  77336.72256041995,
#  76871.89035510995,
#  76624.41234860996,
#  76606.82330540995,
#  76168.29013333995,
#  75384.30702545994,
#  76041.03018996996,
#  76339.79973692996,
#  77278.80172423995,
#  77739.83363281995,
#  78474.91097733995,
#  79548.38840108995,
#  79824.54777615996,
#  80743.62515725997,
#  81364.48410311996,
#  81784.19861437996,
#  81924.38448272995,
#  82165.80298463994,
#  82054.28752997995,
#  81600.33588558996,
#  81052.62158020996,
#  80286.41089569996,
#  79854.50803879996,
#  79372.19572065996,
#  79301.13447191997,
#  79023.82604507997,
#  79278.11959078997,
#  78791.52078880995,
#  78584.36933621996,
#  78751.76034304996,
#  78910.14000515996,
#  80991.70059415996,
#  81175.02423567996,
#  82872.08199988997,
#  83131.67942809997,
#  82519.79516709998,
#  82649.76036966997,
#  82477.61365852997,
#  82146.42430021997,
#  82396.86479193997,
#  82178.59078824996,
#  82558.00817933996,
#  82828.08821102996,
#  83149.68779366996,
#  83761.50615595996,
#  84025.71408693996,
#  84234.95225529996,
#  84215.45509532996,
#  84327.88662366997,
#  83880.70649251997,
#  84462.56510956997,
#  84508.97833334998,
#  84009.25509413998,
#  83009.63653243998,
#  82329.40575795,
#  82426.76555855,
#  82554.52713901,
#  82618.89816573,
#  83548.38160122,
#  84488.61599281999,
#  85450.72623911,
#  86440.19557841,
#  87641.50701961,
#  88329.56290356,
#  88811.48022233,
#  89309.03614780001,
#  88947.81663926001,
#  88469.24936575,
#  88221.61264800999,
#  87573.78962617999,
#  87014.26299914999,
#  85815.82657113999,
#  85174.46352328999,
#  84697.40234048999,
#  84724.83936718,
#  85118.67109674,
#  85220.35027611,
#  85325.10284217999,
#  85745.18610303999,
#  85857.12832450999,
#  86993.21614447999,
#  88098.06748541999,
#  89212.46176394999,
#  89812.58334953,
#  90392.52502686,
#  91487.50424642001,
#  92084.00811930001,
#  91832.9533203,
#  92725.10026738001,
#  92682.18026609,
#  92527.46925997,
#  92259.83025981,
#  92241.23493071999,
#  92308.73745323998,
#  92475.82632110998,
#  92323.51155906999,
#  91987.15824803998,
#  92396.98016683997,
#  92468.19458621998,
#  92568.16979027998,
#  93888.60274835998,
#  94777.63365794998,
#  94663.88467400997,
#  95067.13562534997,
#  94799.06419501998,
#  94242.36743095997,
#  93934.37625495996,
#  94077.67411929998,
#  94208.95584406998,
#  94752.50911180998,
#  94989.07487810998,
#  95263.57203185998,
#  95282.90093941998,
#  95095.40450236999,
#  95280.72946896998,
#  94714.73462137998,
#  95116.25581549997,
#  95417.20764209998,
#  95493.37068418998,
#  96098.54112358998,
#  95912.22776122998,
#  95817.00867297998,
#  96546.15304508997,
#  96312.65654906997,
#  96267.44116389997,
#  96053.12418655997,
#  96668.33383973998,
#  96504.38297598998,
#  96644.11759633997,
#  96509.10481969998,
#  96972.11167072997,
#  97562.79049864996,
#  99042.53373660997,
#  99077.56943393996,
#  99192.72633879996,
#  99203.45834650996,
#  99491.52432830996,
#  99864.68419368996,
#  99108.52622237997,
#  98312.50162582996,
#  97933.43975860997,
#  98069.49644794996,
#  98100.83389003997,
#  97915.05135661997,
#  100067.47258951997,
#  100688.52703410997,
#  100766.70833570998,
#  101773.03296784998,
#  102333.03291156999,
#  102663.92535904999,
#  103060.41241553,
#  102941.14336127999,
#  102699.22913190999,
#  102710.03550439999,
#  102730.57950960999,
#  103396.14823577,
#  103406.22239902,
#  103905.38003654001,
#  104359.29772459001,
#  104485.14285599002,
#  104701.55542600002,
#  104528.14309616001,
#  104630.84346777001,
#  104509.71147200001,
#  104652.30031694002,
#  105415.47984810002,
#  105788.77536864002,
#  106535.62365648002,
#  108054.02824726002,
#  108219.16290504002,
#  107945.65158318002,
#  107713.00112124003,
#  107343.92529350003,
#  106627.13992993002,
#  106149.07456960002,
#  105261.61329572002,
#  104899.94427159001,
#  104463.74011866,
#  104606.76195919,
#  104874.63590046001,
#  105182.28116031001,
#  105457.55800803001,
#  105805.75938527001,
#  106611.33669464,
#  107795.05473312,
#  108997.50214651,
#  109749.09756749,
#  109970.66005486,
#  110657.01397085999,
#  110912.31119862999,
#  112261.76321317999,
#  111910.88827729,
#  110991.51569199999,
#  110648.64622098999,
#  110437.81165606999,
#  109182.25670048999,
#  108227.43353153,
#  107645.12092773,
#  107052.09100285,
#  106710.66634367999,
#  106421.40989365,
#  106890.98909989999,
#  107890.95132581999,
#  109190.77532315,
#  110280.47818317,
#  110993.47240869999,
#  111537.35467563999,
#  112795.91432158998,
#  113116.40605762998,
#  113182.22695029997,
#  112997.92161285997,
#  112578.25589213996,
#  111590.61502387996,
#  110820.13516678996,
#  110650.63802041997,
#  110755.09485772997,
#  109622.79934078998,
#  109162.00921723999,
#  109485.15955408999,
#  109074.27222922999,
#  109080.28434983999,
#  108919.1372166,
#  109511.23391929,
#  110659.20580116,
#  111152.29482675,
#  112543.30480501,
#  113513.29311638001,
#  115529.75485883001,
#  115871.17822259001,
#  115836.43336686,
#  115683.77895713999,
#  115801.09999163999,
#  116081.36456189999,
#  115745.87482745,
#  115118.10687842999,
#  114452.75576888998,
#  113892.51565064998,
#  113334.96675025998,
#  113196.37674386997,
#  112980.96949891996,
#  113453.40648629997,
#  113461.02072463997,
#  113725.74907698996,
#  114647.63012135997,
#  115267.70516378996,
#  115667.06705560995,
#  116033.02610671995,
#  116991.49105150995,
#  116841.12632096995,
#  116944.57409893995,
#  117792.99236381995,
#  117361.35430681995,
#  117137.68768868994,
#  116743.81896982994,
#  116754.26949783994,
#  115435.99548805993,
#  115213.56395818993,
#  115078.69283056993,
#  114758.87563359992,
#  114609.30062747991,
#  115225.51538804991,
#  116220.96147769992,
#  117022.58922611992,
#  117598.34072772991,
#  118504.32599496991,
#  119215.63245407991,
#  119612.52962082991,
#  120294.61515484992,
#  120228.80672472992,
#  119811.56301987992,
#  121183.55831758991,
#  120768.18006363991,
#  120284.4859461299,
#  119682.3670686199,
#  119000.54151224991,
#  118495.8145412299,
#  117443.2894877299,
#  117224.1119469999,
#  117365.9904362299,
#  117302.1054703399,
#  118130.61094228989,
#  118882.71989053988,
#  119634.06964454988,
#  120452.31251415989,
#  121554.09035983989,
#  122134.99738137989,
#  122975.11090707988,
#  123664.09789624989,
#  123849.55463638989,
#  125009.66494984989,
#  124545.29092217989,
#  124407.10634238989,
#  123769.46950982988,
#  123771.77348628988,
#  122904.26846332988,
#  122121.35314021987,
#  121823.30558541988,
#  121629.71118458988,
#  121542.21736064988,
#  120923.83357795989,
#  120924.19198489988,
#  121340.15301841988,
#  121718.77678956988,
#  122640.40367012988,
#  123091.28349365987,
#  123417.71494356987,
#  124270.37680329986,
#  126130.69586333986,
#  126374.61113477986,
#  126405.54137361987,
#  127324.29582968987,
#  127171.56866835986,
#  127190.67148430986,
#  127470.54340223985,
#  127645.01345346986,
#  126956.33263437987,
#  125693.79077548986,
#  125056.04445336986,
#  124915.38728163985,
#  125132.23177579985,
#  126049.84638741985,
#  125938.41984863985,
#  126408.13880758986,
#  126970.42108982986,
#  127911.94763437986,
#  128395.16765139987,
#  128984.66856229986,
#  129607.51065768985,
#  130167.98017631986,
#  131045.77980861985,
#  132395.94808213983,
#  132273.47321625982,
#  132010.11452334982,
#  131281.21987633983,
#  130416.79434602983,
#  129910.54876549983,
#  128864.97618738982,
#  128728.75246164984,
#  128410.33573515984,
#  128301.55172745984,
#  128488.39511658985,
#  129195.87657664984,
#  131443.13631248983,
#  131520.57919047985,
#  132543.91318116986,
#  133586.50976596988]

# %%
#绘图 dynamic_regret和dynamic_regret_T

# %%
sub1=plt.subplot(1, 2, 1)##############################################################
iteration=[]
for i in range(0,999):
    iteration.append(i)

#在同一幅图片上画3条折线
A,=plt.plot(iteration,dynamic_regret,color = 'red',linewidth = '1.5',label='attack-free online primal-dual algorithm')


#设置图例并且设置图例的字体及大小
font1 = {
'size'   : 18,
}
#legend = plt.legend(handles=[A],prop=font1)
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=18)
 
#设置横纵坐标的名称以及对应字体格式
font2 = {
'size'   : 18,
}
plt.xlabel('T',font2)
plt.ylabel(r'Dynamic regret $Reg(T)$',font2)
plt.title('varying $D_{t}$',font2) 

sub2=plt.subplot(1, 2, 2)##############################################################
iteration=[]
for i in range(0,999):
    iteration.append(i)

#在同一幅图片上画3条折线
A,=plt.plot(iteration,dynamic_regret_T,color = 'red',linewidth = '1.5',label='attack-free online primal-dual algorithm')


#设置图例并且设置图例的字体及大小
font1 = {
'size'   : 18,
}
#legend = plt.legend(handles=[A],prop=font1)
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=18)
 
#设置横纵坐标的名称以及对应字体格式
font2 = {
'size'   : 18,
}
plt.xlabel('T',font2)
plt.ylabel(r'Dynamic regret $Reg(T)/T$',font2)
plt.title('varying $D_{t}$',font2) 

plt.legend(handles=[A],prop={'size':18},loc="upper center", bbox_to_anchor=[-0.3, -0.2],
           ncol=18, shadow=True, fancybox=True)

plt.subplots_adjust(wspace=0.5,hspace=0.5) 
plt.gcf().set_size_inches((15, 5))

#plt.savefig('./figures/01-figure1_dynamic_regret_attack_free_varying_D.pdf',format='pdf', bbox_inches='tight')
#plt.savefig('./figures/01-figure1_dynamic_regret_attack_free_varying_D.png',format='png', bbox_inches='tight')

# %%
#累计的约束违反

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
from sympy import *
import math 
from datetime import datetime
from scipy.special import gamma, factorial
import scipy.special as sc

# %%
sum_thermal_wind_power_station_strategy=np.loadtxt("./data/02_IOS_optimal_parameters_large_Gaussian_Byzantine_attack_sum_thermal_wind_power_station_strategy.txt")
d_power_demand=np.loadtxt("./data/d_power_demand_normal_distribution_(70,5).txt")

# %%
accumulative_constraint_violation=[]
accumulative_constraint_violation_T=[]
for T in range(1, 1000):
    accumulative_constraint_violation_auxiliary_variable=0
    for t in range(0, T): 
        accumulative_constraint_violation_auxiliary_variable=accumulative_constraint_violation_auxiliary_variable+(1/5)*sum_thermal_wind_power_station_strategy[t+1]-d_power_demand[t+1]
    accumulative_constraint_violation.append(abs(accumulative_constraint_violation_auxiliary_variable))
    accumulative_constraint_violation_T.append(abs(accumulative_constraint_violation_auxiliary_variable)/T)

# %%
accumulative_constraint_violation
# Out:
# [6.505331695999999,
#  29.963973501999995,
#  60.71754176999999,
#  93.916268022,
#  125.83097055399999,
#  155.92499927799997,
#  183.06559964799996,
#  196.66145446799993,
#  209.25384550199993,
#  230.60540947599995,
#  240.14249790599996,
#  228.77254868399996,
#  216.79358304399994,
#  202.21228508399992,
#  176.7235745659999,
#  154.6707391239999,
#  139.6430867699999,
#  127.7120600699999,
#  109.9936289319999,
#  105.9934466299999,
#  109.6726533459999,
#  117.16981617199991,
#  131.60871125799991,
#  153.7809627879999,
#  165.5479908499999,
#  190.74142596399992,
#  216.0879015679999,
#  228.41596422999987,
#  240.2515750699999,
#  240.68805384599986,
#  235.28930939399984,
#  239.81471242399982,
#  231.8265853099998,
#  221.1939443779998,
#  201.2349776059998,
#  185.3788712419998,
#  172.8289817899998,
#  145.4876400399998,
#  132.9761619699998,
#  131.3593366659998,
#  133.23759091399978,
#  150.22431879999976,
#  164.17183152999976,
#  177.79149446199978,
#  193.42816497399977,
#  206.80827241399976,
#  223.61925871399976,
#  237.06599020999974,
#  254.31804062599974,
#  265.62371624399975,
#  271.3575958919998,
#  277.4678855279998,
#  273.2962035779998,
#  270.7208181339998,
#  271.8219369119998,
#  264.19919247799976,
#  251.52469348799977,
#  224.00696553999978,
#  208.4305328439998,
#  199.7731456039998,
#  184.5689782519998,
#  184.5899814359998,
#  180.08415663399978,
#  180.35110540799977,
#  179.64876037199974,
#  185.64686310199977,
#  194.55858470399977,
#  205.45954246399978,
#  218.71040060399974,
#  224.93023105199975,
#  244.39947586199975,
#  259.46209897599977,
#  270.2110108459998,
#  274.33174684599976,
#  283.73597690399976,
#  283.78716427599977,
#  283.3595311319998,
#  284.4939950779998,
#  285.27711242399977,
#  278.71725366999976,
#  276.8130884479998,
#  266.7568027759998,
#  263.1439522539998,
#  257.70110168199983,
#  256.48086906799983,
#  249.9743591679998,
#  247.8570621739998,
#  244.55807883799977,
#  248.31944124799978,
#  254.11722010199978,
#  256.54000115399975,
#  267.12721110199976,
#  275.55153501799975,
#  296.86176076599975,
#  302.82979250599976,
#  308.9998397839998,
#  304.1459350699998,
#  308.03268647599975,
#  307.6456689719997,
#  297.4671139019997,
#  288.09165600799975,
#  278.1339600099997,
#  274.3925814299997,
#  262.7082512279997,
#  248.12639302199972,
#  250.2224668559997,
#  263.0264007579997,
#  278.4753698519997,
#  285.3805514199997,
#  302.7944544199997,
#  315.07626222399966,
#  326.26713282399965,
#  334.47212026199963,
#  350.19639928999965,
#  354.59257870999966,
#  358.21458420399966,
#  366.6320370319997,
#  363.56252145999963,
#  360.3887764479996,
#  343.91802076799956,
#  331.47297730599956,
#  322.47918401799956,
#  321.14290636799956,
#  315.68228512199954,
#  308.97852517399957,
#  307.0340450599996,
#  309.64484020799955,
#  318.3674303959996,
#  322.9144873359996,
#  323.6603364399996,
#  327.5453852319996,
#  346.59645361199955,
#  349.5733265919995,
#  353.7351876599995,
#  360.7340313699995,
#  363.4690075199995,
#  360.53269760999945,
#  369.59570666999946,
#  374.2118387539995,
#  375.4834182059995,
#  379.3885046179995,
#  380.3545079419995,
#  386.3674790499995,
#  384.7184160799995,
#  381.16294503199947,
#  366.2868774199995,
#  343.6374483899995,
#  325.8580949699995,
#  323.8668567559995,
#  329.75390541999946,
#  336.76175538399946,
#  348.4197024659994,
#  371.9424916439994,
#  397.62983267399943,
#  417.09766226199946,
#  437.31104026999947,
#  452.54184245799945,
#  444.28294190999947,
#  435.86995278999945,
#  421.24595880399943,
#  413.51218488399945,
#  401.3128177999995,
#  389.4205196319995,
#  374.5622744599995,
#  371.55268794199947,
#  372.4631264199994,
#  377.3269000679994,
#  380.4780057819994,
#  390.57316052399943,
#  400.37783103799944,
#  405.9683763599994,
#  413.0341854659994,
#  409.8152222439994,
#  419.70262590199945,
#  424.17945633799945,
#  420.1743495939994,
#  420.1340273399994,
#  421.13546312199946,
#  409.4566751799995,
#  409.9250134659994,
#  414.3549535739994,
#  420.2166599619994,
#  414.47430532799945,
#  415.4974076639994,
#  416.6657217839994,
#  424.27106176799936,
#  431.5685059539993,
#  444.14440914799934,
#  445.50181423599935,
#  444.88927179399934,
#  436.7873052199994,
#  433.54398738399937,
#  436.4819829359993,
#  435.3885282099993,
#  436.37590713199927,
#  436.6938572799993,
#  430.6881836519993,
#  429.5388236519993,
#  426.03104026599925,
#  430.1467869479992,
#  437.5021797039992,
#  440.1256486179992,
#  457.0158675059992,
#  462.07843654199917,
#  471.90565454999916,
#  478.3947837199991,
#  484.7241055779991,
#  480.3559759759991,
#  481.2229137339991,
#  468.35261671599915,
#  460.11633089399913,
#  457.4917314659991,
#  450.9283520879991,
#  453.3675434959991,
#  451.4283646559991,
#  449.23780581999904,
#  439.266411775999,
#  435.6145606019991,
#  444.035547055999,
#  457.67872629999897,
#  458.63744797599895,
#  460.95224215999895,
#  469.705181351999,
#  474.84454253799896,
#  481.69339737799896,
#  483.06066450199893,
#  485.2449933919989,
#  493.6637543439989,
#  498.2483345139989,
#  497.7886885599989,
#  509.5398608339989,
#  508.1220757479989,
#  514.450474785999,
#  525.3971691759989,
#  523.196843093999,
#  518.250980413999,
#  517.4042090179989,
#  508.0700802859989,
#  502.58965132399896,
#  493.75981437399895,
#  489.79228404999895,
#  493.38686739999895,
#  496.4766604059989,
#  504.7893890999989,
#  512.9453549939989,
#  518.0868029959988,
#  526.4795073599988,
#  532.2559479039988,
#  538.1324925199989,
#  538.3694262139988,
#  531.9257430579988,
#  535.3470838959988,
#  529.2026340559988,
#  526.7987252199988,
#  522.8530003059988,
#  517.2320827899988,
#  512.7936219859988,
#  512.8365438139988,
#  508.7208414539988,
#  516.8663134259988,
#  515.2066713899987,
#  521.2766497779987,
#  534.9448947499988,
#  542.3342260859987,
#  540.2521435959987,
#  544.0979613219987,
#  553.0350217259987,
#  553.6487430059988,
#  556.3205737899988,
#  548.5710648499987,
#  542.6507393059987,
#  531.1588367919987,
#  527.3113845539988,
#  526.9864904959987,
#  525.5738789839987,
#  532.4540071859988,
#  537.7040557139987,
#  547.1832192079987,
#  555.6663905659988,
#  563.1080009319987,
#  574.1217182059987,
#  576.8142993759986,
#  574.2739196479987,
#  579.7246479179987,
#  584.9501699759987,
#  587.7035791199987,
#  603.5053002019987,
#  598.7647177259987,
#  595.2998176139987,
#  596.9409077479987,
#  588.6730956719987,
#  591.3671008199988,
#  585.3235800579988,
#  580.3190397539988,
#  574.4344103779988,
#  584.4195770639988,
#  590.6472623359988,
#  583.3879472379988,
#  590.5946970059988,
#  600.2783885699988,
#  602.7618290919988,
#  610.2018781499987,
#  615.4379889579986,
#  629.4236380579987,
#  640.2123965759987,
#  639.9957611519987,
#  639.9745038519987,
#  652.7606144199988,
#  647.3719312399987,
#  632.4186018019986,
#  626.9808174999987,
#  619.1823987619987,
#  610.7857418579987,
#  604.5567913039987,
#  595.2246386839987,
#  598.0664856559988,
#  604.3726325339987,
#  606.6066993599987,
#  610.7622484859987,
#  615.9203440379988,
#  629.9892438339988,
#  649.4967698139989,
#  651.0076601759988,
#  659.3326948799988,
#  663.7606781419988,
#  664.5736854179988,
#  661.5560894219988,
#  652.2188719359988,
#  636.6847487739988,
#  634.6677172819988,
#  631.6008495419987,
#  629.3711854779988,
#  624.4737677959987,
#  625.6296907239987,
#  628.4267807239987,
#  630.4840003439988,
#  646.7712924319987,
#  661.5864542379987,
#  683.9573293899987,
#  697.8106200479987,
#  712.2773837979987,
#  724.3494225499987,
#  725.2163867459988,
#  727.6837650239987,
#  718.0189896559988,
#  709.9287749579988,
#  696.1876497699988,
#  685.6570031779987,
#  678.4155481819987,
#  662.8442120959986,
#  651.3975813139987,
#  640.8548017459987,
#  648.3466126379988,
#  658.6251419339987,
#  666.0378487299988,
#  676.0566239519987,
#  701.9814560979987,
#  722.8679374159988,
#  734.1494170099987,
#  746.9420795019987,
#  752.4790419839987,
#  753.4476400079988,
#  757.5332057919987,
#  763.1214896979988,
#  749.8580846179988,
#  750.6820520079988,
#  742.6254466479987,
#  735.7179360059988,
#  724.5672300219987,
#  716.9544299619988,
#  704.9230675719988,
#  688.2755059619988,
#  679.0704856319987,
#  676.5679354119987,
#  674.8864582639987,
#  679.4538161699988,
#  688.6429910799988,
#  707.6208649539988,
#  726.1466278899987,
#  736.5197472199987,
#  749.9666847619987,
#  765.5249967599988,
#  774.7462052059988,
#  775.3277308799987,
#  772.5106174819987,
#  771.4819886919987,
#  763.6379467939987,
#  760.6425287279988,
#  752.9454665039988,
#  750.0438231779987,
#  740.9460931719987,
#  730.1238177719987,
#  721.4599670959988,
#  714.8285259279987,
#  718.3454447759988,
#  718.0473994019987,
#  728.6490725719988,
#  728.9085121099988,
#  742.6554750759988,
#  757.5252372779988,
#  771.9156958539988,
#  781.6024350939989,
#  781.5905407939989,
#  785.3413711019989,
#  789.7813978519989,
#  786.740709919999,
#  791.7848071439989,
#  789.985426941999,
#  792.1094215959989,
#  797.3463461379989,
#  798.898601983999,
#  795.842033543999,
#  790.384405329999,
#  784.685426861999,
#  778.410078115999,
#  785.554618781999,
#  784.296578745999,
#  793.8426512099991,
#  796.572045845999,
#  799.617505689999,
#  799.106810961999,
#  797.1856839839991,
#  795.9296491559991,
#  801.224943305999,
#  800.751638729999,
#  804.344512883999,
#  808.098517689999,
#  801.615169943999,
#  796.1269534579991,
#  797.8275800519991,
#  798.3919173719992,
#  798.7725092959992,
#  810.1222677459991,
#  814.6354483559992,
#  817.2039930859992,
#  820.2936754659992,
#  827.5873609579992,
#  826.2305145479992,
#  820.7887274799991,
#  823.0088070239991,
#  826.4794191859992,
#  815.7979306119992,
#  817.4145866119992,
#  821.7920544979993,
#  814.9985559199993,
#  816.2709883859992,
#  823.7187366299992,
#  831.0108331839991,
#  840.8216456739991,
#  848.336619879999,
#  847.992391339999,
#  847.258932153999,
#  849.238072705999,
#  837.976246669999,
#  836.470309581999,
#  822.821395465999,
#  819.463056357999,
#  813.0059214219989,
#  815.3113253159988,
#  810.3392607799989,
#  827.8799913839989,
#  836.1511686239988,
#  843.6586712079989,
#  858.4829874899988,
#  874.4962922559988,
#  887.4930246759989,
#  905.2606479739989,
#  921.4635352439989,
#  921.3966982659989,
#  914.8180302259989,
#  906.6852984799989,
#  897.0722061299989,
#  878.7261719659989,
#  862.2048994339989,
#  852.3476886139989,
#  849.5476397279989,
#  846.2583042879988,
#  846.1171995519987,
#  858.3379270719987,
#  870.7616697199987,
#  880.2500162439987,
#  886.9910046219987,
#  896.1167028039988,
#  909.9551579039988,
#  907.8631230159988,
#  901.4212513839988,
#  896.1708313379987,
#  893.2956606779987,
#  897.3265667659988,
#  895.4163083059988,
#  893.3302084319988,
#  883.4449141919988,
#  876.7513355319988,
#  891.1851060459989,
#  894.2135610679989,
#  903.0324101739989,
#  908.8840323159989,
#  917.4543635259988,
#  920.4525854459988,
#  921.2920029299987,
#  929.6450276439988,
#  934.4028814759988,
#  930.9902536619988,
#  930.0621787039988,
#  926.4739414839987,
#  915.4686680359987,
#  915.8822474919987,
#  925.0319266479987,
#  927.2800968699987,
#  937.5879523379987,
#  938.3248918119987,
#  940.0230343699988,
#  935.3237048479988,
#  939.4300891859988,
#  938.0392838839988,
#  938.4279323959988,
#  938.4099233099988,
#  936.8634332899989,
#  933.8526643759988,
#  928.6361032439987,
#  930.9913513559987,
#  921.9928821999988,
#  931.7426302659987,
#  940.5943105079987,
#  951.8072315159986,
#  950.1577887019987,
#  949.9030720099986,
#  961.0344549659985,
#  965.6570980939985,
#  963.2026724179984,
#  969.8859550519985,
#  966.5262075039985,
#  959.4794687639986,
#  961.5132802719986,
#  968.6082428359987,
#  971.7247617899986,
#  983.5534211759987,
#  986.6370544419988,
#  985.1808541139987,
#  984.0963267299987,
#  982.2836998279988,
#  975.9191564639988,
#  966.6991268619987,
#  962.6176707879988,
#  963.2014656599988,
#  962.2422869799989,
#  962.5358538959989,
#  969.5670219099989,
#  979.7433576719989,
#  990.5986756419989,
#  998.6890392279988,
#  1006.5067414859988,
#  1013.1911804699987,
#  1017.2790108339988,
#  1025.3624700659989,
#  1021.6548610459988,
#  1019.4543026779988,
#  1026.8031203379987,
#  1025.8764733839987,
#  1022.5165202239987,
#  1011.4445891679986,
#  1004.7671035179986,
#  996.0335319759987,
#  992.0574501099986,
#  985.4582681859986,
#  985.7153166099986,
#  987.5068723159986,
#  992.4356723959986,
#  1004.5534560079985,
#  1017.8580576319985,
#  1034.9500279279985,
#  1041.3969057079985,
#  1048.0990982299984,
#  1044.6772237419984,
#  1051.9048036679985,
#  1044.5501492319986,
#  1036.4798098379986,
#  1032.8162648539985,
#  1037.3550704399986,
#  1032.6807507999986,
#  1040.8218176999985,
#  1047.2186280039984,
#  1040.4572241479984,
#  1041.2971884439985,
#  1041.4825316579984,
#  1041.4007409199985,
#  1047.2308577579986,
#  1047.9445994839987,
#  1054.4748244159987,
#  1057.2842919819986,
#  1059.0717115759987,
#  1065.9451067419986,
#  1058.3714188299987,
#  1060.6288999859987,
#  1054.3673814959986,
#  1048.6079796839986,
#  1061.0180348039987,
#  1052.4215640539987,
#  1049.1158659439989,
#  1051.193165709999,
#  1050.789894687999,
#  1052.992183779999,
#  1067.4002655279992,
#  1075.4293855859992,
#  1070.154254737999,
#  1076.451870589999,
#  1076.648541033999,
#  1089.418208297999,
#  1102.276717653999,
#  1099.936679373999,
#  1091.638553361999,
#  1085.8571403179988,
#  1086.0072051099987,
#  1085.7992124499988,
#  1080.6926951739988,
#  1081.8688192639988,
#  1085.214279127999,
#  1087.800210069999,
#  1092.316731885999,
#  1095.3005837559988,
#  1098.3917441439987,
#  1105.7574817099987,
#  1121.0615520099989,
#  1125.241737319999,
#  1123.025426221999,
#  1128.6863015139988,
#  1121.7355018419987,
#  1118.5637980239987,
#  1108.816042633999,
#  1104.300471697999,
#  1100.697583985999,
#  1096.422910091999,
#  1095.9415977039992,
#  1093.4717059339991,
#  1098.690585533999,
#  1104.899354271999,
#  1110.895366689999,
#  1112.151763245999,
#  1115.9886905699989,
#  1122.500678669999,
#  1120.200142235999,
#  1118.396627811999,
#  1125.602699613999,
#  1126.350089953999,
#  1124.9983518219992,
#  1119.6709220099992,
#  1121.8926201139993,
#  1128.2726177799993,
#  1131.9979506419995,
#  1135.8666299039994,
#  1139.3966194399995,
#  1143.4158660999994,
#  1153.5237536219995,
#  1171.0914036859995,
#  1175.4298099959994,
#  1181.2913635619993,
#  1191.9457870839992,
#  1208.1160276779992,
#  1202.7040442499992,
#  1197.9719835199992,
#  1182.954377045999,
#  1176.110821261999,
#  1166.310277569999,
#  1149.873079277999,
#  1147.1527828859992,
#  1131.626710655999,
#  1120.708969869999,
#  1113.672263109999,
#  1113.856595005999,
#  1110.657467265999,
#  1115.293642029999,
#  1128.009253041999,
#  1143.184631165999,
#  1164.356457299999,
#  1182.597668869999,
#  1193.762120719999,
#  1196.754482565999,
#  1204.3288445259989,
#  1199.3148844659988,
#  1207.909989661999,
#  1211.787558347999,
#  1209.437186469999,
#  1207.084934311999,
#  1198.177398007999,
#  1197.532893123999,
#  1188.0347220279991,
#  1186.2852957259993,
#  1196.1634150279992,
#  1197.8742265379992,
#  1200.8088007579993,
#  1211.2288231159994,
#  1208.8168727539994,
#  1216.2015606319994,
#  1217.3125632219994,
#  1213.1493025359994,
#  1209.9472427879994,
#  1198.5281349899994,
#  1193.8744160959995,
#  1197.7510970819994,
#  1200.8690119639994,
#  1202.6205804499994,
#  1212.2800240679994,
#  1221.4505253739994,
#  1230.3705405759993,
#  1246.2226270979993,
#  1264.2122606299993,
#  1276.6756821739993,
#  1282.5054320719994,
#  1280.4866274519993,
#  1280.0546428499995,
#  1264.4287103099996,
#  1249.1164826459994,
#  1235.9255704299994,
#  1219.2964594559994,
#  1211.4613604679994,
#  1199.7299977599996,
#  1191.2375640179996,
#  1183.1462995859995,
#  1190.3036724059994,
#  1201.1324964499993,
#  1214.3752870539993,
#  1230.9748956459994,
#  1246.5212378879994,
#  1268.4195276659993,
#  1284.5678976399993,
#  1296.2207852879992,
#  1308.287337215999,
#  1318.313400351999,
#  1317.837331887999,
#  1316.935605711999,
#  1312.706026485999,
#  1312.354869975999,
#  1297.296936969999,
#  1289.462802431999,
#  1282.386693391999,
#  1275.467559461999,
#  1267.0901450939991,
#  1256.9892583459991,
#  1257.7770614799992,
#  1272.4422950299993,
#  1261.0178631259994,
#  1261.8679102199994,
#  1266.4563914239995,
#  1275.2605531599995,
#  1282.1852436419995,
#  1281.4704498659994,
#  1283.2607221219994,
#  1287.0124648739995,
#  1293.2954127679996,
#  1295.0208334999995,
#  1298.3345303499996,
#  1300.4854162619995,
#  1295.4669209059994,
#  1297.0613426299992,
#  1305.2165629059994,
#  1303.3765638759994,
#  1312.6247099839993,
#  1323.9583308639994,
#  1329.5315391379993,
#  1332.7667398979993,
#  1332.4471578019993,
#  1322.8108231699991,
#  1323.427887435999,
#  1324.227472953999,
#  1324.869303685999,
#  1331.903850091999,
#  1340.042893437999,
#  1349.4872035019991,
#  1347.0647688939994,
#  1344.9803674399993,
#  1347.5246066799994,
#  1338.9177229459992,
#  1344.5644071979991,
#  1346.6542377659991,
#  1340.1665568939993,
#  1344.0826599919994,
#  1345.1470543379994,
#  1349.4785196179994,
#  1350.3778174359995,
#  1353.1579476199995,
#  1354.7647426919996,
#  1362.6544009299994,
#  1355.4865377939993,
#  1345.4479597699992,
#  1343.2282934059992,
#  1345.6428342799993,
#  1344.7604601259993,
#  1344.9194375499992,
#  1349.2319634759992,
#  1348.4781465039991,
#  1363.1959814799993,
#  1379.2266102719993,
#  1391.8540688639994,
#  1397.7894542139993,
#  1399.9357702099992,
#  1409.7318068139994,
#  1396.9653880559993,
#  1399.9962394059994,
#  1398.9891267759995,
#  1389.1717900499993,
#  1386.7266051219995,
#  1387.8568735999993,
#  1398.5698149699992,
#  1406.215441497999,
#  1417.113733371999,
#  1417.503840493999,
#  1421.338494705999,
#  1413.1396411099988,
#  1415.348531473999,
#  1410.949071657999,
#  1402.9541233219988,
#  1404.1460822559989,
#  1400.4223444219988,
#  1405.3970123879988,
#  1409.2199474219988,
#  1411.8862429819987,
#  1413.5272571559988,
#  1398.637364697999,
#  1391.680360611999,
#  1376.220330833999,
#  1378.6452313159991,
#  1379.6722897879993,
#  1385.0924017259993,
#  1389.8082509339993,
#  1400.4781901279991,
#  1414.2008394559991,
#  1429.1247923879992,
#  1448.0907262679991,
#  1461.4739359519992,
#  1470.8958890299991,
#  1477.017855717999,
#  1475.2255697579992,
#  1472.0735859199992,
#  1472.0489644999993,
#  1467.5941398039993,
#  1453.4647879539991,
#  1433.719735183999,
#  1411.3529533019992,
#  1398.208146467999,
#  1395.6739065499992,
#  1386.2273286339992,
#  1381.3709085359992,
#  1380.2045415939992,
#  1390.6604349659992,
#  1408.9970438959992,
#  1419.9344320779992,
#  1428.6919345439992,
#  1457.6611518199993,
#  1479.5848649719992,
#  1492.6887737399993,
#  1505.6707437059993,
#  1512.2388508179993,
#  1520.2626811319994,
#  1515.1183152559995,
#  1497.2193914239995,
#  1472.7399998839994,
#  1453.8486168699994,
#  1442.4052558139995,
#  1433.2826922379995,
#  1419.2076119119995,
#  1416.2637724219994,
#  1415.3197224939993,
#  1420.4470534859993,
#  1436.5740988179994,
#  1455.7789445799995,
#  1471.9268200479994,
#  1475.6523347659995,
#  1488.1717559519993,
#  1508.5174682379993,
#  1527.1220542339993,
#  1534.5059480819993,
#  1542.9548502799994,
#  1546.0763074899994,
#  1549.1848738879994,
#  1544.1444364479994,
#  1531.0756446299993,
#  1523.5056260719991,
#  1498.765755465999,
#  1482.861689097999,
#  1473.608846215999,
#  1477.1515994199988,
#  1477.823205111999,
#  1480.8876863239989,
#  1478.8508677859988,
#  1476.0938477299987,
#  1482.3996976559988,
#  1495.105145275999,
#  1512.515172673999,
#  1523.9781178839987,
#  1539.1378218919988,
#  1542.8201303079989,
#  1550.608214325999,
#  1541.5405440259988,
#  1542.414716185999,
#  1538.6505712279989,
#  1522.5772214539988,
#  1519.5812731759988,
#  1514.2038581479987,
#  1507.9735995839987,
#  1503.2091220059988,
#  1508.276945493999,
#  1506.735236073999,
#  1507.6215150699988,
#  1520.388029179999,
#  1526.012189757999,
#  1534.7904893159991,
#  1548.400965369999,
#  1571.537694207999,
#  1579.600886581999,
#  1587.732864427999,
#  1595.524281157999,
#  1598.682314499999,
#  1588.818126683999,
#  1577.028993861999,
#  1563.851645915999,
#  1555.5489167539988,
#  1540.008353117999,
#  1527.9711228019987,
#  1522.3246821359987,
#  1514.0328395619988,
#  1515.2957970419989,
#  1522.845470635999,
#  1521.1744535019989,
#  1535.276322177999,
#  1557.187939471999,
#  1574.851892833999,
#  1592.400032623999,
#  1607.5763958499992,
#  1630.5169750259993,
#  1639.4432595919993,
#  1640.4327569139994,
#  1641.4836530899993,
#  1631.3267647699993,
#  1620.8358467059993,
#  1609.6313390259993,
#  1596.9885255999993,
#  1585.0845796139993,
#  1576.4948594139992,
#  1562.6097388379992,
#  1553.1692192439991,
#  1552.610877009999,
#  1553.0320140619992,
#  1566.8911835479992,
#  1570.207650799999,
#  1583.1651611539992,
#  1583.2752725619991,
#  1602.0658473379992,
#  1617.355234335999,
#  1626.483755245999,
#  1633.539124519999,
#  1640.915445831999,
#  1651.733824931999,
#  1654.493494721999,
#  1651.260189563999,
#  1645.6003964899987,
#  1639.5808935719988,
#  1634.0577897419987,
#  1629.0819094379988,
#  1619.9587898559987,
#  1607.9755353199987,
#  1604.8584676399987,
#  1610.0758379459987,
#  1605.8518163339988,
#  1609.5320410839988,
#  1619.484024557999,
#  1621.3723857419989,
#  1632.3913716179989,
#  1645.9598026559988,
#  1673.0667439959989,
#  1684.0685427759988,
#  1694.8347545339986,
#  1692.2526370979988,
#  1686.2384399039988,
#  1692.8536033899989,
#  1698.1577235619989,
#  1693.8243478619988,
#  1680.1363991759988,
#  1672.800272909999,
#  1663.404255375999,
#  1653.8173809199989,
#  1646.5913314399988,
#  1639.504418847999,
#  1637.082315047999,
#  1644.7623239599989,
#  1655.6229747919988,
#  1670.7299669979989,
#  1685.6676318839989,
#  1695.6321515019988,
#  1713.570964555999,
#  1724.9819234759989,
#  1731.962039555999,
#  1744.8943463159987,
#  1743.147041185999,
#  1735.9984990779988,
#  1722.3630804719987,
#  1721.4700810799986,
#  1720.6186776059988,
#  1706.7253756319988,
#  1702.9789210159986]

# %%
#绘图 accumulative_constraint_violation和accumulative_constraint_violation_T

# %%
sub1=plt.subplot(1, 2, 1)##############################################################
iteration=[]
for i in range(0,999):
    iteration.append(i)

#在同一幅图片上画3条折线
A,=plt.plot(iteration,accumulative_constraint_violation,color = 'green',linewidth = '1.5',label='attack-free online primal-dual algorithm')


#设置图例并且设置图例的字体及大小
font1 = {
'size'   : 18,
}
#legend = plt.legend(handles=[A],prop=font1)
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=18)
 
#设置横纵坐标的名称以及对应字体格式
font2 = {
'size'   : 18,
}
plt.xlabel('T',font2)
plt.ylabel(r'Constraint violation $Fit(T)$',font2)
plt.title('varying $D_{t}$',font2) 

sub2=plt.subplot(1, 2, 2)##############################################################
iteration=[]
for i in range(0,999):
    iteration.append(i)

#在同一幅图片上画3条折线
A,=plt.plot(iteration,accumulative_constraint_violation_T,color = 'green',linewidth = '1.5',label='attack-free online primal-dual algorithm')


#设置图例并且设置图例的字体及大小
font1 = {
'size'   : 18,
}
#legend = plt.legend(handles=[A],prop=font1)
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=18)
 
#设置横纵坐标的名称以及对应字体格式
font2 = {
'size'   : 18,
}
plt.xlabel('T',font2)
plt.ylabel(r'Constraint violation $Fit(T)/T$',font2)
plt.title('varying $D_{t}$',font2) 

plt.legend(handles=[A],prop={'size':18},loc="upper center", bbox_to_anchor=[-0.3, -0.2],
           ncol=18, shadow=True, fancybox=True)

plt.subplots_adjust(wspace=0.5,hspace=0.5) 
plt.gcf().set_size_inches((15, 5))


#plt.savefig('./figures/01-figure2_constraint_violation_attack_free_varying_D.pdf',format='pdf', bbox_inches='tight')
#plt.savefig('./figures/01-figure2_constraint_violation_attack_free_varying_D.png',format='png', bbox_inches='tight')
