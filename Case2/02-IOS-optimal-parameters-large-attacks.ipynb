# %% [raw]
# IOS鲁棒的decentralized online economic dispatch algorithm+大值攻击
#
# 实验设置：IEEE118bus+6个风能发电站
# 发电站数量：54个传统火力发电站+6个风能发电站
# 时变的变量：1. 风速服从的weibull分布的尺度参数c
# 2. 风速服从的weibull分布的形状参数wk
# 3. 用户侧的平均用电需求D
# 尺度参数c和形状参数wk采用真实数据集数据
# 平均用电需求D服从均值为100 均方差为10的正态分布
# 54个传统火力发电站的发电成本相关数据见数据集
# 传统火力发电站成本函数：a+bP+cP^2
# 6个风能发电站的发电成本相关参数见论文手稿
#
# 选择两个拜占庭发电站 一个为54号火力发电站 一个为58号风能发电站
#
# 大值攻击 拜占庭发电站向邻居发送大值的对偶攻击 -0.01
#
# IOS+adaptive clipping

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
from sympy import *
import math 
from datetime import datetime
from scipy.special import gamma, factorial
import scipy.special as sc

# %%
#定义变量
thermal_power_station_strategy=np.zeros(shape=(54,1000)) 
wind_power_station_strategy=np.zeros(shape=(6,1000))
thermal_power_station_dual_variable=np.zeros(shape=(54,1000))
wind_power_station_dual_variable=np.zeros(shape=(6,1000))
E=np.loadtxt("IEEE-118-doubly-stochastic-weight-matrix.txt")
thermal_power_station_cost=np.zeros(shape=(1,1000)) #火力发电成本
wind_power_station_cost=np.zeros(shape=(1,1000)) #风力发电成本
sum_cost=np.zeros(shape=(1,1000)) #总发电成本
sum_thermal_wind_power_station_strategy=np.zeros(shape=(1,1000))#总发电量
#火力发电站的相关数据  其中54号为拜占庭
generator_a_values= np.loadtxt("./real-data/generator_a_values.txt")#每个agent的成本函数中的超参数a
generator_b_values= np.loadtxt("./real-data/generator_b_values.txt")#每个agent的成本函数中的超参数a
generator_c_values= np.loadtxt("./real-data/generator_c_values.txt")#每个agent的成本函数中的超参数a
thermal_power_station_P_max= np.loadtxt("./real-data/generator_Pmax_values.txt")#每个agent的资源量的上界
thermal_power_station_P_min= np.loadtxt("./real-data/generator_Pmin_values.txt")#每个agent的资源量的下界
#55 56 57 58 59 60号诚实风能的成本相关数据 其中58号为拜占庭 
wind_power_station_varphi=[1,6,1,6,1,6]
wind_power_station_v_in=[3,4,5,3,4,5]
wind_power_station_v_out=[25,45,25,45,25,45]
wind_power_station_v_r=[13,15,16,13,15,16]
wind_power_station_sigma_ue=[3,5,3,5,3,5]
wind_power_station_sigma_oe=[20,30,20,30,20,30]
wind_power_station_P_r=[150,160,150,160,150,160]
wind_power_station_P_min=[0,0,0,0,0,0]
wind_power_station_P_max=[500,300,400,200,300,200]
#不确定性的参数 时变参数
d_power_demand=np.loadtxt("./data/d_power_demand_normal_distribution_(100,10).txt") #时变的需求侧用电需求  
c_wind_speed= np.loadtxt("./real-data/weibull_scale_c.txt")      
kappa_wind_speed= np.loadtxt("./real-data/weibull_shape_wk.txt") 
#迭代步长
step_size_primal=5
step_size_dual=5
#正则化参数
regularization_parameter=0.00001

# %%
#变量初始化
#火力，风力发电策略初始化 诚实
'''for i in range(0,53):
    thermal_power_station_strategy[i][0]=0
for j in range(0,6):
    if j!=3:
        wind_power_station_strategy[j][0]=0'''
for i in range(0,53):
    thermal_power_station_strategy[i][0]=thermal_power_station_P_max[i]
for j in range(0,6):
    if j!=3:
        wind_power_station_strategy[j][0]=thermal_power_station_P_max[j]
        
#拜占庭发电站发电策略初始化 拜占庭
thermal_power_station_strategy[53][0]=0
wind_power_station_strategy[3][0]=0
#诚实用户的初始总发电策略
'''sum_thermal_wind_power_station_strategy[0][0]=0'''
#诚实用户的初始总发电策略
for i in range(0,53):
    sum_thermal_wind_power_station_strategy[0][0]+=thermal_power_station_strategy[i][0]
for j in range(0,6):
    if j!=3:
        sum_thermal_wind_power_station_strategy[0][0]+= wind_power_station_strategy[j][0]

#火力，风力对偶策略初始化 诚实
for i in range(0,53):
    thermal_power_station_dual_variable[i][0]=-1000
for j in range(0,6):
    if j!=3:
        wind_power_station_dual_variable[j][0]=-1000
#拜占庭发电站对偶策略初始化 拜占庭
thermal_power_station_dual_variable[53][0]=-0.01
wind_power_station_dual_variable[3][0]=-0.01

#安全发电站的初始总发电成本 诚实
#火力发电成本
for i in range(0,53):
    thermal_power_station_cost[0][0]=thermal_power_station_cost[0][0]+generator_c_values[i]*thermal_power_station_strategy[i][0]*thermal_power_station_strategy[i][0]+generator_b_values[i]*thermal_power_station_strategy[i][0]+generator_a_values[i]
#风力发电成本
for i in range(0,6):
    if i!=3:
        wind_power_station_cost[0][0]=wind_power_station_cost[0][0]+wind_power_station_varphi[i]*wind_power_station_strategy[i][0]+wind_power_station_sigma_ue[i]*((wind_power_station_P_r[i]-wind_power_station_strategy[i][0])*(math.exp(-(math.pow(wind_power_station_v_r[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0])))-math.exp(-(math.pow(wind_power_station_v_out[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0]))))+(wind_power_station_P_r[i]*wind_power_station_v_in[i]/(wind_power_station_v_r[i]-wind_power_station_v_in[i])+wind_power_station_strategy[i][0])*(math.exp(-(math.pow(wind_power_station_v_r[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0])))-math.exp(-(math.pow(wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][0])/wind_power_station_P_r[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0]))))+(wind_power_station_P_r[i]*c_wind_speed[0]/(wind_power_station_v_r[i]-wind_power_station_v_in[i]))*(sc.gammaincc(1+1/kappa_wind_speed[0],(math.pow(wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][0])/wind_power_station_P_r[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0])))*sc.gamma(1+1/kappa_wind_speed[0])-sc.gammaincc(1+1/kappa_wind_speed[0],math.pow(wind_power_station_v_r[i]/c_wind_speed[0],kappa_wind_speed[0]))*sc.gamma(1+1/kappa_wind_speed[0])))+wind_power_station_sigma_oe[i]*((wind_power_station_strategy[i][0])*(1-math.exp(-(math.pow(wind_power_station_v_in[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0])))+math.exp(-(math.pow(wind_power_station_v_out[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0]))))+(wind_power_station_P_r[i]*wind_power_station_v_in[i]/(wind_power_station_v_r[i]-wind_power_station_v_in[i])+wind_power_station_strategy[i][0])*(math.exp(-(math.pow(wind_power_station_v_in[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0])))-math.exp(-(math.pow(wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][0])/wind_power_station_P_r[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0]))))+(wind_power_station_P_r[i]*c_wind_speed[0]/(wind_power_station_v_r[i]-wind_power_station_v_in[i]))*(sc.gammaincc(1+1/kappa_wind_speed[0],(math.pow(wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][0])/wind_power_station_P_r[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0])))*sc.gamma(1+1/kappa_wind_speed[0])-sc.gammaincc(1+1/kappa_wind_speed[0],math.pow(wind_power_station_v_in[i]/c_wind_speed[0],kappa_wind_speed[0]))*sc.gamma(1+1/kappa_wind_speed[0])))
#发电总成本
sum_cost[0][0]=thermal_power_station_cost[0][0]+wind_power_station_cost[0][0]

#计算每个发电站的邻居发电站
neighbor_robust1_help=[]
for i in range (0,60):
    for j in range (0,60):
        if E[i][j]!=0:
            neighbor_robust1_help.append(j)
        elif E[i][j]==0:
            neighbor_robust1_help.append(99)
neighbor_robust1=np.array(neighbor_robust1_help).reshape(60,60)

#计算安全的发电站的拜占庭邻居用户数量
q_robust1=[]
for i in range(0,60):
    q_robust1_help=0
    for j in range(0,60):
        if neighbor_robust1[i][j]==53 or neighbor_robust1[i][j]==57:
            q_robust1_help=q_robust1_help+1
    q_robust1.append(q_robust1_help)

# %%
def IOS_Byzantine_attack_decentralized_economic_dispatch(thermal_power_station_strategy,wind_power_station_strategy,c_wind_speed,kappa_wind_speed,d_power_demand,thermal_power_station_dual_variable,wind_power_station_dual_variable,E,thermal_power_station_cost,wind_power_station_cost,generator_a_values,generator_b_values,generator_c_values,thermal_power_station_P_min,thermal_power_station_P_max,wind_power_station_varphi,wind_power_station_sigma_ue,wind_power_station_sigma_oe,wind_power_station_P_min,wind_power_station_P_max,sum_thermal_wind_power_station_strategy,step_size_primal,step_size_dual):
    #显示初始化的数据
    #输出初始状态的原变量和对偶变量
    print("***************************large_attack_online_decentralized_economic_dispatch*****************************")
    print("相关变量初始值为：")
    for i in range (0,52):
        print("第",(i+1),"个火力发电站的初始计划发电量为:",thermal_power_station_strategy[i][0])
    for i in range (0,6):
        if i!=3:
            print("第",(i+55),"个风力发电站的初始计划发电量为:",wind_power_station_strategy[i][0])
    print("****************************************************************************")
    for i in range (0,52):
        print("第",(i+1),"个火力发电站的初始对偶变量为:",thermal_power_station_dual_variable[i][0])
    for i in range (0,6):
        if i!=3:
            print("第",(i+55),"个风力发电站的初始对偶变量为:",wind_power_station_dual_variable[i][0])
    print("****************************************************************************")
    print("第",(54),"个受到Byzantin攻击的火力发电站的初始对偶变量为:",thermal_power_station_dual_variable[53][0])
    print("第",(58),"个受到Byzantin攻击的风力发电站的初始对偶变量为:",wind_power_station_dual_variable[3][0])
    print("****************************************************************************")
    print("安全发电站的初始总发电量:",sum_thermal_wind_power_station_strategy[0][0])
    print("*************************")
    print("需求侧平均用电需求:",d_power_demand[0])
    print("****************************************************************************")
    print("风速分布参数c:",c_wind_speed[0])
    print("****************************************************************************")
    print("风速分布参数kappa:",kappa_wind_speed[0])
    print("****************************************************************************")
    print("安全发电站的总发电成本：", sum_cost[0][0])
    print("****************************************************************************")
    print("原变量迭代步长为:",step_size_primal)
    print("*****************************************************************************")
    print("对偶变量迭代步长为:",step_size_dual)
    print("*****************************************************************************")
    
    #开始迭代
    for k in range(1,1000):
        #发电站更新计划发电量和对偶变量
        #对偶变量 先做梯度上升 再做聚合
        dual_variable_intermediate=[] #存放当前迭代中60个用户对对偶变量做完梯度下降后得到的中间值
        for i in range(0,53):
            dual_variable_intermediate.append(thermal_power_station_dual_variable[i][k-1]+step_size_dual*((1/60)*thermal_power_station_strategy[i][k-1]-(1/60)*d_power_demand[k-1]-regularization_parameter*thermal_power_station_dual_variable[i][k-1]))
        #添加拜占庭火力发电站的对偶值
        dual_variable_intermediate.append(thermal_power_station_dual_variable[53][k-1])
        for j in range(0,6):
            if j==3: #添加拜占庭风力发电站的对偶值
                dual_variable_intermediate.append(wind_power_station_dual_variable[j][k-1])
            else:
                dual_variable_intermediate.append(wind_power_station_dual_variable[j][k-1]+step_size_dual*((1/60)*wind_power_station_strategy[j][k-1]-(1/60)*d_power_demand[k-1]-regularization_parameter*wind_power_station_dual_variable[j][k-1]))
        
        #IOS鲁棒聚合+adaptive clipping 安全的火力发电站的对偶更新
        #在做鲁棒聚合前 对收集到的信息进行adaptive clipping的剪裁操作
        for i in range (0,53):
            u_neighbor_help_robust1=neighbor_robust1[i].tolist()#将用户i的邻居序号存在辅助变量u中
            u_neighbor_help_robust1 = list(set(u_neighbor_help_robust1))
            u_neighbor_help_robust1.remove(99)
            if int(q_robust1[i])==1: #只有具有拜占庭邻居的用户才需要先进行adaptive clipping和后续的IOS聚合操作
                #先进行adaptive clipping 
                dual_variable_intermediate_auxiliary=[]
                #注意必须以这样的方式赋值 不能直接写dual_variable_intermediate_auxiliary=dual_variable_intermediate
                #不然在修改变量dual_variable_intermediate_auxiliary的同时也会对dual_variable_intermediate进行修改
                for j in range(len(dual_variable_intermediate)): 
                    dual_variable_intermediate_auxiliary.append(dual_variable_intermediate[j])
                dual_variable_receive=[]
                clipping_C=0
                for j in range(0, len(u_neighbor_help_robust1)):
                    dual_variable_receive.append(dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[j]])
                dual_variable_receive.sort()
                clipping_C=-dual_variable_receive[1] #确定clpping的阈值
                #接下来对大于clipping_C的值进行clipping
                for j in range(0, len(u_neighbor_help_robust1)):
                    if -dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[j]]>clipping_C:
                        dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[j]]=-clipping_C
                #接下来做IOS鲁棒聚合
                dual_variable_weight_average_robust1=0
                h_robust1=0
                for j in range(0,len(u_neighbor_help_robust1)):#计算当前循环中的h值
                    h_robust1=h_robust1+E[i][u_neighbor_help_robust1[j]]
                for j in range(0,len(u_neighbor_help_robust1)):#计算当前循环中的对偶权重平均值
                    dual_variable_weight_average_robust1=dual_variable_weight_average_robust1+(1/h_robust1)*(E[i][u_neighbor_help_robust1[j]]*dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[j]])
                #剔除一个对偶值离权重平均对偶值最远的用户 保留自身的值
                u_neighbor_help_robust1.remove(i)
                neighbor_index_robust1=u_neighbor_help_robust1[0]
                max_distance_roubust1=abs(dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[0]]-dual_variable_weight_average_robust1)
                for j in range(1,len(u_neighbor_help_robust1)):
                    if abs(dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[j]]-dual_variable_weight_average_robust1)>=max_distance_roubust1:
                        max_distance_roubust1=abs(dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[j]]-dual_variable_weight_average_robust1)
                        neighbor_index_robust1=u_neighbor_help_robust1[j]
                u_neighbor_help_robust1.remove(neighbor_index_robust1)
                u_neighbor_help_robust1.append(i)
                #计算剔除q个信息后的权重平均对偶值
                dual_variable_weight_average_robust1=0
                h_robust1=0
                for j in range(0,len(u_neighbor_help_robust1)):
                    h_robust1=h_robust1+E[i][u_neighbor_help_robust1[j]]
                for j in range(0,len(u_neighbor_help_robust1)):
                    dual_variable_weight_average_robust1=dual_variable_weight_average_robust1+(1/h_robust1)*(E[i][u_neighbor_help_robust1[j]]*dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[j]])     
                #诚实用户基于IOS鲁棒聚合后的值进行自身的对偶变量的更新 基于权重平均值
                thermal_power_station_dual_variable[i][k]=dual_variable_weight_average_robust1              
            else: #没有拜占庭邻居的用户直接进行权重聚合即可
                dual_variable_weight_average_robust1=0
                h_robust1=0
                for j in range(0,len(u_neighbor_help_robust1)):#计算当前循环中的h值
                    h_robust1=h_robust1+E[i][u_neighbor_help_robust1[j]]
                for j in range(0,len(u_neighbor_help_robust1)):
                    dual_variable_weight_average_robust1=dual_variable_weight_average_robust1+(1/h_robust1)*(E[i][u_neighbor_help_robust1[j]]*dual_variable_intermediate[u_neighbor_help_robust1[j]]) 
                    #dual_variable_weight_average_robust1=dual_variable_weight_average_robust1+(E[i][u_neighbor_help_robust1[j]]*dual_variable_intermediate[u_neighbor_help_robust1[j]])                  
                #诚实用户基于IOS鲁棒聚合后的值进行自身的对偶变量的更新 基于权重平均值
                thermal_power_station_dual_variable[i][k]=dual_variable_weight_average_robust1  
                #thermal_power_station_dual_variable[i][k]=9999

        #安全的风力发电站的adaptive clipping操作 由于风力发电站的邻居中没有拜占庭用户 所以不需要进行adaptive clipping的操作
        #聚合 安全的风力发电站的对偶更新
        for i in range(0,6):
            if i!=3:
                u_neighbor_help_robust1=neighbor_robust1[i+54].tolist()#将用户i的邻居序号存在辅助变量u中
                u_neighbor_help_robust1 = list(set(u_neighbor_help_robust1))
                u_neighbor_help_robust1.remove(99)
                dual_variable_weight_average_robust1=0
                h_robust1=0
                for j in range(0,len(u_neighbor_help_robust1)):
                    h_robust1=h_robust1+E[i+54][u_neighbor_help_robust1[j]]               
                for j in range(0,len(u_neighbor_help_robust1)):
                    dual_variable_weight_average_robust1=dual_variable_weight_average_robust1+(1/h_robust1)*(E[i+54][u_neighbor_help_robust1[j]]*dual_variable_intermediate[u_neighbor_help_robust1[j]])     
                wind_power_station_dual_variable[i][k]=dual_variable_weight_average_robust1
        
        #受到Byzantine攻击的火力和风力发电站的对偶更新
        thermal_power_station_dual_variable[53][k]=thermal_power_station_dual_variable[53][k-1]
        wind_power_station_dual_variable[3][k]=wind_power_station_dual_variable[3][k-1]            
        
        #安全的火力发电站计划发电量
        for i in range(0,53):
            thermal_power_station_strategy[i][k]=thermal_power_station_strategy[i][k-1]-step_size_primal*(2*generator_c_values[i]*thermal_power_station_strategy[i][k-1]+generator_b_values[i]+(1/60)*thermal_power_station_dual_variable[i][k-1]) 
            if thermal_power_station_strategy[i][k]<=thermal_power_station_P_min[i]:
                thermal_power_station_strategy[i][k]=thermal_power_station_P_min[i]
            elif thermal_power_station_strategy[i][k]>=thermal_power_station_P_max[i]:
                thermal_power_station_strategy[i][k]=thermal_power_station_P_max[i]
        #安全的风力发电站计划发电量
        for i in range(0,6):
            if i!=3:
                wind_power_station_strategy[i][k]=wind_power_station_strategy[i][k-1]-step_size_primal*(wind_power_station_varphi[i]+wind_power_station_sigma_oe[i]+(wind_power_station_sigma_ue[i]+wind_power_station_sigma_oe[i])*math.exp(-(math.pow(wind_power_station_v_out[i],kappa_wind_speed[k-1]))/(math.pow(c_wind_speed[k-1],kappa_wind_speed[k-1])))+(-wind_power_station_sigma_ue[i]-wind_power_station_sigma_oe[i])*math.exp(-(math.pow((wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][k-1])/wind_power_station_P_r[i]),kappa_wind_speed[k-1]))/(math.pow(c_wind_speed[k-1],kappa_wind_speed[k-1])))+(1/60)*wind_power_station_dual_variable[i][k-1])
                if wind_power_station_strategy[i][k]<=wind_power_station_P_min[i]:
                    wind_power_station_strategy[i][k]=wind_power_station_P_min[i]
                elif wind_power_station_strategy[i][k]>=wind_power_station_P_max[i]:
                    wind_power_station_strategy[i][k]=wind_power_station_P_max[i]
        #受到Byzantine攻击的火力和风力发电站的计划发电量
        thermal_power_station_strategy[53][k]=thermal_power_station_strategy[53][k-1]
        wind_power_station_strategy[3][k]=wind_power_station_strategy[3][k-1]
        
        #安全发电站的计算总计划发电
        #火力发电量
        for i in range(0,53):
            sum_thermal_wind_power_station_strategy[0][k]=sum_thermal_wind_power_station_strategy[0][k]+thermal_power_station_strategy[i][k]
        #风力发电量
        for i in range(0,6):
            if i!=3:
                sum_thermal_wind_power_station_strategy[0][k]=sum_thermal_wind_power_station_strategy[0][k]+wind_power_station_strategy[i][k]
        
        #安全发电站的计算总发电成本
        #火力发电成本
        for i in range(0,53):
            thermal_power_station_cost[0][k]=thermal_power_station_cost[0][k]+generator_c_values[i]*thermal_power_station_strategy[i][k]*thermal_power_station_strategy[i][k]+generator_b_values[i]*thermal_power_station_strategy[i][k]+generator_a_values[i]
        #风力发电成本
        for i in range(0,6):
            if i!=3:
                wind_power_station_cost[0][k]=wind_power_station_cost[0][k]+wind_power_station_varphi[i]*wind_power_station_strategy[i][k]+wind_power_station_sigma_ue[i]*((wind_power_station_P_r[i]-wind_power_station_strategy[i][k])*(math.exp(-(math.pow(wind_power_station_v_r[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k])))-math.exp(-(math.pow(wind_power_station_v_out[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k]))))+(wind_power_station_P_r[i]*wind_power_station_v_in[i]/(wind_power_station_v_r[i]-wind_power_station_v_in[i])+wind_power_station_strategy[i][k])*(math.exp(-(math.pow(wind_power_station_v_r[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k])))-math.exp(-(math.pow(wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][k])/wind_power_station_P_r[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k]))))+(wind_power_station_P_r[i]*c_wind_speed[k]/(wind_power_station_v_r[i]-wind_power_station_v_in[i]))*(sc.gammaincc(1+1/kappa_wind_speed[k],(math.pow(wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][k])/wind_power_station_P_r[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k])))*sc.gamma(1+1/kappa_wind_speed[k])-sc.gammaincc(1+1/kappa_wind_speed[k],math.pow(wind_power_station_v_r[i]/c_wind_speed[k],kappa_wind_speed[k]))*sc.gamma(1+1/kappa_wind_speed[k])))+wind_power_station_sigma_oe[i]*((wind_power_station_strategy[i][k])*(1-math.exp(-(math.pow(wind_power_station_v_in[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k])))+math.exp(-(math.pow(wind_power_station_v_out[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k]))))+(wind_power_station_P_r[i]*wind_power_station_v_in[i]/(wind_power_station_v_r[i]-wind_power_station_v_in[i])+wind_power_station_strategy[i][k])*(math.exp(-(math.pow(wind_power_station_v_in[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k])))-math.exp(-(math.pow(wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][k])/wind_power_station_P_r[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k]))))+(wind_power_station_P_r[i]*c_wind_speed[k]/(wind_power_station_v_r[i]-wind_power_station_v_in[i]))*(sc.gammaincc(1+1/kappa_wind_speed[k],(math.pow(wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][k])/wind_power_station_P_r[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k])))*sc.gamma(1+1/kappa_wind_speed[k])-sc.gammaincc(1+1/kappa_wind_speed[k],math.pow(wind_power_station_v_in[i]/c_wind_speed[k],kappa_wind_speed[k]))*sc.gamma(1+1/kappa_wind_speed[k])))
        #发电总成本
        sum_cost[0][k]=thermal_power_station_cost[0][k]+wind_power_station_cost[0][k]
        
        #输出第k次迭代中的结果 每间隔10次迭代输出一次结果
        #if (k+1)%10==0:
        if k<=5:
            print(k,"次迭代中的结果：")
            for i in range (0,53):
                print("第",(i+1),"个火力发电站的计划发电量为:",thermal_power_station_strategy[i][k])
            for i in range (0,6):
                if i!=3:
                    print("第",(i+55),"个风力发电站的计划发电量为:",wind_power_station_strategy[i][k])
            print("****************************************************************************")
            for i in range (0,53):
                print("第",(i+1),"个火力发电站的对偶变量为:",thermal_power_station_dual_variable[i][k])
            for i in range (0,6):
                if i!=3:
                    print("第",(i+55),"个风力发电站的对偶变量为:",wind_power_station_dual_variable[i][k])
            print("****************************************************************************")
            print("第",(54),"个受到Byzantin攻击的火力发电站的初始对偶变量为:",thermal_power_station_dual_variable[53][k])
            print("第",(58),"个受到Byzantin攻击的风力发电站的初始对偶变量为:",wind_power_station_dual_variable[3][k])
            print("****************************************************************************")
            print("安全发电站的总发电量:",sum_thermal_wind_power_station_strategy[0][k])
            print("*************************")
            print("需求侧平均用电需求:",d_power_demand[k])
            print("****************************************************************************")
            print("风速分布参数c:",c_wind_speed[k])
            print("****************************************************************************")
            print("风速分布参数kappa:",kappa_wind_speed[k])
            print("****************************************************************************")        
            print("安全发电站的总发电成本：", sum_cost[0][k])
            print("****************************************************************************")
            print("原变量迭代步长为:",step_size_primal)
            print("****************************************************************************")
            print("对偶变量迭代步长为:",step_size_dual)
            print("****************************************************************************")

    print(datetime.now().strftime('%Y-%m-%d %H:%M:%S.%f')[:-3])
    return None

# %%
IOS_Byzantine_attack_decentralized_economic_dispatch(thermal_power_station_strategy,wind_power_station_strategy,c_wind_speed,kappa_wind_speed,d_power_demand,thermal_power_station_dual_variable,wind_power_station_dual_variable,E,thermal_power_station_cost,wind_power_station_cost,generator_a_values,generator_b_values,generator_c_values,thermal_power_station_P_min,thermal_power_station_P_max,wind_power_station_varphi,wind_power_station_sigma_ue,wind_power_station_sigma_oe,wind_power_station_P_min,wind_power_station_P_max,sum_thermal_wind_power_station_strategy,step_size_primal,step_size_dual)
# Out:
# ***************************large_attack_online_decentralized_economic_dispatch*****************************
# 相关变量初始值为：
# 第 1 个火力发电站的初始计划发电量为: 30.0
# 第 2 个火力发电站的初始计划发电量为: 30.0
# 第 3 个火力发电站的初始计划发电量为: 30.0
# 第 4 个火力发电站的初始计划发电量为: 300.0
# 第 5 个火力发电站的初始计划发电量为: 300.0
# 第 6 个火力发电站的初始计划发电量为: 30.0
# 第 7 个火力发电站的初始计划发电量为: 100.0
# 第 8 个火力发电站的初始计划发电量为: 30.0
# 第 9 个火力发电站的初始计划发电量为: 30.0
# 第 10 个火力发电站的初始计划发电量为: 300.0
# 第 11 个火力发电站的初始计划发电量为: 350.0
# 第 12 个火力发电站的初始计划发电量为: 30.0
# 第 13 个火力发电站的初始计划发电量为: 30.0
# 第 14 个火力发电站的初始计划发电量为: 100.0
# 第 15 个火力发电站的初始计划发电量为: 30.0
# 第 16 个火力发电站的初始计划发电量为: 100.0
# 第 17 个火力发电站的初始计划发电量为: 30.0
# 第 18 个火力发电站的初始计划发电量为: 30.0
# 第 19 个火力发电站的初始计划发电量为: 100.0
# 第 20 个火力发电站的初始计划发电量为: 250.0
# 第 21 个火力发电站的初始计划发电量为: 250.0
# 第 22 个火力发电站的初始计划发电量为: 100.0
# 第 23 个火力发电站的初始计划发电量为: 100.0
# 第 24 个火力发电站的初始计划发电量为: 200.0
# 第 25 个火力发电站的初始计划发电量为: 200.0
# 第 26 个火力发电站的初始计划发电量为: 100.0
# 第 27 个火力发电站的初始计划发电量为: 420.0
# 第 28 个火力发电站的初始计划发电量为: 420.0
# 第 29 个火力发电站的初始计划发电量为: 300.0
# 第 30 个火力发电站的初始计划发电量为: 80.0
# 第 31 个火力发电站的初始计划发电量为: 30.0
# 第 32 个火力发电站的初始计划发电量为: 30.0
# 第 33 个火力发电站的初始计划发电量为: 20.0
# 第 34 个火力发电站的初始计划发电量为: 100.0
# 第 35 个火力发电站的初始计划发电量为: 100.0
# 第 36 个火力发电站的初始计划发电量为: 300.0
# 第 37 个火力发电站的初始计划发电量为: 100.0
# 第 38 个火力发电站的初始计划发电量为: 30.0
# 第 39 个火力发电站的初始计划发电量为: 300.0
# 第 40 个火力发电站的初始计划发电量为: 200.0
# 第 41 个火力发电站的初始计划发电量为: 20.0
# 第 42 个火力发电站的初始计划发电量为: 50.0
# 第 43 个火力发电站的初始计划发电量为: 300.0
# 第 44 个火力发电站的初始计划发电量为: 300.0
# 第 45 个火力发电站的初始计划发电量为: 300.0
# 第 46 个火力发电站的初始计划发电量为: 20.0
# 第 47 个火力发电站的初始计划发电量为: 100.0
# 第 48 个火力发电站的初始计划发电量为: 100.0
# 第 49 个火力发电站的初始计划发电量为: 20.0
# 第 50 个火力发电站的初始计划发电量为: 50.0
# 第 51 个火力发电站的初始计划发电量为: 100.0
# 第 52 个火力发电站的初始计划发电量为: 100.0
# 第 55 个风力发电站的初始计划发电量为: 30.0
# 第 56 个风力发电站的初始计划发电量为: 30.0
# 第 57 个风力发电站的初始计划发电量为: 30.0
# 第 59 个风力发电站的初始计划发电量为: 300.0
# 第 60 个风力发电站的初始计划发电量为: 30.0
# ****************************************************************************
# 第 1 个火力发电站的初始对偶变量为: -1000.0
# 第 2 个火力发电站的初始对偶变量为: -1000.0
# 第 3 个火力发电站的初始对偶变量为: -1000.0
# 第 4 个火力发电站的初始对偶变量为: -1000.0
# 第 5 个火力发电站的初始对偶变量为: -1000.0
# 第 6 个火力发电站的初始对偶变量为: -1000.0
# 第 7 个火力发电站的初始对偶变量为: -1000.0
# 第 8 个火力发电站的初始对偶变量为: -1000.0
# 第 9 个火力发电站的初始对偶变量为: -1000.0
# 第 10 个火力发电站的初始对偶变量为: -1000.0
# 第 11 个火力发电站的初始对偶变量为: -1000.0
# 第 12 个火力发电站的初始对偶变量为: -1000.0
# 第 13 个火力发电站的初始对偶变量为: -1000.0
# 第 14 个火力发电站的初始对偶变量为: -1000.0
# 第 15 个火力发电站的初始对偶变量为: -1000.0
# 第 16 个火力发电站的初始对偶变量为: -1000.0
# 第 17 个火力发电站的初始对偶变量为: -1000.0
# 第 18 个火力发电站的初始对偶变量为: -1000.0
# 第 19 个火力发电站的初始对偶变量为: -1000.0
# 第 20 个火力发电站的初始对偶变量为: -1000.0
# 第 21 个火力发电站的初始对偶变量为: -1000.0
# 第 22 个火力发电站的初始对偶变量为: -1000.0
# 第 23 个火力发电站的初始对偶变量为: -1000.0
# 第 24 个火力发电站的初始对偶变量为: -1000.0
# 第 25 个火力发电站的初始对偶变量为: -1000.0
# 第 26 个火力发电站的初始对偶变量为: -1000.0
# 第 27 个火力发电站的初始对偶变量为: -1000.0
# 第 28 个火力发电站的初始对偶变量为: -1000.0
# 第 29 个火力发电站的初始对偶变量为: -1000.0
# 第 30 个火力发电站的初始对偶变量为: -1000.0
# 第 31 个火力发电站的初始对偶变量为: -1000.0
# 第 32 个火力发电站的初始对偶变量为: -1000.0
# 第 33 个火力发电站的初始对偶变量为: -1000.0
# 第 34 个火力发电站的初始对偶变量为: -1000.0
# 第 35 个火力发电站的初始对偶变量为: -1000.0
# 第 36 个火力发电站的初始对偶变量为: -1000.0
# 第 37 个火力发电站的初始对偶变量为: -1000.0
# 第 38 个火力发电站的初始对偶变量为: -1000.0
# 第 39 个火力发电站的初始对偶变量为: -1000.0
# 第 40 个火力发电站的初始对偶变量为: -1000.0
# 第 41 个火力发电站的初始对偶变量为: -1000.0
# 第 42 个火力发电站的初始对偶变量为: -1000.0
# 第 43 个火力发电站的初始对偶变量为: -1000.0
# 第 44 个火力发电站的初始对偶变量为: -1000.0
# 第 45 个火力发电站的初始对偶变量为: -1000.0
# 第 46 个火力发电站的初始对偶变量为: -1000.0
# 第 47 个火力发电站的初始对偶变量为: -1000.0
# 第 48 个火力发电站的初始对偶变量为: -1000.0
# 第 49 个火力发电站的初始对偶变量为: -1000.0
# 第 50 个火力发电站的初始对偶变量为: -1000.0
# 第 51 个火力发电站的初始对偶变量为: -1000.0
# 第 52 个火力发电站的初始对偶变量为: -1000.0
# 第 55 个风力发电站的初始对偶变量为: -1000.0
# 第 56 个风力发电站的初始对偶变量为: -1000.0
# 第 57 个风力发电站的初始对偶变量为: -1000.0
# 第 59 个风力发电站的初始对偶变量为: -1000.0
# 第 60 个风力发电站的初始对偶变量为: -1000.0
# ****************************************************************************
# 第 54 个受到Byzantin攻击的火力发电站的初始对偶变量为: -0.01
# 第 58 个受到Byzantin攻击的风力发电站的初始对偶变量为: -0.01
# ****************************************************************************
# 安全发电站的初始总发电量: 7590.0
# *************************
# 需求侧平均用电需求: 78.10342674
# ****************************************************************************
# 风速分布参数c: 8.36374925
# ****************************************************************************
# 风速分布参数kappa: 2.53999996
# ****************************************************************************
# 安全发电站的总发电成本： 128026.41839387035
# ****************************************************************************
# 原变量迭代步长为: 5
# *****************************************************************************
# 对偶变量迭代步长为: 5
# *****************************************************************************
# 1 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 5.0
# 第 2 个火力发电站的计划发电量为: 5.0
# 第 3 个火力发电站的计划发电量为: 5.0
# 第 4 个火力发电站的计划发电量为: 286.27083333333337
# 第 5 个火力发电站的计划发电量为: 286.27083333333337
# 第 6 个火力发电站的计划发电量为: 10.0
# 第 7 个火力发电站的计划发电量为: 81.43333333333334
# 第 8 个火力发电站的计划发电量为: 5.0
# 第 9 个火力发电站的计划发电量为: 5.0
# 第 10 个火力发电站的计划发电量为: 286.27083333333337
# 第 11 个火力发电站的计划发电量为: 350.0
# 第 12 个火力发电站的计划发电量为: 8.0
# 第 13 个火力发电站的计划发电量为: 8.0
# 第 14 个火力发电站的计划发电量为: 81.43333333333334
# 第 15 个火力发电站的计划发电量为: 8.0
# 第 16 个火力发电站的计划发电量为: 81.43333333333334
# 第 17 个火力发电站的计划发电量为: 8.0
# 第 18 个火力发电站的计划发电量为: 8.0
# 第 19 个火力发电站的计划发电量为: 81.43333333333334
# 第 20 个火力发电站的计划发电量为: 250.0
# 第 21 个火力发电站的计划发电量为: 250.0
# 第 22 个火力发电站的计划发电量为: 81.43333333333334
# 第 23 个火力发电站的计划发电量为: 81.43333333333334
# 第 24 个火力发电站的计划发电量为: 200.0
# 第 25 个火力发电站的计划发电量为: 200.0
# 第 26 个火力发电站的计划发电量为: 81.43333333333334
# 第 27 个火力发电站的计划发电量为: 417.1598333333333
# 第 28 个火力发电站的计划发电量为: 417.1598333333333
# 第 29 个火力发电站的计划发电量为: 286.27083333333337
# 第 30 个火力发电站的计划发电量为: 49.24093333333333
# 第 31 个火力发电站的计划发电量为: 10.0
# 第 32 个火力发电站的计划发电量为: 5.0
# 第 33 个火力发电站的计划发电量为: 5.0
# 第 34 个火力发电站的计划发电量为: 81.43333333333334
# 第 35 个火力发电站的计划发电量为: 81.43333333333334
# 第 36 个火力发电站的计划发电量为: 286.27083333333337
# 第 37 个火力发电站的计划发电量为: 81.43333333333334
# 第 38 个火力发电站的计划发电量为: 10.0
# 第 39 个火力发电站的计划发电量为: 300.0
# 第 40 个火力发电站的计划发电量为: 197.14583333333334
# 第 41 个火力发电站的计划发电量为: 8.0
# 第 42 个火力发电站的计划发电量为: 20.0
# 第 43 个火力发电站的计划发电量为: 286.27083333333337
# 第 44 个火力发电站的计划发电量为: 286.27083333333337
# 第 45 个火力发电站的计划发电量为: 286.27083333333337
# 第 46 个火力发电站的计划发电量为: 8.0
# 第 47 个火力发电站的计划发电量为: 81.43333333333334
# 第 48 个火力发电站的计划发电量为: 81.43333333333334
# 第 49 个火力发电站的计划发电量为: 8.0
# 第 50 个火力发电站的计划发电量为: 25.0
# 第 51 个火力发电站的计划发电量为: 81.43333333333334
# 第 52 个火力发电站的计划发电量为: 81.43333333333334
# 第 53 个火力发电站的计划发电量为: 81.43333333333334
# 第 55 个风力发电站的计划发电量为: 96.0606966394501
# 第 56 个风力发电站的计划发电量为: 45.858623968776264
# 第 57 个风力发电站的计划发电量为: 66.39186374339273
# 第 59 个风力发电站的计划发电量为: 278.3333241455708
# 第 60 个风力发电站的计划发电量为: 24.617138138286876
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -1003.958618895
# 第 2 个火力发电站的对偶变量为: -1001.590197795
# 第 3 个火力发电站的对偶变量为: -995.8394967364313
# 第 4 个火力发电站的对偶变量为: -983.0103430949999
# 第 5 个火力发电站的对偶变量为: -994.7988559448618
# 第 6 个火力发电站的对偶变量为: -996.4161132212753
# 第 7 个火力发电站的对偶变量为: -995.2013078909065
# 第 8 个火力发电站的对偶变量为: -1003.2723443783333
# 第 9 个火力发电站的对偶变量为: -998.2126981625406
# 第 10 个火力发电站的对偶变量为: -995.9331298564118
# 第 11 个火力发电站的对偶变量为: -994.21227988087
# 第 12 个火力发电站的对偶变量为: -998.9702739699999
# 第 13 个火力发电站的对偶变量为: -995.4595551816478
# 第 14 个火力发电站的对偶变量为: -998.8675257940889
# 第 15 个火力发电站的对偶变量为: -998.1128704942633
# 第 16 个火力发电站的对偶变量为: -996.6553841636343
# 第 17 个火力发电站的对偶变量为: -998.8923036533332
# 第 18 个火力发电站的对偶变量为: -1001.1381061167948
# 第 19 个火力发电站的对偶变量为: -984.8475077986668
# 第 20 个火力发电站的对偶变量为: -986.9384168670385
# 第 21 个火力发电站的对偶变量为: -991.8218667486324
# 第 22 个火力发电站的对偶变量为: -994.0654565616669
# 第 23 个火力发电站的对偶变量为: -994.0654565616668
# 第 24 个火力发电站的对偶变量为: -991.8859692952136
# 第 25 个火力发电站的对偶变量为: -991.0617935449998
# 第 26 个火力发电站的对偶变量为: -986.8432341616667
# 第 27 个火力发电站的对偶变量为: -991.7811995401612
# 第 28 个火力发电站的对偶变量为: -981.2571537533333
# 第 29 个火力发电站的对偶变量为: -992.1695745336724
# 第 30 个火力发电站的对偶变量为: -1000.5293260023736
# 第 31 个火力发电站的对偶变量为: -1003.958618895
# 第 32 个火力发电站的对偶变量为: -1003.2010431449999
# 第 33 个火力发电站的对偶变量为: -1002.8424572921715
# 第 34 个火力发电站的对偶变量为: -999.1858916222725
# 第 35 个火力发电站的对偶变量为: -993.1252855866665
# 第 36 个火力发电站的对偶变量为: -980.7423654449625
# 第 37 个火力发电站的对偶变量为: -994.169056638771
# 第 38 个火力发电站的对偶变量为: -992.1861320960581
# 第 39 个火力发电站的对偶变量为: -987.8871904199999
# 第 40 个火力发电站的对偶变量为: -996.610134118485
# 第 41 个火力发电站的对偶变量为: -999.5062378783334
# 第 42 个火力发电站的对偶变量为: -999.5040734783335
# 第 43 个火力发电站的对偶变量为: -989.7919522283332
# 第 44 个火力发电站的对偶变量为: -981.4586188949999
# 第 45 个火力发电站的对偶变量为: -992.125285508333
# 第 46 个火力发电站的对偶变量为: -998.1623226453703
# 第 47 个火力发电站的对偶变量为: -997.3845448616667
# 第 48 个火力发电站的对偶变量为: -1001.5115289278044
# 第 49 个火力发电站的对偶变量为: -999.7760792616668
# 第 50 个火力发电站的对偶变量为: -1000.4665553799207
# 第 51 个火力发电站的对偶变量为: -999.31576177
# 第 52 个火力发电站的对偶变量为: -999.31576177
# 第 53 个火力发电站的对偶变量为: -994.5150333811026
# 第 55 个风力发电站的对偶变量为: -1001.5901978186841
# 第 56 个风力发电站的对偶变量为: -1003.958618895
# 第 57 个风力发电站的对偶变量为: -998.9702739201164
# 第 59 个风力发电站的对偶变量为: -983.6808410616666
# 第 60 个风力发电站的对偶变量为: -998.514174507222
# ****************************************************************************
# 第 54 个受到Byzantin攻击的火力发电站的初始对偶变量为: -0.01
# 第 58 个受到Byzantin攻击的风力发电站的初始对偶变量为: -0.01
# ****************************************************************************
# 安全发电站的总发电量: 6827.6347466354755
# *************************
# 需求侧平均用电需求: 85.73204703
# ****************************************************************************
# 风速分布参数c: 8.41212693
# ****************************************************************************
# 风速分布参数kappa: 2.44000006
# ****************************************************************************
# 安全发电站的总发电成本： 107815.48929545822
# ****************************************************************************
# 原变量迭代步长为: 5
# ****************************************************************************
# 对偶变量迭代步长为: 5
# ****************************************************************************
# 2 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 5.0
# 第 2 个火力发电站的计划发电量为: 5.0
# 第 3 个火力发电站的计划发电量为: 5.0
# 第 4 个火力发电站的计划发电量为: 272.6189087995834
# 第 5 个火力发电站的计划发电量为: 273.60128487040515
# 第 6 个火力发电站的计划发电量为: 10.0
# 第 7 个火力发电站的计划发电量为: 64.84330899090888
# 第 8 个火力发电站的计划发电量为: 5.0
# 第 9 个火力发电站的计划发电量为: 5.0
# 第 10 个火力发电站的计划发电量为: 273.6958076963677
# 第 11 个火力发电站的计划发电量为: 350.0
# 第 12 个火力发电站的计划发电量为: 8.0
# 第 13 个火力发电站的计划发电量为: 8.0
# 第 14 个火力发电站的计划发电量为: 65.14882714950741
# 第 15 个火力发电站的计划发电量为: 8.0
# 第 16 个火力发电站的计划发电量为: 64.9644820136362
# 第 17 个火力发电站的计划发电量为: 8.0
# 第 18 个火力发电站的计划发电量为: 8.0
# 第 19 个火力发电站的计划发电量为: 63.98049231655557
# 第 20 个火力发电站的计划发电量为: 250.0
# 第 21 个火力发电站的计划发电量为: 250.0
# 第 22 个火力发电站的计划发电量为: 64.74865471347225
# 第 23 个火力发电站的计划发电量为: 64.74865471347223
# 第 24 个火力发电站的计划发电量为: 200.0
# 第 25 个火力发电站的计划发电量为: 200.0
# 第 26 个火力发电站的计划发电量为: 64.14680284680557
# 第 27 个火力发电站的计划发电量为: 413.9355402783467
# 第 28 个火力发电站的计划发电量为: 413.05853646277774
# 第 29 个火力发电站的计划发电量为: 273.3821780861394
# 第 30 个火力发电站的计划发电量为: 32.6514633521978
# 第 31 个火力发电站的计划发电量为: 10.0
# 第 32 个火力发电站的计划发电量为: 5.0
# 第 33 个火力发电站的计划发电量为: 5.0
# 第 34 个火力发电站的计划发电量为: 65.17535763518937
# 第 35 个火力发电站的计划发电量为: 64.67030713222219
# 第 36 个火力发电站的计划发电量为: 272.42991066208026
# 第 37 个火力发电站的计划发电量为: 64.75728805323091
# 第 38 个火力发电站的计划发电量为: 10.0
# 第 39 个火力发电站的计划发电量为: 300.0
# 第 40 个火力发电站的计划发电量为: 194.3195684682071
# 第 41 个火力发电站的计划发电量为: 8.0
# 第 42 个火力发电站的计划发电量为: 20.0
# 第 43 个火力发电站的计划发电量为: 273.1840428940278
# 第 44 个火力发电站的计划发电量为: 272.48959844958335
# 第 45 个火力发电站的计划发电量为: 273.3784873340278
# 第 46 个火力发电站的计划发电量为: 8.0
# 第 47 个火力发电站的计划发电量为: 65.02524540513889
# 第 48 个火力发电站的计划发电量为: 65.36916074398368
# 第 49 个火力发电站的计划发电量为: 8.0
# 第 50 个火力发电站的计划发电量为: 25.0
# 第 51 个火力发电站的计划发电量为: 65.1861801475
# 第 52 个火力发电站的计划发电量为: 65.1861801475
# 第 53 个火力发电站的计划发电量为: 64.78611944842523
# 第 55 个风力发电站的计划发电量为: 105.47657026289102
# 第 56 个风力发电站的计划发电量为: 38.7841314920061
# 第 57 个风力发电站的计划发电量为: 70.90991706611979
# 第 59 个风力发电站的计划发电量为: 255.30681865008378
# 第 60 个风力发电站的计划发电量为: 26.56229425796015
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -1007.7395825967942
# 第 2 个火力发电站的对偶变量为: -1003.835660163367
# 第 3 个火力发电站的对偶变量为: -993.6385953982477
# 第 4 个火力发电站的对偶变量为: -968.7508511729516
# 第 5 个火力发电站的对偶变量为: -992.3978383152576
# 第 6 个火力发电站的对偶变量为: -994.5751915110858
# 第 7 个火力发电站的对偶变量为: -993.1909390978255
# 第 8 个火力发电站的对偶变量为: -1004.7443114042006
# 第 9 个火力发电站的对偶变量为: -999.2624800227733
# 第 10 个火力发电站的对偶变量为: -994.9660858166355
# 第 11 个火力发电站的对偶变量为: -991.9808369791162
# 第 12 个火力发电站的对偶变量为: -1000.196105687412
# 第 13 个火力发电站的对偶变量为: -993.4816646805122
# 第 14 个火力发电站的对偶变量为: -997.9167501628951
# 第 15 个火力发电站的对偶变量为: -997.3757673340933
# 第 16 个火力发电站的对偶变量为: -995.3216517190428
# 第 17 个火力发电站的对偶变量为: -998.5737761358448
# 第 18 个火力发电站的对偶变量为: -1001.9792720736029
# 第 19 个火力发电站的对偶变量为: -974.93276094947
# 第 20 个火力发电站的对偶变量为: -975.2180664089121
# 第 21 个火力发电站的对偶变量为: -985.2232152843619
# 第 22 个火力发电站的对偶变量为: -988.8984495512107
# 第 23 个火力发电站的对偶变量为: -988.8984495512109
# 第 24 个火力发电站的对偶变量为: -984.8883200772774
# 第 25 个火力发电站的对偶变量为: -982.1813058077404
# 第 26 个火力发电站的对偶变量为: -975.200594411556
# 第 27 个火力发电站的对偶变量为: -986.6114718548869
# 第 28 个火力发电站的对偶变量为: -966.8334006626989
# 第 29 个火力发电站的对偶变量为: -987.20138932247
# 第 30 个火力发电站的对偶变量为: -1002.2747556006899
# 第 31 个火力发电站的对偶变量为: -1009.114173362046
# 第 32 个火力发电站的对偶变量为: -1008.8588425354708
# 第 33 个火力发电站的对偶变量为: -1005.2001524224012
# 第 34 个火力发电站的对偶变量为: -999.4248452448073
# 第 35 个火力发电站的对偶变量为: -988.0983357707628
# 第 36 个火力发电站的对偶变量为: -969.3538197277609
# 第 37 个火力发电站的对偶变量为: -988.7727662197917
# 第 38 个火力发电站的对偶变量为: -986.2404296909452
# 第 39 个火力发电站的对偶变量为: -978.1151029765851
# 第 40 个火力发电站的对偶变量为: -993.2086401384752
# 第 41 个火力发电站的对偶变量为: -1000.2021782891867
# 第 42 个火力发电站的对偶变量为: -999.5324761342885
# 第 43 个火力发电站的对偶变量为: -984.2393587602148
# 第 44 个火力发电站的对偶变量为: -966.0099441942729
# 第 45 个火力发电站的对偶变量为: -985.6476025441524
# 第 46 个火力发电站的对偶变量为: -998.7421471861651
# 第 47 个火力发电站的对偶变量为: -997.427516868083
# 第 48 个火力发电站的对偶变量为: -1002.5088405557531
# 第 49 个火力发电站的对偶变量为: -1000.8392134221154
# 第 50 个火力发电站的对偶变量为: -1001.9354596011399
# 第 51 个火力发电站的对偶变量为: -1001.2964546763919
# 第 52 个火力发电站的对偶变量为: -1001.2964546763919
# 第 53 个火力发电站的对偶变量为: -991.8377849960245
# 第 55 个风力发电站的对偶变量为: -1001.8030938119737
# 第 56 个风力发电站的对偶变量为: -1006.1449315136281
# 第 57 个风力发电站的对偶变量为: -999.3249812584509
# 第 59 个风力发电站的对偶变量为: -971.0285244898696
# 第 60 个风力发电站的对偶变量为: -998.7929250642
# ****************************************************************************
# 第 54 个受到Byzantin攻击的火力发电站的初始对偶变量为: -0.01
# 第 58 个受到Byzantin攻击的风力发电站的初始对偶变量为: -0.01
# ****************************************************************************
# 安全发电站的总发电量: 6432.522120540353
# *************************
# 需求侧平均用电需求: 91.70415949
# ****************************************************************************
# 风速分布参数c: 8.48068324
# ****************************************************************************
# 风速分布参数kappa: 2.42000008
# ****************************************************************************
# 安全发电站的总发电成本： 100039.48006759159
# ****************************************************************************
# 原变量迭代步长为: 5
# ****************************************************************************
# 对偶变量迭代步长为: 5
# ****************************************************************************
# 3 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 5.0
# 第 2 个火力发电站的计划发电量为: 5.0
# 第 3 个火力发电站的计划发电量为: 5.0
# 第 4 个火力发电站的计划发电量为: 259.2633400653747
# 第 5 个火力发电站的计划发电量为: 262.1094650003534
# 第 6 个火力发电站的计划发电量为: 10.0
# 第 7 个火力发电站的计划发电量为: 50.209277031558
# 第 8 个火力发电站的计划发电量为: 5.0
# 第 9 个火力发电站的计划发电量为: 5.0
# 第 10 个火力发电站的计划发电量为: 262.40772909410737
# 第 11 个火力发电站的计划发电量为: 350.0
# 第 12 个火力发电站的计划发电量为: 8.0
# 第 13 个火力发电站的计划发电量为: 8.0
# 第 14 个火力发电站的计划发电量为: 50.86950645461173
# 第 15 个火力发电站的计划发电量为: 8.0
# 第 16 个火力发电站的计划发电量为: 50.49249929247766
# 第 17 个火力发电站的计划发电量为: 8.0
# 第 18 个火力发电站的计划发电量为: 8.0
# 第 19 个火力发电站的计划发电量为: 47.93538604582561
# 第 20 个火力发电站的计划发电量为: 250.0
# 第 21 个火力发电站的计划发电量为: 250.0
# 第 22 个火力发电站的计划发电量为: 49.76903103941535
# 第 23 个火力发电站的计划发电量为: 49.76903103941536
# 第 24 个火力发电站的计划发电量为: 200.0
# 第 25 个火力发电站的计划发电量为: 200.0
# 第 26 个火力发电站的计划发电量为: 48.102728283377445
# 第 27 个火力发电站的计划发电量为: 410.6218892174437
# 第 28 个火力发电站的计划发电量为: 408.1895875065945
# 第 29 个火力发电站的计划发电量为: 261.4811486628109
# 第 30 个火力发电站的计划发电量为: 30.0
# 第 31 个火力发电站的计划发电量为: 10.0
# 第 32 个火力发电站的计划发电量为: 5.0
# 第 33 个火力发电站的计划发电量为: 5.0
# 第 34 个火力发电站的计划发电量为: 51.01831562828575
# 第 35 个火力发电站的计划发电量为: 49.63403580019465
# 第 36 个火力发电站的计划发电量为: 259.1451428548924
# 第 37 个火力发电站的计划发电量为: 49.76608570073334
# 第 38 个火力发电站的计划发电量为: 10.0
# 第 39 个火力发电站的计划发电量为: 300.0
# 第 40 个火力发电站的计划发电量为: 191.51720207549585
# 第 41 个火力发电站的计划发电量为: 8.0
# 第 42 个火力发电站的计划发电量为: 20.0
# 第 43 个火力发电站的计划发电量为: 261.0577247926535
# 第 44 个火力发电站的计划发电量为: 258.91968330104726
# 第 45 个火力发电站的计划发电量为: 261.348377048465
# 第 46 个火力发电站的计划发电量为: 8.0
# 第 47 个火力发电站的计划发电量为: 50.720973732288016
# 第 48 个火力发电站的计划发电量为: 51.44431154839985
# 第 49 个火力发电站的计划发电量为: 8.0
# 第 50 个火力发电站的计划发电量为: 25.0
# 第 51 个火力发电站的计划发电量为: 51.183720311652664
# 第 52 个火力发电站的计划发电量为: 51.183720311652664
# 第 53 个火力发电站的计划发电量为: 50.046644908695505
# 第 55 个风力发电站的计划发电量为: 109.58101640797749
# 第 56 个风力发电站的计划发电量为: 42.74212158425828
# 第 57 个风力发电站的计划发电量为: 73.27518106493378
# 第 59 个风力发电站的计划发电量为: 231.22794099383134
# 第 60 个风力发电站的计划发电量为: 26.663599703265266
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -1010.4729341384633
# 第 2 个火力发电站的对偶变量为: -1005.7231151864382
# 第 3 个火力发电站的对偶变量为: -992.5038456494558
# 第 4 个火力发电站的对偶变量为: -956.8805346908407
# 第 5 个火力发电站的对偶变量为: -991.6257003056658
# 第 6 个火力发电站的对偶变量为: -993.7713203369259
# 第 7 个火力发电站的对偶变量为: -992.3899337169952
# 第 8 个火力发电站的对偶变量为: -1005.5249015050304
# 第 9 个火力发电站的对偶变量为: -1001.4642231288408
# 第 10 个火力发电站的对偶变量为: -995.7593005376418
# 第 11 个火力发电站的对偶变量为: -991.1366101565234
# 第 12 个火力发电站的对偶变量为: -1002.0281775919916
# 第 13 个火力发电站的对偶变量为: -992.832468999578
# 第 14 个火力发电站的对偶变量为: -998.4793644881116
# 第 15 个火力发电站的对偶变量为: -996.826946010244
# 第 16 个火力发电站的对偶变量为: -995.0557799272569
# 第 17 个火力发电站的对偶变量为: -998.1805443506852
# 第 18 个火力发电站的对偶变量为: -1001.2310096166057
# 第 19 个火力发电站的对偶变量为: -969.8509801849539
# 第 20 个火力发电站的对偶变量为: -966.9163807087098
# 第 21 个火力发电站的对偶变量为: -979.5274799790695
# 第 22 个火力发电站的对偶变量为: -984.4971346813127
# 第 23 个火力发电站的对偶变量为: -984.4971346813124
# 第 24 个火力发电站的对偶变量为: -978.7855895142446
# 第 25 个火力发电站的对偶变量为: -973.9521959403904
# 第 26 个火力发电站的对偶变量为: -965.258777583062
# 第 27 个火力发电站的对偶变量为: -983.2713227102387
# 第 28 个火力发电站的对偶变量为: -955.278016997008
# 第 29 个火力发电站的对偶变量为: -983.1143345841651
# 第 30 个火力发电站的对偶变量为: -1004.358600447547
# 第 31 个火力发电站的对偶变量为: -1014.2215672365139
# 第 32 个火力发电站的对偶变量为: -1014.3531983649964
# 第 33 个火力发电站的对偶变量为: -1006.9896885503665
# 第 34 个火力发电站的对偶变量为: -1000.5512510133692
# 第 35 个火力发电站的对偶变量为: -985.0474109777178
# 第 36 个火力发电站的对偶变量为: -961.8321706370779
# 第 37 个火力发电站的对偶变量为: -984.6143808697312
# 第 38 个火力发电站的对偶变量为: -980.9245758626118
# 第 39 个火力发电站的对偶变量为: -969.9343783977167
# 第 40 个火力发电站的对偶变量为: -990.6140600333824
# 第 41 个火力发电站的对偶变量为: -1000.0254131887269
# 第 42 个火力发电站的对偶变量为: -999.5091640397532
# 第 43 个火力发电站的对偶变量为: -980.3964777250515
# 第 44 个火力发电站的对偶变量为: -954.0197192850386
# 第 45 个火力发电站的对偶变量为: -981.7918860956577
# 第 46 个火力发电站的对偶变量为: -999.7942903370292
# 第 47 个火力发电站的对偶变量为: -998.506969949954
# 第 48 个火力发电站的对偶变量为: -1004.3240632915047
# 第 49 个火力发电站的对偶变量为: -1001.9015015711209
# 第 50 个火力发电站的对偶变量为: -1004.7705130570475
# 第 51 个火力发电站的对偶变量为: -1004.5955990026598
# 第 52 个火力发电站的对偶变量为: -1004.5955990026598
# 第 53 个火力发电站的对偶变量为: -990.8288120059481
# 第 55 个风力发电站的对偶变量为: -1002.7179624590938
# 第 56 个风力发电站的对偶变量为: -1008.4751299917344
# 第 57 个风力发电站的对偶变量为: -1000.4121494638472
# 第 59 个风力发电站的对偶变量为: -961.7404625238071
# 第 60 个风力发电站的对偶变量为: -999.5964783314673
# ****************************************************************************
# 第 54 个受到Byzantin攻击的火力发电站的初始对偶变量为: -0.01
# 第 58 个受到Byzantin攻击的风力发电站的初始对偶变量为: -0.01
# ****************************************************************************
# 安全发电站的总发电量: 6085.696416502091
# *************************
# 需求侧平均用电需求: 92.81865565
# ****************************************************************************
# 风速分布参数c: 8.49440173
# ****************************************************************************
# 风速分布参数kappa: 2.4000001
# ****************************************************************************
# 安全发电站的总发电成本： 93363.06101412342
# ****************************************************************************
# 原变量迭代步长为: 5
# ****************************************************************************
# 对偶变量迭代步长为: 5
# ****************************************************************************
# 4 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 5.0
# 第 2 个火力发电站的计划发电量为: 5.0
# 第 3 个火力发电站的计划发电量为: 5.0
# 第 4 个火力发电站的计划发电量为: 246.37099639083524
# 第 5 个火力发电站的计划发电量为: 251.8030357070371
# 第 6 个火力发电站的计划发电量为: 10.0
# 第 7 个火力发电站的计划发电量为: 37.3816507146015
# 第 8 个火力发电站的计划发电量为: 5.0
# 第 9 个火力发电站的计划发电量为: 5.0
# 第 10 个火力发电站的计划发电量为: 252.41333026659336
# 第 11 个火力发电站的计划发电量为: 350.0
# 第 12 个火力发电站的计划发电量为: 8.0
# 第 13 个火力发电站的计划发电量为: 8.0
# 第 14 个火力发电站的计划发电量为: 38.464823335764066
# 第 15 个火力发电站的计划发电量为: 8.0
# 第 16 个火力发电站的计划发电量为: 37.85077437697859
# 第 17 个火力发电站的计划发电量为: 8.0
# 第 18 个火力发电站的计划发电量为: 8.0
# 第 19 个火力发电站的计划发电量为: 33.52057164737274
# 第 20 个火力发电站的计划发电量为: 250.0
# 第 21 个火力发电站的计划发电量为: 250.0
# 第 22 个火力发电站的计划发电量为: 36.34002295647957
# 第 23 个火力发电站的计划发电量为: 36.34002295647956
# 第 24 个火力发电站的计划发电量为: 200.0
# 第 25 个火力发电站的计划发电量为: 200.0
# 第 26 个火力发电站的计划发电量为: 33.28381052836029
# 第 27 个火力发电站的计划发电量为: 407.3808080418363
# 第 28 个火力发电站的计划发电量为: 402.87331160606345
# 第 29 个火力发电站的计划发电量为: 250.53376829441063
# 第 30 个火力发电站的计划发电量为: 30.0
# 第 31 个火力发电站的计划发电量为: 10.0
# 第 32 个火力发电站的计划发电量为: 5.0
# 第 33 个火力发电站的计划发电量为: 5.0
# 第 34 个火力发电站的计划发电量为: 38.76724214564594
# 第 35 个火力发电站的计划发电量为: 36.26816346591289
# 第 36 个火力发电站的计划发电量为: 246.67828945584603
# 第 37 个火力发电站的计划发电量为: 36.347225136850426
# 第 38 个火力发电站的计划发电量为: 10.0
# 第 39 个火力发电站的计划发电量为: 300.0
# 第 40 个火力发电站的计划发电量为: 188.80337801923423
# 第 41 个火力发电站的计划发电量为: 8.0
# 第 42 个火力发电站的计划发电量为: 20.0
# 第 43 个火力发电站的计划发电量为: 249.92990369854007
# 第 44 个火力发电站的计划发电量为: 245.8263110158116
# 第 45 个火力发电站的计划发电量为: 250.3052315524159
# 第 46 个火力发电站的计划发电量为: 8.0
# 第 47 个火力发电站的计划发电量为: 38.33760325705131
# 第 48 个火力发电站的计划发电量为: 39.4531116111634
# 第 49 个火力发电站的计划发电量为: 8.0
# 第 50 个火力发电站的计划发电量为: 25.0
# 第 51 个火力发电站的计划发电量为: 39.248504028649435
# 第 52 个火力发电站的计划发电量为: 39.248504028649435
# 第 53 个火力发电站的计划发电量为: 37.109742027544826
# 第 55 个风力发电站的计划发电量为: 111.58867848937624
# 第 56 个风力发电站的计划发电量为: 41.3608134787668
# 第 57 个风力发电站的计划发电量为: 74.50397358498724
# 第 59 个风力发电站的计划发电量为: 206.39129505187748
# 第 60 个风力发电站的计划发电量为: 26.665114227706344
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -1012.4514985146044
# 第 2 个火力发电站的对偶变量为: -1007.2647492679105
# 第 3 个火力发电站的对偶变量为: -991.8769727264577
# 第 4 个火力发电站的对偶变量为: -946.8802412435781
# 第 5 个火力发电站的对偶变量为: -991.5924919458796
# 第 6 个火力发电站的对偶变量为: -993.5409935867261
# 第 7 个火力发电站的对偶变量为: -992.2391987795089
# 第 8 个火力发电站的对偶变量为: -1006.0519217544305
# 第 9 个火力发电站的对偶变量为: -1003.9131214754564
# 第 10 个火力发电站的对偶变量为: -997.3141893174104
# 第 11 个火力发电站的对偶变量为: -990.9872712857244
# 第 12 个火力发电站的对偶变量为: -1003.9710441037819
# 第 13 个火力发电站的对偶变量为: -992.8880365493474
# 第 14 个火力发电站的对偶变量为: -999.8373333316522
# 第 15 个火力发电站的对偶变量为: -996.395826064952
# 第 16 个火力发电站的对偶变量为: -995.1715735145503
# 第 17 个火力发电站的对偶变量为: -997.6985932232608
# 第 18 个火力发电站的对偶变量为: -999.4609873144085
# 第 19 个火力发电站的对偶变量为: -965.7274274518334
# 第 20 个火力发电站的对偶变量为: -961.141388239711
# 第 21 个火力发电站的对偶变量为: -974.591467306797
# 第 22 个火力发电站的对偶变量为: -980.4183918753597
# 第 23 个火力发电站的对偶变量为: -980.4183918753597
# 第 24 个火力发电站的对偶变量为: -973.2183611875029
# 第 25 个火力发电站的对偶变量为: -966.3491939592071
# 第 26 个火力发电站的对偶变量为: -956.5124927201398
# 第 27 个火力发电站的对偶变量为: -980.8295344122134
# 第 28 个火力发电站的对偶变量为: -945.8770365200658
# 第 29 个火力发电站的对偶变量为: -980.6100163973156
# 第 30 个火力发电站的对偶变量为: -1006.2291891048346
# 第 31 个火力发电站的对偶变量为: -1019.0480837446527
# 第 32 个火力发电站的对偶变量为: -1019.2054889056055
# 第 33 个火力发电站的对偶变量为: -1008.3066031596762
# 第 34 个火力发电站的对偶变量为: -1002.1283152185896
# 第 35 个火力发电站的对偶变量为: -983.0459528325767
# 第 36 个火力发电站的对偶变量为: -956.7162970719664
# 第 37 个火力发电站的对偶变量为: -981.4330895835851
# 第 38 个火力发电站的对偶变量为: -976.2623770500669
# 第 39 个火力发电站的对偶变量为: -962.6654311207824
# 第 40 个火力发电站的对偶变量为: -988.040190234336
# 第 41 个火力发电站的对偶变量为: -999.3788629929978
# 第 42 个火力发电站的对偶变量为: -999.0066493983046
# 第 43 个火力发电站的对偶变量为: -977.6857521638522
# 第 44 个火力发电站的对偶变量为: -945.0050158523284
# 第 45 个火力发电站的对偶变量为: -979.210781972118
# 第 46 个火力发电站的对偶变量为: -1001.5131522097536
# 第 47 个火力发电站的对偶变量为: -1000.1182212702329
# 第 48 个火力发电站的对偶变量为: -1006.2172087489341
# 第 49 个火力发电站的对偶变量为: -1003.0812354792948
# 第 50 个火力发电站的对偶变量为: -1008.2340822980016
# 第 51 个火力发电站的对偶变量为: -1008.6883420351935
# 第 52 个火力发电站的对偶变量为: -1008.6883420351935
# 第 53 个火力发电站的对偶变量为: -990.7675777351391
# 第 55 个风力发电站的对偶变量为: -1003.7258168396355
# 第 56 个风力发电站的对偶变量为: -1010.2412916810465
# 第 57 个风力发电站的对偶变量为: -1001.8953069233294
# 第 59 个风力发电站的对偶变量为: -955.283416065805
# 第 60 个风力发电站的对偶变量为: -1000.3500313246502
# ****************************************************************************
# 第 54 个受到Byzantin攻击的火力发电站的初始对偶变量为: -0.01
# 第 58 个受到Byzantin攻击的风力发电站的初始对偶变量为: -0.01
# ****************************************************************************
# 安全发电站的总发电量: 5765.39001109884
# *************************
# 需求侧平均用电需求: 107.71966101
# ****************************************************************************
# 风速分布参数c: 8.52563694
# ****************************************************************************
# 风速分布参数kappa: 2.4000001
# ****************************************************************************
# 安全发电站的总发电成本： 87292.27109071419
# ****************************************************************************
# 原变量迭代步长为: 5
# ****************************************************************************
# 对偶变量迭代步长为: 5
# ****************************************************************************
# 5 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 5.0
# 第 2 个火力发电站的计划发电量为: 5.0
# 第 3 个火力发电站的计划发电量为: 5.0
# 第 4 个火力发电站的计划发电量为: 234.0473373036301
# 第 5 个火力发电站的计划发电量为: 242.61466323605347
# 第 6 个火力发电站的计划发电量为: 10.0
# 第 7 个火力发电站的计划发电量为: 26.183399321424915
# 第 8 个火力发电站的计划发电量为: 5.0
# 第 9 个火力发电站的计划发电量为: 5.0
# 第 10 个火力发电站的计划发电量为: 243.6353963765522
# 第 11 个火力发电站的计划发电量为: 350.0
# 第 12 个火力发电站的计划发电量为: 8.0
# 第 13 个火力发电站的计划发电量为: 8.0
# 第 14 个火力发电站的计划发电量为: 27.761103726423954
# 第 15 个火力发电站的计划发电量为: 8.0
# 第 16 个火力发电站的计划发电量为: 26.836839716271182
# 第 17 个火力发电站的计划发电量为: 8.0
# 第 18 个火力发电站的计划发电量为: 8.0
# 第 19 个火力发电站的计划发电量为: 25.0
# 第 20 个火力发电站的计划发电量为: 250.0
# 第 21 个火力发电站的计划发电量为: 250.0
# 第 22 个火力发电站的计划发电量为: 25.0
# 第 23 个火力发电站的计划发电量为: 25.0
# 第 24 个火力发电站的计划发电量为: 200.0
# 第 25 个火力发电站的计划发电量为: 200.0
# 第 26 个火力发电站的计划发电量为: 25.0
# 第 27 个火力发电站的计划发电量为: 404.27947500455696
# 第 28 个火力发电站的计划发电量为: 397.3366142836535
# 第 29 个火力发电站的计划发电量为: 240.56822235883646
# 第 30 个火力发电站的计划发电量为: 30.0
# 第 31 个火力发电站的计划发电量为: 10.0
# 第 32 个火力发电站的计划发电量为: 5.0
# 第 33 个火力发电站的计划发电量为: 5.0
# 第 34 个火力发电站的计划发电量为: 28.215728085885708
# 第 35 个火力发电站的计划发电量为: 25.0
# 第 36 个火力发电站的计划发电量为: 235.14088356685332
# 第 37 个火力发电站的计划发电量为: 25.0
# 第 38 个火力发电站的计划发电量为: 10.0
# 第 39 个火力发电站的计划发电量为: 300.0
# 第 40 个火力发电站的计划发电量为: 186.1701931791705
# 第 41 个火力发电站的计划发电量为: 8.0
# 第 42 个火力发电站的计划发电量为: 20.0
# 第 43 个火力发电站的计划发电量为: 239.78633935164484
# 第 44 个火力发电站的计划发电量为: 233.40561768053612
# 第 45 个火力发电站的计划发电量为: 240.24793611876717
# 第 46 个火力发电站的计划发电量为: 8.0
# 第 47 个火力发电站的计划发电量为: 27.673575146001472
# 第 48 个火力发电站的计划发电量为: 29.154547387345673
# 第 49 个火力发电站的计划发电量为: 8.0
# 第 50 个火力发电站的计划发电量为: 25.0
# 第 51 个火力发电站的计划发电量为: 29.182057349248424
# 第 52 个火力发电站的计划发电量为: 29.182057349248424
# 第 53 个火力发电站的计划发电量为: 25.823659859280664
# 第 55 个风力发电站的计划发电量为: 112.85950304847891
# 第 56 个风力发电站的计划发电量为: 42.54432641404303
# 第 57 个风力发电站的计划发电量为: 75.41667198410101
# 第 59 个风力发电站的计划发电量为: 181.10708926150002
# 第 60 个风力发电站的计划发电量为: 27.231701236487336
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -1015.1880442677993
# 第 2 个火力发电站的对偶变量为: -1009.7927802937984
# 第 3 个火力发电站的对偶变量为: -992.8311534493995
# 第 4 个火力发电站的对偶变量为: -939.7688767968986
# 第 5 个火力发电站的对偶变量为: -993.2184556144683
# 第 6 个火力发电站的对偶变量为: -994.9205753993966
# 第 7 个火力发电站的对偶变量为: -993.7681707289736
# 第 8 个火力发电站的对偶变量为: -1007.8565337995835
# 第 9 个火力发电站的对偶变量为: -1007.7166786215312
# 第 10 个火力发电站的对偶变量为: -1000.4707417271682
# 第 11 个火力发电站的对偶变量为: -992.4958415283394
# 第 12 个火力发电站的对偶变量为: -1007.2879146845901
# 第 13 个火力发电站的对偶变量为: -994.6693968780723
# 第 14 个火力发电站的对偶变量为: -1002.8466697281344
# 第 15 个火力发电站的对偶变量为: -997.3280310936652
# 第 16 个火力发电站的对偶变量为: -996.7080429800026
# 第 17 个火力发电站的对偶变量为: -998.4541057818624
# 第 18 个火力发电站的对偶变量为: -998.4884197538524
# 第 19 个火力发电站的对偶变量为: -964.476357499871
# 第 20 个火力发电站的对偶变量为: -957.8786939252157
# 第 21 个火力发电站的对偶变量为: -971.549639727617
# 第 22 个火力发电站的对偶变量为: -977.8603541573252
# 第 23 个火力发电站的对偶变量为: -977.8603541573252
# 第 24 个火力发电站的对偶变量为: -969.3860980052896
# 第 25 个火力发电站的对偶变量为: -960.656852592995
# 第 26 个火力发电站的对偶变量为: -950.1028850883616
# 第 27 个火力发电站的对偶变量为: -980.344537805011
# 第 28 个火力发电站的对偶变量为: -939.4755258212068
# 第 29 个火力发电站的对偶变量为: -980.2011631765973
# 第 30 个火力发电站的对偶变量为: -1009.2232498058061
# 第 31 个火力发电站的对偶变量为: -1024.6941458789875
# 第 32 个火力发电站的对偶变量为: -1024.746877677499
# 第 33 个火力发电站的对偶变量为: -1010.5695002535274
# 第 34 个火力发电站的对偶变量为: -1005.1678809141499
# 第 35 个火力发电站的对偶变量为: -983.2351508501027
# 第 36 个火力发电站的对偶变量为: -954.4968358843798
# 第 37 个火力发电站的对偶变量为: -980.2955536500073
# 第 38 个火力发电站的对偶变量为: -973.3362357282668
# 第 39 个火力发电站的对偶变量为: -957.3833457853259
# 第 40 个火力发电站的对偶变量为: -986.8617246536539
# 第 41 个火力发电站的对偶变量为: -999.5456865529706
# 第 42 个火力发电站的对偶变量为: -999.4554295206378
# 第 43 个火力发电站的对偶变量为: -976.887160862143
# 第 44 个火力发电站的对偶变量为: -939.7503756852802
# 第 45 个火力发电站的对偶变量为: -978.9678918276343
# 第 46 个火力发电站的对偶变量为: -1004.8769698613728
# 第 47 个火力发电站的对偶变量为: -1003.2950362124009
# 第 48 个火力发电站的对偶变量为: -1009.5299634512494
# 第 49 个火力发电站的对偶变量为: -1005.6132689222618
# 第 50 个火力发电站的对偶变量为: -1013.479388993728
# 第 51 个火力发电站的对偶变量为: -1014.5533054586841
# 第 52 个火力发电站的对偶变量为: -1014.5533054586841
# 第 53 个火力发电站的对偶变量为: -992.5282202741272
# 第 55 个风力发电站的对偶变量为: -1005.9376943292816
# 第 56 个风力发电站的对偶变量为: -1013.189650519809
# 第 57 个风力发电站的对偶变量为: -1004.8608500240614
# 第 59 个风力发电站的对偶变量为: -952.6047590879979
# 第 60 个风力发电站的对偶变量为: -1002.4545987304514
# ****************************************************************************
# 第 54 个受到Byzantin攻击的火力发电站的初始对偶变量为: -0.01
# 第 58 个受到Byzantin攻击的风力发电站的初始对偶变量为: -0.01
# ****************************************************************************
# 安全发电站的总发电量: 5490.404938345996
# *************************
# 需求侧平均用电需求: 82.47730833
# ****************************************************************************
# 风速分布参数c: 8.5565076
# ****************************************************************************
# 风速分布参数kappa: 2.38000011
# ****************************************************************************
# 安全发电站的总发电成本： 82149.0441783463
# ****************************************************************************
# 原变量迭代步长为: 5
# ****************************************************************************
# 对偶变量迭代步长为: 5
# ****************************************************************************
# 2024-07-30 16:54:23.903

# %%
#数据存储
np.savetxt('./data/02_IOS_optimal_parameters_large_Byzantine_attack_sum_cost.txt',sum_cost,fmt='%0.8f')
np.savetxt('./data/02_IOS_optimal_parameters_large_Byzantine_attack_sum_thermal_wind_power_station_strategy.txt',sum_thermal_wind_power_station_strategy,fmt='%0.8f')

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
from sympy import *
import math 
from datetime import datetime
from scipy.special import gamma, factorial
import scipy.special as sc

# %%
sum_cost=np.loadtxt("./data/02_IOS_optimal_parameters_large_Byzantine_attack_sum_cost.txt")
optimal_sum_cost=np.loadtxt("./data/00_optimal_sum_cost_varying_D_c_kappa_normal_distribution_(100,10).txt")

# %%
dynamic_regret=[]
dynamic_regret_T=[]
for T in range(1, 1000):
    dynamic_regret_auxiliary_variable=0
    for t in range(0, T):
        dynamic_regret_auxiliary_variable=dynamic_regret_auxiliary_variable+sum_cost[t+1]-optimal_sum_cost[t+1]
    dynamic_regret.append(dynamic_regret_auxiliary_variable)
    dynamic_regret_T.append((dynamic_regret_auxiliary_variable)/T)

# %%
dynamic_regret
# Out:
# [34923.03850531,
#  56104.61179886,
#  69458.89171172002,
#  60698.06534050002,
#  73161.98716884002,
#  51067.63933611002,
#  45488.18013458002,
#  29350.985006680014,
#  34513.021937880025,
#  13060.935653130015,
#  -10553.947277419982,
#  -45330.93471828998,
#  -74109.35286335998,
#  -92941.58158158998,
#  -123309.97369521999,
#  -142488.60181679,
#  -150181.29882231,
#  -172477.49157897,
#  -172056.49905563,
#  -182656.44094961,
#  -235239.30004958,
#  -242905.49451497,
#  -262531.35243696,
#  -284864.65260232997,
#  -295945.09205648,
#  -313407.55982754,
#  -343876.87248831004,
#  -366990.12365291006,
#  -389205.13437856006,
#  -416510.28667333006,
#  -451870.63429618004,
#  -473629.96816316,
#  -479787.1561026401,
#  -504397.85616852005,
#  -495838.0591413501,
#  -525805.733708,
#  -551068.69092286,
#  -562370.4948560201,
#  -570045.2040880101,
#  -592126.1887723102,
#  -613036.9700733601,
#  -632765.2368204901,
#  -642699.1871565401,
#  -687823.0046290102,
#  -711439.1323997201,
#  -729825.6856760902,
#  -743324.4237486601,
#  -769595.2319919101,
#  -799542.1170440501,
#  -808164.6046572701,
#  -819735.4889376201,
#  -830029.6819153901,
#  -831558.53670665,
#  -847654.8651872202,
#  -850280.8724581702,
#  -861253.0489137302,
#  -858565.5707282302,
#  -871684.2436920402,
#  -898243.9955644902,
#  -894648.5175932202,
#  -913498.0723236502,
#  -934760.0836064902,
#  -936759.4764034902,
#  -935079.0972137301,
#  -953960.34374755,
#  -961220.90852456,
#  -979038.5097040101,
#  -994540.9604206402,
#  -1006725.5564135502,
#  -1002522.9214746102,
#  -1004922.3010404602,
#  -1010953.6919020002,
#  -1015496.5242985102,
#  -1040763.4342726301,
#  -1050536.7494922902,
#  -1073135.1279022002,
#  -1090436.31042325,
#  -1085407.66530716,
#  -1079557.5805674999,
#  -1082462.90449303,
#  -1091584.60341889,
#  -1097992.8152836198,
#  -1105069.72220829,
#  -1103848.6038553298,
#  -1116104.1569581698,
#  -1120584.8429218598,
#  -1143179.6945662699,
#  -1140341.74797689,
#  -1145481.59222688,
#  -1156612.7168909998,
#  -1170876.43823471,
#  -1173334.1243136697,
#  -1187412.82574408,
#  -1199607.6937422499,
#  -1207064.4488909398,
#  -1227662.2745828298,
#  -1237241.85275721,
#  -1250776.43234795,
#  -1262028.18866162,
#  -1244096.6223009601,
#  -1257169.8025028901,
#  -1266012.3580502302,
#  -1278322.0341803802,
#  -1288475.3702138702,
#  -1295293.11451049,
#  -1292880.37007645,
#  -1299538.98559448,
#  -1308840.00858845,
#  -1345877.6053037602,
#  -1350888.9393717002,
#  -1342883.7916482002,
#  -1355434.2288703301,
#  -1362729.3990019003,
#  -1355424.4964557604,
#  -1370161.7515549303,
#  -1370796.6080808404,
#  -1363062.0632890204,
#  -1367456.3871497205,
#  -1380746.7095959606,
#  -1401093.0513986305,
#  -1385944.3746630806,
#  -1381984.5590657308,
#  -1371045.306440071,
#  -1394849.374066701,
#  -1409647.6776283109,
#  -1427821.307692831,
#  -1411454.592199711,
#  -1431014.542837631,
#  -1421196.166627321,
#  -1429162.897748501,
#  -1433159.9815379411,
#  -1426362.7188047112,
#  -1429658.0799764113,
#  -1448738.4234630312,
#  -1464727.8610861013,
#  -1459777.6631419612,
#  -1475115.1578987013,
#  -1478252.8943635414,
#  -1483576.6830426415,
#  -1493097.0435266914,
#  -1516478.8477635914,
#  -1537783.4530733316,
#  -1522776.4625876716,
#  -1525081.2564448016,
#  -1546003.4013413517,
#  -1550743.2264253818,
#  -1558016.621086072,
#  -1558204.069863892,
#  -1565803.4274708119,
#  -1561710.403973612,
#  -1572843.482918682,
#  -1574664.701767512,
#  -1580398.6457613718,
#  -1575053.2328737718,
#  -1583436.516485262,
#  -1568947.081398232,
#  -1569201.337879452,
#  -1553481.517036472,
#  -1548749.3600323019,
#  -1557809.3227656318,
#  -1559011.4422608917,
#  -1563595.8947226517,
#  -1562146.1268303616,
#  -1595634.5955978115,
#  -1611438.3075428416,
#  -1639279.5424790017,
#  -1635849.6055500319,
#  -1633168.4224777417,
#  -1638197.4346078916,
#  -1655097.7949763916,
#  -1646525.1756450315,
#  -1631537.7776208315,
#  -1645464.4994708616,
#  -1640025.1838089617,
#  -1647435.5724445817,
#  -1645437.2342081817,
#  -1655132.6043103016,
#  -1659287.6016430417,
#  -1651540.9130417218,
#  -1644035.1900544218,
#  -1652446.8556177819,
#  -1661144.1524052117,
#  -1680915.4574273818,
#  -1696616.198249532,
#  -1697154.069930052,
#  -1704786.161619522,
#  -1721719.2445671118,
#  -1732829.7103846318,
#  -1737384.8535812916,
#  -1723919.4418139916,
#  -1727571.3174464316,
#  -1702424.2762239517,
#  -1714409.4745903017,
#  -1715472.408913632,
#  -1709490.337784882,
#  -1718169.106029132,
#  -1732642.929011342,
#  -1724133.309205532,
#  -1715235.641808872,
#  -1702643.4717810622,
#  -1696372.3055575122,
#  -1701795.6042084123,
#  -1724617.0953771523,
#  -1726416.9622537624,
#  -1746258.5047913524,
#  -1748577.9562351024,
#  -1739289.4436403224,
#  -1741158.7678873825,
#  -1739212.6063189125,
#  -1729940.6717417324,
#  -1735009.6735940322,
#  -1734274.094989112,
#  -1727274.6481031822,
#  -1719982.0913376622,
#  -1737133.4467571722,
#  -1732633.245905992,
#  -1727420.2312963821,
#  -1728016.4318895722,
#  -1745523.288250222,
#  -1738104.563692212,
#  -1730689.767724192,
#  -1724094.9361196521,
#  -1720139.5628948521,
#  -1737796.640173502,
#  -1727269.891367532,
#  -1732942.409367942,
#  -1726185.344384342,
#  -1724640.4589288319,
#  -1730454.555913752,
#  -1730070.222497992,
#  -1731323.523882322,
#  -1742541.0900514822,
#  -1741516.014780892,
#  -1730484.3627509621,
#  -1732486.8952825223,
#  -1730988.4446736723,
#  -1721049.8819768524,
#  -1727335.4453243623,
#  -1730543.8870856522,
#  -1744027.2489372122,
#  -1739923.0582444922,
#  -1740952.1212361222,
#  -1753398.6784834324,
#  -1769489.1280972422,
#  -1792231.2767663922,
#  -1807221.3526136922,
#  -1804843.457516852,
#  -1803832.315006942,
#  -1820393.8861785722,
#  -1819698.4735425822,
#  -1819800.320519162,
#  -1836960.873598472,
#  -1843947.891523842,
#  -1843881.894838602,
#  -1842217.8371459423,
#  -1838840.4937898524,
#  -1854451.9406573924,
#  -1861493.5295003925,
#  -1865381.9361099023,
#  -1869463.6576813222,
#  -1865753.788093612,
#  -1886619.849686952,
#  -1884477.6862843721,
#  -1881601.243728242,
#  -1876638.486052792,
#  -1873815.8024917122,
#  -1875211.6099844922,
#  -1880744.5251412522,
#  -1886617.2853045124,
#  -1883412.2480200024,
#  -1899889.6428190523,
#  -1910162.6544543724,
#  -1912643.7557308823,
#  -1906207.1052302022,
#  -1910392.7772246222,
#  -1911120.452420952,
#  -1920870.921808582,
#  -1932043.262794672,
#  -1951457.990346112,
#  -1940277.9491373121,
#  -1953892.5260816321,
#  -1969892.7007692722,
#  -1966692.0912563922,
#  -1972558.0608303323,
#  -1975880.7795734524,
#  -1962655.4311025126,
#  -1962900.1438457428,
#  -1987725.058877403,
#  -1980856.7126306328,
#  -1983449.7534560228,
#  -2014649.2737448227,
#  -2022553.2707206227,
#  -2009017.6778942528,
#  -1997289.6238150427,
#  -2008322.6249630027,
#  -2036349.9401182728,
#  -2024246.434762633,
#  -2038518.696078663,
#  -2059352.9816590229,
#  -2049898.206003403,
#  -2052172.5023492232,
#  -2049891.2599863133,
#  -2046428.3904456333,
#  -2029618.5206636833,
#  -2024452.1501484632,
#  -2020946.0202067632,
#  -2042105.099678483,
#  -2057686.7492661832,
#  -2056653.9705742332,
#  -2068096.2308746632,
#  -2057305.8702198733,
#  -2049522.0816540532,
#  -2064944.0363420732,
#  -2064449.2487106132,
#  -2087505.0922781932,
#  -2110458.628657243,
#  -2120712.225604883,
#  -2127933.3112413227,
#  -2134807.0427011726,
#  -2144517.107852773,
#  -2160313.406671443,
#  -2154197.697744423,
#  -2129804.855172423,
#  -2152088.760601453,
#  -2144775.0823320933,
#  -2143169.939985353,
#  -2144987.865852523,
#  -2152980.123531923,
#  -2153490.8487753333,
#  -2170104.324551713,
#  -2170922.592951693,
#  -2167298.385465063,
#  -2178024.081976183,
#  -2162424.9496242832,
#  -2155224.6685521533,
#  -2161522.0472622933,
#  -2170418.934950623,
#  -2160587.4441026035,
#  -2157799.5678855134,
#  -2147330.0823681536,
#  -2158210.7185217137,
#  -2176041.9786981135,
#  -2206957.0525240134,
#  -2209910.3228467936,
#  -2219253.5794767234,
#  -2227574.604398053,
#  -2237929.103740223,
#  -2232645.365203213,
#  -2250678.444220983,
#  -2264419.057309053,
#  -2275912.4648266425,
#  -2283008.3746898724,
#  -2282433.8341247723,
#  -2281709.593998792,
#  -2287488.643934842,
#  -2288553.6455853926,
#  -2324743.0181414927,
#  -2340142.3388492027,
#  -2341722.8752898024,
#  -2333277.445262772,
#  -2356093.571034552,
#  -2359757.4214807423,
#  -2357054.3966949023,
#  -2375976.7449049326,
#  -2379928.794080782,
#  -2387252.927763562,
#  -2372608.4356421023,
#  -2361613.7291401722,
#  -2345477.847159762,
#  -2351816.5926966616,
#  -2335180.0292693814,
#  -2334848.6125946613,
#  -2327147.7697064816,
#  -2313429.4388852115,
#  -2304245.4044106714,
#  -2316237.2292210115,
#  -2300292.873536342,
#  -2289284.865780022,
#  -2272967.4636542317,
#  -2282762.222111492,
#  -2288949.5472216923,
#  -2288983.0909684524,
#  -2291618.6626714827,
#  -2290420.9542638627,
#  -2288044.5201248024,
#  -2281396.4333772925,
#  -2278039.596430693,
#  -2285103.0983698424,
#  -2300076.9289674624,
#  -2296925.2131572324,
#  -2283474.1608745824,
#  -2273801.5185286724,
#  -2271701.1546651325,
#  -2273774.253221213,
#  -2258041.774499213,
#  -2256854.106446833,
#  -2252770.0649272827,
#  -2261191.2928545726,
#  -2263750.3666627426,
#  -2262034.7659817124,
#  -2265477.0560865924,
#  -2275307.980357942,
#  -2268412.504609492,
#  -2270930.793102062,
#  -2271241.9005248817,
#  -2277514.4094912317,
#  -2265065.6723623113,
#  -2269757.348454051,
#  -2282395.5762180514,
#  -2288402.761288211,
#  -2300250.030507341,
#  -2329936.789602681,
#  -2315972.358204181,
#  -2322370.4984505707,
#  -2346277.5494855405,
#  -2333377.98082796,
#  -2348444.3650380704,
#  -2373236.7571659503,
#  -2391030.5230179704,
#  -2395015.1191339204,
#  -2404288.4343946106,
#  -2409320.6154586007,
#  -2412835.1761435806,
#  -2429159.861653471,
#  -2430896.444165581,
#  -2425746.230256321,
#  -2436067.384326891,
#  -2445471.2961941813,
#  -2470788.2034157915,
#  -2480443.1989989416,
#  -2487150.1651788517,
#  -2491257.478236872,
#  -2492442.923566092,
#  -2509539.266900142,
#  -2509304.991542022,
#  -2534910.912963372,
#  -2544215.280234962,
#  -2547776.597261422,
#  -2559286.5749217216,
#  -2572174.9378198916,
#  -2566624.7589064115,
#  -2573313.5140788616,
#  -2569186.1315210317,
#  -2583849.744057912,
#  -2590834.0963831423,
#  -2592525.1667451924,
#  -2591836.7455826923,
#  -2598586.767758062,
#  -2611989.852383172,
#  -2594007.4321630923,
#  -2584019.7859976524,
#  -2572608.9964034725,
#  -2567334.6972046527,
#  -2587544.2012041425,
#  -2567596.3204333824,
#  -2574698.1634834926,
#  -2578050.8294046624,
#  -2576326.2250498924,
#  -2583839.4579561627,
#  -2588753.685070783,
#  -2582269.855038363,
#  -2600088.821687203,
#  -2599287.767875833,
#  -2597383.128846373,
#  -2596388.031105863,
#  -2614798.198211183,
#  -2615255.564920033,
#  -2607954.048562503,
#  -2615029.448347053,
#  -2603093.240741083,
#  -2609148.8802641532,
#  -2635106.280054233,
#  -2631112.7850529933,
#  -2629070.1309634736,
#  -2617593.3288060236,
#  -2609033.7429126333,
#  -2617966.421971803,
#  -2623870.302971483,
#  -2634548.428539413,
#  -2639806.107725553,
#  -2631448.0894925334,
#  -2654433.572009573,
#  -2664736.331971323,
#  -2668599.966969523,
#  -2684708.9424064434,
#  -2688849.8397894334,
#  -2672878.9231550037,
#  -2690041.578479364,
#  -2687265.2889065538,
#  -2707218.7981918836,
#  -2689494.8867886933,
#  -2701234.1292350735,
#  -2716556.5486018634,
#  -2721019.5238380334,
#  -2738111.3278709333,
#  -2738158.9401018335,
#  -2741820.4835010334,
#  -2737531.6063134335,
#  -2740540.7666658238,
#  -2741728.304902324,
#  -2737002.600448094,
#  -2734654.701942524,
#  -2743629.123010194,
#  -2754167.183080294,
#  -2752540.7762517342,
#  -2750449.971010404,
#  -2757003.611634944,
#  -2761421.1552441744,
#  -2773096.131123884,
#  -2765854.168102274,
#  -2790057.914103114,
#  -2801331.897345114,
#  -2800859.925741624,
#  -2797640.839015484,
#  -2763656.029489674,
#  -2770914.460088124,
#  -2760244.5737445443,
#  -2770044.653175474,
#  -2770959.218355574,
#  -2771440.790267534,
#  -2770641.220103744,
#  -2775592.961995904,
#  -2776783.6925202636,
#  -2772850.4114880837,
#  -2807995.8023079135,
#  -2807586.9342752034,
#  -2800213.4165797234,
#  -2809099.1546675935,
#  -2811563.5414843033,
#  -2827140.193826523,
#  -2826066.3634734633,
#  -2837231.6155932234,
#  -2834564.6268474134,
#  -2863621.9691598034,
#  -2870562.2308453033,
#  -2896248.038067923,
#  -2903516.355735873,
#  -2916055.0927638933,
#  -2922220.2022419935,
#  -2926560.915393464,
#  -2938977.5921866437,
#  -2949072.0299810534,
#  -2947155.3128676037,
#  -2954359.7638622737,
#  -2976457.393081834,
#  -2973226.137819294,
#  -2982388.107624344,
#  -2955110.861010674,
#  -2972294.879956674,
#  -2961624.484552674,
#  -2971051.185495074,
#  -2968598.5467098537,
#  -2968992.3909740937,
#  -2969890.301329734,
#  -2971830.7320723636,
#  -2953891.4985773736,
#  -2953838.418933944,
#  -2936349.930591234,
#  -2950612.542055494,
#  -2953654.055926064,
#  -2950638.941968264,
#  -2953889.458688994,
#  -2948945.543925964,
#  -2953492.915339594,
#  -2958028.948868114,
#  -2971009.388603624,
#  -2958685.847409464,
#  -2981476.954668534,
#  -2979532.046415124,
#  -2990542.0816458743,
#  -2985040.073332764,
#  -3005378.835815874,
#  -2995992.259495054,
#  -2997842.756140584,
#  -3010752.135156624,
#  -3004564.627739984,
#  -3001863.6929677743,
#  -2995223.1121044643,
#  -2995258.451185914,
#  -3002482.476581434,
#  -3013951.8338383436,
#  -3029363.3698140737,
#  -3046681.066725494,
#  -3050784.493425584,
#  -3036504.9452064335,
#  -3042427.0861793533,
#  -3051764.408054273,
#  -3057796.525541853,
#  -3056691.5893373634,
#  -3069689.0190268033,
#  -3049835.8004764533,
#  -3047199.1599191832,
#  -3045540.3766144235,
#  -3052620.0719229234,
#  -3045019.0593420337,
#  -3048619.1500094733,
#  -3061655.451995963,
#  -3055016.6674563233,
#  -3058444.8205758235,
#  -3057859.159560044,
#  -3071120.0254032034,
#  -3057767.9374209335,
#  -3052923.7471124134,
#  -3051052.4036598834,
#  -3055500.1203960637,
#  -3058593.3723600837,
#  -3080863.612351074,
#  -3098866.409797494,
#  -3086317.412907124,
#  -3111210.094836314,
#  -3106944.3051519045,
#  -3133768.435758595,
#  -3152959.366684835,
#  -3147850.589205435,
#  -3155301.315057235,
#  -3162980.547648095,
#  -3171253.338610135,
#  -3178776.755769715,
#  -3176987.2814394855,
#  -3170386.6136765154,
#  -3172831.5755899055,
#  -3154307.0676958356,
#  -3145196.2407666454,
#  -3130683.5590393255,
#  -3142754.2854079152,
#  -3147364.6987816254,
#  -3158176.2165003754,
#  -3135368.124197395,
#  -3141182.729724025,
#  -3148317.991152005,
#  -3146573.8126359647,
#  -3159297.062845985,
#  -3163308.810620305,
#  -3142925.408030365,
#  -3140233.807175225,
#  -3138895.846429725,
#  -3143980.612419445,
#  -3150157.4636786953,
#  -3150443.005700725,
#  -3154725.785246805,
#  -3164137.435033875,
#  -3170810.686570215,
#  -3188068.5689174547,
#  -3178425.7224857546,
#  -3181913.7341034347,
#  -3184166.6297770347,
#  -3188320.562675985,
#  -3206775.388862605,
#  -3212012.167375915,
#  -3214463.394740465,
#  -3224969.8741079853,
#  -3229590.0590767353,
#  -3237094.9848043253,
#  -3243720.3712940356,
#  -3242825.3190703955,
#  -3243640.710438966,
#  -3249802.0846420256,
#  -3263147.5469937455,
#  -3278715.1741711255,
#  -3296609.0869050855,
#  -3294573.9794950355,
#  -3300131.1060105255,
#  -3302506.5924027353,
#  -3292913.219543695,
#  -3295272.784684345,
#  -3285090.705364825,
#  -3285007.138344645,
#  -3280789.9121719548,
#  -3275960.7462068046,
#  -3284557.8984056944,
#  -3281375.710530774,
#  -3286634.0805247244,
#  -3276097.7502427744,
#  -3276170.4795270944,
#  -3283175.9271124844,
#  -3315624.351409084,
#  -3327240.114627434,
#  -3340894.147576004,
#  -3355559.335523134,
#  -3366987.770665794,
#  -3371838.336104804,
#  -3373354.989216434,
#  -3378574.334546454,
#  -3389403.350357264,
#  -3400054.2076685936,
#  -3407472.6775334836,
#  -3396251.9074128037,
#  -3392123.9848880335,
#  -3388561.088575104,
#  -3397165.732005004,
#  -3391060.7041672636,
#  -3388582.078799634,
#  -3384450.4902465837,
#  -3396666.8239696138,
#  -3407761.248347194,
#  -3406899.804899484,
#  -3408269.160538764,
#  -3409683.3193404544,
#  -3420417.906316704,
#  -3425394.152594734,
#  -3428949.850698774,
#  -3439100.1200445844,
#  -3453437.5629383246,
#  -3460350.1395156546,
#  -3477366.3926408747,
#  -3459179.2419141345,
#  -3458045.270335974,
#  -3453341.169710464,
#  -3461168.8335383236,
#  -3468620.479133784,
#  -3468316.622992274,
#  -3472000.664372684,
#  -3480141.6473596743,
#  -3490277.4605907747,
#  -3488312.689624425,
#  -3473259.139498325,
#  -3479564.5046467953,
#  -3490485.2280963156,
#  -3490772.6476376657,
#  -3489298.198158526,
#  -3484021.208513716,
#  -3481910.091735526,
#  -3486221.941507896,
#  -3479444.0725698257,
#  -3479824.3370191455,
#  -3472643.3934857454,
#  -3495202.0385823953,
#  -3519707.1234062854,
#  -3529079.1650590356,
#  -3525619.3288595257,
#  -3518004.1372697954,
#  -3522768.1150469254,
#  -3514488.011419415,
#  -3516445.425153955,
#  -3523040.1973969853,
#  -3521985.2411415554,
#  -3531880.3693350353,
#  -3524403.6561368653,
#  -3534046.1263696454,
#  -3541458.3373405053,
#  -3557509.2623162954,
#  -3562244.3664121754,
#  -3564398.4668707955,
#  -3594574.7016118057,
#  -3593751.102599086,
#  -3607016.4296371457,
#  -3601501.758232766,
#  -3614918.151263936,
#  -3615224.935651416,
#  -3608031.0189643563,
#  -3636707.0276084663,
#  -3627197.8736197664,
#  -3639901.446785487,
#  -3639143.835455347,
#  -3643802.008075397,
#  -3646614.6012454173,
#  -3645837.0260970374,
#  -3651110.6845542276,
#  -3647159.2374021276,
#  -3648906.7306185076,
#  -3660105.6052238476,
#  -3670907.1921285777,
#  -3678751.300353578,
#  -3689006.2716561975,
#  -3682255.7916450375,
#  -3664795.3106331876,
#  -3664843.8799595376,
#  -3665266.4016405977,
#  -3669202.4788431874,
#  -3664573.995423687,
#  -3666318.203014917,
#  -3669984.263296457,
#  -3669602.843896537,
#  -3672608.395980357,
#  -3689668.127747447,
#  -3685005.4977656575,
#  -3681379.2565778876,
#  -3700822.8186787274,
#  -3710241.7582315775,
#  -3703000.4387769075,
#  -3690519.3654639074,
#  -3704929.024626037,
#  -3727929.3906076374,
#  -3734771.912693107,
#  -3720961.8984424174,
#  -3724057.9723872477,
#  -3711178.3534471574,
#  -3712111.6492744978,
#  -3712982.548146988,
#  -3731591.071276408,
#  -3718384.128743118,
#  -3723232.496414668,
#  -3725385.5675167283,
#  -3707242.8007949283,
#  -3720138.5938081085,
#  -3716533.5141826984,
#  -3732013.5688636685,
#  -3735189.9484438486,
#  -3739018.546408809,
#  -3738711.8323049285,
#  -3731506.8609832386,
#  -3728409.5338533786,
#  -3719916.5545800286,
#  -3714128.086630589,
#  -3717821.781090249,
#  -3701827.254857259,
#  -3696864.839999089,
#  -3689094.853931629,
#  -3685692.533708309,
#  -3720077.670138479,
#  -3721597.7941792794,
#  -3733762.3323337296,
#  -3737215.90308565,
#  -3759584.81220902,
#  -3770700.0211970597,
#  -3764631.32892351,
#  -3769409.99358339,
#  -3777908.28890412,
#  -3802486.55286688,
#  -3801240.4863420995,
#  -3820736.5902620195,
#  -3810138.8378051496,
#  -3804142.9985603495,
#  -3800558.9515354396,
#  -3799819.89214174,
#  -3821972.48070564,
#  -3812761.8830589,
#  -3804848.34541807,
#  -3813014.08916013,
#  -3825228.7655719197,
#  -3835156.964699,
#  -3832943.31062009,
#  -3837888.94768873,
#  -3855435.96140228,
#  -3848594.11146388,
#  -3851910.67544138,
#  -3846702.6158454204,
#  -3837173.10005456,
#  -3836909.23034175,
#  -3823104.8225527504,
#  -3842262.14874084,
#  -3853154.82361228,
#  -3852172.51009539,
#  -3863039.39181171,
#  -3866834.30336471,
#  -3871149.65070886,
#  -3872871.9117841395,
#  -3875712.5887513696,
#  -3868011.32676176,
#  -3881076.1092066,
#  -3891606.7548042303,
#  -3883057.2563534104,
#  -3878288.3495223504,
#  -3860507.3722452605,
#  -3843504.6410727706,
#  -3852248.8361494103,
#  -3860549.9920962104,
#  -3876921.52234546,
#  -3874735.51319096,
#  -3884499.19200895,
#  -3876170.6316494597,
#  -3876645.27248022,
#  -3886551.90114599,
#  -3883552.38278097,
#  -3890120.98907892,
#  -3898552.2517026,
#  -3899977.28324922,
#  -3886447.0816969,
#  -3886245.84520494,
#  -3883835.99187095,
#  -3880986.40985699,
#  -3875009.38979054,
#  -3870108.97116058,
#  -3850830.05943213,
#  -3850045.09170275,
#  -3843837.24785041,
#  -3842891.88523664,
#  -3846690.93493638,
#  -3841519.66543936,
#  -3858096.40704543,
#  -3853464.07818566,
#  -3850621.48137467,
#  -3856093.0354061797,
#  -3850538.34794107,
#  -3855685.63627378,
#  -3861970.80916028,
#  -3866362.6676137703,
#  -3849326.5723010805,
#  -3858730.258672151,
#  -3889894.0497323307,
#  -3887074.562962921,
#  -3900478.180829401,
#  -3902220.202812701,
#  -3911479.687023451,
#  -3899289.4102513813,
#  -3895513.4712870615,
#  -3905078.1343700215,
#  -3910507.840488582,
#  -3909032.1246696017,
#  -3921167.5714564915,
#  -3924624.776891742,
#  -3938048.818411022,
#  -3940747.329103252,
#  -3950862.659665172,
#  -3965432.037538872,
#  -3971424.5064816824,
#  -3985653.4817991024,
#  -3987473.4973819726,
#  -3990667.976789492,
#  -3979540.905971832,
#  -3964606.2255609822,
#  -3960868.371784902,
#  -3943772.098492072,
#  -3938625.239946162,
#  -3955162.813571062,
#  -3943366.308279272,
#  -3944273.069112152,
#  -3929015.553483382,
#  -3951203.687841172,
#  -3942359.9347240417,
#  -3943385.4606924118,
#  -3955483.8825517218,
#  -3963705.349633652,
#  -3965675.2097415817,
#  -3971155.7152973516,
#  -3975251.1202867515,
#  -3994360.6785339513,
#  -3985057.1925811213,
#  -3991722.5276075113,
#  -3985758.907783131,
#  -4003591.263954221,
#  -4020265.3408803805,
#  -4021550.3990363604,
#  -4027864.4593151202,
#  -4040309.8428749503,
#  -4044344.1769144004,
#  -4054390.6705603506,
#  -4075750.147010931,
#  -4071705.659482501,
#  -4073042.5494716708,
#  -4070162.3848090707,
#  -4082634.7814769605,
#  -4084565.319819241,
#  -4093941.988940491,
#  -4117050.159544621,
#  -4132604.952039101,
#  -4136432.051826651,
#  -4134885.248366591,
#  -4147422.853675811,
#  -4137301.725274501,
#  -4133170.6164563806,
#  -4134633.2396642007,
#  -4148759.794596191,
#  -4141751.4596491707,
#  -4163420.6469886005,
#  -4177841.6098731505,
#  -4171302.4837654005,
#  -4175572.5196303003,
#  -4189423.2149763303,
#  -4183897.7294259802,
#  -4183341.69017439,
#  -4185651.19716349,
#  -4177395.6620971705,
#  -4188034.55502262,
#  -4198124.019113881,
#  -4209966.947403511,
#  -4213645.834551621,
#  -4221229.562600851,
#  -4218416.548515671,
#  -4202907.302945901,
#  -4207604.926799831,
#  -4189211.726906191,
#  -4201103.777225121,
#  -4212150.640113871,
#  -4204268.9640559,
#  -4219383.30605691,
#  -4221812.5433097305,
#  -4235256.27502875,
#  -4259946.82344605,
#  -4238475.12595012,
#  -4241830.29650012,
#  -4254368.21416538,
#  -4253014.8351659505,
#  -4281539.964073581,
#  -4277164.21068891,
#  -4280688.67686135,
#  -4285888.424322311,
#  -4278334.489591951,
#  -4278868.01769392,
#  -4286375.94389795,
#  -4277246.95198219,
#  -4272944.6792120505,
#  -4271876.3971672505,
#  -4287602.73151989,
#  -4304962.151804809,
#  -4301958.361350049,
#  -4309816.7533252295,
#  -4334095.005605499,
#  -4319984.404824009]

# %%
sub1=plt.subplot(1, 2, 1)##############################################################
iteration=[]
for i in range(0,999):
    iteration.append(i)

#在同一幅图片上画3条折线
A,=plt.plot(iteration,dynamic_regret,color = 'red',linewidth = '1.5',label='large-attack online primal-dual algorithm')


#设置图例并且设置图例的字体及大小
font1 = {
'size'   : 18,
}
#legend = plt.legend(handles=[A],prop=font1)
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=18)
 
#设置横纵坐标的名称以及对应字体格式
font2 = {
'size'   : 18,
}
plt.xlabel('T',font2)
plt.ylabel(r'Dynamic regret $Reg(T)$',font2)
plt.title('varying $D_{t}$',font2) 

sub2=plt.subplot(1, 2, 2)##############################################################
iteration=[]
for i in range(0,999):
    iteration.append(i)

#在同一幅图片上画3条折线
A,=plt.plot(iteration,dynamic_regret_T,color = 'red',linewidth = '1.5',label='large-attack online primal-dual algorithm')


#设置图例并且设置图例的字体及大小
font1 = {
'size'   : 18,
}
#legend = plt.legend(handles=[A],prop=font1)
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=18)
 
#设置横纵坐标的名称以及对应字体格式
font2 = {
'size'   : 18,
}
plt.xlabel('T',font2)
plt.ylabel(r'Dynamic regret $Reg(T)/T$',font2)
plt.title('varying $D_{t}$',font2) 

plt.legend(handles=[A],prop={'size':18},loc="upper center", bbox_to_anchor=[-0.3, -0.2],
           ncol=18, shadow=True, fancybox=True)

plt.subplots_adjust(wspace=0.5,hspace=0.5) 
plt.gcf().set_size_inches((15, 5))

#plt.savefig('./figures/01-figure1_dynamic_regret_attack_free_varying_D.pdf',format='pdf', bbox_inches='tight')
#plt.savefig('./figures/01-figure1_dynamic_regret_attack_free_varying_D.png',format='png', bbox_inches='tight')

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
from sympy import *
import math 
from datetime import datetime
from scipy.special import gamma, factorial
import scipy.special as sc

# %%
sum_thermal_wind_power_station_strategy=np.loadtxt("./data/02_IOS_optimal_parameters_large_Byzantine_attack_sum_thermal_wind_power_station_strategy.txt")
d_power_demand=np.loadtxt("./data/d_power_demand_normal_distribution_(100,10).txt")

# %%
accumulative_constraint_violation=[]
accumulative_constraint_violation_T=[]
for T in range(1, 1000):
    accumulative_constraint_violation_auxiliary_variable=0
    for t in range(0, T): 
        accumulative_constraint_violation_auxiliary_variable=accumulative_constraint_violation_auxiliary_variable+(1/58)*sum_thermal_wind_power_station_strategy[t+1]-d_power_demand[t+1]
    accumulative_constraint_violation.append(abs(accumulative_constraint_violation_auxiliary_variable))
    accumulative_constraint_violation_T.append(abs(accumulative_constraint_violation_auxiliary_variable)/T)

# %%
accumulative_constraint_violation
# Out:
# [31.98579342931035,
#  51.18718774172413,
#  63.294332376206896,
#  54.977947419655194,
#  67.16279319913795,
#  46.652590536379336,
#  41.1790433924138,
#  25.864855181896544,
#  31.100147820172396,
#  10.736024792758599,
#  11.690237549482774,
#  44.15912370965519,
#  71.40417447706898,
#  89.6851594034483,
#  118.48199673000002,
#  137.17037729413795,
#  145.01049310000002,
#  166.61173618310346,
#  166.23213587189656,
#  176.94232734948275,
#  225.01952318379307,
#  232.8781736577586,
#  252.09279600689655,
#  273.7991147787931,
#  284.9983528543104,
#  302.2121339646552,
#  331.27813330775865,
#  353.68461238775865,
#  375.26001152724143,
#  401.4473068217242,
#  434.80275263637935,
#  455.9210329260345,
#  462.29959519189657,
#  485.9758355010345,
#  477.03991080413795,
#  505.4959402472414,
#  529.7125457274137,
#  541.0546348901723,
#  548.9173846479309,
#  570.1988568063791,
#  590.4004394929309,
#  609.5074247191378,
#  619.5180356943102,
#  660.8964104060344,
#  683.4861690732757,
#  701.3015032489653,
#  714.598243201724,
#  739.501755479655,
#  767.6501519339653,
#  776.3595072179309,
#  787.8097329505171,
#  798.0598680963791,
#  799.9202916175859,
#  815.4977308399997,
#  818.4415330867239,
#  829.2796423949998,
#  826.9540931727583,
#  839.7566840051722,
#  864.6890162289653,
#  861.4704904118963,
#  879.471966127586,
#  899.6376438018963,
#  901.98305161431,
#  900.7192511641376,
#  918.7069099156894,
#  926.0332816249997,
#  943.0412849753446,
#  957.9415219303446,
#  969.8027820224136,
#  966.048033334655,
#  968.7762740656894,
#  974.9278312715514,
#  979.68364922431,
#  1003.2864812706893,
#  1012.8966595260341,
#  1034.1157878546549,
#  1050.5786497868962,
#  1046.0354024741375,
#  1040.67131352931,
#  1043.8662131696549,
#  1052.8451981744824,
#  1059.3111027446548,
#  1066.3947568577582,
#  1065.6322392312065,
#  1077.4729833199997,
#  1082.1355977715514,
#  1103.2767976286204,
#  1100.9361993682755,
#  1106.2062553346548,
#  1117.0023922599996,
#  1130.6484091098273,
#  1133.4044947349996,
#  1146.8756069834478,
#  1158.6304091291374,
#  1166.034617245689,
#  1185.3517439794823,
#  1194.7036987986203,
#  1207.6595657977582,
#  1218.5330392706892,
#  1200.6753842849996,
#  1213.1958894356892,
#  1221.8523230075857,
#  1233.6735299694824,
#  1243.5254425348273,
#  1250.310275735517,
#  1248.4122642865516,
#  1255.0449544286205,
#  1264.1046989263791,
#  1297.4826550793102,
#  1302.5859415837929,
#  1295.172023989655,
#  1307.178255976379,
#  1314.3818948686203,
#  1307.6835453229307,
#  1321.6555338401722,
#  1322.6673260889654,
#  1315.5455499099999,
#  1320.0608943689656,
#  1332.7174283234483,
#  1351.6922418867243,
#  1336.9575715689657,
#  1333.5711982651726,
#  1323.2102891081038,
#  1345.221434762759,
#  1359.2309513717244,
#  1376.264074894483,
#  1360.2486341227589,
#  1378.5100209987934,
#  1369.2949323263797,
#  1377.0897909282762,
#  1381.2243237337934,
#  1375.0472568701728,
#  1378.5291092994833,
#  1396.3569161932762,
#  1411.4233553015522,
#  1407.067658681897,
#  1421.5445759763797,
#  1424.876554283966,
#  1430.2320631850005,
#  1439.4375830339661,
#  1461.0455473294835,
#  1480.8258722436215,
#  1466.2895174258629,
#  1468.8407595362078,
#  1488.2681349351733,
#  1493.074294647587,
#  1500.210159683449,
#  1500.7819471591388,
#  1508.2122735253456,
#  1504.7108232274145,
#  1515.357195113794,
#  1517.4506224422423,
#  1523.163334088794,
#  1518.44822067138,
#  1526.5869054165526,
#  1512.6515804913802,
#  1513.2807048205182,
#  1498.0586017096562,
#  1493.937683005001,
#  1502.6937024294837,
#  1504.2063905918974,
#  1508.8577760986213,
#  1507.878864497242,
#  1538.0984980441383,
#  1552.9559913289659,
#  1578.3830741434488,
#  1575.5122391112075,
#  1573.3618075815523,
#  1578.420708107759,
#  1594.2457072841385,
#  1586.3374117665523,
#  1571.8822189291384,
#  1585.0367831450005,
#  1580.227200975173,
#  1587.4687850336213,
#  1585.9691814027592,
#  1595.296060930173,
#  1599.5432914748283,
#  1592.460502974311,
#  1585.6152453975872,
#  1593.7716929572423,
#  1602.1895363294836,
#  1620.5611474582768,
#  1635.3034339462079,
#  1636.1920722827597,
#  1643.6345574396562,
#  1659.4769793386217,
#  1670.0838096868974,
#  1674.6967436256905,
#  1661.8357828581043,
#  1665.612504090518,
#  1640.168529863449,
#  1651.5582740241387,
#  1652.9313697644834,
#  1647.5941006124144,
#  1655.9856505962077,
#  1669.6207554370699,
#  1661.7790779967252,
#  1653.5495057017251,
#  1641.571533763794,
#  1635.942799225173,
#  1641.3554272041388,
#  1662.4078023022423,
#  1664.468197864139,
#  1682.9043117546562,
#  1685.448468902932,
#  1676.805104704656,
#  1678.930607035001,
#  1677.4735301401734,
#  1668.8453951953459,
#  1673.935176975001,
#  1673.6236663894838,
#  1667.2585820172424,
#  1660.6005838755182,
#  1676.6561362198286,
#  1672.7363380705183,
#  1668.1208849487941,
#  1669.0609775934493,
#  1685.4433393443114,
#  1678.6429124884492,
#  1671.8462410706907,
#  1665.8612797413803,
#  1662.461902218794,
#  1678.9890799979319,
#  1669.039803933794,
#  1674.6997164906904,
#  1668.5403937372423,
#  1667.4559328256908,
#  1673.2497934496562,
#  1673.2677899234493,
#  1674.8279458974148,
#  1685.574217673277,
#  1684.9835334489665,
#  1674.488435003277,
#  1676.7507380375873,
#  1675.707880689139,
#  1666.3205982489667,
#  1672.5590264587943,
#  1675.9483425572425,
#  1688.7636537713806,
#  1685.1959513050012,
#  1686.5506525768976,
#  1698.4311342534493,
#  1713.6020988824148,
#  1734.6926403427597,
#  1748.8733249410357,
#  1746.9853429017253,
#  1746.4099821284494,
#  1761.994780479484,
#  1761.7213992901736,
#  1762.2044920234496,
#  1778.3185675217255,
#  1785.202869923622,
#  1785.52783093276,
#  1784.3343799439667,
#  1781.4934496431047,
#  1796.2086851213805,
#  1803.1385409318978,
#  1807.1565764637944,
#  1811.3532182696563,
#  1808.1946725850012,
#  1827.584984599484,
#  1825.9378854281047,
#  1823.5872037768977,
#  1819.2128266877598,
#  1816.9144773187945,
#  1818.6107198937946,
#  1824.145967651898,
#  1829.9946519255188,
#  1827.327222553105,
#  1842.8073985820704,
#  1852.6872202982772,
#  1855.3951873681049,
#  1849.5699353062082,
#  1853.8595469570703,
#  1854.9307845886221,
#  1864.332499735519,
#  1875.0278354472432,
#  1893.1243396234502,
#  1882.528150622588,
#  1895.429414036209,
#  1910.4743603215538,
#  1907.8153285632782,
#  1913.6526214146577,
#  1917.1386029013818,
#  1904.4585075393127,
#  1905.07543152983,
#  1927.9040013837955,
#  1921.6667760200023,
#  1924.4736992018989,
#  1952.7696426275884,
#  1960.4739111208644,
#  1947.484496522761,
#  1936.3616093870714,
#  1946.9126450194851,
#  1972.4907887713816,
#  1960.9819237689678,
#  1974.4563492246575,
#  1993.776721452416,
#  1984.9684169853472,
#  1987.4746653500022,
#  1985.70357168914,
#  1982.8018096708643,
#  1966.414395183623,
#  1961.864308172071,
#  1958.9184627539676,
#  1978.5219044032779,
#  1993.1709420708642,
#  1992.5818458889676,
#  2003.500966748795,
#  1993.3326517565538,
#  1986.1924200036228,
#  2000.6987830510366,
#  2000.616502821209,
#  2021.890120455002,
#  2043.0751997365537,
#  2052.916377517071,
#  2059.9876799677604,
#  2066.738912528105,
#  2076.079597841036,
#  2090.90967354276,
#  2085.4349698698293,
#  2060.8126017574155,
#  2081.3761912391396,
#  2074.7270681468985,
#  2073.599103455002,
#  2075.674970926899,
#  2083.440275148278,
#  2084.298237871554,
#  2099.8473403881057,
#  2100.991881512416,
#  2097.9383120684506,
#  2108.1896487337954,
#  2093.1055748358644,
#  2086.5697054043126,
#  2092.7816048039676,
#  2101.3717975367263,
#  2092.2006459268987,
#  2089.9448251287954,
#  2080.1244774187953,
#  2090.5216244743124,
#  2107.165999750347,
#  2135.1832253313814,
#  2138.314173104485,
#  2147.316203215519,
#  2155.3850793715537,
#  2165.3041602831054,
#  2160.642148753105,
#  2177.455381685864,
#  2190.42900123914,
#  2201.373618902243,
#  2208.3148186237945,
#  2208.1566449398288,
#  2207.858225254484,
#  2213.587266615346,
#  2214.9581689918978,
#  2247.2396412981047,
#  2261.679289171898,
#  2263.528694123277,
#  2255.7972176831045,
#  2276.7682848703457,
#  2280.5422596060353,
#  2278.382412788449,
#  2295.929098727932,
#  2299.96543291207,
#  2307.090732059484,
#  2293.124735716208,
#  2282.9534720908628,
#  2267.4595975732764,
#  2273.681340717587,
#  2257.6366816900004,
#  2257.6998802991384,
#  2250.7140642541385,
#  2237.6658659794834,
#  2229.1996017370698,
#  2240.565765962415,
#  2225.1718730101734,
#  2214.8481885081046,
#  2199.047541884484,
#  2208.438779463622,
#  2214.5430733275875,
#  2214.9512464805184,
#  2217.794245851208,
#  2217.0436613500015,
#  2215.1632817532773,
#  2209.135448812243,
#  2206.3146436341394,
#  2213.2385951917254,
#  2227.3492681805183,
#  2224.7226547651735,
#  2211.7859943393114,
#  2202.7163050894837,
#  2201.0985370153458,
#  2203.413981725346,
#  2188.0696144784492,
#  2187.320256718794,
#  2183.7829346265526,
#  2191.970529692587,
#  2194.744651553104,
#  2193.488577903104,
#  2197.0870543301735,
#  2206.573241116898,
#  2200.248062570001,
#  2202.989280735863,
#  2203.661033782932,
#  2209.886728506208,
#  2197.9043761843113,
#  2202.669975330001,
#  2214.7233980831043,
#  2220.70901135207,
#  2232.047068076208,
#  2259.184108596208,
#  2245.613748868794,
#  2251.960850547415,
#  2274.0760248968973,
#  2261.632798878104,
#  2275.8777160262075,
#  2298.7589850703453,
#  2315.4483580000006,
#  2319.5588936013796,
#  2328.5389885179316,
#  2333.617413748104,
#  2337.2881533337936,
#  2352.6409838815525,
#  2354.655328496725,
#  2350.0974953424147,
#  2360.0185263310354,
#  2369.1021504232767,
#  2392.3776493482765,
#  2401.686584947932,
#  2408.295560333966,
#  2412.5062658655174,
#  2414.0022252137933,
#  2430.0068271625864,
#  2430.174396328621,
#  2453.6537901096553,
#  2462.6254336705174,
#  2466.323640557414,
#  2477.2907551329313,
#  2489.499201404828,
#  2484.598657281035,
#  2491.1685337817244,
#  2487.647555469656,
#  2501.4375142991385,
#  2508.2732898450004,
#  2510.230058886207,
#  2509.9698647425867,
#  2516.5867260346554,
#  2529.2336132556898,
#  2511.7505143813796,
#  2502.4962505479316,
#  2491.8071947868975,
#  2487.1877379343114,
#  2505.8923810339666,
#  2486.293392766898,
#  2493.2305081510353,
#  2496.722289133449,
#  2495.483591373449,
#  2502.7997345081044,
#  2507.733040198449,
#  2501.918855692587,
#  2518.5260565132767,
#  2518.1543333237937,
#  2516.7426526829317,
#  2516.1883974698285,
#  2533.3253148536214,
#  2534.129882865863,
#  2527.503208521035,
#  2534.4226324806905,
#  2523.141451412415,
#  2529.126418238794,
#  2552.8745096056905,
#  2549.4658616262077,
#  2547.9208557743113,
#  2537.101996212932,
#  2529.220949798622,
#  2537.838793374829,
#  2543.6865263063805,
#  2553.8936926622423,
#  2559.1481083374147,
#  2551.4561660143113,
#  2572.6369142222425,
#  2582.504797544656,
#  2586.4734895162073,
#  2601.5707206541383,
#  2605.7948585655176,
#  2590.330073357069,
#  2606.3622879796553,
#  2604.118338136207,
#  2622.6257583434485,
#  2605.3221165286213,
#  2616.4834551498284,
#  2630.867593856208,
#  2635.3860355848283,
#  2651.348601902932,
#  2651.769487497759,
#  2655.5465107020696,
#  2651.859614951897,
#  2655.0322761820694,
#  2656.5145237136207,
#  2652.407855096552,
#  2650.5757671343104,
#  2659.2213608610346,
#  2669.287402659483,
#  2668.1367575668974,
#  2666.547462653794,
#  2672.9826516274147,
#  2677.454996596208,
#  2688.549603729311,
#  2681.988337824656,
#  2704.1940834003453,
#  2714.9256990820695,
#  2714.859914893966,
#  2712.2007376582765,
#  2676.402703656725,
#  2683.479341951725,
#  2673.501135363622,
#  2682.8962214586218,
#  2684.1228276313805,
#  2684.9462406987946,
#  2684.571675140346,
#  2689.538287674656,
#  2691.0230965475876,
#  2687.668674314829,
#  2719.1806670237943,
#  2719.172451596036,
#  2712.462238324312,
#  2721.0357834741394,
#  2723.705648485519,
#  2738.321467825346,
#  2737.6888967837945,
#  2748.3322820967255,
#  2746.191460057415,
#  2772.593740735346,
#  2779.3885389917255,
#  2802.8915618348287,
#  2809.9839735600012,
#  2821.858863705518,
#  2827.9367905739664,
#  2832.33602383707,
#  2844.0899401015527,
#  2853.7425104536214,
#  2852.3222236644838,
#  2859.340672275001,
#  2879.6708948072423,
#  2877.0102063172426,
#  2885.8037687355186,
#  2858.1954958484494,
#  2874.183053173277,
#  2864.2717773762083,
#  2873.2996960525875,
#  2871.376905234484,
#  2872.1139271682773,
#  2873.3188715958636,
#  2875.4899557367257,
#  2858.105117792588,
#  2858.425347401036,
#  2841.50218187276,
#  2854.89077400845,
#  2858.080727083105,
#  2855.619257383967,
#  2859.0034655568984,
#  2854.695312487588,
#  2859.2761336022436,
#  2863.847405452588,
#  2876.102283332243,
#  2864.4849928177605,
#  2885.4325594344846,
#  2883.980452843967,
#  2894.4616412394844,
#  2889.6047873853463,
#  2908.4157951058633,
#  2899.730456384139,
#  2901.822251085174,
#  2914.01691036707,
#  2908.4932077546564,
#  2906.323906271036,
#  2900.357214309829,
#  2900.7602469646567,
#  2907.8012760977604,
#  2918.7015403768983,
#  2933.146163919312,
#  2949.291183755864,
#  2953.468205150519,
#  2939.8042226465536,
#  2945.6526458113813,
#  2954.618983015692,
#  2960.568114685692,
#  2959.905267270692,
#  2972.1786938751748,
#  2952.659071475175,
#  2950.5519550953472,
#  2949.3683696725884,
#  2956.276113276726,
#  2949.36381539914,
#  2953.0756235443123,
#  2965.3892173512086,
#  2959.4171519937945,
#  2962.9714733308633,
#  2962.7947135587942,
#  2975.3147231946564,
#  2962.5864144867255,
#  2958.357600969829,
#  2956.9704280041396,
#  2961.468729838795,
#  2964.716414076381,
#  2985.251421913278,
#  3002.0238932794855,
#  2990.0989863953473,
#  3012.9147647844857,
#  3009.239166442072,
#  3033.7175370358655,
#  3051.539822731555,
#  3047.0548755320724,
#  3054.308817551038,
#  3061.770060688624,
#  3069.7712893637968,
#  3077.087276349659,
#  3075.782695520694,
#  3069.862894885521,
#  3072.506319528797,
#  3054.4274339401763,
#  3046.034048518969,
#  3032.1525460617277,
#  3043.590288258107,
#  3048.23359491259,
#  3058.5386391293146,
#  3035.7759709329353,
#  3041.5285380853493,
#  3048.4928536313837,
#  3047.2263899644868,
#  3059.2674373460386,
#  3063.364452219142,
#  3043.2072279725903,
#  3041.0411029729353,
#  3040.156973036211,
#  3045.2464469803494,
#  3051.341554169143,
#  3051.981486796212,
#  3056.334348467074,
#  3065.3909011853502,
#  3071.945729773971,
#  3088.072792176902,
#  3079.0758498056953,
#  3082.6958745474194,
#  3085.170604114661,
#  3089.406853910695,
#  3106.5999221462125,
#  3111.83552187673,
#  3114.4948336679367,
#  3124.5472639527643,
#  3129.213518377247,
#  3136.529437344316,
#  3143.0389697681094,
#  3142.5745733031094,
#  3143.7110712720746,
#  3149.792757005178,
#  3162.404123183109,
#  3177.00865939035,
#  3193.685980595178,
#  3192.146989845523,
#  3197.6694653248333,
#  3200.2543037827645,
#  3191.3568708577645,
#  3193.9259994012127,
#  3184.4398213629365,
#  3184.7359837172467,
#  3181.1186042443155,
#  3176.910537576729,
#  3185.210962101039,
#  3182.5818029550046,
#  3187.8278387644873,
#  3177.9683849777634,
#  3178.4102465260394,
#  3185.2617005644875,
#  3214.522280620349,
#  3225.570791182246,
#  3238.4561326637977,
#  3252.2477938232805,
#  3263.122892719315,
#  3267.994562816039,
#  3269.7816496082805,
#  3274.990067406039,
#  3285.3133950850047,
#  3295.473597206901,
#  3302.6930078289697,
#  3292.1787150784526,
#  3288.656600789142,
#  3285.674801187418,
#  3293.969865223452,
#  3288.5402238839692,
#  3286.587547702245,
#  3283.0606673325897,
#  3294.6260387632797,
#  3305.1801595341417,
#  3304.747071017073,
#  3306.3927476572453,
#  3308.080050546556,
#  3318.308961424142,
#  3323.2871186655216,
#  3326.9567320660385,
#  3336.6562394377625,
#  3350.127873768452,
#  3356.8798736427625,
#  3372.7396236106933,
#  3355.0320862248313,
#  3354.344406022245,
#  3350.270931398969,
#  3357.853873335521,
#  3365.094156621555,
#  3365.180895769314,
#  3368.965476401038,
#  3376.8337730769,
#  3386.5135591618996,
#  3385.0446339713826,
#  3370.6275705724174,
#  3376.818975265521,
#  3387.2082736431075,
#  3387.8451165381075,
#  3386.8367037246594,
#  3382.208807814487,
#  3380.6006922567285,
#  3384.9636793793147,
#  3378.8723594100047,
#  3379.5955447112115,
#  3373.1049486453494,
#  3393.851666247591,
#  3416.2927948653496,
#  3425.288279545522,
#  3422.3972406141424,
#  3415.4788168367286,
#  3420.260426860694,
#  3412.684956152763,
#  3414.8746513158667,
#  3421.3365384936255,
#  3420.7200681608665,
#  3430.190124768625,
#  3423.4025724248318,
#  3432.6439786477627,
#  3439.8552792160385,
#  3454.86543023328,
#  3459.622520636556,
#  3461.995689178625,
#  3489.290947621901,
#  3488.8921929193148,
#  3501.401156507763,
#  3496.540860862418,
#  3509.180722001384,
#  3509.836944756384,
#  3503.3487596174186,
#  3529.3338967365567,
#  3520.5595122263844,
#  3532.5501771227637,
#  3532.214016379488,
#  3536.892046755522,
#  3539.885636278281,
#  3539.5313976239704,
#  3544.7725972987982,
#  3541.4229138269015,
#  3543.412946117591,
#  3554.0425661055224,
#  3564.3134899719016,
#  3571.9021245900053,
#  3581.6776711265575,
#  3575.6350839601782,
#  3558.7514893448338,
#  3559.163548450696,
#  3559.922997089834,
#  3563.93236974242,
#  3559.9355281436274,
#  3561.922422313972,
#  3565.6847931019033,
#  3565.6975710574206,
#  3568.8522453072483,
#  3584.7277320238,
#  3580.705564127248,
#  3577.6713861138,
#  3595.7105125819035,
#  3604.751375609317,
#  3598.197018475007,
#  3586.4086390943176,
#  3599.9378188163864,
#  3621.0622314831103,
#  3627.7443698162137,
#  3614.6030832067313,
#  3617.840739425869,
#  3605.6625869151794,
#  3606.8968339293174,
#  3608.0731528472484,
#  3625.339259356731,
#  3612.8196169191447,
#  3617.672844084317,
#  3620.0395867901793,
#  3602.3867060243174,
#  3614.558518044317,
#  3611.5288306881102,
#  3626.02156996949,
#  3629.3369016872484,
#  3633.2547969022485,
#  3633.335368332938,
#  3626.818261313283,
#  3624.270245772249,
#  3616.4793883229386,
#  3611.3418992736283,
#  3615.1377371501803,
#  3599.6881880506976,
#  3595.3438871162152,
#  3588.248745248629,
#  3585.400288568629,
#  3616.2998980539737,
#  3618.0867257841464,
#  3629.6339605972503,
#  3633.216582150526,
#  3653.8549915306985,
#  3664.4543294534574,
#  3659.0216956789745,
#  3663.8285269319053,
#  3672.0460948210434,
#  3694.6018697031127,
#  3693.8042459653543,
#  3711.9012061829403,
#  3701.9801395825957,
#  3696.635560063975,
#  3693.6224741900096,
#  3693.303697907423,
#  3713.725352560354,
#  3705.2069044555265,
#  3697.9816733105263,
#  3705.888115265354,
#  3717.468534717423,
#  3726.9797757453543,
#  3725.271142131044,
#  3730.2272852488027,
#  3746.5834704925956,
#  3740.4159424005265,
#  3743.868852647423,
#  3739.295947629837,
#  3730.468518050009,
#  3730.5945719163883,
#  3717.422093532078,
#  3735.207289624492,
#  3745.5938505843196,
#  3745.0470902103543,
#  3755.4109076720783,
#  3759.3077751662163,
#  3763.6850194850094,
#  3765.662134172596,
#  3768.6766218032853,
#  3761.6580713153544,
#  3774.00681132432,
#  3784.06685814432,
#  3776.206255495182,
#  3772.053752811217,
#  3754.7183638856995,
#  3738.2001632762167,
#  3746.638745808458,
#  3754.675896606389,
#  3770.0010623519065,
#  3768.3144635522513,
#  3777.688045798458,
#  3770.0246358553545,
#  3770.84257373501,
#  3780.348603472596,
#  3777.8850895998376,
#  3784.343685309148,
#  3792.507792646217,
#  3794.2130353241478,
#  3781.261618478113,
#  3781.448476509665,
#  3779.5469872424237,
#  3777.2252014794926,
#  3771.873626251389,
#  3767.571007806389,
#  3748.530421126561,
#  3748.1675362898372,
#  3742.5762387565615,
#  3742.060938169665,
#  3745.9789827089753,
#  3741.3920917677688,
#  3756.951806832079,
#  3752.8857517700103,
#  3750.5544467210448,
#  3756.027321109838,
#  3751.0517173758726,
#  3756.227764981045,
#  3762.455535979493,
#  3766.93478425139,
#  3750.167628826735,
#  3759.260607646218,
#  3787.612148171735,
#  3785.2966147170796,
#  3798.0291303882864,
#  3800.0471751112173,
#  3809.011628568114,
#  3797.3260371769065,
#  3794.0887529743204,
#  3803.3314834548373,
#  3808.7760792136305,
#  3807.756132807596,
#  3819.3398213189753,
#  3822.9572819886303,
#  3835.7076214362164,
#  3838.619448999837,
#  3848.364704736561,
#  3862.144889924492,
#  3868.1080387570782,
#  3881.5780695641474,
#  3883.6699489788025,
#  3887.040797044492,
#  3876.4869651520785,
#  3861.9962888322507,
#  3858.812180846906,
#  3842.035322476733,
#  3837.475515611216,
#  3853.015156983285,
#  3841.7601991825954,
#  3842.998780924492,
#  3828.131354555699,
#  3848.706921185527,
#  3840.4406610527685,
#  3841.792445927941,
#  3853.3501952291476,
#  3861.3728707932855,
#  3863.6106181379405,
#  3869.1107411643197,
#  3873.3282823096647,
#  3891.19477521932,
#  3882.451324074837,
#  3889.045712542768,
#  3883.6565025372506,
#  3900.3830404322507,
#  3916.0735839379404,
#  3917.6722632613887,
#  3923.9422983475956,
#  3935.816763371389,
#  3939.9768569331127,
#  3949.666849360009,
#  3969.5169279769057,
#  3966.027293419664,
#  3967.673062385871,
#  3965.3158785427677,
#  3977.2003842027675,
#  3979.398890645009,
#  3988.4662679246644,
#  4009.8309776358715,
#  4024.487264335699,
#  4028.4463815055265,
#  4027.3728910275954,
#  4039.3004024346646,
#  4029.8030213458715,
#  4026.252165473975,
#  4028.00893571363,
#  4041.362125475699,
#  4034.993327307768,
#  4055.0600068336303,
#  4068.67548316932,
#  4062.7757971555275,
#  4067.1357007294932,
#  4080.2319585482865,
#  4075.3312565882866,
#  4075.196518945873,
#  4077.737204967252,
#  4070.161044864666,
#  4080.3476848539763,
#  4090.0360263455277,
#  4101.315011429493,
#  4105.124218632769,
#  4112.526362224148,
#  4110.249742682424,
#  4095.2412664019066,
#  4099.989555467424,
#  4081.9279310251827,
#  4093.247765092424,
#  4103.804424024321,
#  4096.5746586207,
#  4110.800927929148,
#  4113.450594785355,
#  4126.177417633631,
#  4148.868327745011,
#  4127.43817064501,
#  4130.946329022252,
#  4142.853302103804,
#  4141.961661940701,
#  4167.953857071735,
#  4164.167008418114,
#  4167.83078387639,
#  4173.041283454839,
#  4166.142589680701,
#  4167.024311995873,
#  4174.35300145277,
#  4165.88114770639,
#  4162.169155843459,
#  4161.546353267769,
#  4176.3153428175965,
#  4192.544809917941,
#  4190.079926152079,
#  4197.730171180182,
#  4220.05207005932,
#  4206.48957891794]

# %%
sub1=plt.subplot(1, 2, 1)##############################################################
iteration=[]
for i in range(0,999):
    iteration.append(i)

#在同一幅图片上画3条折线
A,=plt.plot(iteration,accumulative_constraint_violation,color = 'green',linewidth = '1.5',label='attack-free online primal-dual algorithm')


#设置图例并且设置图例的字体及大小
font1 = {
'size'   : 18,
}
#legend = plt.legend(handles=[A],prop=font1)
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=18)
 
#设置横纵坐标的名称以及对应字体格式
font2 = {
'size'   : 18,
}
plt.xlabel('T',font2)
plt.ylabel(r'Constraint violation $Fit(T)$',font2)
plt.title('varying $D_{t}$',font2) 

sub2=plt.subplot(1, 2, 2)##############################################################
iteration=[]
for i in range(0,999):
    iteration.append(i)

#在同一幅图片上画3条折线
A,=plt.plot(iteration,accumulative_constraint_violation_T,color = 'green',linewidth = '1.5',label='attack-free online primal-dual algorithm')


#设置图例并且设置图例的字体及大小
font1 = {
'size'   : 18,
}
#legend = plt.legend(handles=[A],prop=font1)
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=18)
 
#设置横纵坐标的名称以及对应字体格式
font2 = {
'size'   : 18,
}
plt.xlabel('T',font2)
plt.ylabel(r'Constraint violation $Fit(T)/T$',font2)
plt.title('varying $D_{t}$',font2) 

plt.legend(handles=[A],prop={'size':18},loc="upper center", bbox_to_anchor=[-0.3, -0.2],
           ncol=18, shadow=True, fancybox=True)

plt.subplots_adjust(wspace=0.5,hspace=0.5) 
plt.gcf().set_size_inches((15, 5))


#plt.savefig('./figures/01-figure2_constraint_violation_attack_free_varying_D.pdf',format='pdf', bbox_inches='tight')
#plt.savefig('./figures/01-figure2_constraint_violation_attack_free_varying_D.png',format='png', bbox_inches='tight')
