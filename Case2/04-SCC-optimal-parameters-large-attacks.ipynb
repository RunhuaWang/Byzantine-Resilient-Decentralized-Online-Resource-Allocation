# %% [raw]
# SCC鲁棒的decentralized online economic dispatch algorithm+大值攻击
#
# 实验设置：IEEE118bus+6个风能发电站
# 发电站数量：54个传统火力发电站+6个风能发电站
# 时变的变量：1. 风速服从的weibull分布的尺度参数c
# 2. 风速服从的weibull分布的形状参数wk
# 3. 用户侧的平均用电需求D
# 尺度参数c和形状参数wk采用真实数据集数据
# 平均用电需求D服从均值为100 均方差为10的正态分布
# 54个传统火力发电站的发电成本相关数据见数据集
# 传统火力发电站成本函数：a+bP+cP^2
# 6个风能发电站的发电成本相关参数见论文手稿
#
# 选择两个拜占庭发电站 一个为54号火力发电站 一个为58号风能发电站
#
# 大值攻击 拜占庭发电站向邻居发送大值的对偶攻击 -0.01
#
# SCC+adaptive clipping

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
from sympy import *
import math 
from datetime import datetime
from scipy.special import gamma, factorial
import scipy.special as sc

# %%
#定义变量
thermal_power_station_strategy=np.zeros(shape=(54,1000)) 
wind_power_station_strategy=np.zeros(shape=(6,1000))
thermal_power_station_dual_variable=np.zeros(shape=(54,1000))
wind_power_station_dual_variable=np.zeros(shape=(6,1000))
E=np.loadtxt("IEEE-118-doubly-stochastic-weight-matrix.txt")
thermal_power_station_cost=np.zeros(shape=(1,1000)) #火力发电成本
wind_power_station_cost=np.zeros(shape=(1,1000)) #风力发电成本
sum_cost=np.zeros(shape=(1,1000)) #总发电成本
sum_thermal_wind_power_station_strategy=np.zeros(shape=(1,1000))#总发电量
#火力发电站的相关数据  其中54号为拜占庭
generator_a_values= np.loadtxt("./real-data/generator_a_values.txt")#每个agent的成本函数中的超参数a
generator_b_values= np.loadtxt("./real-data/generator_b_values.txt")#每个agent的成本函数中的超参数a
generator_c_values= np.loadtxt("./real-data/generator_c_values.txt")#每个agent的成本函数中的超参数a
thermal_power_station_P_max= np.loadtxt("./real-data/generator_Pmax_values.txt")#每个agent的资源量的上界
thermal_power_station_P_min= np.loadtxt("./real-data/generator_Pmin_values.txt")#每个agent的资源量的下界
#55 56 57 58 59 60号诚实风能的成本相关数据 其中58号为拜占庭 
wind_power_station_varphi=[1,6,1,6,1,6]
wind_power_station_v_in=[3,4,5,3,4,5]
wind_power_station_v_out=[25,45,25,45,25,45]
wind_power_station_v_r=[13,15,16,13,15,16]
wind_power_station_sigma_ue=[3,5,3,5,3,5]
wind_power_station_sigma_oe=[20,30,20,30,20,30]
wind_power_station_P_r=[150,160,150,160,150,160]
wind_power_station_P_min=[0,0,0,0,0,0]
wind_power_station_P_max=[500,300,400,200,300,200]
#不确定性的参数 时变参数
d_power_demand=np.loadtxt("./data/d_power_demand_normal_distribution_(100,10).txt") #时变的需求侧用电需求  
c_wind_speed= np.loadtxt("./real-data/weibull_scale_c.txt")      
kappa_wind_speed= np.loadtxt("./real-data/weibull_shape_wk.txt") 
#迭代步长
step_size_primal=5
step_size_dual=5
#正则化参数
regularization_parameter=0.00001
#每个用户在每次迭代中均需要计算出一个tau值
tau_robust1=np.zeros(shape=(60,1000))

# %%
#变量初始化
#火力，风力发电策略初始化 诚实
'''for i in range(0,53):
    thermal_power_station_strategy[i][0]=0
for j in range(0,6):
    if j!=3:
        wind_power_station_strategy[j][0]=0'''
for i in range(0,53):
    thermal_power_station_strategy[i][0]=thermal_power_station_P_max[i]
for j in range(0,6):
    if j!=3:
        wind_power_station_strategy[j][0]=thermal_power_station_P_max[j]
        
#拜占庭发电站发电策略初始化 拜占庭
thermal_power_station_strategy[53][0]=0
wind_power_station_strategy[3][0]=0
#诚实用户的初始总发电策略
'''sum_thermal_wind_power_station_strategy[0][0]=0'''
#诚实用户的初始总发电策略
for i in range(0,53):
    sum_thermal_wind_power_station_strategy[0][0]+=thermal_power_station_strategy[i][0]
for j in range(0,6):
    if j!=3:
        sum_thermal_wind_power_station_strategy[0][0]+= wind_power_station_strategy[j][0]

#火力，风力对偶策略初始化 诚实
for i in range(0,53):
    thermal_power_station_dual_variable[i][0]=-1000
for j in range(0,6):
    if j!=3:
        wind_power_station_dual_variable[j][0]=-1000
#拜占庭发电站对偶策略初始化 拜占庭
thermal_power_station_dual_variable[53][0]=-0.01
wind_power_station_dual_variable[3][0]=-0.01

#安全发电站的初始总发电成本 诚实
#火力发电成本
for i in range(0,53):
    thermal_power_station_cost[0][0]=thermal_power_station_cost[0][0]+generator_c_values[i]*thermal_power_station_strategy[i][0]*thermal_power_station_strategy[i][0]+generator_b_values[i]*thermal_power_station_strategy[i][0]+generator_a_values[i]
#风力发电成本
for i in range(0,6):
    if i!=3:
        wind_power_station_cost[0][0]=wind_power_station_cost[0][0]+wind_power_station_varphi[i]*wind_power_station_strategy[i][0]+wind_power_station_sigma_ue[i]*((wind_power_station_P_r[i]-wind_power_station_strategy[i][0])*(math.exp(-(math.pow(wind_power_station_v_r[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0])))-math.exp(-(math.pow(wind_power_station_v_out[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0]))))+(wind_power_station_P_r[i]*wind_power_station_v_in[i]/(wind_power_station_v_r[i]-wind_power_station_v_in[i])+wind_power_station_strategy[i][0])*(math.exp(-(math.pow(wind_power_station_v_r[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0])))-math.exp(-(math.pow(wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][0])/wind_power_station_P_r[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0]))))+(wind_power_station_P_r[i]*c_wind_speed[0]/(wind_power_station_v_r[i]-wind_power_station_v_in[i]))*(sc.gammaincc(1+1/kappa_wind_speed[0],(math.pow(wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][0])/wind_power_station_P_r[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0])))*sc.gamma(1+1/kappa_wind_speed[0])-sc.gammaincc(1+1/kappa_wind_speed[0],math.pow(wind_power_station_v_r[i]/c_wind_speed[0],kappa_wind_speed[0]))*sc.gamma(1+1/kappa_wind_speed[0])))+wind_power_station_sigma_oe[i]*((wind_power_station_strategy[i][0])*(1-math.exp(-(math.pow(wind_power_station_v_in[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0])))+math.exp(-(math.pow(wind_power_station_v_out[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0]))))+(wind_power_station_P_r[i]*wind_power_station_v_in[i]/(wind_power_station_v_r[i]-wind_power_station_v_in[i])+wind_power_station_strategy[i][0])*(math.exp(-(math.pow(wind_power_station_v_in[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0])))-math.exp(-(math.pow(wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][0])/wind_power_station_P_r[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0]))))+(wind_power_station_P_r[i]*c_wind_speed[0]/(wind_power_station_v_r[i]-wind_power_station_v_in[i]))*(sc.gammaincc(1+1/kappa_wind_speed[0],(math.pow(wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][0])/wind_power_station_P_r[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0])))*sc.gamma(1+1/kappa_wind_speed[0])-sc.gammaincc(1+1/kappa_wind_speed[0],math.pow(wind_power_station_v_in[i]/c_wind_speed[0],kappa_wind_speed[0]))*sc.gamma(1+1/kappa_wind_speed[0])))
#发电总成本
sum_cost[0][0]=thermal_power_station_cost[0][0]+wind_power_station_cost[0][0]

#计算每个发电站的邻居发电站
neighbor_robust1_help=[]
for i in range (0,60):
    for j in range (0,60):
        if E[i][j]!=0:
            neighbor_robust1_help.append(j)
        elif E[i][j]==0:
            neighbor_robust1_help.append(99)
neighbor_robust1=np.array(neighbor_robust1_help).reshape(60,60)

#计算安全的发电站的拜占庭邻居用户数量
q_robust1=[]
for i in range(0,60):
    q_robust1_help=0
    for j in range(0,60):
        if neighbor_robust1[i][j]==53 or neighbor_robust1[i][j]==57:
            q_robust1_help=q_robust1_help+1
    q_robust1.append(q_robust1_help)

# %%
def SCC_Byzantine_attack_decentralized_economic_dispatch(thermal_power_station_strategy,wind_power_station_strategy,c_wind_speed,kappa_wind_speed,d_power_demand,thermal_power_station_dual_variable,wind_power_station_dual_variable,E,thermal_power_station_cost,wind_power_station_cost,generator_a_values,generator_b_values,generator_c_values,thermal_power_station_P_min,thermal_power_station_P_max,wind_power_station_varphi,wind_power_station_sigma_ue,wind_power_station_sigma_oe,wind_power_station_P_min,wind_power_station_P_max,sum_thermal_wind_power_station_strategy,step_size_primal,step_size_dual):
    #显示初始化的数据
    #输出初始状态的原变量和对偶变量
    print("***************************large_attack_online_decentralized_economic_dispatch*****************************")
    print("相关变量初始值为：")
    for i in range (0,52):
        print("第",(i+1),"个火力发电站的初始计划发电量为:",thermal_power_station_strategy[i][0])
    for i in range (0,6):
        if i!=3:
            print("第",(i+55),"个风力发电站的初始计划发电量为:",wind_power_station_strategy[i][0])
    print("****************************************************************************")
    for i in range (0,52):
        print("第",(i+1),"个火力发电站的初始对偶变量为:",thermal_power_station_dual_variable[i][0])
    for i in range (0,6):
        if i!=3:
            print("第",(i+55),"个风力发电站的初始对偶变量为:",wind_power_station_dual_variable[i][0])
    print("****************************************************************************")
    print("第",(54),"个受到Byzantin攻击的火力发电站的初始对偶变量为:",thermal_power_station_dual_variable[53][0])
    print("第",(58),"个受到Byzantin攻击的风力发电站的初始对偶变量为:",wind_power_station_dual_variable[3][0])
    print("****************************************************************************")
    print("安全发电站的初始总发电量:",sum_thermal_wind_power_station_strategy[0][0])
    print("*************************")
    print("需求侧平均用电需求:",d_power_demand[0])
    print("****************************************************************************")
    print("风速分布参数c:",c_wind_speed[0])
    print("****************************************************************************")
    print("风速分布参数kappa:",kappa_wind_speed[0])
    print("****************************************************************************")
    print("安全发电站的总发电成本：", sum_cost[0][0])
    print("****************************************************************************")
    print("原变量迭代步长为:",step_size_primal)
    print("*****************************************************************************")
    print("对偶变量迭代步长为:",step_size_dual)
    print("*****************************************************************************")
    
    #开始迭代
    for k in range(1,1000):
        #发电站更新计划发电量和对偶变量
        #对偶变量 先做梯度上升 再做聚合
        dual_variable_intermediate=[] #存放当前迭代中60个用户对对偶变量做完梯度下降后得到的中间值
        for i in range(0,53):
            dual_variable_intermediate.append(thermal_power_station_dual_variable[i][k-1]+step_size_dual*((1/60)*thermal_power_station_strategy[i][k-1]-(1/60)*d_power_demand[k-1]-regularization_parameter*thermal_power_station_dual_variable[i][k-1]))
        #添加拜占庭火力发电站的对偶值
        dual_variable_intermediate.append(thermal_power_station_dual_variable[53][k-1])
        for j in range(0,6):
            if j==3: #添加拜占庭风力发电站的对偶值
                dual_variable_intermediate.append(wind_power_station_dual_variable[j][k-1])
            else:
                dual_variable_intermediate.append(wind_power_station_dual_variable[j][k-1]+step_size_dual*((1/60)*wind_power_station_strategy[j][k-1]-(1/60)*d_power_demand[k-1]-regularization_parameter*wind_power_station_dual_variable[j][k-1]))
        
        #TM鲁棒聚合+adaptive clipping 安全的火力发电站的对偶更新
        #在做鲁棒聚合前 对收集到的信息进行adaptive clipping的剪裁操作
        for i in range (0,53):
            u_neighbor_help_robust1=neighbor_robust1[i].tolist()#将用户i的邻居序号存在辅助变量u中
            u_neighbor_help_robust1 = list(set(u_neighbor_help_robust1))
            u_neighbor_help_robust1.remove(99)
            if int(q_robust1[i])==1: #只有具有拜占庭邻居的用户才需要先进行adaptive clipping和后续的IOS聚合操作
                #先进行adaptive clipping
                dual_variable_intermediate_auxiliary=[]
                #注意必须以这样的方式赋值 不能直接写dual_variable_intermediate_auxiliary=dual_variable_intermediate
                #不然在修改变量dual_variable_intermediate_auxiliary的同时也会对dual_variable_intermediate进行修改
                for j in range(len(dual_variable_intermediate)): 
                    dual_variable_intermediate_auxiliary.append(dual_variable_intermediate[j])
                dual_variable_receive=[]
                clipping_C=0
                for j in range(0, len(u_neighbor_help_robust1)):
                    dual_variable_receive.append(dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[j]])
                dual_variable_receive.sort()
                clipping_C=-dual_variable_receive[1] #确定clpping的阈值
                #接下来对大于clipping_C的值进行clipping
                for j in range(0, len(u_neighbor_help_robust1)):
                    if -dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[j]]>clipping_C:
                        dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[j]]=-clipping_C
                #接下来做SCC鲁棒聚合   
                c_clipping_dual_robust1=[]#存放当前诚实用户对邻居的对偶变量裁剪后的值
                mix_sum_c_dual_robust1=0#存放clipping后的对偶值和  
                u_neighbor_help_robust1.remove(i)
                weight_sum_robust1=0
                for j in range(0,len(u_neighbor_help_robust1)):
                    if u_neighbor_help_robust1[j]!=53 and u_neighbor_help_robust1[j]!=57:
                        weight_sum_robust1=weight_sum_robust1+E[i][u_neighbor_help_robust1[j]]*(dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[j]]-dual_variable_intermediate_auxiliary[i])*(dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[j]]-dual_variable_intermediate_auxiliary[i])
                tau_robust1[i][k]=sqrt(weight_sum_robust1/(E[i][53]+E[i][57])) 
                #每个诚实用户首先对邻居传来的对偶变量进行剪裁clipping
                for j in range (0, len(u_neighbor_help_robust1)): #问题：分母会出现0的情况
                    if (dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[j]]-dual_variable_intermediate_auxiliary[i])==0:
                        c_clipping_dual_robust1.append(0)
                    elif 1<=(tau_robust1[i][k]/(abs((dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[j]]-dual_variable_intermediate_auxiliary[i])))):
                        c_clipping_dual_robust1.append(dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[j]]-dual_variable_intermediate_auxiliary[i])
                    else:
                        c_clipping_dual_robust1.append((dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[j]]-dual_variable_intermediate_auxiliary[i])*((tau_robust1[i][k]/(abs((dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[j]]-dual_variable_intermediate_auxiliary[i]))))))
                #诚实用户聚合clipping后的邻居对偶值和自身的对偶值 
                for j in range(0,len(u_neighbor_help_robust1)):
                    mix_sum_c_dual_robust1=mix_sum_c_dual_robust1+E[i][u_neighbor_help_robust1[j]]*(dual_variable_intermediate_auxiliary[i]+c_clipping_dual_robust1[j])            
                #诚实用户基于SCC鲁棒聚合后的值进行自身的对偶变量的更新
                thermal_power_station_dual_variable[i][k]=E[i][i]*dual_variable_intermediate_auxiliary[i]+mix_sum_c_dual_robust1               
            else: #没有拜占庭邻居的用户直接进行权重聚合即可
                for j in range(0,len(u_neighbor_help_robust1)):
                     thermal_power_station_dual_variable[i][k]=thermal_power_station_dual_variable[i][k]+E[i][u_neighbor_help_robust1[j]]*dual_variable_intermediate[u_neighbor_help_robust1[j]]

        #安全的风力发电站的adaptive clipping操作 由于风力发电站的邻居中没有拜占庭用户 所以不需要进行adaptive clipping的操作
        #聚合 安全的风力发电站的对偶更新
        for i in range(0,6):
            if i!=3:
                weight_aggregation_dual_variable=0
                for j in range(0,54):
                    weight_aggregation_dual_variable=weight_aggregation_dual_variable+E[i+54][j]*dual_variable_intermediate[j]               
                for j in range(0,6):
                    weight_aggregation_dual_variable=weight_aggregation_dual_variable+E[i+54][j+54]*dual_variable_intermediate[j+54]
                wind_power_station_dual_variable[i][k]=weight_aggregation_dual_variable 
        
        #受到Byzantine攻击的火力和风力发电站的对偶更新
        thermal_power_station_dual_variable[53][k]=thermal_power_station_dual_variable[53][k-1]
        wind_power_station_dual_variable[3][k]=wind_power_station_dual_variable[3][k-1]            
        
        #安全的火力发电站计划发电量
        for i in range(0,53):
            thermal_power_station_strategy[i][k]=thermal_power_station_strategy[i][k-1]-step_size_primal*(2*generator_c_values[i]*thermal_power_station_strategy[i][k-1]+generator_b_values[i]+(1/60)*thermal_power_station_dual_variable[i][k-1]) 
            if thermal_power_station_strategy[i][k]<=thermal_power_station_P_min[i]:
                thermal_power_station_strategy[i][k]=thermal_power_station_P_min[i]
            elif thermal_power_station_strategy[i][k]>=thermal_power_station_P_max[i]:
                thermal_power_station_strategy[i][k]=thermal_power_station_P_max[i]
        #安全的风力发电站计划发电量
        for i in range(0,6):
            if i!=3:
                wind_power_station_strategy[i][k]=wind_power_station_strategy[i][k-1]-step_size_primal*(wind_power_station_varphi[i]+wind_power_station_sigma_oe[i]+(wind_power_station_sigma_ue[i]+wind_power_station_sigma_oe[i])*math.exp(-(math.pow(wind_power_station_v_out[i],kappa_wind_speed[k-1]))/(math.pow(c_wind_speed[k-1],kappa_wind_speed[k-1])))+(-wind_power_station_sigma_ue[i]-wind_power_station_sigma_oe[i])*math.exp(-(math.pow((wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][k-1])/wind_power_station_P_r[i]),kappa_wind_speed[k-1]))/(math.pow(c_wind_speed[k-1],kappa_wind_speed[k-1])))+(1/60)*wind_power_station_dual_variable[i][k-1])
                if wind_power_station_strategy[i][k]<=wind_power_station_P_min[i]:
                    wind_power_station_strategy[i][k]=wind_power_station_P_min[i]
                elif wind_power_station_strategy[i][k]>=wind_power_station_P_max[i]:
                    wind_power_station_strategy[i][k]=wind_power_station_P_max[i]
        #受到Byzantine攻击的火力和风力发电站的计划发电量
        thermal_power_station_strategy[53][k]=thermal_power_station_strategy[53][k-1]
        wind_power_station_strategy[3][k]=wind_power_station_strategy[3][k-1]
        
        #安全发电站的计算总计划发电
        #火力发电量
        for i in range(0,53):
            sum_thermal_wind_power_station_strategy[0][k]=sum_thermal_wind_power_station_strategy[0][k]+thermal_power_station_strategy[i][k]
        #风力发电量
        for i in range(0,6):
            if i!=3:
                sum_thermal_wind_power_station_strategy[0][k]=sum_thermal_wind_power_station_strategy[0][k]+wind_power_station_strategy[i][k]
        
        #安全发电站的计算总发电成本
        #火力发电成本
        for i in range(0,53):
            thermal_power_station_cost[0][k]=thermal_power_station_cost[0][k]+generator_c_values[i]*thermal_power_station_strategy[i][k]*thermal_power_station_strategy[i][k]+generator_b_values[i]*thermal_power_station_strategy[i][k]+generator_a_values[i]
        #风力发电成本
        for i in range(0,6):
            if i!=3:
                wind_power_station_cost[0][k]=wind_power_station_cost[0][k]+wind_power_station_varphi[i]*wind_power_station_strategy[i][k]+wind_power_station_sigma_ue[i]*((wind_power_station_P_r[i]-wind_power_station_strategy[i][k])*(math.exp(-(math.pow(wind_power_station_v_r[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k])))-math.exp(-(math.pow(wind_power_station_v_out[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k]))))+(wind_power_station_P_r[i]*wind_power_station_v_in[i]/(wind_power_station_v_r[i]-wind_power_station_v_in[i])+wind_power_station_strategy[i][k])*(math.exp(-(math.pow(wind_power_station_v_r[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k])))-math.exp(-(math.pow(wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][k])/wind_power_station_P_r[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k]))))+(wind_power_station_P_r[i]*c_wind_speed[k]/(wind_power_station_v_r[i]-wind_power_station_v_in[i]))*(sc.gammaincc(1+1/kappa_wind_speed[k],(math.pow(wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][k])/wind_power_station_P_r[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k])))*sc.gamma(1+1/kappa_wind_speed[k])-sc.gammaincc(1+1/kappa_wind_speed[k],math.pow(wind_power_station_v_r[i]/c_wind_speed[k],kappa_wind_speed[k]))*sc.gamma(1+1/kappa_wind_speed[k])))+wind_power_station_sigma_oe[i]*((wind_power_station_strategy[i][k])*(1-math.exp(-(math.pow(wind_power_station_v_in[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k])))+math.exp(-(math.pow(wind_power_station_v_out[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k]))))+(wind_power_station_P_r[i]*wind_power_station_v_in[i]/(wind_power_station_v_r[i]-wind_power_station_v_in[i])+wind_power_station_strategy[i][k])*(math.exp(-(math.pow(wind_power_station_v_in[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k])))-math.exp(-(math.pow(wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][k])/wind_power_station_P_r[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k]))))+(wind_power_station_P_r[i]*c_wind_speed[k]/(wind_power_station_v_r[i]-wind_power_station_v_in[i]))*(sc.gammaincc(1+1/kappa_wind_speed[k],(math.pow(wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][k])/wind_power_station_P_r[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k])))*sc.gamma(1+1/kappa_wind_speed[k])-sc.gammaincc(1+1/kappa_wind_speed[k],math.pow(wind_power_station_v_in[i]/c_wind_speed[k],kappa_wind_speed[k]))*sc.gamma(1+1/kappa_wind_speed[k])))
        #发电总成本
        sum_cost[0][k]=thermal_power_station_cost[0][k]+wind_power_station_cost[0][k]
        
        #输出第k次迭代中的结果 每间隔10次迭代输出一次结果
        #if (k+1)%10==0:
        if k<=5:
            print(k,"次迭代中的结果：")
            for i in range (0,53):
                print("第",(i+1),"个火力发电站的计划发电量为:",thermal_power_station_strategy[i][k])
            for i in range (0,6):
                if i!=3:
                    print("第",(i+55),"个风力发电站的计划发电量为:",wind_power_station_strategy[i][k])
            print("****************************************************************************")
            for i in range (0,53):
                print("第",(i+1),"个火力发电站的对偶变量为:",thermal_power_station_dual_variable[i][k])
            for i in range (0,6):
                if i!=3:
                    print("第",(i+55),"个风力发电站的对偶变量为:",wind_power_station_dual_variable[i][k])
            print("****************************************************************************")
            print("第",(54),"个受到Byzantin攻击的火力发电站的初始对偶变量为:",thermal_power_station_dual_variable[53][k])
            print("第",(58),"个受到Byzantin攻击的风力发电站的初始对偶变量为:",wind_power_station_dual_variable[3][k])
            print("****************************************************************************")
            print("安全发电站的总发电量:",sum_thermal_wind_power_station_strategy[0][k])
            print("*************************")
            print("需求侧平均用电需求:",d_power_demand[k])
            print("****************************************************************************")
            print("风速分布参数c:",c_wind_speed[k])
            print("****************************************************************************")
            print("风速分布参数kappa:",kappa_wind_speed[k])
            print("****************************************************************************")        
            print("安全发电站的总发电成本：", sum_cost[0][k])
            print("****************************************************************************")
            print("原变量迭代步长为:",step_size_primal)
            print("****************************************************************************")
            print("对偶变量迭代步长为:",step_size_dual)
            print("****************************************************************************")

    print(datetime.now().strftime('%Y-%m-%d %H:%M:%S.%f')[:-3])
    return None

# %%
SCC_Byzantine_attack_decentralized_economic_dispatch(thermal_power_station_strategy,wind_power_station_strategy,c_wind_speed,kappa_wind_speed,d_power_demand,thermal_power_station_dual_variable,wind_power_station_dual_variable,E,thermal_power_station_cost,wind_power_station_cost,generator_a_values,generator_b_values,generator_c_values,thermal_power_station_P_min,thermal_power_station_P_max,wind_power_station_varphi,wind_power_station_sigma_ue,wind_power_station_sigma_oe,wind_power_station_P_min,wind_power_station_P_max,sum_thermal_wind_power_station_strategy,step_size_primal,step_size_dual)
# Out:
# ***************************large_attack_online_decentralized_economic_dispatch*****************************
# 相关变量初始值为：
# 第 1 个火力发电站的初始计划发电量为: 30.0
# 第 2 个火力发电站的初始计划发电量为: 30.0
# 第 3 个火力发电站的初始计划发电量为: 30.0
# 第 4 个火力发电站的初始计划发电量为: 300.0
# 第 5 个火力发电站的初始计划发电量为: 300.0
# 第 6 个火力发电站的初始计划发电量为: 30.0
# 第 7 个火力发电站的初始计划发电量为: 100.0
# 第 8 个火力发电站的初始计划发电量为: 30.0
# 第 9 个火力发电站的初始计划发电量为: 30.0
# 第 10 个火力发电站的初始计划发电量为: 300.0
# 第 11 个火力发电站的初始计划发电量为: 350.0
# 第 12 个火力发电站的初始计划发电量为: 30.0
# 第 13 个火力发电站的初始计划发电量为: 30.0
# 第 14 个火力发电站的初始计划发电量为: 100.0
# 第 15 个火力发电站的初始计划发电量为: 30.0
# 第 16 个火力发电站的初始计划发电量为: 100.0
# 第 17 个火力发电站的初始计划发电量为: 30.0
# 第 18 个火力发电站的初始计划发电量为: 30.0
# 第 19 个火力发电站的初始计划发电量为: 100.0
# 第 20 个火力发电站的初始计划发电量为: 250.0
# 第 21 个火力发电站的初始计划发电量为: 250.0
# 第 22 个火力发电站的初始计划发电量为: 100.0
# 第 23 个火力发电站的初始计划发电量为: 100.0
# 第 24 个火力发电站的初始计划发电量为: 200.0
# 第 25 个火力发电站的初始计划发电量为: 200.0
# 第 26 个火力发电站的初始计划发电量为: 100.0
# 第 27 个火力发电站的初始计划发电量为: 420.0
# 第 28 个火力发电站的初始计划发电量为: 420.0
# 第 29 个火力发电站的初始计划发电量为: 300.0
# 第 30 个火力发电站的初始计划发电量为: 80.0
# 第 31 个火力发电站的初始计划发电量为: 30.0
# 第 32 个火力发电站的初始计划发电量为: 30.0
# 第 33 个火力发电站的初始计划发电量为: 20.0
# 第 34 个火力发电站的初始计划发电量为: 100.0
# 第 35 个火力发电站的初始计划发电量为: 100.0
# 第 36 个火力发电站的初始计划发电量为: 300.0
# 第 37 个火力发电站的初始计划发电量为: 100.0
# 第 38 个火力发电站的初始计划发电量为: 30.0
# 第 39 个火力发电站的初始计划发电量为: 300.0
# 第 40 个火力发电站的初始计划发电量为: 200.0
# 第 41 个火力发电站的初始计划发电量为: 20.0
# 第 42 个火力发电站的初始计划发电量为: 50.0
# 第 43 个火力发电站的初始计划发电量为: 300.0
# 第 44 个火力发电站的初始计划发电量为: 300.0
# 第 45 个火力发电站的初始计划发电量为: 300.0
# 第 46 个火力发电站的初始计划发电量为: 20.0
# 第 47 个火力发电站的初始计划发电量为: 100.0
# 第 48 个火力发电站的初始计划发电量为: 100.0
# 第 49 个火力发电站的初始计划发电量为: 20.0
# 第 50 个火力发电站的初始计划发电量为: 50.0
# 第 51 个火力发电站的初始计划发电量为: 100.0
# 第 52 个火力发电站的初始计划发电量为: 100.0
# 第 55 个风力发电站的初始计划发电量为: 30.0
# 第 56 个风力发电站的初始计划发电量为: 30.0
# 第 57 个风力发电站的初始计划发电量为: 30.0
# 第 59 个风力发电站的初始计划发电量为: 300.0
# 第 60 个风力发电站的初始计划发电量为: 30.0
# ****************************************************************************
# 第 1 个火力发电站的初始对偶变量为: -1000.0
# 第 2 个火力发电站的初始对偶变量为: -1000.0
# 第 3 个火力发电站的初始对偶变量为: -1000.0
# 第 4 个火力发电站的初始对偶变量为: -1000.0
# 第 5 个火力发电站的初始对偶变量为: -1000.0
# 第 6 个火力发电站的初始对偶变量为: -1000.0
# 第 7 个火力发电站的初始对偶变量为: -1000.0
# 第 8 个火力发电站的初始对偶变量为: -1000.0
# 第 9 个火力发电站的初始对偶变量为: -1000.0
# 第 10 个火力发电站的初始对偶变量为: -1000.0
# 第 11 个火力发电站的初始对偶变量为: -1000.0
# 第 12 个火力发电站的初始对偶变量为: -1000.0
# 第 13 个火力发电站的初始对偶变量为: -1000.0
# 第 14 个火力发电站的初始对偶变量为: -1000.0
# 第 15 个火力发电站的初始对偶变量为: -1000.0
# 第 16 个火力发电站的初始对偶变量为: -1000.0
# 第 17 个火力发电站的初始对偶变量为: -1000.0
# 第 18 个火力发电站的初始对偶变量为: -1000.0
# 第 19 个火力发电站的初始对偶变量为: -1000.0
# 第 20 个火力发电站的初始对偶变量为: -1000.0
# 第 21 个火力发电站的初始对偶变量为: -1000.0
# 第 22 个火力发电站的初始对偶变量为: -1000.0
# 第 23 个火力发电站的初始对偶变量为: -1000.0
# 第 24 个火力发电站的初始对偶变量为: -1000.0
# 第 25 个火力发电站的初始对偶变量为: -1000.0
# 第 26 个火力发电站的初始对偶变量为: -1000.0
# 第 27 个火力发电站的初始对偶变量为: -1000.0
# 第 28 个火力发电站的初始对偶变量为: -1000.0
# 第 29 个火力发电站的初始对偶变量为: -1000.0
# 第 30 个火力发电站的初始对偶变量为: -1000.0
# 第 31 个火力发电站的初始对偶变量为: -1000.0
# 第 32 个火力发电站的初始对偶变量为: -1000.0
# 第 33 个火力发电站的初始对偶变量为: -1000.0
# 第 34 个火力发电站的初始对偶变量为: -1000.0
# 第 35 个火力发电站的初始对偶变量为: -1000.0
# 第 36 个火力发电站的初始对偶变量为: -1000.0
# 第 37 个火力发电站的初始对偶变量为: -1000.0
# 第 38 个火力发电站的初始对偶变量为: -1000.0
# 第 39 个火力发电站的初始对偶变量为: -1000.0
# 第 40 个火力发电站的初始对偶变量为: -1000.0
# 第 41 个火力发电站的初始对偶变量为: -1000.0
# 第 42 个火力发电站的初始对偶变量为: -1000.0
# 第 43 个火力发电站的初始对偶变量为: -1000.0
# 第 44 个火力发电站的初始对偶变量为: -1000.0
# 第 45 个火力发电站的初始对偶变量为: -1000.0
# 第 46 个火力发电站的初始对偶变量为: -1000.0
# 第 47 个火力发电站的初始对偶变量为: -1000.0
# 第 48 个火力发电站的初始对偶变量为: -1000.0
# 第 49 个火力发电站的初始对偶变量为: -1000.0
# 第 50 个火力发电站的初始对偶变量为: -1000.0
# 第 51 个火力发电站的初始对偶变量为: -1000.0
# 第 52 个火力发电站的初始对偶变量为: -1000.0
# 第 55 个风力发电站的初始对偶变量为: -1000.0
# 第 56 个风力发电站的初始对偶变量为: -1000.0
# 第 57 个风力发电站的初始对偶变量为: -1000.0
# 第 59 个风力发电站的初始对偶变量为: -1000.0
# 第 60 个风力发电站的初始对偶变量为: -1000.0
# ****************************************************************************
# 第 54 个受到Byzantin攻击的火力发电站的初始对偶变量为: -0.01
# 第 58 个受到Byzantin攻击的风力发电站的初始对偶变量为: -0.01
# ****************************************************************************
# 安全发电站的初始总发电量: 7590.0
# *************************
# 需求侧平均用电需求: 78.10342674
# ****************************************************************************
# 风速分布参数c: 8.36374925
# ****************************************************************************
# 风速分布参数kappa: 2.53999996
# ****************************************************************************
# 安全发电站的总发电成本： 128026.41839387035
# ****************************************************************************
# 原变量迭代步长为: 5
# *****************************************************************************
# 对偶变量迭代步长为: 5
# *****************************************************************************
# 1 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 5.0
# 第 2 个火力发电站的计划发电量为: 5.0
# 第 3 个火力发电站的计划发电量为: 5.0
# 第 4 个火力发电站的计划发电量为: 286.27083333333337
# 第 5 个火力发电站的计划发电量为: 286.27083333333337
# 第 6 个火力发电站的计划发电量为: 10.0
# 第 7 个火力发电站的计划发电量为: 81.43333333333334
# 第 8 个火力发电站的计划发电量为: 5.0
# 第 9 个火力发电站的计划发电量为: 5.0
# 第 10 个火力发电站的计划发电量为: 286.27083333333337
# 第 11 个火力发电站的计划发电量为: 350.0
# 第 12 个火力发电站的计划发电量为: 8.0
# 第 13 个火力发电站的计划发电量为: 8.0
# 第 14 个火力发电站的计划发电量为: 81.43333333333334
# 第 15 个火力发电站的计划发电量为: 8.0
# 第 16 个火力发电站的计划发电量为: 81.43333333333334
# 第 17 个火力发电站的计划发电量为: 8.0
# 第 18 个火力发电站的计划发电量为: 8.0
# 第 19 个火力发电站的计划发电量为: 81.43333333333334
# 第 20 个火力发电站的计划发电量为: 250.0
# 第 21 个火力发电站的计划发电量为: 250.0
# 第 22 个火力发电站的计划发电量为: 81.43333333333334
# 第 23 个火力发电站的计划发电量为: 81.43333333333334
# 第 24 个火力发电站的计划发电量为: 200.0
# 第 25 个火力发电站的计划发电量为: 200.0
# 第 26 个火力发电站的计划发电量为: 81.43333333333334
# 第 27 个火力发电站的计划发电量为: 417.1598333333333
# 第 28 个火力发电站的计划发电量为: 417.1598333333333
# 第 29 个火力发电站的计划发电量为: 286.27083333333337
# 第 30 个火力发电站的计划发电量为: 49.24093333333333
# 第 31 个火力发电站的计划发电量为: 10.0
# 第 32 个火力发电站的计划发电量为: 5.0
# 第 33 个火力发电站的计划发电量为: 5.0
# 第 34 个火力发电站的计划发电量为: 81.43333333333334
# 第 35 个火力发电站的计划发电量为: 81.43333333333334
# 第 36 个火力发电站的计划发电量为: 286.27083333333337
# 第 37 个火力发电站的计划发电量为: 81.43333333333334
# 第 38 个火力发电站的计划发电量为: 10.0
# 第 39 个火力发电站的计划发电量为: 300.0
# 第 40 个火力发电站的计划发电量为: 197.14583333333334
# 第 41 个火力发电站的计划发电量为: 8.0
# 第 42 个火力发电站的计划发电量为: 20.0
# 第 43 个火力发电站的计划发电量为: 286.27083333333337
# 第 44 个火力发电站的计划发电量为: 286.27083333333337
# 第 45 个火力发电站的计划发电量为: 286.27083333333337
# 第 46 个火力发电站的计划发电量为: 8.0
# 第 47 个火力发电站的计划发电量为: 81.43333333333334
# 第 48 个火力发电站的计划发电量为: 81.43333333333334
# 第 49 个火力发电站的计划发电量为: 8.0
# 第 50 个火力发电站的计划发电量为: 25.0
# 第 51 个火力发电站的计划发电量为: 81.43333333333334
# 第 52 个火力发电站的计划发电量为: 81.43333333333334
# 第 53 个火力发电站的计划发电量为: 81.43333333333334
# 第 55 个风力发电站的计划发电量为: 96.0606966394501
# 第 56 个风力发电站的计划发电量为: 45.858623968776264
# 第 57 个风力发电站的计划发电量为: 66.39186374339273
# 第 59 个风力发电站的计划发电量为: 278.3333241455708
# 第 60 个风力发电站的计划发电量为: 24.617138138286876
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -1003.958618895
# 第 2 个火力发电站的对偶变量为: -1001.590197795
# 第 3 个火力发电站的对偶变量为: -995.8395365700114
# 第 4 个火力发电站的对偶变量为: -983.0103430949999
# 第 5 个火力发电站的对偶变量为: -994.798875840839
# 第 6 个火力发电站的对偶变量为: -996.4161431137586
# 第 7 个火力发电站的对偶变量为: -995.2013178429195
# 第 8 个火力发电站的对偶变量为: -1003.2723443783333
# 第 9 个火力发电站的对偶变量为: -998.2126881804137
# 第 10 个火力发电站的对偶变量为: -995.9331198970802
# 第 11 个火力发电站的对偶变量为: -994.2122699387472
# 第 12 个火力发电站的对偶变量为: -998.9702739699999
# 第 13 个火力发电站的对偶变量为: -995.4595750908389
# 第 14 个火力发电站的对偶变量为: -998.8675158054136
# 第 15 个火力发电站的对偶变量为: -994.7972061620354
# 第 16 个火力发电站的对偶变量为: -996.6553741970805
# 第 17 个火力发电站的对偶变量为: -998.8923036533332
# 第 18 个火力发电站的对偶变量为: -1001.1380961054138
# 第 19 个火力发电站的对偶变量为: -984.4325188269851
# 第 20 个火力发电站的对偶变量为: -983.2004557228688
# 第 21 个火力发电站的对偶变量为: -991.8218568304139
# 第 22 个火力发电站的对偶变量为: -994.0654565616665
# 第 23 个火力发电站的对偶变量为: -994.0654565616667
# 第 24 个火力发电站的对偶变量为: -991.885949457494
# 第 25 个火力发电站的对偶变量为: -991.0617935449998
# 第 26 个火力发电站的对偶变量为: -986.8432341616667
# 第 27 个火力发电站的对偶变量为: -984.9879970047059
# 第 28 个火力发电站的对偶变量为: -981.2571537533333
# 第 29 个火力发电站的对偶变量为: -985.9514500484518
# 第 30 个火力发电站的对偶变量为: -1000.5293159970804
# 第 31 个火力发电站的对偶变量为: -1003.958618895
# 第 32 个火力发电站的对偶变量为: -1003.2010431449999
# 第 33 个火力发电站的对偶变量为: -1002.8424472637471
# 第 34 个火力发电站的对偶变量为: -999.1858816304137
# 第 35 个火力发电站的对偶变量为: -993.1252657241611
# 第 36 个火力发电站的对偶变量为: -980.1125987211965
# 第 37 个火力发电站的对偶变量为: -994.1690466970805
# 第 38 个火力发电站的对偶变量为: -992.1861420179196
# 第 39 个火力发电站的对偶变量为: -987.8871904199999
# 第 40 个火力发电站的对偶变量为: -996.6101440845863
# 第 41 个火力发电站的对偶变量为: -999.5062378783334
# 第 42 个火力发电站的对偶变量为: -999.5040734783335
# 第 43 个火力发电站的对偶变量为: -989.7919423304139
# 第 44 个火力发电站的对偶变量为: -981.4586090804138
# 第 45 个火力发电站的对偶变量为: -992.1252656658276
# 第 46 个火力发电站的对偶变量为: -998.1623126637472
# 第 47 个火力发电站的对偶变量为: -997.3845448616667
# 第 48 个火力发电站的对偶变量为: -1001.5115389429195
# 第 49 个火力发电站的对偶变量为: -999.7760792616668
# 第 50 个火力发电站的对偶变量为: -1000.4665653845861
# 第 51 个火力发电站的对偶变量为: -999.31576177
# 第 52 个火力发电站的对偶变量为: -999.31576177
# 第 53 个火力发电站的对偶变量为: -994.5150433262529
# 第 55 个风力发电站的对偶变量为: -1001.5902078345862
# 第 56 个风力发电站的对偶变量为: -1003.9586289345862
# 第 57 个风力发电站的对偶变量为: -998.9702639304138
# 第 59 个风力发电站的对偶变量为: -983.6808410616666
# 第 60 个风力发电站的对偶变量为: -998.5141645220805
# ****************************************************************************
# 第 54 个受到Byzantin攻击的火力发电站的初始对偶变量为: -0.01
# 第 58 个受到Byzantin攻击的风力发电站的初始对偶变量为: -0.01
# ****************************************************************************
# 安全发电站的总发电量: 6827.6347466354755
# *************************
# 需求侧平均用电需求: 85.73204703
# ****************************************************************************
# 风速分布参数c: 8.41212693
# ****************************************************************************
# 风速分布参数kappa: 2.44000006
# ****************************************************************************
# 安全发电站的总发电成本： 107815.48929545822
# ****************************************************************************
# 原变量迭代步长为: 5
# ****************************************************************************
# 对偶变量迭代步长为: 5
# ****************************************************************************
# 2 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 5.0
# 第 2 个火力发电站的计划发电量为: 5.0
# 第 3 个火力发电站的计划发电量为: 5.0
# 第 4 个火力发电站的计划发电量为: 272.6189087995834
# 第 5 个火力发电站的计划发电量为: 273.60128652840325
# 第 6 个火力发电站的计划发电量为: 10.0
# 第 7 个火力发电站的计划发电量为: 64.84330982024329
# 第 8 个火力发电站的计划发电量为: 5.0
# 第 9 个火力发电站的计划发电量为: 5.0
# 第 10 个火力发电站的计划发电量为: 273.69580686642337
# 第 11 个火力发电站的计划发电量为: 350.0
# 第 12 个火力发电站的计划发电量为: 8.0
# 第 13 个火力发电站的计划发电量为: 8.0
# 第 14 个火力发电站的计划发电量为: 65.14882631711781
# 第 15 个火力发电站的计划发电量为: 8.0
# 第 16 个火力发电站的计划发电量为: 64.96448118309004
# 第 17 个火力发电站的计划发电量为: 8.0
# 第 18 个火力发电站的计划发电量为: 8.0
# 第 19 个火力发电站的计划发电量为: 63.945909902248744
# 第 20 个火力发电站的计划发电量为: 250.0
# 第 21 个火力发电站的计划发电量为: 250.0
# 第 22 个火力发电站的计划发电量为: 64.74865471347219
# 第 23 个火力发电站的计划发电量为: 64.7486547134722
# 第 24 个火力发电站的计划发电量为: 200.0
# 第 25 个火力发电站的计划发电量为: 200.0
# 第 26 个火力发电站的计划发电量为: 64.14680284680557
# 第 27 个火力发电站的计划发电量为: 413.3694400670588
# 第 28 个火力发电站的计划发电量为: 413.05853646277774
# 第 29 个火力发电站的计划发电量为: 272.86400104570436
# 第 30 个火力发电站的计划发电量为: 32.651462518423365
# 第 31 个火力发电站的计划发电量为: 10.0
# 第 32 个火力发电站的计划发电量为: 5.0
# 第 33 个火力发电站的计划发电量为: 5.0
# 第 34 个火力发电站的计划发电量为: 65.17535680253448
# 第 35 个火力发电站的计划发电量为: 64.67030547701343
# 第 36 个火力发电站的计划发电量为: 272.3774301017664
# 第 37 个火力发电站的计划发电量为: 64.7572872247567
# 第 38 个火力发电站的计划发电量为: 10.0
# 第 39 个火力发电站的计划发电量为: 300.0
# 第 40 个火力发电站的计划发电量为: 194.31956929871555
# 第 41 个火力发电站的计划发电量为: 8.0
# 第 42 个火力发电站的计划发电量为: 20.0
# 第 43 个火力发电站的计划发电量为: 273.1840420692012
# 第 44 个火力发电站的计划发电量为: 272.4895976317012
# 第 45 个火力发电站的计划发电量为: 273.37848568048565
# 第 46 个火力发电站的计划发电量为: 8.0
# 第 47 个火力发电站的计划发电量为: 65.02524540513889
# 第 48 个火力发电站的计划发电量为: 65.36916157857662
# 第 49 个火力发电站的计划发电量为: 8.0
# 第 50 个火力发电站的计划发电量为: 25.0
# 第 51 个火力发电站的计划发电量为: 65.1861801475
# 第 52 个火力发电站的计划发电量为: 65.1861801475
# 第 53 个火力发电站的计划发电量为: 64.78612027718773
# 第 55 个风力发电站的计划发电量为: 105.47657109754952
# 第 56 个风力发电站的计划发电量为: 38.784132328638265
# 第 57 个风力发电站的计划发电量为: 70.90991623364457
# 第 59 个风力发电站的计划发电量为: 255.30681865008378
# 第 60 个风力发电站的计划发电量为: 26.56229342586501
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -1007.7395871647825
# 第 2 个火力发电站的对偶变量为: -1003.835666825564
# 第 3 个火力发电站的对偶变量为: -992.9982986101973
# 第 4 个火力发电站的对偶变量为: -968.7508539199578
# 第 5 个火力发电站的对偶变量为: -991.9861827030404
# 第 6 个火力发电站的对偶变量为: -994.1635447067886
# 第 7 个火力发电站的对偶变量为: -992.7792728761668
# 第 8 个火力发电站的对偶变量为: -1004.3022467397553
# 第 9 个火力发电站的对偶变量为: -999.2624618609102
# 第 10 个火力发电站的对偶变量为: -994.966067706154
# 第 11 个火力发电站的对偶变量为: -991.280842120227
# 第 12 个火力发电站的对偶变量为: -1000.1961052083823
# 第 13 个火力发电站的对偶变量为: -993.0700080418263
# 第 14 个火力发电站的对偶变量为: -997.9167372295831
# 第 15 个火力发电站的对偶变量为: -991.8467266976143
# 第 16 个火力发电站的对偶变量为: -994.4678833806901
# 第 17 个火力发电站的对偶变量为: -997.7200230843877
# 第 18 个火力发电站的对偶变量为: -1001.4042127405157
# 第 19 个火力发电站的对偶变量为: -969.3845180594562
# 第 20 个火力发电站的对偶变量为: -968.6785880862601
# 第 21 个火力发电站的对偶变量为: -984.6481577447531
# 第 22 个火力发电站的对偶变量为: -988.898444295468
# 第 23 个火力发电站的对偶变量为: -988.898444295468
# 第 24 个火力发电站的对偶变量为: -984.476606823233
# 第 25 个火力发电站的对偶变量为: -981.7696141009422
# 第 26 个火力发电站的对偶变量为: -975.200591359752
# 第 27 个火力发电站的对偶变量为: -976.1030572312605
# 第 28 个火力发电站的对偶变量为: -965.8466698303714
# 第 29 个火力发电站的对偶变量为: -975.3657758790199
# 第 30 个火力发电站的对偶变量为: -1001.4456969400387
# 第 31 个火力发电站的对偶变量为: -1009.1141715472046
# 第 32 个火力发电站的对偶变量为: -1008.8588407164175
# 第 33 个火力发电站的对偶变量为: -1005.2001310434063
# 第 34 个火力发电站的对偶变量为: -999.4248239444007
# 第 35 个火力发电站的对偶变量为: -987.1853028729146
# 第 36 个火力发电站的对偶变量为: -964.9670207696913
# 第 37 个火力发电站的对偶变量为: -988.7727481699787
# 第 38 个火力发电站的对偶变量为: -986.2404422387765
# 第 39 个火力发电站的对偶变量为: -978.115105811261
# 第 40 个火力发电站的对偶变量为: -993.2086535647504
# 第 41 个火力发电站的对偶变量为: -1000.2021811365018
# 第 42 个火力发电站的对偶变量为: -999.5324743347568
# 第 43 个火力发电站的对偶变量为: -984.142462278742
# 第 44 个火力发电站的对偶变量为: -965.9130425514596
# 第 45 个火力发电站的对偶变量为: -985.5636115279628
# 第 46 个火力发电站的对偶变量为: -998.7421370056015
# 第 47 个火力发电站的对偶变量为: -997.4275148658388
# 第 48 个火力发电站的对偶变量为: -1002.5088504293218
# 第 49 个火力发电站的对偶变量为: -1000.8392136378988
# 第 50 个火力发电站的对偶变量为: -1001.9354694668184
# 第 51 个火力发电站的对偶变量为: -1001.2964575347248
# 第 52 个火力发电站的对偶变量为: -1001.2964575347248
# 第 53 个火力发电站的对偶变量为: -991.4261175848986
# 第 55 个风力发电站的对偶变量为: -1001.8031151925998
# 第 56 个风力发电站的对偶变量为: -1006.1449497847057
# 第 57 个风力发电站的对偶变量为: -999.3249635028782
# 第 59 个风力发电站的对偶变量为: -971.028521841668
# 第 60 个风力发电站的对偶变量为: -997.9638633034373
# ****************************************************************************
# 第 54 个受到Byzantin攻击的火力发电站的初始对偶变量为: -0.01
# 第 58 个受到Byzantin攻击的风力发电站的初始对偶变量为: -0.01
# ****************************************************************************
# 安全发电站的总发电量: 6431.350775362683
# *************************
# 需求侧平均用电需求: 91.70415949
# ****************************************************************************
# 风速分布参数c: 8.48068324
# ****************************************************************************
# 风速分布参数kappa: 2.42000008
# ****************************************************************************
# 安全发电站的总发电成本： 100018.38314571431
# ****************************************************************************
# 原变量迭代步长为: 5
# ****************************************************************************
# 对偶变量迭代步长为: 5
# ****************************************************************************
# 3 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 5.0
# 第 2 个火力发电站的计划发电量为: 5.0
# 第 3 个火力发电站的计划发电量为: 5.0
# 第 4 个火力发电站的计划发电量为: 259.2633402942918
# 第 5 个火力发电站的计划发电量为: 262.07516184369274
# 第 6 个火力发电站的计划发电量为: 10.0
# 第 7 个火力发电站的计划发电量为: 50.17497223626604
# 第 8 个火力发电站的计划发电量为: 5.0
# 第 9 个火力发电站的计划发电量为: 5.0
# 第 10 个火力发电站的计划发电量为: 262.40772684521266
# 第 11 个火力发电站的计划发电量为: 350.0
# 第 12 个火力发电站的计划发电量为: 8.0
# 第 13 个火力发电站的计划发电量为: 8.0
# 第 14 个火力发电站的计划发电量为: 50.86950465099199
# 第 15 个火力发电站的计划发电量为: 8.0
# 第 16 个火力发电站的计划发电量为: 50.42135120671203
# 第 17 个火力发电站的计划发电量为: 8.0
# 第 18 个火力发电站的计划发电量为: 8.0
# 第 19 个火力发电站的计划发电量为: 47.44287660638226
# 第 20 个火力发电站的计划发电量为: 250.0
# 第 21 个火力发电站的计划发电量为: 250.0
# 第 22 个火力发电站的计划发电量为: 49.769030601436754
# 第 23 个火力发电站的计划发电量为: 49.76903060143677
# 第 24 个火力发电站的计划发电量为: 200.0
# 第 25 个火力发电站的计划发电量为: 200.0
# 第 26 个火力发电站的计划发电量为: 48.10272802906045
# 第 27 个火力发电站的计划发电量为: 409.2400377998957
# 第 28 个火力发电站的计划发电量为: 408.10735993723387
# 第 29 个火力发电站的计划发电量为: 260.03302225523566
# 第 30 个火力发电站的计划发电量为: 30.0
# 第 31 个火力发电站的计划发电量为: 10.0
# 第 32 个火力发电站的计划发电量为: 5.0
# 第 33 个火力发电站的计划发电量为: 5.0
# 第 34 个火力发电站的计划发电量为: 51.018313127176775
# 第 35 个火力发电站的计划发电量为: 49.557948282031916
# 第 36 个火力发电站的计划发电量为: 258.73280297567356
# 第 37 个火力发电站的计划发电量为: 49.76608347415273
# 第 38 个火力发电站的计划发电量为: 10.0
# 第 39 个火力发电站的计划发电量为: 300.0
# 第 40 个火力发电站的计划发电量为: 191.51720393454278
# 第 41 个火力发电站的计划发电量为: 8.0
# 第 42 个火力发电站的计划发电量为: 20.0
# 第 43 个火力发电站的计划发电量为: 261.0496493507374
# 第 44 个火力发电站的计划发电量为: 258.9116074352087
# 第 45 个火力发电站的计划发电量为: 261.3413763233964
# 第 46 个火力发电站的计划发电量为: 8.0
# 第 47 个火力发电站的计划发电量为: 50.72097356543434
# 第 48 个火力发电站的计划发电量为: 51.4443130989623
# 第 49 个火力发电站的计划发电量为: 8.0
# 第 50 个火力发电站的计划发电量为: 25.0
# 第 51 个火力发电站的计划发电量为: 51.18372054984707
# 第 52 个火力发电站的计划发电量为: 51.18372054984707
# 第 53 个火力发电站的计划发电量为: 50.0123400137826
# 第 55 个风力发电站的计划发电量为: 109.58101850795941
# 第 56 个风力发电站的计划发电量为: 42.742122776038514
# 第 57 个风力发电站的计划发电量为: 73.27517929821828
# 第 59 个风力发电站的计划发电量为: 231.22794077314785
# 第 60 个风力发电站的计划发电量为: 26.594511553014293
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -1010.4287857075834
# 第 2 个火力发电站的对偶变量为: -1005.6356366740246
# 第 3 个火力发电站的对偶变量为: -991.1532091999129
# 第 4 个火力发电站的对偶变量为: -956.8363810552481
# 第 5 个火力发电站的对偶变量为: -990.6508720007873
# 第 6 个火力发电站的对偶变量为: -992.7040464888601
# 第 7 个火力发电站的对偶变量为: -991.324853594936
# 第 8 个火力发电站的对偶变量为: -1004.5093300550639
# 第 9 个火力发电站的对偶变量为: -1001.3134717634307
# 第 10 个火力发电站的对偶变量为: -995.6984120669853
# 第 11 个火力发电站的对偶变量为: -989.5887817005469
# 第 12 个火力发电站的对偶变量为: -1002.0281773517127
# 第 13 个火力发电站的对偶变量为: -991.8576382859088
# 第 14 个火力发电站的对偶变量为: -998.3875849001264
# 第 15 个火力发电站的对偶变量为: -989.5337580215082
# 第 16 个火力发电站的对偶变量为: -993.0245586083682
# 第 17 个火力发电站的对偶变量为: -996.2285993663498
# 第 18 个火力发电站的对偶变量为: -999.7012547079769
# 第 19 个火力发电站的对偶变量为: -958.6780787947077
# 第 20 个火力发电站的对偶变量为: -955.9623417178138
# 第 21 个火力发电站的对偶变量为: -978.3155787528192
# 第 22 个火力发电站的对偶变量为: -984.3060098966871
# 第 23 个火力发电站的对偶变量为: -984.3060098966871
# 第 24 个火力发电站的对偶变量为: -977.9297302687073
# 第 25 个火力发电站的对偶变量为: -973.0491080470553
# 第 26 个火力发电站的对偶变量为: -964.7959100872615
# 第 27 个火力发电站的对偶变量为: -970.0354176038181
# 第 28 个火力发电站的对偶变量为: -953.1448337288571
# 第 29 个火力发电站的对偶变量为: -966.6136209763379
# 第 30 个火力发电站的对偶变量为: -1002.5200466418175
# 第 31 个火力发电站的对偶变量为: -1014.2215624480416
# 第 32 个火力发电站的对偶变量为: -1014.202466491176
# 第 33 个火力发电站的对偶变量为: -1006.5664747771526
# 第 34 个火力发电站的对偶变量为: -1000.2787639062457
# 第 35 个火力发电站的对偶变量为: -982.7194415291868
# 第 36 个火力发电站的对偶变量为: -953.287181822375
# 第 37 个火力发电站的对偶变量为: -984.4638214077166
# 第 38 个火力发电站的对偶变量为: -980.924588891416
# 第 39 个火力发电站的对偶变量为: -969.9343840072993
# 第 40 个火力发电站的对偶变量为: -990.596460985115
# 第 41 个火力发电站的对偶变量为: -1000.0254171798889
# 第 42 个火力发电站的对偶变量为: -999.4915477775929
# 第 43 个火力发电站的对偶变量为: -979.6948666202321
# 第 44 个火力发电站的对偶变量为: -953.2652559868463
# 第 45 个火力发电站的对偶变量为: -981.1761307652865
# 第 46 个火力发电站的对偶变量为: -999.7830840054135
# 第 47 个火力发电站的对偶变量为: -998.4957715469318
# 第 48 个火力发电站的对偶变量为: -1004.324072585069
# 第 49 个火力发电站的对偶变量为: -1001.8903062739157
# 第 50 个火力发电站的对偶变量为: -1004.7705245114429
# 第 51 个火力发电站的对偶变量为: -1004.5956038628485
# 第 52 个火力发电站的对偶变量为: -1004.5956038628485
# 第 53 个火力发电站的对偶变量为: -989.8157352142774
# 第 55 个风力发电站的对偶变量为: -1002.5912936357754
# 第 56 个风力发电站的对偶变量为: -1008.4318209120993
# 第 57 个风力发电站的对偶变量为: -1000.3138946159999
# 第 59 个风力发电站的对偶变量为: -961.6187286174211
# 第 60 个风力发电站的对偶变量为: -997.5959979443035
# ****************************************************************************
# 第 54 个受到Byzantin攻击的火力发电站的初始对偶变量为: -0.01
# 第 58 个受到Byzantin攻击的风力发电站的初始对偶变量为: -0.01
# ****************************************************************************
# 安全发电站的总发电量: 6081.536968497018
# *************************
# 需求侧平均用电需求: 92.81865565
# ****************************************************************************
# 风速分布参数c: 8.49440173
# ****************************************************************************
# 风速分布参数kappa: 2.4000001
# ****************************************************************************
# 安全发电站的总发电成本： 93287.91314204743
# ****************************************************************************
# 原变量迭代步长为: 5
# ****************************************************************************
# 对偶变量迭代步长为: 5
# ****************************************************************************
# 4 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 5.0
# 第 2 个火力发电站的计划发电量为: 5.0
# 第 3 个火力发电站的计划发电量为: 5.0
# 第 4 个火力发电站的计划发电量为: 246.36731712522493
# 第 5 个火力发电站的计划发电量为: 251.6912273265901
# 第 6 个火力发电站的计划发电量为: 10.0
# 第 7 个火力发电站的计划发电量为: 37.26298025626866
# 第 8 个火力发电站的计划发电量为: 5.0
# 第 9 个火力发电站的计划发电量为: 5.0
# 第 10 个火力发电站的计划发电量为: 252.40825422304457
# 第 11 个火力发电站的计划发电量为: 350.0
# 第 12 个火力发电站的计划发电量为: 8.0
# 第 13 个火力发电站的计划发电量为: 8.0
# 第 14 个火力发电站的计划发电量为: 38.45717346400888
# 第 15 个火力发电站的计划发电量为: 8.0
# 第 16 个火力发电站的计划发电量为: 37.619464802950255
# 第 17 个火力发电站的计划发电量为: 8.0
# 第 18 个火力发电站的计划发电量为: 8.0
# 第 19 个火力发电站的计划发电量为: 32.160028300324306
# 第 20 个火力发电站的计划发电量为: 250.0
# 第 21 个火力发电站的计划发电量为: 250.0
# 第 22 个火力发电站的计划发电量为: 36.32409550917677
# 第 23 个火力发电站的计划发电量为: 36.324095509176786
# 第 24 个火力发电站的计划发电量为: 200.0
# 第 25 个火力发电站的计划发电量为: 200.0
# 第 26 个火力发电站的计划发电量为: 33.24523801527917
# 第 27 个火力发电站的计划发电量为: 405.0423025972049
# 第 28 个火力发电站的计划发电量为: 402.6220266639522
# 第 29 个火力发电站的计划发电量为: 247.86806616634027
# 第 30 个火力发电站的计划发电量为: 30.0
# 第 31 个火力发电站的计划发电量为: 10.0
# 第 32 个火力发电站的计划发电量为: 5.0
# 第 33 个火力发电站的计划发电量为: 5.0
# 第 34 个火力发电站的计划发电量为: 38.744532705751965
# 第 35 个火力发电站的计划发电量为: 36.007817696030735
# 第 36 个火力发电站的计划发电量为: 245.59870913726698
# 第 37 个火力发电站的计划发电量为: 36.33467657343756
# 第 38 个火力发电站的计划发电量为: 10.0
# 第 39 个火力发电站的计划发电量为: 300.0
# 第 40 个火力发电站的计划发电量为: 188.80191308875416
# 第 41 个火力发电站的计划发电量为: 8.0
# 第 42 个火力发电站的计划发电量为: 20.0
# 第 43 个火力发电站的计划发电量为: 249.86423886886405
# 第 44 个火力发电站的计划发电量为: 245.75624145886695
# 第 45 个火力发电站的计划发电量为: 250.24767921200092
# 第 46 个火力发电站的计划发电量为: 8.0
# 第 47 个火力发电站的计划发电量为: 38.33666991130306
# 第 48 个火力发电站的计划发电量为: 39.453113737717544
# 第 49 个火力发电站的计划发电量为: 8.0
# 第 50 个火力发电站的计划发电量为: 25.0
# 第 51 个火力发电站的计划发电量为: 39.24850464137069
# 第 52 个火力发电站的计划发电量为: 39.24850464137069
# 第 53 个火力发电站的计划发电量为: 36.99540509320819
# 第 55 个风力发电站的计划发电量为: 111.57812363841687
# 第 56 个风力发电站的计划发电量为: 41.35720393116127
# 第 57 个风力发电站的计划发电量为: 74.49578502131018
# 第 59 个风力发电站的计划发电量为: 206.38115033929466
# 第 60 个风力发电站的计划发电量为: 26.525010958828208
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -1012.2926227560321
# 第 2 个火力发电站的对偶变量为: -1006.9995687120556
# 第 3 个火力发电站的对偶变量为: -989.7683867702393
# 第 4 个火力发电站的对偶变量为: -946.7459920363847
# 第 5 个火力发电站的对偶变量为: -989.9673236371483
# 第 6 个火力发电站的对偶变量为: -991.716044626744
# 第 7 个火力发电站的对偶变量为: -990.4139659080674
# 第 8 个火力发电站的对偶变量为: -1004.39285365939
# 第 9 个火力发电站的对偶变量为: -1003.5178713299166
# 第 10 个火力发电站的对偶变量为: -997.1071877007944
# 第 11 个火力发电站的对偶变量为: -988.5354730236928
# 第 12 个火力发电站的对偶变量为: -1003.9334813297464
# 第 13 个火力发电站的对偶变量为: -991.2710277496063
# 第 14 个火力发电站的对偶变量为: -999.5533573050509
# 第 15 个火力发电站的对偶变量为: -987.5496879543131
# 第 16 个火力发电站的对偶变量为: -991.8694250229202
# 第 17 个火力发电站的对偶变量为: -994.5651191623255
# 第 18 个火力发电站的对偶变量为: -996.4251923920539
# 第 19 个火力发电站的对偶变量为: -949.4650487788618
# 第 20 个火力发电站的对偶变量为: -945.1714616623782
# 第 21 个火力发电站的对偶变量为: -972.3893301889213
# 第 22 个火力发电站的对偶变量为: -979.8981870804828
# 第 23 个火力发电站的对偶变量为: -979.8981870804828
# 第 24 个火力发电站的对偶变量为: -971.8221782243302
# 第 25 个火力发电站的对偶变量为: -964.8387607378012
# 第 26 个火力发电站的对偶变量为: -955.3881687353899
# 第 27 个火力发电站的对偶变量为: -965.3274257413997
# 第 28 个火力发电站的对偶变量为: -942.201727774564
# 第 29 个火力发电站的对偶变量为: -959.3084014204115
# 第 30 个火力发电站的对偶变量为: -1003.2945985723958
# 第 31 个火力发电站的对偶变量为: -1018.9603840389856
# 第 32 个火力发电站的对偶变量为: -1018.808191019988
# 第 33 个火力发电站的对偶变量为: -1007.0872548682521
# 第 34 个火力发电站的对偶变量为: -1001.269508580675
# 第 35 个火力发电站的对偶变量为: -979.1775684639726
# 第 36 个火力发电站的对偶变量为: -944.157441003614
# 第 37 个火力发电站的对偶变量为: -980.8645163174735
# 第 38 个火力发电站的对偶变量为: -976.2239070674939
# 第 39 个火力发电站的对偶变量为: -962.6654388497561
# 第 40 个火力发电站的对偶变量为: -987.908425613205
# 第 41 个火力发电站的对偶变量为: -999.3667900023329
# 第 42 个火力发电站的对偶变量为: -998.8718476417739
# 第 43 个火力发电站的对偶变量为: -976.1433792186203
# 第 44 个火力发电站的对偶变量为: -943.0764357898903
# 第 45 个火力发电站的对偶变量为: -977.8165522561496
# 第 46 个火力发电站的对偶变量为: -1001.4263983978158
# 第 47 个火力发电站的对偶变量为: -1000.0296979002557
# 第 48 个火力发电站的对偶变量为: -1006.2083326544137
# 第 49 个火力发电站的对偶变量为: -1002.9927156703927
# 第 50 个火力发电站的对偶变量为: -1008.231607338224
# 第 51 个火力发电站的对偶变量为: -1008.688348764926
# 第 52 个火力发电站的对偶变量为: -1008.688348764926
# 第 53 个火力发电站的对偶变量为: -989.0575087694712
# 第 55 个风力发电站的对偶变量为: -1003.358333555761
# 第 56 个风力发电站的对偶变量为: -1010.1123181358885
# 第 57 个风力发电站的对偶变量为: -1001.591454473366
# 第 59 个风力发电站的对偶变量为: -954.8683836555381
# 第 60 个风力发电站的对偶变量为: -997.0210936870469
# ****************************************************************************
# 第 54 个受到Byzantin攻击的火力发电站的初始对偶变量为: -0.01
# 第 58 个受到Byzantin攻击的风力发电站的初始对偶变量为: -0.01
# ****************************************************************************
# 安全发电站的总发电量: 5756.367550614495
# *************************
# 需求侧平均用电需求: 107.71966101
# ****************************************************************************
# 风速分布参数c: 8.52563694
# ****************************************************************************
# 风速分布参数kappa: 2.4000001
# ****************************************************************************
# 安全发电站的总发电成本： 87130.11326200074
# ****************************************************************************
# 原变量迭代步长为: 5
# ****************************************************************************
# 对偶变量迭代步长为: 5
# ****************************************************************************
# 5 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 5.0
# 第 2 个火力发电站的计划发电量为: 5.0
# 第 3 个火力发电站的计划发电量为: 5.0
# 第 4 个火力发电站的计划发电量为: 234.0328707242221
# 第 5 个火力发电站的计划发电量为: 242.37958332458578
# 第 6 个火力发电站的计划发电量为: 10.0
# 第 7 个火力发电站的计划发电量为: 25.92781594247189
# 第 8 个火力发电站的计划发电量为: 5.0
# 第 9 个火力发电站的计划发电量为: 5.0
# 第 10 个火力发电站的计划发电量为: 243.61362221802136
# 第 11 个火力发电站的计划发电量为: 350.0
# 第 12 个火力发电站的计划发电量为: 8.0
# 第 13 个火力发电站的计划发电量为: 8.0
# 第 14 个火力发电站的计划发电量为: 27.730768369369986
# 第 15 个火力发电站的计划发电量为: 8.0
# 第 16 个火力发电站的计划发电量为: 26.359958726749294
# 第 17 个火力发电站的计划发电量为: 8.0
# 第 18 个火力发电站的计划发电量为: 8.0
# 第 19 个火力发电站的计划发电量为: 25.0
# 第 20 个火力发电站的计划发电量为: 250.0
# 第 21 个火力发电站的计划发电量为: 250.0
# 第 22 个火力发电站的计划发电量为: 25.0
# 第 23 个火力发电站的计划发电量为: 25.0
# 第 24 个火力发电站的计划发电量为: 200.0
# 第 25 个火力发电站的计划发电量为: 200.0
# 第 26 个火力发电站的计划发电量为: 25.0
# 第 27 个火力发电站的计划发电量为: 400.89677489727757
# 第 28 个火力发电站的计划发电量为: 396.80566468812003
# 第 29 个火力发电站的计划发电量为: 236.41728075578507
# 第 30 个火力发电站的计划发电量为: 30.0
# 第 31 个火力发电站的计划发电量为: 10.0
# 第 32 个火力发电站的计划发电量为: 5.0
# 第 33 个火力发电站的计划发电量为: 5.0
# 第 34 个火力发电站的计划发电量为: 28.124358234471952
# 第 35 个火力发电站的计划发电量为: 25.0
# 第 36 个火力发电站的计划发电量为: 233.13213626889038
# 第 37 个火力发电站的计划发电量为: 25.0
# 第 38 个火力发电站的计划发电量为: 10.0
# 第 39 个火力发电站的计划发电量为: 300.0
# 第 40 个火力发电站的计划发电量为: 186.15790717478592
# 第 41 个火力发电站的计划发电量为: 8.0
# 第 42 个火力发电站的计划发电量为: 20.0
# 第 43 个火力发电站的计划发电量为: 239.59928449342678
# 第 44 个火力发电站的计划发电量为: 233.18245318270604
# 第 45 个火力发电站的计划发电量为: 240.0804567857083
# 第 46 个火力发电站的计划发电量为: 8.0
# 第 47 个火力发电站的计划发电量为: 27.66538432101092
# 第 48 个火力发电站的计划发电量为: 29.153809567157502
# 第 49 个火力发电站的计划发电量为: 8.0
# 第 50 个火力发电站的计划发电量为: 25.0
# 第 51 个火力发电站的计划发电量为: 29.182058444352396
# 第 52 个火力发电站的计划发电量为: 29.182058444352396
# 第 53 个火力发电站的计划发电量为: 25.581452305400134
# 第 55 个风力发电站的计划发电量为: 112.8242761690124
# 第 56 个风力发电站的计划发电量为: 42.53495038746378
# 第 57 个风力发电站的计划发电量为: 75.38821166565809
# 第 59 个风力发电站的计划发电量为: 181.06242936445065
# 第 60 个风力发电站的计划发电量为: 27.0075397170506
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -1014.8333314694695
# 第 2 个火力发电站的对偶变量为: -1009.2635017292974
# 第 3 个火力发电站的对偶变量为: -989.9365614012057
# 第 4 个火力发电站的对偶变量为: -939.498765409934
# 第 5 个火力发电站的对偶变量为: -990.8900137743036
# 第 6 个火力发电站的对偶变量为: -992.287158573687
# 第 7 个火力发电站的对偶变量为: -991.1325652037254
# 第 8 个火力发电站的对偶变量为: -1005.5064344323706
# 第 9 个火力发电站的对偶变量为: -1006.9839379863276
# 第 10 个火力发电站的对偶变量为: -1000.0359933137385
# 第 11 个火力发电站的对偶变量为: -989.1168798204761
# 第 12 个火力发电站的对偶变量为: -1007.1557853012732
# 第 13 个火力发电站的对偶变量为: -992.3640222878179
# 第 14 个火力发电站的对偶变量为: -1002.2855859526187
# 第 15 个火力发电站的对偶变量为: -987.0557891743342
# 第 16 个火力发电站的对偶变量为: -992.1280450855924
# 第 17 个火力发电站的对偶变量为: -994.0690432136731
# 第 18 个火力发电站的对偶变量为: -993.4499765676985
# 第 19 个火力发电站的对偶变量为: -942.9644675245484
# 第 20 个火力发电站的对偶变量为: -937.0390700652683
# 第 21 个火力发电站的对偶变量为: -968.1016522695629
# 第 22 个火力发电站的对偶变量为: -976.8325003322482
# 第 23 个火力发电站的对偶变量为: -976.8325003322482
# 第 24 个火力发电站的对偶变量为: -967.3175950048711
# 第 25 个火力发电站的对偶变量为: -958.4391734911869
# 第 26 个火力发电站的对偶变量为: -948.1045332314553
# 第 27 个火力发电站的对偶变量为: -962.7323659763239
# 第 28 个火力发电站的对偶变量为: -933.9442879919254
# 第 29 个火力发电站的对偶变量为: -954.3739850125959
# 第 30 个火力发电站的对偶变量为: -1005.0348523129779
# 第 31 个火力发电站的对偶变量为: -1024.4267020129664
# 第 32 个火力发电站的对偶变量为: -1024.0121298719164
# 第 33 个火力发电站的对偶变量为: -1008.3066420554853
# 第 34 个火力发电站的对偶变量为: -1003.4650695008786
# 第 35 个火力发电站的对偶变量为: -977.6558194707467
# 第 36 个火力发电站的对偶变量为: -938.3192169545074
# 第 37 个火力发电站的对偶变量为: -979.1225848665764
# 第 38 个火力发电站的对偶变量为: -973.1645886275271
# 第 39 个火力发电站的对偶变量为: -957.3723604315594
# 第 40 个火力发电站的对偶变量为: -986.5353902962391
# 第 41 个火力发电站的对偶变量为: -999.4503640941448
# 第 42 个火力发电站的对偶变量为: -999.1148092419693
# 第 43 个火力发电站的对偶变量为: -974.3748726416668
# 第 44 个火力发电站的对偶变量为: -936.276423051622
# 第 45 个火力发电站的对偶变量为: -976.6407231669514
# 第 46 个火力发电站的对偶变量为: -1004.6521854304681
# 第 47 个火力发电站的对偶变量为: -1003.0562475619879
# 第 48 个火力发电站的对偶变量为: -1009.4583053512704
# 第 49 个火力发电站的对偶变量为: -1005.3740612235006
# 第 50 个火力发电站的对偶变量为: -1013.459614603503
# 第 51 个火力发电站的对偶变量为: -1014.552603132905
# 第 52 个火力发电站的对偶变量为: -1014.552603132905
# 第 53 个火力发电站的对偶变量为: -990.0687799861838
# 第 55 个风力发电站的对偶变量为: -1005.2368186228509
# 第 56 个风力发电站的对偶变量为: -1012.9303653416393
# 第 57 个风力发电站的对偶变量为: -1004.2602605435852
# 第 59 个风力发电站的对偶变量为: -951.7329489398237
# 第 60 个风力发电站的对偶变量为: -997.5970377482817
# ****************************************************************************
# 第 54 个受到Byzantin攻击的火力发电站的初始对偶变量为: -0.01
# 第 58 个受到Byzantin攻击的风力发电站的初始对偶变量为: -0.01
# ****************************************************************************
# 安全发电站的总发电量: 5478.023106172502
# *************************
# 需求侧平均用电需求: 82.47730833
# ****************************************************************************
# 风速分布参数c: 8.5565076
# ****************************************************************************
# 风速分布参数kappa: 2.38000011
# ****************************************************************************
# 安全发电站的总发电成本： 81930.07599004851
# ****************************************************************************
# 原变量迭代步长为: 5
# ****************************************************************************
# 对偶变量迭代步长为: 5
# ****************************************************************************
# 2024-07-30 16:56:35.349

# %%
#数据存储
np.savetxt('./data/04_SCC_optimal_parameters_large_Byzantine_attack_sum_cost.txt',sum_cost,fmt='%0.8f')
np.savetxt('./data/04_SCC_optimal_parameters_large_Byzantine_attack_sum_thermal_wind_power_station_strategy.txt',sum_thermal_wind_power_station_strategy,fmt='%0.8f')

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
from sympy import *
import math 
from datetime import datetime
from scipy.special import gamma, factorial
import scipy.special as sc

# %%
sum_cost=np.loadtxt("./data/04_SCC_optimal_parameters_large_Byzantine_attack_sum_cost.txt")
optimal_sum_cost=np.loadtxt("./data/00_optimal_sum_cost_varying_D_c_kappa_normal_distribution_(100,10).txt")

# %%
dynamic_regret=[]
dynamic_regret_T=[]
for T in range(1, 1000):
    dynamic_regret_auxiliary_variable=0
    for t in range(0, T):
        dynamic_regret_auxiliary_variable=dynamic_regret_auxiliary_variable+sum_cost[t+1]-optimal_sum_cost[t+1]
    dynamic_regret.append(dynamic_regret_auxiliary_variable)
    dynamic_regret_T.append((dynamic_regret_auxiliary_variable)/T)

# %%
dynamic_regret
# Out:
# [34923.03850531,
#  56083.51487698,
#  69362.64691777002,
#  60439.66271784001,
#  72684.61635788,
#  50297.7121781,
#  44317.34685174,
#  27659.419189399996,
#  32172.41137042,
#  9936.19155091999,
#  -14602.911133420013,
#  -50448.635437730016,
#  -80443.26082425001,
#  -100641.77893311002,
#  -132527.78467306003,
#  -153357.05461790002,
#  -162835.00954684,
#  -187027.58542769,
#  -188624.20010160998,
#  -201373.09946215997,
#  -256243.59170791996,
#  -266348.28999122995,
#  -288572.22409890994,
#  -313673.3543769299,
#  -327700.8548760199,
#  -348305.4917987699,
#  -382119.9473360299,
#  -408786.7071008099,
#  -434768.0784079999,
#  -466056.4556682199,
#  -505620.3891585799,
#  -531806.26618511,
#  -542614.74693595,
#  -572103.14875223,
#  -568648.9158443899,
#  -603950.62132777,
#  -634777.2236024999,
#  -651872.2758864299,
#  -665569.47255071,
#  -693903.73594225,
#  -721300.4759966,
#  -747750.8912100799,
#  -764647.8835486199,
#  -816981.6074662199,
#  -848056.0125267699,
#  -874161.12262222,
#  -895641.50613445,
#  -930154.54154882,
#  -968600.26035183,
#  -985976.5471551601,
#  -1006556.3621143901,
#  -1026108.3062766201,
#  -1037138.2975367501,
#  -1062972.6431450702,
#  -1075561.5635484,
#  -1096717.83797463,
#  -1104427.17541763,
#  -1128150.53572984,
#  -1165514.2432683099,
#  -1172918.32125486,
#  -1202962.10248887,
#  -1235603.7296506101,
#  -1249165.74140809,
#  -1259228.5233084902,
#  -1290025.8423358703,
#  -1309367.4482026002,
#  -1339430.3264469402,
#  -1367333.6546798402,
#  -1392073.6382984002,
#  -1400577.2289091202,
#  -1415830.3258172902,
#  -1434854.9044438803,
#  -1452525.0515922902,
#  -1491049.4714638903,
#  -1514206.2469790303,
#  -1550315.6821887202,
#  -1581251.85662883,
#  -1589980.1978053702,
#  -1597998.5520370002,
#  -1614876.5576797202,
#  -1638068.3925656402,
#  -1658641.8411633102,
#  -1679978.3419734002,
#  -1693110.4341618302,
#  -1719811.9585851403,
#  -1738826.7008576402,
#  -1776045.2856656301,
#  -1787918.4856266503,
#  -1807861.8750918703,
#  -1833881.7931103602,
#  -1863113.1104511803,
#  -1880612.3077514402,
#  -1909808.3534792503,
#  -1937192.4267125002,
#  -1959911.7979825302,
#  -1995845.0426084402,
#  -2020830.60805014,
#  -2049843.4359811102,
#  -2076643.67857941,
#  -2074331.0354220502,
#  -2103087.14767616,
#  -2127666.6670814203,
#  -2155768.0960524003,
#  -2181767.7867685603,
#  -2204487.0756815705,
#  -2218030.9854856306,
#  -2240699.9617338907,
#  -2266060.315807361,
#  -2319205.317908321,
#  -2340373.121933061,
#  -2348576.801990461,
#  -2377386.574773801,
#  -2400983.9540428007,
#  -2410025.5128192403,
#  -2441151.9539530906,
#  -2458212.906471721,
#  -2466944.102713801,
#  -2487841.255221961,
#  -2517667.060528941,
#  -2554581.527003901,
#  -2556035.7372195013,
#  -2568717.7829127912,
#  -2574451.259299601,
#  -2614956.555021141,
#  -2646479.9740412515,
#  -2681410.5703889513,
#  -2681835.9713127716,
#  -2718226.3515451713,
#  -2725268.891800151,
#  -2750126.806327361,
#  -2771041.2203897014,
#  -2781188.4614095013,
#  -2801456.1513616513,
#  -2837533.2082220213,
#  -2870544.6113460613,
#  -2882646.913691881,
#  -2915070.612203951,
#  -2935323.812329791,
#  -2957795.283902511,
#  -2984493.749939841,
#  -3025083.4987210413,
#  -3063626.4726636712,
#  -3065893.268108941,
#  -3085510.3303668513,
#  -3123773.1105162813,
#  -3145879.819043631,
#  -3170550.281264271,
#  -3188162.746254951,
#  -3213215.905532521,
#  -3226597.435739911,
#  -3255227.414924981,
#  -3274563.295254491,
#  -3297832.676512241,
#  -3310042.340327151,
#  -3336000.9387068613,
#  -3339103.5454622614,
#  -3356968.1029601116,
#  -3358870.2528411313,
#  -3371771.8732815613,
#  -3398471.7389487014,
#  -3417320.1263684216,
#  -3439562.1203696714,
#  -3455782.1688820818,
#  -3506954.926000042,
#  -3540457.210844182,
#  -3586022.370250602,
#  -3600344.3759849416,
#  -3615448.8256650516,
#  -3638291.4226643215,
#  -3673028.9632079415,
#  -3682315.6233644015,
#  -3685212.319530411,
#  -3717041.6204560213,
#  -3729517.5071396814,
#  -3754854.7546383915,
#  -3770791.939576742,
#  -3798437.865587202,
#  -3820558.0980561217,
#  -3830790.1474882714,
#  -3841276.260029071,
#  -3867693.0191173013,
#  -3894404.7346938816,
#  -3932205.1598703917,
#  -3965966.974026152,
#  -3984574.3570876517,
#  -4010284.4952612515,
#  -4045297.9654159714,
#  -4074495.910256651,
#  -4097153.2920030314,
#  -4101809.3417088413,
#  -4123597.3586104712,
#  -4116595.5467062015,
#  -4146734.2725920216,
#  -4165949.7507719616,
#  -4178124.9940776615,
#  -4204966.9393974515,
#  -4237608.405424432,
#  -4247274.632331502,
#  -4256565.805269712,
#  -4262171.501478482,
#  -4274103.744284492,
#  -4297731.611544412,
#  -4338756.685200431,
#  -4358768.029102561,
#  -4396835.929503001,
#  -4417397.332018332,
#  -4426370.606257712,
#  -4446519.616368282,
#  -4462865.396814901,
#  -4471897.108727191,
#  -4495279.47954391,
#  -4512862.983959701,
#  -4524190.173204651,
#  -4535231.521148771,
#  -4570721.787793631,
#  -4584563.831436121,
#  -4597702.910391761,
#  -4616658.964835061,
#  -4652531.499392111,
#  -4663484.508302831,
#  -4674453.660976641,
#  -4686250.082706981,
#  -4700695.581830241,
#  -4736760.303166431,
#  -4744642.670964741,
#  -4768731.789726161,
#  -4780399.067623891,
#  -4797287.557458381,
#  -4821541.887050492,
#  -4839603.427406572,
#  -4859310.191046872,
#  -4888988.451209572,
#  -4906429.108592502,
#  -4913871.656813082,
#  -4934355.660091623,
#  -4951341.089889233,
#  -4959889.777914563,
#  -4984665.357860233,
#  -5006363.216265162,
#  -5038338.6922778925,
#  -5052730.004219112,
#  -5072262.916223282,
#  -5103218.4555685725,
#  -5137822.693712322,
#  -5179088.407886832,
#  -5212615.798520492,
#  -5228793.9063405525,
#  -5246358.077609582,
#  -5281508.815960341,
#  -5299412.456216361,
#  -5318125.538400811,
#  -5353905.905176502,
#  -5379520.337186682,
#  -5398091.765441182,
#  -5415074.274032623,
#  -5430349.598701922,
#  -5464616.425051732,
#  -5490312.805877731,
#  -5512859.580027471,
#  -5535603.134990221,
#  -5550557.256856721,
#  -5590088.250724611,
#  -5606608.283219241,
#  -5622397.328955421,
#  -5636099.899965662,
#  -5651939.340008101,
#  -5671991.059424572,
#  -5696172.053013952,
#  -5720686.905448442,
#  -5736114.308180522,
#  -5771217.878051313,
#  -5800108.115935642,
#  -5821203.757786732,
#  -5833381.3117943825,
#  -5856180.455179333,
#  -5875517.366434663,
#  -5903873.873792003,
#  -5933648.334644423,
#  -5971663.590064803,
#  -5979086.467380223,
#  -6011305.996945233,
#  -6045908.295492473,
#  -6061309.147275573,
#  -6085779.994234793,
#  -6107707.391661743,
#  -6113087.312342163,
#  -6131937.221043473,
#  -6175360.997476974,
#  -6187086.374571123,
#  -6208270.871070563,
#  -6258056.896674222,
#  -6284541.846642872,
#  -6289592.377817422,
#  -6296455.889992572,
#  -6326078.417082353,
#  -6372687.550925902,
#  -6379161.724103742,
#  -6412016.169203863,
#  -6451430.640594712,
#  -6460557.835489713,
#  -6481420.271240563,
#  -6497727.002897243,
#  -6512851.578706003,
#  -6514626.440237342,
#  -6528041.6083065225,
#  -6543100.568132183,
#  -6582814.0993324425,
#  -6616937.117103073,
#  -6634445.176227412,
#  -6664427.262605432,
#  -6672176.621564233,
#  -6682932.991382453,
#  -6716896.171663612,
#  -6734938.917024123,
#  -6776535.522156673,
#  -6818030.808068163,
#  -6846834.358107002,
#  -6872618.589264862,
#  -6898068.843523952,
#  -6926367.280840063,
#  -6960762.3870610325,
#  -6973255.582830522,
#  -6967483.854306842,
#  -7008395.978213343,
#  -7019700.795342563,
#  -7036713.320037123,
#  -7057143.253302633,
#  -7083742.452830173,
#  -7102855.255822533,
#  -7138068.836964322,
#  -7157485.015230683,
#  -7172462.1098156925,
#  -7201791.207398833,
#  -7204794.667967973,
#  -7216198.827394643,
#  -7241095.668184103,
#  -7268584.786230303,
#  -7277340.979821494,
#  -7293139.712567643,
#  -7301252.275557153,
#  -7330710.090040573,
#  -7367110.524299943,
#  -7416592.236603892,
#  -7438118.161618313,
#  -7466044.912064773,
#  -7492959.944986633,
#  -7521918.107527314,
#  -7535247.635984424,
#  -7571904.112243744,
#  -7604273.006350104,
#  -7634404.154256714,
#  -7660149.029274203,
#  -7678242.681134063,
#  -7696202.907868983,
#  -7720676.776655813,
#  -7740446.006758792,
#  -7795347.612424432,
#  -7829466.487797433,
#  -7849784.957565363,
#  -7860098.967328733,
#  -7901689.830655502,
#  -7924132.566805592,
#  -7940220.907546102,
#  -7977948.496813342,
#  -8000714.439217852,
#  -8026867.732839863,
#  -8031063.920419592,
#  -8038978.5468570925,
#  -8041768.686986113,
#  -8067020.693032543,
#  -8069249.692354984,
#  -8087742.508339814,
#  -8098826.229836884,
#  -8103858.3193293745,
#  -8113399.466487384,
#  -8144084.593705924,
#  -8146801.214886084,
#  -8154434.6361928545,
#  -8156733.383095885,
#  -8185130.889151026,
#  -8209908.040842796,
#  -8228508.705024606,
#  -8249601.8901494155,
#  -8266869.0947605055,
#  -8282985.552428635,
#  -8294892.980733794,
#  -8310131.468807364,
#  -8335823.920474834,
#  -8369452.085292194,
#  -8384983.505752364,
#  -8390250.262449004,
#  -8399321.378254984,
#  -8415987.030413013,
#  -8436839.856631013,
#  -8439897.324990762,
#  -8457513.571753804,
#  -8472240.017337034,
#  -8499473.295760553,
#  -8520848.237797473,
#  -8537950.714427704,
#  -8560214.360356284,
#  -8588867.804618934,
#  -8600796.176387426,
#  -8622149.148193056,
#  -8641298.902410025,
#  -8666414.736500505,
#  -8672812.790702855,
#  -8696356.701126264,
#  -8727844.977255395,
#  -8752702.090627914,
#  -8783404.582462694,
#  -8831951.040725134,
#  -8836860.725239964,
#  -8862153.284496475,
#  -8904965.416804785,
#  -8910979.974284234,
#  -8944973.911916273,
#  -8988697.291494103,
#  -9025427.229501722,
#  -9048356.770301191,
#  -9076583.45841301,
#  -9100573.532135181,
#  -9123048.172801571,
#  -9158331.98016596,
#  -9179029.390116362,
#  -9192844.189843893,
#  -9222130.520005602,
#  -9250494.472971482,
#  -9294767.540163761,
#  -9323375.20758998,
#  -9349036.22904065,
#  -9372098.269225031,
#  -9392239.337186422,
#  -9428283.952703992,
#  -9446989.429569142,
#  -9491528.994926821,
#  -9519758.025077092,
#  -9542241.530698812,
#  -9572670.919836922,
#  -9604473.552483963,
#  -9617834.295575762,
#  -9643432.982802182,
#  -9658206.648269711,
#  -9691763.17879794,
#  -9717627.82860075,
#  -9738192.20286914,
#  -9756371.39854559,
#  -9781981.50968002,
#  -9814235.442539549,
#  -9815090.795897478,
#  -9823935.596189229,
#  -9831337.213368379,
#  -9844849.914329968,
#  -9883816.934401238,
#  -9882599.681573348,
#  -9908417.59372441,
#  -9930464.76233564,
#  -9947420.237934459,
#  -9973601.577062918,
#  -9997174.323862158,
#  -10009337.584763268,
#  -10045796.3663945,
#  -10063625.217278589,
#  -10080348.47839878,
#  -10097979.167442579,
#  -10135012.216427308,
#  -10154089.544095326,
#  -10165411.664966226,
#  -10191113.508813476,
#  -10197803.575376727,
#  -10222487.885741577,
#  -10267071.378829386,
#  -10281705.100892765,
#  -10298294.012896685,
#  -10305452.096959574,
#  -10315528.837388296,
#  -10343095.111383235,
#  -10367627.306723235,
#  -10396933.015084675,
#  -10420820.065688334,
#  -10431096.773142025,
#  -10472723.793062845,
#  -10501672.691084486,
#  -10524188.886088155,
#  -10558960.283029025,
#  -10581771.930202236,
#  -10584483.994479507,
#  -10620340.331418866,
#  -10636260.439903976,
#  -10674918.071092766,
#  -10675903.003070654,
#  -10706361.439667333,
#  -10740405.641737692,
#  -10763590.683382683,
#  -10799410.371756932,
#  -10818190.678941742,
#  -10840596.543302491,
#  -10855059.787840001,
#  -10876827.730166072,
#  -10896775.516886022,
#  -10910811.344196532,
#  -10927225.51423517,
#  -10954959.39699465,
#  -10984252.19076756,
#  -11001379.06168134,
#  -11018044.01646499,
#  -11043353.96914799,
#  -11066526.558323769,
#  -11096957.47373524,
#  -11108473.08813828,
#  -11151439.681461452,
#  -11181475.954274561,
#  -11199778.06063901,
#  -11215342.5100209,
#  -11200148.31643568,
#  -11226198.54423434,
#  -11234298.41563515,
#  -11262855.788689729,
#  -11282512.93985791,
#  -11301730.52527914,
#  -11319662.31886717,
#  -11343341.77807243,
#  -11363257.06241343,
#  -11378047.214450419,
#  -11431915.655076109,
#  -11450228.644569788,
#  -11461588.175516289,
#  -11489215.706907948,
#  -11510426.064068729,
#  -11544754.4948023,
#  -11562437.14458068,
#  -11592369.177475771,
#  -11608471.2766125,
#  -11656303.80215549,
#  -11682021.451280879,
#  -11726498.506797748,
#  -11752571.992259897,
#  -11783940.524817606,
#  -11808957.982927788,
#  -11832174.829853978,
#  -11863488.354384698,
#  -11892496.882452508,
#  -11909512.803738689,
#  -11935668.29169864,
#  -11976728.73612181,
#  -11992471.08981501,
#  -12020624.20850686,
#  -12012347.86603938,
#  -12048543.744880062,
#  -12056874.634143682,
#  -12085300.419643251,
#  -12101836.720793711,
#  -12121213.216042971,
#  -12141084.690941062,
#  -12161988.925895533,
#  -12163003.109980673,
#  -12181893.510909572,
#  -12183327.404153302,
#  -12216493.321703533,
#  -12238409.775873203,
#  -12254252.967731893,
#  -12276350.375167213,
#  -12290234.427606072,
#  -12313600.939773232,
#  -12336943.978455761,
#  -12368720.083143512,
#  -12375207.208003582,
#  -12416799.172527501,
#  -12433634.654853141,
#  -12463412.630253052,
#  -12476668.294548212,
#  -12515764.925645221,
#  -12525133.734291442,
#  -12545749.89333417,
#  -12577428.88929121,
#  -12590010.05680673,
#  -12606084.753502911,
#  -12618220.272752391,
#  -12637030.72686499,
#  -12663024.0764174,
#  -12693257.67048727,
#  -12727433.048523,
#  -12763520.20234277,
#  -12786405.68585947,
#  -12790927.960730499,
#  -12815670.140019348,
#  -12843831.198981088,
#  -12868696.958377378,
#  -12886436.534185039,
#  -12918290.84917683,
#  -12917301.630460419,
#  -12933540.73251012,
#  -12950753.63288496,
#  -12976699.10405577,
#  -12987956.36493857,
#  -13010411.249615071,
#  -13042293.731500752,
#  -13054495.325755702,
#  -13076765.730103282,
#  -13095019.074473953,
#  -13127117.187235294,
#  -13132598.989126094,
#  -13146592.686841873,
#  -13163554.637004303,
#  -13186829.381875662,
#  -13208741.483071422,
#  -13249830.584197123,
#  -13286655.925569562,
#  -13292935.098826002,
#  -13336673.930348853,
#  -13351259.011020273,
#  -13396950.969550343,
#  -13435018.569756744,
#  -13448807.665083375,
#  -13475182.638606705,
#  -13501803.102790205,
#  -13529032.840733415,
#  -13555528.060558114,
#  -13572725.160221495,
#  -13585125.510505756,
#  -13606580.281071777,
#  -13607066.256941337,
#  -13616965.400347948,
#  -13621448.008539498,
#  -13652494.07953504,
#  -13676052.35759318,
#  -13705794.3079068,
#  -13701903.103128111,
#  -13726628.27796149,
#  -13752652.980002401,
#  -13769782.893650692,
#  -13801372.656040242,
#  -13824243.453231262,
#  -13822718.542680042,
#  -13838886.309449082,
#  -13856398.789980672,
#  -13880326.453940582,
#  -13905338.823687201,
#  -13924455.87474638,
#  -13947569.47279364,
#  -13975811.51076304,
#  -14001316.51538841,
#  -14037410.37354611,
#  -14046608.97898156,
#  -14068948.39332564,
#  -14090056.76532336,
#  -14113069.9244556,
#  -14150386.92845642,
#  -14174488.601304341,
#  -14195812.51293055,
#  -14225201.07733237,
#  -14248706.22388554,
#  -14275102.08912205,
#  -14300622.160700219,
#  -14318626.7017309,
#  -14338346.52728506,
#  -14363414.200472498,
#  -14395666.032618068,
#  -14430141.472201157,
#  -14466949.184104167,
#  -14483839.578631757,
#  -14508339.467896387,
#  -14529667.844116079,
#  -14539037.742526429,
#  -14560362.748928327,
#  -14569140.329712166,
#  -14588008.831568146,
#  -14602729.151789125,
#  -14616823.006392736,
#  -14644326.875623737,
#  -14660033.246852217,
#  -14684170.841531847,
#  -14692499.215348767,
#  -14711426.901908167,
#  -14737271.324836656,
#  -14788547.342944207,
#  -14818983.838087928,
#  -14851464.679004138,
#  -14884966.309117258,
#  -14915245.240812436,
#  -14938964.002014166,
#  -14959367.326648256,
#  -14983488.798469005,
#  -15013230.867628675,
#  -15042803.805798836,
#  -15069155.300291436,
#  -15076880.347533887,
#  -15091710.651554829,
#  -15107107.010050299,
#  -15134668.09576067,
#  -15147507.17319789,
#  -15163965.335351368,
#  -15178756.881381707,
#  -15209882.670493867,
#  -15239871.191631107,
#  -15257895.213835198,
#  -15278153.72055804,
#  -15298451.84888243,
#  -15328067.71102809,
#  -15351919.56554875,
#  -15374351.131262109,
#  -15403378.09171079,
#  -15436593.24915025,
#  -15462388.25572232,
#  -15498297.23790957,
#  -15499013.372443011,
#  -15516799.06079249,
#  -15531014.680066701,
#  -15557759.15909406,
#  -15584120.05337067,
#  -15602722.175483858,
#  -15625311.943497678,
#  -15652356.515538687,
#  -15681394.349529387,
#  -15698333.388846297,
#  -15702189.215911547,
#  -15727405.268830508,
#  -15757226.312108088,
#  -15776407.265982568,
#  -15793826.891435198,
#  -15807438.377169838,
#  -15824209.722834768,
#  -15847393.083470097,
#  -15859475.998065868,
#  -15878709.291607998,
#  -15890370.24185206,
#  -15931760.695125269,
#  -15975084.34073313,
#  -16003276.06396568,
#  -16018649.83327038,
#  -16029884.015202371,
#  -16053506.22008888,
#  -16064084.99810324,
#  -16084902.60351428,
#  -16110352.383240791,
#  -16128148.194514873,
#  -16156892.079686703,
#  -16168264.901152883,
#  -16196760.278378522,
#  -16223022.862636643,
#  -16257925.452521643,
#  -16281516.484062493,
#  -16302538.877907623,
#  -16351594.113052871,
#  -16369659.73123314,
#  -16401837.23535429,
#  -16415251.469704349,
#  -16447619.51645423,
#  -16466890.610854149,
#  -16478675.689237298,
#  -16526345.607937288,
#  -16535831.833295507,
#  -16567550.886785747,
#  -16585816.152861908,
#  -16609506.610998947,
#  -16631393.472449176,
#  -16649704.238672826,
#  -16674063.897705266,
#  -16689170.638069127,
#  -16709959.374006826,
#  -16740185.062969208,
#  -16770002.865168778,
#  -16796858.769985817,
#  -16826131.007384606,
#  -16838404.359828215,
#  -16839978.444917817,
#  -16859059.781922806,
#  -16878496.367818438,
#  -16901426.756698247,
#  -16915775.50395937,
#  -16936489.57018396,
#  -16959115.42614328,
#  -16977689.61941861,
#  -16999638.659329332,
#  -17035644.82048536,
#  -17049904.84835228,
#  -17065186.68881226,
#  -17103411.834773168,
#  -17131643.01989295,
#  -17143253.32467467,
#  -17149695.59704372,
#  -17183065.474948637,
#  -17225053.90887987,
#  -17250911.9839542,
#  -17256157.826996487,
#  -17278349.73783048,
#  -17284587.79231305,
#  -17304654.31374614,
#  -17324665.24488143,
#  -17362413.588094108,
#  -17368350.03080373,
#  -17392351.013705187,
#  -17413655.107643306,
#  -17414659.874549385,
#  -17446703.471140586,
#  -17462231.194926824,
#  -17496837.142751034,
#  -17519129.226171102,
#  -17542069.868454993,
#  -17560877.199423384,
#  -17572786.365542777,
#  -17588801.96865901,
#  -17599414.13131866,
#  -17612720.464333378,
#  -17635492.718058668,
#  -17638558.06325679,
#  -17652639.818278957,
#  -17663890.52501182,
#  -17679490.847298168,
#  -17732860.942625757,
#  -17753358.503482055,
#  -17784504.367743935,
#  -17806944.077130772,
#  -17848306.411705133,
#  -17878421.262188405,
#  -17891363.748205204,
#  -17915165.743385363,
#  -17942693.17587528,
#  -17986305.81178308,
#  -18004099.68549521,
#  -18042650.561509196,
#  -18051116.696184225,
#  -18064200.72161225,
#  -18079701.88502643,
#  -18098040.63173882,
#  -18139261.00962265,
#  -18149105.86076663,
#  -18160247.455917038,
#  -18187460.68084313,
#  -18218711.27844376,
#  -18247667.886432104,
#  -18264479.970577125,
#  -18288452.072675955,
#  -18325022.891455352,
#  -18337202.92927718,
#  -18359546.992134683,
#  -18373364.341518555,
#  -18382857.782796483,
#  -18401608.841696464,
#  -18406806.605985682,
#  -18444953.620077603,
#  -18474817.72708553,
#  -18492802.01802782,
#  -18522628.5632278,
#  -18545376.68445686,
#  -18568641.28964248,
#  -18589310.41612268,
#  -18611096.56276871,
#  -18622338.875276558,
#  -18654345.44106932,
#  -18683812.68586706,
#  -18694198.71739198,
#  -18708367.61545735,
#  -18709522.31603485,
#  -18711445.309242718,
#  -18739100.458517898,
#  -18766292.292969868,
#  -18801540.85534161,
#  -18818223.30984063,
#  -18846854.37200297,
#  -18857391.057535823,
#  -18876732.134384803,
#  -18905502.49242195,
#  -18921363.94019091,
#  -18946795.78311998,
#  -18974085.472829822,
#  -18994368.063946433,
#  -18999695.511562992,
#  -19018352.38978865,
#  -19034795.91439164,
#  -19050796.17233584,
#  -19063664.59507886,
#  -19077604.24242381,
#  -19077158.50958264,
#  -19095199.30613269,
#  -19107805.59226253,
#  -19125659.746003866,
#  -19148245.811243955,
#  -19161851.068866003,
#  -19197198.281871032,
#  -19211331.10297156,
#  -19227254.983064212,
#  -19251493.512316283,
#  -19264704.062372223,
#  -19288615.96559321,
#  -19313663.35351305,
#  -19336819.02663108,
#  -19338544.99394711,
#  -19366712.06405831,
#  -19416632.7903985,
#  -19432568.89426877,
#  -19464737.66304505,
#  -19485251.271061067,
#  -19513291.718165737,
#  -19519889.50654725,
#  -19534909.64428927,
#  -19563270.79786555,
#  -19587495.20252968,
#  -19604815.27555303,
#  -19635748.40782806,
#  -19658002.975898128,
#  -19690228.09350742,
#  -19711731.05130142,
#  -19740657.89927844,
#  -19774045.51329812,
#  -19798858.76760041,
#  -19831914.6851721,
#  -19852565.811620187,
#  -19874598.097879738,
#  -19882312.65634703,
#  -19886221.959874187,
#  -19901323.86255305,
#  -19903056.12940345,
#  -19916724.91540307,
#  -19952059.449365854,
#  -19959040.814461544,
#  -19978713.066428576,
#  -19982203.79113168,
#  -20023125.11797977,
#  -20032995.23639242,
#  -20052725.93257473,
#  -20083518.55568313,
#  -20110425.33212771,
#  -20131076.5652513,
#  -20155236.5375328,
#  -20178009.17299501,
#  -20215796.23984944,
#  -20225165.42529418,
#  -20250505.79542292,
#  -20263213.906988688,
#  -20299717.669671487,
#  -20335058.670749288,
#  -20355013.288348686,
#  -20380004.598522525,
#  -20411132.593051903,
#  -20433855.135580912,
#  -20462597.48138237,
#  -20502658.28254359,
#  -20517320.9427768,
#  -20537374.97900431,
#  -20553216.22856942,
#  -20584411.61470528,
#  -20605062.93043337,
#  -20633160.692178402,
#  -20674988.698862784,
#  -20709263.357425302,
#  -20731815.68587846,
#  -20749001.005582668,
#  -20780274.6304464,
#  -20788889.07466769,
#  -20803494.04373022,
#  -20823686.36281611,
#  -20856533.38712405,
#  -20868236.100218672,
#  -20908611.314555053,
#  -20941729.45519901,
#  -20953886.92258211,
#  -20976850.49899713,
#  -21009388.52235448,
#  -21022543.0301954,
#  -21040663.92179466,
#  -21061643.70278397,
#  -21072072.051668297,
#  -21101376.975554578,
#  -21130110.54272496,
#  -21160567.9264807,
#  -21182846.518173378,
#  -21209021.070887417,
#  -21224794.880515914,
#  -21227870.942956585,
#  -21251150.738735016,
#  -21251331.32303006,
#  -21281785.85191575,
#  -21311379.304845832,
#  -21322033.99555135,
#  -21355680.494089033,
#  -21376635.429101195,
#  -21408603.171229348,
#  -21451823.046295017,
#  -21448883.158906527,
#  -21470781.814899657,
#  -21501861.8072721,
#  -21519051.13412485,
#  -21566121.14798279,
#  -21580296.045166124,
#  -21602383.383545574,
#  -21626154.482788194,
#  -21637178.446612153,
#  -21656295.906006344,
#  -21682388.829410203,
#  -21691845.246860433,
#  -21706130.485694043,
#  -21723647.326907072,
#  -21757955.04169258,
#  -21793892.360672563,
#  -21809469.050358742,
#  -21835915.674832445,
#  -21878786.791494377,
#  -21883274.40940533]

# %%
sub1=plt.subplot(1, 2, 1)##############################################################
iteration=[]
for i in range(0,999):
    iteration.append(i)

#在同一幅图片上画3条折线
A,=plt.plot(iteration,dynamic_regret,color = 'red',linewidth = '1.5',label='large-attack online primal-dual algorithm')


#设置图例并且设置图例的字体及大小
font1 = {
'size'   : 18,
}
#legend = plt.legend(handles=[A],prop=font1)
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=18)
 
#设置横纵坐标的名称以及对应字体格式
font2 = {
'size'   : 18,
}
plt.xlabel('T',font2)
plt.ylabel(r'Dynamic regret $Reg(T)$',font2)
plt.title('varying $D_{t}$',font2) 

sub2=plt.subplot(1, 2, 2)##############################################################
iteration=[]
for i in range(0,999):
    iteration.append(i)

#在同一幅图片上画3条折线
A,=plt.plot(iteration,dynamic_regret_T,color = 'red',linewidth = '1.5',label='large-attack online primal-dual algorithm')


#设置图例并且设置图例的字体及大小
font1 = {
'size'   : 18,
}
#legend = plt.legend(handles=[A],prop=font1)
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=18)
 
#设置横纵坐标的名称以及对应字体格式
font2 = {
'size'   : 18,
}
plt.xlabel('T',font2)
plt.ylabel(r'Dynamic regret $Reg(T)/T$',font2)
plt.title('varying $D_{t}$',font2) 

plt.legend(handles=[A],prop={'size':18},loc="upper center", bbox_to_anchor=[-0.3, -0.2],
           ncol=18, shadow=True, fancybox=True)

plt.subplots_adjust(wspace=0.5,hspace=0.5) 
plt.gcf().set_size_inches((15, 5))

#plt.savefig('./figures/01-figure1_dynamic_regret_attack_free_varying_D.pdf',format='pdf', bbox_inches='tight')
#plt.savefig('./figures/01-figure1_dynamic_regret_attack_free_varying_D.png',format='png', bbox_inches='tight')

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
from sympy import *
import math 
from datetime import datetime
from scipy.special import gamma, factorial
import scipy.special as sc

# %%
sum_thermal_wind_power_station_strategy=np.loadtxt("./data/04_SCC_optimal_parameters_large_Byzantine_attack_sum_thermal_wind_power_station_strategy.txt")
d_power_demand=np.loadtxt("./data/d_power_demand_normal_distribution_(100,10).txt")

# %%
accumulative_constraint_violation=[]
accumulative_constraint_violation_T=[]
for T in range(1, 1000):
    accumulative_constraint_violation_auxiliary_variable=0
    for t in range(0, T): 
        accumulative_constraint_violation_auxiliary_variable=accumulative_constraint_violation_auxiliary_variable+(1/58)*sum_thermal_wind_power_station_strategy[t+1]-d_power_demand[t+1]
    accumulative_constraint_violation.append(abs(accumulative_constraint_violation_auxiliary_variable))
    accumulative_constraint_violation_T.append(abs(accumulative_constraint_violation_auxiliary_variable)/T)

# %%
accumulative_constraint_violation
# Out:
# [31.98579342931035,
#  51.16699213517242,
#  63.20242214896551,
#  54.73047752879312,
#  66.70184344310346,
#  45.902835210000006,
#  40.03025949310347,
#  24.1934328074138,
#  28.771924147068972,
#  7.608378370517244,
#  15.766430989137916,
#  49.338562488103435,
#  77.8454130201724,
#  97.55005725913793,
#  127.93402262327585,
#  148.3538376405172,
#  158.0713054953448,
#  181.67089598603445,
#  183.4221047793103,
#  196.4063612727586,
#  246.90952657517238,
#  257.3598287865517,
#  279.3398316639655,
#  303.9972845443104,
#  318.3434845682759,
#  338.91599785706904,
#  371.56153237086215,
#  397.77403761672423,
#  423.3862569936208,
#  453.8452555560346,
#  491.7108100601725,
#  517.5798426212069,
#  528.9505552696552,
#  557.8620462101725,
#  554.4071701127586,
#  588.5898280608621,
#  618.7821908246553,
#  636.347337677414,
#  650.6794855937933,
#  678.6785616389657,
#  705.8479613350002,
#  732.1754024715519,
#  749.6631606682761,
#  798.780416847414,
#  829.3722888136209,
#  855.4610115332761,
#  877.3045350982761,
#  911.0254255991382,
#  948.2574659341382,
#  966.3135550151727,
#  987.3719861803452,
#  1007.4861967412072,
#  1019.4610054170694,
#  1045.3961529763797,
#  1058.93090741069,
#  1080.5888427244831,
#  1089.30430388069,
#  1113.3637260893106,
#  1149.761699293276,
#  1158.2129372605173,
#  1188.0850745281036,
#  1220.315041357069,
#  1234.9141189656896,
#  1246.089402641724,
#  1276.6949891599997,
#  1296.8115827253446,
#  1326.7783985891379,
#  1354.7985385610345,
#  1379.9387103525862,
#  1389.6170461456898,
#  1405.928368098793,
#  1425.8068589831034,
#  1444.4287321108623,
#  1482.0326327393104,
#  1505.7748200498277,
#  1541.2553074862071,
#  1572.1053531256898,
#  1582.0697497786207,
#  1591.323323484655,
#  1609.241764773793,
#  1633.0448732305172,
#  1654.4331970031035,
#  1676.5359657393103,
#  1690.888123987931,
#  1717.9379600244827,
#  1737.9008235606896,
#  1774.4331937305174,
#  1787.5727225193104,
#  1808.4137081575864,
#  1834.8669685656898,
#  1864.2482977922416,
#  1882.813545011207,
#  1912.168362812069,
#  1939.8780148894828,
#  1963.3077781132758,
#  1998.7201320056897,
#  2024.2349336717243,
#  2053.4204144543105,
#  2080.5880859753447,
#  2079.087471308448,
#  2108.022666901207,
#  2133.1476391913793,
#  2161.4888901889653,
#  2187.9124165815515,
#  2211.3197338693103,
#  2226.0943423824137,
#  2249.448467529655,
#  2275.276144555689,
#  2325.4670473063784,
#  2347.4275731537923,
#  2356.9142128717235,
#  2385.864583937413,
#  2410.0510633117233,
#  2420.3742955568955,
#  2451.405576621206,
#  2469.5116207348265,
#  2479.5190916851716,
#  2501.1978670296544,
#  2531.0498991322406,
#  2567.252174456551,
#  2569.77784352931,
#  2583.6858246093097,
#  2590.650252258965,
#  2630.0162400013787,
#  2661.4086880255163,
#  2695.855416200344,
#  2697.2863106589643,
#  2733.0280001253436,
#  2741.3236387862057,
#  2766.6569039548267,
#  2788.357664275172,
#  2799.7735114196544,
#  2820.8762263251715,
#  2856.3514602534474,
#  2889.092243897068,
#  2902.439981590344,
#  2934.6508260848263,
#  2955.7454880444816,
#  2978.8927505187917,
#  3005.9183694387916,
#  3045.37393670724,
#  3083.029312070171,
#  3086.396648333619,
#  3106.8811218029296,
#  3144.267242414309,
#  3167.055396406033,
#  3192.1973669343092,
#  3210.7984606427576,
#  3236.280207972758,
#  3250.8476534649994,
#  3279.581849599827,
#  3299.779234658965,
#  3323.6133226506895,
#  3337.0368448922413,
#  3363.331678392931,
#  3367.568978326724,
#  3386.3875966137925,
#  3389.369794905862,
#  3403.467706687241,
#  3430.4558414358617,
#  3450.213932895172,
#  3473.1267394915517,
#  3490.4269169506897,
#  3538.944426833793,
#  3572.118931849138,
#  3615.8862215358618,
#  3631.380702146379,
#  3647.622016480517,
#  3671.0965148074133,
#  3705.3580335849992,
#  3715.9060615870685,
#  3719.927117033965,
#  3751.575370629827,
#  3765.2735350201715,
#  3791.0345615368956,
#  3808.067548860861,
#  3835.942667920516,
#  3858.75261533793,
#  3870.2462269382745,
#  3881.993072358792,
#  3908.75765732724,
#  3935.796987573447,
#  3972.805839549137,
#  4006.198458282413,
#  4025.7569389946543,
#  4051.8777558572406,
#  4086.4029014277576,
#  4115.696965762758,
#  4139.007872417758,
#  4144.856978106896,
#  4167.353906617758,
#  4160.6397611096545,
#  4190.766948466896,
#  4210.882994020862,
#  4224.295587177413,
#  4251.446127662068,
#  4283.849270524482,
#  4294.786445406551,
#  4305.348805517759,
#  4312.175117621035,
#  4325.361487426379,
#  4349.598626193793,
#  4389.484674439484,
#  4410.393103876552,
#  4447.693486282759,
#  4469.120418934311,
#  4479.378571632759,
#  4500.42374131638,
#  4517.901344421208,
#  4528.222078949138,
#  4552.274093027069,
#  4570.93652428,
#  4583.557369268276,
#  4595.897510552932,
#  4630.962755513449,
#  4646.063601471726,
#  4660.482285245864,
#  4680.469997942243,
#  4715.912395524139,
#  4728.184450832415,
#  4740.474691761898,
#  4753.590428426898,
#  4769.307439779656,
#  4804.963556326553,
#  4814.15320713138,
#  4838.965250377242,
#  4851.972561870173,
#  4870.068317932932,
#  4895.056527592242,
#  4914.281577250863,
#  4935.061815096725,
#  4965.041293096725,
#  4983.6940466175865,
#  4992.453355255518,
#  5013.980779241552,
#  5032.211912966552,
#  5042.107342122069,
#  5067.637242377242,
#  5090.3257204532765,
#  5122.448924210517,
#  5138.198200075,
#  5158.880649199656,
#  5190.09841177638,
#  5224.615557658449,
#  5265.063280767243,
#  5298.613668136725,
#  5316.108748603277,
#  5334.929107487242,
#  5369.918794669138,
#  5389.056374787931,
#  5408.955715542586,
#  5444.490117495862,
#  5470.799892094311,
#  5490.554920752587,
#  5508.79492715345,
#  5525.389139694829,
#  5559.539386931553,
#  5585.902160651898,
#  5609.351769483622,
#  5632.979083494139,
#  5649.249362008104,
#  5688.065582238966,
#  5705.839793079139,
#  5722.90714881276,
#  5737.947097209657,
#  5755.0577415505195,
#  5776.156115912933,
#  5801.086075291899,
#  5826.322476280175,
#  5843.033274976381,
#  5877.885282791726,
#  5907.128916646208,
#  5929.195730431726,
#  5942.72559905138,
#  5966.366872151209,
#  5986.785026941898,
#  6015.529107335691,
#  6045.562580814312,
#  6082.993873665691,
#  6091.730045159313,
#  6123.959598388106,
#  6158.329015497072,
#  6174.989475488624,
#  6200.143771926209,
#  6222.942814089312,
#  6229.571836537589,
#  6249.493914402072,
#  6291.621634106209,
#  6304.677165636554,
#  6326.7702251377605,
#  6374.347396990864,
#  6401.326042976725,
#  6407.608827175863,
#  6415.756972173966,
#  6445.575450613794,
#  6490.414567345345,
#  6498.161286780172,
#  6530.889600630862,
#  6569.4608010018965,
#  6579.900843422414,
#  6601.655026505346,
#  6619.129177489656,
#  6635.4689163074145,
#  6638.3189836236215,
#  6653.00180312707,
#  6669.279083431726,
#  6708.100826935001,
#  6741.960708208794,
#  6760.581412683794,
#  6790.708265656208,
#  6799.748522105863,
#  6811.816896851208,
#  6845.535036905347,
#  6864.663897355174,
#  6905.1517588218985,
#  6945.553722887588,
#  6974.616702533968,
#  7000.916604725519,
#  7026.9031362568985,
#  7055.484663524657,
#  7089.55964744845,
#  7103.333067188795,
#  7097.962313684312,
#  7137.777992709312,
#  7150.373724381036,
#  7168.486676601036,
#  7189.79788247483,
#  7216.793940742071,
#  7236.878715028795,
#  7271.652080733451,
#  7292.01887679052,
#  7308.187658974485,
#  7337.661920979485,
#  7341.800259637934,
#  7354.486751362244,
#  7379.919007440864,
#  7407.72669168414,
#  7417.771519411382,
#  7434.731924740519,
#  7444.127633072589,
#  7473.740693278106,
#  7509.600367024657,
#  7556.834245876209,
#  7579.186634297071,
#  7607.415915573451,
#  7634.71998211414,
#  7663.879571210003,
#  7678.463740604658,
#  7714.527662555692,
#  7746.754848785002,
#  7776.956326802416,
#  7803.1599301405195,
#  7822.27442623345,
#  7841.256824333795,
#  7866.272569781208,
#  7886.93457180845,
#  7938.509327873106,
#  7972.244363387588,
#  7993.39643467914,
#  8004.979585248623,
#  8045.270586155865,
#  8068.3648909093135,
#  8085.528987637072,
#  8122.406124433968,
#  8145.773093417071,
#  8172.235997867243,
#  8177.611279544657,
#  8186.78847285845,
#  8190.708918932071,
#  8216.329952261382,
#  8219.654986566728,
#  8239.048084906382,
#  8251.363204477933,
#  8257.588543996382,
#  8268.379209341037,
#  8298.981285235692,
#  8302.804893476035,
#  8311.684953630518,
#  8315.070320686897,
#  8343.636572786552,
#  8368.910308092069,
#  8388.489103709138,
#  8410.490209078276,
#  8428.868843578104,
#  8446.15739310069,
#  8459.353034437068,
#  8475.806847295344,
#  8502.04823696431,
#  8535.512430863448,
#  8552.273412646035,
#  8558.760404958277,
#  8569.145416483449,
#  8587.012178625173,
#  8608.835019396382,
#  8613.019495070692,
#  8631.821731562588,
#  8647.854804653967,
#  8675.62654489138,
#  8697.999619948105,
#  8716.352924302932,
#  8739.572122258793,
#  8768.688725701551,
#  8782.003723979828,
#  8804.400586258103,
#  8824.738273515344,
#  8850.64061151069,
#  8858.343896417931,
#  8882.804585436208,
#  8914.558457115172,
#  8940.250182356724,
#  8971.302300590689,
#  9018.161655872585,
#  9024.326847731723,
#  9050.422344624654,
#  9092.295358507587,
#  9099.61620225069,
#  9133.631401603448,
#  9176.284390625518,
#  9212.745557930346,
#  9236.627645803967,
#  9265.375956650863,
#  9290.216339502931,
#  9313.639988028277,
#  9348.73404430776,
#  9370.482933915346,
#  9385.653671782587,
#  9415.295160340174,
#  9444.088083915174,
#  9487.06127660276,
#  9516.056353324311,
#  9542.341370658794,
#  9566.217202314485,
#  9587.366113842416,
#  9623.006544620173,
#  9642.793610039656,
#  9685.875451531036,
#  9714.432315336035,
#  9737.700137392587,
#  9768.221830193448,
#  9799.968819087757,
#  9814.591515671722,
#  9840.671197063963,
#  9856.642523613446,
#  9889.907624539996,
#  9916.199469764995,
#  9937.596517502754,
#  9956.76243526896,
#  9982.790620872926,
#  10014.832847955857,
#  10016.726631746891,
#  10026.836747796719,
#  10035.491297107752,
#  10050.191884597061,
#  10088.191679352407,
#  10087.866094561372,
#  10114.06205780275,
#  10136.797632866717,
#  10154.791984702408,
#  10181.33300437258,
#  10205.484134625856,
#  10218.879462419822,
#  10254.69191979189,
#  10273.520190981028,
#  10291.306945627752,
#  10309.95071889689,
#  10346.285808591889,
#  10366.288959688614,
#  10378.863860330339,
#  10404.988571074131,
#  10412.915327113613,
#  10438.111865601371,
#  10481.074183209821,
#  10496.883121934821,
#  10514.558532230856,
#  10522.96497452551,
#  10534.312285870164,
#  10562.161183197406,
#  10587.241594327063,
#  10616.684920790338,
#  10641.180782602063,
#  10652.737362691372,
#  10693.174350515683,
#  10722.3051420312,
#  10745.542116638959,
#  10779.916172534304,
#  10803.423804623959,
#  10807.250839807924,
#  10842.582375024476,
#  10859.641939622752,
#  10897.45802076189,
#  10899.467674250855,
#  10929.948156467406,
#  10963.654648664304,
#  10987.495095643098,
#  11022.782958178444,
#  11042.53109438517,
#  11065.641337073963,
#  11081.291901895169,
#  11103.805401632755,
#  11124.628797002239,
#  11139.863343047067,
#  11157.372020092585,
#  11185.356417947756,
#  11214.758743094653,
#  11232.94354542948,
#  11250.69076216241,
#  11276.462838104824,
#  11300.271705540514,
#  11330.70371450155,
#  11343.481277606377,
#  11385.029220149481,
#  11415.103737952413,
#  11434.386563572585,
#  11451.080835507068,
#  11434.640793258275,
#  11461.075319245345,
#  11470.441743445346,
#  11499.173974859657,
#  11519.73158409552,
#  11539.883934396554,
#  11558.838368056036,
#  11583.135373819312,
#  11603.952635571382,
#  11619.933798515176,
#  11670.78513622328,
#  11690.119975047244,
#  11702.760869320691,
#  11730.694044979138,
#  11752.729761875862,
#  11786.717502498277,
#  11805.462437835864,
#  11835.489727148795,
#  11852.73502548552,
#  11898.527921357416,
#  11924.715302565002,
#  11967.618220651038,
#  11994.118743893452,
#  12025.415819812935,
#  12050.929227201039,
#  12074.777105400693,
#  12105.990835973626,
#  12135.111516783452,
#  12153.168057163797,
#  12179.67139083604,
#  12219.490472613454,
#  12236.3215769438,
#  12264.612870373281,
#  12256.503850218625,
#  12291.992098522074,
#  12301.571888117247,
#  12330.084837939316,
#  12347.637437152936,
#  12367.841049756213,
#  12388.503515058454,
#  12410.122701003453,
#  12412.17674624897,
#  12431.926964407936,
#  12434.418656714832,
#  12467.208162980522,
#  12489.780864344144,
#  12506.690675329834,
#  12529.438130634144,
#  12544.482311824833,
#  12568.41229786035,
#  12592.325205373454,
#  12623.915748800868,
#  12631.632069283281,
#  12671.918180589833,
#  12689.794634167936,
#  12719.596333652591,
#  12734.052408401385,
#  12772.177248164833,
#  12782.805966255868,
#  12804.219859173281,
#  12835.741296097764,
#  12849.54548738966,
#  12866.71093913173,
#  12880.081341025523,
#  12899.823481146384,
#  12926.20281815173,
#  12956.440856627249,
#  12990.225714010006,
#  13025.717673627765,
#  13049.252656415867,
#  13054.961618731557,
#  13080.19713800466,
#  13108.557001818626,
#  13133.90887923742,
#  13152.657492235698,
#  13184.352847654663,
#  13184.261988900182,
#  13201.592613863286,
#  13219.846265808284,
#  13246.18880330725,
#  13258.7085344738,
#  13281.85178955225,
#  13313.593632852595,
#  13327.047894693113,
#  13350.031601351217,
#  13369.28486597932,
#  13401.236143171905,
#  13407.939769379147,
#  13423.147261973974,
#  13441.197191497766,
#  13465.132261001387,
#  13487.816119377765,
#  13527.791667286387,
#  13564.010302774663,
#  13571.538177016904,
#  13613.821583495697,
#  13629.619356670353,
#  13673.583700042765,
#  13710.8997183638,
#  13725.922529879317,
#  13752.701624351386,
#  13779.699444298283,
#  13807.247095257422,
#  13834.118144150008,
#  13852.376596262768,
#  13866.027235239148,
#  13888.244841096044,
#  13889.738900737078,
#  13900.915786785527,
#  13906.593865523113,
#  13937.576736197767,
#  13961.746584267594,
#  13991.565517894318,
#  13988.307873146387,
#  14013.560980832248,
#  14040.013587679663,
#  14058.225847042422,
#  14089.74262032432,
#  14113.312856416733,
#  14112.629849423802,
#  14129.940438204836,
#  14148.532168891905,
#  14173.097349375526,
#  14198.668290300526,
#  14218.78562379087,
#  14242.619458244491,
#  14271.1613782288,
#  14297.206498828455,
#  14332.829975610697,
#  14343.336160326731,
#  14366.46719217156,
#  14388.458791175526,
#  14412.216731057422,
#  14448.93573042225,
#  14473.701118670526,
#  14495.895288751215,
#  14525.487595870525,
#  14549.694865469492,
#  14576.5550022907,
#  14602.60959265363,
#  14621.691849172597,
#  14642.376168615701,
#  14668.005172522599,
#  14700.162127367772,
#  14734.310945016738,
#  14770.533541322944,
#  14788.544646521219,
#  14813.625417751564,
#  14835.772520917599,
#  14846.439525965703,
#  14868.570159654497,
#  14878.638790539842,
#  14898.480547890877,
#  14914.396283559325,
#  14929.708481480531,
#  14957.515884887944,
#  14974.379704962772,
#  14999.109596886565,
#  15008.723350488634,
#  15028.631474397598,
#  15054.938902372942,
#  15103.648969153459,
#  15134.143225956908,
#  15166.476296623116,
#  15199.721160053288,
#  15230.057390248116,
#  15254.400137500876,
#  15275.66861556829,
#  15300.366422228979,
#  15330.183860143463,
#  15359.841478092774,
#  15386.562192501568,
#  15395.553883466222,
#  15411.542249152084,
#  15428.068545302429,
#  15455.865582258464,
#  15469.92623407605,
#  15487.45607897657,
#  15503.399643398467,
#  15534.423498969156,
#  15564.4236820945,
#  15583.429803419845,
#  15604.515219094155,
#  15625.636756272948,
#  15655.297578834672,
#  15679.702770022603,
#  15702.798565762603,
#  15731.923680615879,
#  15764.82084093812,
#  15791.000352590707,
#  15826.292976331397,
#  15828.024103786052,
#  15846.784003967949,
#  15862.157677450536,
#  15889.184557625707,
#  15915.863010060535,
#  15935.384167871396,
#  15958.602098877775,
#  15985.901780152948,
#  16015.011278695707,
#  16032.97228336019,
#  16037.988002175707,
#  16063.6129870345,
#  16093.429491896568,
#  16113.488517054671,
#  16131.90129523243,
#  16146.690453131396,
#  16164.496025994671,
#  16188.265545327256,
#  16201.574228778636,
#  16221.692981976395,
#  16234.592083365878,
#  16274.723407290534,
#  16316.542477132258,
#  16344.917712080016,
#  16361.416841102948,
#  16373.900573206396,
#  16398.092300393808,
#  16409.92905839984,
#  16431.53285739105,
#  16457.40692678536,
#  16476.20096997467,
#  16505.08217882588,
#  16517.70910665657,
#  16546.368569580536,
#  16572.999204467258,
#  16607.430828218465,
#  16631.613814438293,
#  16653.421349773293,
#  16700.16023036933,
#  16719.211693858637,
#  16751.186021462432,
#  16765.802752017258,
#  16797.93552064812,
#  16818.091961302773,
#  16831.114061215187,
#  16876.61820139053,
#  16887.36475575191,
#  16918.88833038984,
#  16938.087553866048,
#  16962.30355569329,
#  16984.8329285607,
#  17004.071989425007,
#  17028.897661249317,
#  17045.114649653802,
#  17066.650635734146,
#  17096.811914441212,
#  17126.603446583624,
#  17153.707497122414,
#  17182.999626902416,
#  17196.47496264121,
#  17199.114419816895,
#  17219.04710196724,
#  17239.313280937757,
#  17262.814725894656,
#  17278.29500689983,
#  17299.748139605173,
#  17322.970512498276,
#  17342.44021428724,
#  17365.041957719826,
#  17400.352233196725,
#  17415.750946453794,
#  17432.127113817416,
#  17469.53832144621,
#  17497.947579652933,
#  17510.792847074656,
#  17518.461009911036,
#  17551.488478547413,
#  17592.141969628105,
#  17618.379108226727,
#  17624.825352254484,
#  17647.682888692932,
#  17655.144717192932,
#  17676.03484237104,
#  17696.876362907933,
#  17733.81157901897,
#  17740.967350362243,
#  17765.503247624143,
#  17787.55412342121,
#  17789.585811080695,
#  17821.445245286555,
#  17838.095139845,
#  17872.264311123105,
#  17895.250678595174,
#  17918.839033135002,
#  17938.593403861036,
#  17951.75101619828,
#  17968.878137620693,
#  17980.758489523105,
#  17995.286472713793,
#  18018.738742722588,
#  18022.934572677415,
#  18038.22680930845,
#  18050.75496451845,
#  18067.52159311604,
#  18118.03140422638,
#  18139.43128688983,
#  18170.597079377247,
#  18193.805779863455,
#  18234.07815864587,
#  18264.318822492245,
#  18278.535545149487,
#  18302.999812971382,
#  18330.879339949486,
#  18373.10050425483,
#  18391.971115072593,
#  18429.74352070604,
#  18439.502077327936,
#  18453.844648224658,
#  18470.51926697914,
#  18489.879657056554,
#  18529.97138640845,
#  18541.1121109188,
#  18553.54164724242,
#  18581.095330067936,
#  18612.31356605604,
#  18641.455154596042,
#  18659.37234938863,
#  18683.951685490698,
#  18719.927141968456,
#  18733.375031901214,
#  18756.443735386045,
#  18771.482972565354,
#  18782.26338547139,
#  18801.989918433286,
#  18808.40815343777,
#  18845.77462353294,
#  18875.730657758973,
#  18894.747942454836,
#  18924.66915083863,
#  18948.119116711558,
#  18972.04491119966,
#  18993.567261574142,
#  19016.124408135867,
#  19028.646384237247,
#  19060.53335272897,
#  19090.128211531384,
#  19101.800495581214,
#  19117.180739124487,
#  19119.375557611213,
#  19122.38067020432,
#  19150.335477802422,
#  19177.879000873458,
#  19212.70414085139,
#  19230.51420198639,
#  19259.38469464225,
#  19271.21946714173,
#  19291.537901942076,
#  19320.54580382104,
#  19337.58526093225,
#  19363.54915794846,
#  19391.21697217639,
#  19412.427422594836,
#  19418.982475195528,
#  19438.6774900857,
#  19456.283997194838,
#  19473.470429631736,
#  19487.62796362846,
#  19502.83513298432,
#  19503.30440780777,
#  19522.45149435294,
#  19536.36899797518,
#  19555.358618187765,
#  19578.78118547742,
#  19593.698845327763,
#  19628.76627602638,
#  19644.212848196035,
#  19661.400581126723,
#  19686.400246894827,
#  19700.956665565864,
#  19725.669660985004,
#  19751.438873010004,
#  19775.464894594486,
#  19778.247140022242,
#  19806.894902457414,
#  19854.803068696725,
#  19872.047908116554,
#  19904.348504651207,
#  19925.941918702243,
#  19954.48905271638,
#  19962.392210023798,
#  19978.748847277246,
#  20007.587709579315,
#  20032.628534449315,
#  20051.20625804897,
#  20082.389771378796,
#  20105.60759629293,
#  20137.960525979655,
#  20160.47702457069,
#  20189.830710346378,
#  20223.222073563964,
#  20248.795548432412,
#  20281.877249777586,
#  20303.579617477757,
#  20326.56050944017,
#  20335.61473761603,
#  20340.728761883616,
#  20357.14332946379,
#  20359.956227397928,
#  20374.97637145155,
#  20410.084294602413,
#  20418.38498961431,
#  20439.169314325864,
#  20443.83645011845,
#  20483.936369648796,
#  20495.184032525693,
#  20516.043332817073,
#  20547.103145221903,
#  20574.623509234316,
#  20596.35719356449,
#  20621.352763544834,
#  20645.064996621557,
#  20682.42548943656,
#  20693.171767397766,
#  20719.255604364316,
#  20733.353390604145,
#  20769.565830900698,
#  20804.73927674828,
#  20825.821316125177,
#  20851.578247921385,
#  20882.941839902764,
#  20906.59289608914,
#  20935.776143775172,
#  20975.12069308224,
#  20991.12578317138,
#  21012.267094835002,
#  21029.40419395121,
#  21060.77956420397,
#  21082.463526050353,
#  21111.011111406387,
#  21151.850436076387,
#  21185.975798179836,
#  21209.40014996501,
#  21227.788544445357,
#  21259.173065676736,
#  21269.125392003978,
#  21285.016566402253,
#  21306.20512354415,
#  21338.97813936053,
#  21352.01735911967,
#  21391.482112162943,
#  21424.485293373633,
#  21437.965050211566,
#  21461.694401069497,
#  21494.15086080553,
#  21508.59927462691,
#  21527.80468645398,
#  21549.67584981398,
#  21561.420436257773,
#  21590.920314032774,
#  21619.90339041053,
#  21650.452588421907,
#  21673.51559138725,
#  21700.15888013863,
#  21717.11612467363,
#  21721.335893817424,
#  21745.307489434836,
#  21746.462116927767,
#  21776.98849784139,
#  21806.743015164666,
#  21818.70344818639,
#  21852.11704459604,
#  21873.951313916732,
#  21905.86272557949,
#  21947.742642988454,
#  21945.502076343455,
#  21968.206649214146,
#  21999.31066268432,
#  22017.616932751906,
#  22062.809272871735,
#  22078.2282974357,
#  22101.103864601217,
#  22125.5325984707,
#  22137.856075753458,
#  22157.96369238553,
#  22184.519776371908,
#  22195.276207149494,
#  22210.794105944322,
#  22229.401739090874,
#  22263.400807711736,
#  22298.86046645122,
#  22315.628556965014,
#  22342.51721616605,
#  22384.082247257946,
#  22389.767301487256]

# %%
sub1=plt.subplot(1, 2, 1)##############################################################
iteration=[]
for i in range(0,999):
    iteration.append(i)

#在同一幅图片上画3条折线
A,=plt.plot(iteration,accumulative_constraint_violation,color = 'green',linewidth = '1.5',label='attack-free online primal-dual algorithm')


#设置图例并且设置图例的字体及大小
font1 = {
'size'   : 18,
}
#legend = plt.legend(handles=[A],prop=font1)
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=18)
 
#设置横纵坐标的名称以及对应字体格式
font2 = {
'size'   : 18,
}
plt.xlabel('T',font2)
plt.ylabel(r'Constraint violation $Fit(T)$',font2)
plt.title('varying $D_{t}$',font2) 

sub2=plt.subplot(1, 2, 2)##############################################################
iteration=[]
for i in range(0,999):
    iteration.append(i)

#在同一幅图片上画3条折线
A,=plt.plot(iteration,accumulative_constraint_violation_T,color = 'green',linewidth = '1.5',label='attack-free online primal-dual algorithm')


#设置图例并且设置图例的字体及大小
font1 = {
'size'   : 18,
}
#legend = plt.legend(handles=[A],prop=font1)
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=18)
 
#设置横纵坐标的名称以及对应字体格式
font2 = {
'size'   : 18,
}
plt.xlabel('T',font2)
plt.ylabel(r'Constraint violation $Fit(T)/T$',font2)
plt.title('varying $D_{t}$',font2) 

plt.legend(handles=[A],prop={'size':18},loc="upper center", bbox_to_anchor=[-0.3, -0.2],
           ncol=18, shadow=True, fancybox=True)

plt.subplots_adjust(wspace=0.5,hspace=0.5) 
plt.gcf().set_size_inches((15, 5))


#plt.savefig('./figures/01-figure2_constraint_violation_attack_free_varying_D.pdf',format='pdf', bbox_inches='tight')
#plt.savefig('./figures/01-figure2_constraint_violation_attack_free_varying_D.png',format='png', bbox_inches='tight')
