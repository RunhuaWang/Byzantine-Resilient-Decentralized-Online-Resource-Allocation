# %% [raw]
# IOS鲁棒的decentralized online economic dispatch algorithm+小值高斯攻击
#
# 实验设置：IEEE118bus+6个风能发电站
# 发电站数量：54个传统火力发电站+6个风能发电站
# 时变的变量：1. 风速服从的weibull分布的尺度参数c
# 2. 风速服从的weibull分布的形状参数wk
# 3. 用户侧的平均用电需求D
# 尺度参数c和形状参数wk采用真实数据集数据
# 平均用电需求D服从均值为100 均方差为10的正态分布
# 54个传统火力发电站的发电成本相关数据见数据集
# 传统火力发电站成本函数：a+bP+cP^2
# 6个风能发电站的发电成本相关参数见论文手稿
#
# 选择两个拜占庭发电站 一个为54号火力发电站 一个为58号风能发电站
#
# 小值高斯攻击
#
# IOS+adaptive clipping

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
from sympy import *
import math 
from datetime import datetime
from scipy.special import gamma, factorial
import scipy.special as sc

# %%
#定义变量
thermal_power_station_strategy=np.zeros(shape=(54,1000)) 
wind_power_station_strategy=np.zeros(shape=(6,1000))
thermal_power_station_dual_variable=np.zeros(shape=(54,1000))
wind_power_station_dual_variable=np.zeros(shape=(6,1000))
E=np.loadtxt("IEEE-118-doubly-stochastic-weight-matrix.txt")
thermal_power_station_cost=np.zeros(shape=(1,1000)) #火力发电成本
wind_power_station_cost=np.zeros(shape=(1,1000)) #风力发电成本
sum_cost=np.zeros(shape=(1,1000)) #总发电成本
sum_thermal_wind_power_station_strategy=np.zeros(shape=(1,1000))#总发电量
#火力发电站的相关数据  其中54号为拜占庭
generator_a_values= np.loadtxt("./real-data/generator_a_values.txt")#每个agent的成本函数中的超参数a
generator_b_values= np.loadtxt("./real-data/generator_b_values.txt")#每个agent的成本函数中的超参数a
generator_c_values= np.loadtxt("./real-data/generator_c_values.txt")#每个agent的成本函数中的超参数a
thermal_power_station_P_max= np.loadtxt("./real-data/generator_Pmax_values.txt")#每个agent的资源量的上界
thermal_power_station_P_min= np.loadtxt("./real-data/generator_Pmin_values.txt")#每个agent的资源量的下界
#55 56 57 58 59 60号诚实风能的成本相关数据 其中58号为拜占庭 
wind_power_station_varphi=[1,6,1,6,1,6]
wind_power_station_v_in=[3,4,5,3,4,5]
wind_power_station_v_out=[25,45,25,45,25,45]
wind_power_station_v_r=[13,15,16,13,15,16]
wind_power_station_sigma_ue=[3,5,3,5,3,5]
wind_power_station_sigma_oe=[20,30,20,30,20,30]
wind_power_station_P_r=[150,160,150,160,150,160]
wind_power_station_P_min=[0,0,0,0,0,0]
wind_power_station_P_max=[500,300,400,200,300,200]
#不确定性的参数 时变参数
d_power_demand=np.loadtxt("./data/d_power_demand_normal_distribution_(100,10).txt") #时变的需求侧用电需求  
c_wind_speed= np.loadtxt("./real-data/weibull_scale_c.txt")      
kappa_wind_speed= np.loadtxt("./real-data/weibull_shape_wk.txt") 
#迭代步长
step_size_primal=5
step_size_dual=5
#正则化参数
regularization_parameter=0.00001

small_Gaussian_Byzantine_attack=np.loadtxt("./data/small_Gaussian_Byzantine_attack_(-1500,30).txt")

# %%
#变量初始化
#火力，风力发电策略初始化 诚实
'''for i in range(0,53):
    thermal_power_station_strategy[i][0]=0
for j in range(0,6):
    if j!=3:
        wind_power_station_strategy[j][0]=0'''
for i in range(0,53):
    thermal_power_station_strategy[i][0]=thermal_power_station_P_max[i]
for j in range(0,6):
    if j!=3:
        wind_power_station_strategy[j][0]=thermal_power_station_P_max[j]
        
#拜占庭发电站发电策略初始化 拜占庭
thermal_power_station_strategy[53][0]=0
wind_power_station_strategy[3][0]=0
#诚实用户的初始总发电策略
'''sum_thermal_wind_power_station_strategy[0][0]=0'''
#诚实用户的初始总发电策略
for i in range(0,53):
    sum_thermal_wind_power_station_strategy[0][0]+=thermal_power_station_strategy[i][0]
for j in range(0,6):
    if j!=3:
        sum_thermal_wind_power_station_strategy[0][0]+= wind_power_station_strategy[j][0]

#火力，风力对偶策略初始化 诚实
for i in range(0,53):
    thermal_power_station_dual_variable[i][0]=-1000
for j in range(0,6):
    if j!=3:
        wind_power_station_dual_variable[j][0]=-1000
#拜占庭发电站对偶策略初始化 拜占庭
#拜占庭发电站对偶策略初始化 拜占庭
thermal_power_station_dual_variable[53][0]=small_Gaussian_Byzantine_attack[0]
wind_power_station_dual_variable[3][0]=small_Gaussian_Byzantine_attack[0]

#安全发电站的初始总发电成本 诚实
#火力发电成本
for i in range(0,53):
    thermal_power_station_cost[0][0]=thermal_power_station_cost[0][0]+generator_c_values[i]*thermal_power_station_strategy[i][0]*thermal_power_station_strategy[i][0]+generator_b_values[i]*thermal_power_station_strategy[i][0]+generator_a_values[i]
#风力发电成本
for i in range(0,6):
    if i!=3:
        wind_power_station_cost[0][0]=wind_power_station_cost[0][0]+wind_power_station_varphi[i]*wind_power_station_strategy[i][0]+wind_power_station_sigma_ue[i]*((wind_power_station_P_r[i]-wind_power_station_strategy[i][0])*(math.exp(-(math.pow(wind_power_station_v_r[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0])))-math.exp(-(math.pow(wind_power_station_v_out[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0]))))+(wind_power_station_P_r[i]*wind_power_station_v_in[i]/(wind_power_station_v_r[i]-wind_power_station_v_in[i])+wind_power_station_strategy[i][0])*(math.exp(-(math.pow(wind_power_station_v_r[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0])))-math.exp(-(math.pow(wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][0])/wind_power_station_P_r[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0]))))+(wind_power_station_P_r[i]*c_wind_speed[0]/(wind_power_station_v_r[i]-wind_power_station_v_in[i]))*(sc.gammaincc(1+1/kappa_wind_speed[0],(math.pow(wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][0])/wind_power_station_P_r[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0])))*sc.gamma(1+1/kappa_wind_speed[0])-sc.gammaincc(1+1/kappa_wind_speed[0],math.pow(wind_power_station_v_r[i]/c_wind_speed[0],kappa_wind_speed[0]))*sc.gamma(1+1/kappa_wind_speed[0])))+wind_power_station_sigma_oe[i]*((wind_power_station_strategy[i][0])*(1-math.exp(-(math.pow(wind_power_station_v_in[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0])))+math.exp(-(math.pow(wind_power_station_v_out[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0]))))+(wind_power_station_P_r[i]*wind_power_station_v_in[i]/(wind_power_station_v_r[i]-wind_power_station_v_in[i])+wind_power_station_strategy[i][0])*(math.exp(-(math.pow(wind_power_station_v_in[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0])))-math.exp(-(math.pow(wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][0])/wind_power_station_P_r[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0]))))+(wind_power_station_P_r[i]*c_wind_speed[0]/(wind_power_station_v_r[i]-wind_power_station_v_in[i]))*(sc.gammaincc(1+1/kappa_wind_speed[0],(math.pow(wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][0])/wind_power_station_P_r[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0])))*sc.gamma(1+1/kappa_wind_speed[0])-sc.gammaincc(1+1/kappa_wind_speed[0],math.pow(wind_power_station_v_in[i]/c_wind_speed[0],kappa_wind_speed[0]))*sc.gamma(1+1/kappa_wind_speed[0])))
#发电总成本
sum_cost[0][0]=thermal_power_station_cost[0][0]+wind_power_station_cost[0][0]

#计算每个发电站的邻居发电站
neighbor_robust1_help=[]
for i in range (0,60):
    for j in range (0,60):
        if E[i][j]!=0:
            neighbor_robust1_help.append(j)
        elif E[i][j]==0:
            neighbor_robust1_help.append(99)
neighbor_robust1=np.array(neighbor_robust1_help).reshape(60,60)

#计算安全的发电站的拜占庭邻居用户数量
q_robust1=[]
for i in range(0,60):
    q_robust1_help=0
    for j in range(0,60):
        if neighbor_robust1[i][j]==53 or neighbor_robust1[i][j]==57:
            q_robust1_help=q_robust1_help+1
    q_robust1.append(q_robust1_help)

# %%
def IOS_Byzantine_attack_decentralized_economic_dispatch(thermal_power_station_strategy,wind_power_station_strategy,c_wind_speed,kappa_wind_speed,d_power_demand,thermal_power_station_dual_variable,wind_power_station_dual_variable,E,thermal_power_station_cost,wind_power_station_cost,generator_a_values,generator_b_values,generator_c_values,thermal_power_station_P_min,thermal_power_station_P_max,wind_power_station_varphi,wind_power_station_sigma_ue,wind_power_station_sigma_oe,wind_power_station_P_min,wind_power_station_P_max,sum_thermal_wind_power_station_strategy,step_size_primal,step_size_dual):
    #显示初始化的数据
    #输出初始状态的原变量和对偶变量
    print("***************************large_attack_online_decentralized_economic_dispatch*****************************")
    print("相关变量初始值为：")
    for i in range (0,52):
        print("第",(i+1),"个火力发电站的初始计划发电量为:",thermal_power_station_strategy[i][0])
    for i in range (0,6):
        if i!=3:
            print("第",(i+55),"个风力发电站的初始计划发电量为:",wind_power_station_strategy[i][0])
    print("****************************************************************************")
    for i in range (0,52):
        print("第",(i+1),"个火力发电站的初始对偶变量为:",thermal_power_station_dual_variable[i][0])
    for i in range (0,6):
        if i!=3:
            print("第",(i+55),"个风力发电站的初始对偶变量为:",wind_power_station_dual_variable[i][0])
    print("****************************************************************************")
    print("第",(54),"个受到Byzantin攻击的火力发电站的初始对偶变量为:",thermal_power_station_dual_variable[53][0])
    print("第",(58),"个受到Byzantin攻击的风力发电站的初始对偶变量为:",wind_power_station_dual_variable[3][0])
    print("****************************************************************************")
    print("安全发电站的初始总发电量:",sum_thermal_wind_power_station_strategy[0][0])
    print("*************************")
    print("需求侧平均用电需求:",d_power_demand[0])
    print("****************************************************************************")
    print("风速分布参数c:",c_wind_speed[0])
    print("****************************************************************************")
    print("风速分布参数kappa:",kappa_wind_speed[0])
    print("****************************************************************************")
    print("安全发电站的总发电成本：", sum_cost[0][0])
    print("****************************************************************************")
    print("原变量迭代步长为:",step_size_primal)
    print("*****************************************************************************")
    print("对偶变量迭代步长为:",step_size_dual)
    print("*****************************************************************************")
    
    #开始迭代
    for k in range(1,1000):
        #发电站更新计划发电量和对偶变量
        #对偶变量 先做梯度上升 再做聚合
        dual_variable_intermediate=[] #存放当前迭代中60个用户对对偶变量做完梯度下降后得到的中间值
        for i in range(0,53):
            dual_variable_intermediate.append(thermal_power_station_dual_variable[i][k-1]+step_size_dual*((1/60)*thermal_power_station_strategy[i][k-1]-(1/60)*d_power_demand[k-1]-regularization_parameter*thermal_power_station_dual_variable[i][k-1]))
        #添加拜占庭火力发电站的对偶值
        dual_variable_intermediate.append(small_Gaussian_Byzantine_attack[k])
        for j in range(0,6):
            if j==3: #添加拜占庭风力发电站的对偶值
                dual_variable_intermediate.append(small_Gaussian_Byzantine_attack[k])
            else:
                dual_variable_intermediate.append(wind_power_station_dual_variable[j][k-1]+step_size_dual*((1/60)*wind_power_station_strategy[j][k-1]-(1/60)*d_power_demand[k-1]-regularization_parameter*wind_power_station_dual_variable[j][k-1]))
        
        #IOS鲁棒聚合+adaptive clipping 安全的火力发电站的对偶更新
        #在做鲁棒聚合前 对收集到的信息进行adaptive clipping的剪裁操作
        for i in range (0,53):
            u_neighbor_help_robust1=neighbor_robust1[i].tolist()#将用户i的邻居序号存在辅助变量u中
            u_neighbor_help_robust1 = list(set(u_neighbor_help_robust1))
            u_neighbor_help_robust1.remove(99)
            if int(q_robust1[i])==1: #只有具有拜占庭邻居的用户才需要先进行adaptive clipping和后续的IOS聚合操作
                #先进行adaptive clipping
                dual_variable_intermediate_auxiliary=[]
                #注意必须以这样的方式赋值 不能直接写dual_variable_intermediate_auxiliary=dual_variable_intermediate
                #不然在修改变量dual_variable_intermediate_auxiliary的同时也会对dual_variable_intermediate进行修改
                for j in range(len(dual_variable_intermediate)): 
                    dual_variable_intermediate_auxiliary.append(dual_variable_intermediate[j])
                dual_variable_receive=[]
                clipping_C=0
                for j in range(0, len(u_neighbor_help_robust1)):
                    dual_variable_receive.append(dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[j]])
                dual_variable_receive.sort()
                clipping_C=-dual_variable_receive[1] #确定clpping的阈值
                #接下来对大于clipping_C的值进行clipping
                for j in range(0, len(u_neighbor_help_robust1)):
                    if -dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[j]]>clipping_C:
                        dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[j]]=-clipping_C
                #接下来做IOS鲁棒聚合
                dual_variable_weight_average_robust1=0
                h_robust1=0
                for j in range(0,len(u_neighbor_help_robust1)):#计算当前循环中的h值
                    h_robust1=h_robust1+E[i][u_neighbor_help_robust1[j]]
                for j in range(0,len(u_neighbor_help_robust1)):#计算当前循环中的对偶权重平均值
                    dual_variable_weight_average_robust1=dual_variable_weight_average_robust1+(1/h_robust1)*(E[i][u_neighbor_help_robust1[j]]*dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[j]])
                #剔除一个对偶值离权重平均对偶值最远的用户 保留自身的值
                u_neighbor_help_robust1.remove(i)
                neighbor_index_robust1=u_neighbor_help_robust1[0]
                max_distance_roubust1=abs(dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[0]]-dual_variable_weight_average_robust1)
                for j in range(1,len(u_neighbor_help_robust1)):
                    if abs(dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[j]]-dual_variable_weight_average_robust1)>=max_distance_roubust1:
                        max_distance_roubust1=abs(dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[j]]-dual_variable_weight_average_robust1)
                        neighbor_index_robust1=u_neighbor_help_robust1[j]
                u_neighbor_help_robust1.remove(neighbor_index_robust1)
                u_neighbor_help_robust1.append(i)
                #计算剔除q个信息后的权重平均对偶值
                dual_variable_weight_average_robust1=0
                h_robust1=0
                for j in range(0,len(u_neighbor_help_robust1)):
                    h_robust1=h_robust1+E[i][u_neighbor_help_robust1[j]]
                for j in range(0,len(u_neighbor_help_robust1)):
                    dual_variable_weight_average_robust1=dual_variable_weight_average_robust1+(1/h_robust1)*(E[i][u_neighbor_help_robust1[j]]*dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[j]])     
                #诚实用户基于IOS鲁棒聚合后的值进行自身的对偶变量的更新 基于权重平均值
                thermal_power_station_dual_variable[i][k]=dual_variable_weight_average_robust1              
            else: #没有拜占庭邻居的用户直接进行权重聚合即可
                dual_variable_weight_average_robust1=0
                h_robust1=0
                for j in range(0,len(u_neighbor_help_robust1)):#计算当前循环中的h值
                    h_robust1=h_robust1+E[i][u_neighbor_help_robust1[j]]
                for j in range(0,len(u_neighbor_help_robust1)):
                    dual_variable_weight_average_robust1=dual_variable_weight_average_robust1+(1/h_robust1)*(E[i][u_neighbor_help_robust1[j]]*dual_variable_intermediate[u_neighbor_help_robust1[j]]) 
                    #dual_variable_weight_average_robust1=dual_variable_weight_average_robust1+(E[i][u_neighbor_help_robust1[j]]*dual_variable_intermediate[u_neighbor_help_robust1[j]])                  
                #诚实用户基于IOS鲁棒聚合后的值进行自身的对偶变量的更新 基于权重平均值
                thermal_power_station_dual_variable[i][k]=dual_variable_weight_average_robust1  
                #thermal_power_station_dual_variable[i][k]=9999

        #安全的风力发电站的adaptive clipping操作 由于风力发电站的邻居中没有拜占庭用户 所以不需要进行adaptive clipping的操作
        #聚合 安全的风力发电站的对偶更新
        for i in range(0,6):
            if i!=3:
                u_neighbor_help_robust1=neighbor_robust1[i+54].tolist()#将用户i的邻居序号存在辅助变量u中
                u_neighbor_help_robust1 = list(set(u_neighbor_help_robust1))
                u_neighbor_help_robust1.remove(99)
                dual_variable_weight_average_robust1=0
                h_robust1=0
                for j in range(0,len(u_neighbor_help_robust1)):
                    h_robust1=h_robust1+E[i+54][u_neighbor_help_robust1[j]]               
                for j in range(0,len(u_neighbor_help_robust1)):
                    dual_variable_weight_average_robust1=dual_variable_weight_average_robust1+(1/h_robust1)*(E[i+54][u_neighbor_help_robust1[j]]*dual_variable_intermediate[u_neighbor_help_robust1[j]])     
                wind_power_station_dual_variable[i][k]=dual_variable_weight_average_robust1
        
        #受到Byzantine攻击的火力和风力发电站的对偶更新
        thermal_power_station_dual_variable[53][k]=small_Gaussian_Byzantine_attack[k]
        wind_power_station_dual_variable[3][k]=small_Gaussian_Byzantine_attack[k]            
        
        #安全的火力发电站计划发电量
        for i in range(0,53):
            thermal_power_station_strategy[i][k]=thermal_power_station_strategy[i][k-1]-step_size_primal*(2*generator_c_values[i]*thermal_power_station_strategy[i][k-1]+generator_b_values[i]+(1/60)*thermal_power_station_dual_variable[i][k-1]) 
            if thermal_power_station_strategy[i][k]<=thermal_power_station_P_min[i]:
                thermal_power_station_strategy[i][k]=thermal_power_station_P_min[i]
            elif thermal_power_station_strategy[i][k]>=thermal_power_station_P_max[i]:
                thermal_power_station_strategy[i][k]=thermal_power_station_P_max[i]
        #安全的风力发电站计划发电量
        for i in range(0,6):
            if i!=3:
                wind_power_station_strategy[i][k]=wind_power_station_strategy[i][k-1]-step_size_primal*(wind_power_station_varphi[i]+wind_power_station_sigma_oe[i]+(wind_power_station_sigma_ue[i]+wind_power_station_sigma_oe[i])*math.exp(-(math.pow(wind_power_station_v_out[i],kappa_wind_speed[k-1]))/(math.pow(c_wind_speed[k-1],kappa_wind_speed[k-1])))+(-wind_power_station_sigma_ue[i]-wind_power_station_sigma_oe[i])*math.exp(-(math.pow((wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][k-1])/wind_power_station_P_r[i]),kappa_wind_speed[k-1]))/(math.pow(c_wind_speed[k-1],kappa_wind_speed[k-1])))+(1/60)*wind_power_station_dual_variable[i][k-1])
                if wind_power_station_strategy[i][k]<=wind_power_station_P_min[i]:
                    wind_power_station_strategy[i][k]=wind_power_station_P_min[i]
                elif wind_power_station_strategy[i][k]>=wind_power_station_P_max[i]:
                    wind_power_station_strategy[i][k]=wind_power_station_P_max[i]
        #受到Byzantine攻击的火力和风力发电站的计划发电量
        thermal_power_station_strategy[53][k]=thermal_power_station_strategy[53][k-1]
        wind_power_station_strategy[3][k]=wind_power_station_strategy[3][k-1]
        
        #安全发电站的计算总计划发电
        #火力发电量
        for i in range(0,53):
            sum_thermal_wind_power_station_strategy[0][k]=sum_thermal_wind_power_station_strategy[0][k]+thermal_power_station_strategy[i][k]
        #风力发电量
        for i in range(0,6):
            if i!=3:
                sum_thermal_wind_power_station_strategy[0][k]=sum_thermal_wind_power_station_strategy[0][k]+wind_power_station_strategy[i][k]
        
        #安全发电站的计算总发电成本
        #火力发电成本
        for i in range(0,53):
            thermal_power_station_cost[0][k]=thermal_power_station_cost[0][k]+generator_c_values[i]*thermal_power_station_strategy[i][k]*thermal_power_station_strategy[i][k]+generator_b_values[i]*thermal_power_station_strategy[i][k]+generator_a_values[i]
        #风力发电成本
        for i in range(0,6):
            if i!=3:
                wind_power_station_cost[0][k]=wind_power_station_cost[0][k]+wind_power_station_varphi[i]*wind_power_station_strategy[i][k]+wind_power_station_sigma_ue[i]*((wind_power_station_P_r[i]-wind_power_station_strategy[i][k])*(math.exp(-(math.pow(wind_power_station_v_r[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k])))-math.exp(-(math.pow(wind_power_station_v_out[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k]))))+(wind_power_station_P_r[i]*wind_power_station_v_in[i]/(wind_power_station_v_r[i]-wind_power_station_v_in[i])+wind_power_station_strategy[i][k])*(math.exp(-(math.pow(wind_power_station_v_r[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k])))-math.exp(-(math.pow(wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][k])/wind_power_station_P_r[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k]))))+(wind_power_station_P_r[i]*c_wind_speed[k]/(wind_power_station_v_r[i]-wind_power_station_v_in[i]))*(sc.gammaincc(1+1/kappa_wind_speed[k],(math.pow(wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][k])/wind_power_station_P_r[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k])))*sc.gamma(1+1/kappa_wind_speed[k])-sc.gammaincc(1+1/kappa_wind_speed[k],math.pow(wind_power_station_v_r[i]/c_wind_speed[k],kappa_wind_speed[k]))*sc.gamma(1+1/kappa_wind_speed[k])))+wind_power_station_sigma_oe[i]*((wind_power_station_strategy[i][k])*(1-math.exp(-(math.pow(wind_power_station_v_in[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k])))+math.exp(-(math.pow(wind_power_station_v_out[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k]))))+(wind_power_station_P_r[i]*wind_power_station_v_in[i]/(wind_power_station_v_r[i]-wind_power_station_v_in[i])+wind_power_station_strategy[i][k])*(math.exp(-(math.pow(wind_power_station_v_in[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k])))-math.exp(-(math.pow(wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][k])/wind_power_station_P_r[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k]))))+(wind_power_station_P_r[i]*c_wind_speed[k]/(wind_power_station_v_r[i]-wind_power_station_v_in[i]))*(sc.gammaincc(1+1/kappa_wind_speed[k],(math.pow(wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][k])/wind_power_station_P_r[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k])))*sc.gamma(1+1/kappa_wind_speed[k])-sc.gammaincc(1+1/kappa_wind_speed[k],math.pow(wind_power_station_v_in[i]/c_wind_speed[k],kappa_wind_speed[k]))*sc.gamma(1+1/kappa_wind_speed[k])))
        #发电总成本
        sum_cost[0][k]=thermal_power_station_cost[0][k]+wind_power_station_cost[0][k]
        
        #输出第k次迭代中的结果 每间隔10次迭代输出一次结果
        if (k+1)%10==0:
        #if k<=5:
            print(k,"次迭代中的结果：")
            for i in range (0,53):
                print("第",(i+1),"个火力发电站的计划发电量为:",thermal_power_station_strategy[i][k])
            for i in range (0,6):
                if i!=3:
                    print("第",(i+55),"个风力发电站的计划发电量为:",wind_power_station_strategy[i][k])
            print("****************************************************************************")
            for i in range (0,53):
                print("第",(i+1),"个火力发电站的对偶变量为:",thermal_power_station_dual_variable[i][k])
            for i in range (0,6):
                if i!=3:
                    print("第",(i+55),"个风力发电站的对偶变量为:",wind_power_station_dual_variable[i][k])
            print("****************************************************************************")
            print("第",(54),"个受到Byzantin攻击的火力发电站的初始对偶变量为:",thermal_power_station_dual_variable[53][k])
            print("第",(58),"个受到Byzantin攻击的风力发电站的初始对偶变量为:",wind_power_station_dual_variable[3][k])
            print("****************************************************************************")
            print("安全发电站的总发电量:",sum_thermal_wind_power_station_strategy[0][k])
            print("*************************")
            print("需求侧平均用电需求:",d_power_demand[k])
            print("****************************************************************************")
            print("风速分布参数c:",c_wind_speed[k])
            print("****************************************************************************")
            print("风速分布参数kappa:",kappa_wind_speed[k])
            print("****************************************************************************")        
            print("安全发电站的总发电成本：", sum_cost[0][k])
            print("****************************************************************************")
            print("原变量迭代步长为:",step_size_primal)
            print("****************************************************************************")
            print("对偶变量迭代步长为:",step_size_dual)
            print("****************************************************************************")

    print(datetime.now().strftime('%Y-%m-%d %H:%M:%S.%f')[:-3])
    return None

# %%
IOS_Byzantine_attack_decentralized_economic_dispatch(thermal_power_station_strategy,wind_power_station_strategy,c_wind_speed,kappa_wind_speed,d_power_demand,thermal_power_station_dual_variable,wind_power_station_dual_variable,E,thermal_power_station_cost,wind_power_station_cost,generator_a_values,generator_b_values,generator_c_values,thermal_power_station_P_min,thermal_power_station_P_max,wind_power_station_varphi,wind_power_station_sigma_ue,wind_power_station_sigma_oe,wind_power_station_P_min,wind_power_station_P_max,sum_thermal_wind_power_station_strategy,step_size_primal,step_size_dual)
# Out:
# ***************************large_attack_online_decentralized_economic_dispatch*****************************
# 相关变量初始值为：
# 第 1 个火力发电站的初始计划发电量为: 30.0
# 第 2 个火力发电站的初始计划发电量为: 30.0
# 第 3 个火力发电站的初始计划发电量为: 30.0
# 第 4 个火力发电站的初始计划发电量为: 300.0
# 第 5 个火力发电站的初始计划发电量为: 300.0
# 第 6 个火力发电站的初始计划发电量为: 30.0
# 第 7 个火力发电站的初始计划发电量为: 100.0
# 第 8 个火力发电站的初始计划发电量为: 30.0
# 第 9 个火力发电站的初始计划发电量为: 30.0
# 第 10 个火力发电站的初始计划发电量为: 300.0
# 第 11 个火力发电站的初始计划发电量为: 350.0
# 第 12 个火力发电站的初始计划发电量为: 30.0
# 第 13 个火力发电站的初始计划发电量为: 30.0
# 第 14 个火力发电站的初始计划发电量为: 100.0
# 第 15 个火力发电站的初始计划发电量为: 30.0
# 第 16 个火力发电站的初始计划发电量为: 100.0
# 第 17 个火力发电站的初始计划发电量为: 30.0
# 第 18 个火力发电站的初始计划发电量为: 30.0
# 第 19 个火力发电站的初始计划发电量为: 100.0
# 第 20 个火力发电站的初始计划发电量为: 250.0
# 第 21 个火力发电站的初始计划发电量为: 250.0
# 第 22 个火力发电站的初始计划发电量为: 100.0
# 第 23 个火力发电站的初始计划发电量为: 100.0
# 第 24 个火力发电站的初始计划发电量为: 200.0
# 第 25 个火力发电站的初始计划发电量为: 200.0
# 第 26 个火力发电站的初始计划发电量为: 100.0
# 第 27 个火力发电站的初始计划发电量为: 420.0
# 第 28 个火力发电站的初始计划发电量为: 420.0
# 第 29 个火力发电站的初始计划发电量为: 300.0
# 第 30 个火力发电站的初始计划发电量为: 80.0
# 第 31 个火力发电站的初始计划发电量为: 30.0
# 第 32 个火力发电站的初始计划发电量为: 30.0
# 第 33 个火力发电站的初始计划发电量为: 20.0
# 第 34 个火力发电站的初始计划发电量为: 100.0
# 第 35 个火力发电站的初始计划发电量为: 100.0
# 第 36 个火力发电站的初始计划发电量为: 300.0
# 第 37 个火力发电站的初始计划发电量为: 100.0
# 第 38 个火力发电站的初始计划发电量为: 30.0
# 第 39 个火力发电站的初始计划发电量为: 300.0
# 第 40 个火力发电站的初始计划发电量为: 200.0
# 第 41 个火力发电站的初始计划发电量为: 20.0
# 第 42 个火力发电站的初始计划发电量为: 50.0
# 第 43 个火力发电站的初始计划发电量为: 300.0
# 第 44 个火力发电站的初始计划发电量为: 300.0
# 第 45 个火力发电站的初始计划发电量为: 300.0
# 第 46 个火力发电站的初始计划发电量为: 20.0
# 第 47 个火力发电站的初始计划发电量为: 100.0
# 第 48 个火力发电站的初始计划发电量为: 100.0
# 第 49 个火力发电站的初始计划发电量为: 20.0
# 第 50 个火力发电站的初始计划发电量为: 50.0
# 第 51 个火力发电站的初始计划发电量为: 100.0
# 第 52 个火力发电站的初始计划发电量为: 100.0
# 第 55 个风力发电站的初始计划发电量为: 30.0
# 第 56 个风力发电站的初始计划发电量为: 30.0
# 第 57 个风力发电站的初始计划发电量为: 30.0
# 第 59 个风力发电站的初始计划发电量为: 300.0
# 第 60 个风力发电站的初始计划发电量为: 30.0
# ****************************************************************************
# 第 1 个火力发电站的初始对偶变量为: -1000.0
# 第 2 个火力发电站的初始对偶变量为: -1000.0
# 第 3 个火力发电站的初始对偶变量为: -1000.0
# 第 4 个火力发电站的初始对偶变量为: -1000.0
# 第 5 个火力发电站的初始对偶变量为: -1000.0
# 第 6 个火力发电站的初始对偶变量为: -1000.0
# 第 7 个火力发电站的初始对偶变量为: -1000.0
# 第 8 个火力发电站的初始对偶变量为: -1000.0
# 第 9 个火力发电站的初始对偶变量为: -1000.0
# 第 10 个火力发电站的初始对偶变量为: -1000.0
# 第 11 个火力发电站的初始对偶变量为: -1000.0
# 第 12 个火力发电站的初始对偶变量为: -1000.0
# 第 13 个火力发电站的初始对偶变量为: -1000.0
# 第 14 个火力发电站的初始对偶变量为: -1000.0
# 第 15 个火力发电站的初始对偶变量为: -1000.0
# 第 16 个火力发电站的初始对偶变量为: -1000.0
# 第 17 个火力发电站的初始对偶变量为: -1000.0
# 第 18 个火力发电站的初始对偶变量为: -1000.0
# 第 19 个火力发电站的初始对偶变量为: -1000.0
# 第 20 个火力发电站的初始对偶变量为: -1000.0
# 第 21 个火力发电站的初始对偶变量为: -1000.0
# 第 22 个火力发电站的初始对偶变量为: -1000.0
# 第 23 个火力发电站的初始对偶变量为: -1000.0
# 第 24 个火力发电站的初始对偶变量为: -1000.0
# 第 25 个火力发电站的初始对偶变量为: -1000.0
# 第 26 个火力发电站的初始对偶变量为: -1000.0
# 第 27 个火力发电站的初始对偶变量为: -1000.0
# 第 28 个火力发电站的初始对偶变量为: -1000.0
# 第 29 个火力发电站的初始对偶变量为: -1000.0
# 第 30 个火力发电站的初始对偶变量为: -1000.0
# 第 31 个火力发电站的初始对偶变量为: -1000.0
# 第 32 个火力发电站的初始对偶变量为: -1000.0
# 第 33 个火力发电站的初始对偶变量为: -1000.0
# 第 34 个火力发电站的初始对偶变量为: -1000.0
# 第 35 个火力发电站的初始对偶变量为: -1000.0
# 第 36 个火力发电站的初始对偶变量为: -1000.0
# 第 37 个火力发电站的初始对偶变量为: -1000.0
# 第 38 个火力发电站的初始对偶变量为: -1000.0
# 第 39 个火力发电站的初始对偶变量为: -1000.0
# 第 40 个火力发电站的初始对偶变量为: -1000.0
# 第 41 个火力发电站的初始对偶变量为: -1000.0
# 第 42 个火力发电站的初始对偶变量为: -1000.0
# 第 43 个火力发电站的初始对偶变量为: -1000.0
# 第 44 个火力发电站的初始对偶变量为: -1000.0
# 第 45 个火力发电站的初始对偶变量为: -1000.0
# 第 46 个火力发电站的初始对偶变量为: -1000.0
# 第 47 个火力发电站的初始对偶变量为: -1000.0
# 第 48 个火力发电站的初始对偶变量为: -1000.0
# 第 49 个火力发电站的初始对偶变量为: -1000.0
# 第 50 个火力发电站的初始对偶变量为: -1000.0
# 第 51 个火力发电站的初始对偶变量为: -1000.0
# 第 52 个火力发电站的初始对偶变量为: -1000.0
# 第 55 个风力发电站的初始对偶变量为: -1000.0
# 第 56 个风力发电站的初始对偶变量为: -1000.0
# 第 57 个风力发电站的初始对偶变量为: -1000.0
# 第 59 个风力发电站的初始对偶变量为: -1000.0
# 第 60 个风力发电站的初始对偶变量为: -1000.0
# ****************************************************************************
# 第 54 个受到Byzantin攻击的火力发电站的初始对偶变量为: -1462.97561805
# 第 58 个受到Byzantin攻击的风力发电站的初始对偶变量为: -1462.97561805
# ****************************************************************************
# 安全发电站的初始总发电量: 7590.0
# *************************
# 需求侧平均用电需求: 78.10342674
# ****************************************************************************
# 风速分布参数c: 8.36374925
# ****************************************************************************
# 风速分布参数kappa: 2.53999996
# ****************************************************************************
# 安全发电站的总发电成本： 128026.41839387035
# ****************************************************************************
# 原变量迭代步长为: 5
# *****************************************************************************
# 对偶变量迭代步长为: 5
# *****************************************************************************
# 9 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 5.0
# 第 2 个火力发电站的计划发电量为: 5.0
# 第 3 个火力发电站的计划发电量为: 5.0
# 第 4 个火力发电站的计划发电量为: 192.2249225000447
# 第 5 个火力发电站的计划发电量为: 216.35404063475224
# 第 6 个火力发电站的计划发电量为: 10.0
# 第 7 个火力发电站的计划发电量为: 25.0
# 第 8 个火力发电站的计划发电量为: 5.0
# 第 9 个火力发电站的计划发电量为: 5.0
# 第 10 个火力发电站的计划发电量为: 219.27261159200708
# 第 11 个火力发电站的计划发电量为: 350.0
# 第 12 个火力发电站的计划发电量为: 8.0
# 第 13 个火力发电站的计划发电量为: 8.0
# 第 14 个火力发电站的计划发电量为: 25.0
# 第 15 个火力发电站的计划发电量为: 8.0
# 第 16 个火力发电站的计划发电量为: 25.0
# 第 17 个火力发电站的计划发电量为: 8.0
# 第 18 个火力发电站的计划发电量为: 8.0
# 第 19 个火力发电站的计划发电量为: 25.0
# 第 20 个火力发电站的计划发电量为: 250.0
# 第 21 个火力发电站的计划发电量为: 250.0
# 第 22 个火力发电站的计划发电量为: 25.0
# 第 23 个火力发电站的计划发电量为: 25.0
# 第 24 个火力发电站的计划发电量为: 200.0
# 第 25 个火力发电站的计划发电量为: 200.0
# 第 26 个火力发电站的计划发电量为: 25.0
# 第 27 个火力发电站的计划发电量为: 398.7410586784586
# 第 28 个火力发电站的计划发电量为: 380.2059857983173
# 第 29 个火力发电站的计划发电量为: 218.6102027217211
# 第 30 个火力发电站的计划发电量为: 30.0
# 第 31 个火力发电站的计划发电量为: 10.0
# 第 32 个火力发电站的计划发电量为: 5.0
# 第 33 个火力发电站的计划发电量为: 5.0
# 第 34 个火力发电站的计划发电量为: 25.0
# 第 35 个火力发电站的计划发电量为: 25.0
# 第 36 个火力发电站的计划发电量为: 207.13116966618765
# 第 37 个火力发电站的计划发电量为: 25.0
# 第 38 个火力发电站的计划发电量为: 10.0
# 第 39 个火力发电站的计划发电量为: 300.0
# 第 40 个火力发电站的计划发电量为: 177.27444503433077
# 第 41 个火力发电站的计划发电量为: 8.0
# 第 42 个火力发电站的计划发电量为: 20.0
# 第 43 个火力发电站的计划发电量为: 209.86192676594965
# 第 44 个火力发电站的计划发电量为: 195.2160384734831
# 第 45 个火力发电站的计划发电量为: 211.1414930272604
# 第 46 个火力发电站的计划发电量为: 8.0
# 第 47 个火力发电站的计划发电量为: 25.0
# 第 48 个火力发电站的计划发电量为: 25.0
# 第 49 个火力发电站的计划发电量为: 8.0
# 第 50 个火力发电站的计划发电量为: 25.0
# 第 51 个火力发电站的计划发电量为: 25.0
# 第 52 个火力发电站的计划发电量为: 25.0
# 第 53 个火力发电站的计划发电量为: 25.0
# 第 55 个风力发电站的计划发电量为: 117.21004296888118
# 第 56 个风力发电站的计划发电量为: 43.6104410799406
# 第 57 个风力发电站的计划发电量为: 79.64529943592301
# 第 59 个风力发电站的计划发电量为: 99.47520464298145
# 第 60 个风力发电站的计划发电量为: 28.72566802009432
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -1022.4663038589072
# 第 2 个火力发电站的对偶变量为: -1017.3128328052113
# 第 3 个火力发电站的对偶变量为: -1000.0489533550378
# 第 4 个火力发电站的对偶变量为: -922.9496841280818
# 第 5 个火力发电站的对偶变量为: -1001.667397386611
# 第 6 个火力发电站的对偶变量为: -1003.4168575855571
# 第 7 个火力发电站的对偶变量为: -1002.514205970602
# 第 8 个火力发电站的对偶变量为: -1017.8459163386849
# 第 9 个火力发电站的对偶变量为: -1021.8203287155411
# 第 10 个火力发电站的对偶变量为: -1012.4908468152021
# 第 11 个火力发电站的对偶变量为: -1002.4203690109824
# 第 12 个火力发电站的对偶变量为: -1018.4088345349805
# 第 13 个火力发电站的对偶变量为: -1003.7530909467607
# 第 14 个火力发电站的对偶变量为: -1014.3147276398101
# 第 15 个火力发电站的对偶变量为: -1014.3163768523232
# 第 16 个火力发电站的对偶变量为: -1007.4701331234037
# 第 17 个火力发电站的对偶变量为: -1008.7453440657199
# 第 18 个火力发电站的对偶变量为: -1014.3800547242683
# 第 19 个火力发电站的对偶变量为: -1011.1305479627886
# 第 20 个火力发电站的对偶变量为: -1000.8249039823746
# 第 21 个火力发电站的对偶变量为: -972.3440734523406
# 第 22 个火力发电站的对偶变量为: -971.7993403383991
# 第 23 个火力发电站的对偶变量为: -971.799340338399
# 第 24 个火力发电站的对偶变量为: -960.813640212065
# 第 25 个火力发电站的对偶变量为: -946.1873140907563
# 第 26 个火力发电站的对偶变量为: -937.5405593370591
# 第 27 个火力发电站的对偶变量为: -994.75680971915
# 第 28 个火力发电站的对偶变量为: -938.9955847101455
# 第 29 个火力发电站的对偶变量为: -1010.553278007664
# 第 30 个火力发电站的对偶变量为: -1025.5107257902273
# 第 31 个火力发电站的对偶变量为: -1042.4652614903798
# 第 32 个火力发电站的对偶变量为: -1042.7698829318927
# 第 33 个火力发电站的对偶变量为: -1022.8847593289547
# 第 34 个火力发电站的对偶变量为: -1019.0128988711665
# 第 35 个火力发电站的对偶变量为: -997.5149192973447
# 第 36 个火力发电站的对偶变量为: -981.4656602158889
# 第 37 个火力发电站的对偶变量为: -981.5507385247413
# 第 38 个火力发电站的对偶变量为: -964.096856686264
# 第 39 个火力发电站的对偶变量为: -939.9637670291893
# 第 40 个火力发电站的对偶变量为: -983.0285097992987
# 第 41 个火力发电站的对偶变量为: -997.5795814108541
# 第 42 个火力发电站的对偶变量为: -999.5142901478794
# 第 43 个火力发电站的对偶变量为: -981.9529175203847
# 第 44 个火力发电站的对偶变量为: -945.4806235753149
# 第 45 个火力发电站的对偶变量为: -988.4102620513238
# 第 46 个火力发电站的对偶变量为: -1018.7476906975417
# 第 47 个火力发电站的对偶变量为: -1015.6475964300366
# 第 48 个火力发电站的对偶变量为: -1021.4234311998678
# 第 49 个火力发电站的对偶变量为: -1015.9261157264332
# 第 50 个火力发电站的对偶变量为: -1033.5944178116442
# 第 51 个火力发电站的对偶变量为: -1036.6235394659732
# 第 52 个火力发电站的对偶变量为: -1036.6235394659732
# 第 53 个火力发电站的对偶变量为: -1001.7108587669992
# 第 55 个风力发电站的对偶变量为: -1013.2685529572825
# 第 56 个风力发电站的对偶变量为: -1022.7241784557066
# 第 57 个风力发电站的对偶变量为: -1016.5186278909679
# 第 59 个风力发电站的对偶变量为: -962.4064978335934
# 第 60 个风力发电站的对偶变量为: -1017.7325434874496
# ****************************************************************************
# 第 54 个受到Byzantin攻击的火力发电站的初始对偶变量为: -1534.15243474
# 第 58 个受到Byzantin攻击的风力发电站的初始对偶变量为: -1534.15243474
# ****************************************************************************
# 安全发电站的总发电量: 5123.700551040333
# *************************
# 需求侧平均用电需求: 82.53743152
# ****************************************************************************
# 风速分布参数c: 8.64232458
# ****************************************************************************
# 风速分布参数kappa: 2.31999993
# ****************************************************************************
# 安全发电站的总发电成本： 75459.83728623018
# ****************************************************************************
# 原变量迭代步长为: 5
# ****************************************************************************
# 对偶变量迭代步长为: 5
# ****************************************************************************
# 19 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 5.0
# 第 2 个火力发电站的计划发电量为: 5.0
# 第 3 个火力发电站的计划发电量为: 5.0
# 第 4 个火力发电站的计划发电量为: 150.0
# 第 5 个火力发电站的计划发电量为: 194.93055749422467
# 第 6 个火力发电站的计划发电量为: 10.0
# 第 7 个火力发电站的计划发电量为: 25.0
# 第 8 个火力发电站的计划发电量为: 5.0
# 第 9 个火力发电站的计划发电量为: 5.0
# 第 10 个火力发电站的计划发电量为: 204.0110998487638
# 第 11 个火力发电站的计划发电量为: 350.0
# 第 12 个火力发电站的计划发电量为: 8.0
# 第 13 个火力发电站的计划发电量为: 8.0
# 第 14 个火力发电站的计划发电量为: 25.0
# 第 15 个火力发电站的计划发电量为: 8.0
# 第 16 个火力发电站的计划发电量为: 25.0
# 第 17 个火力发电站的计划发电量为: 8.0
# 第 18 个火力发电站的计划发电量为: 8.0
# 第 19 个火力发电站的计划发电量为: 25.0
# 第 20 个火力发电站的计划发电量为: 250.0
# 第 21 个火力发电站的计划发电量为: 250.0
# 第 22 个火力发电站的计划发电量为: 25.0
# 第 23 个火力发电站的计划发电量为: 25.0
# 第 24 个火力发电站的计划发电量为: 200.0
# 第 25 个火力发电站的计划发电量为: 200.0
# 第 26 个火力发电站的计划发电量为: 25.0
# 第 27 个火力发电站的计划发电量为: 398.06083231681777
# 第 28 个火力发电站的计划发电量为: 357.25105090172764
# 第 29 个火力发电站的计划发电量为: 203.3438594983201
# 第 30 个火力发电站的计划发电量为: 30.0
# 第 31 个火力发电站的计划发电量为: 10.0
# 第 32 个火力发电站的计划发电量为: 5.0
# 第 33 个火力发电站的计划发电量为: 5.0
# 第 34 个火力发电站的计划发电量为: 25.0
# 第 35 个火力发电站的计划发电量为: 25.0
# 第 36 个火力发电站的计划发电量为: 183.26747583660222
# 第 37 个火力发电站的计划发电量为: 25.0
# 第 38 个火力发电站的计划发电量为: 10.0
# 第 39 个火力发电站的计划发电量为: 300.0
# 第 40 个火力发电站的计划发电量为: 167.2596065049815
# 第 41 个火力发电站的计划发电量为: 8.0
# 第 42 个火力发电站的计划发电量为: 20.0
# 第 43 个火力发电站的计划发电量为: 180.7427676464681
# 第 44 个火力发电站的计划发电量为: 162.94024540169087
# 第 45 个火力发电站的计划发电量为: 188.3780830911221
# 第 46 个火力发电站的计划发电量为: 8.0
# 第 47 个火力发电站的计划发电量为: 25.0
# 第 48 个火力发电站的计划发电量为: 25.0
# 第 49 个火力发电站的计划发电量为: 8.0
# 第 50 个火力发电站的计划发电量为: 25.0
# 第 51 个火力发电站的计划发电量为: 25.0
# 第 52 个火力发电站的计划发电量为: 25.0
# 第 53 个火力发电站的计划发电量为: 25.0
# 第 55 个风力发电站的计划发电量为: 122.91936683566368
# 第 56 个风力发电站的计划发电量为: 45.11670817300033
# 第 57 个风力发电站的计划发电量为: 86.26564761241738
# 第 59 个风力发电站的计划发电量为: 94.17830470237308
# 第 60 个风力发电站的计划发电量为: 30.602250850189954
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -1044.5544882922295
# 第 2 个火力发电站的对偶变量为: -1039.9617849861609
# 第 3 个火力发电站的对偶变量为: -1022.9369448251891
# 第 4 个火力发电站的对偶变量为: -938.5834783101432
# 第 5 个火力发电站的对偶变量为: -1025.6910875848985
# 第 6 个火力发电站的对偶变量为: -1027.5279663410668
# 第 7 个火力发电站的对偶变量为: -1027.1565182159954
# 第 8 个火力发电站的对偶变量为: -1044.5212529453584
# 第 9 个火力发电站的对偶变量为: -1056.709624283718
# 第 10 个火力发电站的对偶变量为: -1044.4870619971366
# 第 11 个火力发电站的对偶变量为: -1027.1710229185076
# 第 12 个火力发电站的对偶变量为: -1049.6667201973632
# 第 13 个火力发电站的对偶变量为: -1029.4278142250478
# 第 14 个火力发电站的对偶变量为: -1045.288850904294
# 第 15 个火力发电站的对偶变量为: -1038.4657004470087
# 第 16 个火力发电站的对偶变量为: -1030.1327790833386
# 第 17 个火力发电站的对偶变量为: -1031.412483384554
# 第 18 个火力发电站的对偶变量为: -1036.2238741126769
# 第 19 个火力发电站的对偶变量为: -1048.7702550698841
# 第 20 个火力发电站的对偶变量为: -1024.8783124971417
# 第 21 个火力发电站的对偶变量为: -969.0783648830331
# 第 22 个火力发电站的对偶变量为: -963.2583087453304
# 第 23 个火力发电站的对偶变量为: -963.2583087453304
# 第 24 个火力发电站的对偶变量为: -953.9627573394176
# 第 25 个火力发电站的对偶变量为: -938.5027730138212
# 第 26 个火力发电站的对偶变量为: -932.3998032948529
# 第 27 个火力发电站的对偶变量为: -1015.6635091085908
# 第 28 个火力发电站的对偶变量为: -944.0914240908069
# 第 29 个火力发电站的对偶变量为: -1045.0045050162425
# 第 30 个火力发电站的对偶变量为: -1062.078603286025
# 第 31 个火力发电站的对偶变量为: -1082.144528483367
# 第 32 个火力发电站的对偶变量为: -1082.7147128004826
# 第 33 个火力发电站的对偶变量为: -1058.2876399047902
# 第 34 个火力发电站的对偶变量为: -1053.7395940177594
# 第 35 个火力发电站的对偶变量为: -1032.421766503668
# 第 36 个火力发电站的对偶变量为: -1011.8717332903459
# 第 37 个火力发电站的对偶变量为: -999.7990625502166
# 第 38 个火力发电站的对偶变量为: -965.7753533528
# 第 39 个火力发电站的对偶变量为: -930.5758934046269
# 第 40 个火力发电站的对偶变量为: -989.7316590865958
# 第 41 个火力发电站的对偶变量为: -1004.6225549696883
# 第 42 个火力发电站的对偶变量为: -1009.2284264379037
# 第 43 个火力发电站的对偶变量为: -1000.6209942266488
# 第 44 个火力发电站的对偶变量为: -984.0603359576262
# 第 45 个火力发电站的对偶变量为: -1019.9863280256461
# 第 46 个火力发电站的对偶变量为: -1058.158343068644
# 第 47 个火力发电站的对偶变量为: -1051.970625128813
# 第 48 个火力发电站的对偶变量为: -1057.4931415611832
# 第 49 个火力发电站的对偶变量为: -1050.2122287138586
# 第 50 个火力发电站的对偶变量为: -1083.1058705419186
# 第 51 个火力发电站的对偶变量为: -1088.9759849899272
# 第 52 个火力发电站的对偶变量为: -1088.9759849899272
# 第 53 个火力发电站的对偶变量为: -1026.9920911322708
# 第 55 个风力发电站的对偶变量为: -1035.9858007781147
# 第 56 个风力发电站的对偶变量为: -1052.2407612995935
# 第 57 个风力发电站的对偶变量为: -1047.9014781531432
# 第 59 个风力发电站的对偶变量为: -1013.7628190873606
# 第 60 个风力发电站的对偶变量为: -1053.166161295709
# ****************************************************************************
# 第 54 个受到Byzantin攻击的火力发电站的初始对偶变量为: -1510.43639407
# 第 58 个受到Byzantin攻击的风力发电站的初始对偶变量为: -1510.43639407
# ****************************************************************************
# 安全发电站的总发电量: 4898.267856714362
# *************************
# 需求侧平均用电需求: 82.13934673
# ****************************************************************************
# 风速分布参数c: 8.65293401
# ****************************************************************************
# 风速分布参数kappa: 2.25999999
# ****************************************************************************
# 安全发电站的总发电成本： 71667.07627188084
# ****************************************************************************
# 原变量迭代步长为: 5
# ****************************************************************************
# 对偶变量迭代步长为: 5
# ****************************************************************************
# 29 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 5.0
# 第 2 个火力发电站的计划发电量为: 5.0
# 第 3 个火力发电站的计划发电量为: 5.0
# 第 4 个火力发电站的计划发电量为: 150.0
# 第 5 个火力发电站的计划发电量为: 199.78440544404614
# 第 6 个火力发电站的计划发电量为: 10.0
# 第 7 个火力发电站的计划发电量为: 25.0
# 第 8 个火力发电站的计划发电量为: 5.0
# 第 9 个火力发电站的计划发电量为: 5.0
# 第 10 个火力发电站的计划发电量为: 213.84691465626796
# 第 11 个火力发电站的计划发电量为: 350.0
# 第 12 个火力发电站的计划发电量为: 8.0
# 第 13 个火力发电站的计划发电量为: 8.0
# 第 14 个火力发电站的计划发电量为: 25.0
# 第 15 个火力发电站的计划发电量为: 8.0
# 第 16 个火力发电站的计划发电量为: 25.0
# 第 17 个火力发电站的计划发电量为: 8.0
# 第 18 个火力发电站的计划发电量为: 8.0
# 第 19 个火力发电站的计划发电量为: 25.0
# 第 20 个火力发电站的计划发电量为: 250.0
# 第 21 个火力发电站的计划发电量为: 250.0
# 第 22 个火力发电站的计划发电量为: 25.0
# 第 23 个火力发电站的计划发电量为: 25.0
# 第 24 个火力发电站的计划发电量为: 200.0
# 第 25 个火力发电站的计划发电量为: 200.0
# 第 26 个火力发电站的计划发电量为: 25.0
# 第 27 个火力发电站的计划发电量为: 408.14039002870595
# 第 28 个火力发电站的计划发电量为: 355.0661440882747
# 第 29 个火力发电站的计划发电量为: 214.6777975074233
# 第 30 个火力发电站的计划发电量为: 30.0
# 第 31 个火力发电站的计划发电量为: 10.0
# 第 32 个火力发电站的计划发电量为: 5.0
# 第 33 个火力发电站的计划发电量为: 5.0
# 第 34 个火力发电站的计划发电量为: 25.0
# 第 35 个火力发电站的计划发电量为: 25.0
# 第 36 个火力发电站的计划发电量为: 182.3358843218744
# 第 37 个火力发电站的计划发电量为: 25.0
# 第 38 个火力发电站的计划发电量为: 10.0
# 第 39 个火力发电站的计划发电量为: 300.0
# 第 40 个火力发电站的计划发电量为: 169.35760083515765
# 第 41 个火力发电站的计划发电量为: 8.0
# 第 42 个火力发电站的计划发电量为: 20.0
# 第 43 个火力发电站的计划发电量为: 179.8520620954315
# 第 44 个火力发电站的计划发电量为: 167.24538721094603
# 第 45 个火力发电站的计划发电量为: 194.9785163745558
# 第 46 个火力发电站的计划发电量为: 8.0
# 第 47 个火力发电站的计划发电量为: 25.0
# 第 48 个火力发电站的计划发电量为: 25.0
# 第 49 个火力发电站的计划发电量为: 8.0
# 第 50 个火力发电站的计划发电量为: 25.0
# 第 51 个火力发电站的计划发电量为: 29.116829184512625
# 第 52 个火力发电站的计划发电量为: 29.116829184512625
# 第 53 个火力发电站的计划发电量为: 25.0
# 第 55 个风力发电站的计划发电量为: 127.31418846166324
# 第 56 个风力发电站的计划发电量为: 46.368829139330536
# 第 57 个风力发电站的计划发电量为: 91.38550158949158
# 第 59 个风力发电站的计划发电量为: 99.86406334002548
# 第 60 个风力发电站的计划发电量为: 32.10224650149597
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -1065.8271500994874
# 第 2 个火力发电站的对偶变量为: -1061.3075874601368
# 第 3 个火力发电站的对偶变量为: -1045.0367759934738
# 第 4 个火力发电站的对偶变量为: -963.0244550380174
# 第 5 个火力发电站的对偶变量为: -1047.6227610910114
# 第 6 个火力发电站的对偶变量为: -1049.7547575391368
# 第 7 个火力发电站的对偶变量为: -1049.6175395944217
# 第 8 个火力发电站的对偶变量为: -1068.5543017657315
# 第 9 个火力发电站的对偶变量为: -1084.9606162695936
# 第 10 个火力发电站的对偶变量为: -1070.7309787561717
# 第 11 个火力发电站的对偶变量为: -1049.6721979425658
# 第 12 个火力发电站的对偶变量为: -1075.7925602166692
# 第 13 个火力发电站的对偶变量为: -1052.4554322840424
# 第 14 个火力发电站的对偶变量为: -1071.0806942291613
# 第 15 个火力发电站的对偶变量为: -1061.4061507849428
# 第 16 个火力发电站的对偶变量为: -1052.1017310427528
# 第 17 个火力发电站的对偶变量为: -1053.5334763307847
# 第 18 个火力发电站的对偶变量为: -1059.0103278205443
# 第 19 个火力发电站的对偶变量为: -1079.921956681167
# 第 20 个火力发电站的对偶变量为: -1048.7395225529874
# 第 21 个火力发电站的对偶变量为: -975.5534618151889
# 第 22 个火力发电站的对偶变量为: -966.2330604295485
# 第 23 个火力发电站的对偶变量为: -966.2330604295485
# 第 24 个火力发电站的对偶变量为: -959.1283218108339
# 第 25 个火力发电站的对偶变量为: -945.0492662124263
# 第 26 个火力发电站的对偶变量为: -940.3375482620331
# 第 27 个火力发电站的对偶变量为: -1035.1196799825705
# 第 28 个火力发电站的对偶变量为: -957.5406573221635
# 第 29 个火力发电站的对偶变量为: -1073.6657967349959
# 第 30 个火力发电站的对偶变量为: -1092.1425349484584
# 第 31 个火力发电站的对偶变量为: -1113.8054300847414
# 第 32 个火力发电站的对偶变量为: -1114.7327369443356
# 第 33 个火力发电站的对偶变量为: -1087.8703736738182
# 第 34 个火力发电站的对偶变量为: -1083.0885313479678
# 第 35 个火力发电站的对偶变量为: -1057.4648610086379
# 第 36 个火力发电站的对偶变量为: -1017.9027812274835
# 第 37 个火力发电站的对偶变量为: -1017.337798811171
# 第 38 个火力发电站的对偶变量为: -977.6921470967377
# 第 39 个火力发电站的对偶变量为: -939.3496498263369
# 第 40 个火力发电站的对偶变量为: -1002.0299635554142
# 第 41 个火力发电站的对偶变量为: -1016.8132631453186
# 第 42 个火力发电站的对偶变量为: -1021.9467224849948
# 第 43 个火力发电站的对偶变量为: -1014.899448902954
# 第 44 个火力发电站的对偶变量为: -1002.1065109170431
# 第 45 个火力发电站的对偶变量为: -1042.4237768996727
# 第 46 个火力发电站的对偶变量为: -1091.9248084047404
# 第 47 个火力发电站的对偶变量为: -1083.685220615403
# 第 48 个火力发电站的对偶变量为: -1090.0790998744674
# 第 49 个火力发电站的对偶变量为: -1080.7866086040085
# 第 50 个火力发电站的对偶变量为: -1124.375152053485
# 第 51 个火力发电站的对偶变量为: -1132.1815656591693
# 第 52 个火力发电站的对偶变量为: -1132.1815656591693
# 第 53 个火力发电站的对偶变量为: -1049.7157608696727
# 第 55 个风力发电站的对偶变量为: -1057.3718708747954
# 第 56 个风力发电站的对偶变量为: -1078.0044602562807
# 第 57 个风力发电站的对偶变量为: -1073.9566364567552
# 第 59 个风力发电站的对偶变量为: -1044.875597550904
# 第 60 个风力发电站的对偶变量为: -1082.4601374110603
# ****************************************************************************
# 第 54 个受到Byzantin攻击的火力发电站的初始对偶变量为: -1461.32939982
# 第 58 个受到Byzantin攻击的风力发电站的初始对偶变量为: -1461.32939982
# ****************************************************************************
# 安全发电站的总发电量: 4969.553589963715
# *************************
# 需求侧平均用电需求: 104.19200066
# ****************************************************************************
# 风速分布参数c: 8.64573599
# ****************************************************************************
# 风速分布参数kappa: 2.24000001
# ****************************************************************************
# 安全发电站的总发电成本： 72921.52169182771
# ****************************************************************************
# 原变量迭代步长为: 5
# ****************************************************************************
# 对偶变量迭代步长为: 5
# ****************************************************************************
# 39 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 5.0
# 第 2 个火力发电站的计划发电量为: 5.0
# 第 3 个火力发电站的计划发电量为: 5.0
# 第 4 个火力发电站的计划发电量为: 154.32269988344896
# 第 5 个火力发电站的计划发电量为: 213.56103429578525
# 第 6 个火力发电站的计划发电量为: 10.0
# 第 7 个火力发电站的计划发电量为: 25.0
# 第 8 个火力发电站的计划发电量为: 5.0
# 第 9 个火力发电站的计划发电量为: 5.0
# 第 10 个火力发电站的计划发电量为: 230.77255431652674
# 第 11 个火力发电站的计划发电量为: 350.0
# 第 12 个火力发电站的计划发电量为: 8.0
# 第 13 个火力发电站的计划发电量为: 8.0
# 第 14 个火力发电站的计划发电量为: 25.0
# 第 15 个火力发电站的计划发电量为: 8.0
# 第 16 个火力发电站的计划发电量为: 25.0
# 第 17 个火力发电站的计划发电量为: 8.0
# 第 18 个火力发电站的计划发电量为: 8.0
# 第 19 个火力发电站的计划发电量为: 25.0
# 第 20 个火力发电站的计划发电量为: 250.0
# 第 21 个火力发电站的计划发电量为: 250.0
# 第 22 个火力发电站的计划发电量为: 25.0
# 第 23 个火力发电站的计划发电量为: 25.0
# 第 24 个火力发电站的计划发电量为: 200.0
# 第 25 个火力发电站的计划发电量为: 200.0
# 第 26 个火力发电站的计划发电量为: 25.0
# 第 27 个火力发电站的计划发电量为: 420.0
# 第 28 个火力发电站的计划发电量为: 363.36920731222233
# 第 29 个火力发电站的计划发电量为: 233.02247133511247
# 第 30 个火力发电站的计划发电量为: 33.59000157632484
# 第 31 个火力发电站的计划发电量为: 10.0
# 第 32 个火力发电站的计划发电量为: 5.0
# 第 33 个火力发电站的计划发电量为: 5.0
# 第 34 个火力发电站的计划发电量为: 25.0
# 第 35 个火力发电站的计划发电量为: 25.0
# 第 36 个火力发电站的计划发电量为: 191.78182637214996
# 第 37 个火力发电站的计划发电量为: 25.0
# 第 38 个火力发电站的计划发电量为: 10.0
# 第 39 个火力发电站的计划发电量为: 300.0
# 第 40 个火力发电站的计划发电量为: 177.99326408584776
# 第 41 个火力发电站的计划发电量为: 8.0
# 第 42 个火力发电站的计划发电量为: 20.0
# 第 43 个火力发电站的计划发电量为: 188.73451681197372
# 第 44 个火力发电站的计划发电量为: 178.33138711442348
# 第 45 个火力发电站的计划发电量为: 209.46916678242482
# 第 46 个火力发电站的计划发电量为: 8.0
# 第 47 个火力发电站的计划发电量为: 25.142119388996935
# 第 48 个火力发电站的计划发电量为: 26.324376019798308
# 第 49 个火力发电站的计划发电量为: 8.0
# 第 50 个火力发电站的计划发电量为: 25.0
# 第 51 个火力发电站的计划发电量为: 47.77097003240933
# 第 52 个火力发电站的计划发电量为: 47.77097003240933
# 第 53 个火力发电站的计划发电量为: 25.0
# 第 55 个风力发电站的计划发电量为: 131.1369056946892
# 第 56 个风力发电站的计划发电量为: 47.44989156470409
# 第 57 个风力发电站的计划发电量为: 95.62588772531836
# 第 59 个风力发电站的计划发电量为: 103.76514407467597
# 第 60 个风力发电站的计划发电量为: 33.28889927664105
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -1087.6579405200525
# 第 2 个火力发电站的对偶变量为: -1083.0067262745679
# 第 3 个火力发电站的对偶变量为: -1067.2164243013647
# 第 4 个火力发电站的对偶变量为: -986.3426487926504
# 第 5 个火力发电站的对偶变量为: -1069.500981946003
# 第 6 个火力发电站的对偶变量为: -1071.9269292826355
# 第 7 个火力发电站的对偶变量为: -1071.8655168873468
# 第 8 个火力发电站的对偶变量为: -1091.7945176152004
# 第 9 个火力发电站的对偶变量为: -1110.1490287704366
# 第 10 个火力发电站的对偶变量为: -1094.6552190936154
# 第 11 个火力发电站的对偶变量为: -1071.9581032576555
# 第 12 个火力发电站的对偶变量为: -1099.7707586661388
# 第 13 个火力发电站的对偶变量为: -1074.9694737652694
# 第 14 个火力发电站的对偶变量为: -1094.8480303764582
# 第 15 个火力发电站的对偶变量为: -1084.3375319191127
# 第 16 个火力发电站的对偶变量为: -1074.5762048155723
# 第 17 个火力发电站的对偶变量为: -1076.1242174047304
# 第 18 个火力发电站的对偶变量为: -1082.3843005304482
# 第 19 个火力发电站的对偶变量为: -1106.7443227248154
# 第 20 个火力发电站的对偶变量为: -1071.9654462684066
# 第 21 个火力发电站的对偶变量为: -989.8238997278263
# 第 22 个火力发电站的对偶变量为: -978.670690443409
# 第 23 个火力发电站的对偶变量为: -978.6706904434091
# 第 24 个火力发电站的对偶变量为: -972.5457956959148
# 第 25 个火力发电站的对偶变量为: -959.024170245959
# 第 26 个火力发电站的对偶变量为: -954.6416197555523
# 第 27 个火力发电站的对偶变量为: -1056.2885917947085
# 第 28 个火力发电站的对偶变量为: -974.4126663980832
# 第 29 个火力发电站的对偶变量为: -1099.0244072721327
# 第 30 个火力发电站的对偶变量为: -1118.3989271399375
# 第 31 个火力发电站的对偶变量为: -1141.7542800638826
# 第 32 个火力发电站的对偶变量为: -1142.8408728320753
# 第 33 个火力发电站的对偶变量为: -1113.8155775023124
# 第 34 个火力发电站的对偶变量为: -1108.9129436513347
# 第 35 个火力发电站的对偶变量为: -1081.0001255204916
# 第 36 个火力发电站的对偶变量为: -1037.255605999808
# 第 37 个火力发电站的对偶变量为: -1035.8617454350815
# 第 38 个火力发电站的对偶变量为: -993.1360804868134
# 第 39 个火力发电站的对偶变量为: -953.9852933678258
# 第 40 个火力发电站的对偶变量为: -1017.0169896581151
# 第 41 个火力发电站的对偶变量为: -1031.3514549721103
# 第 42 个火力发电站的对偶变量为: -1036.9331987702897
# 第 43 个火力发电站的对偶变量为: -1032.0422813092616
# 第 44 个火力发电站的对偶变量为: -1020.0658319885923
# 第 45 个火力发电站的对偶变量为: -1064.5938844197772
# 第 46 个火力发电站的对偶变量为: -1120.6095611443761
# 第 47 个火力发电站的对偶变量为: -1111.2954602030377
# 第 48 个火力发电站的对偶变量为: -1118.319273739323
# 第 49 个火力发电站的对偶变量为: -1107.6432889737027
# 第 50 个火力发电站的对偶变量为: -1156.3975223545435
# 第 51 个火力发电站的对偶变量为: -1164.9892799613353
# 第 52 个火力发电站的对偶变量为: -1164.9892799613353
# 第 53 个火力发电站的对偶变量为: -1072.0488543186302
# 第 55 个风力发电站的对偶变量为: -1079.049945084883
# 第 56 个风力发电站的对偶变量为: -1102.1105473404937
# 第 57 个风力发电站的对偶变量为: -1097.8648062626603
# 第 59 个风力发电站的对偶变量为: -1069.3419991801763
# 第 60 个风力发电站的对偶变量为: -1108.0940153861748
# ****************************************************************************
# 第 54 个受到Byzantin攻击的火力发电站的初始对偶变量为: -1525.54684523
# 第 58 个受到Byzantin攻击的风力发电站的初始对偶变量为: -1525.54684523
# ****************************************************************************
# 安全发电站的总发电量: 5152.223293695884
# *************************
# 需求侧平均用电需求: 92.5131194
# ****************************************************************************
# 风速分布参数c: 8.59739237
# ****************************************************************************
# 风速分布参数kappa: 2.24000001
# ****************************************************************************
# 安全发电站的总发电成本： 76157.51853407046
# ****************************************************************************
# 原变量迭代步长为: 5
# ****************************************************************************
# 对偶变量迭代步长为: 5
# ****************************************************************************
# 49 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 5.0
# 第 2 个火力发电站的计划发电量为: 5.0
# 第 3 个火力发电站的计划发电量为: 5.0
# 第 4 个火力发电站的计划发电量为: 166.1533955816225
# 第 5 个火力发电站的计划发电量为: 229.13871698707072
# 第 6 个火力发电站的计划发电量为: 10.0
# 第 7 个火力发电站的计划发电量为: 25.0
# 第 8 个火力发电站的计划发电量为: 5.0
# 第 9 个火力发电站的计划发电量为: 5.0
# 第 10 个火力发电站的计划发电量为: 247.9997692397637
# 第 11 个火力发电站的计划发电量为: 350.0
# 第 12 个火力发电站的计划发电量为: 8.0
# 第 13 个火力发电站的计划发电量为: 8.0
# 第 14 个火力发电站的计划发电量为: 26.563811903343986
# 第 15 个火力发电站的计划发电量为: 8.0
# 第 16 个火力发电站的计划发电量为: 25.0
# 第 17 个火力发电站的计划发电量为: 8.0
# 第 18 个火力发电站的计划发电量为: 8.0
# 第 19 个火力发电站的计划发电量为: 31.230449994512135
# 第 20 个火力发电站的计划发电量为: 250.0
# 第 21 个火力发电站的计划发电量为: 250.0
# 第 22 个火力发电站的计划发电量为: 25.0
# 第 23 个火力发电站的计划发电量为: 25.0
# 第 24 个火力发电站的计划发电量为: 200.0
# 第 25 个火力发电站的计划发电量为: 200.0
# 第 26 个火力发电站的计划发电量为: 25.0
# 第 27 个火力发电站的计划发电量为: 420.0
# 第 28 个火力发电站的计划发电量为: 375.31983504063186
# 第 29 个火力发电站的计划发电量为: 251.15874517913295
# 第 30 个火力发电站的计划发电量为: 38.06334190428274
# 第 31 个火力发电站的计划发电量为: 10.0
# 第 32 个火力发电站的计划发电量为: 5.0
# 第 33 个火力发电站的计划发电量为: 5.0
# 第 34 个火力发电站的计划发电量为: 32.16532514966842
# 第 35 个火力发电站的计划发电量为: 25.0
# 第 36 个火力发电站的计划发电量为: 204.37627366823898
# 第 37 个火力发电站的计划发电量为: 25.0
# 第 38 个火力发电站的计划发电量为: 10.0
# 第 39 个火力发电站的计划发电量为: 300.0
# 第 40 个火力发电站的计划发电量为: 188.7530758917025
# 第 41 个火力发电站的计划发电量为: 8.0
# 第 42 个火力发电站的计划发电量为: 20.0
# 第 43 个火力发电站的计划发电量为: 200.32017104607678
# 第 44 个火力发电站的计划发电量为: 190.6588836002235
# 第 45 个火力发电站的计划发电量为: 224.76957735587345
# 第 46 个火力发电站的计划发电量为: 8.0
# 第 47 个火力发电站的计划发电量为: 33.33790281214176
# 第 48 个火力发电站的计划发电量为: 37.2319772236639
# 第 49 个火力发电站的计划发电量为: 8.0
# 第 50 个火力发电站的计划发电量为: 25.0
# 第 51 个火力发电站的计划发电量为: 65.2365569804873
# 第 52 个火力发电站的计划发电量为: 65.2365569804873
# 第 53 个火力发电站的计划发电量为: 25.0
# 第 55 个风力发电站的计划发电量为: 135.00328474298004
# 第 56 个风力发电站的计划发电量为: 48.44814885191072
# 第 57 个风力发电站的计划发电量为: 99.73408848431171
# 第 59 个风力发电站的计划发电量为: 107.34511126353817
# 第 60 个风力发电站的计划发电量为: 34.29703752342444
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -1111.1017041996265
# 第 2 个火力发电站的对偶变量为: -1106.270034631535
# 第 3 个火力发电站的对偶变量为: -1090.5623928221407
# 第 4 个火力发电站的对偶变量为: -1006.4338111867087
# 第 5 个火力发电站的对偶变量为: -1092.8397037614482
# 第 6 个火力发电站的对偶变量为: -1095.5105086034691
# 第 7 个火力发电站的对偶变量为: -1095.4684678421543
# 第 8 个火力发电站的对偶变量为: -1115.918128994011
# 第 9 个火力发电站的对偶变量为: -1134.8641281532844
# 第 10 个火力发电站的对偶变量为: -1118.6725510673407
# 第 11 个火力发电站的对偶变量为: -1095.5748915409201
# 第 12 个火力发电站的对偶变量为: -1123.907819408455
# 第 13 个火力发电站的对偶变量为: -1098.6468121888154
# 第 14 个火力发电站的对偶变量为: -1118.8715378005882
# 第 15 个火力发电站的对偶变量为: -1108.5231796345847
# 第 16 个火力发电站的对偶变量为: -1098.6401622798644
# 第 17 个火力发电站的对偶变量为: -1100.2175614771643
# 第 18 个火力发电站的对偶变量为: -1106.8813069324003
# 第 19 个火力发电站的对偶变量为: -1131.1451241905622
# 第 20 个火力发电站的对偶变量为: -1095.3900777789415
# 第 21 个火力发电站的对偶变量为: -1009.6927370628612
# 第 22 个火力发电站的对偶变量为: -997.7563930536618
# 第 23 个火力发电站的对偶变量为: -997.7563930536618
# 第 24 个火力发电站的对偶变量为: -991.9133829934409
# 第 25 个火力发电站的对偶变量为: -978.4080800031205
# 第 26 个火力发电站的对偶变量为: -973.7707780661367
# 第 27 个火力发电站的对偶变量为: -1079.100287438489
# 第 28 个火力发电站的对偶变量为: -994.4517432775915
# 第 29 个火力发电站的对偶变量为: -1123.3130000138483
# 第 30 个火力发电站的对偶变量为: -1143.591837587231
# 第 31 个火力发电站的对偶变量为: -1168.4772776349057
# 第 32 个火力发电站的对偶变量为: -1169.5943120508834
# 第 33 个火力发电站的对偶变量为: -1138.7344048556647
# 第 34 个火力发电站的对偶变量为: -1133.1522294455635
# 第 35 个火力发电站的对偶变量为: -1103.9070441327144
# 第 36 个火力发电站的对偶变量为: -1056.8463539113404
# 第 37 个火力发电站的对偶变量为: -1055.5444119416838
# 第 38 个火力发电站的对偶变量为: -1011.440736870487
# 第 39 个火力发电站的对偶变量为: -972.3944405678892
# 第 40 个火力发电站的对偶变量为: -1034.6618091132796
# 第 41 个火力发电站的对偶变量为: -1048.7612551795912
# 第 42 个火力发电站的对偶变量为: -1054.5757568534068
# 第 43 个火力发电站的对偶变量为: -1050.5353542751752
# 第 44 个火力发电站的对偶变量为: -1037.9855495917336
# 第 45 个火力发电站的对偶变量为: -1085.5945022219578
# 第 46 个火力发电站的对偶变量为: -1144.5717678399606
# 第 47 个火力发电站的对偶变量为: -1135.0834640464534
# 第 48 个火力发电站的对偶变量为: -1142.7889362165572
# 第 49 个火力发电站的对偶变量为: -1131.6872819821608
# 第 50 个火力发电站的对偶变量为: -1180.4012928029695
# 第 51 个火力发电站的对偶变量为: -1188.8011629623484
# 第 52 个火力发电站的对偶变量为: -1188.8011629623484
# 第 53 个火力发电站的对偶变量为: -1095.6370054977115
# 第 55 个风力发电站的对偶变量为: -1102.271379722149
# 第 56 个风力发电站的对偶变量为: -1126.5706133687147
# 第 57 个风力发电站的对偶变量为: -1121.9369609746252
# 第 59 个风力发电站的对偶变量为: -1093.0475375162555
# 第 60 个风力发电站的对偶变量为: -1132.5441518610337
# ****************************************************************************
# 第 54 个受到Byzantin攻击的火力发电站的初始对偶变量为: -1512.57359061
# 第 58 个受到Byzantin攻击的风力发电站的初始对偶变量为: -1512.57359061
# ****************************************************************************
# 安全发电站的总发电量: 5376.542037405089
# *************************
# 需求侧平均用电需求: 115.29130885
# ****************************************************************************
# 风速分布参数c: 8.55654343
# ****************************************************************************
# 风速分布参数kappa: 2.24000001
# ****************************************************************************
# 安全发电站的总发电成本： 80197.01250686937
# ****************************************************************************
# 原变量迭代步长为: 5
# ****************************************************************************
# 对偶变量迭代步长为: 5
# ****************************************************************************
# 59 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 5.0
# 第 2 个火力发电站的计划发电量为: 5.0
# 第 3 个火力发电站的计划发电量为: 5.0
# 第 4 个火力发电站的计划发电量为: 177.5428286697066
# 第 5 个火力发电站的计划发电量为: 244.75287233170243
# 第 6 个火力发电站的计划发电量为: 10.0
# 第 7 个火力发电站的计划发电量为: 25.22686707385695
# 第 8 个火力发电站的计划发电量为: 5.0
# 第 9 个火力发电站的计划发电量为: 5.0
# 第 10 个火力发电站的计划发电量为: 264.2052698386558
# 第 11 个火力发电站的计划发电量为: 350.0
# 第 12 个火力发电站的计划发电量为: 8.0
# 第 13 个火力发电站的计划发电量为: 8.0
# 第 14 个火力发电站的计划发电量为: 35.447475416631846
# 第 15 个火力发电站的计划发电量为: 8.0
# 第 16 个火力发电站的计划发电量为: 26.122630067356987
# 第 17 个火力发电站的计划发电量为: 8.0
# 第 18 个火力发电站的计划发电量为: 8.0
# 第 19 个火力发电站的计划发电量为: 41.59516893053747
# 第 20 个火力发电站的计划发电量为: 250.0
# 第 21 个火力发电站的计划发电量为: 250.0
# 第 22 个火力发电站的计划发电量为: 25.0
# 第 23 个火力发电站的计划发电量为: 25.0
# 第 24 个火力发电站的计划发电量为: 200.0
# 第 25 个火力发电站的计划发电量为: 200.0
# 第 26 个火力发电站的计划发电量为: 25.0
# 第 27 个火力发电站的计划发电量为: 420.0
# 第 28 个火力发电站的计划发电量为: 388.4352650271731
# 第 29 个火力发电站的计划发电量为: 267.2373222594192
# 第 30 个火力发电站的计划发电量为: 41.327757819772245
# 第 31 个火力发电站的计划发电量为: 10.0
# 第 32 个火力发电站的计划发电量为: 5.0
# 第 33 个火力发电站的计划发电量为: 5.0
# 第 34 个火力发电站的计划发电量为: 43.1775678912559
# 第 35 个火力发电站的计划发电量为: 27.223521030037716
# 第 36 个火力发电站的计划发电量为: 216.4784610992535
# 第 37 个火力发电站的计划发电量为: 25.0
# 第 38 个火力发电站的计划发电量为: 10.0
# 第 39 个火力发电站的计划发电量为: 300.0
# 第 40 个火力发电站的计划发电量为: 199.8821141656987
# 第 41 个火力发电站的计划发电量为: 8.0
# 第 42 个火力发电站的计划发电量为: 20.0
# 第 43 个火力发电站的计划发电量为: 211.8184038431099
# 第 44 个火力发电站的计划发电量为: 201.67462407737364
# 第 45 个火力发电站的计划发电量为: 238.0391108036085
# 第 46 个火力发电站的计划发电量为: 8.0
# 第 47 个火力发电站的计划发电量为: 43.778283825295375
# 第 48 个火力发电站的计划发电量为: 48.67343355087938
# 第 49 个火力发电站的计划发电量为: 8.0
# 第 50 个火力发电站的计划发电量为: 25.0
# 第 51 个火力发电站的计划发电量为: 77.76122958321798
# 第 52 个火力发电站的计划发电量为: 77.76122958321798
# 第 53 个火力发电站的计划发电量为: 25.22930009566382
# 第 55 个风力发电站的计划发电量为: 138.13892142674993
# 第 56 个风力发电站的计划发电量为: 49.27683816293704
# 第 57 个风力发电站的计划发电量为: 102.94224132668688
# 第 59 个风力发电站的计划发电量为: 109.75787917563915
# 第 60 个风力发电站的计划发电量为: 34.99014195940006
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -1126.8581447709848
# 第 2 个火力发电站的对偶变量为: -1121.8108925127235
# 第 3 个火力发电站的对偶变量为: -1105.706971428369
# 第 4 个火力发电站的对偶变量为: -1014.449885836108
# 第 5 个火力发电站的对偶变量为: -1108.2564594655134
# 第 6 个火力发电站的对偶变量为: -1111.1277806001324
# 第 7 个火力发电站的对偶变量为: -1111.068173701487
# 第 8 个火力发电站的对偶变量为: -1131.8608751518448
# 第 9 个火力发电站的对偶变量为: -1150.3302055927998
# 第 10 个火力发电站的对偶变量为: -1133.8262917167374
# 第 11 个火力发电站的对偶变量为: -1111.1565976336447
# 第 12 个火力发电站的对偶变量为: -1139.2980598480262
# 第 13 个火力发电站的对偶变量为: -1114.1308452578628
# 第 14 个火力发电站的对偶变量为: -1134.1145500657951
# 第 15 个火力发电站的对偶变量为: -1124.731637495165
# 第 16 个火力发电站的对偶变量为: -1114.812529348591
# 第 17 个火力发电站的对偶变量为: -1116.2784812968189
# 第 18 个火力发电站的对偶变量为: -1122.4765334122537
# 第 19 个火力发电站的对偶变量为: -1142.247610028619
# 第 20 个火力发电站的对偶变量为: -1108.293327788796
# 第 21 个火力发电站的对偶变量为: -1023.6244049647255
# 第 22 个火力发电站的对偶变量为: -1011.8016985808081
# 第 23 个火力发电站的对偶变量为: -1011.8016985808081
# 第 24 个火力发电站的对偶变量为: -1005.8065356191348
# 第 25 个火力发电站的对偶变量为: -992.0542901545311
# 第 26 个火力发电站的对偶变量为: -986.7269364248493
# 第 27 个火力发电站的对偶变量为: -1093.889971842803
# 第 28 个火力发电站的对偶变量为: -1006.9214626552405
# 第 29 个火力发电站的对偶变量为: -1136.7829595109424
# 第 30 个火力发电站的对偶变量为: -1158.780132042191
# 第 31 个火力发电站的对偶变量为: -1185.7075979073777
# 第 32 个火力发电站的对偶变量为: -1186.7349128465594
# 第 33 个火力发电站的对偶变量为: -1153.4116847925266
# 第 34 个火力发电站的对偶变量为: -1145.7835867222793
# 第 35 个火力发电站的对偶变量为: -1116.4590366768598
# 第 36 个火力发电站的对偶变量为: -1066.444287240991
# 第 37 个火力发电站的对偶变量为: -1065.9583714255825
# 第 38 个火力发电站的对偶变量为: -1021.85987349718
# 第 39 个火力发电站的对偶变量为: -983.5924058926677
# 第 40 个火力发电站的对偶变量为: -1044.348180508171
# 第 41 个火力发电站的对偶变量为: -1058.4286241497211
# 第 42 个火力发电站的对偶变量为: -1064.3033904587382
# 第 43 个火力发电站的对偶变量为: -1059.973834374842
# 第 44 个火力发电站的对偶变量为: -1045.5245528908895
# 第 45 个火力发电站的对偶变量为: -1095.1880224398355
# 第 46 个火力发电站的对偶变量为: -1154.6607218310091
# 第 47 个火力发电站的对偶变量为: -1145.1250522712403
# 第 48 个火力发电站的对偶变量为: -1153.380589444111
# 第 49 个火力发电站的对偶变量为: -1142.4776692867524
# 第 50 个火力发电站的对偶变量为: -1189.9483852822834
# 第 51 个火力发电站的对偶变量为: -1198.0284878931996
# 第 52 个火力发电站的对偶变量为: -1198.0284878931996
# 第 53 个火力发电站的对偶变量为: -1111.053077795056
# 第 55 个风力发电站的对偶变量为: -1117.7513507722017
# 第 56 个风力发电站的对偶变量为: -1142.5579157528396
# 第 57 个风力发电站的对偶变量为: -1137.2116480529985
# 第 59 个风力发电站的对偶变量为: -1106.8800755943048
# 第 60 个风力发电站的对偶变量为: -1146.3382021357047
# ****************************************************************************
# 第 54 个受到Byzantin攻击的火力发电站的初始对偶变量为: -1471.61058041
# 第 58 个受到Byzantin攻击的风力发电站的初始对偶变量为: -1471.61058041
# ****************************************************************************
# 安全发电站的总发电量: 5602.496759034837
# *************************
# 需求侧平均用电需求: 114.50575338
# ****************************************************************************
# 风速分布参数c: 8.52593303
# ****************************************************************************
# 风速分布参数kappa: 2.25999999
# ****************************************************************************
# 安全发电站的总发电成本： 84314.03227750288
# ****************************************************************************
# 原变量迭代步长为: 5
# ****************************************************************************
# 对偶变量迭代步长为: 5
# ****************************************************************************
# 69 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 5.0
# 第 2 个火力发电站的计划发电量为: 5.0
# 第 3 个火力发电站的计划发电量为: 5.0
# 第 4 个火力发电站的计划发电量为: 185.0321530835406
# 第 5 个火力发电站的计划发电量为: 257.528825402004
# 第 6 个火力发电站的计划发电量为: 10.0
# 第 7 个火力发电站的计划发电量为: 31.123191113845774
# 第 8 个火力发电站的计划发电量为: 5.0
# 第 9 个火力发电站的计划发电量为: 5.0
# 第 10 个火力发电站的计划发电量为: 276.9510720863196
# 第 11 个火力发电站的计划发电量为: 350.0
# 第 12 个火力发电站的计划发电量为: 8.0
# 第 13 个火力发电站的计划发电量为: 8.0
# 第 14 个火力发电站的计划发电量为: 44.80362904643306
# 第 15 个火力发电站的计划发电量为: 8.0
# 第 16 个火力发电站的计划发电量为: 33.22397311585539
# 第 17 个火力发电站的计划发电量为: 8.0
# 第 18 个火力发电站的计划发电量为: 8.0
# 第 19 个火力发电站的计划发电量为: 48.87508425081596
# 第 20 个火力发电站的计划发电量为: 250.0
# 第 21 个火力发电站的计划发电量为: 250.0
# 第 22 个火力发电站的计划发电量为: 25.0
# 第 23 个火力发电站的计划发电量为: 25.0
# 第 24 个火力发电站的计划发电量为: 200.0
# 第 25 个火力发电站的计划发电量为: 200.0
# 第 26 个火力发电站的计划发电量为: 25.0
# 第 27 个火力发电站的计划发电量为: 420.0
# 第 28 个火力发电站的计划发电量为: 399.2198775598669
# 第 29 个火力发电站的计划发电量为: 278.7036294045715
# 第 30 个火力发电站的计划发电量为: 43.885733313734306
# 第 31 个火力发电站的计划发电量为: 10.0
# 第 32 个火力发电站的计划发电量为: 5.0
# 第 33 个火力发电站的计划发电量为: 5.0
# 第 34 个火力发电站的计划发电量为: 51.45498422974801
# 第 35 个火力发电站的计划发电量为: 33.20432453496464
# 第 36 个火力发电站的计划发电量为: 224.90138863252537
# 第 37 个火力发电站的计划发电量为: 25.0
# 第 38 个火力发电站的计划发电量为: 10.0
# 第 39 个火力发电站的计划发电量为: 300.0
# 第 40 个火力发电站的计划发电量为: 200.0
# 第 41 个火力发电站的计划发电量为: 8.0
# 第 42 个火力发电站的计划发电量为: 20.0
# 第 43 个火力发电站的计划发电量为: 220.11093311894734
# 第 44 个火力发电站的计划发电量为: 208.72649460410443
# 第 45 个火力发电站的计划发电量为: 246.58333351905577
# 第 46 个火力发电站的计划发电量为: 8.0
# 第 47 个火力发电站的计划发电量为: 50.351610322169876
# 第 48 个火力发电站的计划发电量为: 55.68027049399645
# 第 49 个火力发电站的计划发电量为: 8.0
# 第 50 个火力发电站的计划发电量为: 25.0
# 第 51 个火力发电站的计划发电量为: 84.42006206525872
# 第 52 个火力发电站的计划发电量为: 84.42006206525872
# 第 53 个火力发电站的计划发电量为: 31.060929002332482
# 第 55 个风力发电站的计划发电量为: 141.2692321485785
# 第 56 个风力发电站的计划发电量为: 50.302179420643256
# 第 57 个风力发电站的计划发电量为: 105.99836839817044
# 第 59 个风力发电站的计划发电量为: 111.8353777717229
# 第 60 个风力发电站的计划发电量为: 35.8026290755691
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -1143.6742514213436
# 第 2 个火力发电站的对偶变量为: -1138.3907713841795
# 第 3 个火力发电站的对偶变量为: -1121.3981726742209
# 第 4 个火力发电站的对偶变量为: -1023.4148642967868
# 第 5 个火力发电站的对偶变量为: -1124.2857552418834
# 第 6 个火力发电站的对偶变量为: -1127.2461790758325
# 第 7 个火力发电站的对偶变量为: -1127.0609397692422
# 第 8 个火力发电站的对偶变量为: -1148.2188449060648
# 第 9 个火力发电站的对偶变量为: -1165.948607004009
# 第 10 个火力发电站的对偶变量为: -1149.4348013786612
# 第 11 个火力发电站的对偶变量为: -1127.1232632213378
# 第 12 个火力发电站的对偶变量为: -1155.2146273297283
# 第 13 个火力发电站的对偶变量为: -1130.0645895402665
# 第 14 个火力发电站的对偶变量为: -1149.7538234865337
# 第 15 个火力发电站的对偶变量为: -1141.2326954117789
# 第 16 个火力发电站的对偶变量为: -1130.9760081910615
# 第 17 个火力发电站的对偶变量为: -1132.555837681956
# 第 18 个火力发电站的对偶变量为: -1137.913660188466
# 第 19 个火力发电站的对偶变量为: -1152.6320264420942
# 第 20 个火力发电站的对偶变量为: -1121.0994619510207
# 第 21 个火力发电站的对偶变量为: -1039.1908989491603
# 第 22 个火力发电站的对偶变量为: -1027.8656978240188
# 第 23 个火力发电站的对偶变量为: -1027.8656978240188
# 第 24 个火力发电站的对偶变量为: -1021.5681811137955
# 第 25 个火力发电站的对偶变量为: -1007.5108405395268
# 第 26 个火力发电站的对偶变量为: -1001.4363065358398
# 第 27 个火力发电站的对偶变量为: -1109.3010601455671
# 第 28 个火力发电站的对偶变量为: -1020.6239258300006
# 第 29 个火力发电站的对偶变量为: -1149.705522426449
# 第 30 个火力发电站的对偶变量为: -1173.5147229441504
# 第 31 个火力发电站的对偶变量为: -1202.6549097215761
# 第 32 个火力发电站的对偶变量为: -1203.4866617210357
# 第 33 个火力发电站的对偶变量为: -1167.3227985806514
# 第 34 个火力发电站的对偶变量为: -1157.7808718885633
# 第 35 个火力发电站的对偶变量为: -1128.640399426007
# 第 36 个火力发电站的对偶变量为: -1076.3356831752628
# 第 37 个火力发电站的对偶变量为: -1076.6896141506422
# 第 38 个火力发电站的对偶变量为: -1033.4052943534202
# 第 39 个火力发电站的对偶变量为: -995.7559629876584
# 第 40 个火力发电站的对偶变量为: -1055.3955313022711
# 第 41 个火力发电站的对偶变量为: -1069.5140934421322
# 第 42 个火力发电站的对偶变量为: -1075.1453966289369
# 第 43 个火力发电站的对偶变量为: -1070.2103571934401
# 第 44 个火力发电站的对偶变量为: -1053.5908220716767
# 第 45 个火力发电站的对偶变量为: -1104.341433992405
# 第 46 个火力发电站的对偶变量为: -1163.1548784918036
# 第 47 个火力发电站的对偶变量为: -1153.6726339535355
# 第 48 个火力发电站的对偶变量为: -1162.1779468755394
# 第 49 个火力发电站的对偶变量为: -1151.5571357098365
# 第 50 个火力发电站的对偶变量为: -1197.803674718354
# 第 51 个火力发电站的对偶变量为: -1205.6223894722166
# 第 52 个火力发电站的对偶变量为: -1205.6223894722166
# 第 53 个火力发电站的对偶变量为: -1126.8440332222976
# 第 55 个风力发电站的对偶变量为: -1134.215787478124
# 第 56 个风力发电站的对偶变量为: -1159.0498231147878
# 第 57 个风力发电站的对偶变量为: -1152.9275148520528
# 第 59 个风力发电站的对偶变量为: -1120.141584301246
# 第 60 个风力发电站的对偶变量为: -1159.499058569098
# ****************************************************************************
# 第 54 个受到Byzantin攻击的火力发电站的初始对偶变量为: -1501.50133872
# 第 58 个受到Byzantin攻击的风力发电站的初始对偶变量为: -1501.50133872
# ****************************************************************************
# 安全发电站的总发电量: 5779.469347780032
# *************************
# 需求侧平均用电需求: 103.02196875
# ****************************************************************************
# 风速分布参数c: 8.51365986
# ****************************************************************************
# 风速分布参数kappa: 2.27999997
# ****************************************************************************
# 安全发电站的总发电成本： 87579.96638505484
# ****************************************************************************
# 原变量迭代步长为: 5
# ****************************************************************************
# 对偶变量迭代步长为: 5
# ****************************************************************************
# 79 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 5.0
# 第 2 个火力发电站的计划发电量为: 5.0
# 第 3 个火力发电站的计划发电量为: 5.0
# 第 4 个火力发电站的计划发电量为: 191.2410487931647
# 第 5 个火力发电站的计划发电量为: 268.5991514379374
# 第 6 个火力发电站的计划发电量为: 10.0
# 第 7 个火力发电站的计划发电量为: 39.063139647809066
# 第 8 个火力发电站的计划发电量为: 5.0
# 第 9 个火力发电站的计划发电量为: 5.0
# 第 10 个火力发电站的计划发电量为: 287.8326965688823
# 第 11 个火力发电站的计划发电量为: 350.0
# 第 12 个火力发电站的计划发电量为: 8.0
# 第 13 个火力发电站的计划发电量为: 8.0
# 第 14 个火力发电站的计划发电量为: 53.516066551985006
# 第 15 个火力发电站的计划发电量为: 8.0
# 第 16 个火力发电站的计划发电量为: 41.51181971161291
# 第 17 个火力发电站的计划发电量为: 8.0
# 第 18 个火力发电站的计划发电量为: 8.0
# 第 19 个火力发电站的计划发电量为: 54.656514086728436
# 第 20 个火力发电站的计划发电量为: 250.0
# 第 21 个火力发电站的计划发电量为: 250.0
# 第 22 个火力发电站的计划发电量为: 25.0
# 第 23 个火力发电站的计划发电量为: 25.0
# 第 24 个火力发电站的计划发电量为: 200.0
# 第 25 个火力发电站的计划发电量为: 200.0
# 第 26 个火力发电站的计划发电量为: 25.0
# 第 27 个火力发电站的计划发电量为: 420.0
# 第 28 个火力发电站的计划发电量为: 408.8982957210899
# 第 29 个火力发电站的计划发电量为: 287.79076132329794
# 第 30 个火力发电站的计划发电量为: 46.08461821914159
# 第 31 个火力发电站的计划发电量为: 10.0
# 第 32 个火力发电站的计划发电量为: 5.0
# 第 33 个火力发电站的计划发电量为: 5.0
# 第 34 个火力发电站的计划发电量为: 58.13790637591284
# 第 35 个火力发电站的计划发电量为: 39.429154199594976
# 第 36 个火力发电站的计划发电量为: 231.62695039865602
# 第 37 个火力发电站的计划发电量为: 25.0
# 第 38 个火力发电站的计划发电量为: 10.0
# 第 39 个火力发电站的计划发电量为: 300.0
# 第 40 个火力发电站的计划发电量为: 200.0
# 第 41 个火力发电站的计划发电量为: 8.0
# 第 42 个火力发电站的计划发电量为: 20.0
# 第 43 个火力发电站的计划发电量为: 227.08523056868225
# 第 44 个火力发电站的计划发电量为: 214.1445130888313
# 第 45 个火力发电站的计划发电量为: 252.91261670407883
# 第 46 个火力发电站的计划发电量为: 8.0
# 第 47 个火力发电站的计划发电量为: 54.97125344555306
# 第 48 个火力发电站的计划发电量为: 60.49008829406344
# 第 49 个火力发电站的计划发电量为: 8.0
# 第 50 个火力发电站的计划发电量为: 25.0
# 第 51 个火力发电站的计划发电量为: 88.58846866606683
# 第 52 个火力发电站的计划发电量为: 88.58846866606683
# 第 53 个火力发电站的计划发电量为: 38.89323222174093
# 第 55 个风力发电站的计划发电量为: 144.18695943450956
# 第 56 个风力发电站的计划发电量为: 51.1216517701318
# 第 57 个风力发电站的计划发电量为: 108.79442740572375
# 第 59 个风力发电站的计划发电量为: 113.46559721158751
# 第 60 个风力发电站的计划发电量为: 36.40672752650987
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -1156.5250250301588
# 第 2 个火力发电站的对偶变量为: -1150.9758244651082
# 第 3 个火力发电站的对偶变量为: -1132.905049144133
# 第 4 个火力发电站的对偶变量为: -1029.8699341701013
# 第 5 个火力发电站的对偶变量为: -1136.0329202199525
# 第 6 个火力发电站的对偶变量为: -1139.020352330426
# 第 7 个火力发电站的对偶变量为: -1138.6317400425387
# 第 8 个火力发电站的对偶变量为: -1160.197829122682
# 第 9 个火力发电站的对偶变量为: -1177.3453079515555
# 第 10 个火力发电站的对偶变量为: -1160.8952993825333
# 第 11 个火力发电站的对偶变量为: -1138.7075100108573
# 第 12 个火力发电站的对偶变量为: -1167.0517416812102
# 第 13 个火力发电站的对偶变量为: -1141.6725796165422
# 第 14 个火力发电站的对偶变量为: -1161.1819760813823
# 第 15 个火力发电站的对偶变量为: -1153.28763154389
# 第 16 个火力发电站的对偶变量为: -1142.587247257849
# 第 17 个火力发电站的对偶变量为: -1144.4395215681936
# 第 18 个火力发电站的对偶变量为: -1149.2221447160528
# 第 19 个火力发电站的对偶变量为: -1159.4605092921604
# 第 20 个火力发电站的对偶变量为: -1130.2620244501445
# 第 21 个火力发电站的对偶变量为: -1051.5373200373715
# 第 22 个火力发电站的对偶变量为: -1040.8058240187365
# 第 23 个火力发电站的对偶变量为: -1040.8058240187365
# 第 24 个火力发电站的对偶变量为: -1034.1119990098784
# 第 25 个火力发电站的对偶变量为: -1019.7100964425397
# 第 26 个火力发电站的对偶变量为: -1012.9383292599268
# 第 27 个火力发电站的对偶变量为: -1120.5594195280262
# 第 28 个火力发电站的对偶变量为: -1030.978321210041
# 第 29 个火力发电站的对偶变量为: -1158.6480912865097
# 第 30 个火力发电站的对偶变量为: -1183.9971418120956
# 第 31 个火力发电站的对偶变量为: -1215.1765471262217
# 第 32 个火力发电站的对偶变量为: -1215.8019838641985
# 第 33 个火力发电站的对偶变量为: -1176.9543569751786
# 第 34 个火力发电站的对偶变量为: -1165.7461654561912
# 第 35 个火力发电站的对偶变量为: -1136.8920168437567
# 第 36 个火力发电站的对偶变量为: -1082.8818425651891
# 第 37 个火力发电站的对偶变量为: -1084.1404336805072
# 第 38 个火力发电站的对偶变量为: -1041.944515734396
# 第 39 个火力发电站的对偶变量为: -1004.8807172902568
# 第 40 个火力发电站的对偶变量为: -1063.6120731121782
# 第 41 个火力发电站的对偶变量为: -1077.8704722721034
# 第 42 个火力发电站的对偶变量为: -1083.220136136326
# 第 43 个火力发电站的对偶变量为: -1077.4081255585509
# 第 44 个火力发电站的对偶变量为: -1058.6075026291314
# 第 45 个火力发电站的对偶变量为: -1110.028300307119
# 第 46 个火力发电站的对偶变量为: -1167.8021167754498
# 第 47 个火力发电站的对偶变量为: -1158.4127928976702
# 第 48 个火力发电站的对偶变量为: -1167.0311387640995
# 第 49 个火力发电站的对偶变量为: -1156.6913407951179
# 第 50 个火力发电站的对偶变量为: -1201.7951296880747
# 第 51 个火力发电站的对偶变量为: -1209.384070162267
# 第 52 个火力发电站的对偶变量为: -1209.384070162267
# 第 53 个火力发电站的对偶变量为: -1138.2419927617836
# 第 55 个风力发电站的对偶变量为: -1146.640101532484
# 第 56 个风力发电站的对偶变量为: -1171.427788243677
# 第 57 个风力发电站的对偶变量为: -1164.4440931183706
# 第 59 个风力发电站的对偶变量为: -1128.9747699152508
# 第 60 个风力发电站的对偶变量为: -1168.520029305068
# ****************************************************************************
# 第 54 个受到Byzantin攻击的火力发电站的初始对偶变量为: -1482.05937664
# 第 58 个受到Byzantin攻击的风力发电站的初始对偶变量为: -1482.05937664
# ****************************************************************************
# 安全发电站的总发电量: 5932.037358039358
# *************************
# 需求侧平均用电需求: 87.01916861
# ****************************************************************************
# 风速分布参数c: 8.49448934
# ****************************************************************************
# 风速分布参数kappa: 2.29999995
# ****************************************************************************
# 安全发电站的总发电成本： 90425.98996516565
# ****************************************************************************
# 原变量迭代步长为: 5
# ****************************************************************************
# 对偶变量迭代步长为: 5
# ****************************************************************************
# 89 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 5.0
# 第 2 个火力发电站的计划发电量为: 5.0
# 第 3 个火力发电站的计划发电量为: 5.0
# 第 4 个火力发电站的计划发电量为: 195.62061132487966
# 第 5 个火力发电站的计划发电量为: 276.89969863294726
# 第 6 个火力发电站的计划发电量为: 10.0
# 第 7 个火力发电站的计划发电量为: 45.39412467783115
# 第 8 个火力发电站的计划发电量为: 5.0
# 第 9 个火力发电站的计划发电量为: 5.0
# 第 10 个火力发电站的计划发电量为: 295.9424028616105
# 第 11 个火力发电站的计划发电量为: 350.0
# 第 12 个火力发电站的计划发电量为: 8.0
# 第 13 个火力发电站的计划发电量为: 8.0
# 第 14 个火力发电站的计划发电量为: 59.99659579471823
# 第 15 个火力发电站的计划发电量为: 8.0
# 第 16 个火力发电站的计划发电量为: 47.94149996035726
# 第 17 个火力发电站的计划发电量为: 8.0
# 第 18 个火力发电站的计划发电量为: 8.0
# 第 19 个火力发电站的计划发电量为: 58.410397024089846
# 第 20 个火力发电站的计划发电量为: 250.0
# 第 21 个火力发电站的计划发电量为: 250.0
# 第 22 个火力发电站的计划发电量为: 25.0
# 第 23 个火力发电站的计划发电量为: 25.0
# 第 24 个火力发电站的计划发电量为: 200.0
# 第 25 个火力发电站的计划发电量为: 200.0
# 第 26 个火力发电站的计划发电量为: 25.0
# 第 27 个火力发电站的计划发电量为: 420.0
# 第 28 个火力发电站的计划发电量为: 416.3791309874562
# 第 29 个火力发电站的计划发电量为: 294.15116475876016
# 第 30 个火力发电站的计划发电量为: 47.298493589483094
# 第 31 个火力发电站的计划发电量为: 10.0
# 第 32 个火力发电站的计划发电量为: 5.0
# 第 33 个火力发电站的计划发电量为: 5.0
# 第 34 个火力发电站的计划发电量为: 62.58166297754719
# 第 35 个火力发电站的计划发电量为: 43.893762984850895
# 第 36 个火力发电站的计划发电量为: 236.12854217402273
# 第 37 个火力发电站的计划发电量为: 25.0
# 第 38 个火力发电站的计划发电量为: 10.0
# 第 39 个火力发电站的计划发电量为: 300.0
# 第 40 个火力发电站的计划发电量为: 200.0
# 第 41 个火力发电站的计划发电量为: 8.0
# 第 42 个火力发电站的计划发电量为: 20.0
# 第 43 个火力发电站的计划发电量为: 232.01838456951307
# 第 44 个火力发电站的计划发电量为: 217.51155208815715
# 第 45 个火力发电站的计划发电量为: 256.85345625940164
# 第 46 个火力发电站的计划发电量为: 8.0
# 第 47 个火力发电站的计划发电量为: 57.44856645501826
# 第 48 个火力发电站的计划发电量为: 63.050694951289174
# 第 49 个火力发电站的计划发电量为: 8.0
# 第 50 个火力发电站的计划发电量为: 25.0
# 第 51 个火力发电站的计划发电量为: 90.48935395936144
# 第 52 个火力发电站的计划发电量为: 90.48935395936144
# 第 53 个火力发电站的计划发电量为: 45.12310889375222
# 第 55 个风力发电站的计划发电量为: 146.2412912622244
# 第 56 个风力发电站的计划发电量为: 51.594875694253574
# 第 57 个风力发电站的计划发电量为: 110.69291716793526
# 第 59 个风力发电站的计划发电量为: 114.343783880728
# 第 60 个风力发电站的计划发电量为: 36.69803996835054
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -1164.8428197880148
# 第 2 个火力发电站的对偶变量为: -1159.06062076713
# 第 3 个火力发电站的对偶变量为: -1140.0306595931963
# 第 4 个火力发电站的对偶变量为: -1033.2017746536328
# 第 5 个火力发电站的对偶变量为: -1143.3350197680484
# 第 6 个火力发电站的对偶变量为: -1146.32195037396
# 第 7 个火力发电站的对偶变量为: -1145.7442908959647
# 第 8 个火力发电站的对偶变量为: -1167.6413973100616
# 第 9 个火力发电站的对偶变量为: -1184.36928633446
# 第 10 个火力发电站的对偶变量为: -1167.972524369785
# 第 11 个火力发电站的对偶变量为: -1145.8399258551426
# 第 12 个火力发电站的对偶变量为: -1174.4584832372184
# 第 13 个火力发电站的对偶变量为: -1148.8386996854415
# 第 14 个火力发电站的对偶变量为: -1168.221336961524
# 第 15 个火力发电站的对偶变量为: -1160.7793810053804
# 第 16 个火力发电站的对偶变量为: -1149.7123993148462
# 第 17 个火力发电站的对偶变量为: -1151.8237155756979
# 第 18 个火力发电站的对偶变量为: -1156.2463477606902
# 第 19 个火力发电站的对偶变量为: -1162.8611992971332
# 第 20 个火力发电站的对偶变量为: -1135.6709948371463
# 第 21 个火力发电站的对偶变量为: -1059.9783613400766
# 第 22 个火力发电站的对偶变量为: -1049.8248337869259
# 第 23 个火力发电站的对偶变量为: -1049.8248337869259
# 第 24 个火力发电站的对偶变量为: -1042.7026148583764
# 第 25 个火力发电站的对偶变量为: -1027.9391333473848
# 第 26 个火力发电站的对偶变量为: -1020.5775873111434
# 第 27 个火力发电站的对偶变量为: -1127.5228595879628
# 第 28 个火力发电站的对偶变量为: -1037.5334612974568
# 第 29 个火力发电站的对偶变量为: -1163.7110913662282
# 第 30 个火力发电站的对偶变量为: -1190.250228893319
# 第 31 个火力发电站的对偶变量为: -1223.1026114259914
# 第 32 个火力发电站的对偶变量为: -1223.5627247629948
# 第 33 个火力发电站的对偶变量为: -1182.4815550945825
# 第 34 个火力发电站的对偶变量为: -1169.9544184802721
# 第 35 个火力发电站的对偶变量为: -1141.3581835307912
# 第 36 个火力发电站的对偶变量为: -1086.0542933481747
# 第 37 个火力发电站的对偶变量为: -1088.1105860317543
# 第 38 个火力发电站的对偶变量为: -1046.937658095355
# 第 39 个火力发电站的对偶变量为: -1010.4134283748717
# 第 40 个火力发电站的对偶变量为: -1068.363185143337
# 第 41 个火力发电站的对偶变量为: -1082.7673065951562
# 第 42 个火力发电站的对偶变量为: -1087.8749956856232
# 第 43 个火力发电站的对偶变量为: -1081.2216015719257
# 第 44 个火力发电站的对偶变量为: -1060.5429385163684
# 第 45 个火力发电站的对偶变量为: -1112.3977698823885
# 第 46 个火力发电站的对偶变量为: -1169.1351206339377
# 第 47 个火力发电站的对偶变量为: -1159.8623271347474
# 第 48 个火力发电站的对偶变量为: -1168.5184161509828
# 第 49 个火力发电站的对偶变量为: -1158.4176864230799
# 第 50 个火力发电站的对偶变量为: -1202.521085754986
# 第 51 个火力发电站的对偶变量为: -1209.919734342074
# 第 52 个火力发电站的对偶变量为: -1209.919734342074
# 第 53 个火力发电站的对偶变量为: -1145.2225979789325
# 第 55 个风力发电站的对偶变量为: -1154.5817495872502
# 第 56 个风力发电站的对偶变量为: -1179.2753299927024
# 第 57 个风力发电站的对偶变量为: -1171.552603159304
# 第 59 个风力发电站的对偶变量为: -1133.8029678553196
# 第 60 个风力发电站的对偶变量为: -1173.585068907076
# ****************************************************************************
# ...
# 第 55 个风力发电站的对偶变量为: -1195.1656283218713
# 第 56 个风力发电站的对偶变量为: -1220.9570181070885
# 第 57 个风力发电站的对偶变量为: -1210.7466057477877
# 第 59 个风力发电站的对偶变量为: -1162.5826635554567
# 第 60 个风力发电站的对偶变量为: -1204.0958780568735
# ****************************************************************************
# 第 54 个受到Byzantin攻击的火力发电站的初始对偶变量为: -1534.54413411
# 第 58 个受到Byzantin攻击的风力发电站的初始对偶变量为: -1534.54413411
# ****************************************************************************
# 安全发电站的总发电量: 6386.131735347142
# *************************
# 需求侧平均用电需求: 93.71828935
# ****************************************************************************
# 风速分布参数c: 8.30997421
# ****************************************************************************
# 风速分布参数kappa: 2.48000002
# ****************************************************************************
# 安全发电站的总发电成本： 99129.25495742017
# ****************************************************************************
# 原变量迭代步长为: 5
# ****************************************************************************
# 对偶变量迭代步长为: 5
# ****************************************************************************
# 979 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 5.0
# 第 2 个火力发电站的计划发电量为: 5.0
# 第 3 个火力发电站的计划发电量为: 5.0
# 第 4 个火力发电站的计划发电量为: 214.3717363798086
# 第 5 个火力发电站的计划发电量为: 300.0
# 第 6 个火力发电站的计划发电量为: 10.0
# 第 7 个火力发电站的计划发电量为: 73.16609833622324
# 第 8 个火力发电站的计划发电量为: 5.0
# 第 9 个火力发电站的计划发电量为: 5.0
# 第 10 个火力发电站的计划发电量为: 300.0
# 第 11 个火力发电站的计划发电量为: 350.0
# 第 12 个火力发电站的计划发电量为: 8.0
# 第 13 个火力发电站的计划发电量为: 8.0
# 第 14 个火力发电站的计划发电量为: 88.50868434210881
# 第 15 个火力发电站的计划发电量为: 8.0
# 第 16 个火力发电站的计划发电量为: 75.60569579075442
# 第 17 个火力发电站的计划发电量为: 8.0
# 第 18 个火力发电站的计划发电量为: 8.0
# 第 19 个火力发电站的计划发电量为: 76.33407380316824
# 第 20 个火力发电站的计划发电量为: 250.0
# 第 21 个火力发电站的计划发电量为: 250.0
# 第 22 个火力发电站的计划发电量为: 25.0
# 第 23 个火力发电站的计划发电量为: 25.0
# 第 24 个火力发电站的计划发电量为: 200.0
# 第 25 个火力发电站的计划发电量为: 200.0
# 第 26 个火力发电站的计划发电量为: 25.0
# 第 27 个火力发电站的计划发电量为: 420.0
# 第 28 个火力发电站的计划发电量为: 420.0
# 第 29 个火力发电站的计划发电量为: 300.0
# 第 30 个火力发电站的计划发电量为: 53.54719656545379
# 第 31 个火力发电站的计划发电量为: 10.0
# 第 32 个火力发电站的计划发电量为: 5.0
# 第 33 个火力发电站的计划发电量为: 5.0
# 第 34 个火力发电站的计划发电量为: 81.48778804047573
# 第 35 个火力发电站的计划发电量为: 63.62938303434814
# 第 36 个火力发电站的计划发电量为: 254.37104921620346
# 第 37 个火力发电站的计划发电量为: 26.35494547330344
# 第 38 个火力发电站的计划发电量为: 10.0
# 第 39 个火力发电站的计划发电量为: 300.0
# 第 40 个火力发电站的计划发电量为: 200.0
# 第 41 个火力发电站的计划发电量为: 8.0
# 第 42 个火力发电站的计划发电量为: 20.0
# 第 43 个火力发电站的计划发电量为: 251.94872059521023
# 第 44 个火力发电站的计划发电量为: 230.88644543546866
# 第 45 个火力发电站的计划发电量为: 271.5043825488296
# 第 46 个火力发电站的计划发电量为: 8.0
# 第 47 个火力发电站的计划发电量为: 66.26274723868052
# 第 48 个火力发电站的计划发电量为: 71.92567008497542
# 第 49 个火力发电站的计划发电量为: 8.0
# 第 50 个火力发电站的计划发电量为: 25.0
# 第 51 个火力发电站的计划发电量为: 96.41750924775451
# 第 52 个火力发电站的计划发电量为: 96.41750924775451
# 第 53 个火力发电站的计划发电量为: 72.57675447373931
# 第 55 个风力发电站的计划发电量为: 149.47843989128555
# 第 56 个风力发电站的计划发电量为: 52.35119306975744
# 第 57 个风力发电站的计划发电量为: 114.76815038709171
# 第 59 个风力发电站的计划发电量为: 112.5499177503712
# 第 60 个风力发电站的计划发电量为: 36.794634798756064
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -1205.6630433645464
# 第 2 个火力发电站的对偶变量为: -1199.1548644869395
# 第 3 个火力发电站的对偶变量为: -1176.4925885161147
# 第 4 个火力发电站的对偶变量为: -1053.3169523622184
# 第 5 个火力发电站的对偶变量为: -1180.7350765242888
# 第 6 个火力发电站的对偶变量为: -1183.758066467183
# 第 7 个火力发电站的对偶变量为: -1182.3764277110702
# 第 8 个火力发电站的对偶变量为: -1205.862278216174
# 第 9 个火力发电站的对偶变量为: -1222.067431305058
# 第 10 个火力发电站的对偶变量为: -1206.3195022198233
# 第 11 个火力发电站的对偶变量为: -1182.8700890889536
# 第 12 个火力发电站的对偶变量为: -1214.0237963729724
# 第 13 个火力发电站的对偶变量为: -1185.9466704192646
# 第 14 个火力发电站的对偶变量为: -1206.029060716111
# 第 15 个火力发电站的对偶变量为: -1198.738623756797
# 第 16 个火力发电站的对偶变量为: -1186.0624805616444
# 第 17 个火力发电站的对偶变量为: -1189.8712605154547
# 第 18 个火力发电站的对偶变量为: -1195.7426051604084
# 第 19 个火力发电站的对偶变量为: -1186.9872281648722
# 第 20 个火力发电站的对偶变量为: -1172.1824093487762
# 第 21 个火力发电站的对偶变量为: -1109.6198292122688
# 第 22 个火力发电站的对偶变量为: -1101.9915734954836
# 第 23 个火力发电站的对偶变量为: -1101.9915734954834
# 第 24 个火力发电站的对偶变量为: -1093.0079660428294
# 第 25 个火力发电站的对偶变量为: -1077.0804880830658
# 第 26 个火力发电站的对偶变量为: -1068.9344384200297
# 第 27 个火力发电站的对偶变量为: -1164.6545262009226
# 第 28 个火力发电站的对偶变量为: -1081.8317306168178
# 第 29 个火力发电站的对偶变量为: -1194.1779106832576
# 第 30 个火力发电站的对偶变量为: -1224.3112054804085
# 第 31 个火力发电站的对偶变量为: -1262.9997888525436
# 第 32 个火力发电站的对偶变量为: -1262.6769787501476
# 第 33 个火力发电站的对偶变量为: -1213.0413401805977
# 第 34 个火力发电站的对偶变量为: -1195.0022388120724
# 第 35 个火力发电站的对偶变量为: -1167.63162180014
# 第 36 个火力发电站的对偶变量为: -1105.5606708228725
# 第 37 个火力发电站的对偶变量为: -1110.09333670609
# 第 38 个火力发电站的对偶变量为: -1072.4315053268438
# 第 39 个火力发电站的对偶变量为: -1037.886694608408
# 第 40 个火力发电站的对偶变量为: -1092.8990547728906
# 第 41 个火力发电站的对偶变量为: -1107.8318689074256
# 第 42 个火力发电站的对偶变量为: -1112.035251538293
# 第 43 个火力发电站的对偶变量为: -1102.3638780290828
# 第 44 个火力发电站的对偶变量为: -1074.760276321855
# 第 45 个火力发电站的对偶变量为: -1127.731903038395
# 第 46 个火力发电站的对偶变量为: -1179.842584104981
# 第 47 个火力发电站的对偶变量为: -1171.103102285721
# 第 48 个火力发电站的对偶变量为: -1179.7734872057247
# 第 49 个火力发电站的对偶变量为: -1170.634612169486
# 第 50 个火力发电站的对偶变量为: -1210.682392765508
# 第 51 个火力发电站的对偶变量为: -1217.3193618741907
# 第 52 个火力发电站的对偶变量为: -1217.3193618741907
# 第 53 个火力发电站的对偶变量为: -1181.4706872925397
# 第 55 个风力发电站的对偶变量为: -1194.2535066933888
# 第 56 个风力发电站的对偶变量为: -1219.8412344854032
# 第 57 个风力发电站的对偶变量为: -1209.734886911253
# 第 59 个风力发电站的对偶变量为: -1162.277095926091
# 第 60 个风力发电站的对偶变量为: -1202.7294920806976
# ****************************************************************************
# 第 54 个受到Byzantin攻击的火力发电站的初始对偶变量为: -1509.26323187
# 第 58 个受到Byzantin攻击的风力发电站的初始对偶变量为: -1509.26323187
# ****************************************************************************
# 安全发电站的总发电量: 6370.258725751522
# *************************
# 需求侧平均用电需求: 118.48390282
# ****************************************************************************
# 风速分布参数c: 8.30337672
# ****************************************************************************
# 风速分布参数kappa: 2.5
# ****************************************************************************
# 安全发电站的总发电成本： 98818.39807929748
# ****************************************************************************
# 原变量迭代步长为: 5
# ****************************************************************************
# 对偶变量迭代步长为: 5
# ****************************************************************************
# 989 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 5.0
# 第 2 个火力发电站的计划发电量为: 5.0
# 第 3 个火力发电站的计划发电量为: 5.0
# 第 4 个火力发电站的计划发电量为: 215.0643382001502
# 第 5 个火力发电站的计划发电量为: 300.0
# 第 6 个火力发电站的计划发电量为: 10.0
# 第 7 个火力发电站的计划发电量为: 74.08716060200567
# 第 8 个火力发电站的计划发电量为: 5.0
# 第 9 个火力发电站的计划发电量为: 5.0
# 第 10 个火力发电站的计划发电量为: 300.0
# 第 11 个火力发电站的计划发电量为: 350.0
# 第 12 个火力发电站的计划发电量为: 8.0
# 第 13 个火力发电站的计划发电量为: 8.0
# 第 14 个火力发电站的计划发电量为: 89.47193898958925
# 第 15 个火力发电站的计划发电量为: 8.0
# 第 16 个火力发电站的计划发电量为: 76.48483739945564
# 第 17 个火力发电站的计划发电量为: 8.0
# 第 18 个火力发电站的计划发电量为: 8.0
# 第 19 个火力发电站的计划发电量为: 77.07919524775149
# 第 20 个火力发电站的计划发电量为: 250.0
# 第 21 个火力发电站的计划发电量为: 250.0
# 第 22 个火力发电站的计划发电量为: 25.0
# 第 23 个火力发电站的计划发电量为: 25.0
# 第 24 个火力发电站的计划发电量为: 200.0
# 第 25 个火力发电站的计划发电量为: 200.0
# 第 26 个火力发电站的计划发电量为: 25.0
# 第 27 个火力发电站的计划发电量为: 420.0
# 第 28 个火力发电站的计划发电量为: 420.0
# 第 29 个火力发电站的计划发电量为: 300.0
# 第 30 个火力发电站的计划发电量为: 54.002347773367745
# 第 31 个火力发电站的计划发电量为: 10.0
# 第 32 个火力发电站的计划发电量为: 5.0
# 第 33 个火力发电站的计划发电量为: 5.0
# 第 34 个火力发电站的计划发电量为: 82.28462455419424
# 第 35 个火力发电站的计划发电量为: 64.45246778685991
# 第 36 个火力发电站的计划发电量为: 255.0077300249154
# 第 37 个火力发电站的计划发电量为: 26.96233113071825
# 第 38 个火力发电站的计划发电量为: 10.0
# 第 39 个火力发电站的计划发电量为: 300.0
# 第 40 个火力发电站的计划发电量为: 200.0
# 第 41 个火力发电站的计划发电量为: 8.0
# 第 42 个火力发电站的计划发电量为: 20.0
# 第 43 个火力发电站的计划发电量为: 252.52989237956723
# 第 44 个火力发电站的计划发电量为: 231.4328668342481
# 第 45 个火力发电站的计划发电量为: 271.99774987120134
# 第 46 个火力发电站的计划发电量为: 8.0
# 第 47 个火力发电站的计划发电量为: 66.68023707145993
# 第 48 个火力发电站的计划发电量为: 72.32574322716309
# 第 49 个火力发电站的计划发电量为: 8.0
# 第 50 个火力发电站的计划发电量为: 25.0
# 第 51 个火力发电站的计划发电量为: 96.75867581135728
# 第 52 个火力发电站的计划发电量为: 96.75867581135728
# 第 53 个火力发电站的计划发电量为: 73.49464295687552
# 第 55 个风力发电站的计划发电量为: 150.33390928470112
# 第 56 个风力发电站的计划发电量为: 52.48926396908752
# 第 57 个风力发电站的计划发电量为: 115.54826282385724
# 第 59 个风力发电站的计划发电量为: 113.39040043889318
# 第 60 个风力发电站的计划发电量为: 36.92414028973229
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -1206.7877597868173
# 第 2 个火力发电站的对偶变量为: -1200.2662099483075
# 第 3 个火力发电站的对偶变量为: -1177.5099297395343
# 第 4 个火力发电站的对偶变量为: -1054.196905703834
# 第 5 个火力发电站的对偶变量为: -1181.7663632924289
# 第 6 个火力发电站的对偶变量为: -1184.7767196820532
# 第 7 个火力发电站的对偶变量为: -1183.3856716403425
# 第 8 个火力发电站的对偶变量为: -1206.8868620382782
# 第 9 个火力发电站的对偶变量为: -1223.0384835827
# 第 10 个火力发电站的对偶变量为: -1207.3313731065305
# 第 11 个火力发电站的对偶变量为: -1183.8780317695703
# 第 12 个火力发电站的对偶变量为: -1215.0667275171677
# 第 13 个火力发电站的对偶变量为: -1186.959849247696
# 第 14 个火力发电站的对偶变量为: -1207.032926857476
# 第 15 个火力发电站的对偶变量为: -1199.7587448100412
# 第 16 个火力发电站的对偶变量为: -1187.0321131854605
# 第 17 个火力发电站的对偶变量为: -1190.8601192632098
# 第 18 个火力发电站的对偶变量为: -1196.652093746148
# 第 19 个火力发电站的对偶变量为: -1187.780974733393
# 第 20 个火力发电站的对偶变量为: -1173.0474908285146
# 第 21 个火力发电站的对偶变量为: -1110.4926265186368
# 第 22 个火力发电站的对偶变量为: -1102.864532603171
# 第 23 个火力发电站的对偶变量为: -1102.864532603171
# 第 24 个火力发电站的对偶变量为: -1093.8902273931521
# 第 25 个火力发电站的对偶变量为: -1077.9680539337612
# 第 26 个火力发电站的对偶变量为: -1069.8153173305818
# 第 27 个火力发电站的对偶变量为: -1165.6116110421553
# 第 28 个火力发电站的对偶变量为: -1082.7152227921624
# 第 29 个火力发电站的对偶变量为: -1195.027171210672
# 第 30 个火力发电站的对偶变量为: -1225.2229237801944
# 第 31 个火力发电站的对偶变量为: -1263.961444436178
# 第 32 个火力发电站的对偶变量为: -1263.618535340035
# 第 33 个火力发电站的对偶变量为: -1213.910909992725
# 第 34 个火力发电站的对偶变量为: -1195.8052435332215
# 第 35 个火力发电站的对偶变量为: -1168.4259747362496
# 第 36 个火力发电站的对偶变量为: -1106.1649047806807
# 第 37 个火力发电站的对偶变量为: -1110.6267537090193
# 第 38 个火力发电站的对偶变量为: -1072.9227197708292
# 第 39 个火力发电站的对偶变量为: -1038.3671556049467
# 第 40 个火力发电站的对偶变量为: -1093.3813424492387
# 第 41 个火力发电站的对偶变量为: -1108.304888620273
# 第 42 个火力发电站的对偶变量为: -1112.5064566466851
# 第 43 个火力发电站的对偶变量为: -1102.8655671460117
# 第 44 个火力发电站的对偶变量为: -1075.315508865382
# 第 45 个火力发电站的对偶变量为: -1128.1978817175632
# 第 46 个火力发电站的对偶变量为: -1180.1981572492546
# 第 47 个火力发电站的对偶变量为: -1171.4705769706645
# 第 48 个火力发电站的对偶变量为: -1180.1362043001006
# 第 49 个火力发电站的对偶变量为: -1171.0169423893842
# 第 50 个火力发电站的对偶变量为: -1210.9753941093486
# 第 51 个火力发电站的对偶变量为: -1217.5929120997353
# 第 52 个火力发电站的对偶变量为: -1217.5929120997353
# 第 53 个火力发电站的对偶变量为: -1182.4677312628667
# 第 55 个风力发电站的对偶变量为: -1195.337543756961
# 第 56 个风力发电站的对偶变量为: -1220.9024312525914
# 第 57 个风力发电站的对偶变量为: -1210.7432334130283
# 第 59 个风力发电站的对偶变量为: -1163.2770767194938
# 第 60 个风力发电站的对偶变量为: -1203.5790167886412
# ****************************************************************************
# 第 54 个受到Byzantin攻击的火力发电站的初始对偶变量为: -1440.32113388
# 第 58 个受到Byzantin攻击的风力发电站的初始对偶变量为: -1440.32113388
# ****************************************************************************
# 安全发电站的总发电量: 6384.561432478508
# *************************
# 需求侧平均用电需求: 96.88076137
# ****************************************************************************
# 风速分布参数c: 8.30250634
# ****************************************************************************
# 风速分布参数kappa: 2.48000002
# ****************************************************************************
# 安全发电站的总发电成本： 99103.85033743044
# ****************************************************************************
# 原变量迭代步长为: 5
# ****************************************************************************
# 对偶变量迭代步长为: 5
# ****************************************************************************
# 999 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 5.0
# 第 2 个火力发电站的计划发电量为: 5.0
# 第 3 个火力发电站的计划发电量为: 5.0
# 第 4 个火力发电站的计划发电量为: 215.03165972944
# 第 5 个火力发电站的计划发电量为: 300.0
# 第 6 个火力发电站的计划发电量为: 10.0
# 第 7 个火力发电站的计划发电量为: 74.1663163706989
# 第 8 个火力发电站的计划发电量为: 5.0
# 第 9 个火力发电站的计划发电量为: 5.0
# 第 10 个火力发电站的计划发电量为: 300.0
# 第 11 个火力发电站的计划发电量为: 350.0
# 第 12 个火力发电站的计划发电量为: 8.0
# 第 13 个火力发电站的计划发电量为: 8.0
# 第 14 个火力发电站的计划发电量为: 89.55931747815508
# 第 15 个火力发电站的计划发电量为: 8.0
# 第 16 个火力发电站的计划发电量为: 76.54544215299029
# 第 17 个火力发电站的计划发电量为: 8.0
# 第 18 个火力发电站的计划发电量为: 8.0
# 第 19 个火力发电站的计划发电量为: 77.00019022820263
# 第 20 个火力发电站的计划发电量为: 250.0
# 第 21 个火力发电站的计划发电量为: 250.0
# 第 22 个火力发电站的计划发电量为: 25.0
# 第 23 个火力发电站的计划发电量为: 25.0
# 第 24 个火力发电站的计划发电量为: 200.0
# 第 25 个火力发电站的计划发电量为: 200.0
# 第 26 个火力发电站的计划发电量为: 25.0
# 第 27 个火力发电站的计划发电量为: 420.0
# 第 28 个火力发电站的计划发电量为: 420.0
# 第 29 个火力发电站的计划发电量为: 300.0
# 第 30 个火力发电站的计划发电量为: 53.90971693024464
# 第 31 个火力发电站的计划发电量为: 10.0
# 第 32 个火力发电站的计划发电量为: 5.0
# 第 33 个火力发电站的计划发电量为: 5.0
# 第 34 个火力发电站的计划发电量为: 82.21654548922557
# 第 35 个火力发电站的计划发电量为: 64.38317663449585
# 第 36 个火力发电站的计划发电量为: 254.83924154207276
# 第 37 个火力发电站的计划发电量为: 26.750455467097733
# 第 38 个火力发电站的计划发电量为: 10.0
# 第 39 个火力发电站的计划发电量为: 300.0
# 第 40 个火力发电站的计划发电量为: 200.0
# 第 41 个火力发电站的计划发电量为: 8.0
# 第 42 个火力发电站的计划发电量为: 20.0
# 第 43 个火力发电站的计划发电量为: 252.31717610430016
# 第 44 个火力发电站的计划发电量为: 231.19518493802417
# 第 45 个火力发电站的计划发电量为: 271.7302692342501
# 第 46 个火力发电站的计划发电量为: 8.0
# 第 47 个火力发电站的计划发电量为: 66.35466855660297
# 第 48 个火力发电站的计划发电量为: 71.99496485559052
# 第 49 个火力发电站的计划发电量为: 8.0
# 第 50 个火力发电站的计划发电量为: 25.0
# 第 51 个火力发电站的计划发电量为: 96.37654847240918
# 第 52 个火力发电站的计划发电量为: 96.37654847240918
# 第 53 个火力发电站的计划发电量为: 73.5696743795084
# 第 55 个风力发电站的计划发电量为: 150.46687563749282
# 第 56 个风力发电站的计划发电量为: 52.477343040056994
# 第 57 个风力发电站的计划发电量为: 115.68634693438484
# 第 59 个风力发电站的计划发电量为: 113.31259739256197
# 第 60 个风力发电站的计划发电量为: 36.900575665623656
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -1208.9115962118608
# 第 2 个火力发电站的对偶变量为: -1202.385523079875
# 第 3 个火力发电站的对偶变量为: -1179.5945506100084
# 第 4 个火力发电站的对偶变量为: -1056.1263232045885
# 第 5 个火力发电站的对偶变量为: -1183.8625999857268
# 第 6 个火力发电站的对偶变量为: -1186.868368914285
# 第 7 个火力发电站的对偶变量为: -1185.4743254074147
# 第 8 个火力发电站的对偶变量为: -1208.969140298515
# 第 9 个火力发电站的对偶变量为: -1225.1137176448603
# 第 10 个火力发电站的对偶变量为: -1209.4227347603294
# 第 11 个火力发电站的对偶变量为: -1185.9689008839641
# 第 12 个火力发电站的对偶变量为: -1217.193439172226
# 第 13 个火力发电站的对偶变量为: -1189.0576685780143
# 第 14 个火力发电站的对偶变量为: -1209.123597103276
# 第 15 个火力发电站的对偶变量为: -1201.8488682687894
# 第 16 个火力发电站的对偶变量为: -1189.1175504699975
# 第 17 个火力发电站的对偶变量为: -1192.9510367799767
# 第 18 个火力发电站的对偶变量为: -1198.7326392214923
# 第 19 个火力发电站的对偶变量为: -1189.6849068869356
# 第 20 个火力发电站的对偶变量为: -1175.0738646430157
# 第 21 个火力发电站的对偶变量为: -1112.5816624174133
# 第 22 个火力发电站的对偶变量为: -1104.9654907831086
# 第 23 个火力发电站的对偶变量为: -1104.9654907831086
# 第 24 个火力发电站的对偶变量为: -1095.9900301697094
# 第 25 个火力发电站的对偶变量为: -1080.070658167918
# 第 26 个火力发电站的对偶变量为: -1071.9140888870616
# 第 27 个火力发电站的对偶变量为: -1167.673527573077
# 第 28 个火力发电站的对偶变量为: -1084.7951198972619
# 第 29 个火力发电站的对偶变量为: -1196.9876798121945
# 第 30 个火力发电站的对偶变量为: -1227.2347045223357
# 第 31 个火力发电站的对偶变量为: -1266.0613605388016
# 第 32 个火力发电站的对偶变量为: -1265.7086514462703
# 第 33 个火力发电站的对偶变量为: -1215.861873605291
# 第 34 个火力发电站的对偶变量为: -1197.6899664519472
# 第 35 个火力发电站的对偶变量为: -1170.2806797523153
# 第 36 个火力发电站的对偶变量为: -1107.9123027199983
# 第 37 个火力发电站的对偶变量为: -1112.3458230292017
# 第 38 个火力发电站的对偶变量为: -1074.6198600811272
# 第 39 个火力发电站的对偶变量为: -1040.0615647225966
# 第 40 个火力发电站的对偶变量为: -1095.0698180828206
# 第 41 个火力发电站的对偶变量为: -1109.9867595372627
# 第 42 个火力发电站的对偶变量为: -1114.1907361599697
# 第 43 个火力发电站的对偶变量为: -1104.563271452
# 第 44 个火力发电站的对偶变量为: -1076.9950097455726
# 第 45 个火力发电站的对偶变量为: -1129.8537816689372
# 第 46 个火力发电站的对偶变量为: -1181.7847851861166
# 第 47 个火力发电站的对偶变量为: -1173.0738404328167
# 第 48 个火力发电站的对偶变量为: -1181.7266672830283
# 第 49 个火力发电站的对偶变量为: -1172.614645522229
# 第 50 个火力发电站的对偶变量为: -1212.5239385189834
# 第 51 个火力发电站的对偶变量为: -1219.1354918292436
# 第 52 个火力发电站的对偶变量为: -1219.1354918292436
# 第 53 个火力发电站的对偶变量为: -1184.5560084403544
# 第 55 个风力发电站的对偶变量为: -1197.4482628233493
# 第 56 个风力发电站的对偶变量为: -1223.049690303746
# 第 57 个风力发电站的对偶变量为: -1212.8227095615946
# 第 59 个风力发电站的对偶变量为: -1165.0775111408107
# 第 60 个风力发电站的对偶变量为: -1205.5164430029745
# ****************************************************************************
# 第 54 个受到Byzantin攻击的火力发电站的初始对偶变量为: -1486.96302845
# 第 58 个受到Byzantin攻击的风力发电站的初始对偶变量为: -1486.96302845
# ****************************************************************************
# 安全发电站的总发电量: 6382.160835705839
# *************************
# 需求侧平均用电需求: 82.38553176
# ****************************************************************************
# 风速分布参数c: 8.30302612
# ****************************************************************************
# 风速分布参数kappa: 2.48000002
# ****************************************************************************
# 安全发电站的总发电成本： 99057.32790722298
# ****************************************************************************
# 原变量迭代步长为: 5
# ****************************************************************************
# 对偶变量迭代步长为: 5
# ****************************************************************************
# 2024-07-30 17:41:22.143

# %%
#数据存储
np.savetxt('./data/02_IOS_optimal_parameters_small_Gaussian_Byzantine_attack_sum_cost.txt',sum_cost,fmt='%0.8f')
np.savetxt('./data/02_IOS_optimal_parameters_small_Gaussian_Byzantine_attack_sum_thermal_wind_power_station_strategy.txt',sum_thermal_wind_power_station_strategy,fmt='%0.8f')

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
from sympy import *
import math 
from datetime import datetime
from scipy.special import gamma, factorial
import scipy.special as sc

# %%
sum_cost=np.loadtxt("./data/02_IOS_optimal_parameters_small_Gaussian_Byzantine_attack_sum_cost.txt")
optimal_sum_cost=np.loadtxt("./data/00_optimal_sum_cost_varying_D_c_kappa_normal_distribution_(100,10).txt")

# %%
dynamic_regret=[]
dynamic_regret_T=[]
for T in range(1, 1000):
    dynamic_regret_auxiliary_variable=0
    for t in range(0, T):
        dynamic_regret_auxiliary_variable=dynamic_regret_auxiliary_variable+sum_cost[t+1]-optimal_sum_cost[t+1]
    dynamic_regret.append(dynamic_regret_auxiliary_variable)
    dynamic_regret_T.append((dynamic_regret_auxiliary_variable)/T)

# %%
dynamic_regret
# Out:
# [34923.03850531,
#  56140.309487050006,
#  69588.25929296,
#  60999.54486264002,
#  73652.96285068002,
#  51795.23911260003,
#  46552.09541064003,
#  30861.587339350022,
#  36587.92631121003,
#  15822.848012960021,
#  -6978.524391189974,
#  -40812.12854552998,
#  -68515.09329554997,
#  -86137.84855679997,
#  -115161.72610112997,
#  -132873.87174527996,
#  -138966.49614934996,
#  -159529.07075753994,
#  -157241.34924618993,
#  -165841.06422191992,
#  -216291.1318846699,
#  -221707.5764157899,
#  -238975.84180986992,
#  -258850.4818071099,
#  -267365.8962739099,
#  -282159.7423844399,
#  -309858.0172477599,
#  -330099.2307785999,
#  -349341.2392457599,
#  -373572.3970687099,
#  -405755.0094095399,
#  -424228.1462295499,
#  -426981.97568368993,
#  -448068.28502487997,
#  -435863.96927775,
#  -462059.92727518,
#  -483430.17958994,
#  -490730.69817235,
#  -494285.85138619004,
#  -512124.21652616,
#  -528665.33137355,
#  -543885.6939968499,
#  -549167.3407361599,
#  -589492.5028532799,
#  -608165.07493661,
#  -621451.37923084,
#  -629688.9994671299,
#  -650536.69694528,
#  -674899.37275182,
#  -677772.10058482,
#  -683424.22927389,
#  -687635.6325921201,
#  -682919.16400786,
#  -692608.74128116,
#  -688674.3563546301,
#  -692927.3105158501,
#  -683366.01341357,
#  -689451.0701764,
#  -708823.30253796,
#  -697891.52837264,
#  -709242.61243054,
#  -722851.62187923,
#  -717034.75905079,
#  -707365.7747582099,
#  -718091.7351806998,
#  -717038.6649402998,
#  -726376.3471491098,
#  -733237.1776748197,
#  -736612.7139436697,
#  -723431.6785598497,
#  -716683.1324461498,
#  -713409.3108400198,
#  -708496.0868413599,
#  -724159.4443910099,
#  -724186.02423038,
#  -736883.7723742799,
#  -744131.8477642599,
#  -728886.3078991099,
#  -712651.4244479599,
#  -705018.09064626,
#  -703463.47909307,
#  -699064.4145947901,
#  -695204.79969022,
#  -682921.6807574701,
#  -683992.8535487602,
#  -677174.8990907802,
#  -688356.0393150302,
#  -673993.2605809802,
#  -667490.1890105102,
#  -666869.4513033503,
#  -669269.5244129802,
#  -659754.0910263702,
#  -661746.9998099902,
#  -661750.6425029802,
#  -656917.6381177203,
#  -665142.4750302903,
#  -662267.9929992803,
#  -663263.3506124304,
#  -661892.1219692603,
#  -631261.7621042402,
#  -631566.7860381902,
#  -627583.8186237202,
#  -627011.3177674401,
#  -624226.6501410701,
#  -618050.21949199,
#  -602587.0207123301,
#  -596140.0455668,
#  -592285.1558780901,
#  -616117.65106414,
#  -607873.31260432,
#  -586554.9151316499,
#  -585736.1075692599,
#  -579614.59891361,
#  -558844.5144239201,
#  -560069.6311054701,
#  -547152.3089064801,
#  -525823.3682947,
#  -516584.11142105004,
#  -516207.50700376,
#  -522854.36808574,
#  -493971.52496307,
#  -476238.08587028,
#  -451494.74296741,
#  -461468.00855633,
#  -462415.10242376995,
#  -466709.60243751,
#  -436431.73954895,
#  -442043.93240894,
#  -418248.93830774,
#  -412207.94754585007,
#  -402172.06617976003,
#  -381317.12400935,
#  -370530.27301896,
#  -375508.66334555,
#  -377377.03122810996,
#  -358285.315929,
#  -359457.8872018,
#  -348409.95674356003,
#  -339524.89085960004,
#  -334814.00326438004,
#  -343942.44864403,
#  -350970.83530780004,
#  -321659.87341773004,
#  -309627.30013457,
#  -316187.75927013997,
#  -306543.48303393996,
#  -299405.431353,
#  -285155.64275090996,
#  -278290.5723287499,
#  -259711.34576157993,
#  -256336.07181878993,
#  -243632.81611265993,
#  -234824.29055533995,
#  -214920.14782721992,
#  -208728.2633185499,
#  -179651.24084492988,
#  -165304.2317685599,
#  -134977.1524183699,
#  -115633.0082308499,
#  -110083.71321274989,
#  -96681.36263193989,
#  -86662.17704829988,
#  -70608.92967539988,
#  -89491.98049016988,
#  -90688.55455900988,
#  -103908.34018919988,
#  -85837.35952608987,
#  -68486.92960366988,
#  -58822.178471019884,
#  -61007.93376691987,
#  -37700.70711860988,
#  -7955.364600979869,
#  -7107.317466149878,
#  13116.46241609013,
#  20501.068386480125,
#  37299.35291260012,
#  42410.59107074012,
#  53068.46911064013,
#  75636.23895623013,
#  97970.37583256012,
#  104390.85693842013,
#  110525.1707705101,
#  105590.8199001001,
#  104749.51411576012,
#  119092.84615786011,
#  126361.35817977012,
#  124335.90173136012,
#  128135.95329838013,
#  138500.05793445013,
#  166896.94284172013,
#  178187.86090664013,
#  218282.1519555801,
#  221246.7258687101,
#  235124.35781306014,
#  256041.68921173015,
#  262293.4944100701,
#  262743.30912385014,
#  286173.5697005001,
#  309994.6361365001,
#  337509.6762198601,
#  358699.5885507501,
#  368185.77486217016,
#  360260.65056192013,
#  373349.3290992201,
#  368397.69158074015,
#  380972.63891864015,
#  405167.09688039013,
#  418215.58991430013,
#  435086.39193622017,
#  459289.5526602701,
#  469156.3289317301,
#  484827.40442828013,
#  506763.19351967005,
#  528992.0737295101,
#  526773.9188033901,
#  546201.52106684,
#  566344.13299883,
#  580679.0624592601,
#  578103.3483442002,
#  600453.2528276702,
#  622803.7822184102,
#  644335.2799829001,
#  663228.5525084701,
#  660509.9557487201,
#  685973.9706965201,
#  695240.60356244,
#  716936.81105057,
#  733422.2838665701,
#  742549.9695032701,
#  757876.34920575,
#  771567.1606250501,
#  775295.4758736601,
#  791268.5159587101,
#  817253.0656914001,
#  830208.0094540401,
#  846665.13691124,
#  871563.85548283,
#  880239.2103954,
#  891989.4547041099,
#  893464.24243151,
#  912526.9650377,
#  926460.5750448101,
#  928979.85354233,
#  927858.4902984699,
#  920091.8088391199,
#  920087.1292519599,
#  937465.4429775699,
#  953494.5549684898,
#  951966.2056507696,
#  967708.1433767496,
#  982668.8009910497,
#  980584.6671652597,
#  988685.5488258497,
#  1003852.7609101298,
#  1020630.8655006097,
#  1039133.0623032097,
#  1038654.8409618398,
#  1046752.0393281798,
#  1058010.7007983099,
#  1069084.75657685,
#  1087958.4599507102,
#  1082263.5646043802,
#  1099581.2873211103,
#  1117642.7122164702,
#  1137797.2288978603,
#  1155815.3591190802,
#  1169616.0415404502,
#  1179279.18907042,
#  1188603.42088965,
#  1207004.72220097,
#  1205724.1991753099,
#  1210645.19370136,
#  1223359.10425085,
#  1244993.85323283,
#  1256009.39290373,
#  1270483.0711440702,
#  1275935.2270686103,
#  1279966.4153003204,
#  1275757.8371977604,
#  1302151.3296582503,
#  1303761.2234562603,
#  1302990.7933189003,
#  1321427.8906520503,
#  1330809.4226033902,
#  1342741.2561579102,
#  1371228.7259006002,
#  1386253.0527642001,
#  1376696.90269972,
#  1398834.16436377,
#  1411516.10316279,
#  1395593.57415551,
#  1402966.1844545798,
#  1431788.7680510597,
#  1458815.3648946197,
#  1463085.0611430597,
#  1450357.8388951498,
#  1477761.4884180399,
#  1478798.52185001,
#  1473276.12262749,
#  1498049.2760152698,
#  1511105.6149168496,
#  1528723.2874015695,
#  1547527.3675597496,
#  1579680.5113585696,
#  1600191.0097437396,
#  1619029.8034265796,
#  1613191.1189496997,
#  1612913.1853972697,
#  1629244.9928868196,
#  1633100.5223170097,
#  1659187.7452154998,
#  1682267.7040809297,
#  1682138.4942416798,
#  1697917.9836209198,
#  1690146.5487442997,
#  1682475.9385871696,
#  1687512.1866558595,
#  1695595.1722195195,
#  1704041.8217979497,
#  1709668.7315263196,
#  1709225.6664825496,
#  1730711.3576653197,
#  1770493.2764255996,
#  1763614.0025447896,
#  1786331.6499235898,
#  1803346.2746529398,
#  1816936.0451206297,
#  1824347.57750715,
#  1839235.66600298,
#  1838017.7792773398,
#  1852591.0407435398,
#  1871608.3768199899,
#  1876276.8231467297,
#  1907268.2650358398,
#  1929861.82166241,
#  1938950.95200019,
#  1945430.09042437,
#  1970628.95333697,
#  1988778.46364196,
#  2014599.62242099,
#  2019059.5267783897,
#  2016553.4573570795,
#  2000952.8725402493,
#  2013312.888507869,
#  2019291.8894369989,
#  2026303.3374464486,
#  2031291.7480517686,
#  2051929.9800357986,
#  2049263.9688135888,
#  2050898.063634419,
#  2054791.256251219,
#  2063095.844395989,
#  2079088.512416099,
#  2095247.7987968188,
#  2104917.1933609387,
#  2119311.8515315684,
#  2098592.4798177285,
#  2098674.7083477587,
#  2112595.848942619,
#  2136565.658561069,
#  2129291.038924519,
#  2141178.018032629,
#  2159443.502659209,
#  2156094.321651929,
#  2167722.2297033593,
#  2175984.310193939,
#  2206218.289487299,
#  2232841.9262843993,
#  2264644.5059417496,
#  2273983.9367812597,
#  2306286.2137711397,
#  2322249.90915886,
#  2345547.5895561096,
#  2374821.0130839297,
#  2399523.4837056496,
#  2403008.8955301996,
#  2434390.9891615394,
#  2460806.1268043895,
#  2492500.8868373698,
#  2498058.6121841497,
#  2507214.9997383696,
#  2522515.1544365,
#  2535120.9253592994,
#  2551467.3564765193,
#  2568938.4597576996,
#  2590676.2752538193,
#  2609131.3808084093,
#  2617177.1430495195,
#  2617324.0960161695,
#  2635612.99013379,
#  2664228.3153445697,
#  2689090.30793748,
#  2706403.70584278,
#  2719561.26576693,
#  2750538.39469559,
#  2766985.2192288097,
#  2786335.37135702,
#  2793184.51293954,
#  2805900.1781236003,
#  2822894.9183458104,
#  2834736.7861909904,
#  2840192.8958912203,
#  2862376.21048584,
#  2875150.8898170004,
#  2890133.9544756506,
#  2899157.4439833006,
#  2926902.990588761,
#  2937509.701223771,
#  2940166.975822671,
#  2949452.757091361,
#  2952898.5662488313,
#  2938503.4440213013,
#  2967763.7326618517,
#  2976671.920587652,
#  2968077.869518142,
#  2996297.4445506823,
#  2996562.8862998923,
#  2987108.377277072,
#  2984660.257088412,
#  2996032.917463342,
#  3002130.652893432,
#  3012482.030072442,
#  3024364.046553532,
#  3023447.754693722,
#  3037129.482310072,
#  3057710.809985102,
#  3062830.5694782822,
#  3068871.951138582,
#  3059005.975589712,
#  3064808.4213110325,
#  3073571.6695939526,
#  3084947.700018782,
#  3099260.127524382,
#  3097671.6421266417,
#  3113421.4062000015,
#  3103340.2859678017,
#  3109566.3414552817,
#  3121547.3877228517,
#  3125592.5216249917,
#  3128270.025894752,
#  3149399.3031142517,
#  3158304.7144444617,
#  3178035.0711950115,
#  3178981.3935782216,
#  3187604.8711844217,
#  3201521.0378240016,
#  3217816.239278832,
#  3226672.029923552,
#  3228874.7681212723,
#  3262460.1861193823,
#  3288049.512250862,
#  3315056.025242642,
#  3335915.787483602,
#  3331273.655487672,
#  3366765.074770242,
#  3375193.198372102,
#  3387343.840702942,
#  3404548.233145142,
#  3412493.8621598617,
#  3423021.601241292,
#  3444933.688219722,
#  3442531.842435522,
#  3458734.594314402,
#  3476032.443328502,
#  3492411.806078022,
#  3489375.829028912,
#  3504281.998438192,
#  3526943.209735092,
#  3535223.2778575215,
#  3562507.361164232,
#  3571794.5593780414,
#  3561169.5757097015,
#  3580488.759350491,
#  3597857.137414981,
#  3624657.790454211,
#  3648536.3430509814,
#  3654912.3845375516,
#  3664302.6984137716,
#  3668907.6726319217,
#  3678924.219055962,
#  3702551.5240931017,
#  3694832.383319712,
#  3699791.453625452,
#  3711191.0613850816,
#  3710350.4985716413,
#  3721481.8327336917,
#  3752733.5065858117,
#  3750859.5813603713,
#  3768923.8859956516,
#  3764262.8259459217,
#  3797280.8571484718,
#  3800844.5211093016,
#  3800824.461558982,
#  3811664.7585553615,
#  3809882.7619050713,
#  3825149.9064157014,
#  3836814.2696513813,
#  3856437.6179514015,
#  3868770.309297271,
#  3882927.344857671,
#  3902998.8643178106,
#  3920692.3464423707,
#  3927059.2404168006,
#  3931855.5108980406,
#  3948812.1771288,
#  3966232.92029132,
#  3975006.70251773,
#  3985912.00221299,
#  3989557.63945108,
#  4012119.00877751,
#  4003237.7547124596,
#  4007283.6046552793,
#  4023084.058563049,
#  4041640.5609637788,
#  4090969.911797669,
#  4099058.117655989,
#  4125059.4545512786,
#  4130574.3144160686,
#  4144949.9368171385,
#  4159743.421250958,
#  4175804.6514565283,
#  4186101.840064138,
#  4200147.671969138,
#  4219307.366773908,
#  4199379.100368128,
#  4214994.884842109,
#  4237578.966372009,
#  4243907.19824121,
#  4256656.54413531,
#  4256295.985444119,
#  4272587.80092233,
#  4276649.00203191,
#  4294546.68854806,
#  4280727.34559434,
#  4289027.78935353,
#  4278595.813879279,
#  4286594.79704725,
#  4289344.12568756,
#  4298487.76497317,
#  4309477.941102141,
#  4312413.08449095,
#  4317689.319924081,
#  4334996.481664141,
#  4343202.248793741,
#  4336530.134491601,
#  4355201.261579401,
#  4361490.491880121,
#  4404224.265499161,
#  4402501.59735173,
#  4428636.03073112,
#  4434674.300998529,
#  4452590.335899159,
#  4467658.515698469,
#  4482220.70354901,
#  4495737.85689374,
#  4529131.086535839,
#  4544633.57974609,
#  4577558.48624167,
#  4578718.98742192,
#  4591080.0869011395,
#  4609483.22058218,
#  4621610.0841387,
#  4641916.05893954,
#  4652719.82860092,
#  4663521.99054733,
#  4665869.02051915,
#  4693529.71244143,
#  4686082.810949731,
#  4703368.382622201,
#  4707690.97495882,
#  4728510.56241619,
#  4723479.21657736,
#  4748160.09681287,
#  4761599.479921221,
#  4763973.732753151,
#  4785437.532936421,
#  4803412.664030431,
#  4825320.63564622,
#  4840545.05862307,
#  4848569.97581358,
#  4852338.91467439,
#  4852158.18063576,
#  4850068.35837306,
#  4861195.4525119,
#  4890714.21796903,
#  4900040.83388256,
#  4905952.99930381,
#  4915174.02685491,
#  4931537.3963609,
#  4933806.31607802,
#  4968931.222299321,
#  4986848.1014646,
#  5003785.570162791,
#  5011980.916334401,
#  5034851.729844501,
#  5046517.903706111,
#  5048740.590943921,
#  5070632.1633196315,
#  5082455.615554071,
#  5098288.863210051,
#  5100272.692790321,
#  5128865.743729912,
#  5148951.806138892,
#  5166058.328543222,
#  5176840.468885782,
#  5188969.719184833,
#  5181917.826039363,
#  5179129.745025293,
#  5206896.255829942,
#  5197231.904769212,
#  5216728.815334472,
#  5205148.622407142,
#  5201210.4621488815,
#  5221589.367066162,
#  5229431.020009421,
#  5237061.461403451,
#  5244115.295617561,
#  5251934.889914251,
#  5269083.548372891,
#  5291059.353499681,
#  5304001.854122181,
#  5337920.573944292,
#  5362430.691614652,
#  5392337.583922602,
#  5395650.570974692,
#  5406406.551931112,
#  5410948.572782132,
#  5449099.215928962,
#  5458620.4446180025,
#  5466804.940215592,
#  5483855.668507992,
#  5486426.678859582,
#  5497701.355404412,
#  5533368.338683142,
#  5551342.591438172,
#  5567954.513885022,
#  5578131.708899613,
#  5587204.023309522,
#  5602157.124855092,
#  5613105.682253482,
#  5618918.673374952,
#  5627465.5858768225,
#  5625427.267098183,
#  5650291.522874533,
#  5662032.873614533,
#  5675012.451331902,
#  5686094.2695651725,
#  5682878.083684373,
#  5692882.750193362,
#  5705681.373264072,
#  5710435.736086513,
#  5721084.851965883,
#  5728860.570399943,
#  5737524.821969523,
#  5753718.930944073,
#  5768211.242114663,
#  5777363.973959743,
#  5779337.326121133,
#  5779093.446839603,
#  5776531.997373603,
#  5793912.589093303,
#  5803718.513347793,
#  5816719.928586613,
#  5841705.098874163,
#  5854748.311924613,
#  5880337.817011893,
#  5895829.783961163,
#  5915450.158882262,
#  5935675.178018342,
#  5942464.135875172,
#  5961020.356230161,
#  5971128.684566522,
#  5997019.409816181,
#  6012291.930764841,
#  6020619.983046691,
#  6003492.456312841,
#  6007186.96310012,
#  6008845.738561161,
#  6009501.091306241,
#  6013405.461811951,
#  6023904.113751811,
#  6037754.971268101,
#  6047920.435379431,
#  6052490.932424431,
#  6057252.91407478,
#  6065261.42286945,
#  6091924.304572481,
#  6111509.32337065,
#  6130536.913705241,
#  6137402.102691201,
#  6158976.300524031,
#  6176924.479135951,
#  6196519.143266931,
#  6199757.247601941,
#  6204106.188915761,
#  6220402.729212871,
#  6234467.924480411,
#  6248484.630228581,
#  6253179.883716301,
#  6263630.034089072,
#  6275501.069520632,
#  6280778.279009542,
#  6281869.3571775425,
#  6290388.923692263,
#  6288812.526069703,
#  6322448.205315632,
#  6339043.882299482,
#  6359213.037304131,
#  6366851.161060072,
#  6374862.271840801,
#  6390627.471848272,
#  6402405.129692602,
#  6409724.801092362,
#  6415048.801159302,
#  6432474.579505522,
#  6462993.106138612,
#  6472154.346022773,
#  6476693.930906143,
#  6491861.669637003,
#  6508791.1589676635,
#  6529520.430923954,
#  6547079.919411943,
#  6558207.437562703,
#  6580414.594607733,
#  6595454.610956643,
#  6618044.291061043,
#  6610883.1484985035,
#  6601762.116515663,
#  6607770.013498833,
#  6626615.439982213,
#  6649625.071742533,
#  6660261.532602133,
#  6683943.001742123,
#  6697387.781791903,
#  6706191.231218553,
#  6722640.252647934,
#  6728135.357689153,
#  6750998.959239423,
#  6756742.224766764,
#  6764711.9874069635,
#  6764041.390550214,
#  6774687.261374224,
#  6787920.465055275,
#  6773138.366483695,
#  6789363.087388204,
#  6791515.678403134,
#  6812461.783889434,
#  6814494.433169554,
#  6829648.958783303,
#  6852318.550830553,
#  6839131.704207913,
#  6864135.124460343,
#  6866941.712916833,
#  6883218.948136093,
#  6894094.157066624,
#  6906849.869214044,
#  6923227.302323644,
#  6933562.582461445,
#  6953114.696743775,
#  6966946.645744455,
#  6971307.119390986,
#  6976044.316184686,
#  6983723.381240046,
#  6988982.118981296,
#  7011240.050198656,
#  7044206.998714086,
#  7059660.639991595,
#  7074728.127244815,
#  7086264.366415205,
#  7106346.693278245,
#  7120044.286721595,
#  7131810.108759215,
#  7147620.353654095,
#  7160040.822326525,
#  7158420.069764955,
#  7178534.6685518045,
#  7197632.647328105,
#  7193571.573507525,
#  7199453.462040155,
#  7221951.646200955,
#  7249701.783186985,
#  7250577.711796985,
#  7242880.141336935,
#  7251363.155486914,
#  7280533.436699115,
#  7292837.4596444545,
#  7321149.839978814,
#  7335679.629261124,
#  7350295.963717533,
#  7347192.801097163,
#  7375924.101116333,
#  7386622.029725193,
#  7400030.389157543,
#  7433746.482801323,
#  7436436.052075573,
#  7455627.182084793,
#  7455737.747990073,
#  7468153.1757690525,
#  7479919.4991290225,
#  7495826.125904523,
#  7518634.530341064,
#  7537338.253832474,
#  7561435.984838485,
#  7582825.086913845,
#  7594723.028634764,
#  7626297.041755244,
#  7646827.345093654,
#  7670146.059502054,
#  7689071.000305104,
#  7670173.7581759235,
#  7684110.592850334,
#  7687392.480711544,
#  7699377.7046816135,
#  7692444.912208793,
#  7696764.265906203,
#  7718276.372238092,
#  7728953.762885822,
#  7735917.547836712,
#  7726807.022552812,
#  7743528.548677782,
#  7739523.758770001,
#  7765625.105369901,
#  7787140.9986569015,
#  7806255.771838412,
#  7822527.985069271,
#  7815907.378552271,
#  7840643.2658378305,
#  7864082.4328989405,
#  7871435.912563221,
#  7874727.55354164,
#  7880295.83369439,
#  7898000.9308363,
#  7908545.3302689,
#  7906484.21699762,
#  7928808.72803454,
#  7940977.3707481,
#  7961668.73043265,
#  7986679.2802165,
#  8002418.13169346,
#  8031684.040426889,
#  8027973.314441999,
#  8032504.026090359,
#  8048897.20885894,
#  8053432.4331837995,
#  8065029.48484193,
#  8076099.90251919,
#  8089758.2948215995,
#  8102294.41793633,
#  8125368.13328203,
#  8127671.63741515,
#  8132498.765566461,
#  8156402.54548306,
#  8176526.83971983,
#  8209659.87994008,
#  8242003.46010918,
#  8248576.32715288,
#  8255564.08081541,
#  8254460.73974007,
#  8271897.97244034,
#  8277375.896570439,
#  8300936.185395929,
#  8315687.54517498,
#  8320997.927255751,
#  8339205.53516869,
#  8347841.986339959,
#  8354608.997448289,
#  8368378.534818038,
#  8397100.589122348,
#  8412490.843805907,
#  8430080.804040527,
#  8448101.919583626,
#  8469241.041058576,
#  8489292.790144706,
#  8523709.943415217,
#  8539618.544170327,
#  8560930.090912798,
#  8576959.287612448,
#  8588228.636273667,
#  8608452.520224117,
#  8606915.413483467,
#  8626574.407497428,
#  8644436.853081789,
#  8653978.514222229,
#  8674540.270944118,
#  8684396.277515348,
#  8693109.784300689,
#  8703715.878434869,
#  8735748.656645268,
#  8741342.372134127,
#  8725170.311313896,
#  8742978.531466505,
#  8744568.729617735,
#  8757824.799951274,
#  8763570.874297723,
#  8790773.946205063,
#  8809571.400041671,
#  8815032.344835002,
#  8824630.352112621,
#  8841137.50858137,
#  8844037.52126959,
#  8855618.489150649,
#  8857237.71545532,
#  8869587.84158482,
#  8874529.2122244,
#  8875026.131667031,
#  8884108.19692306,
#  8884964.70990676,
#  8898239.31129873,
#  8910151.43713634,
#  8936395.314230472,
#  8966456.164722212,
#  8985323.0474047,
#  9017545.87952584,
#  9037814.97612647,
#  9036389.36776875,
#  9063286.05404568,
#  9077472.376499591,
#  9107812.902785152,
#  9100698.493577942,
#  9124602.988827301,
#  9138631.947236102,
#  9141580.617701033,
#  9148400.338077942,
#  9161470.019156862,
#  9171029.725810273,
#  9181975.647124723,
#  9177911.519901743,
#  9202262.605960174,
#  9210651.952433893,
#  9231672.271216463,
#  9228899.844533592,
#  9227286.409772202,
#  9241066.638161244,
#  9249826.104848463,
#  9252461.849568153,
#  9263516.986052873,
#  9268570.472454423,
#  9262320.920511823,
#  9281486.110859124,
#  9295285.310708193,
#  9313312.838912662,
#  9315997.093581982,
#  9329229.584450701,
#  9335024.17417415,
#  9327094.24608391,
#  9326726.31680869,
#  9338101.39785542,
#  9354868.98131164,
#  9357569.08262356,
#  9382940.90961381,
#  9402337.02284275,
#  9416146.10930178,
#  9417293.48724887,
#  9439576.38274918,
#  9433186.018322779,
#  9434043.63174022,
#  9455869.64210793,
#  9466896.230583541,
#  9468347.536776511,
#  9489178.064202402,
#  9505045.539539931,
#  9518049.368020471,
#  9541635.60303875,
#  9546336.46558938,
#  9551587.4997778,
#  9555072.93798954,
#  9566709.76273647,
#  9574431.76560316,
#  9592543.378517382,
#  9623347.416764602,
#  9633939.934335273,
#  9667613.582949653,
#  9670991.808417732,
#  9675197.663689563,
#  9698317.739773223,
#  9698432.913561255,
#  9711221.440525284,
#  9712988.636482134,
#  9703507.406516705,
#  9740189.418974945,
#  9752056.751557706,
#  9754740.794232816,
#  9771316.680643676,
#  9758016.275131166,
#  9777619.497799337,
#  9789334.160468277,
#  9799383.436225656,
#  9822195.295791537,
#  9836928.830073558,
#  9844691.622312298,
#  9869093.462998837,
#  9888671.880246079,
#  9905014.156994069,
#  9904556.72652652,
#  9902460.06496773,
#  9920726.19692816,
#  9928135.94036522,
#  9919129.32255482,
#  9948516.492815979]

# %%
sub1=plt.subplot(1, 2, 1)##############################################################
iteration=[]
for i in range(0,999):
    iteration.append(i)

#在同一幅图片上画3条折线
A,=plt.plot(iteration,dynamic_regret,color = 'red',linewidth = '1.5',label='large-attack online primal-dual algorithm')


#设置图例并且设置图例的字体及大小
font1 = {
'size'   : 18,
}
#legend = plt.legend(handles=[A],prop=font1)
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=18)
 
#设置横纵坐标的名称以及对应字体格式
font2 = {
'size'   : 18,
}
plt.xlabel('T',font2)
plt.ylabel(r'Dynamic regret $Reg(T)$',font2)
plt.title('varying $D_{t}$',font2) 

sub2=plt.subplot(1, 2, 2)##############################################################
iteration=[]
for i in range(0,999):
    iteration.append(i)

#在同一幅图片上画3条折线
A,=plt.plot(iteration,dynamic_regret_T,color = 'red',linewidth = '1.5',label='large-attack online primal-dual algorithm')


#设置图例并且设置图例的字体及大小
font1 = {
'size'   : 18,
}
#legend = plt.legend(handles=[A],prop=font1)
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=18)
 
#设置横纵坐标的名称以及对应字体格式
font2 = {
'size'   : 18,
}
plt.xlabel('T',font2)
plt.ylabel(r'Dynamic regret $Reg(T)/T$',font2)
plt.title('varying $D_{t}$',font2) 

plt.legend(handles=[A],prop={'size':18},loc="upper center", bbox_to_anchor=[-0.3, -0.2],
           ncol=18, shadow=True, fancybox=True)

plt.subplots_adjust(wspace=0.5,hspace=0.5) 
plt.gcf().set_size_inches((15, 5))

#plt.savefig('./figures/01-figure1_dynamic_regret_attack_free_varying_D.pdf',format='pdf', bbox_inches='tight')
#plt.savefig('./figures/01-figure1_dynamic_regret_attack_free_varying_D.png',format='png', bbox_inches='tight')

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
from sympy import *
import math 
from datetime import datetime
from scipy.special import gamma, factorial
import scipy.special as sc

# %%
sum_thermal_wind_power_station_strategy=np.loadtxt("./data/02_IOS_optimal_parameters_small_Gaussian_Byzantine_attack_sum_thermal_wind_power_station_strategy.txt")
d_power_demand=np.loadtxt("./data/d_power_demand_normal_distribution_(100,10).txt")

# %%
accumulative_constraint_violation=[]
accumulative_constraint_violation_T=[]
for T in range(1, 1000):
    accumulative_constraint_violation_auxiliary_variable=0
    for t in range(0, T): 
        accumulative_constraint_violation_auxiliary_variable=accumulative_constraint_violation_auxiliary_variable+(1/58)*sum_thermal_wind_power_station_strategy[t+1]-d_power_demand[t+1]
    accumulative_constraint_violation.append(abs(accumulative_constraint_violation_auxiliary_variable))
    accumulative_constraint_violation_T.append(abs(accumulative_constraint_violation_auxiliary_variable)/T)

# %%
accumulative_constraint_violation
# Out:
# [31.98579342931035,
#  51.21961283189654,
#  63.41351642844826,
#  55.25923282879309,
#  67.62684206241377,
#  47.34874794034482,
#  42.20787296344827,
#  27.339083024655153,
#  33.14131617775861,
#  13.471942327068959,
#  8.126986277241386,
#  39.63197644396554,
#  65.77397947551727,
#  82.8106520634483,
#  110.2209691346552,
#  127.39464904017245,
#  133.57994197224141,
#  153.3865359894828,
#  151.07298863827592,
#  159.71014287982763,
#  205.57619507655176,
#  211.10187656017246,
#  227.87254682103452,
#  247.03088253068967,
#  255.57415998017242,
#  270.0273150710345,
#  296.2294880656897,
#  315.6709863294828,
#  334.1810285418966,
#  357.2030963367242,
#  387.2913225277586,
#  405.0365219374138,
#  407.92827752655177,
#  428.0002086729311,
#  415.3427737658621,
#  439.9538356155173,
#  460.20702398568966,
#  467.4813108551724,
#  471.16299415689656,
#  488.14542154689656,
#  503.92624257586203,
#  518.4809129043103,
#  523.8024150800001,
#  560.3536543118967,
#  577.9797041151725,
#  590.6860312724139,
#  598.724903801207,
#  618.2208605627587,
#  640.8131687677587,
#  643.8147530858622,
#  649.4033846755174,
#  653.6422570934484,
#  649.3432228729312,
#  658.614647701207,
#  655.1116618174138,
#  659.3578690855173,
#  650.2987647151725,
#  656.2216624148277,
#  674.132644087414,
#  663.7574145994829,
#  674.456029444138,
#  687.178335458276,
#  681.9329488341381,
#  672.9234348827588,
#  683.0149043303451,
#  682.3012867203452,
#  691.1204249110348,
#  697.6859048658623,
#  701.0618503782762,
#  688.6701251193107,
#  682.6100365682762,
#  679.831841419483,
#  675.5219032620691,
#  689.9260847991382,
#  690.2084819755174,
#  701.9629426115519,
#  708.8253843946553,
#  694.5378085675864,
#  679.2804710044828,
#  672.4442183082759,
#  671.2680102794828,
#  667.4607314231035,
#  664.1552530631035,
#  652.8912998743103,
#  654.1212577756896,
#  648.0702508989655,
#  658.3953101103448,
#  645.139442615862,
#  639.390552283793,
#  639.0707891544827,
#  641.5023602512068,
#  632.9464630984481,
#  635.0058212434482,
#  635.2553324927585,
#  631.0686968241379,
#  638.7237055282759,
#  636.344033587069,
#  637.4964532824138,
#  636.4959700696552,
#  606.7025370215517,
#  607.2297167124138,
#  603.842623195,
#  603.5725022725862,
#  601.2858395265517,
#  595.8852277746552,
#  581.755170922931,
#  576.1101909098276,
#  572.8495601137931,
#  593.8657919058621,
#  586.5663698451724,
#  566.7040599574138,
#  566.2164585125863,
#  560.8869455579312,
#  541.6159217175864,
#  542.9767671546554,
#  531.3434183605174,
#  511.54211164741395,
#  503.34527122396565,
#  503.260961370345,
#  509.467060640345,
#  481.93452626603465,
#  465.71858969000016,
#  442.5016530467243,
#  451.63323589482775,
#  452.7435510858622,
#  456.8542080856898,
#  427.8900726163794,
#  433.17345114224156,
#  410.9562657100002,
#  405.72357474793125,
#  396.80803233724157,
#  377.5600568865519,
#  367.9500036660346,
#  372.66806810706913,
#  374.60782562810357,
#  357.109035396207,
#  358.4247572601725,
#  348.5782923801725,
#  340.7373955839656,
#  336.72863354551737,
#  345.1048325358622,
#  351.63556835413806,
#  323.82949902913805,
#  313.0869220808622,
#  319.2011448825864,
#  310.6766038156898,
#  304.46140138982776,
#  291.6623289541381,
#  285.70253579051746,
#  268.79384768448296,
#  266.01562264431055,
#  254.67148167844846,
#  246.93292711379326,
#  228.75387349758637,
#  223.4159894151726,
#  195.99374833568982,
#  183.12509564879326,
#  154.39882164913809,
#  136.76875622517258,
#  132.014969148276,
#  120.01929343137945,
#  111.16147795241393,
#  96.67157566017255,
#  113.37718840034496,
#  114.7176084860346,
#  126.61709136568979,
#  110.20371060758633,
#  94.49033359948288,
#  85.96744884379322,
#  88.19434976896564,
#  66.67212920379323,
#  38.585535187586345,
#  38.09494132120703,
#  19.63230132396565,
#  13.212061637069098,
#  1.9563225360343495,
#  6.30378291568951,
#  15.734837995689517,
#  36.50262267896538,
#  57.04092180706884,
#  62.581564964827464,
#  67.86169859844816,
#  63.19173397637918,
#  62.156287084310236,
#  74.9986452948275,
#  81.3044174248275,
#  79.21737393637922,
#  82.36693800655163,
#  91.51584095637924,
#  118.14475449672406,
#  128.14351297793095,
#  167.36702469344817,
#  169.7585268365516,
#  182.16166985844814,
#  201.2712340831033,
#  206.64916006034468,
#  206.77934017431016,
#  228.38450769793084,
#  250.37954223379293,
#  276.1237148982757,
#  295.51715794672396,
#  303.86469304224124,
#  296.5662059212068,
#  308.25522931534476,
#  303.56958919568956,
#  314.7805585199999,
#  337.18792180327574,
#  348.8363450631033,
#  364.07408822551713,
#  386.4892660558619,
#  395.1917359668964,
#  409.29764792586184,
#  429.45945590689627,
#  449.9159988765514,
#  447.6588765005169,
#  465.37510377362037,
#  483.79007691827553,
#  496.65318469896516,
#  494.07682536896516,
#  514.6859768932754,
#  535.295824815172,
#  555.0982998951719,
#  572.3187115424132,
#  569.6146736532753,
#  593.3898864079304,
#  601.5606488196545,
#  621.5534535389647,
#  636.4743414510338,
#  644.5211065368958,
#  658.347002698275,
#  670.6347525958612,
#  673.7403711917232,
#  688.1870801237922,
#  712.5434595318956,
#  724.1478884051713,
#  739.0615364934472,
#  762.323286554654,
#  769.9627070241368,
#  780.4531586732746,
#  781.5197889127575,
#  798.9722195991368,
#  811.5066233436195,
#  813.5198152074125,
#  812.247030002585,
#  805.0604898781023,
#  804.7916060886196,
#  820.6016453963782,
#  835.1110420270678,
#  833.4713877124127,
#  847.6998177291368,
#  861.1825291798265,
#  859.0444996927574,
#  866.1451475834472,
#  879.8141695572403,
#  895.0100874291369,
#  911.8609620115507,
#  911.161913660861,
#  918.252751634999,
#  928.2604498863782,
#  938.0953282596541,
#  955.2908581403437,
#  949.9424717644818,
#  965.6349568336196,
#  982.0363836074127,
#  1000.4661739660336,
#  1016.822637748275,
#  1029.1856316987921,
#  1037.71001887793,
#  1045.9209784072402,
#  1062.6480784443092,
#  1061.2285338774127,
#  1065.407840649999,
#  1076.7591411624126,
#  1096.645044483447,
#  1106.4178414172402,
#  1119.4092815291367,
#  1124.0710110717228,
#  1127.4401215353435,
#  1123.4097995741365,
#  1148.0756319467225,
#  1149.2510004093085,
#  1148.2872261910327,
#  1165.031562134481,
#  1173.2866932827567,
#  1183.8978976194808,
#  1210.6799306548257,
#  1224.1694541191362,
#  1215.4476512143085,
#  1235.7906454910328,
#  1247.0929678370674,
#  1232.9084694156882,
#  1239.3149924460329,
#  1266.4208402825845,
#  1291.6672723562053,
#  1295.2430111370675,
#  1283.790276786378,
#  1309.424178201033,
#  1310.0798812903433,
#  1304.8916344012055,
#  1327.8357834620676,
#  1339.4730719853435,
#  1355.3918288460331,
#  1372.4440159994815,
#  1402.9831998905158,
#  1421.6844558165503,
#  1438.775833290516,
#  1433.3101383570677,
#  1432.787098641033,
#  1447.4968845465503,
#  1450.696818445171,
#  1474.9838088508604,
#  1496.2426412970672,
#  1495.8527990272396,
#  1510.04592239655,
#  1502.8825342331018,
#  1495.807026122757,
#  1500.0795773018947,
#  1507.1310617981017,
#  1514.5134235858602,
#  1519.3176567093085,
#  1518.6435311322393,
#  1538.2854324348255,
#  1577.0874070734462,
#  1570.7130521405152,
#  1591.55232998586,
#  1606.8737911715498,
#  1618.9900403406878,
#  1625.4137376181015,
#  1638.7409574860326,
#  1637.3739498801706,
#  1650.408050263274,
#  1667.6399236560326,
#  1671.5669893610327,
#  1700.8280153237913,
#  1721.5406719791363,
#  1729.5010718141361,
#  1735.076071498274,
#  1758.406197889136,
#  1774.8164242141358,
#  1798.7844429893082,
#  1802.527309549308,
#  1800.0129115165494,
#  1786.1178046313769,
#  1797.1059720620665,
#  1802.2279375125836,
#  1808.290346566377,
#  1812.5091713503425,
#  1831.3170236620667,
#  1828.6575708013772,
#  1829.8432923415496,
#  1833.0651569684462,
#  1840.3005565556878,
#  1854.646213242412,
#  1869.1429868122395,
#  1877.6226996260327,
#  1890.4678476796535,
#  1872.4085566555157,
#  1872.1977793732742,
#  1884.5895531736192,
#  1906.5778503284466,
#  1899.8739981112053,
#  1910.3740372453433,
#  1926.8149263708606,
#  1923.5555407156883,
#  1933.8084141224124,
#  1940.9743768891365,
#  1969.2319148801712,
#  1993.6956630299985,
#  2023.5432222575846,
#  2031.683780043619,
#  2062.089352820688,
#  2076.35864307086,
#  2097.651166540515,
#  2124.973300111205,
#  2147.68486276155,
#  2150.5323956246534,
#  2180.111360014136,
#  2204.59405149586,
#  2234.528654224826,
#  2239.246121740688,
#  2247.242382366895,
#  2260.936458104826,
#  2272.184490876033,
#  2286.9254853679295,
#  2302.7523766570675,
#  2322.7145736486195,
#  2339.4822702236197,
#  2346.5187774958613,
#  2346.3835199267237,
#  2363.0017201405167,
#  2389.952855728965,
#  2413.0611190956893,
#  2428.7408427703444,
#  2440.5062417874133,
#  2469.94903680431,
#  2484.812716818965,
#  2502.47531197931,
#  2508.4227589553443,
#  2519.7920890767236,
#  2535.198579478103,
#  2545.7579824149993,
#  2550.435582152758,
#  2570.9295442513785,
#  2582.362999711034,
#  2595.869375594999,
#  2603.825749380861,
#  2629.992998297758,
#  2639.41509354862,
#  2641.5500997046543,
#  2649.7531005148267,
#  2652.6046396093093,
#  2639.6585459056887,
#  2667.4225588131026,
#  2675.2742496324126,
#  2667.3631109093094,
#  2694.01516773362,
#  2693.9859407731024,
#  2685.3250434581023,
#  2682.8607167577575,
#  2692.98148613224,
#  2698.2397492779296,
#  2707.4062791498263,
#  2717.9875520924124,
#  2716.8931391062056,
#  2729.1424253674127,
#  2747.97071228224,
#  2752.325408874654,
#  2757.519188485688,
#  2748.522995934654,
#  2753.495922116033,
#  2761.1752700017228,
#  2771.259652084999,
#  2784.065012281378,
#  2782.3667937668956,
#  2796.5095710913783,
#  2787.3443606224128,
#  2792.6889141565507,
#  2803.311928429654,
#  2806.672284240516,
#  2808.79652932293,
#  2828.036670727068,
#  2835.8147753420685,
#  2853.6884852884477,
#  2854.2541623522407,
#  2861.7702309951715,
#  2874.161758119137,
#  2888.7669544053438,
#  2896.4918357427578,
#  2898.1834408055165,
#  2930.001028704999,
#  2953.5861760018956,
#  2978.6012814924125,
#  2997.539212073102,
#  2993.139737979481,
#  3027.025582368964,
#  3034.36348159224,
#  3045.1263827731023,
#  3060.600660089309,
#  3067.5033560982743,
#  3076.7740771132744,
#  3096.781745938102,
#  3094.3596179429296,
#  3108.905037440171,
#  3124.482901666378,
#  3139.196037233964,
#  3136.2104061244813,
#  3149.5491028863776,
#  3170.314909731895,
#  3177.5310034167223,
#  3202.9420398518946,
#  3211.0826405713774,
#  3201.4531460355156,
#  3218.9741884541363,
#  3234.630437040171,
#  3259.559272176205,
#  3281.546358663619,
#  3287.027864094653,
#  3295.2697291705153,
#  3299.14398142586,
#  3307.9644059227567,
#  3329.7272041849983,
#  3322.6146330381016,
#  3326.810515080343,
#  3336.905841255171,
#  3335.876064168619,
#  3345.7214953055154,
#  3375.261027639136,
#  3373.3086936851705,
#  3389.6323555568947,
#  3385.2069227801708,
#  3416.5937291886194,
#  3419.520785715171,
#  3419.2237079584465,
#  3428.792669058964,
#  3426.9218574122397,
#  3440.595560628274,
#  3450.9201371393087,
#  3468.7144641467225,
#  3479.654192434654,
#  3492.286195811723,
#  3510.5076419356883,
#  3526.4537919286195,
#  3531.91868174793,
#  3535.957937269309,
#  3551.210559143102,
#  3566.900831686033,
#  3574.564232708274,
#  3584.1867342629293,
#  3587.1848699787915,
#  3607.837591678102,
#  3599.7250600844814,
#  3603.0848814765504,
#  3617.245806823619,
#  3634.005916782757,
#  3683.910076200516,
#  3690.940903344309,
#  3715.0173724281017,
#  3719.708147385343,
#  3732.5494585087913,
#  3745.7826871575844,
#  3760.2042234631017,
#  3769.2756733687916,
#  3781.8203902349983,
#  3799.1972584343084,
#  3781.701303646205,
#  3795.7186518263775,
#  3816.4391598898255,
#  3821.8784581632735,
#  3833.22193505086,
#  3832.6213395556874,
#  3847.270981977239,
#  3850.649002923101,
#  3866.8147993796524,
#  3854.442981239825,
#  3861.6808322689626,
#  3852.2187549960317,
#  3859.176417428963,
#  3861.364890578618,
#  3869.3643028920665,
#  3879.0570550137904,
#  3881.409311594825,
#  3885.8755639279284,
#  3901.4277908679283,
#  3908.554197783101,
#  3902.379010858446,
#  3919.2041045105148,
#  3924.5801892134455,
#  3966.359749323618,
#  3964.544000641204,
#  3988.630314360687,
#  3993.776925987584,
#  4009.8733959327565,
#  4023.30789363655,
#  4036.27301376724,
#  4048.2701075168948,
#  4079.82070939517,
#  4093.662863952584,
#  4124.739858624135,
#  4125.49573864379,
#  4136.436958542756,
#  4153.018967638445,
#  4163.746307104652,
#  4182.157092956376,
#  4191.671638317065,
#  4201.185235037065,
#  4203.007965904479,
#  4228.697545147238,
#  4221.835250294479,
#  4237.3750239613755,
#  4240.976708447755,
#  4259.90452677379,
#  4255.15585784379,
#  4277.893231701031,
#  4289.848364011721,
#  4291.694484774307,
#  4311.253414372755,
#  4327.455930963445,
#  4347.450594282583,
#  4361.070044614479,
#  4368.044125759135,
#  4371.151446213617,
#  4370.708800075342,
#  4368.563398078273,
#  4378.387335847929,
#  4406.057421327756,
#  4414.22135046017,
#  4419.26997634879,
#  4427.338363034996,
#  4442.022108745686,
#  4443.775428505685,
#  4477.326231615685,
#  4493.470631345857,
#  4508.691660535857,
#  4515.819520794133,
#  4536.76483792827,
#  4547.084086093269,
#  4548.797490372752,
#  4568.792625450856,
#  4579.260593587235,
#  4593.4576709980975,
#  4594.956553154477,
#  4621.702133306891,
#  4639.948882318615,
#  4655.350389076546,
#  4664.864488121029,
#  4675.627157676891,
#  4669.100659466029,
#  4666.333260178788,
#  4692.266696771374,
#  4683.467037191546,
#  4701.161432996373,
#  4690.710738196545,
#  4686.9231961262,
#  4705.454568698614,
#  4712.262364092407,
#  4718.875499207578,
#  4724.960919976026,
#  4731.743254347233,
#  4747.157402290164,
#  4767.197745443613,
#  4778.683593212061,
#  4810.897097424992,
#  4833.428814649131,
#  4861.446355469649,
#  4864.138198629304,
#  4873.613550509821,
#  4877.418120742235,
#  4914.283031583098,
#  4922.627696386891,
#  4929.75068954396,
#  4945.0954377184435,
#  4947.123872682064,
#  4957.09184933034,
#  4991.312154845512,
#  5007.541156603271,
#  5022.4844731870635,
#  5031.447145085856,
#  5039.396489023442,
#  5052.794270174649,
#  5062.4745160262,
#  5067.44731377051,
#  5074.919346961027,
#  5072.819241494476,
#  5095.84509714051,
#  5106.259673183613,
#  5117.822971468958,
#  5127.627976597061,
#  5124.479192120682,
#  5133.290828678268,
#  5144.684699082923,
#  5148.691999050853,
#  5158.092085853612,
#  5164.851126513439,
#  5172.423133800854,
#  5186.975868287061,
#  5199.933705052061,
#  5207.951071121372,
#  5209.442287362923,
#  5208.9435470275785,
#  5206.377465048613,
#  5222.036123168786,
#  5230.644826121026,
#  5242.2008852418885,
#  5265.24797670344,
#  5276.836289035681,
#  5300.484092567405,
#  5314.350163055508,
#  5332.1266381317155,
#  5350.488612703612,
#  5356.33532501637,
#  5373.10326102499,
#  5381.988938364645,
#  5405.971368733093,
#  5419.645929973783,
#  5426.903689769989,
#  5411.743869320334,
#  5414.788421437748,
#  5415.996325000335,
#  5416.302783151197,
#  5419.5337603046455,
#  5428.779051936887,
#  5441.12138557068,
#  5450.054347029819,
#  5453.882685014301,
#  5457.883518813094,
#  5464.83460967568,
#  5489.529239313956,
#  5507.24153058499,
#  5524.418961156196,
#  5530.321942276541,
#  5549.949783736542,
#  5566.101210575853,
#  5583.822355887749,
#  5586.444764853611,
#  5590.070288948438,
#  5604.677649108783,
#  5617.203472251714,
#  5629.684475619472,
#  5633.623188759645,
#  5642.810119491024,
#  5653.305447494645,
#  5657.770952288093,
#  5658.464812679128,
#  5665.880276278094,
#  5664.192513235681,
#  5696.077538526888,
#  5710.95090694775,
#  5729.212965206715,
#  5735.81920349568,
#  5742.766381982404,
#  5756.86560758999,
#  5767.266942042232,
#  5773.583747013266,
#  5778.088273277748,
#  5793.741760854127,
#  5822.345562041024,
#  5830.342131121542,
#  5834.137184108956,
#  5847.680901295507,
#  5862.868086427576,
#  5881.6730462643,
#  5897.456013451369,
#  5907.261712167576,
#  5927.514699442921,
#  5940.94666855792,
#  5961.58453825654,
#  5954.97730048723,
#  5946.666560850851,
#  5951.797698746369,
#  5968.818266155162,
#  5989.871898796714,
#  5999.230156396369,
#  6020.9467743443,
#  6032.898976455162,
#  6040.576767478265,
#  6055.330134884127,
#  6059.995322386368,
#  6080.916009461195,
#  6085.806510926023,
#  6092.725365754299,
#  6091.844012308782,
#  6101.216076170506,
#  6112.975358816886,
#  6099.817750005852,
#  6114.358117918783,
#  6116.001586282231,
#  6135.024283411024,
#  6136.558875131024,
#  6150.085080833093,
#  6170.766817515852,
#  6158.983763025335,
#  6181.965755222576,
#  6184.192620379127,
#  6198.7513671836105,
#  6208.303840606542,
#  6219.547846498438,
#  6234.192426109127,
#  6243.245831350335,
#  6260.889547321369,
#  6273.173353401714,
#  6276.80008080068,
#  6280.767224623439,
#  6287.403406047922,
#  6291.842032979301,
#  6312.090499391024,
#  6343.17610276792,
#  6356.961944286369,
#  6370.39194060792,
#  6380.558957945334,
#  6398.71659712068,
#  6410.876893186714,
#  6421.254488271369,
#  6435.377539238439,
#  6446.3556316349905,
#  6444.610782269128,
#  6462.777728376197,
#  6479.9732166963695,
#  6476.090091778266,
#  6481.115161113782,
#  6501.689641011196,
#  6527.499392903437,
#  6528.009863795851,
#  6520.941750280505,
#  6528.33523953947,
#  6555.578806913953,
#  6566.473987967573,
#  6592.812168514642,
#  6605.764978757055,
#  6618.797355813607,
#  6615.758086479297,
#  6642.521829246712,
#  6651.930398222574,
#  6663.839558945504,
#  6695.781100397573,
#  6697.909373810331,
#  6715.242569098779,
#  6715.058688842572,
#  6726.055081769468,
#  6736.453818145158,
#  6750.694532221538,
#  6771.536179179814,
#  6788.411872848779,
#  6810.530570472917,
#  6829.994224811538,
#  6840.519881819124,
#  6870.283592708434,
#  6888.934911397745,
#  6910.324761729469,
#  6927.449084084469,
#  6910.801350538435,
#  6923.2434688034355,
#  6925.916191121367,
#  6936.547651448608,
#  6930.120822096884,
#  6933.731921352057,
#  6953.38085923292,
#  6962.799450743437,
#  6968.811941010161,
#  6960.490318254643,
#  6975.527659978264,
#  6971.680882619125,
#  6995.860824621194,
#  7015.475038479987,
#  7032.764207337056,
#  7047.361081126712,
#  7041.2173134989525,
#  7064.008878867918,
#  7085.505963550331,
#  7091.8662235955035,
#  7094.542493562228,
#  7099.279578161021,
#  7115.231564954986,
#  7124.51627547016,
#  7122.39707138016,
#  7142.798147628609,
#  7153.5788835734365,
#  7172.383408558437,
#  7195.439950790334,
#  7209.538384515161,
#  7236.925156400678,
#  7233.3427777870575,
#  7237.141719329644,
#  7251.861601402576,
#  7255.6635336849895,
#  7265.924733442575,
#  7275.700063256713,
#  7287.870759654127,
#  7299.00028645361,
#  7320.159117001369,
#  7321.946908298955,
#  7326.014999718266,
#  7348.000340450508,
#  7366.277506830508,
#  7397.733514428612,
#  7428.364052569129,
#  7434.020407589129,
#  7440.058504921198,
#  7438.793946076542,
#  7454.528775151542,
#  7459.195464848955,
#  7480.892071927059,
#  7494.102735517577,
#  7498.619337893783,
#  7515.099451825163,
#  7522.653718113438,
#  7528.4980451665415,
#  7540.799039557403,
#  7567.7548691577485,
#  7581.57049991499,
#  7597.468825900853,
#  7613.781567963094,
#  7633.118286589129,
#  7651.3994707587835,
#  7684.410410898611,
#  7698.734324784301,
#  7718.273142545508,
#  7732.723658970335,
#  7742.733277396543,
#  7761.239069226888,
#  7759.591234922061,
#  7777.56256464206,
#  7793.795343873784,
#  7802.221378840335,
#  7821.0937379539555,
#  7829.813751374818,
#  7837.48126397999,
#  7846.897400264817,
#  7877.560878345335,
#  7882.366699030508,
#  7867.913006220336,
#  7884.126079645508,
#  7885.294338456542,
#  7897.18110268706,
#  7902.126858451543,
#  7927.728492551543,
#  7944.888084798095,
#  7949.5723482094745,
#  7958.057685095337,
#  7973.011107153267,
#  7975.36465747844,
#  7985.687427477577,
#  7986.881090262233,
#  7997.917404912578,
#  8002.125690227405,
#  8002.304693397061,
#  8010.306418806026,
#  8010.808628507233,
#  8022.6945640775775,
#  8033.308778851198,
#  8057.854127495854,
#  8086.342108004647,
#  8103.525582847578,
#  8134.301395215509,
#  8152.858580190854,
#  8151.311542691716,
#  8176.552690826198,
#  8189.295936480854,
#  8218.140234698267,
#  8211.536524174819,
#  8233.768378383957,
#  8246.378259272406,
#  8248.778848368613,
#  8254.711851722923,
#  8266.42961949413,
#  8274.88653647982,
#  8284.627989356199,
#  8280.722957662061,
#  8303.430380684475,
#  8310.805111714992,
#  8330.165911211889,
#  8327.413536510681,
#  8325.698812979992,
#  8338.078979443959,
#  8345.792853885683,
#  8347.907418133096,
#  8357.74178386775,
#  8362.052747121024,
#  8356.210316294817,
#  8373.71438536361,
#  8386.092038554816,
#  8402.48002046999,
#  8404.632265159129,
#  8416.474889361716,
#  8421.453409869819,
#  8414.138940781026,
#  8413.538066460853,
#  8423.643625068267,
#  8438.793508043094,
#  8440.953468604992,
#  8464.54693746189,
#  8482.203025529994,
#  8494.556178077408,
#  8495.314160747408,
#  8515.794104729823,
#  8509.84040054172,
#  8510.33750204672,
#  8530.35282811672,
#  8540.114236137064,
#  8541.143096104133,
#  8560.170292894478,
#  8574.434693839134,
#  8586.024345545167,
#  8607.730209211202,
#  8611.686784274305,
#  8616.144421249996,
#  8619.005142878961,
#  8629.324335153444,
#  8636.040481616203,
#  8652.427911841203,
#  8681.54214639034,
#  8690.894970379306,
#  8723.049357845857,
#  8725.814456284306,
#  8729.33115908603,
#  8750.623043141548,
#  8750.451752502755,
#  8761.848577338962,
#  8763.163765155341,
#  8754.51190933103,
#  8789.980884582064,
#  8800.519613203962,
#  8802.66000749241,
#  8817.599360091548,
#  8805.657427802927,
#  8823.496637766377,
#  8833.891995753273,
#  8842.748107838272,
#  8863.71971785965,
#  8876.917601877238,
#  8883.671800858445,
#  8906.228457801893,
#  8924.027693890343,
#  8938.737186035516,
#  8938.051889747929,
#  8935.902225457758,
#  8952.446281616723,
#  8958.87878973517,
#  8950.642495472757,
#  8978.294219500862]

# %%
sub1=plt.subplot(1, 2, 1)##############################################################
iteration=[]
for i in range(0,999):
    iteration.append(i)

#在同一幅图片上画3条折线
A,=plt.plot(iteration,accumulative_constraint_violation,color = 'green',linewidth = '1.5',label='attack-free online primal-dual algorithm')


#设置图例并且设置图例的字体及大小
font1 = {
'size'   : 18,
}
#legend = plt.legend(handles=[A],prop=font1)
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=18)
 
#设置横纵坐标的名称以及对应字体格式
font2 = {
'size'   : 18,
}
plt.xlabel('T',font2)
plt.ylabel(r'Constraint violation $Fit(T)$',font2)
plt.title('varying $D_{t}$',font2) 

sub2=plt.subplot(1, 2, 2)##############################################################
iteration=[]
for i in range(0,999):
    iteration.append(i)

#在同一幅图片上画3条折线
A,=plt.plot(iteration,accumulative_constraint_violation_T,color = 'green',linewidth = '1.5',label='attack-free online primal-dual algorithm')


#设置图例并且设置图例的字体及大小
font1 = {
'size'   : 18,
}
#legend = plt.legend(handles=[A],prop=font1)
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=18)
 
#设置横纵坐标的名称以及对应字体格式
font2 = {
'size'   : 18,
}
plt.xlabel('T',font2)
plt.ylabel(r'Constraint violation $Fit(T)/T$',font2)
plt.title('varying $D_{t}$',font2) 

plt.legend(handles=[A],prop={'size':18},loc="upper center", bbox_to_anchor=[-0.3, -0.2],
           ncol=18, shadow=True, fancybox=True)

plt.subplots_adjust(wspace=0.5,hspace=0.5) 
plt.gcf().set_size_inches((15, 5))


#plt.savefig('./figures/01-figure2_constraint_violation_attack_free_varying_D.pdf',format='pdf', bbox_inches='tight')
#plt.savefig('./figures/01-figure2_constraint_violation_attack_free_varying_D.png',format='png', bbox_inches='tight')
