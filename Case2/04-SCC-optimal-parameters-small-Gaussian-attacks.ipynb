# %% [raw]
# SCC鲁棒的decentralized online economic dispatch algorithm+小值高斯攻击
#
# 实验设置：IEEE118bus+6个风能发电站
# 发电站数量：54个传统火力发电站+6个风能发电站
# 时变的变量：1. 风速服从的weibull分布的尺度参数c
# 2. 风速服从的weibull分布的形状参数wk
# 3. 用户侧的平均用电需求D
# 尺度参数c和形状参数wk采用真实数据集数据
# 平均用电需求D服从均值为100 均方差为10的正态分布
# 54个传统火力发电站的发电成本相关数据见数据集
# 传统火力发电站成本函数：a+bP+cP^2
# 6个风能发电站的发电成本相关参数见论文手稿
#
# 选择两个拜占庭发电站 一个为54号火力发电站 一个为58号风能发电站
#
# 小值高斯攻击
#
# SCC+adaptive clipping

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
from sympy import *
import math 
from datetime import datetime
from scipy.special import gamma, factorial
import scipy.special as sc

# %%
#定义变量
thermal_power_station_strategy=np.zeros(shape=(54,1000)) 
wind_power_station_strategy=np.zeros(shape=(6,1000))
thermal_power_station_dual_variable=np.zeros(shape=(54,1000))
wind_power_station_dual_variable=np.zeros(shape=(6,1000))
E=np.loadtxt("IEEE-118-doubly-stochastic-weight-matrix.txt")
thermal_power_station_cost=np.zeros(shape=(1,1000)) #火力发电成本
wind_power_station_cost=np.zeros(shape=(1,1000)) #风力发电成本
sum_cost=np.zeros(shape=(1,1000)) #总发电成本
sum_thermal_wind_power_station_strategy=np.zeros(shape=(1,1000))#总发电量
#火力发电站的相关数据  其中54号为拜占庭
generator_a_values= np.loadtxt("./real-data/generator_a_values.txt")#每个agent的成本函数中的超参数a
generator_b_values= np.loadtxt("./real-data/generator_b_values.txt")#每个agent的成本函数中的超参数a
generator_c_values= np.loadtxt("./real-data/generator_c_values.txt")#每个agent的成本函数中的超参数a
thermal_power_station_P_max= np.loadtxt("./real-data/generator_Pmax_values.txt")#每个agent的资源量的上界
thermal_power_station_P_min= np.loadtxt("./real-data/generator_Pmin_values.txt")#每个agent的资源量的下界
#55 56 57 58 59 60号诚实风能的成本相关数据 其中58号为拜占庭 
wind_power_station_varphi=[1,6,1,6,1,6]
wind_power_station_v_in=[3,4,5,3,4,5]
wind_power_station_v_out=[25,45,25,45,25,45]
wind_power_station_v_r=[13,15,16,13,15,16]
wind_power_station_sigma_ue=[3,5,3,5,3,5]
wind_power_station_sigma_oe=[20,30,20,30,20,30]
wind_power_station_P_r=[150,160,150,160,150,160]
wind_power_station_P_min=[0,0,0,0,0,0]
wind_power_station_P_max=[500,300,400,200,300,200]
#不确定性的参数 时变参数
d_power_demand=np.loadtxt("./data/d_power_demand_normal_distribution_(100,10).txt") #时变的需求侧用电需求  
c_wind_speed= np.loadtxt("./real-data/weibull_scale_c.txt")      
kappa_wind_speed= np.loadtxt("./real-data/weibull_shape_wk.txt") 
#迭代步长
step_size_primal=5
step_size_dual=5
#正则化参数
regularization_parameter=0.00001
#每个用户在每次迭代中均需要计算出一个tau值
tau_robust1=np.zeros(shape=(60,1000))

small_Gaussian_Byzantine_attack=np.loadtxt("./data/small_Gaussian_Byzantine_attack_(-1500,30).txt")

# %%
#变量初始化
#火力，风力发电策略初始化 诚实
'''for i in range(0,53):
    thermal_power_station_strategy[i][0]=0
for j in range(0,6):
    if j!=3:
        wind_power_station_strategy[j][0]=0'''
for i in range(0,53):
    thermal_power_station_strategy[i][0]=thermal_power_station_P_max[i]
for j in range(0,6):
    if j!=3:
        wind_power_station_strategy[j][0]=thermal_power_station_P_max[j]
        
#拜占庭发电站发电策略初始化 拜占庭
thermal_power_station_strategy[53][0]=0
wind_power_station_strategy[3][0]=0
#诚实用户的初始总发电策略
'''sum_thermal_wind_power_station_strategy[0][0]=0'''
#诚实用户的初始总发电策略
for i in range(0,53):
    sum_thermal_wind_power_station_strategy[0][0]+=thermal_power_station_strategy[i][0]
for j in range(0,6):
    if j!=3:
        sum_thermal_wind_power_station_strategy[0][0]+= wind_power_station_strategy[j][0]

#火力，风力对偶策略初始化 诚实
for i in range(0,53):
    thermal_power_station_dual_variable[i][0]=-1000
for j in range(0,6):
    if j!=3:
        wind_power_station_dual_variable[j][0]=-1000
#拜占庭发电站对偶策略初始化 拜占庭
thermal_power_station_dual_variable[53][0]=small_Gaussian_Byzantine_attack[0]
wind_power_station_dual_variable[3][0]=small_Gaussian_Byzantine_attack[0]

#安全发电站的初始总发电成本 诚实
#火力发电成本
for i in range(0,53):
    thermal_power_station_cost[0][0]=thermal_power_station_cost[0][0]+generator_c_values[i]*thermal_power_station_strategy[i][0]*thermal_power_station_strategy[i][0]+generator_b_values[i]*thermal_power_station_strategy[i][0]+generator_a_values[i]
#风力发电成本
for i in range(0,6):
    if i!=3:
        wind_power_station_cost[0][0]=wind_power_station_cost[0][0]+wind_power_station_varphi[i]*wind_power_station_strategy[i][0]+wind_power_station_sigma_ue[i]*((wind_power_station_P_r[i]-wind_power_station_strategy[i][0])*(math.exp(-(math.pow(wind_power_station_v_r[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0])))-math.exp(-(math.pow(wind_power_station_v_out[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0]))))+(wind_power_station_P_r[i]*wind_power_station_v_in[i]/(wind_power_station_v_r[i]-wind_power_station_v_in[i])+wind_power_station_strategy[i][0])*(math.exp(-(math.pow(wind_power_station_v_r[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0])))-math.exp(-(math.pow(wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][0])/wind_power_station_P_r[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0]))))+(wind_power_station_P_r[i]*c_wind_speed[0]/(wind_power_station_v_r[i]-wind_power_station_v_in[i]))*(sc.gammaincc(1+1/kappa_wind_speed[0],(math.pow(wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][0])/wind_power_station_P_r[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0])))*sc.gamma(1+1/kappa_wind_speed[0])-sc.gammaincc(1+1/kappa_wind_speed[0],math.pow(wind_power_station_v_r[i]/c_wind_speed[0],kappa_wind_speed[0]))*sc.gamma(1+1/kappa_wind_speed[0])))+wind_power_station_sigma_oe[i]*((wind_power_station_strategy[i][0])*(1-math.exp(-(math.pow(wind_power_station_v_in[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0])))+math.exp(-(math.pow(wind_power_station_v_out[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0]))))+(wind_power_station_P_r[i]*wind_power_station_v_in[i]/(wind_power_station_v_r[i]-wind_power_station_v_in[i])+wind_power_station_strategy[i][0])*(math.exp(-(math.pow(wind_power_station_v_in[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0])))-math.exp(-(math.pow(wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][0])/wind_power_station_P_r[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0]))))+(wind_power_station_P_r[i]*c_wind_speed[0]/(wind_power_station_v_r[i]-wind_power_station_v_in[i]))*(sc.gammaincc(1+1/kappa_wind_speed[0],(math.pow(wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][0])/wind_power_station_P_r[i],kappa_wind_speed[0]))/(math.pow(c_wind_speed[0],kappa_wind_speed[0])))*sc.gamma(1+1/kappa_wind_speed[0])-sc.gammaincc(1+1/kappa_wind_speed[0],math.pow(wind_power_station_v_in[i]/c_wind_speed[0],kappa_wind_speed[0]))*sc.gamma(1+1/kappa_wind_speed[0])))
#发电总成本
sum_cost[0][0]=thermal_power_station_cost[0][0]+wind_power_station_cost[0][0]

#计算每个发电站的邻居发电站
neighbor_robust1_help=[]
for i in range (0,60):
    for j in range (0,60):
        if E[i][j]!=0:
            neighbor_robust1_help.append(j)
        elif E[i][j]==0:
            neighbor_robust1_help.append(99)
neighbor_robust1=np.array(neighbor_robust1_help).reshape(60,60)

#计算安全的发电站的拜占庭邻居用户数量
q_robust1=[]
for i in range(0,60):
    q_robust1_help=0
    for j in range(0,60):
        if neighbor_robust1[i][j]==53 or neighbor_robust1[i][j]==57:
            q_robust1_help=q_robust1_help+1
    q_robust1.append(q_robust1_help)

# %%
def SCC_Byzantine_attack_decentralized_economic_dispatch(thermal_power_station_strategy,wind_power_station_strategy,c_wind_speed,kappa_wind_speed,d_power_demand,thermal_power_station_dual_variable,wind_power_station_dual_variable,E,thermal_power_station_cost,wind_power_station_cost,generator_a_values,generator_b_values,generator_c_values,thermal_power_station_P_min,thermal_power_station_P_max,wind_power_station_varphi,wind_power_station_sigma_ue,wind_power_station_sigma_oe,wind_power_station_P_min,wind_power_station_P_max,sum_thermal_wind_power_station_strategy,step_size_primal,step_size_dual):
    #显示初始化的数据
    #输出初始状态的原变量和对偶变量
    print("***************************large_attack_online_decentralized_economic_dispatch*****************************")
    print("相关变量初始值为：")
    for i in range (0,52):
        print("第",(i+1),"个火力发电站的初始计划发电量为:",thermal_power_station_strategy[i][0])
    for i in range (0,6):
        if i!=3:
            print("第",(i+55),"个风力发电站的初始计划发电量为:",wind_power_station_strategy[i][0])
    print("****************************************************************************")
    for i in range (0,52):
        print("第",(i+1),"个火力发电站的初始对偶变量为:",thermal_power_station_dual_variable[i][0])
    for i in range (0,6):
        if i!=3:
            print("第",(i+55),"个风力发电站的初始对偶变量为:",wind_power_station_dual_variable[i][0])
    print("****************************************************************************")
    print("第",(54),"个受到Byzantin攻击的火力发电站的初始对偶变量为:",thermal_power_station_dual_variable[53][0])
    print("第",(58),"个受到Byzantin攻击的风力发电站的初始对偶变量为:",wind_power_station_dual_variable[3][0])
    print("****************************************************************************")
    print("安全发电站的初始总发电量:",sum_thermal_wind_power_station_strategy[0][0])
    print("*************************")
    print("需求侧平均用电需求:",d_power_demand[0])
    print("****************************************************************************")
    print("风速分布参数c:",c_wind_speed[0])
    print("****************************************************************************")
    print("风速分布参数kappa:",kappa_wind_speed[0])
    print("****************************************************************************")
    print("安全发电站的总发电成本：", sum_cost[0][0])
    print("****************************************************************************")
    print("原变量迭代步长为:",step_size_primal)
    print("*****************************************************************************")
    print("对偶变量迭代步长为:",step_size_dual)
    print("*****************************************************************************")
    
    #开始迭代
    for k in range(1,1000):
        #发电站更新计划发电量和对偶变量
        #对偶变量 先做梯度上升 再做聚合
        dual_variable_intermediate=[] #存放当前迭代中60个用户对对偶变量做完梯度下降后得到的中间值
        for i in range(0,53):
            dual_variable_intermediate.append(thermal_power_station_dual_variable[i][k-1]+step_size_dual*((1/60)*thermal_power_station_strategy[i][k-1]-(1/60)*d_power_demand[k-1]-regularization_parameter*thermal_power_station_dual_variable[i][k-1]))
        #添加拜占庭火力发电站的对偶值
        dual_variable_intermediate.append(small_Gaussian_Byzantine_attack[k])
        for j in range(0,6):
            if j==3: #添加拜占庭风力发电站的对偶值
                dual_variable_intermediate.append(small_Gaussian_Byzantine_attack[k])
            else:
                dual_variable_intermediate.append(wind_power_station_dual_variable[j][k-1]+step_size_dual*((1/60)*wind_power_station_strategy[j][k-1]-(1/60)*d_power_demand[k-1]-regularization_parameter*wind_power_station_dual_variable[j][k-1]))
        
        #TM鲁棒聚合+adaptive clipping 安全的火力发电站的对偶更新
        #在做鲁棒聚合前 对收集到的信息进行adaptive clipping的剪裁操作
        for i in range (0,53):
            u_neighbor_help_robust1=neighbor_robust1[i].tolist()#将用户i的邻居序号存在辅助变量u中
            u_neighbor_help_robust1 = list(set(u_neighbor_help_robust1))
            u_neighbor_help_robust1.remove(99)
            if int(q_robust1[i])==1: #只有具有拜占庭邻居的用户才需要先进行adaptive clipping和后续的IOS聚合操作
                #先进行adaptive clipping
                dual_variable_intermediate_auxiliary=[]
                #注意必须以这样的方式赋值 不能直接写dual_variable_intermediate_auxiliary=dual_variable_intermediate
                #不然在修改变量dual_variable_intermediate_auxiliary的同时也会对dual_variable_intermediate进行修改
                for j in range(len(dual_variable_intermediate)): 
                    dual_variable_intermediate_auxiliary.append(dual_variable_intermediate[j])
                dual_variable_receive=[]
                clipping_C=0
                for j in range(0, len(u_neighbor_help_robust1)):
                    dual_variable_receive.append(dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[j]])
                dual_variable_receive.sort()
                clipping_C=-dual_variable_receive[1] #确定clpping的阈值
                #接下来对大于clipping_C的值进行clipping
                for j in range(0, len(u_neighbor_help_robust1)):
                    if -dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[j]]>clipping_C:
                        dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[j]]=-clipping_C
                #接下来做SCC鲁棒聚合   
                c_clipping_dual_robust1=[]#存放当前诚实用户对邻居的对偶变量裁剪后的值
                mix_sum_c_dual_robust1=0#存放clipping后的对偶值和  
                u_neighbor_help_robust1.remove(i)
                weight_sum_robust1=0
                for j in range(0,len(u_neighbor_help_robust1)):
                    if u_neighbor_help_robust1[j]!=53 and u_neighbor_help_robust1[j]!=57:
                        weight_sum_robust1=weight_sum_robust1+E[i][u_neighbor_help_robust1[j]]*(dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[j]]-dual_variable_intermediate_auxiliary[i])*(dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[j]]-dual_variable_intermediate_auxiliary[i])
                tau_robust1[i][k]=sqrt(weight_sum_robust1/(E[i][53]+E[i][57])) 
                #每个诚实用户首先对邻居传来的对偶变量进行剪裁clipping
                for j in range (0, len(u_neighbor_help_robust1)): #问题：分母会出现0的情况
                    if (dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[j]]-dual_variable_intermediate_auxiliary[i])==0:
                        c_clipping_dual_robust1.append(0)
                    elif 1<=(tau_robust1[i][k]/(abs((dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[j]]-dual_variable_intermediate_auxiliary[i])))):
                        c_clipping_dual_robust1.append(dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[j]]-dual_variable_intermediate_auxiliary[i])
                    else:
                        c_clipping_dual_robust1.append((dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[j]]-dual_variable_intermediate_auxiliary[i])*((tau_robust1[i][k]/(abs((dual_variable_intermediate_auxiliary[u_neighbor_help_robust1[j]]-dual_variable_intermediate_auxiliary[i]))))))
                #诚实用户聚合clipping后的邻居对偶值和自身的对偶值 
                for j in range(0,len(u_neighbor_help_robust1)):
                    mix_sum_c_dual_robust1=mix_sum_c_dual_robust1+E[i][u_neighbor_help_robust1[j]]*(dual_variable_intermediate_auxiliary[i]+c_clipping_dual_robust1[j])            
                #诚实用户基于SCC鲁棒聚合后的值进行自身的对偶变量的更新
                thermal_power_station_dual_variable[i][k]=E[i][i]*dual_variable_intermediate_auxiliary[i]+mix_sum_c_dual_robust1               
            else: #没有拜占庭邻居的用户直接进行权重聚合即可
                for j in range(0,len(u_neighbor_help_robust1)):
                     thermal_power_station_dual_variable[i][k]=thermal_power_station_dual_variable[i][k]+E[i][u_neighbor_help_robust1[j]]*dual_variable_intermediate[u_neighbor_help_robust1[j]]

        #安全的风力发电站的adaptive clipping操作 由于风力发电站的邻居中没有拜占庭用户 所以不需要进行adaptive clipping的操作
        #聚合 安全的风力发电站的对偶更新
        for i in range(0,6):
            if i!=3:
                weight_aggregation_dual_variable=0
                for j in range(0,54):
                    weight_aggregation_dual_variable=weight_aggregation_dual_variable+E[i+54][j]*dual_variable_intermediate[j]               
                for j in range(0,6):
                    weight_aggregation_dual_variable=weight_aggregation_dual_variable+E[i+54][j+54]*dual_variable_intermediate[j+54]
                wind_power_station_dual_variable[i][k]=weight_aggregation_dual_variable 
        
        #受到Byzantine攻击的火力和风力发电站的对偶更新
        thermal_power_station_dual_variable[53][k]=small_Gaussian_Byzantine_attack[k]
        wind_power_station_dual_variable[3][k]=small_Gaussian_Byzantine_attack[k]           
        
        #安全的火力发电站计划发电量
        for i in range(0,53):
            thermal_power_station_strategy[i][k]=thermal_power_station_strategy[i][k-1]-step_size_primal*(2*generator_c_values[i]*thermal_power_station_strategy[i][k-1]+generator_b_values[i]+(1/60)*thermal_power_station_dual_variable[i][k-1]) 
            if thermal_power_station_strategy[i][k]<=thermal_power_station_P_min[i]:
                thermal_power_station_strategy[i][k]=thermal_power_station_P_min[i]
            elif thermal_power_station_strategy[i][k]>=thermal_power_station_P_max[i]:
                thermal_power_station_strategy[i][k]=thermal_power_station_P_max[i]
        #安全的风力发电站计划发电量
        for i in range(0,6):
            if i!=3:
                wind_power_station_strategy[i][k]=wind_power_station_strategy[i][k-1]-step_size_primal*(wind_power_station_varphi[i]+wind_power_station_sigma_oe[i]+(wind_power_station_sigma_ue[i]+wind_power_station_sigma_oe[i])*math.exp(-(math.pow(wind_power_station_v_out[i],kappa_wind_speed[k-1]))/(math.pow(c_wind_speed[k-1],kappa_wind_speed[k-1])))+(-wind_power_station_sigma_ue[i]-wind_power_station_sigma_oe[i])*math.exp(-(math.pow((wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][k-1])/wind_power_station_P_r[i]),kappa_wind_speed[k-1]))/(math.pow(c_wind_speed[k-1],kappa_wind_speed[k-1])))+(1/60)*wind_power_station_dual_variable[i][k-1])
                if wind_power_station_strategy[i][k]<=wind_power_station_P_min[i]:
                    wind_power_station_strategy[i][k]=wind_power_station_P_min[i]
                elif wind_power_station_strategy[i][k]>=wind_power_station_P_max[i]:
                    wind_power_station_strategy[i][k]=wind_power_station_P_max[i]
        #受到Byzantine攻击的火力和风力发电站的计划发电量
        thermal_power_station_strategy[53][k]=thermal_power_station_strategy[53][k-1]
        wind_power_station_strategy[3][k]=wind_power_station_strategy[3][k-1]
        
        #安全发电站的计算总计划发电
        #火力发电量
        for i in range(0,53):
            sum_thermal_wind_power_station_strategy[0][k]=sum_thermal_wind_power_station_strategy[0][k]+thermal_power_station_strategy[i][k]
        #风力发电量
        for i in range(0,6):
            if i!=3:
                sum_thermal_wind_power_station_strategy[0][k]=sum_thermal_wind_power_station_strategy[0][k]+wind_power_station_strategy[i][k]
        
        #安全发电站的计算总发电成本
        #火力发电成本
        for i in range(0,53):
            thermal_power_station_cost[0][k]=thermal_power_station_cost[0][k]+generator_c_values[i]*thermal_power_station_strategy[i][k]*thermal_power_station_strategy[i][k]+generator_b_values[i]*thermal_power_station_strategy[i][k]+generator_a_values[i]
        #风力发电成本
        for i in range(0,6):
            if i!=3:
                wind_power_station_cost[0][k]=wind_power_station_cost[0][k]+wind_power_station_varphi[i]*wind_power_station_strategy[i][k]+wind_power_station_sigma_ue[i]*((wind_power_station_P_r[i]-wind_power_station_strategy[i][k])*(math.exp(-(math.pow(wind_power_station_v_r[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k])))-math.exp(-(math.pow(wind_power_station_v_out[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k]))))+(wind_power_station_P_r[i]*wind_power_station_v_in[i]/(wind_power_station_v_r[i]-wind_power_station_v_in[i])+wind_power_station_strategy[i][k])*(math.exp(-(math.pow(wind_power_station_v_r[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k])))-math.exp(-(math.pow(wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][k])/wind_power_station_P_r[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k]))))+(wind_power_station_P_r[i]*c_wind_speed[k]/(wind_power_station_v_r[i]-wind_power_station_v_in[i]))*(sc.gammaincc(1+1/kappa_wind_speed[k],(math.pow(wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][k])/wind_power_station_P_r[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k])))*sc.gamma(1+1/kappa_wind_speed[k])-sc.gammaincc(1+1/kappa_wind_speed[k],math.pow(wind_power_station_v_r[i]/c_wind_speed[k],kappa_wind_speed[k]))*sc.gamma(1+1/kappa_wind_speed[k])))+wind_power_station_sigma_oe[i]*((wind_power_station_strategy[i][k])*(1-math.exp(-(math.pow(wind_power_station_v_in[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k])))+math.exp(-(math.pow(wind_power_station_v_out[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k]))))+(wind_power_station_P_r[i]*wind_power_station_v_in[i]/(wind_power_station_v_r[i]-wind_power_station_v_in[i])+wind_power_station_strategy[i][k])*(math.exp(-(math.pow(wind_power_station_v_in[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k])))-math.exp(-(math.pow(wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][k])/wind_power_station_P_r[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k]))))+(wind_power_station_P_r[i]*c_wind_speed[k]/(wind_power_station_v_r[i]-wind_power_station_v_in[i]))*(sc.gammaincc(1+1/kappa_wind_speed[k],(math.pow(wind_power_station_v_in[i]+((wind_power_station_v_r[i]-wind_power_station_v_in[i])*wind_power_station_strategy[i][k])/wind_power_station_P_r[i],kappa_wind_speed[k]))/(math.pow(c_wind_speed[k],kappa_wind_speed[k])))*sc.gamma(1+1/kappa_wind_speed[k])-sc.gammaincc(1+1/kappa_wind_speed[k],math.pow(wind_power_station_v_in[i]/c_wind_speed[k],kappa_wind_speed[k]))*sc.gamma(1+1/kappa_wind_speed[k])))
        #发电总成本
        sum_cost[0][k]=thermal_power_station_cost[0][k]+wind_power_station_cost[0][k]
        
        #输出第k次迭代中的结果 每间隔10次迭代输出一次结果
        #if (k+1)%10==0:
        if k<=5:
            print(k,"次迭代中的结果：")
            for i in range (0,53):
                print("第",(i+1),"个火力发电站的计划发电量为:",thermal_power_station_strategy[i][k])
            for i in range (0,6):
                if i!=3:
                    print("第",(i+55),"个风力发电站的计划发电量为:",wind_power_station_strategy[i][k])
            print("****************************************************************************")
            for i in range (0,53):
                print("第",(i+1),"个火力发电站的对偶变量为:",thermal_power_station_dual_variable[i][k])
            for i in range (0,6):
                if i!=3:
                    print("第",(i+55),"个风力发电站的对偶变量为:",wind_power_station_dual_variable[i][k])
            print("****************************************************************************")
            print("第",(54),"个受到Byzantin攻击的火力发电站的初始对偶变量为:",thermal_power_station_dual_variable[53][k])
            print("第",(58),"个受到Byzantin攻击的风力发电站的初始对偶变量为:",wind_power_station_dual_variable[3][k])
            print("****************************************************************************")
            print("安全发电站的总发电量:",sum_thermal_wind_power_station_strategy[0][k])
            print("*************************")
            print("需求侧平均用电需求:",d_power_demand[k])
            print("****************************************************************************")
            print("风速分布参数c:",c_wind_speed[k])
            print("****************************************************************************")
            print("风速分布参数kappa:",kappa_wind_speed[k])
            print("****************************************************************************")        
            print("安全发电站的总发电成本：", sum_cost[0][k])
            print("****************************************************************************")
            print("原变量迭代步长为:",step_size_primal)
            print("****************************************************************************")
            print("对偶变量迭代步长为:",step_size_dual)
            print("****************************************************************************")

    print(datetime.now().strftime('%Y-%m-%d %H:%M:%S.%f')[:-3])
    return None

# %%
SCC_Byzantine_attack_decentralized_economic_dispatch(thermal_power_station_strategy,wind_power_station_strategy,c_wind_speed,kappa_wind_speed,d_power_demand,thermal_power_station_dual_variable,wind_power_station_dual_variable,E,thermal_power_station_cost,wind_power_station_cost,generator_a_values,generator_b_values,generator_c_values,thermal_power_station_P_min,thermal_power_station_P_max,wind_power_station_varphi,wind_power_station_sigma_ue,wind_power_station_sigma_oe,wind_power_station_P_min,wind_power_station_P_max,sum_thermal_wind_power_station_strategy,step_size_primal,step_size_dual)
# Out:
# ***************************large_attack_online_decentralized_economic_dispatch*****************************
# 相关变量初始值为：
# 第 1 个火力发电站的初始计划发电量为: 30.0
# 第 2 个火力发电站的初始计划发电量为: 30.0
# 第 3 个火力发电站的初始计划发电量为: 30.0
# 第 4 个火力发电站的初始计划发电量为: 300.0
# 第 5 个火力发电站的初始计划发电量为: 300.0
# 第 6 个火力发电站的初始计划发电量为: 30.0
# 第 7 个火力发电站的初始计划发电量为: 100.0
# 第 8 个火力发电站的初始计划发电量为: 30.0
# 第 9 个火力发电站的初始计划发电量为: 30.0
# 第 10 个火力发电站的初始计划发电量为: 300.0
# 第 11 个火力发电站的初始计划发电量为: 350.0
# 第 12 个火力发电站的初始计划发电量为: 30.0
# 第 13 个火力发电站的初始计划发电量为: 30.0
# 第 14 个火力发电站的初始计划发电量为: 100.0
# 第 15 个火力发电站的初始计划发电量为: 30.0
# 第 16 个火力发电站的初始计划发电量为: 100.0
# 第 17 个火力发电站的初始计划发电量为: 30.0
# 第 18 个火力发电站的初始计划发电量为: 30.0
# 第 19 个火力发电站的初始计划发电量为: 100.0
# 第 20 个火力发电站的初始计划发电量为: 250.0
# 第 21 个火力发电站的初始计划发电量为: 250.0
# 第 22 个火力发电站的初始计划发电量为: 100.0
# 第 23 个火力发电站的初始计划发电量为: 100.0
# 第 24 个火力发电站的初始计划发电量为: 200.0
# 第 25 个火力发电站的初始计划发电量为: 200.0
# 第 26 个火力发电站的初始计划发电量为: 100.0
# 第 27 个火力发电站的初始计划发电量为: 420.0
# 第 28 个火力发电站的初始计划发电量为: 420.0
# 第 29 个火力发电站的初始计划发电量为: 300.0
# 第 30 个火力发电站的初始计划发电量为: 80.0
# 第 31 个火力发电站的初始计划发电量为: 30.0
# 第 32 个火力发电站的初始计划发电量为: 30.0
# 第 33 个火力发电站的初始计划发电量为: 20.0
# 第 34 个火力发电站的初始计划发电量为: 100.0
# 第 35 个火力发电站的初始计划发电量为: 100.0
# 第 36 个火力发电站的初始计划发电量为: 300.0
# 第 37 个火力发电站的初始计划发电量为: 100.0
# 第 38 个火力发电站的初始计划发电量为: 30.0
# 第 39 个火力发电站的初始计划发电量为: 300.0
# 第 40 个火力发电站的初始计划发电量为: 200.0
# 第 41 个火力发电站的初始计划发电量为: 20.0
# 第 42 个火力发电站的初始计划发电量为: 50.0
# 第 43 个火力发电站的初始计划发电量为: 300.0
# 第 44 个火力发电站的初始计划发电量为: 300.0
# 第 45 个火力发电站的初始计划发电量为: 300.0
# 第 46 个火力发电站的初始计划发电量为: 20.0
# 第 47 个火力发电站的初始计划发电量为: 100.0
# 第 48 个火力发电站的初始计划发电量为: 100.0
# 第 49 个火力发电站的初始计划发电量为: 20.0
# 第 50 个火力发电站的初始计划发电量为: 50.0
# 第 51 个火力发电站的初始计划发电量为: 100.0
# 第 52 个火力发电站的初始计划发电量为: 100.0
# 第 55 个风力发电站的初始计划发电量为: 30.0
# 第 56 个风力发电站的初始计划发电量为: 30.0
# 第 57 个风力发电站的初始计划发电量为: 30.0
# 第 59 个风力发电站的初始计划发电量为: 300.0
# 第 60 个风力发电站的初始计划发电量为: 30.0
# ****************************************************************************
# 第 1 个火力发电站的初始对偶变量为: -1000.0
# 第 2 个火力发电站的初始对偶变量为: -1000.0
# 第 3 个火力发电站的初始对偶变量为: -1000.0
# 第 4 个火力发电站的初始对偶变量为: -1000.0
# 第 5 个火力发电站的初始对偶变量为: -1000.0
# 第 6 个火力发电站的初始对偶变量为: -1000.0
# 第 7 个火力发电站的初始对偶变量为: -1000.0
# 第 8 个火力发电站的初始对偶变量为: -1000.0
# 第 9 个火力发电站的初始对偶变量为: -1000.0
# 第 10 个火力发电站的初始对偶变量为: -1000.0
# 第 11 个火力发电站的初始对偶变量为: -1000.0
# 第 12 个火力发电站的初始对偶变量为: -1000.0
# 第 13 个火力发电站的初始对偶变量为: -1000.0
# 第 14 个火力发电站的初始对偶变量为: -1000.0
# 第 15 个火力发电站的初始对偶变量为: -1000.0
# 第 16 个火力发电站的初始对偶变量为: -1000.0
# 第 17 个火力发电站的初始对偶变量为: -1000.0
# 第 18 个火力发电站的初始对偶变量为: -1000.0
# 第 19 个火力发电站的初始对偶变量为: -1000.0
# 第 20 个火力发电站的初始对偶变量为: -1000.0
# 第 21 个火力发电站的初始对偶变量为: -1000.0
# 第 22 个火力发电站的初始对偶变量为: -1000.0
# 第 23 个火力发电站的初始对偶变量为: -1000.0
# 第 24 个火力发电站的初始对偶变量为: -1000.0
# 第 25 个火力发电站的初始对偶变量为: -1000.0
# 第 26 个火力发电站的初始对偶变量为: -1000.0
# 第 27 个火力发电站的初始对偶变量为: -1000.0
# 第 28 个火力发电站的初始对偶变量为: -1000.0
# 第 29 个火力发电站的初始对偶变量为: -1000.0
# 第 30 个火力发电站的初始对偶变量为: -1000.0
# 第 31 个火力发电站的初始对偶变量为: -1000.0
# 第 32 个火力发电站的初始对偶变量为: -1000.0
# 第 33 个火力发电站的初始对偶变量为: -1000.0
# 第 34 个火力发电站的初始对偶变量为: -1000.0
# 第 35 个火力发电站的初始对偶变量为: -1000.0
# 第 36 个火力发电站的初始对偶变量为: -1000.0
# 第 37 个火力发电站的初始对偶变量为: -1000.0
# 第 38 个火力发电站的初始对偶变量为: -1000.0
# 第 39 个火力发电站的初始对偶变量为: -1000.0
# 第 40 个火力发电站的初始对偶变量为: -1000.0
# 第 41 个火力发电站的初始对偶变量为: -1000.0
# 第 42 个火力发电站的初始对偶变量为: -1000.0
# 第 43 个火力发电站的初始对偶变量为: -1000.0
# 第 44 个火力发电站的初始对偶变量为: -1000.0
# 第 45 个火力发电站的初始对偶变量为: -1000.0
# 第 46 个火力发电站的初始对偶变量为: -1000.0
# 第 47 个火力发电站的初始对偶变量为: -1000.0
# 第 48 个火力发电站的初始对偶变量为: -1000.0
# 第 49 个火力发电站的初始对偶变量为: -1000.0
# 第 50 个火力发电站的初始对偶变量为: -1000.0
# 第 51 个火力发电站的初始对偶变量为: -1000.0
# 第 52 个火力发电站的初始对偶变量为: -1000.0
# 第 55 个风力发电站的初始对偶变量为: -1000.0
# 第 56 个风力发电站的初始对偶变量为: -1000.0
# 第 57 个风力发电站的初始对偶变量为: -1000.0
# 第 59 个风力发电站的初始对偶变量为: -1000.0
# 第 60 个风力发电站的初始对偶变量为: -1000.0
# ****************************************************************************
# 第 54 个受到Byzantin攻击的火力发电站的初始对偶变量为: -1462.97561805
# 第 58 个受到Byzantin攻击的风力发电站的初始对偶变量为: -1462.97561805
# ****************************************************************************
# 安全发电站的初始总发电量: 7590.0
# *************************
# 需求侧平均用电需求: 78.10342674
# ****************************************************************************
# 风速分布参数c: 8.36374925
# ****************************************************************************
# 风速分布参数kappa: 2.53999996
# ****************************************************************************
# 安全发电站的总发电成本： 128026.41839387035
# ****************************************************************************
# 原变量迭代步长为: 5
# *****************************************************************************
# 对偶变量迭代步长为: 5
# *****************************************************************************
# 1 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 5.0
# 第 2 个火力发电站的计划发电量为: 5.0
# 第 3 个火力发电站的计划发电量为: 5.0
# 第 4 个火力发电站的计划发电量为: 286.27083333333337
# 第 5 个火力发电站的计划发电量为: 286.27083333333337
# 第 6 个火力发电站的计划发电量为: 10.0
# 第 7 个火力发电站的计划发电量为: 81.43333333333334
# 第 8 个火力发电站的计划发电量为: 5.0
# 第 9 个火力发电站的计划发电量为: 5.0
# 第 10 个火力发电站的计划发电量为: 286.27083333333337
# 第 11 个火力发电站的计划发电量为: 350.0
# 第 12 个火力发电站的计划发电量为: 8.0
# 第 13 个火力发电站的计划发电量为: 8.0
# 第 14 个火力发电站的计划发电量为: 81.43333333333334
# 第 15 个火力发电站的计划发电量为: 8.0
# 第 16 个火力发电站的计划发电量为: 81.43333333333334
# 第 17 个火力发电站的计划发电量为: 8.0
# 第 18 个火力发电站的计划发电量为: 8.0
# 第 19 个火力发电站的计划发电量为: 81.43333333333334
# 第 20 个火力发电站的计划发电量为: 250.0
# 第 21 个火力发电站的计划发电量为: 250.0
# 第 22 个火力发电站的计划发电量为: 81.43333333333334
# 第 23 个火力发电站的计划发电量为: 81.43333333333334
# 第 24 个火力发电站的计划发电量为: 200.0
# 第 25 个火力发电站的计划发电量为: 200.0
# 第 26 个火力发电站的计划发电量为: 81.43333333333334
# 第 27 个火力发电站的计划发电量为: 417.1598333333333
# 第 28 个火力发电站的计划发电量为: 417.1598333333333
# 第 29 个火力发电站的计划发电量为: 286.27083333333337
# 第 30 个火力发电站的计划发电量为: 49.24093333333333
# 第 31 个火力发电站的计划发电量为: 10.0
# 第 32 个火力发电站的计划发电量为: 5.0
# 第 33 个火力发电站的计划发电量为: 5.0
# 第 34 个火力发电站的计划发电量为: 81.43333333333334
# 第 35 个火力发电站的计划发电量为: 81.43333333333334
# 第 36 个火力发电站的计划发电量为: 286.27083333333337
# 第 37 个火力发电站的计划发电量为: 81.43333333333334
# 第 38 个火力发电站的计划发电量为: 10.0
# 第 39 个火力发电站的计划发电量为: 300.0
# 第 40 个火力发电站的计划发电量为: 197.14583333333334
# 第 41 个火力发电站的计划发电量为: 8.0
# 第 42 个火力发电站的计划发电量为: 20.0
# 第 43 个火力发电站的计划发电量为: 286.27083333333337
# 第 44 个火力发电站的计划发电量为: 286.27083333333337
# 第 45 个火力发电站的计划发电量为: 286.27083333333337
# 第 46 个火力发电站的计划发电量为: 8.0
# 第 47 个火力发电站的计划发电量为: 81.43333333333334
# 第 48 个火力发电站的计划发电量为: 81.43333333333334
# 第 49 个火力发电站的计划发电量为: 8.0
# 第 50 个火力发电站的计划发电量为: 25.0
# 第 51 个火力发电站的计划发电量为: 81.43333333333334
# 第 52 个火力发电站的计划发电量为: 81.43333333333334
# 第 53 个火力发电站的计划发电量为: 81.43333333333334
# 第 55 个风力发电站的计划发电量为: 96.0606966394501
# 第 56 个风力发电站的计划发电量为: 45.858623968776264
# 第 57 个风力发电站的计划发电量为: 66.39186374339273
# 第 59 个风力发电站的计划发电量为: 278.3333241455708
# 第 60 个风力发电站的计划发电量为: 24.617138138286876
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -1003.958618895
# 第 2 个火力发电站的对偶变量为: -1001.590197795
# 第 3 个火力发电站的对偶变量为: -995.8395365700114
# 第 4 个火力发电站的对偶变量为: -983.0103430949999
# 第 5 个火力发电站的对偶变量为: -994.798875840839
# 第 6 个火力发电站的对偶变量为: -996.4161431137586
# 第 7 个火力发电站的对偶变量为: -995.2013178429195
# 第 8 个火力发电站的对偶变量为: -1003.2723443783333
# 第 9 个火力发电站的对偶变量为: -998.2126881804137
# 第 10 个火力发电站的对偶变量为: -995.9331198970802
# 第 11 个火力发电站的对偶变量为: -994.2122699387472
# 第 12 个火力发电站的对偶变量为: -998.9702739699999
# 第 13 个火力发电站的对偶变量为: -995.4595750908389
# 第 14 个火力发电站的对偶变量为: -998.8675158054136
# 第 15 个火力发电站的对偶变量为: -998.9667454186675
# 第 16 个火力发电站的对偶变量为: -996.6553741970805
# 第 17 个火力发电站的对偶变量为: -998.8923036533332
# 第 18 个火力发电站的对偶变量为: -1001.1380961054138
# 第 19 个火力发电站的对偶变量为: -994.2527849506167
# 第 20 个火力发电站的对偶变量为: -990.4543255574943
# 第 21 个火力发电站的对偶变量为: -991.8218568304139
# 第 22 个火力发电站的对偶变量为: -994.0654565616665
# 第 23 个火力发电站的对偶变量为: -994.0654565616667
# 第 24 个火力发电站的对偶变量为: -991.885949457494
# 第 25 个火力发电站的对偶变量为: -991.0617935449998
# 第 26 个火力发电站的对偶变量为: -986.8432341616667
# 第 27 个火力发电站的对偶变量为: -992.5192150304139
# 第 28 个火力发电站的对偶变量为: -981.2571537533333
# 第 29 个火力发电站的对偶变量为: -994.2969827741608
# 第 30 个火力发电站的对偶变量为: -1000.5293159970804
# 第 31 个火力发电站的对偶变量为: -1003.958618895
# 第 32 个火力发电站的对偶变量为: -1003.2010431449999
# 第 33 个火力发电站的对偶变量为: -1002.8424472637471
# 第 34 个火力发电站的对偶变量为: -999.1858816304137
# 第 35 个火力发电站的对偶变量为: -993.1252657241611
# 第 36 个火力发电站的对偶变量为: -985.6388633324943
# 第 37 个火力发电站的对偶变量为: -994.1690466970805
# 第 38 个火力发电站的对偶变量为: -992.1861420179196
# 第 39 个火力发电站的对偶变量为: -987.8871904199999
# 第 40 个火力发电站的对偶变量为: -996.6101440845863
# 第 41 个火力发电站的对偶变量为: -999.5062378783334
# 第 42 个火力发电站的对偶变量为: -999.5040734783335
# 第 43 个火力发电站的对偶变量为: -989.7919423304139
# 第 44 个火力发电站的对偶变量为: -981.4586090804138
# 第 45 个火力发电站的对偶变量为: -992.1252656658276
# 第 46 个火力发电站的对偶变量为: -998.1623126637472
# 第 47 个火力发电站的对偶变量为: -997.3845448616667
# 第 48 个火力发电站的对偶变量为: -1001.5115389429195
# 第 49 个火力发电站的对偶变量为: -999.7760792616668
# 第 50 个火力发电站的对偶变量为: -1000.4665653845861
# 第 51 个火力发电站的对偶变量为: -999.31576177
# 第 52 个火力发电站的对偶变量为: -999.31576177
# 第 53 个火力发电站的对偶变量为: -994.5150433262529
# 第 55 个风力发电站的对偶变量为: -1001.5902078345862
# 第 56 个风力发电站的对偶变量为: -1003.9586289345862
# 第 57 个风力发电站的对偶变量为: -998.9702639304138
# 第 59 个风力发电站的对偶变量为: -983.6808410616666
# 第 60 个风力发电站的对偶变量为: -998.5141645220805
# ****************************************************************************
# 第 54 个受到Byzantin攻击的火力发电站的初始对偶变量为: -1482.06916171
# 第 58 个受到Byzantin攻击的风力发电站的初始对偶变量为: -1482.06916171
# ****************************************************************************
# 安全发电站的总发电量: 6827.6347466354755
# *************************
# 需求侧平均用电需求: 85.73204703
# ****************************************************************************
# 风速分布参数c: 8.41212693
# ****************************************************************************
# 风速分布参数kappa: 2.44000006
# ****************************************************************************
# 安全发电站的总发电成本： 107815.48929545822
# ****************************************************************************
# 原变量迭代步长为: 5
# ****************************************************************************
# 对偶变量迭代步长为: 5
# ****************************************************************************
# 2 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 5.0
# 第 2 个火力发电站的计划发电量为: 5.0
# 第 3 个火力发电站的计划发电量为: 5.0
# 第 4 个火力发电站的计划发电量为: 272.6189087995834
# 第 5 个火力发电站的计划发电量为: 273.60128652840325
# 第 6 个火力发电站的计划发电量为: 10.0
# 第 7 个火力发电站的计划发电量为: 64.84330982024329
# 第 8 个火力发电站的计划发电量为: 5.0
# 第 9 个火力发电站的计划发电量为: 5.0
# 第 10 个火力发电站的计划发电量为: 273.69580686642337
# 第 11 个火力发电站的计划发电量为: 350.0
# 第 12 个火力发电站的计划发电量为: 8.0
# 第 13 个火力发电站的计划发电量为: 8.0
# 第 14 个火力发电站的计划发电量为: 65.14882631711781
# 第 15 个火力发电站的计划发电量为: 8.0
# 第 16 个火力发电站的计划发电量为: 64.96448118309004
# 第 17 个火力发电站的计划发电量为: 8.0
# 第 18 个火力发电站的计划发电量为: 8.0
# 第 19 个火力发电站的计划发电量为: 64.7642654125514
# 第 20 个火力发电站的计划发电量为: 250.0
# 第 21 个火力发电站的计划发电量为: 250.0
# 第 22 个火力发电站的计划发电量为: 64.74865471347219
# 第 23 个火力发电站的计划发电量为: 64.7486547134722
# 第 24 个火力发电站的计划发电量为: 200.0
# 第 25 个火力发电站的计划发电量为: 200.0
# 第 26 个火力发电站的计划发电量为: 64.14680284680557
# 第 27 个火力发电站的计划发电量为: 413.99704156920114
# 第 28 个火力发电站的计划发电量为: 413.05853646277774
# 第 29 个火力发电站的计划发电量为: 273.5594621061801
# 第 30 个火力发电站的计划发电量为: 32.651462518423365
# 第 31 个火力发电站的计划发电量为: 10.0
# 第 32 个火力发电站的计划发电量为: 5.0
# 第 33 个火力发电站的计划发电量为: 5.0
# 第 34 个火力发电站的计划发电量为: 65.17535680253448
# 第 35 个火力发电站的计划发电量为: 64.67030547701343
# 第 36 个火力发电站的计划发电量为: 272.8379521527079
# 第 37 个火力发电站的计划发电量为: 64.7572872247567
# 第 38 个火力发电站的计划发电量为: 10.0
# 第 39 个火力发电站的计划发电量为: 300.0
# 第 40 个火力发电站的计划发电量为: 194.31956929871555
# 第 41 个火力发电站的计划发电量为: 8.0
# 第 42 个火力发电站的计划发电量为: 20.0
# 第 43 个火力发电站的计划发电量为: 273.1840420692012
# 第 44 个火力发电站的计划发电量为: 272.4895976317012
# 第 45 个火力发电站的计划发电量为: 273.37848568048565
# 第 46 个火力发电站的计划发电量为: 8.0
# 第 47 个火力发电站的计划发电量为: 65.02524540513889
# 第 48 个火力发电站的计划发电量为: 65.36916157857662
# 第 49 个火力发电站的计划发电量为: 8.0
# 第 50 个火力发电站的计划发电量为: 25.0
# 第 51 个火力发电站的计划发电量为: 65.1861801475
# 第 52 个火力发电站的计划发电量为: 65.1861801475
# 第 53 个火力发电站的计划发电量为: 64.78612027718773
# 第 55 个风力发电站的计划发电量为: 105.47657109754952
# 第 56 个风力发电站的计划发电量为: 38.784132328638265
# 第 57 个风力发电站的计划发电量为: 70.90991623364457
# 第 59 个风力发电站的计划发电量为: 255.30681865008378
# 第 60 个风力发电站的计划发电量为: 26.56229342586501
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -1007.7395871647825
# 第 2 个火力发电站的对偶变量为: -1003.835666825564
# 第 3 个火力发电站的对偶变量为: -993.7422533051357
# 第 4 个火力发电站的对偶变量为: -968.7508539199578
# 第 5 个火力发电站的对偶变量为: -992.4425973327069
# 第 6 个火力发电站的对偶变量为: -994.619959336455
# 第 7 个火力发电站的对偶变量为: -993.2356875058333
# 第 8 个火力发电站的对偶变量为: -1004.8581574964801
# 第 9 个火力发电站的对偶变量为: -999.2624618609102
# 第 10 个火力发电站的对偶变量为: -994.966067706154
# 第 11 个火力发电站的对偶变量为: -992.0998072452225
# 第 12 个火力发电站的对偶变量为: -1000.1961052083823
# 第 13 个火力发电站的对偶变量为: -993.5264226714928
# 第 14 个火力发电站的对偶变量为: -997.9167372295831
# 第 15 个火力发电站的对偶变量为: -999.9879188520162
# 第 16 个火力发电站的对偶变量为: -995.4802087670814
# 第 17 个火力发电站的对偶变量为: -998.732348470779
# 第 18 个火力发电站的对偶变量为: -1002.5201368881767
# 第 19 个火力发电站的对偶变量为: -989.5967039943669
# 第 20 个火力发电站的对偶变量为: -985.7152698941484
# 第 21 个火力发电站的对偶变量为: -985.7640818924141
# 第 22 个火力发电站的对偶变量为: -988.898444295468
# 第 23 个火力发电站的对偶变量为: -988.898444295468
# 第 24 个火力发电站的对偶变量为: -984.9330214528995
# 第 25 个火力发电站的对偶变量为: -982.2260287306087
# 第 26 个火力发电站的对偶变量为: -975.200591359752
# 第 27 个火力发电站的对偶变量为: -988.2968471922446
# 第 28 个火力发电站的对偶变量为: -967.419008607699
# 第 29 个火力发电站的对偶变量为: -991.4510538704039
# 第 30 个火力发电站的对偶变量为: -1002.5583789720979
# 第 31 个火力发电站的对偶变量为: -1009.1141715472046
# 第 32 个火力发电站的对偶变量为: -1008.8588407164175
# 第 33 个火力发电站的对偶变量为: -1005.2001310434063
# 第 34 个火力发电站的对偶变量为: -999.4248239444007
# 第 35 个火力发电站的对偶变量为: -989.0347833262962
# 第 36 个火力发电站的对偶变量为: -976.5299027337147
# 第 37 个火力发电站的对偶变量为: -988.7727481699787
# 第 38 个火力发电站的对偶变量为: -986.2404422387765
# 第 39 个火力发电站的对偶变量为: -978.115105811261
# 第 40 个火力发电站的对偶变量为: -993.2086535647504
# 第 41 个火力发电站的对偶变量为: -1000.2021811365018
# 第 42 个火力发电站的对偶变量为: -999.5324743347568
# 第 43 个火力发电站的对偶变量为: -984.9926143033447
# 第 44 个火力发电站的对偶变量为: -966.7631945760623
# 第 45 个火力发电站的对偶变量为: -986.3004099492853
# 第 46 个火力发电站的对偶变量为: -998.7421370056015
# 第 47 个火力发电站的对偶变量为: -997.4275148658388
# 第 48 个火力发电站的对偶变量为: -1002.5088504293218
# 第 49 个火力发电站的对偶变量为: -1000.8392136378988
# 第 50 个火力发电站的对偶变量为: -1001.9354694668184
# 第 51 个火力发电站的对偶变量为: -1001.2964575347248
# 第 52 个火力发电站的对偶变量为: -1001.2964575347248
# 第 53 个火力发电站的对偶变量为: -991.8825322145651
# 第 55 个风力发电站的对偶变量为: -1001.8031151925998
# 第 56 个风力发电站的对偶变量为: -1006.1449497847057
# 第 57 个风力发电站的对偶变量为: -999.3249635028782
# 第 59 个风力发电站的对偶变量为: -971.028521841668
# 第 60 个风力发电站的对偶变量为: -999.0765453354966
# ****************************************************************************
# 第 54 个受到Byzantin攻击的火力发电站的初始对偶变量为: -1492.90882383
# 第 58 个受到Byzantin攻击的风力发电站的初始对偶变量为: -1492.90882383
# ****************************************************************************
# 安全发电站的总发电量: 6433.9527154865455
# *************************
# 需求侧平均用电需求: 91.70415949
# ****************************************************************************
# 风速分布参数c: 8.48068324
# ****************************************************************************
# 风速分布参数kappa: 2.42000008
# ****************************************************************************
# 安全发电站的总发电成本： 100066.80797535843
# ****************************************************************************
# 原变量迭代步长为: 5
# ****************************************************************************
# 对偶变量迭代步长为: 5
# ****************************************************************************
# 3 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 5.0
# 第 2 个火力发电站的计划发电量为: 5.0
# 第 3 个火力发电站的计划发电量为: 5.0
# 第 4 个火力发电站的计划发电量为: 259.2633402942918
# 第 5 个火力发电站的计划发电量为: 262.113196396165
# 第 6 个火力发电站的计划发电量为: 10.0
# 第 7 个火力发电站的计划发电量为: 50.213006788738255
# 第 8 个火力发电站的计划发电量为: 5.0
# 第 9 个火力发电站的计划发电量为: 5.0
# 第 10 个火力发电站的计划发电量为: 262.40772684521266
# 第 11 个火力发电站的计划发电量为: 350.0
# 第 12 个火力发电站的计划发电量为: 8.0
# 第 13 个火力发电站的计划发电量为: 8.0
# 第 14 个火力发电站的计划发电量为: 50.86950465099199
# 第 15 个火力发电站的计划发电量为: 8.0
# 第 16 个火力发电站的计划发电量为: 50.50571165557797
# 第 17 个火力发电站的计划发电量为: 8.0
# 第 18 个火力发电站的计划发电量为: 8.0
# 第 19 个火力发电站的计划发电量为: 49.84083143927538
# 第 20 个火力发电站的计划发电量为: 250.0
# 第 21 个火力发电站的计划发电量为: 250.0
# 第 22 个火力发电站的计划发电量为: 49.769030601436754
# 第 23 个火力发电站的计划发电量为: 49.76903060143677
# 第 24 个火力发电站的计划发电量为: 200.0
# 第 25 个火力发电站的计划发电量为: 200.0
# 第 26 个火力发电站的计划发电量为: 48.10272802906045
# 第 27 个火力发电站的计划发电量为: 410.8173254663765
# 第 28 个火力发电站的计划发电量为: 408.23838816867783
# 第 29 个火力发电站的计划发电量为: 261.993291758
# 第 30 个火力发电站的计划发电量为: 30.0
# 第 31 个火力发电站的计划发电量为: 10.0
# 第 32 个火力发电站的计划发电量为: 5.0
# 第 33 个火力发电站的计划发电量为: 5.0
# 第 34 个火力发电站的计划发电量为: 51.018313127176775
# 第 35 个火力发电站的计划发电量为: 49.71207165314705
# 第 36 个火力发电站的计划发电量为: 260.10681675057714
# 第 37 个火力发电站的计划发电量为: 49.76608347415273
# 第 38 个火力发电站的计划发电量为: 10.0
# 第 39 个火力发电站的计划发电量为: 300.0
# 第 40 个火力发电站的计划发电量为: 191.51720393454278
# 第 41 个火力发电站的计划发电量为: 8.0
# 第 42 个火力发电站的计划发电量为: 20.0
# 第 43 个火力发电站的计划发电量为: 261.12049535278766
# 第 44 个火力发电站的计划发电量为: 258.98245343725887
# 第 45 个火力发电站的计划发电量为: 261.40277619183996
# 第 46 个火力发电站的计划发电量为: 8.0
# 第 47 个火力发电站的计划发电量为: 50.72097356543434
# 第 48 个火力发电站的计划发电量为: 51.4443130989623
# 第 49 个火力发电站的计划发电量为: 8.0
# 第 50 个火力发电站的计划发电量为: 25.0
# 第 51 个火力发电站的计划发电量为: 51.18372054984707
# 第 52 个火力发电站的计划发电量为: 51.18372054984707
# 第 53 个火力发电站的计划发电量为: 50.0503745662548
# 第 55 个风力发电站的计划发电量为: 109.58101850795941
# 第 56 个风力发电站的计划发电量为: 42.742122776038514
# 第 57 个风力发电站的计划发电量为: 73.27517929821828
# 第 59 个风力发电站的计划发电量为: 231.22794077314785
# 第 60 个风力发电站的计划发电量为: 26.687235055685896
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -1010.4800903646152
# 第 2 个火力发电站的对偶变量为: -1005.734982575063
# 第 3 个火力发电站的对偶变量为: -992.8358028004934
# 第 4 个火力发电站的对偶变量为: -956.8876857122799
# 第 5 个火力发电站的对偶变量为: -991.7706860437775
# 第 6 个火力发电站的对偶变量为: -993.9388937210418
# 第 7 个火力发电站的对偶变量为: -992.5524549629338
# 第 8 个火力发电站的对偶变量为: -1005.931823539888
# 第 9 个火力发电站的对偶变量为: -1001.5157674701272
# 第 10 个火力发电站的对偶变量为: -995.7696228635383
# 第 11 个火力发电站的对偶变量为: -991.5301883100761
# 第 12 个火力发电站的对偶变量为: -1002.0281773517127
# 第 13 个火力发电站的对偶变量为: -992.977452328899
# 第 14 个火力发电站的对偶变量为: -998.4893192986623
# 第 15 个火力发电站的对偶变量为: -1000.6318958547074
# 第 16 个火力发电站的对偶变量为: -995.6264418194277
# 第 17 个火力发电站的对偶变量为: -998.7913538276517
# 第 18 个火力发电站的对偶变量为: -1003.2525353748516
# 第 19 个火力发电站的对偶变量为: -986.9946012030086
# 第 20 个火力发电站的对偶变量为: -982.4274808994273
# 第 21 个火力发电站的对偶变量为: -981.2832724852021
# 第 22 个火力发电站的对偶变量为: -984.6241947616709
# 第 23 个火力发电站的对偶变量为: -984.624194761671
# 第 24 个火力发电站的对偶变量为: -978.9850884287516
# 第 25 个火力发电站的对偶变量为: -974.0832529955827
# 第 26 个火力发电站的对偶变量为: -965.44573906703
# 第 27 个火力发电站的对偶变量为: -985.7626397269731
# 第 28 个火力发电站的对偶变量为: -957.287409791858
# 第 29 个火力发电站的对偶变量为: -990.9914168976846
# 第 30 个火力发电站的对偶变量为: -1005.0143048243333
# 第 31 个火力发电站的对偶变量为: -1014.2215624480416
# 第 32 个火力发电站的对偶变量为: -1014.4047621978726
# 第 33 个火力发电站的对偶变量为: -1007.2176512482957
# 第 34 个火力发电站的对偶变量为: -1000.7276446706921
# 第 35 个火力发电站的对偶变量为: -986.6644769076873
# 第 36 个火力发电站的对偶变量为: -971.0556047533815
# 第 37 个火力发电站的对偶变量为: -984.9632067057129
# 第 38 个火力发电站的对偶变量为: -980.924588891416
# 第 39 个火力发电站的对偶变量为: -969.9343840072993
# 第 40 个火力发电站的对偶变量为: -990.7510263502968
# 第 41 个火力发电站的对偶变量为: -1000.0254171798889
# 第 42 个火力发电站的对偶变量为: -999.6461131427748
# 第 43 个火力发电站的对偶变量为: -981.7082926983308
# 第 44 个火力发电站的对偶变量为: -955.7423781604907
# 第 45 个火力发电站的对偶变量为: -982.9884676312687
# 第 46 个火力发电站的对偶变量为: -999.8813188804777
# 第 47 个火力发电站的对偶变量为: -998.5940064219963
# 第 48 个火力发电站的对偶变量为: -1004.324072585069
# 第 49 个火力发电站的对偶变量为: -1001.9885411489802
# 第 50 个火力发电站的对偶变量为: -1004.7705245114429
# 第 51 个火力发电站的对偶变量为: -1004.5956038628485
# 第 52 个火力发电站的对偶变量为: -1004.5956038628485
# 第 53 个火力发电站的对偶变量为: -990.9779385861876
# 第 55 个风力发电站的对偶变量为: -1002.7341054255526
# 第 56 个风力发电站的对偶变量为: -1008.4798621561058
# 第 57 个风力发电站的对偶变量为: -1000.4374241616948
# 第 59 个风力发电站的对偶变量为: -961.865313675171
# 第 60 个风力发电站的对偶变量为: -1000.3907867085801
# ****************************************************************************
# 第 54 个受到Byzantin攻击的火力发电站的初始对偶变量为: -1548.8257111
# 第 58 个受到Byzantin攻击的风力发电站的初始对偶变量为: -1548.8257111
# ****************************************************************************
# 安全发电站的总发电量: 6089.625925358118
# *************************
# 需求侧平均用电需求: 92.81865565
# ****************************************************************************
# 风速分布参数c: 8.49440173
# ****************************************************************************
# 风速分布参数kappa: 2.4000001
# ****************************************************************************
# 安全发电站的总发电成本： 93436.58548835652
# ****************************************************************************
# 原变量迭代步长为: 5
# ****************************************************************************
# 对偶变量迭代步长为: 5
# ****************************************************************************
# 4 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 5.0
# 第 2 个火力发电站的计划发电量为: 5.0
# 第 3 个火力发电站的计划发电量为: 5.0
# 第 4 个火力发电站的计划发电量为: 246.3715925133109
# 第 5 个火力发电站的计划发电量为: 251.81844345839684
# 第 6 个火力发电站的计划发电量为: 10.0
# 第 7 个火力发电站的计划发电量为: 37.398446500024235
# 第 8 个火力发电站的计划发电量为: 5.0
# 第 9 个火力发电站的计划发电量为: 5.0
# 第 10 个火力发电站的计划发电量为: 252.41418845609064
# 第 11 个火力发电站的计划发电量为: 350.0
# 第 12 个火力发电站的计划发电量为: 8.0
# 第 13 个火力发电站的计划发电量为: 8.0
# 第 14 个火力发电站的计划发电量为: 38.46565133055353
# 第 15 个火力发电站的计划发电量为: 8.0
# 第 16 个火力发电站的计划发电量为: 37.90985071528296
# 第 17 个火力发电站的计划发电量为: 8.0
# 第 18 个火力发电站的计划发电量为: 8.0
# 第 19 个火力发电站的计划发电量为: 36.61075511529884
# 第 20 个火力发电站的计划发电量为: 250.0
# 第 21 个火力发电站的计划发电量为: 250.0
# 第 22 个火力发电站的计划发电量为: 36.35061091459209
# 第 23 个火力发电站的计划发电量为: 36.350610914592124
# 第 24 个火力发电站的计划发电量为: 200.0
# 第 25 个火力发电站的计划发电量为: 200.0
# 第 26 个火力发电站的计划发电量为: 33.299390430259876
# 第 27 个火力发电站的计划发电量为: 407.76315734340164
# 第 28 个火力发电站的计划发电量为: 403.08439367760303
# 第 29 个火力发电站的计划发电量为: 251.64663935412455
# 第 30 个火力发电站的计划发电量为: 30.0
# 第 31 个火力发电站的计划发电量为: 10.0
# 第 32 个火力发电站的计划发电量为: 5.0
# 第 33 个火力发电站的计划发电量为: 5.0
# 第 34 个火力发电站的计划发电量为: 38.7819394361225
# 第 35 个火力发电站的计划发电量为: 36.470966223851505
# 第 36 个火力发电站的计划发电量为: 248.304000825067
# 第 37 个火力发电站的计划发电量为: 36.37629201493726
# 第 38 个火力发电站的计划发电量为: 10.0
# 第 39 个火力发电站的计划发电量为: 300.0
# 第 40 个火力发电站的计划发电量为: 188.81479353585266
# 第 41 个火力发电站的计划发电量为: 8.0
# 第 42 个火力发电站的计划发电量为: 20.0
# 第 43 个火力发电站的计划发电量为: 250.09516587469957
# 第 44 个火力发电站的计划发电量为: 246.02580980599788
# 第 45 个火力发电站的计划发电量为: 250.45342991691643
# 第 46 个火力发电站的计划发电量为: 8.0
# 第 47 个火力发电站的计划发电量为: 38.34485615089177
# 第 48 个火力发电站的计划发电量为: 39.453113737717544
# 第 49 个火力发电站的计划发电量为: 8.0
# 第 50 个火力发电站的计划发电量为: 25.0
# 第 51 个火力发电站的计划发电量为: 39.24850464137069
# 第 52 个火力发电站的计划发电量为: 39.24850464137069
# 第 53 个火力发电站的计划发电量为: 37.12542150395649
# 第 55 个风力发电站的计划发电量为: 111.5900246208983
# 第 56 个风力发电站的计划发电量为: 41.361207368161814
# 第 57 个风力发电站的计划发电量为: 74.50607915011811
# 第 59 个风力发电站的计划发电量为: 206.40169909410713
# 第 60 个风力发电站的计划发电量为: 26.72220579698834
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -1012.4837340395113
# 第 2 个火力发电站的对偶变量为: -1007.3123995767307
# 第 3 个火力发电站的对偶变量为: -992.4680666845114
# 第 4 个火力发电站的对偶变量为: -946.9097911933111
# 第 5 个火力发电站的对偶变量为: -991.8899507618456
# 第 6 个火力发电站的对偶变量为: -993.9233695677287
# 第 7 个火力发电站的对偶变量为: -992.5974629693649
# 第 8 个火力发电站的对偶变量为: -1006.7754827738588
# 第 9 个火力发电站的对偶变量为: -1004.0464543029623
# 第 10 个火力发电站的对偶变量为: -997.3661059104526
# 第 11 个火力发电站的对偶变量为: -991.6958939868182
# 第 12 个火力发电站的对偶变量为: -1003.9758041463848
# 第 13 个火力发电站的对偶变量为: -993.1841105043835
# 第 14 个火力发电站的对偶变量为: -999.8851062307131
# 第 15 个火力发电站的对偶变量为: -1001.1609559940293
# 第 16 个火力发电站的对偶变量为: -996.2617485410601
# 第 17 个火力发电站的对偶变量为: -998.9504703646145
# 第 18 个火力发电站的对偶变量为: -1003.3695312124689
# 第 19 个火力发电站的对偶变量为: -985.9057331857352
# 第 20 个火力发电站的对偶变量为: -980.0974651781105
# 第 21 个火力发电站的对偶变量为: -977.4999949126545
# 第 22 个火力发电站的对偶变量为: -980.9185119424235
# 第 23 个火力发电站的对偶变量为: -980.9185119424235
# 第 24 个火力发电站的对偶变量为: -973.7604070617065
# 第 25 个火力发电站的对偶变量为: -966.6487972060106
# 第 26 个火力发电站的对偶变量为: -957.2049084180784
# 第 27 个火力发电站的对偶变量为: -984.1751568352054
# 第 28 个火力发电站的对偶变量为: -949.4689283923649
# 第 29 个火力发电站的对偶变量为: -991.1354084180263
# 第 30 个火力发电站的对偶变量为: -1007.5693563767921
# 第 31 个火力发电站的对偶变量为: -1019.0780774739117
# 第 32 个火力发电站的对偶变量为: -1019.3462619850942
# 第 33 个火力发电站的对偶变量为: -1008.8992578137131
# 第 34 个火力发电站的对偶变量为: -1002.607887538925
# 第 35 个火力发电站的对偶变量为: -985.6395828839596
# 第 36 个火力发电站的对偶变量为: -967.5749090914385
# 第 37 个火力发电站的对偶变量为: -982.1591544085195
# 第 38 个火力发电站的对偶变量为: -976.3790353538193
# 第 39 个火力发电站的对偶变量为: -962.6654388497561
# 第 40 个火力发电站的对偶变量为: -988.3115489493744
# 第 41 个火力发电站的对偶变量为: -999.4727723825931
# 第 42 个火力发电站的对偶变量为: -999.3014665726218
# 第 43 个火力发电站的对偶变量为: -979.5831506650566
# 第 44 个火力发电站的对偶变量为: -947.7946844452478
# 第 45 个火力发电站的对偶变量为: -980.993774110379
# 第 46 个火力发电站的对偶变量为: -1001.7088238774338
# 第 47 个火力发电站的对偶变量为: -1000.3277154376682
# 第 48 个火力发电站的对偶变量为: -1006.2862929433869
# 第 49 个火力发电站的对偶变量为: -1003.2907332078054
# 第 50 个火力发电站的对偶变量为: -1008.2534362187434
# 第 51 个火力发电站的对偶变量为: -1008.688348764926
# 第 52 个火力发电站的对偶变量为: -1008.688348764926
# 第 53 个火力发电站的对偶变量为: -991.0774711177896
# 第 55 个风力发电站的对偶变量为: -1003.7892871744142
# 第 56 个风力发电站的对偶变量为: -1010.259444145408
# 第 57 个风力发电站的对偶变量为: -1002.0050775067041
# 第 59 个风力发电站的对偶变量为: -955.606345942947
# 第 60 个风力发电站的对偶变量为: -1001.9508717845553
# ****************************************************************************
# 第 54 个受到Byzantin攻击的火力发电站的初始对偶变量为: -1550.41113486
# 第 58 个受到Byzantin攻击的风力发电站的初始对偶变量为: -1550.41113486
# ****************************************************************************
# 安全发电站的总发电量: 5772.807745062556
# *************************
# 需求侧平均用电需求: 107.71966101
# ****************************************************************************
# 风速分布参数c: 8.52563694
# ****************************************************************************
# 风速分布参数kappa: 2.4000001
# ****************************************************************************
# 安全发电站的总发电成本： 87428.5839607009
# ****************************************************************************
# 原变量迭代步长为: 5
# ****************************************************************************
# 对偶变量迭代步长为: 5
# ****************************************************************************
# 5 次迭代中的结果：
# 第 1 个火力发电站的计划发电量为: 5.0
# 第 2 个火力发电站的计划发电量为: 5.0
# 第 3 个火力发电站的计划发电量为: 5.0
# 第 4 个火力发电站的计划发电量为: 234.0503310935976
# 第 5 个火力发电站的计划发电量为: 242.65318362911665
# 第 6 个火力发电站的计划发电量为: 10.0
# 第 7 个火力发电站的计划发电量为: 26.227900595468213
# 第 8 个火力发电站的计划发电量为: 5.0
# 第 9 个火力发电站的计划发电量为: 5.0
# 第 10 个火力发电站的计划发电量为: 243.64048762069515
# 第 11 个火力发电站的计划发电量为: 350.0
# 第 12 个火力发电站的计划发电量为: 8.0
# 第 13 个火力发电站的计划发电量为: 8.0
# 第 14 个火力发电站的计划发电量为: 27.765806812802094
# 第 15 个火力发电站的计划发电量为: 8.0
# 第 16 个火力发电站的计划发电量为: 26.97920220214842
# 第 17 个火力发电站的计划发电量为: 8.0
# 第 18 个火力发电站的计划发电量为: 8.0
# 第 19 个火力发电站的计划发电量为: 25.0
# 第 20 个火力发电站的计划发电量为: 250.0
# 第 21 个火力发电站的计划发电量为: 250.0
# 第 22 个火力发电站的计划发电量为: 25.0
# 第 23 个火力发电站的计划发电量为: 25.0
# 第 24 个火力发电站的计划发电量为: 200.0
# 第 25 个火力发电站的计划发电量为: 200.0
# 第 26 个火力发电站的计划发电量为: 25.0
# 第 27 个火力发电站的计划发电量为: 404.9001353836692
# 第 28 个火力发电站的计划发电量为: 397.8246670865086
# 第 29 个火力发电站的计划发电量为: 242.43718469253236
# 第 30 个火力发电站的计划发电量为: 30.0
# 第 31 个火力发电站的计划发电量为: 10.0
# 第 32 个火力发电站的计划发电量为: 5.0
# 第 33 个火力发电站的计划发电量为: 5.0
# 第 34 个火力发电站的计划发电量为: 28.26850848320924
# 第 35 个火力发电站的计划发电量为: 25.0
# 第 36 个火力发电站的计划发电量为: 237.4946831596275
# 第 37 个火力发电站的计划发电量为: 25.0
# 第 38 个火力发电站的计划发电量为: 10.0
# 第 39 个火力发电站的计划发电量为: 300.0
# 第 40 个火力发电站的计划发电量为: 186.20298048460987
# 第 41 个火力发电站的计划发电量为: 8.0
# 第 42 个火力发电站的计划发电量为: 20.0
# 第 43 个火力发电站的计划发电量为: 240.09174580791404
# 第 44 个火力发电站的计划发电量为: 233.81589336003293
# 第 45 个火力发电站的计划发电量为: 240.5286005893167
# 第 46 个火力发电站的计划发电量为: 8.0
# 第 47 个火力发电站的计划发电量为: 27.697357516716647
# 第 48 个火力发电站的计划发电量为: 29.160306257905273
# 第 49 个火力发电站的计划发电量为: 8.0
# 第 50 个火力发电站的计划发电量为: 25.0
# 第 51 个火力发电站的计划发电量为: 29.182058444352396
# 第 52 个火力发电站的计划发电量为: 29.182058444352396
# 第 53 个火力发电站的计划发电量为: 25.863156811265853
# 第 55 个风力发电站的计划发电量为: 112.86537940167156
# 第 56 个风力发电站的计划发电量为: 42.54568942625333
# 第 57 个风力发电站的计划发电量为: 75.4266268694571
# 第 59 个风力发电站的计划发电量为: 181.14433150974634
# 第 60 个风力发电站的计划发电量为: 27.343406245171096
# ****************************************************************************
# 第 1 个火力发电站的对偶变量为: -1015.2679019289058
# 第 2 个火力发电站的对偶变量为: -1009.903494874729
# 第 3 个火力发电站的对偶变量为: -993.7210098755038
# 第 4 个火力发电站的对偶变量为: -939.8371042564305
# 第 5 个火力发电站的对偶变量为: -993.7189398288915
# 第 6 个火力发电站的对偶变量为: -995.5824060109244
# 第 7 个火力发电站的对偶变量为: -994.378065074418
# 第 8 个火力发电站的对偶变量为: -1008.9068466890458
# 第 9 个火力发电站的对偶变量为: -1008.0183162179155
# 第 10 个火力发电站的对偶变量为: -1000.5957995816622
# 第 11 个火力发电站的对偶变量为: -993.5643194415403
# 第 12 个火力发电站的对偶变量为: -1007.3116582286154
# 第 13 个火力发电站的对偶变量为: -995.165119339752
# 第 14 个火力发电站的对偶变量为: -1002.9679196076787
# 第 15 个火力发电站的对偶变量为: -1002.9648679460431
# 第 16 个火力发电站的对偶变量为: -998.3742993721065
# 第 17 个火力发电站的对偶变量为: -1000.455664129625
# 第 18 个火力发电站的对偶变量为: -1004.3574429614924
# 第 19 个火力发电站的对偶变量为: -987.1116805594881
# 第 20 个火力发电站的对偶变量为: -979.5657441279786
# 第 21 个火力发电站的对偶变量为: -975.4919445355247
# 第 22 个火力发电站的对偶变量为: -978.9015234162484
# 第 23 个火力发电站的对偶变量为: -978.9015234162484
# 第 24 个火力发电站的对偶变量为: -970.4325922846243
# 第 25 个火力发电站的对偶变量为: -961.288260361969
# 第 26 个火力发电站的对偶变量为: -951.4829048938032
# 第 27 个火力发电站的对偶变量为: -984.4443963421606
# 第 28 个火力发电站的对偶变量为: -944.5764414383325
# 第 29 个火力发电站的对偶变量为: -993.0272121300891
# 第 30 个火力发电站的对偶变量为: -1011.2487590041101
# 第 31 个火力发电站的对偶变量为: -1024.7872356203845
# 第 32 个火力发电站的对偶变量为: -1025.0613949594226
# 第 33 个火力发电站的对偶变量为: -1011.7449820798095
# 第 34 个火力发电站的对偶变量为: -1006.1291790294094
# 第 35 个火力发电站的对偶变量为: -986.7225476567644
# 第 36 个火力发电站的对偶变量为: -966.8447022350263
# 第 37 个火力发电站的对偶变量为: -981.4818257924553
# 第 38 个火力发电站的对偶变量为: -973.5983755973886
# 第 39 个火力发电站的对偶变量为: -957.4166805836273
# 第 40 个火力发电站的对偶变量为: -987.3310745962356
# 第 41 个火力发电站的对偶变量为: -999.7703758178503
# 第 42 个火力发电站的对偶变量为: -999.9587327372578
# 第 43 个火力发电站的对偶变量为: -979.3224213716617
# 第 44 个火力发电站的对偶变量为: -943.6126526980663
# 第 45 个火力发电站的对偶变量为: -981.3147975853847
# 第 46 个火力发电站的对偶变量为: -1005.2182354441823
# 第 47 个火力发电站的对偶变量为: -1003.6692589780594
# 第 48 个火力发电站的对偶变量为: -1009.707241982926
# 第 49 个火力发电站的对偶变量为: -1005.9907820889443
# 第 50 个火力发电站的对偶变量为: -1013.5268768295391
# 第 51 个火力发电站的对偶变量为: -1014.5588396441628
# 第 52 个火力发电站的对偶变量为: -1014.5588396441628
# 第 53 个火力发电站的对偶变量为: -993.0525828403614
# 第 55 个风力发电站的对偶变量为: -1006.0838258431729
# 第 56 个风力发电站的对偶变量为: -1013.2332194346398
# 第 57 个风力发电站的对偶变量为: -1005.0911546527725
# 第 59 个风力发电站的对偶变量为: -953.2274129293348
# 第 60 个风力发电站的对偶变量为: -1004.9273131340829
# ****************************************************************************
# 第 54 个受到Byzantin攻击的火力发电站的初始对偶变量为: -1482.72775826
# 第 58 个受到Byzantin攻击的风力发电站的初始对偶变量为: -1482.72775826
# ****************************************************************************
# 安全发电站的总发电量: 5497.291681928141
# *************************
# 需求侧平均用电需求: 82.47730833
# ****************************************************************************
# 风速分布参数c: 8.5565076
# ****************************************************************************
# 风速分布参数kappa: 2.38000011
# ****************************************************************************
# 安全发电站的总发电成本： 82272.16949883552
# ****************************************************************************
# 原变量迭代步长为: 5
# ****************************************************************************
# 对偶变量迭代步长为: 5
# ****************************************************************************
# 2024-07-30 17:03:50.657

# %%
#数据存储
np.savetxt('./data/04_SCC_optimal_parameters_small_Gaussian_Byzantine_attack_sum_cost.txt',sum_cost,fmt='%0.8f')
np.savetxt('./data/04_SCC_optimal_parameters_small_Gaussian_Byzantine_attack_sum_thermal_wind_power_station_strategy.txt',sum_thermal_wind_power_station_strategy,fmt='%0.8f')

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
from sympy import *
import math 
from datetime import datetime
from scipy.special import gamma, factorial
import scipy.special as sc

# %%
sum_cost=np.loadtxt("./data/04_SCC_optimal_parameters_small_Gaussian_Byzantine_attack_sum_cost.txt")
optimal_sum_cost=np.loadtxt("./data/00_optimal_sum_cost_varying_D_c_kappa_normal_distribution_(100,10).txt")

# %%
dynamic_regret=[]
dynamic_regret_T=[]
for T in range(1, 1000):
    dynamic_regret_auxiliary_variable=0
    for t in range(0, T):
        dynamic_regret_auxiliary_variable=dynamic_regret_auxiliary_variable+sum_cost[t+1]-optimal_sum_cost[t+1]
    dynamic_regret.append(dynamic_regret_auxiliary_variable)
    dynamic_regret_T.append((dynamic_regret_auxiliary_variable)/T)

# %%
dynamic_regret
# Out:
# [34923.03850531,
#  56131.93970663,
#  69559.74409372998,
#  60935.23059249997,
#  73522.27774132995,
#  51599.02899457993,
#  46250.49773077994,
#  30407.960823499932,
#  35930.509008409936,
#  14906.152387609924,
#  -8212.642157800074,
#  -42423.903308790075,
#  -70566.14906074008,
#  -88690.91540180008,
#  -118280.18084520008,
#  -136614.7488220801,
#  -143392.75040636008,
#  -164703.77475530008,
#  -163227.52533647008,
#  -172702.04743762006,
#  -224090.02981301007,
#  -230492.25537122006,
#  -248784.84011709006,
#  -269715.96629652,
#  -279319.91009476,
#  -295231.94081344,
#  -324076.93595375004,
#  -345492.53950738005,
#  -365936.5855571101,
#  -391397.62006479007,
#  -424840.7913876601,
#  -444609.88177888,
#  -448703.5077130201,
#  -471177.3959093401,
#  -460407.95927560015,
#  -488088.2483746401,
#  -510988.4490690401,
#  -519838.5463656701,
#  -524963.3776909001,
#  -544393.1860233801,
#  -562551.1407057001,
#  -579420.3418866901,
#  -586388.3799762501,
#  -628442.1121508201,
#  -648887.9573524101,
#  -664001.6579238801,
#  -674123.8905740702,
#  -696915.0787451501,
#  -723280.7530474701,
#  -728225.1107155201,
#  -736036.9951463001,
#  -742494.02563587,
#  -740107.4897733,
#  -752209.6666701001,
#  -750765.3976046601,
#  -757589.3360795202,
#  -750676.9757839801,
#  -759493.4069616802,
#  -781675.5495569501,
#  -773626.0563601101,
#  -787942.80572336,
#  -804609.05879179,
#  -801948.7849946,
#  -795543.8271902199,
#  -809636.0129610399,
#  -812043.8912618399,
#  -824943.3062971999,
#  -835462.6614027899,
#  -842596.1424253999,
#  -833272.8690283599,
#  -830480.79183492,
#  -831252.1880100799,
#  -830467.4203260898,
#  -850339.3047485598,
#  -854650.6913575499,
#  -871716.6575602199,
#  -883413.5580794798,
#  -872694.4534453298,
#  -861057.6623231698,
#  -858085.9410537598,
#  -861248.2161111698,
#  -861615.8088835299,
#  -862568.6934322398,
#  -855140.1566868698,
#  -861104.7586276599,
#  -859214.7168277799,
#  -875356.6185244299,
#  -865984.7483568199,
#  -864503.2696453299,
#  -868931.0151296599,
#  -876404.8826556199,
#  -871986.6479671099,
#  -879100.0061993198,
#  -884244.6214835899,
#  -884563.1497770199,
#  -897933.4830428698,
#  -900197.9214930699,
#  -906324.2857099599,
#  -910075.8376030899,
#  -884548.8664450399,
#  -889932.7932911199,
#  -891012.6857541398,
#  -895483.5669625797,
#  -897721.6537760998,
#  -896545.2809122697,
#  -886058.6074213998,
#  -884565.0339871597,
#  -885643.7016720898,
#  -914389.9243004498,
#  -911039.3371770798,
#  -894585.1753770397,
#  -898603.3507971298,
#  -897297.1014686998,
#  -881319.3290852099,
#  -887314.21552415,
#  -879149.23745601,
#  -862552.80900561,
#  -858028.64254023,
#  -862354.68487203,
#  -873692.1744755601,
#  -849485.4290666501,
#  -836409.3395431502,
#  -816312.4993693301,
#  -830924.4883459901,
#  -836507.57889352,
#  -845428.83218266,
#  -819765.73791318,
#  -829977.25283722,
#  -810775.00668963,
#  -809314.87583918,
#  -803853.5613181,
#  -787565.21540586,
#  -781338.2095826799,
#  -790875.1692255998,
#  -797300.3977146299,
#  -782756.6516675199,
#  -788465.2472271099,
#  -781945.3737285199,
#  -777577.4458347998,
#  -777374.0381758298,
#  -791000.7147371898,
#  -802517.1679974498,
#  -777679.8547839198,
#  -770105.0553761898,
#  -781113.3801233897,
#  -775908.4709528596,
#  -773198.8869659196,
#  -763367.6288664496,
#  -760912.2496998495,
#  -746735.0167077795,
#  -747754.1728002495,
#  -739439.4584620596,
#  -735012.5852919096,
#  -719484.1913544897,
#  -717662.3651782697,
#  -692952.1724411797,
#  -682968.0722134897,
#  -657004.1113168097,
#  -642023.6842414397,
#  -640842.4284900797,
#  -631813.3128755197,
#  -626170.7948802697,
#  -614497.6803818396,
#  -637763.7888290696,
#  -643347.1723918496,
#  -660951.7176905596,
#  -647261.8153665696,
#  -634285.0331227696,
#  -628989.3508298995,
#  -635541.7437966894,
#  -616598.9280060594,
#  -591213.5143537094,
#  -594724.0290519295,
#  -578862.1129474496,
#  -575839.6119962395,
#  -563404.7070446695,
#  -562656.7810718796,
#  -556363.8325966195,
#  -538161.3409853495,
#  -520192.2520230895,
#  -518138.84563210956,
#  -516375.4548212995,
#  -525684.4429508796,
#  -530908.6880659196,
#  -520952.91895843955,
#  -518072.25572345953,
#  -524482.4225354395,
#  -525060.6085786695,
#  -519066.1252859795,
#  -495029.0221484295,
#  -488088.7261854195,
#  -452342.6045028695,
#  -453721.88264758943,
#  -444190.09049530944,
#  -427618.0773179194,
#  -425711.4836355294,
#  -429608.54509137943,
#  -410525.6427474695,
#  -391050.33816207945,
#  -367882.4011124695,
#  -351043.4364982295,
#  -345914.8732428595,
#  -358204.5760992395,
#  -349486.62069093954,
#  -358810.7689692995,
#  -350611.4687741495,
#  -330792.6784521695,
#  -322120.7479826895,
#  -309630.26046654955,
#  -289811.34066162957,
#  -284333.47851182957,
#  -273058.08168591955,
#  -255523.54799769958,
#  -237701.69046198958,
#  -244334.11946293956,
#  -229329.47586513957,
#  -213616.1573150796,
#  -203719.1818613496,
#  -210743.2583157596,
#  -192851.6995840896,
#  -174963.90842767962,
#  -157902.02657591962,
#  -143488.52537982963,
#  -150699.67144675963,
#  -129741.92395398964,
#  -124988.53979083964,
#  -107816.33047320964,
#  -95863.52483299964,
#  -91280.10342106964,
#  -80509.60779751964,
#  -71384.21686502964,
#  -72230.85992341963,
#  -60841.84069837963,
#  -39446.84273217963,
#  -31087.84038384963,
#  -19237.06542391963,
#  1045.8021500703762,
#  5095.534054200383,
#  12207.367171670383,
#  9033.627381420389,
#  23439.029094420388,
#  32710.762293060397,
#  30561.640930480396,
#  24765.42461915039,
#  12321.000075570395,
#  7639.965728530384,
#  20348.93817880038,
#  31718.27817886039,
#  25536.500326910376,
#  36629.00636024038,
#  46947.65674334038,
#  40226.559904130394,
#  43693.9833903704,
#  54235.36896417041,
#  66395.65531226041,
#  80286.0351808604,
#  75199.76859727039,
#  78690.2644501504,
#  85347.2982228204,
#  91825.34019002039,
#  106108.20206372037,
#  95827.37173291038,
#  108561.44353812038,
#  122045.82548546036,
#  137627.90048958035,
#  151076.44291924036,
#  160307.54018194036,
#  165398.88809418035,
#  170148.18169423036,
#  183973.1259257804,
#  178115.81861576042,
#  178458.49878397043,
#  186597.07810599043,
#  203661.2738265304,
#  210110.2487661704,
#  220018.2749837204,
#  220905.42686442035,
#  220371.3228023104,
#  211599.28867733036,
#  233431.85659454035,
#  230486.42269510034,
#  225162.2009341703,
#  239049.6264333303,
#  243887.56263962033,
#  251280.04090656037,
#  275232.3390687204,
#  285725.14705194044,
#  271637.2362487304,
#  289241.30532462045,
#  297393.3595493704,
#  276941.66526784044,
#  279786.4914520705,
#  304087.72349434043,
#  326599.3957623804,
#  326356.10097485036,
#  309114.6083302103,
#  332004.61054081033,
#  328533.2856308203,
#  318503.8235485603,
#  338773.1510906103,
#  347331.8463506403,
#  360454.73111687024,
#  374766.31073904026,
#  402427.83814963023,
#  418445.45406313025,
#  432787.30667739024,
#  422446.4603367903,
#  417661.8810573503,
#  429485.41844981036,
#  428834.0947647903,
#  450414.3376121103,
#  468990.1226533303,
#  464355.7650348503,
#  475627.3504211203,
#  463347.08726860024,
#  451165.9879983702,
#  451693.71346363024,
#  455273.2973705803,
#  459221.9082377503,
#  460355.84559178026,
#  455424.7069543703,
#  472428.41012954037,
#  507737.4427174604,
#  496389.33907338034,
#  514632.6208389703,
#  527174.1229154302,
#  536291.0708118002,
#  539229.4063910502,
#  549644.1395748402,
#  543954.0553784502,
#  554055.7749176603,
#  568604.7378337103,
#  568806.9325061603,
#  595332.6332310704,
#  613462.4218322403,
#  618085.6126521503,
#  620094.9655068703,
#  640821.5059875103,
#  654497.7493611203,
#  675842.1398528704,
#  675821.0889783903,
#  668827.7138745904,
#  648735.8685590404,
#  656602.9179920004,
#  658092.3499529003,
#  660616.1591332803,
#  661120.0567851702,
#  677277.2179951502,
#  670135.2191803702,
#  667294.9986967202,
#  666719.5292904002,
#  670561.7129268902,
#  682097.4209097403,
#  693804.5253091003,
#  699025.3417551303,
#  708973.8867978203,
#  683810.5750348403,
#  679448.8342622003,
#  688928.3143072103,
#  708458.8411176403,
#  696747.5037382703,
#  704199.2134364803,
#  718033.5475303702,
#  710256.9882443502,
#  717460.4219718501,
#  721307.8042015901,
#  747130.8691112502,
#  769333.3086245502,
#  796699.7963687503,
#  801594.0696958103,
#  829445.8680532003,
#  840965.1357948002,
#  859822.1747994802,
#  884662.9469390502,
#  904938.5697673103,
#  904002.3629496404,
#  930966.2627156004,
#  952966.9305468304,
#  980246.8503403803,
#  981385.1533586204,
#  986099.0306578904,
#  996935.8138859004,
#  1005093.9741261306,
#  1017024.7492521605,
#  1030100.0958756604,
#  1047441.1149278103,
#  1061488.7415821203,
#  1065111.7319552703,
#  1060818.3900063802,
#  1074649.92079237,
#  1098790.75265691,
#  1119158.7406456103,
#  1131952.5722767904,
#  1140563.0953645504,
#  1166966.9072931004,
#  1178815.8500974304,
#  1193540.0843008803,
#  1195737.3574681003,
#  1203775.1214746803,
#  1216070.8858952601,
#  1223194.4451412302,
#  1223913.7098304203,
#  1241344.7327742805,
#  1249354.8799068306,
#  1259559.6038668205,
#  1263792.0134652106,
#  1286734.3946362105,
#  1292528.2925726804,
#  1290359.1377257204,
#  1294807.2176720605,
#  1293408.5026130504,
#  1274164.8491826805,
#  1298574.9889865804,
#  1302639.6379994203,
#  1289201.2665459202,
#  1312576.6168589701,
#  1308003.9825281901,
#  1293711.3392829902,
#  1286428.83846526,
#  1292977.20256672,
#  1294263.9253339001,
#  1299815.9797389603,
#  1306910.0624421905,
#  1301216.1540908306,
#  1310129.4406717706,
#  1325953.0410549007,
#  1326324.3968872908,
#  1327624.1506074308,
#  1313024.0938379809,
#  1314100.4813165208,
#  1318149.228946971,
#  1324822.308499851,
#  1334441.801994881,
#  1328170.065328671,
#  1339244.706405941,
#  1324499.612506221,
#  1326070.867494961,
#  1333412.4608786812,
#  1332833.156206041,
#  1330899.458105541,
#  1347429.691673741,
#  1351747.439669521,
#  1366899.445306571,
#  1363276.753465751,
#  1367342.354899951,
#  1376713.555174341,
#  1388470.338032451,
#  1392793.3122831709,
#  1390467.047373191,
#  1419527.772583851,
#  1440596.854742881,
#  1463086.039533671,
#  1479428.738014111,
#  1470269.121588191,
#  1501242.5514284312,
#  1505153.843529161,
#  1512786.8933898911,
#  1525473.581314891,
#  1528901.594535601,
#  1534907.9416443012,
#  1552295.3432336112,
#  1545366.5778883912,
#  1557038.8790210513,
#  1569808.3081947814,
#  1581660.4705115412,
#  1574097.6478610213,
#  1584476.7141601513,
#  1602613.7314252213,
#  1606371.6989605115,
#  1629133.4577648016,
#  1633898.9080243416,
#  1618749.6630787216,
#  1633542.4009398015,
#  1646387.4229259316,
#  1668665.8307632115,
#  1688022.7158904115,
#  1689874.7922506616,
#  1694737.2595016116,
#  1694812.4706129115,
#  1700298.3633105315,
#  1719395.8632539215,
#  1707148.0147564115,
#  1707576.0428348414,
#  1714446.7932466315,
#  1709080.2861627217,
#  1715688.8619978216,
#  1742423.2706644917,
#  1736037.1729513817,
#  1749589.0391015515,
#  1740418.5394370814,
#  1768928.5795272114,
#  1767988.5289537015,
#  1763463.6131775414,
#  1769800.2090166016,
#  1763517.6381890115,
#  1774287.7134049116,
#  1781459.0465341816,
#  1796592.6605001616,
#  1804438.6153670517,
#  1814111.0639975115,
#  1829700.1066425114,
#  1842912.9114337913,
#  1844800.0802704412,
#  1845117.1468291814,
#  1857595.7984012812,
#  1870540.3219341512,
#  1874839.0665891813,
#  1881269.8486789314,
#  1880441.6055843714,
#  1898529.6745319113,
#  1885176.2651216711,
#  1884750.1464358212,
#  1896079.5934041312,
#  1910166.8168577512,
#  1955027.8427684112,
#  1958648.7075977912,
#  1980180.4715176912,
#  1981224.709684561,
#  1991129.583076321,
#  2001449.836793551,
#  2013034.8644113909,
#  2018852.9250511508,
#  2028416.368727011,
#  2043091.3475553012,
#  2018675.995873901,
#  2029801.126252281,
#  2047897.1039380112,
#  2049738.2402011415,
#  2057998.9464566412,
#  2053149.333554171,
#  2064951.5841941112,
#  2064524.2801808212,
#  2077933.841501511,
#  2059628.087561331,
#  2063443.148695231,
#  2048529.779544071,
#  2052051.0519271712,
#  2050327.361165101,
#  2055002.022881871,
#  2061527.203567611,
#  2060000.777922801,
#  2060818.351848591,
#  2073669.9901107408,
#  2077423.3984486808,
#  2066301.1459862406,
#  2080524.3844361305,
#  2082375.8516426708,
#  2120674.831627581,
#  2114519.742773401,
#  2136221.113410281,
#  2137827.226498811,
#  2151311.0173734413,
#  2161947.632867691,
#  2172078.421550471,
#  2181163.453495671,
#  2210123.692982201,
#  2221192.701898151,
#  2249682.161275311,
#  2246405.509504781,
#  2254326.4959497713,
#  2268288.1257887413,
#  2275971.4140166715,
#  2291832.721536801,
#  2298190.401978571,
#  2304544.7433723807,
#  2302442.2341848304,
#  2325644.7005459005,
#  2313732.12129958,
#  2326545.1894423203,
#  2326396.01850693,
#  2342747.59548284,
#  2333252.94607589,
#  2353475.11039396,
#  2362461.42965756,
#  2360385.96432623,
#  2377403.3613702897,
#  2390935.7878379896,
#  2408404.4556786893,
#  2419192.1805195794,
#  2422782.2998105995,
#  2422118.1257505394,
#  2417506.200585429,
#  2410987.532343999,
#  2417688.734361489,
#  2442785.038588229,
#  2447691.7971394593,
#  2449185.3472905895,
#  2453988.6585992696,
#  2465935.6595509895,
#  2463788.7335709697,
#  2494497.8535667597,
#  2507999.66090161,
#  2520520.6803349596,
#  2524297.9376906697,
#  2542748.9344670596,
#  2549994.3298210097,
#  2547794.6660549496,
#  2565262.68533739,
#  2572662.19986582,
#  2584072.00032907,
#  2581632.67821766,
#  2605802.9440209297,
#  2621466.0473485896,
#  2634149.9767924496,
#  2640504.9603888295,
#  2648202.4909077296,
#  2636714.9091884,
#  2629486.87253001,
#  2652813.44725126,
#  2638709.6544031496,
#  2653767.1363709993,
#  2637747.1901901593,
#  2629368.552650159,
#  2645307.306351819,
#  2648709.807621899,
#  2651900.871778139,
#  2654515.240709389,
#  2657895.599894379,
#  2670605.5856372085,
#  2688143.419407039,
#  2696647.996059029,
#  2726128.0382004986,
#  2746198.8751028785,
#  2771664.3904351485,
#  2770533.638038079,
#  2776842.820015229,
#  2776936.539263239,
#  2810637.9398477394,
#  2815709.8682933296,
#  2819444.2136761597,
#  2832046.9659903697,
#  2830171.6770953597,
#  2836996.60794062,
#  2868211.8614429096,
#  2881732.3641068493,
#  2893883.5458730995,
#  2899592.91042296,
#  2904190.62350579,
#  2914663.7745132498,
#  2921128.16367098,
#  2922452.5673104697,
#  2926506.9962992794,
#  2919973.7107335995,
#  2940341.1800845093,
#  2947586.4858632293,
#  2956067.636938469,
#  2962648.831922629,
#  2954929.784570069,
#  2960429.902325699,
#  2968725.404476319,
#  2968977.2061019987,
#  2975124.1074295784,
#  2978398.8735251385,
#  2982564.1963871885,
#  2994262.022288359,
#  3004261.3189225886,
#  3008923.2416834887,
#  3006407.446645569,
#  3001676.529157839,
#  2994630.5436738087,
#  3007529.4302127287,
#  3012856.935810249,
#  3021382.163823629,
#  3041892.3876383887,
#  3050461.8611435485,
#  3071577.5465621585,
#  3082596.6138880285,
#  3097744.2180194487,
#  3113496.980603429,
#  3115813.873398009,
#  3129897.8662495892,
#  3135533.6919458294,
#  3156953.8760048393,
#  3167757.3315958492,
#  3171613.877183259,
#  3150011.487468899,
#  3149229.258904069,
#  3146413.9492024295,
#  3142597.0990083795,
#  3142031.1179258493,
#  3148061.305341929,
#  3157445.5538560594,
#  3163145.7841726993,
#  3163251.9015679895,
#  3163550.3784932094,
#  3167096.777165199,
#  3189299.278744669,
#  3204425.6044314294,
#  3218994.6305816094,
#  3221400.0369156795,
#  3238513.2975650397,
#  3252000.28668965,
#  3267134.1594654,
#  3265911.87383058,
#  3265800.6195502,
#  3277638.7904148204,
#  3287246.78381722,
#  3296807.30115077,
#  3297045.93839733,
#  3303039.6218838203,
#  3310454.69375262,
#  3311276.6045202496,
#  3307912.897895979,
#  3311978.603920239,
#  3305949.837414739,
#  3335134.4969169293,
#  3347281.1360536995,
#  3363000.95500959,
#  3366189.2108124597,
#  3369749.4964962495,
#  3381063.5385758593,
#  3388390.028712519,
#  3391258.2367452187,
#  3392130.5519644585,
#  3405104.7760917386,
#  3431172.2220316287,
#  3435882.2812571786,
#  3435969.2179454486,
#  3446683.5322275585,
#  3459158.8469588486,
#  3475433.2855333486,
#  3488536.9102039486,
#  3495207.9965635887,
#  3512958.018925849,
#  3523540.729450669,
#  3541672.2236209093,
#  3530052.021079889,
#  3516470.2757960293,
#  3518017.318641359,
#  3532402.8501433786,
#  3550953.2775921286,
#  3557130.2133538187,
#  3576350.9775999687,
#  3585334.3002197086,
#  3589674.8096558084,
#  3601659.583758878,
#  3602690.2376563777,
#  3621088.6576433075,
#  3622366.9237394677,
#  3625870.4613408777,
#  3620733.387464978,
#  3626912.749889218,
#  3635680.0801163777,
#  3616432.4614611277,
#  3628191.365419348,
#  3625879.383762118,
#  3642361.555853018,
#  3639930.932985588,
#  3650621.812994518,
#  3668828.0363703375,
#  3651177.216621227,
#  3671716.097877197,
#  3670058.882139037,
#  3681871.486697617,
#  3688280.626204707,
#  3696559.3064997573,
#  3708448.210314257,
#  3714292.149377687,
#  3729355.124738017,
#  3738707.7587370872,
#  3738597.3902895073,
#  3738872.9305946473,
#  3742099.9262009473,
#  3742915.9491683375,
#  3760739.6469747773,
#  3789279.294511577,
#  3800311.0942778373,
#  3810960.5285709673,
#  3818083.5404874873,
#  3833757.7933197175,
#  3843050.6632184377,
#  3850412.3718614276,
#  3861816.2558491076,
#  3869827.391126678,
#  3863786.815873038,
#  3879467.7923359177,
#  3894117.7476639976,
#  3885636.5272881775,
#  3887142.576786678,
#  3905298.573277468,
#  3928716.002206788,
#  3925259.928949648,
#  3913225.257499008,
#  3917364.9230496683,
#  3942184.062078018,
#  3950126.2314434377,
#  3974062.962876308,
#  3984203.122912538,
#  3994413.893082968,
#  3986890.881001528,
#  4011187.435986248,
#  4017438.033288328,
#  4026384.962113248,
#  4055627.4140852583,
#  4053831.379855668,
#  4068524.524180818,
#  4064126.2273481176,
#  4072022.2902008477,
#  4079261.5765707176,
#  4090633.524816178,
#  4108900.6437783376,
#  4123056.161397588,
#  4142598.4745640582,
#  4159425.0707153585,
#  4166753.344401879,
#  4193750.7634707987,
#  4209702.013236298,
#  4228440.393407898,
#  4242784.247967808,
#  4219306.734849988,
#  4228659.191788508,
#  4227352.986210967,
#  4234745.601503577,
#  4223217.563633056,
#  4222938.960102856,
#  4239851.221986456,
#  4245926.433351786,
#  4248286.146696175,
#  4234569.719344135,
#  4246683.513700745,
#  4238070.125510955,
#  4259561.6620788155,
#  4276467.926130395,
#  4290971.256499926,
#  4302630.532193756,
#  4291395.317128326,
#  4311516.167402586,
#  4330342.0489657065,
#  4333083.395000217,
#  4331763.645993486,
#  4332722.071055476,
#  4345819.816606666,
#  4351759.834130656,
#  4345096.746536856,
#  4362821.786797746,
#  4370394.419828855,
#  4386492.176476195,
#  4406911.521534395,
#  4418060.967531905,
#  4442738.505317344,
#  4434440.567467114,
#  4434387.367427614,
#  4446199.041477473,
#  4446155.286142454,
#  4453175.884314483,
#  4459672.741862763,
#  4468760.363536692,
#  4476728.340262952,
#  4495236.449694432,
#  4492976.790169313,
#  4493243.4792890325,
#  4512588.997898143,
#  4528156.914170893,
#  4556734.405617363,
#  4584524.532311202,
#  4586546.914462902,
#  4588980.269507372,
#  4583317.824831352,
#  4596193.458071462,
#  4597110.355394752,
#  4616109.118198711,
#  4626299.865683562,
#  4627048.1278628325,
#  4640691.963939922,
#  4644763.712395002,
#  4646964.511768422,
#  4656166.994724692,
#  4680323.064387912,
#  4691148.131191022,
#  4704170.329535391,
#  4717620.767651201,
#  4734185.632085112,
#  4749659.071226251,
#  4779492.811916752,
#  4790812.1882917015,
#  4807524.102367882,
#  4818943.122045261,
#  4825586.360824831,
#  4841169.83748492,
#  4834980.2465780005,
#  4849973.76946964,
#  4863163.54640251,
#  4868023.6356833195,
#  4883894.034957259,
#  4889050.809561639,
#  4893055.379267939,
#  4898943.85885164,
#  4926253.01350045,
#  4927118.068830331,
#  4906206.877555031,
#  4919269.058245991,
#  4916115.803338301,
#  4924628.718443152,
#  4925635.045257431,
#  4948100.8573779715,
#  4962165.158340922,
#  4962891.533234792,
#  4967751.680649602,
#  4979520.294902052,
#  4977682.1637562625,
#  4984524.078814102,
#  4981406.437557282,
#  4989021.746556052,
#  4989233.316558862,
#  4985003.895601732,
#  4989365.522569262,
#  4985510.284235352,
#  4994082.4550256515,
#  5001303.158405172,
#  5022865.183922232,
#  5048252.649544222,
#  5062450.707673732,
#  5090002.627046142,
#  5105596.733860712,
#  5099486.396429472,
#  5121687.736909541,
#  5131174.005106182,
#  5156805.787255762,
#  5144974.709215443,
#  5164149.802308133,
#  5173444.377637933,
#  5171650.352131353,
#  5173719.425280033,
#  5182034.176356303,
#  5186836.864995723,
#  5193023.647939303,
#  5184198.600793003,
#  5203788.202581204,
#  5207420.449103824,
#  5223684.199223103,
#  5216156.990630473,
#  5209787.668895642,
#  5218815.844504842,
#  5222830.901966471,
#  5220728.393628551,
#  5227051.639077491,
#  5227381.648107541,
#  5216416.31237678,
#  5230874.724222471,
#  5239979.867399701,
#  5253322.9998874,
#  5251331.05444963,
#  5259892.80764728,
#  5261024.11919316,
#  5248437.26221044,
#  5243419.244045059,
#  5250153.988570958,
#  5262292.074662378,
#  5260372.251821699,
#  5281131.679326299,
#  5295924.058027728,
#  5305134.596633428,
#  5301686.920410927,
#  5319377.840987697,
#  5308400.587930847,
#  5304673.858888207,
#  5321920.6892104475,
#  5328375.217084588,
#  5325258.629726298,
#  5341526.0457504885,
#  5352836.929266378,
#  5361288.425590918,
#  5380318.8874002285,
#  5380460.688911629,
#  5381147.970694129,
#  5380073.016560619,
#  5387157.0083395485,
#  5390336.215713679,
#  5403914.205747008,
#  5430193.745305998,
#  5436268.577841698,
#  5465426.095252639,
#  5464290.565384729,
#  5463980.459464858,
#  5482585.524205308,
#  5478188.143230938,
#  5486464.243155168,
#  5483722.148929318,
#  5469732.973671278,
#  5501910.550499148,
#  5509279.409161618,
#  5507465.496328748,
#  5519543.660325837,
#  5501748.365353477,
#  5516857.801185328,
#  5524084.506982848,
#  5529648.463015768,
#  5547977.325075348,
#  5558230.049219498,
#  5561511.855064928,
#  5581432.083425907,
#  5596529.311197757,
#  5608388.429521977,
#  5603444.851117328,
#  5596858.724807748,
#  5610634.922376058,
#  5613556.825335639,
#  5600062.756030869,
#  5624963.731507328]

# %%
sub1=plt.subplot(1, 2, 1)##############################################################
iteration=[]
for i in range(0,999):
    iteration.append(i)

#在同一幅图片上画3条折线
A,=plt.plot(iteration,dynamic_regret,color = 'red',linewidth = '1.5',label='large-attack online primal-dual algorithm')


#设置图例并且设置图例的字体及大小
font1 = {
'size'   : 18,
}
#legend = plt.legend(handles=[A],prop=font1)
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=18)
 
#设置横纵坐标的名称以及对应字体格式
font2 = {
'size'   : 18,
}
plt.xlabel('T',font2)
plt.ylabel(r'Dynamic regret $Reg(T)$',font2)
plt.title('varying $D_{t}$',font2) 

sub2=plt.subplot(1, 2, 2)##############################################################
iteration=[]
for i in range(0,999):
    iteration.append(i)

#在同一幅图片上画3条折线
A,=plt.plot(iteration,dynamic_regret_T,color = 'red',linewidth = '1.5',label='large-attack online primal-dual algorithm')


#设置图例并且设置图例的字体及大小
font1 = {
'size'   : 18,
}
#legend = plt.legend(handles=[A],prop=font1)
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=18)
 
#设置横纵坐标的名称以及对应字体格式
font2 = {
'size'   : 18,
}
plt.xlabel('T',font2)
plt.ylabel(r'Dynamic regret $Reg(T)/T$',font2)
plt.title('varying $D_{t}$',font2) 

plt.legend(handles=[A],prop={'size':18},loc="upper center", bbox_to_anchor=[-0.3, -0.2],
           ncol=18, shadow=True, fancybox=True)

plt.subplots_adjust(wspace=0.5,hspace=0.5) 
plt.gcf().set_size_inches((15, 5))

#plt.savefig('./figures/01-figure1_dynamic_regret_attack_free_varying_D.pdf',format='pdf', bbox_inches='tight')
#plt.savefig('./figures/01-figure1_dynamic_regret_attack_free_varying_D.png',format='png', bbox_inches='tight')

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
from sympy import *
import math 
from datetime import datetime
from scipy.special import gamma, factorial
import scipy.special as sc

# %%
sum_thermal_wind_power_station_strategy=np.loadtxt("./data/04_SCC_optimal_parameters_small_Gaussian_Byzantine_attack_sum_thermal_wind_power_station_strategy.txt")
d_power_demand=np.loadtxt("./data/d_power_demand_normal_distribution_(100,10).txt")

# %%
accumulative_constraint_violation=[]
accumulative_constraint_violation_T=[]
for T in range(1, 1000):
    accumulative_constraint_violation_auxiliary_variable=0
    for t in range(0, T): 
        accumulative_constraint_violation_auxiliary_variable=accumulative_constraint_violation_auxiliary_variable+(1/58)*sum_thermal_wind_power_station_strategy[t+1]-d_power_demand[t+1]
    accumulative_constraint_violation.append(abs(accumulative_constraint_violation_auxiliary_variable))
    accumulative_constraint_violation_T.append(abs(accumulative_constraint_violation_auxiliary_variable)/T)

# %%
accumulative_constraint_violation
# Out:
# [31.98579342931035,
#  51.211853171896564,
#  63.386747959137935,
#  55.1982549674138,
#  67.50183770517242,
#  47.15869851724139,
#  41.912862060172415,
#  26.891930307931048,
#  32.4891152660345,
#  12.557515485689677,
#  9.3639626327586,
#  41.254237708965505,
#  67.84586879293103,
#  85.39771733810345,
#  113.38939768741379,
#  131.20382667086207,
#  138.09536733172416,
#  158.67371456293105,
#  157.19733166293105,
#  166.7371056934483,
#  213.57097533258622,
#  220.11393592931034,
#  237.94110311155174,
#  258.1885922906897,
#  267.8529400265518,
#  283.4564297939656,
#  310.8369379900001,
#  331.48365220086214,
#  351.2254809060346,
#  375.50590805689666,
#  406.8816131210346,
#  425.947685625345,
#  430.201930957414,
#  451.6820155605174,
#  440.47827456517257,
#  466.5902676850002,
#  488.38836188155193,
#  497.2250817001726,
#  502.486940680345,
#  521.068963359483,
#  538.4722597368967,
#  554.6781753548278,
#  561.6847365243106,
#  599.958999144483,
#  619.348450929483,
#  633.8663999058623,
#  643.7679107591382,
#  665.1790383260347,
#  689.7395634305175,
#  694.7709876320693,
#  702.4699627755175,
#  708.8977026693105,
#  706.8645161396553,
#  718.4769092556897,
#  717.3857453015519,
#  724.1175232415519,
#  717.6151361184485,
#  726.1698950072416,
#  746.7845524301727,
#  739.1779238012072,
#  752.7196019710348,
#  768.3685425196554,
#  766.1401208074141,
#  760.2450520267244,
#  773.5437707282761,
#  776.1235435184485,
#  788.3268977039658,
#  798.3641913851727,
#  805.3016948210349,
#  796.5613508072418,
#  794.2411878136211,
#  795.2826535317245,
#  794.8671472120693,
#  813.2375465417244,
#  817.5544784789658,
#  833.4175899236211,
#  844.4602225075866,
#  834.4204835553453,
#  823.4734183031039,
#  821.0030940979315,
#  824.2413138103452,
#  824.8919228248279,
#  826.0839740453451,
#  819.3536499794832,
#  825.1503105031038,
#  823.6954465272418,
#  838.644172769828,
#  830.03711219569,
#  828.9619349336211,
#  833.3379681906902,
#  840.4854013553453,
#  836.6641709981038,
#  843.4765727544832,
#  848.4952312210348,
#  849.0837699487935,
#  861.5046221237935,
#  863.881108272759,
#  869.778196289483,
#  873.510650033621,
#  848.4277929294831,
#  853.6392686241381,
#  854.919519962414,
#  859.2960341215519,
#  861.6343364591381,
#  860.8348825117243,
#  851.2812970377588,
#  850.1885459862071,
#  851.4595421343106,
#  876.986738751552,
#  874.176853971552,
#  858.7732450056899,
#  862.7160598575865,
#  861.7945134160348,
#  846.907623532759,
#  852.62931253069,
#  845.338974766552,
#  829.8600789987934,
#  825.9676754987934,
#  830.1749510148279,
#  840.6601753691382,
#  817.391758837414,
#  805.4204037153451,
#  786.4368991101726,
#  799.7938073360347,
#  805.1266927181036,
#  813.4500107668966,
#  788.6858079044829,
#  798.152801921207,
#  780.1116963305174,
#  779.0425101310346,
#  774.2839150281037,
#  759.1844100267244,
#  753.7155701255176,
#  762.5730306570694,
#  768.6498818355176,
#  755.278699763621,
#  760.7093623082762,
#  754.9694064218969,
#  751.2233380846554,
#  751.2991173222417,
#  763.7499137443107,
#  774.344344926552,
#  750.5863935308623,
#  743.8746079127588,
#  754.0090209084485,
#  749.4953759498278,
#  747.2790030351727,
#  738.4678891560346,
#  736.4854930622415,
#  723.5457625950002,
#  724.7281565720691,
#  717.3382644046553,
#  713.5463503037932,
#  699.3074384877586,
#  697.9033306134482,
#  674.4112408543103,
#  665.4682746143103,
#  640.6678938234483,
#  626.9642134577587,
#  626.1415893743103,
#  618.0826001063792,
#  613.1649263003447,
#  602.6187713024137,
#  623.2710112548275,
#  628.5617695031034,
#  644.4085875246551,
#  631.9378848043103,
#  620.1582566124139,
#  615.5634122665517,
#  621.7148977610345,
#  604.1140970505172,
#  579.9432272282759,
#  583.3662837310345,
#  568.8196224694827,
#  566.3150496405173,
#  555.0642146924138,
#  554.6338805334483,
#  549.1205316282759,
#  532.2703027018965,
#  515.6497209774137,
#  514.028693880862,
#  512.672006730862,
#  521.2681036072413,
#  526.2312851201723,
#  517.3218433381033,
#  514.9488256793103,
#  520.9658410482758,
#  521.7397416098275,
#  516.5055259439655,
#  493.7804228155172,
#  487.6760714636207,
#  452.3446818306897,
#  453.8411193384483,
#  445.3288546193104,
#  430.1099749427587,
#  428.6231020301725,
#  432.3861898331036,
#  414.6750023617243,
#  396.5722373081036,
#  374.7218935765519,
#  359.22647879465535,
#  354.78432251965535,
#  365.9965439256898,
#  358.22771024568976,
#  366.8350285386208,
#  359.54866457534496,
#  341.06521456689666,
#  333.3410541577588,
#  322.03101960241395,
#  303.54710471241395,
#  298.78037965603465,
#  288.6170839287933,
#  272.4033989187933,
#  255.9007679425864,
#  262.11926654086227,
#  248.37338833344847,
#  233.93485025275882,
#  225.0568177787933,
#  231.62868404293124,
#  215.02505598224158,
#  198.42478242431054,
#  182.6394389415519,
#  169.446232835345,
#  176.1895741681036,
#  156.46753833258637,
#  152.35744471465534,
#  136.43610134034498,
#  125.59514982500015,
#  121.63997983500015,
#  111.91734856637946,
#  103.7423021520691,
#  104.75891769913807,
#  94.44349246810359,
#  74.22367767431048,
#  66.76205984017254,
#  56.001769404482886,
#  36.90287147275876,
#  33.436184002931185,
#  27.131585163448435,
#  30.261025146724307,
#  17.01358721827603,
#  8.688542676034643,
#  10.891259042931196,
#  16.38638869086222,
#  27.797876832758774,
#  32.28991759241396,
#  20.695275924655334,
#  10.390943511034635,
#  16.228724571724285,
#  6.19384551275877,
#  3.1036087934481316,
#  3.2140511460346204,
#  0.289148773275997,
#  9.212332708792971,
#  20.24929102672401,
#  32.947642492413664,
#  28.10010375362056,
#  31.04394905068952,
#  36.91026220758607,
#  42.6097400105171,
#  55.67534872948262,
#  46.20222251620676,
#  57.77230919499985,
#  70.05858349362053,
#  84.37803671586188,
#  96.62707425551704,
#  104.88263879344807,
#  109.29732741896531,
#  113.39614739120668,
#  126.00960009068942,
#  120.47591693499974,
#  120.53929495517215,
#  127.77767932206869,
#  143.5555560343101,
#  149.22437859413768,
#  158.11265740534458,
#  158.67198439982735,
#  157.93839863206875,
#  149.80732635689637,
#  170.3759955632757,
#  167.4604432748274,
#  162.40732736034465,
#  175.06682999637917,
#  179.243741878793,
#  185.78122065448264,
#  208.494140619655,
#  217.91855983413777,
#  205.13128330706877,
#  221.40804574793083,
#  228.64791689362048,
#  210.40155462293083,
#  212.74759826327568,
#  235.80019592793087,
#  257.0004750532757,
#  256.53207411879293,
#  241.03373001551708,
#  262.6227722551722,
#  259.23960787982736,
#  250.01385392741358,
#  268.9242623710343,
#  276.5347099474136,
#  288.42968627637913,
#  301.4607892998274,
#  327.97994135551704,
#  342.6606624101722,
#  355.7260741122412,
#  346.2284985927584,
#  341.66825176086184,
#  352.33981428999977,
#  351.50299111793083,
#  371.75297318706873,
#  388.9770469113791,
#  384.55120470206873,
#  394.70523052724116,
#  383.5020512408619,
#  372.38502583275846,
#  372.61864240017223,
#  375.6372803032757,
#  378.99317321344813,
#  379.77696418155153,
#  375.0882683199998,
#  390.72264651068946,
#  425.5272586331033,
#  415.1610433060343,
#  432.0029178331033,
#  443.32875815017223,
#  451.4496116282757,
#  453.8774458698274,
#  463.2084202375861,
#  457.8462721731034,
#  466.8857425522413,
#  480.1264991096551,
#  480.0646843272413,
#  505.33723538982747,
#  522.0635927812067,
#  526.0351551877585,
#  527.6169784829309,
#  546.951039156724,
#  559.3641060763791,
#  579.3309612868964,
#  579.0679798029308,
#  572.5405603287929,
#  554.6281510949998,
#  561.5982512193102,
#  562.7064334812067,
#  564.7576015670687,
#  564.9691035541377,
#  579.7737498553447,
#  573.1170245984481,
#  570.3075350074137,
#  569.5406955831032,
#  572.7939056662067,
#  583.1641630272411,
#  593.6914895868962,
#  598.2056094615514,
#  607.0884914574134,
#  585.070114555172,
#  580.9017752862065,
#  589.3401956418962,
#  607.3790478525859,
#  596.7298837648273,
#  603.286542957586,
#  615.7888540694826,
#  608.5954603913791,
#  614.9184287044825,
#  618.1643136331032,
#  642.5061145582757,
#  663.0574313949999,
#  688.9701968743102,
#  693.1687200853447,
#  719.62425332,
#  729.9481616553447,
#  747.2964417812068,
#  770.6794611968965,
#  789.4554557294827,
#  788.3700538189654,
#  814.0166256277586,
#  834.5697889172413,
#  860.5741009906897,
#  861.3587041158621,
#  865.4018792996552,
#  875.1206158374139,
#  882.37890543,
#  893.1627052875862,
#  905.0480978649999,
#  921.0707557013792,
#  933.8876589951723,
#  936.9583716518963,
#  932.8399870358618,
#  945.4593137725858,
#  968.3969872858617,
#  987.4738125299996,
#  999.0985203077582,
#  1006.7831544465513,
#  1032.11966778862,
#  1042.8539593755165,
#  1056.360117290344,
#  1058.1253740903442,
#  1065.2872856393096,
#  1076.4661395589646,
#  1082.779295890689,
#  1083.192583526551,
#  1099.4064839903442,
#  1106.5482801112062,
#  1115.7495050625855,
#  1119.38823999362,
#  1141.226004757758,
#  1146.309256211896,
#  1144.0916686191374,
#  1147.9307647105168,
#  1146.4117495874132,
#  1129.090246542758,
#  1152.477713073965,
#  1155.96046807431,
#  1143.6799646684478,
#  1165.9633019036203,
#  1161.5724138355167,
#  1148.5501015758616,
#  1141.728655872241,
#  1147.5031066355168,
#  1148.4292161246549,
#  1153.2760361056894,
#  1159.5497580618965,
#  1154.1588039562066,
#  1162.121309352241,
#  1176.6743319287928,
#  1176.7635748086202,
#  1177.6988908282754,
#  1164.4522458641375,
#  1165.1832125827582,
#  1168.6329510141377,
#  1174.5000751722412,
#  1183.0999111531032,
#  1177.2064149099997,
#  1187.1623806744824,
#  1173.8221424762064,
#  1175.001091730689,
#  1181.4745701691372,
#  1180.7009904467236,
#  1178.7049915867235,
#  1193.837778937413,
#  1197.5207485448268,
#  1211.3089549710337,
#  1207.7987833277577,
#  1211.2496227489646,
#  1219.5884496029303,
#  1230.1479939551716,
#  1233.833210501551,
#  1231.4899298655166,
#  1259.277068615689,
#  1278.836691089137,
#  1299.828651094482,
#  1314.7430853951716,
#  1306.3186564108612,
#  1336.1779024827579,
#  1339.490024973275,
#  1346.2250595641372,
#  1357.670504195689,
#  1360.543577191896,
#  1365.7810931360339,
#  1381.7517650974132,
#  1375.2899087555165,
#  1385.7913233943098,
#  1397.3268803063788,
#  1407.998457758103,
#  1400.9709689208617,
#  1410.2669167686204,
#  1426.992785031379,
#  1430.170711342241,
#  1451.5428927389653,
#  1455.6450222836204,
#  1441.9738480681033,
#  1455.4513506724136,
#  1467.06724872431,
#  1487.9565699627583,
#  1505.9044500208618,
#  1507.3436850682754,
#  1511.5384587815513,
#  1511.3631264906892,
#  1516.132554426896,
#  1533.8448776729306,
#  1522.6827738908617,
#  1522.8272044503444,
#  1528.8733989953444,
#  1523.7975829289649,
#  1529.6003336005165,
#  1555.1030887729303,
#  1549.1193568936199,
#  1561.4111866117232,
#  1552.9572622917233,
#  1580.3170105706888,
#  1579.2218786565509,
#  1574.9020087605165,
#  1580.4494012362063,
#  1574.5604460087925,
#  1584.219776931896,
#  1590.5347344603442,
#  1604.3231208379302,
#  1611.260240139999,
#  1619.8918092413783,
#  1634.114942523275,
#  1646.0645877136199,
#  1647.533744348275,
#  1647.5773425458613,
#  1658.8352380793096,
#  1670.532633175344,
#  1674.2042529270682,
#  1679.835300200344,
#  1678.8425857756888,
#  1695.5050509670682,
#  1683.4036571168958,
#  1682.7745652070682,
#  1692.9490169832752,
#  1705.725003507758,
#  1751.6463488612062,
#  1754.6954429749994,
#  1774.7866292696547,
#  1775.4902663353444,
#  1784.3427457887926,
#  1793.583952573965,
#  1804.009817697241,
#  1809.081930086379,
#  1817.6233250086204,
#  1830.9939311563792,
#  1809.4887793222413,
#  1819.4927934796551,
#  1836.2030287751722,
#  1837.6331686406895,
#  1844.9658382875862,
#  1840.3541653027587,
#  1850.9922304150002,
#  1850.3609796087933,
#  1862.5179774696553,
#  1846.1393579989656,
#  1849.3714425179312,
#  1835.908485134138,
#  1838.8696948444826,
#  1837.0678875115516,
#  1841.0823478006896,
#  1846.79564619931,
#  1845.1732282324135,
#  1845.669002607586,
#  1857.2552698260342,
#  1860.4203256210342,
#  1850.2871029408618,
#  1863.1574796365514,
#  1864.5894745151722,
#  1902.4288953025862,
#  1896.676684689138,
#  1916.8257601746552,
#  1918.0365046041381,
#  1930.1968424222416,
#  1939.6961693262072,
#  1948.7261672106897,
#  1956.787379015862,
#  1984.4010523565514,
#  1994.3055797344825,
#  2021.4421089736204,
#  2018.2550894465514,
#  2025.248965317931,
#  2037.8814955246553,
#  2044.6574357370691,
#  2059.1139799984485,
#  2064.6721058013795,
#  2070.2274416684486,
#  2068.089524313621,
#  2089.816316134828,
#  2078.982497129483,
#  2090.542706913966,
#  2090.1645599000003,
#  2105.1151692167246,
#  2096.3931634758624,
#  2115.1606229600006,
#  2123.151155556552,
#  2121.0358843186214,
#  2136.6359212477596,
#  2148.8828193872423,
#  2164.924517017759,
#  2174.5927854900006,
#  2177.616494419483,
#  2176.774175901207,
#  2172.3831684201723,
#  2166.291370116207,
#  2172.171890582931,
#  2195.9025609987934,
#  2200.130243501207,
#  2201.2429553493103,
#  2205.376531718793,
#  2216.1271894836204,
#  2213.9483941268963,
#  2243.567319021379,
#  2255.7810869191376,
#  2267.0697701879308,
#  2270.263374797931,
#  2287.272192751207,
#  2293.653686781207,
#  2291.427087418276,
#  2307.4805884060347,
#  2314.006502221897,
#  2324.2614885712073,
#  2321.818221873104,
#  2344.621463894483,
#  2358.9258080058626,
#  2370.3844865146557,
#  2375.950623187759,
#  2382.759429309483,
#  2372.274783694138,
#  2365.545524243793,
#  2387.516688141379,
#  2374.7560070029303,
#  2388.489397968275,
#  2374.0783844436196,
#  2366.3302472289647,
#  2380.902744903275,
#  2383.754265251379,
#  2386.412013572931,
#  2388.5430736294825,
#  2391.372382188793,
#  2402.8352131384477,
#  2418.926097253448,
#  2426.463408330172,
#  2454.7280074932755,
#  2473.310623242758,
#  2497.3764302222407,
#  2496.1134015882753,
#  2501.6295233941373,
#  2501.472619614137,
#  2534.374304011206,
#  2538.755294772757,
#  2541.9122944124124,
#  2553.29211170224,
#  2551.35637224293,
#  2557.3561097477577,
#  2587.6061275405164,
#  2599.862790658792,
#  2610.8259416405162,
#  2615.800612855516,
#  2619.7543656586195,
#  2629.1506413124125,
#  2634.8247834962053,
#  2635.786593785171,
#  2639.2435058194815,
#  2633.1257748144812,
#  2652.1322425282747,
#  2658.5286587848263,
#  2666.0714338449984,
#  2671.8538416167225,
#  2664.6802905467225,
#  2669.465479797757,
#  2676.8348018008605,
#  2676.81942825155,
#  2682.197570720688,
#  2684.9364621631016,
#  2688.4907424358603,
#  2699.02879068655,
#  2707.9755672753436,
#  2711.984263499654,
#  2709.4685759731024,
#  2704.965287458964,
#  2698.3977805844816,
#  2710.058744976378,
#  2714.6742454532746,
#  2722.2401072494813,
#  2741.2999117632744,
#  2748.902800026033,
#  2768.5651569924125,
#  2778.446707100516,
#  2792.23821933724,
#  2806.6151858822404,
#  2808.4763345349993,
#  2821.2576499301717,
#  2826.156722584482,
#  2846.1535274796543,
#  2855.843227872758,
#  2859.1126671899992,
#  2839.960357177758,
#  2839.0099553575856,
#  2836.22599977862,
#  2832.5430087727577,
#  2831.787287377585,
#  2837.0489616393093,
#  2845.4107787427574,
#  2850.3657639527573,
#  2850.2179709079296,
#  2850.2444161425847,
#  2853.223540823447,
#  2873.9491101717226,
#  2887.6951623024124,
#  2900.9070038012055,
#  2902.844256559654,
#  2918.5051191474126,
#  2930.6892919720676,
#  2944.443051657757,
#  2943.0979622320674,
#  2942.7554989532746,
#  2953.395614390861,
#  2961.9561412939643,
#  2970.472688531378,
#  2970.44650308724,
#  2975.6684692194817,
#  2982.199440684999,
#  2982.7013937305164,
#  2979.432324670689,
#  2982.886140537068,
#  2977.2389165727577,
#  3005.166507671551,
#  3016.085510008792,
#  3030.393014194137,
#  3033.044277705516,
#  3036.0352996377574,
#  3046.178171573102,
#  3052.6232896320676,
#  3054.983586500861,
#  3055.531433198792,
#  3067.2286635258606,
#  3091.8771374808607,
#  3095.9183891303433,
#  3095.75611831224,
#  3105.3415319453434,
#  3116.570466131895,
#  3131.4163210437914,
#  3143.2388147532743,
#  3149.0828362855154,
#  3165.372781250343,
#  3174.840968191033,
#  3191.5133678851707,
#  3180.9390427081016,
#  3168.6586672589633,
#  3169.8200535724113,
#  3182.872491886377,
#  3199.959432284308,
#  3205.3509963010324,
#  3223.0997382451706,
#  3231.083409262929,
#  3234.790889148446,
#  3245.5724576660323,
#  3246.2649224998254,
#  3263.2119297915497,
#  3264.128974134481,
#  3267.0727135156876,
#  3262.215975049308,
#  3267.6127101065495,
#  3275.3980981268946,
#  3258.267265000343,
#  3268.8350174348257,
#  3266.508545684998,
#  3281.5626109781015,
#  3279.130574869653,
#  3288.690991153791,
#  3305.4077988691356,
#  3289.660663613101,
#  3308.677713732411,
#  3306.941919880687,
#  3317.538698799825,
#  3323.1297243684457,
#  3330.411285706032,
#  3341.074771555515,
#  3346.146148788618,
#  3359.807274357756,
#  3368.117465222583,
#  3367.7778167168935,
#  3367.7865816510316,
#  3370.472427527066,
#  3370.969755877583,
#  3387.2853981282724,
#  3414.445423855169,
#  3424.3106864130996,
#  3433.822649005686,
#  3440.074907709651,
#  3454.322015291375,
#  3462.575864570685,
#  3469.047023767237,
#  3479.2624538255127,
#  3486.3307767782712,
#  3480.67254849603,
#  3494.9135605684437,
#  3508.171471642409,
#  3500.344940002581,
#  3501.470224602926,
#  3518.17717447965,
#  3540.1316197524084,
#  3536.7861583058566,
#  3525.8573114774085,
#  3529.385052570167,
#  3552.7577464034425,
#  3559.7747052134428,
#  3582.223482807063,
#  3591.2747320751664,
#  3600.3917114456835,
#  3593.4238266130974,
#  3616.2458881165458,
#  3621.7024927144766,
#  3629.6471767218904,
#  3657.6126859986143,
#  3655.7542056653383,
#  3669.088743185683,
#  3664.8961584443036,
#  3671.8739158362,
#  3678.2463083568896,
#  3688.4538186077516,
#  3705.256317023096,
#  3718.08650625982,
#  3736.1526608803374,
#  3751.5566935729235,
#  3758.015068981544,
#  3783.7039714913717,
#  3798.27715866413,
#  3815.5860916530955,
#  3828.6272125936125,
#  3807.894252497578,
#  3816.2455423601637,
#  3814.8236979455082,
#  3821.3559974127497,
#  3810.8275336255083,
#  3810.334345403784,
#  3825.877930023267,
#  3831.1897473322324,
#  3833.0939516760254,
#  3820.662653233956,
#  3831.589054368094,
#  3823.6317815891284,
#  3843.700869879473,
#  3859.205722583611,
#  3872.3850893360245,
#  3882.870790718266,
#  3872.6139686155075,
#  3891.2915169337834,
#  3908.6765730491284,
#  3910.925478993266,
#  3909.490332274128,
#  3910.117050641714,
#  3921.9609340384377,
#  3927.140525108093,
#  3920.9183026461965,
#  3937.2186874070585,
#  3943.9025217182652,
#  3958.612336580679,
#  3977.5764101546447,
#  3987.5836238277484,
#  4010.879317610507,
#  4003.206103404644,
#  4002.915883101713,
#  4013.5492425463676,
#  4013.266651567747,
#  4019.4450087218847,
#  4025.139951502919,
#  4033.2327237384357,
#  4040.286708312057,
#  4057.372131451367,
#  4055.0886317525733,
#  4055.087455247056,
#  4073.0055103127456,
#  4087.2173997811938,
#  4114.6093650844705,
#  4141.177070349298,
#  4142.771846224298,
#  4144.742634983953,
#  4139.404846912402,
#  4151.062936342574,
#  4151.6529903929195,
#  4169.271704134471,
#  4178.404974818437,
#  4178.84192072585,
#  4191.240025494988,
#  4194.711839216022,
#  4196.471632826022,
#  4204.686840818264,
#  4227.557534924643,
#  4237.288432507229,
#  4249.09871595447,
#  4261.31999424016,
#  4276.560917674988,
#  4290.741368893263,
#  4319.645502328952,
#  4329.8557839782625,
#  4345.269844952055,
#  4355.583763006365,
#  4361.439703576193,
#  4375.77651942809,
#  4369.946743469814,
#  4383.722183121882,
#  4395.751465948261,
#  4399.964467758434,
#  4414.613468823951,
#  4419.101818847917,
#  4422.527440309123,
#  4427.693502085675,
#  4454.100571732744,
#  4454.64466442171,
#  4435.918027885159,
#  4447.850855160504,
#  4444.741695958262,
#  4452.351234062573,
#  4453.023383917229,
#  4474.353968678091,
#  4487.246894853609,
#  4487.66284606516,
#  4491.876467856023,
#  4502.557483736712,
#  4500.638943718436,
#  4506.688583689298,
#  4503.6114252729185,
#  4510.379072785678,
#  4510.324013477574,
#  4506.244105047057,
#  4509.993023186367,
#  4506.251390279298,
#  4513.903044226022,
#  4520.294420084815,
#  4540.626751591195,
#  4564.910487392402,
#  4577.8941271077465,
#  4604.467536374471,
#  4618.817704566712,
#  4613.05301143447,
#  4634.0651270280905,
#  4642.574183513435,
#  4667.17471818809,
#  4656.318642378952,
#  4674.284341406022,
#  4682.622766565677,
#  4680.742973981539,
#  4682.387259032917,
#  4689.811868171021,
#  4693.973371873263,
#  4699.4171259277455,
#  4691.213335129469,
#  4709.621304178779,
#  4712.701121199812,
#  4727.767277696536,
#  4720.722041972744,
#  4714.713082561364,
#  4722.802974849123,
#  4726.234501698949,
#  4724.073058090156,
#  4729.638084275329,
#  4729.688600138087,
#  4719.593703916363,
#  4732.854730158087,
#  4741.002894360673,
#  4753.171378712743,
#  4751.1126234015355,
#  4758.749839959812,
#  4759.530828471708,
#  4748.025434322226,
#  4743.240920214295,
#  4749.173502972054,
#  4760.162264196709,
#  4758.1714877729155,
#  4777.622330211536,
#  4791.145165540846,
#  4799.370380791536,
#  4796.003950383088,
#  4812.362553154984,
#  4802.292918062053,
#  4798.676522123088,
#  4814.584807828778,
#  4820.246864088089,
#  4817.1806397887785,
#  4832.117648564813,
#  4842.298783499813,
#  4849.809467465675,
#  4867.43955436671,
#  4867.315917519124,
#  4867.6885949137795,
#  4866.465654097745,
#  4872.7078586624,
#  4875.356353699297,
#  4887.684698889641,
#  4912.748607703779,
#  4918.057376086021,
#  4946.1690072098145,
#  4944.892950082745,
#  4944.364886138607,
#  4961.612151911538,
#  4957.398083722572,
#  4964.751414958779,
#  4962.025196719813,
#  4949.33378440895,
#  4980.766799491536,
#  4987.276125564985,
#  4985.3872902189505,
#  4996.297731974812,
#  4980.329221809812,
#  4994.143054360157,
#  5000.519746488433,
#  5005.36022777602,
#  5022.319044969468,
#  5031.506798652744,
#  5034.2508150979165,
#  5052.796813036882,
#  5066.586048226537,
#  5077.283322359813,
#  5072.58256475533,
#  5066.413867855503,
#  5078.938598046365,
#  5081.354340105848,
#  5069.1018183105025,
#  5092.73882368964]

# %%
sub1=plt.subplot(1, 2, 1)##############################################################
iteration=[]
for i in range(0,999):
    iteration.append(i)

#在同一幅图片上画3条折线
A,=plt.plot(iteration,accumulative_constraint_violation,color = 'green',linewidth = '1.5',label='attack-free online primal-dual algorithm')


#设置图例并且设置图例的字体及大小
font1 = {
'size'   : 18,
}
#legend = plt.legend(handles=[A],prop=font1)
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=18)
 
#设置横纵坐标的名称以及对应字体格式
font2 = {
'size'   : 18,
}
plt.xlabel('T',font2)
plt.ylabel(r'Constraint violation $Fit(T)$',font2)
plt.title('varying $D_{t}$',font2) 

sub2=plt.subplot(1, 2, 2)##############################################################
iteration=[]
for i in range(0,999):
    iteration.append(i)

#在同一幅图片上画3条折线
A,=plt.plot(iteration,accumulative_constraint_violation_T,color = 'green',linewidth = '1.5',label='attack-free online primal-dual algorithm')


#设置图例并且设置图例的字体及大小
font1 = {
'size'   : 18,
}
#legend = plt.legend(handles=[A],prop=font1)
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=18)
 
#设置横纵坐标的名称以及对应字体格式
font2 = {
'size'   : 18,
}
plt.xlabel('T',font2)
plt.ylabel(r'Constraint violation $Fit(T)/T$',font2)
plt.title('varying $D_{t}$',font2) 

plt.legend(handles=[A],prop={'size':18},loc="upper center", bbox_to_anchor=[-0.3, -0.2],
           ncol=18, shadow=True, fancybox=True)

plt.subplots_adjust(wspace=0.5,hspace=0.5) 
plt.gcf().set_size_inches((15, 5))


#plt.savefig('./figures/01-figure2_constraint_violation_attack_free_varying_D.pdf',format='pdf', bbox_inches='tight')
#plt.savefig('./figures/01-figure2_constraint_violation_attack_free_varying_D.png',format='png', bbox_inches='tight')
